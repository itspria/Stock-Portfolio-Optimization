# %%
import json
import numpy as np
import math
from datetime import datetime
import pandas as pd 
import matplotlib.pyplot as plt
import pymongo

# %% [markdown]
# # SHOP Stock Calculations

# %%
with open('../Data/SHOP_prices.json') as json_file:
    SHOP_data = json.load(json_file)
    
#stock annual return
SHOP_ann_return=round((((SHOP_data[0]['adjclose']/SHOP_data[len(SHOP_data)-1]['adjclose'])-1)*100),2)

SHOP_price_array=[]
for i in range(len(SHOP_data)):
    SHOP_price_array.append(SHOP_data[i]['adjclose'])
    
#daily volatility
SHOP_daily_vol = round(np.std(SHOP_price_array),2)

#annualized volatility
SHOP_ann_vol = SHOP_daily_vol * math.sqrt(252)
SHOP_ann_vol = round(SHOP_ann_vol,2)

#3 mon return volatility
SHOP_date_array=[]

for y in range(len(SHOP_data)):
    SHOP_date_array.append(datetime.strptime(SHOP_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=SHOP_date_array[y]
    if ((firstdate-SHOP_date_array[y]).days==91):
        date_3mon_ago=SHOP_date_array[y]
        mon3_index = y
        
#last three month return
SHOP_3mon_return=round((((SHOP_data[0]['adjclose']/SHOP_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
SHOP_summ_stats = {
    "Ticker": "SHOP",
  "Annual Return": SHOP_ann_return,
  "Daily Volatility": SHOP_daily_vol,
  "Annualized Volatility": SHOP_ann_vol,
  "Last 3 Months Return":  SHOP_3mon_return
}

# convert into JSON:
SHOP_summ_stats = json.dumps(SHOP_summ_stats)

# the result is a JSON string:
print(SHOP_summ_stats)
# Out:
# {"Ticker": "SHOP", "Annual Return": 42.07, "Daily Volatility": 187.12, "Annualized Volatility": 2970.44, "Last 3 Months Return": 18.51}

# %% [markdown]
# # TSLA Stock Calculations

# %%
with open('../Data/TSLA_prices.json') as json_file:
    TSLA_data = json.load(json_file)
    
#stock annual return
TSLA_ann_return=round((((TSLA_data[0]['adjclose']/TSLA_data[len(TSLA_data)-1]['adjclose'])-1)*100),2)

TSLA_price_array=[]
for i in range(len(TSLA_data)):
    TSLA_price_array.append(TSLA_data[i]['adjclose'])
    
#daily volatility
TSLA_daily_vol = round(np.std(TSLA_price_array),2)

#annualized volatility
TSLA_ann_vol = TSLA_daily_vol * math.sqrt(252)
TSLA_ann_vol = round(TSLA_ann_vol,2)

#3 mon return volatility
TSLA_date_array=[]

for y in range(len(TSLA_data)):
    TSLA_date_array.append(datetime.strptime(TSLA_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=TSLA_date_array[y]
    if ((firstdate-TSLA_date_array[y]).days==91):
        date_3mon_ago=TSLA_date_array[y]
        mon3_index = y
        
#last three month return
TSLA_3mon_return=round((((TSLA_data[0]['adjclose']/TSLA_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
TSLA_summ_stats = {
    "Ticker": "TSLA",
  "Annual Return": TSLA_ann_return,
  "Daily Volatility": TSLA_daily_vol,
  "Annualized Volatility": TSLA_ann_vol,
  "Last 3 Months Return":  TSLA_3mon_return
}

# convert into JSON:
TSLA_summ_stats = json.dumps(TSLA_summ_stats)

# the result is a JSON string:
print(TSLA_summ_stats)
# Out:
# {"Ticker": "TSLA", "Annual Return": 65.92, "Daily Volatility": 134.14, "Annualized Volatility": 2129.41, "Last 3 Months Return": 17.11}

# %% [markdown]
# # GOLD Stock Calculations

# %%
with open('../Data/GOLD_prices.json') as json_file:
    GOLD_data = json.load(json_file)
    
#stock annual return
GOLD_ann_return=round((((GOLD_data[0]['adjclose']/GOLD_data[len(GOLD_data)-1]['adjclose'])-1)*100),2)

GOLD_price_array=[]
for i in range(len(GOLD_data)):
    GOLD_price_array.append(GOLD_data[i]['adjclose'])
    
#daily volatility
GOLD_daily_vol = round(np.std(GOLD_price_array),2)

#annualized volatility
GOLD_ann_vol = GOLD_daily_vol * math.sqrt(252)
GOLD_ann_vol = round(GOLD_ann_vol,2)

#3 mon return volatility
GOLD_date_array=[]

for y in range(len(GOLD_data)):
    GOLD_date_array.append(datetime.strptime(GOLD_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=GOLD_date_array[y]
    if ((firstdate-GOLD_date_array[y]).days==91):
        date_3mon_ago=GOLD_date_array[y]
        mon3_index = y
        
#last three month return
GOLD_3mon_return=round((((GOLD_data[0]['adjclose']/GOLD_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
GOLD_summ_stats = {
    "Ticker": "GOLD",
  "Annual Return": GOLD_ann_return,
  "Daily Volatility": GOLD_daily_vol,
  "Annualized Volatility": GOLD_ann_vol,
  "Last 3 Months Return":  GOLD_3mon_return
}

# convert into JSON:
GOLD_summ_stats = json.dumps(GOLD_summ_stats)

# the result is a JSON string:
print(GOLD_summ_stats)
# Out:
# {"Ticker": "GOLD", "Annual Return": -33.02, "Daily Volatility": 2.83, "Annualized Volatility": 44.92, "Last 3 Months Return": -21.41}

# %% [markdown]
# # DAL Stock Calculations

# %%
with open('../Data/DAL_prices.json') as json_file:
    DAL_data = json.load(json_file)
    
#stock annual return
DAL_ann_return=round((((DAL_data[0]['adjclose']/DAL_data[len(DAL_data)-1]['adjclose'])-1)*100),2)

DAL_price_array=[]
for i in range(len(DAL_data)):
    DAL_price_array.append(DAL_data[i]['adjclose'])
    
#daily volatility
DAL_daily_vol = round(np.std(DAL_price_array),2)

#annualized volatility
DAL_ann_vol = DAL_daily_vol * math.sqrt(252)
DAL_ann_vol = round(DAL_ann_vol,2)

#3 mon return volatility
DAL_date_array=[]

for y in range(len(DAL_data)):
    DAL_date_array.append(datetime.strptime(DAL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=DAL_date_array[y]
    if ((firstdate-DAL_date_array[y]).days==91):
        date_3mon_ago=DAL_date_array[y]
        mon3_index = y
        
#last three month return
DAL_3mon_return=round((((DAL_data[0]['adjclose']/DAL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
DAL_summ_stats = {
    "Ticker": "DAL",
  "Annual Return": DAL_ann_return,
  "Daily Volatility": DAL_daily_vol,
  "Annualized Volatility": DAL_ann_vol,
  "Last 3 Months Return":  DAL_3mon_return
}

# convert into JSON:
DAL_summ_stats = json.dumps(DAL_summ_stats)

# the result is a JSON string:
print(DAL_summ_stats)
# Out:
# {"Ticker": "DAL", "Annual Return": 39.79, "Daily Volatility": 6.0, "Annualized Volatility": 95.25, "Last 3 Months Return": -15.68}

# %% [markdown]
# # NFLX Stock Calculations

# %%
with open('../Data/NFLX_prices.json') as json_file:
    NFLX_data = json.load(json_file)
    
#stock annual return
NFLX_ann_return=round((((NFLX_data[0]['adjclose']/NFLX_data[len(NFLX_data)-1]['adjclose'])-1)*100),2)

NFLX_price_array=[]
for i in range(len(NFLX_data)):
    NFLX_price_array.append(NFLX_data[i]['adjclose'])
    
#daily volatility
NFLX_daily_vol = round(np.std(NFLX_price_array),2)

#annualized volatility
NFLX_ann_vol = NFLX_daily_vol * math.sqrt(252)
NFLX_ann_vol = round(NFLX_ann_vol,2)

#3 mon return volatility
NFLX_date_array=[]

for y in range(len(NFLX_data)):
    NFLX_date_array.append(datetime.strptime(NFLX_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=NFLX_date_array[y]
    if ((firstdate-NFLX_date_array[y]).days==91):
        date_3mon_ago=NFLX_date_array[y]
        mon3_index = y
        
#last three month return
NFLX_3mon_return=round((((NFLX_data[0]['adjclose']/NFLX_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
NFLX_summ_stats = {
    "Ticker": "NFLX",
  "Annual Return": NFLX_ann_return,
  "Daily Volatility": NFLX_daily_vol,
  "Annualized Volatility": NFLX_ann_vol,
  "Last 3 Months Return":  NFLX_3mon_return
}

# convert into JSON:
NFLX_summ_stats = json.dumps(NFLX_summ_stats)

# the result is a JSON string:
print(NFLX_summ_stats)
# Out:
# {"Ticker": "NFLX", "Annual Return": 11.08, "Daily Volatility": 23.71, "Annualized Volatility": 376.38, "Last 3 Months Return": 9.84}

# %% [markdown]
# # AAPL Stock Calculations

# %%
with open('../Data/AAPL_prices.json') as json_file:
    AAPL_data = json.load(json_file)
    
#stock annual return
AAPL_ann_return=round((((AAPL_data[0]['adjclose']/AAPL_data[len(AAPL_data)-1]['adjclose'])-1)*100),2)

AAPL_price_array=[]
for i in range(len(AAPL_data)):
    AAPL_price_array.append(AAPL_data[i]['adjclose'])
    
#daily volatility
AAPL_daily_vol = round(np.std(AAPL_price_array),2)

#annualized volatility
AAPL_ann_vol = AAPL_daily_vol * math.sqrt(252)
AAPL_ann_vol = round(AAPL_ann_vol,2)

#3 mon return volatility
AAPL_date_array=[]

for y in range(len(AAPL_data)):
    AAPL_date_array.append(datetime.strptime(AAPL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=AAPL_date_array[y]
    if ((firstdate-AAPL_date_array[y]).days==91):
        date_3mon_ago=AAPL_date_array[y]
        mon3_index = y
        
#last three month return
AAPL_3mon_return=round((((AAPL_data[0]['adjclose']/AAPL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
AAPL_summ_stats = {
    "Ticker": "AAPL",
  "Annual Return": AAPL_ann_return,
  "Daily Volatility": AAPL_daily_vol,
  "Annualized Volatility": AAPL_ann_vol,
  "Last 3 Months Return":  AAPL_3mon_return
}

# convert into JSON:
AAPL_summ_stats = json.dumps(AAPL_summ_stats)

# the result is a JSON string:
print(AAPL_summ_stats)
# Out:
# {"Ticker": "AAPL", "Annual Return": 19.91, "Daily Volatility": 10.44, "Annualized Volatility": 165.73, "Last 3 Months Return": 18.32}

# %% [markdown]
# # PFE Stock Calculations

# %%
with open('../Data/PFE_prices.json') as json_file:
    PFE_data = json.load(json_file)
    
#stock annual return
PFE_ann_return=round((((PFE_data[0]['adjclose']/PFE_data[len(PFE_data)-1]['adjclose'])-1)*100),2)

PFE_price_array=[]
for i in range(len(PFE_data)):
    PFE_price_array.append(PFE_data[i]['adjclose'])
    
#daily volatility
PFE_daily_vol = round(np.std(PFE_price_array),2)

#annualized volatility
PFE_ann_vol = PFE_daily_vol * math.sqrt(252)
PFE_ann_vol = round(PFE_ann_vol,2)

#3 mon return volatility
PFE_date_array=[]

for y in range(len(PFE_data)):
    PFE_date_array.append(datetime.strptime(PFE_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=PFE_date_array[y]
    if ((firstdate-PFE_date_array[y]).days==91):
        date_3mon_ago=PFE_date_array[y]
        mon3_index = y
        
#last three month return
PFE_3mon_return=round((((PFE_data[0]['adjclose']/PFE_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
PFE_summ_stats = {
    "Ticker": "PFE",
  "Annual Return": PFE_ann_return,
  "Daily Volatility": PFE_daily_vol,
  "Annualized Volatility": PFE_ann_vol,
  "Last 3 Months Return":  PFE_3mon_return
}

# convert into JSON:
PFE_summ_stats = json.dumps(PFE_summ_stats)

# the result is a JSON string:
print(PFE_summ_stats)
# Out:
# {"Ticker": "PFE", "Annual Return": 37.43, "Daily Volatility": 3.6, "Annualized Volatility": 57.15, "Last 3 Months Return": 23.06}

# %% [markdown]
# # BTC Stock Calculations

# %%
with open('../Data/BTC_prices.json') as json_file:
    BTC_data = json.load(json_file)
    
#stock annual return
BTC_ann_return=round((((BTC_data[0]['adjclose']/BTC_data[len(BTC_data)-1]['adjclose'])-1)*100),2)

BTC_price_array=[]
for i in range(len(BTC_data)):
    BTC_price_array.append(BTC_data[i]['adjclose'])
    
#daily volatility
BTC_daily_vol = round(np.std(BTC_price_array),2)

#annualized volatility
BTC_ann_vol = BTC_daily_vol * math.sqrt(252)
BTC_ann_vol = round(BTC_ann_vol,2)

#3 mon return volatility
BTC_date_array=[]

for y in range(len(BTC_data)):
    BTC_date_array.append(datetime.strptime(BTC_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=BTC_date_array[y]
    if ((firstdate-BTC_date_array[y]).days==91):
        date_3mon_ago=BTC_date_array[y]
        mon3_index = y
        
#last three month return
BTC_3mon_return=round((((BTC_data[0]['adjclose']/BTC_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
BTC_summ_stats = {
    "Ticker": "BTC",
  "Annual Return": BTC_ann_return,
  "Daily Volatility": BTC_daily_vol,
  "Annualized Volatility": BTC_ann_vol,
  "Last 3 Months Return":  BTC_3mon_return
}

# convert into JSON:
BTC_summ_stats = json.dumps(BTC_summ_stats)

# the result is a JSON string:
print(BTC_summ_stats)
# Out:
# {"Ticker": "BTC", "Annual Return": -0.39, "Daily Volatility": 0.47, "Annualized Volatility": 7.46, "Last 3 Months Return": 0.5}

# %% [markdown]
# # Creating a Dataframe of values

# %%
shop_df = pd.DataFrame(json.loads(SHOP_summ_stats), index=[0])
tsla_df = pd.DataFrame(json.loads(TSLA_summ_stats), index=[0])
gold_df = pd.DataFrame(json.loads(GOLD_summ_stats), index=[0])
dal_df = pd.DataFrame(json.loads(DAL_summ_stats), index=[0])
nflx_df = pd.DataFrame(json.loads(NFLX_summ_stats), index=[0])
aapl_df = pd.DataFrame(json.loads(AAPL_summ_stats), index=[0])
pfe_df = pd.DataFrame(json.loads(PFE_summ_stats), index=[0])
btc_df = pd.DataFrame(json.loads(BTC_summ_stats), index=[0])


stocks_calc = shop_df.append([tsla_df,gold_df,dal_df,nflx_df,aapl_df,pfe_df,btc_df])
stocks_calc.reset_index(inplace = True,drop = True)

stocks_calc
# Out:
#   Ticker  Annual Return  Daily Volatility  Annualized Volatility  \
# 0   SHOP          42.07            187.12                2970.44
# 1   TSLA          65.92            134.14                2129.41
# 2   GOLD         -33.02              2.83                  44.92
# 3    DAL          39.79              6.00                  95.25
# 4   NFLX          11.08             23.71                 376.38
# 5   AAPL          19.91             10.44                 165.73
# 6    PFE          37.43              3.60                  57.15
# 7    BTC          -0.39              0.47                   7.46
#
#    Last 3 Months Return
# 0                 18.51
# 1                 17.11
# 2                -21.41
# 3                -15.68
# 4                  9.84
# 5                 18.32
# 6                 23.06
# 7                  0.50

# %% [markdown]
# # Get daily returns and asssets covariance

# %%
#created dataframes for daily prices
SHOP_data_df = pd.DataFrame(SHOP_data)
SHOP_data_df = SHOP_data_df[["formatted_date", "adjclose"]]
SHOP_data_df.set_index("formatted_date", inplace = True)
SHOP_data_df = SHOP_data_df.rename (columns = {"adjclose": "SHOP"})

TSLA_data_df = pd.DataFrame(TSLA_data)
TSLA_data_df = TSLA_data_df[["formatted_date", "adjclose"]]
TSLA_data_df.set_index("formatted_date", inplace = True)
TSLA_data_df = TSLA_data_df.rename (columns = {"adjclose": "TSLA"})

GOLD_data_df = pd.DataFrame(GOLD_data)
GOLD_data_df = GOLD_data_df[["formatted_date", "adjclose"]]
GOLD_data_df.set_index("formatted_date", inplace = True)
GOLD_data_df = GOLD_data_df.rename (columns = {"adjclose": "GOLD"})

DAL_data_df = pd.DataFrame(DAL_data)
DAL_data_df = DAL_data_df[["formatted_date", "adjclose"]]
DAL_data_df.set_index("formatted_date", inplace = True)
DAL_data_df = DAL_data_df.rename (columns = {"adjclose": "DAL"})

NFLX_data_df = pd.DataFrame(NFLX_data)
NFLX_data_df = NFLX_data_df[["formatted_date", "adjclose"]]
NFLX_data_df.set_index("formatted_date", inplace = True)
NFLX_data_df = NFLX_data_df.rename (columns = {"adjclose": "NFLX"})

AAPL_data_df = pd.DataFrame(AAPL_data)
AAPL_data_df = AAPL_data_df[["formatted_date", "adjclose"]]
AAPL_data_df.set_index("formatted_date", inplace = True)
AAPL_data_df = AAPL_data_df.rename (columns = {"adjclose": "AAPL"})

PFE_data_df = pd.DataFrame(PFE_data)
PFE_data_df = PFE_data_df[["formatted_date", "adjclose"]]
PFE_data_df.set_index("formatted_date", inplace = True)
PFE_data_df = PFE_data_df.rename (columns = {"adjclose": "PFE"})

BTC_data_df = pd.DataFrame(BTC_data)
BTC_data_df = BTC_data_df[["formatted_date", "adjclose"]]
BTC_data_df.set_index("formatted_date", inplace = True)
BTC_data_df = BTC_data_df.rename (columns = {"adjclose": "BTC"})
#BTC_data_df

# %%
#merge assest into a single dataframe
assets_all = pd.concat([SHOP_data_df, TSLA_data_df,GOLD_data_df , DAL_data_df, NFLX_data_df, AAPL_data_df,PFE_data_df,BTC_data_df],axis=1, join="inner")
assets_all
# Out:
#                    SHOP    TSLA   GOLD    DAL    NFLX    AAPL    PFE     BTC
# formatted_date
# 2021-08-19      1466.11  673.47  19.13  37.93  543.71  146.70  48.80   99.61
# 2021-08-18      1489.18  688.99  19.46  38.65  521.87  146.36  49.31   99.55
# 2021-08-17      1481.87  665.71  19.97  38.78  518.91  150.19  50.42   99.60
# 2021-08-16      1489.00  686.17  20.19  39.93  517.92  151.12  48.91   99.65
# 2021-08-13      1498.00  717.17  20.27  39.90  515.92  149.10  48.48   99.58
# ...                 ...     ...    ...    ...     ...     ...    ...     ...
# 2020-10-07      1073.43  425.30  26.47  32.15  534.66  114.34  33.25   99.92
# 2020-10-06      1041.25  413.98  26.58  31.06  505.87  112.44  32.98  100.03
# 2020-10-05      1065.53  425.68  27.86  32.00  520.65  115.76  33.50  100.00
# 2020-10-02      1028.99  415.09  27.39  31.75  503.06  112.30  33.17  100.00
# 2020-10-01      1054.43  448.16  27.76  31.10  527.51  116.04  33.16  100.00
#
# [223 rows x 8 columns]

# %%
#calculate daily pricec changes
assets_all_pricechng = assets_all.pct_change()
#assets_all_pricechng

# %%
#calculate covariance
assets_all_cov = assets_all_pricechng.cov()
assets_all_cov
# Out:
#           SHOP      TSLA      GOLD       DAL      NFLX      AAPL  \
# SHOP  0.001044  0.000428  0.000132 -0.000113  0.000343  0.000245
# TSLA  0.000428  0.001229  0.000096  0.000143  0.000249  0.000263
# GOLD  0.000132  0.000096  0.000409  0.000015  0.000102  0.000101
# DAL  -0.000113  0.000143  0.000015  0.000634 -0.000046  0.000030
# NFLX  0.000343  0.000249  0.000102 -0.000046  0.000504  0.000189
# AAPL  0.000245  0.000263  0.000101  0.000030  0.000189  0.000327
# PFE  -0.000036 -0.000003  0.000026  0.000062 -0.000039  0.000026
# BTC   0.000009  0.000008  0.000003 -0.000005  0.000005  0.000004
#
#                PFE           BTC
# SHOP -3.579589e-05  9.423874e-06
# TSLA -2.910476e-06  7.966360e-06
# GOLD  2.627074e-05  3.028141e-06
# DAL   6.154588e-05 -4.739645e-06
# NFLX -3.868208e-05  5.046523e-06
# AAPL  2.644448e-05  4.075365e-06
# PFE   2.206190e-04 -1.272857e-07
# BTC  -1.272857e-07  9.158551e-07

# %%
# convert into JSON:
assets_all_json = assets_all_cov.to_json()
assets_all_json = json.dumps(assets_all_json)

# %% [markdown]
# # Calculate portfolio return and volatility

# %% [markdown]
# ref: https://www.machinelearningplus.com/machine-learning/portfolio-optimization-python-example/

# %%
portfolio_return = []
portfolio_volati = []
asset_weights = []

# %%
#calculate number of assest and max number of portfolios to itterate
num_assets = stocks_calc["Ticker"].count()
print(num_assets)
num_portf = 1000
# Out:
# 8

# %% [markdown]
# for portfolio in range(num_portf):
#     #portfolio returns
#     weights = np.random.random(num_assets)
#     weights = weights/np.sum(weights)
#     asset_weights.append(weights)
# asset_weights

# %% [markdown]
# len(asset_weights)

# %%
for portfolio in range(num_portf):
    #portfolio returns
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    asset_weights.append(weights)
    portf_return = np.dot(weights, stocks_calc["Annual Return"])
    portfolio_return.append(portf_return)
    
    #portfolio risk
    portf_var = assets_all_cov.mul(weights, axis=0).mul(weights, axis=1).sum().sum()
    portf_stdev = np.sqrt(portf_var) # Daily standard deviation
    portf_ann_stdev = portf_stdev*np.sqrt(250) # Annual standard deviation = volatility
    portfolio_volati.append(portf_ann_stdev)
    
    
#portfolio_return

# %%
print(len(portfolio_return), len(portfolio_volati), len(asset_weights))
# Out:
# 1000 1000 1000

# %% [markdown]
# #plot the graph
# plt.figure(figsize=(12,8))
# plt.scatter(portfolio_volati,portfolio_return, marker = "o",facecolors = 'green')
# plt.title(f"Efficient Frontier", fontsize = 13, fontweight = 'bold', y=1.05)
# plt.xlabel("Risk")
# plt.ylabel("Return")
# plt.grid()
# plt.ylim(-20,60)
# plt.xlim(0.05,0.4)
#
# plt.show()

# %%
data = {'Returns':portfolio_return, 'Volatility':portfolio_volati}

for counter, symbol in enumerate(assets_all.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in asset_weights]
    
portfolios  = pd.DataFrame(data)
portf = portfolios.to_dict(orient='records')
portf
# Out:
# [{'Returns': 29.69784349148868,
#   'Volatility': 0.19117430196631874,
#   'SHOP weight': 0.10086224121126677,
#   'TSLA weight': 0.13889514173088394,
#   'GOLD weight': 0.05683654632918506,
#   'DAL weight': 0.2036800123624427,
#   'NFLX weight': 0.06286146736957926,
#   'AAPL weight': 0.19716528523571822,
#   'PFE weight': 0.14654503359247983,
#   'BTC weight': 0.09315427216844428},
#  {'Returns': 23.30251184074931,
#   'Volatility': 0.1906000085038309,
#   'SHOP weight': 0.13621437021667465,
#   'TSLA weight': 0.11323911209381948,
#   'GOLD weight': 0.13826940053447914,
#   'DAL weight': 0.08567535291776594,
#   'NFLX weight': 0.08918850868878363,
#   'AAPL weight': 0.18754019427750115,
#   'PFE weight': 0.1755473527001251,
#   'BTC weight': 0.07432570857085084},
#  {'Returns': 16.879993684289413,
#   'Volatility': 0.14616084302766513,
#   'SHOP weight': 0.023402433009613456,
#   'TSLA weight': 0.046224551383306535,
#   'GOLD weight': 0.10281948910106481,
#   'DAL weight': 0.17561407256934605,
#   'NFLX weight': 0.09475996280936279,
#   'AAPL weight': 0.2227981249632366,
#   'PFE weight': 0.10312808460678208,
#   'BTC weight': 0.23125328155728772},
#  {'Returns': 24.272941585503823,
#   'Volatility': 0.1999579545532018,
#   'SHOP weight': 0.027291452173426385,
#   'TSLA weight': 0.22114531881788158,
#   'GOLD weight': 0.17695647831435676,
#   'DAL weight': 0.07476960347362757,
#   'NFLX weight': 0.013280134343138695,
#   'AAPL weight': 0.19995833578056657,
#   'PFE weight': 0.19562057900508234,
#   'BTC weight': 0.0909780980919202},
#  {'Returns': 33.09026563191193,
#   'Volatility': 0.26019229827069673,
#   'SHOP weight': 0.06739557966738252,
#   'TSLA weight': 0.329049354495404,
#   'GOLD weight': 0.0569168577622669,
#   'DAL weight': 0.016980469114192803,
#   'NFLX weight': 0.22707563207225862,
#   'AAPL weight': 0.08177669131368702,
#   'PFE weight': 0.15096996586151443,
#   'BTC weight': 0.06983544971329357},
#  {'Returns': 30.32567384987304,
#   'Volatility': 0.194492408543291,
#   'SHOP weight': 0.24936185998786736,
#   'TSLA weight': 0.10000061223165238,
#   'GOLD weight': 0.06795398947107094,
#   'DAL weight': 0.052800121004363994,
#   'NFLX weight': 0.0071293089868987155,
#   'AAPL weight': 0.10111490062325378,
#   'PFE weight': 0.302965437214734,
#   'BTC weight': 0.1186737704801588},
#  {'Returns': 31.725538631157796,
#   'Volatility': 0.21775344543470307,
#   'SHOP weight': 0.16461408144391765,
#   'TSLA weight': 0.1799103438426869,
#   'GOLD weight': 0.001873906469453683,
#   'DAL weight': 0.07381890207788712,
#   'NFLX weight': 0.1296977592685849,
#   'AAPL weight': 0.18381638500463127,
#   'PFE weight': 0.13411332631000988,
#   'BTC weight': 0.1321552955828286},
#  {'Returns': 15.851503305685494,
#   'Volatility': 0.2107468999531567,
#   'SHOP weight': 0.08766027606407573,
#   'TSLA weight': 0.13295725364153804,
#   'GOLD weight': 0.2218812264033733,
#   'DAL weight': 0.04602018307865094,
#   'NFLX weight': 0.21721541427700872,
#   'AAPL weight': 0.14419130268470712,
#   'PFE weight': 0.09718143073028782,
#   'BTC weight': 0.052892913120358445},
#  {'Returns': 22.97538349179844,
#   'Volatility': 0.17305011159280295,
#   'SHOP weight': 0.06764882604277346,
#   'TSLA weight': 0.08031710955640647,
#   'GOLD weight': 0.1294021773176923,
#   'DAL weight': 0.16594808308232276,
#   'NFLX weight': 0.11431648972215232,
#   'AAPL weight': 0.18688479763393892,
#   'PFE weight': 0.20139646594086438,
#   'BTC weight': 0.05408605070384928},
#  {'Returns': 25.35696664773089,
#   'Volatility': 0.19723215382126305,
#   'SHOP weight': 0.13102183890520508,
#   'TSLA weight': 0.15794838111353918,
#   'GOLD weight': 0.11543274687611231,
#   'DAL weight': 0.19315857526960814,
#   'NFLX weight': 0.06686531723160302,
#   'AAPL weight': 0.12868168035972102,
#   'PFE weight': 0.06177942603022116,
#   'BTC weight': 0.14511203421399},
#  {'Returns': 26.10469724222329,
#   'Volatility': 0.2615573956961358,
#   'SHOP weight': 0.2642607873396333,
#   'TSLA weight': 0.19425716384457414,
#   'GOLD weight': 0.15764045472678842,
#   'DAL weight': 0.07430851936661567,
#   'NFLX weight': 0.05200545049598361,
#   'AAPL weight': 0.17889120288809873,
#   'PFE weight': 0.008542820492223645,
#   'BTC weight': 0.07009360084608247},
#  {'Returns': 20.264141630768425,
#   'Volatility': 0.19216516519564217,
#   'SHOP weight': 0.2492056136121599,
#   'TSLA weight': 0.003611677929968588,
#   'GOLD weight': 0.09675005625858096,
#   'DAL weight': 0.024864252879795743,
#   'NFLX weight': 0.08746438167710645,
#   'AAPL weight': 0.18539997394963176,
#   'PFE weight': 0.19102204228591396,
#   'BTC weight': 0.1616820014068426},
#  {'Returns': 33.27948676232553,
#   'Volatility': 0.24181361082313815,
#   'SHOP weight': 0.0013276931199747842,
#   'TSLA weight': 0.27477392035227294,
#   'GOLD weight': 0.030676376641047224,
#   'DAL weight': 0.062573609991381,
#   'NFLX weight': 0.053991595934382255,
#   'AAPL weight': 0.3798919720155806,
#   'PFE weight': 0.1467087820452728,
#   'BTC weight': 0.05005604990008835},
#  {'Returns': 22.42406404956032,
#   'Volatility': 0.20753461168100032,
#   'SHOP weight': 0.08757539967372663,
#   'TSLA weight': 0.16951945803383708,
#   'GOLD weight': 0.09961804507013408,
#   'DAL weight': 0.15075662450914554,
#   'NFLX weight': 0.2376008621812262,
#   'AAPL weight': 0.07926823683398704,
#   'PFE weight': 0.018865305608211497,
#   'BTC weight': 0.15679606808973184},
#  {'Returns': 44.07419033139884,
#   'Volatility': 0.31345260535282793,
#   'SHOP weight': 0.2818192912235338,
#   'TSLA weight': 0.3589379688698776,
#   'GOLD weight': 0.020977451325402765,
#   'DAL weight': 0.06697487891994487,
#   'NFLX weight': 0.004258514031006012,
#   'AAPL weight': 0.13834089560084323,
#   'PFE weight': 0.10135496497614384,
#   'BTC weight': 0.02733603505324797},
#  {'Returns': 16.580989246443995,
#   'Volatility': 0.18791815728655956,
#   'SHOP weight': 0.023974935980216706,
#   'TSLA weight': 0.17856244571196578,
#   'GOLD weight': 0.18591319417903113,
#   'DAL weight': 0.07493524964151946,
#   'NFLX weight': 0.189882732263411,
#   'AAPL weight': 0.08631305055755956,
#   'PFE weight': 0.08561282442224466,
#   'BTC weight': 0.17480556724405175},
#  {'Returns': 19.612379390865726,
#   'Volatility': 0.17325607197237552,
#   'SHOP weight': 0.106415710107155,
#   'TSLA weight': 0.019595801379978857,
#   'GOLD weight': 0.050178994101885005,
#   'DAL weight': 0.1915174935715931,
#   'NFLX weight': 0.21417683752573188,
#   'AAPL weight': 0.18634466575474581,
#   'PFE weight': 0.0499030511582745,
#   'BTC weight': 0.18186744640063607},
#  {'Returns': 15.470143631057367,
#   'Volatility': 0.20065277413687324,
#   'SHOP weight': 0.22026163771649623,
#   'TSLA weight': 0.02812696861556611,
#   'GOLD weight': 0.21089685006214834,
#   'DAL weight': 0.14809938502051317,
#   'NFLX weight': 0.20298591482802877,
#   'AAPL weight': 0.0061938738337121765,
#   'PFE weight': 0.08248762692275469,
#   'BTC weight': 0.10094774300078047},
#  {'Returns': 16.05823898146248,
#   'Volatility': 0.17336151740359282,
#   'SHOP weight': 0.11197557841878464,
#   'TSLA weight': 0.01347655945299263,
#   'GOLD weight': 0.10967236725522009,
#   'DAL weight': 0.18344606568540192,
#   'NFLX weight': 0.1595608963870447,
#   'AAPL weight': 0.2226605891254034,
#   'PFE weight': 0.017390223372983415,
#   'BTC weight': 0.18181772030216906},
#  {'Returns': 25.90806921410227,
#   'Volatility': 0.17154751172965063,
#   'SHOP weight': 0.10252831798195562,
#   'TSLA weight': 0.11467164728147308,
#   'GOLD weight': 0.04358197856006998,
#   'DAL weight': 0.10075278735344148,
#   'NFLX weight': 0.048958299218558265,
#   'AAPL weight': 0.23828042340887892,
#   'PFE weight': 0.16700234211186288,
#   'BTC weight': 0.18422420408375975},
#  {'Returns': 21.58532721652503,
#   'Volatility': 0.1795891902874434,
#   'SHOP weight': 0.13589080761481626,
#   'TSLA weight': 0.06490089796316556,
#   'GOLD weight': 0.06695718465175035,
#   'DAL weight': 0.006242059332548548,
#   'NFLX weight': 0.13648042875401886,
#   'AAPL weight': 0.226225403923848,
#   'PFE weight': 0.20301495914871823,
#   'BTC weight': 0.16028825861113413},
#  {'Returns': 27.22629831747708,
#   'Volatility': 0.25965454150924383,
#   'SHOP weight': 0.2369703486570097,
#   'TSLA weight': 0.23063284972046183,
#   'GOLD weight': 0.12982226680255024,
#   'DAL weight': 0.019708710641276144,
#   'NFLX weight': 0.18143286163682967,
#   'AAPL weight': 0.015698079825990374,
#   'PFE weight': 0.08740802954244639,
#   'BTC weight': 0.09832685317343558},
#  {'Returns': 20.089092443397334,
#   'Volatility': 0.17585539698974556,
#   'SHOP weight': 0.11208953477246963,
#   'TSLA weight': 0.142309061850387,
#   'GOLD weight': 0.15307312109112303,
#   'DAL weight': 0.10734183911424762,
#   'NFLX weight': 0.08262246482238401,
#   'AAPL weight': 0.09537772106562036,
#   'PFE weight': 0.10791090275270096,
#   'BTC weight': 0.19927535453106737},
#  {'Returns': 17.524411334406285,
#   'Volatility': 0.17151848761216656,
#   'SHOP weight': 0.036091636072175866,
#   'TSLA weight': 0.14476436990235603,
#   'GOLD weight': 0.19377372345502972,
#   'DAL weight': 0.13595696047995237,
#   'NFLX weight': 0.09872347465713682,
#   'AAPL weight': 0.10832803760765566,
#   'PFE weight': 0.11399533593487135,
#   'BTC weight': 0.16836646189082216},
#  {'Returns': 22.230334924904003,
#   'Volatility': 0.18242961322540682,
#   'SHOP weight': 0.049640783025221,
#   'TSLA weight': 0.1719915605772001,
#   'GOLD weight': 0.1963893762258726,
#   'DAL weight': 0.14670392883653174,
#   'NFLX weight': 0.0035292201522473454,
#   'AAPL weight': 0.13474266830370704,
#   'PFE weight': 0.18100719353955128,
#   'BTC weight': 0.11599526933966892},
#  {'Returns': 29.15982945256264,
#   'Volatility': 0.1620606173138589,
#   'SHOP weight': 0.0714976937149577,
#   'TSLA weight': 0.1508654103973217,
#   'GOLD weight': 0.013980090421921864,
#   'DAL weight': 0.13826646716534916,
#   'NFLX weight': 0.02602375538396873,
#   'AAPL weight': 0.15037343642245327,
#   'PFE weight': 0.2131068873641668,
#   'BTC weight': 0.23588625912986075},
#  {'Returns': 16.99642197479132,
#   'Volatility': 0.21361953693387922,
#   'SHOP weight': 0.2050875373543501,
#   'TSLA weight': 0.07564361755458868,
#   'GOLD weight': 0.14723709349898473,
#   'DAL weight': 0.006498689774478294,
#   'NFLX weight': 0.18905407147301145,
#   'AAPL weight': 0.1402836175686235,
#   'PFE weight': 0.08433363902632683,
#   'BTC weight': 0.15186173374963632},
#  {'Returns': 16.40065555080497,
#   'Volatility': 0.1667047844175402,
#   'SHOP weight': 0.061610726789533145,
#   'TSLA weight': 0.029091146637422387,
#   'GOLD weight': 0.004107571427789137,
#   'DAL weight': 0.03202251178940193,
#   'NFLX weight': 0.2045832688531875,
#   'AAPL weight': 0.3058994400232096,
#   'PFE weight': 0.06707210374318583,
#   'BTC weight': 0.29561323073627044},
#  {'Returns': 16.54417976990949,
#   'Volatility': 0.1763246746387912,
#   'SHOP weight': 0.08851315669324597,
#   'TSLA weight': 0.08566754004167695,
#   'GOLD weight': 0.14003569816552963,
#   'DAL weight': 0.09370073922879604,
#   'NFLX weight': 0.1766742155396681,
#   'AAPL weight': 0.1654241480844851,
#   'PFE weight': 0.07708096845911767,
#   'BTC weight': 0.1729035337874806},
#  {'Returns': 20.51176195042947,
#   'Volatility': 0.1762323467402904,
#   'SHOP weight': 0.08728886479517507,
#   'TSLA weight': 0.12109775722442441,
#   'GOLD weight': 0.1582244384417352,
#   'DAL weight': 0.12126597392678731,
#   'NFLX weight': 0.14824258141503335,
#   'AAPL weight': 0.08777780328893156,
#   'PFE weight': 0.15794947773808873,
#   'BTC weight': 0.11815310316982441},
#  {'Returns': 25.28937683388083,
#   'Volatility': 0.2039556864488056,
#   'SHOP weight': 0.03703016693178966,
#   'TSLA weight': 0.17338766189972513,
#   'GOLD weight': 0.11374449395000577,
#   'DAL weight': 0.1459915426341598,
#   'NFLX weight': 0.13843366010262828,
#   'AAPL weight': 0.22544814977827546,
#   'PFE weight': 0.113454553623963,
#   'BTC weight': 0.05250977107945298},
#  {'Returns': 17.39022738190779,
#   'Volatility': 0.1638958181075885,
#   'SHOP weight': 0.12872059221706483,
#   'TSLA weight': 0.004777075809954477,
#   'GOLD weight': 0.1360963719164427,
#   'DAL weight': 0.15819470654706208,
#   'NFLX weight': 0.1461250369990862,
#   'AAPL weight': 0.15500391880859934,
#   'PFE weight': 0.13907749126894817,
#   'BTC weight': 0.13200480643284235},
#  {'Returns': 15.3930445246239,
#   'Volatility': 0.2203192635352663,
#   'SHOP weight': 0.052128285419314045,
#   'TSLA weight': 0.16027429387855466,
#   'GOLD weight': 0.217348074463646,
#   'DAL weight': 0.03152712999391451,
#   'NFLX weight': 0.23530429604529962,
#   'AAPL weight': 0.182143141560249,
#   'PFE weight': 0.06268510406963275,
#   'BTC weight': 0.058589674569389495},
#  {'Returns': 19.32283618028722,
#   'Volatility': 0.24929845771427334,
#   'SHOP weight': 0.2144091595155491,
#   'TSLA weight': 0.14796905194672696,
#   'GOLD weight': 0.22924130675718948,
#   'DAL weight': 0.01613797871560118,
#   'NFLX weight': 0.05407908341677922,
#   'AAPL weight': 0.26287123203448226,
#   'PFE weight': 0.04421846087449305,
#   'BTC weight': 0.031073726739178773},
#  {'Returns': 15.947479159113389,
#   'Volatility': 0.15913378787744334,
#   'SHOP weight': 0.045101768505653186,
#   'TSLA weight': 0.004033479552097254,
#   'GOLD weight': 0.20314787009577062,
#   'DAL weight': 0.2570927979814721,
#   'NFLX weight': 0.14343469311604257,
#   'AAPL weight': 0.024382086712596226,
#   'PFE weight': 0.2198194639684432,
#   'BTC weight': 0.10298784006792493},
#  {'Returns': 27.70480108211676,
#   'Volatility': 0.17946279804405635,
#   'SHOP weight': 0.0764827338401692,
#   'TSLA weight': 0.08125745542727847,
#   'GOLD weight': 0.06216921656540632,
#   'DAL weight': 0.24044514722674312,
#   'NFLX weight': 0.17612671848040007,
#   'AAPL weight': 0.11332887774690395,
#   'PFE weight': 0.1984639919515248,
#   'BTC weight': 0.05172585876157401},
#  {'Returns': 24.612113786983556,
#   'Volatility': 0.17295252066308192,
#   'SHOP weight': 0.21724590799141566,
#   'TSLA weight': 0.026321864545896217,
#   'GOLD weight': 0.031243161246605165,
#   'DAL weight': 0.17250784707275987,
#   'NFLX weight': 0.1831736022911644,
#   'AAPL weight': 0.00013822933959178605,
#   'PFE weight': 0.15908888095847534,
#   'BTC weight': 0.21028050655409167},
#  {'Returns': 4.771399514702553,
#   'Volatility': 0.18570386195472566,
#   'SHOP weight': 0.05166403323919205,
#   'TSLA weight': 0.10009618673422123,
#   'GOLD weight': 0.2913199798867053,
#   'DAL weight': 0.009818388691515738,
#   'NFLX weight': 0.227284509451853,
#   'AAPL weight': 0.05470696951899954,
#   'PFE weight': 0.04558777901771281,
#   'BTC weight': 0.21952215345980028},
#  {'Returns': 32.38500548736456,
#   'Volatility': 0.2514785985367916,
#   'SHOP weight': 0.06360506863947372,
#   'TSLA weight': 0.3362953822035802,
#   'GOLD weight': 0.1311804690138889,
#   'DAL weight': 0.15254946872286007,
#   'NFLX weight': 0.03953299170806903,
#   'AAPL weight': 0.10903393221151722,
#   'PFE weight': 0.08616436517362312,
#   'BTC weight': 0.08163832232698771},
#  {'Returns': 18.046678908400025,
#   'Volatility': 0.1544871983485291,
#   'SHOP weight': 0.16510325157580982,
#   'TSLA weight': 0.00663611606753127,
#   'GOLD weight': 0.10458075263174202,
#   'DAL weight': 0.05788982888908203,
#   'NFLX weight': 0.08030139552833707,
#   'AAPL weight': 0.16276939809031143,
#   'PFE weight': 0.20749695493707615,
#   'BTC weight': 0.21522230228011013},
#  {'Returns': 23.434913791465135,
#   'Volatility': 0.19962257190630156,
#   'SHOP weight': 0.12186355193059664,
#   'TSLA weight': 0.18311840676380634,
#   'GOLD weight': 0.10914969467168484,
#   'DAL weight': 0.0075170243738561715,
#   'NFLX weight': 0.15299896231895213,
#   'AAPL weight': 0.0888996400075656,
#   'PFE weight': 0.16414504314721243,
#   'BTC weight': 0.17230767678632591},
#  {'Returns': 24.17386238365774,
#   'Volatility': 0.19235186581987865,
#   'SHOP weight': 0.23744755149545524,
#   'TSLA weight': 0.0684437425329771,
#   'GOLD weight': 0.08122673479438393,
#   'DAL weight': 0.13514529323340596,
#   'NFLX weight': 0.11303088749277328,
#   'AAPL weight': 0.08256659415124293,
#   'PFE weight': 0.1108159469383701,
#   'BTC weight': 0.17132324936139143},
#  {'Returns': 22.189503503509297,
#   'Volatility': 0.19966971722613272,
#   'SHOP weight': 0.20209857345786272,
#   'TSLA weight': 0.12752091081233205,
#   'GOLD weight': 0.13601356533879566,
#   'DAL weight': 0.17737056103300342,
#   'NFLX weight': 0.07126839132429516,
#   'AAPL weight': 0.07168914696702884,
#   'PFE weight': 0.015365463810184606,
#   'BTC weight': 0.1986733872564976},
#  {'Returns': 21.23884825817659,
#   'Volatility': 0.1822632547619785,
#   'SHOP weight': 0.10007834047311481,
#   'TSLA weight': 0.10703751597841647,
#   'GOLD weight': 0.08962767366248832,
#   'DAL weight': 0.04718654437650015,
#   'NFLX weight': 0.17898089329354824,
#   'AAPL weight': 0.17341819367944936,
#   'PFE weight': 0.151696448914562,
#   'BTC weight': 0.1519743896219207},
#  {'Returns': 24.727306070746444,
#   'Volatility': 0.18109115747099652,
#   'SHOP weight': 0.010409238321060173,
#   'TSLA weight': 0.16138955632263702,
#   'GOLD weight': 0.16389012791879953,
#   'DAL weight': 0.24440242055002645,
#   'NFLX weight': 0.04372389201538425,
#   'AAPL weight': 0.04785766048583863,
#   'PFE weight': 0.21227420409549327,
#   'BTC weight': 0.11605290029076067},
#  {'Returns': 17.459042267143662,
#   'Volatility': 0.23187728936768492,
#   'SHOP weight': 0.16201999903918904,
#   'TSLA weight': 0.10066117486617934,
#   'GOLD weight': 0.20382640850165493,
#   'DAL weight': 0.08817832955341205,
#   'NFLX weight': 0.22489753277531652,
#   'AAPL weight': 0.17759940606552366,
#   'PFE weight': 0.03220090921346474,
#   'BTC weight': 0.010616239985259679},
#  {'Returns': 20.65487055449009,
#   'Volatility': 0.19560620929711606,
#   'SHOP weight': 0.0017407591126494184,
#   'TSLA weight': 0.12753809932886268,
#   'GOLD weight': 0.16685386944646174,
#   'DAL weight': 0.22847566018275348,
#   'NFLX weight': 0.09737275409533766,
#   'AAPL weight': 0.24951307267416656,
#   'PFE weight': 0.0686466267902173,
#   'BTC weight': 0.059859158369551184},
#  {'Returns': 21.327810884957387,
#   'Volatility': 0.18608462408672446,
#   'SHOP weight': 0.04578470533622631,
#   'TSLA weight': 0.12220839009887363,
#   'GOLD weight': 0.14655236881819603,
#   'DAL weight': 0.15210522194650997,
#   'NFLX weight': 0.23883652527491078,
#   'AAPL weight': 0.07591785458799674,
#   'PFE weight': 0.16023221926526474,
#   'BTC weight': 0.05836271467202197},
#  {'Returns': 13.246090611982668,
#   'Volatility': 0.1705259474207549,
#   'SHOP weight': 0.017894888140886286,
#   'TSLA weight': 0.11123719704231196,
#   'GOLD weight': 0.18331548225738814,
#   'DAL weight': 0.13851611949154075,
#   'NFLX weight': 0.24071683060297777,
#   'AAPL weight': 0.04611962849699698,
#   'PFE weight': 0.05866978120116886,
#   'BTC weight': 0.20353007276672933},
#  {'Returns': 23.684855506482897,
#   'Volatility': 0.18199387082861354,
#   'SHOP weight': 0.18943526983913436,
#   'TSLA weight': 0.07642678886375544,
#   'GOLD weight': 0.07203487587639687,
#   'DAL weight': 0.20332850665971525,
#   'NFLX weight': 0.10865014624244715,
#   'AAPL weight': 0.08755054559491027,
#   'PFE weight': 0.05607717950395436,
#   'BTC weight': 0.2064966874196863},
#  {'Returns': 30.21383422328345,
#   'Volatility': 0.2346044585833981,
#   'SHOP weight': 0.21113338832433495,
#   'TSLA weight': 0.11103269933554602,
#   'GOLD weight': 0.00994776906873491,
#   'DAL weight': 0.06611292794332937,
#   'NFLX weight': 0.2407407916770868,
#   'AAPL weight': 0.1789574362381342,
#   'PFE weight': 0.14676302712511013,
#   'BTC weight': 0.035311960287723605},
#  {'Returns': 32.314130671750725,
#   'Volatility': 0.19229635117859023,
#   'SHOP weight': 0.15798128779066273,
#   'TSLA weight': 0.10908733160480479,
#   'GOLD weight': 0.07151545163800013,
#   'DAL weight': 0.24205515744431916,
#   'NFLX weight': 0.015779830213085107,
#   'AAPL weight': 0.13753796603835278,
#   'PFE weight': 0.222036537048047,
#   'BTC weight': 0.04400643822272843},
#  {'Returns': 23.96915374795247,
#   'Volatility': 0.16054236779514708,
#   'SHOP weight': 0.10045435372358272,
#   'TSLA weight': 0.10562852382041188,
#   'GOLD weight': 0.0905742657309874,
#   'DAL weight': 0.20758208852483556,
#   'NFLX weight': 0.11857818109904363,
#   'AAPL weight': 0.01427525601804826,
#   'PFE weight': 0.16008844563245514,
#   'BTC weight': 0.20281888545063548},
#  {'Returns': 34.46516121021842,
#   'Volatility': 0.24989440937714738,
#   'SHOP weight': 0.20427266381959253,
#   'TSLA weight': 0.21969037462470856,
#   'GOLD weight': 0.034879319434159145,
#   'DAL weight': 0.15833349067895444,
#   'NFLX weight': 0.14149903117807788,
#   'AAPL weight': 0.12338140448792732,
#   'PFE weight': 0.0598284320997577,
#   'BTC weight': 0.05811528367682238},
#  {'Returns': 19.60926658056114,
#   'Volatility': 0.1902879446890373,
#   'SHOP weight': 0.13198319974647538,
#   'TSLA weight': 0.13574646073725094,
#   'GOLD weight': 0.1654578768378836,
#   'DAL weight': 0.15578105909017892,
#   'NFLX weight': 0.09786662821092922,
#   'AAPL weight': 0.10303589527725565,
#   'PFE weight': 0.034885266396292795,
#   'BTC weight': 0.17524361370373348},
#  {'Returns': 17.79409283739118,
#   'Volatility': 0.20998865406331557,
#   'SHOP weight': 0.10272876023259314,
#   'TSLA weight': 0.09901280586814944,
#   'GOLD weight': 0.22581009845082223,
#   'DAL weight': 0.2099073076706767,
#   'NFLX weight': 0.1347113303887819,
#   'AAPL weight': 0.19376398339824444,
#   'PFE weight': 0.018832643799501208,
#   'BTC weight': 0.01523307019123096},
#  {'Returns': 19.844342721218162,
#   'Volatility': 0.16870068677965724,
#   'SHOP weight': 0.0747878049074695,
#   'TSLA weight': 0.03513393770155723,
#   'GOLD weight': 0.1746914416911321,
#   'DAL weight': 0.1891419779553494,
#   'NFLX weight': 0.04558388998100614,
#   'AAPL weight': 0.22376433222451714,
#   'PFE weight': 0.2052965367993816,
#   'BTC weight': 0.05160007873958686},
#  {'Returns': 22.52856635205494,
#   'Volatility': 0.17809629048384332,
#   'SHOP weight': 0.1452252746723869,
#   'TSLA weight': 0.12444551456713197,
#   'GOLD weight': 0.10669052969028761,
#   'DAL weight': 0.019969739811196322,
#   'NFLX weight': 0.11562555861400663,
#   'AAPL weight': 0.09130066884398766,
#   'PFE weight': 0.2115181972994046,
#   'BTC weight': 0.1852245165015983},
#  {'Returns': 18.010643949564056,
#   'Volatility': 0.15768857989996246,
#   'SHOP weight': 0.023646759198340934,
#   'TSLA weight': 0.011932434545756801,
#   'GOLD weight': 0.09669408725889633,
#   'DAL weight': 0.21097869016246448,
#   'NFLX weight': 0.11431259778101191,
#   'AAPL weight': 0.26795647578285603,
#   'PFE weight': 0.11984889372985578,
#   'BTC weight': 0.1546300615408176},
#  {'Returns': 34.22345592244654,
#   'Volatility': 0.1869069568332101,
#   'SHOP weight': 0.1401368285703026,
#   'TSLA weight': 0.17998367376239824,
#   'GOLD weight': 0.014902593442833657,
#   'DAL weight': 0.19047702840159578,
#   'NFLX weight': 0.0728443649218189,
#   'AAPL weight': 0.0022740975254067395,
#   'PFE weight': 0.22950143711293997,
#   'BTC weight': 0.16987997626270412},
#  {'Returns': 27.47337526119354,
#   'Volatility': 0.19282091706342766,
#   'SHOP weight': 0.11132249804948491,
#   'TSLA weight': 0.15860120421321683,
#   'GOLD weight': 0.09950406613073966,
#   'DAL weight': 0.1901139290699033,
#   'NFLX weight': 0.16583922079847765,
#   'AAPL weight': 0.021688155717103978,
#   'PFE weight': 0.15561530213737637,
#   'BTC weight': 0.09731562388369724},
#  {'Returns': 30.24567984069808,
#   'Volatility': 0.21477258433116042,
#   'SHOP weight': 0.1127766939842452,
#   'TSLA weight': 0.20041420657460463,
#   'GOLD weight': 0.11212184371546195,
#   'DAL weight': 0.19502680412469367,
#   'NFLX weight': 0.1485081136494799,
#   'AAPL weight': 0.051071309008914774,
#   'PFE weight': 0.14912581994790647,
#   'BTC weight': 0.03095520899469354},
#  {'Returns': 10.756365672896532,
#   'Volatility': 0.1734223650965479,
#   'SHOP weight': 0.004029494939581835,
#   'TSLA weight': 0.055600488632979894,
#   'GOLD weight': 0.20932428758040725,
#   'DAL weight': 0.14649074697232237,
#   'NFLX weight': 0.27101075569890615,
#   'AAPL weight': 0.10504173784038848,
#   'PFE weight': 0.07910675729464378,
#   'BTC weight': 0.12939573104077026},
#  {'Returns': 20.536518550399936,
#   'Volatility': 0.16612828921048514,
#   'SHOP weight': 0.04723866254936192,
#   'TSLA weight': 0.12160226873531674,
#   'GOLD weight': 0.09197491433791623,
#   'DAL weight': 0.1143072952153949,
#   'NFLX weight': 0.008757937229927373,
#   'AAPL weight': 0.2879744692641863,
#   'PFE weight': 0.08776461041027411,
#   'BTC weight': 0.24037984225762238},
#  {'Returns': 14.994566270351381,
#   'Volatility': 0.15052333972591236,
#   'SHOP weight': 0.0906527766970217,
#   'TSLA weight': 0.02777973933388323,
#   'GOLD weight': 0.16221053081205963,
#   'DAL weight': 0.10600424972877712,
#   'NFLX weight': 0.21138684703865812,
#   'AAPL weight': 0.01716879927456644,
#   'PFE weight': 0.21030988794431985,
#   'BTC weight': 0.17448716917071394},
#  {'Returns': 25.206938893555204,
#   'Volatility': 0.20099144054352075,
#   'SHOP weight': 0.2057957920804979,
#   'TSLA weight': 0.114407831326136,
#   'GOLD weight': 0.006052169746390137,
#   'DAL weight': 0.05017326013157393,
#   'NFLX weight': 0.17409866356968248,
#   'AAPL weight': 0.10638364598162324,
#   'PFE weight': 0.08718898172258178,
#   'BTC weight': 0.2558996554415146},
#  {'Returns': 27.002650433046114,
#   'Volatility': 0.18870053241267576,
#   'SHOP weight': 0.08682326360348348,
#   'TSLA weight': 0.1262992707404922,
#   'GOLD weight': 0.15422869521959218,
#   'DAL weight': 0.22233755115210474,
#   'NFLX weight': 0.05035387916910259,
#   'AAPL weight': 0.12617773067630114,
#   'PFE weight': 0.21922851958131612,
#   'BTC weight': 0.014551089857607441},
#  {'Returns': 17.83836964283,
#   'Volatility': 0.19741498250970346,
#   'SHOP weight': 0.0714773204119994,
#   'TSLA weight': 0.1631857175604621,
#   'GOLD weight': 0.12259824928773914,
#   'DAL weight': 0.06981795587931051,
#   'NFLX weight': 0.24882997182723493,
#   'AAPL weight': 0.07523882031285539,
#   'PFE weight': 0.03136608314439838,
#   'BTC weight': 0.21748588157600018},
#  {'Returns': 35.26493748261406,
#   'Volatility': 0.22777835258046253,
#   'SHOP weight': 0.201106704872027,
#   'TSLA weight': 0.21277755764637338,
#   'GOLD weight': 0.057333870493375315,
#   'DAL weight': 0.14176231374326756,
#   'NFLX weight': 0.05221819533392505,
#   'AAPL weight': 0.10222577504405916,
#   'PFE weight': 0.17206069382169742,
#   'BTC weight': 0.060514889045275196},
#  {'Returns': 24.389382155755797,
#   'Volatility': 0.1901955992457442,
#   'SHOP weight': 0.11714073326728687,
#   'TSLA weight': 0.1485184046313329,
#   'GOLD weight': 0.09809014954950492,
#   'DAL weight': 0.11677247183716687,
#   'NFLX weight': 0.1374542127648223,
#   'AAPL weight': 0.12223192406486266,
#   'PFE weight': 0.11655703311943075,
#   'BTC weight': 0.14323507076559264},
#  {'Returns': 16.387545092751523,
#   'Volatility': 0.21554971557091737,
#   'SHOP weight': 0.15363804259423047,
#   'TSLA weight': 0.14785666256878688,
#   'GOLD weight': 0.18583978554006966,
#   'DAL weight': 0.024406247811863076,
#   'NFLX weight': 0.15936826939415527,
#   'AAPL weight': 0.13102026102782702,
#   'PFE weight': 0.02763993457271823,
#   'BTC weight': 0.17023079649034947},
#  {'Returns': 21.035622422288487,
#   'Volatility': 0.2244885728798796,
#   'SHOP weight': 0.13281509291359533,
#   'TSLA weight': 0.2144955154073085,
#   'GOLD weight': 0.17610151639573823,
#   'DAL weight': 0.055878377216220715,
#   'NFLX weight': 0.04671842875257534,
#   'AAPL weight': 0.1964598318364636,
#   'PFE weight': 0.014280810943721436,
#   'BTC weight': 0.16325042653437694},
#  {'Returns': 11.956773176555835,
#   'Volatility': 0.17484065340750263,
#   'SHOP weight': 0.07502398919676706,
#   'TSLA weight': 0.09718432491780742,
#   'GOLD weight': 0.25943482583054744,
#   'DAL weight': 0.06196929821993373,
#   'NFLX weight': 0.1542498547814943,
#   'AAPL weight': 0.0721528590538534,
#   'PFE weight': 0.14432694609196609,
#   'BTC weight': 0.1356579019076305},
#  {'Returns': 24.9302113750331,
#   'Volatility': 0.23281674616779047,
#   'SHOP weight': 0.16215466090275393,
#   'TSLA weight': 0.17415718465595592,
#   'GOLD weight': 0.029728999921848527,
#   'DAL weight': 0.016710883682474375,
#   'NFLX weight': 0.14085247655924954,
#   'AAPL weight': 0.26543391368532226,
#   'PFE weight': 0.004798761652754871,
#   'BTC weight': 0.20616311893964048},
#  {'Returns': 30.46338778518064,
#   'Volatility': 0.2708967000020349,
#   'SHOP weight': 0.23921089210291493,
#   'TSLA weight': 0.2296404998074006,
#   'GOLD weight': 0.04274566917565896,
#   'DAL weight': 0.037822886691915115,
#   'NFLX weight': 0.18528420069755808,
#   'AAPL weight': 0.12328884980222211,
#   'PFE weight': 0.018935111824342703,
#   'BTC weight': 0.12307188989798755},
#  {'Returns': 26.106839209885152,
#   'Volatility': 0.23663786125622255,
#   'SHOP weight': 0.18179809888264392,
#   'TSLA weight': 0.18028243229225208,
#   'GOLD weight': 0.11878306403237873,
#   'DAL weight': 0.05195472559770237,
#   'NFLX weight': 0.13957505915066873,
#   'AAPL weight': 0.1823875861479894,
#   'PFE weight': 0.08747013282991385,
#   'BTC weight': 0.05774890106645107},
#  {'Returns': 19.85197504032172,
#   'Volatility': 0.16176211118583034,
#   'SHOP weight': 0.06405091065979593,
#   'TSLA weight': 0.04759304205106384,
#   'GOLD weight': 0.1011952623171121,
#   'DAL weight': 0.13373726640858732,
#   'NFLX weight': 0.18816900852875348,
#   'AAPL weight': 0.16543243837846816,
#   'PFE weight': 0.17922632928353682,
#   'BTC weight': 0.12059574237268239},
#  {'Returns': 20.553302475523694,
#   'Volatility': 0.14304000785512208,
#   'SHOP weight': 0.05526269671023399,
#   'TSLA weight': 0.02206797193737981,
#   'GOLD weight': 0.09612364122056424,
#   'DAL weight': 0.22086892723456467,
#   'NFLX weight': 0.10618752353466379,
#   'AAPL weight': 0.09970674373468016,
#   'PFE weight': 0.21558710412546547,
#   'BTC weight': 0.18419539150244785},
#  {'Returns': 25.031359901493772,
#   'Volatility': 0.2077386131653177,
#   'SHOP weight': 0.20555613860554453,
#   'TSLA weight': 0.098586291198113,
#   'GOLD weight': 0.15230963645240791,
#   'DAL weight': 0.089323745449247,
#   'NFLX weight': 0.054235965383499736,
#   'AAPL weight': 0.19175213906276203,
#   'PFE weight': 0.18567873311274433,
#   'BTC weight': 0.022557350735681513},
#  {'Returns': 14.475982047866442,
#   'Volatility': 0.20328000638842234,
#   'SHOP weight': 0.11839869958458375,
#   'TSLA weight': 0.13312604133582612,
#   'GOLD weight': 0.22344983115109557,
#   'DAL weight': 0.009888811614519136,
#   'NFLX weight': 0.17843348434547748,
#   'AAPL weight': 0.10483915882007347,
#   'PFE weight': 0.09862913836132038,
#   'BTC weight': 0.13323483478710418},
#  {'Returns': 29.59035765401807,
#   'Volatility': 0.21579532448356167,
#   'SHOP weight': 0.061769394092033976,
#   'TSLA weight': 0.24537619802366759,
#   'GOLD weight': 0.11299946852439384,
#   'DAL weight': 0.00274005341291885,
#   'NFLX weight': 0.1984589378345992,
#   'AAPL weight': 0.030721246570457054,
#   'PFE weight': 0.311048267567363,
#   'BTC weight': 0.03688643397456644},
#  {'Returns': 12.981846641072128,
#   'Volatility': 0.16966937436880716,
#   'SHOP weight': 0.03414168296217331,
#   'TSLA weight': 0.04927668313794023,
#   'GOLD weight': 0.13853061933242813,
#   'DAL weight': 0.12805632634084121,
#   'NFLX weight': 0.20950204828670774,
#   'AAPL weight': 0.21859645683554188,
#   'PFE weight': 0.0314412552208758,
#   'BTC weight': 0.19045492788349172},
#  {'Returns': 10.340999129869324,
#   'Volatility': 0.16088759208472111,
#   'SHOP weight': 0.06898047942389787,
#   'TSLA weight': 0.03631140286971328,
#   'GOLD weight': 0.18192698569488872,
#   'DAL weight': 0.17578317935425447,
#   'NFLX weight': 0.24473112391638097,
#   'AAPL weight': 0.021616235400911028,
#   'PFE weight': 0.02701514214835603,
#   'BTC weight': 0.24363545119159769},
#  {'Returns': 30.827589807605296,
#   'Volatility': 0.21127954556125103,
#   'SHOP weight': 0.20481536717478774,
#   'TSLA weight': 0.19609008015507592,
#   'GOLD weight': 0.09225634432734395,
#   'DAL weight': 0.1285275458741778,
#   'NFLX weight': 0.010768667835915744,
#   'AAPL weight': 0.07382780250922279,
#   'PFE weight': 0.1518313805775335,
#   'BTC weight': 0.14188281154594273},
#  {'Returns': 27.64180759370828,
#   'Volatility': 0.2134861517367743,
#   'SHOP weight': 0.08900127555711593,
#   'TSLA weight': 0.21006391149243267,
#   'GOLD weight': 0.17129398939803991,
#   'DAL weight': 0.11923231919819502,
#   'NFLX weight': 0.06931802742605193,
#   'AAPL weight': 0.14430290550255287,
#   'PFE weight': 0.19560066089068884,
#   'BTC weight': 0.0011869105349226472},
#  {'Returns': 25.617597455613065,
#   'Volatility': 0.1691610735466628,
#   'SHOP weight': 0.1893522707742308,
#   'TSLA weight': 0.06655403516664365,
#   'GOLD weight': 0.051780965657502405,
#   'DAL weight': 0.18500683118290995,
#   'NFLX weight': 0.03573974689830493,
#   'AAPL weight': 0.12726428117890293,
#   'PFE weight': 0.12737019022365886,
#   'BTC weight': 0.21693167891784648},
#  {'Returns': 20.79242058157451,
#   'Volatility': 0.18701985834606222,
#   'SHOP weight': 0.1995925708541721,
#   'TSLA weight': 0.0669719247234775,
#   'GOLD weight': 0.07126040891297691,
#   'DAL weight': 0.14927826020506224,
#   'NFLX weight': 0.2091528193775812,
#   'AAPL weight': 0.0189183316202718,
#   'PFE weight': 0.04788507065920772,
#   'BTC weight': 0.2369406136472506},
#  {'Returns': 24.535959966051813,
#   'Volatility': 0.2175637632517989,
#   'SHOP weight': 0.17924374346378127,
#   'TSLA weight': 0.11987906435685146,
#   'GOLD weight': 0.07020083604274459,
#   'DAL weight': 0.0356017530888021,
#   'NFLX weight': 0.1685614085151925,
#   'AAPL weight': 0.208792253223008,
#   'PFE weight': 0.10720207842271824,
#   'BTC weight': 0.1105188628869018},
#  {'Returns': 26.46753718934109,
#   'Volatility': 0.22018399844515654,
#   'SHOP weight': 0.18328441458027747,
#   'TSLA weight': 0.13679313833644416,
#   'GOLD weight': 0.02297951658039733,
#   'DAL weight': 0.015737236963072023,
#   'NFLX weight': 0.06918259932185117,
#   'AAPL weight': 0.31485381756774716,
#   'PFE weight': 0.0776565435528326,
#   'BTC weight': 0.17951273309737797},
#  {'Returns': 20.639944178037283,
#   'Volatility': 0.19501591679320493,
#   'SHOP weight': 0.2553873337422816,
#   'TSLA weight': 0.00020906188436538664,
#   'GOLD weight': 0.18187373720481334,
#   'DAL weight': 0.2515384012869498,
#   'NFLX weight': 0.006743936654001466,
#   'AAPL weight': 0.11426083231935438,
#   'PFE weight': 0.09527272145866895,
#   'BTC weight': 0.09471397544956503},
#  {'Returns': 21.50705657467569,
#   'Volatility': 0.19658231219249514,
#   'SHOP weight': 0.05211094337558166,
#   'TSLA weight': 0.22935428190357637,
#   'GOLD weight': 0.17411146008812936,
#   'DAL weight': 0.05785288403635226,
#   'NFLX weight': 0.13595896927917647,
#   'AAPL weight': 0.03524525282930322,
#   'PFE weight': 0.146952499681395,
#   'BTC weight': 0.16841370880648573},
#  {'Returns': 13.29075602481901,
#   'Volatility': 0.1854437556940471,
#   'SHOP weight': 0.12264554845223716,
#   'TSLA weight': 0.07293430050940664,
#   'GOLD weight': 0.228740364835747,
#   'DAL weight': 0.12724532262233856,
#   'NFLX weight': 0.06556202102702056,
#   'AAPL weight': 0.20908470866432047,
#   'PFE weight': 0.026219398342609678,
#   'BTC weight': 0.14756833554631998},
#  {'Returns': 22.4398150044847,
#   'Volatility': 0.19870566639064907,
#   'SHOP weight': 0.11285234866670053,
#   'TSLA weight': 0.1956414197477724,
#   'GOLD weight': 0.18953792284649332,
#   'DAL weight': 0.07950645044183406,
#   'NFLX weight': 0.08036501500066535,
#   'AAPL weight': 0.06830344329564379,
#   'PFE weight': 0.1519520983445476,
#   'BTC weight': 0.12184130165634295},
#  {'Returns': 26.584074490975915,
#   'Volatility': 0.2261162224461867,
#   'SHOP weight': 0.17283370471949766,
#   'TSLA weight': 0.20328875250312164,
#   'GOLD weight': 0.20547977587462676,
#   'DAL weight': 0.05135876101200047,
#   'NFLX weight': 0.01593313019178393,
#   'AAPL weight': 0.13618783322285022,
#   'PFE weight': 0.20754421633282172,
#   'BTC weight': 0.007373826143297527},
#  {'Returns': 25.73269288984897,
#   'Volatility': 0.2127650337235357,
#   'SHOP weight': 0.0744257963936991,
#   'TSLA weight': 0.20230426236168556,
#   'GOLD weight': 0.03691140239876735,
#   'DAL weight': 0.11449700755755908,
#   'NFLX weight': 0.16734049716689287,
#   'AAPL weight': 0.19587543747980676,
#   'PFE weight': 0.006769972264247853,
#   'BTC weight': 0.20187562437734147},
#  {'Returns': 22.87565409973426,
#   'Volatility': 0.2326742407820671,
#   'SHOP weight': 0.09903731622814066,
#   'TSLA weight': 0.2456845063001728,
#   'GOLD weight': 0.12305141049184248,
#   'DAL weight': 0.004142048637901266,
#   'NFLX weight': 0.1547435354258163,
#   'AAPL weight': 0.15592353459579336,
#   'PFE weight': 0.044362082135700025,
#   'BTC weight': 0.17305556618463314},
#  {'Returns': 14.418527554196524,
#   'Volatility': 0.12831129466696728,
#   'SHOP weight': 0.029644555685590768,
#   'TSLA weight': 0.01474323294363998,
#   'GOLD weight': 0.11897719712039602,
#   'DAL weight': 0.11188058995218754,
#   'NFLX weight': 0.14403151581434187,
#   'AAPL weight': 0.13419347230156187,
#   'PFE weight': 0.2004994925156265,
#   'BTC weight': 0.24602994366665548},
#  {'Returns': 22.198480607840253,
#   'Volatility': 0.19719738695690534,
#   'SHOP weight': 0.1521431201093492,
#   'TSLA weight': 0.12318009813202639,
#   'GOLD weight': 0.14887703548487505,
#   'DAL weight': 0.12102435881289786,
#   'NFLX weight': 0.1501754420521851,
#   'AAPL weight': 0.09450645001574633,
#   'PFE weight': 0.1140803039654585,
#   'BTC weight': 0.09601319142746156},
#  {'Returns': 25.174737696284275,
#   'Volatility': 0.19432716617230514,
#   'SHOP weight': 0.1559156954694049,
#   'TSLA weight': 0.14140423738081037,
#   'GOLD weight': 0.11338941767417296,
#   'DAL weight': 0.053820245055477195,
#   'NFLX weight': 0.09720581603538953,
#   'AAPL weight': 0.1325601126308309,
#   'PFE weight': 0.19300688899997903,
#   'BTC weight': 0.11269758675393513},
#  {'Returns': 21.122848827956513,
#   'Volatility': 0.22590220464454658,
#   'SHOP weight': 0.16115578086755633,
#   'TSLA weight': 0.17313838977195511,
#   'GOLD weight': 0.17487071545265795,
#   'DAL weight': 0.05395638343048529,
#   'NFLX weight': 0.1740396699012403,
#   'AAPL weight': 0.10157523118631938,
#   'PFE weight': 0.0705769301606438,
#   'BTC weight': 0.09068689922914176},
#  {'Returns': 20.51383270102594,
#   'Volatility': 0.1637334870657074,
#   'SHOP weight': 0.03785736603605548,
#   'TSLA weight': 0.023595459705013474,
#   'GOLD weight': 0.08871617455546382,
#   'DAL weight': 0.15608471591792264,
#   'NFLX weight': 0.1961613510218164,
#   'AAPL weight': 0.2150962513171911,
#   'PFE weight': 0.20461909831568015,
#   'BTC weight': 0.07786958313085693},
#  {'Returns': 21.28991848062096,
#   'Volatility': 0.1729836738921488,
#   'SHOP weight': 0.1147056882063423,
#   'TSLA weight': 0.11777203713298048,
#   'GOLD weight': 0.1432092743238628,
#   'DAL weight': 0.1021709011451304,
#   'NFLX weight': 0.09867222052977914,
#   'AAPL weight': 0.10926010680953359,
#   'PFE weight': 0.16441016532411243,
#   'BTC weight': 0.14979960652825894},
#  {'Returns': 30.72577531110376,
#   'Volatility': 0.2491334551206865,
#   'SHOP weight': 0.13701945053271375,
#   'TSLA weight': 0.26973522153736224,
#   'GOLD weight': 0.1331354999003107,
#   'DAL weight': 0.02860674370813639,
#   'NFLX weight': 0.1635118005093684,
#   'AAPL weight': 0.07924586650723542,
#   'PFE weight': 0.188323846085593,
#   'BTC weight': 0.0004215712192801845},
#  {'Returns': 27.61006172816832,
#   'Volatility': 0.1983754036330909,
#   'SHOP weight': 0.11474942768287495,
#   'TSLA weight': 0.14904098342766242,
#   'GOLD weight': 0.13848925349663482,
#   'DAL weight': 0.17950669124134488,
#   'NFLX weight': 0.031554928137921955,
#   'AAPL weight': 0.18147831243250134,
#   'PFE weight': 0.17200619082658303,
#   'BTC weight': 0.03317421275447659},
#  {'Returns': 31.515421538925285,
#   'Volatility': 0.21938372637299583,
#   'SHOP weight': 0.08473939562633684,
#   'TSLA weight': 0.22588866715611639,
#   'GOLD weight': 0.08196653977728628,
#   'DAL weight': 0.16563092612241148,
#   'NFLX weight': 0.1310915951647516,
#   'AAPL weight': 0.1249242832825648,
#   'PFE weight': 0.1403660316146889,
#   'BTC weight': 0.04539256125584362},
#  {'Returns': 29.931476680599765,
#   'Volatility': 0.2043816057730296,
#   'SHOP weight': 0.12476317844453222,
#   'TSLA weight': 0.2572641503690963,
#   'GOLD weight': 0.029179066183697668,
#   'DAL weight': 0.13345390222977618,
#   'NFLX weight': 0.07174736455836214,
#   'AAPL weight': 0.004463707114076615,
#   'PFE weight': 0.06983675105636258,
#   'BTC weight': 0.3092918800440963},
#  {'Returns': 25.51912985810638,
#   'Volatility': 0.19892806955212358,
#   'SHOP weight': 0.16469593072380803,
#   'TSLA weight': 0.08672819381724163,
#   'GOLD weight': 0.049646137348896405,
#   'DAL weight': 0.22359961829084485,
#   'NFLX weight': 0.16253303769528984,
#   'AAPL weight': 0.1431378800434898,
#   'PFE weight': 0.027259703835873225,
#   'BTC weight': 0.14239949824455628},
#  {'Returns': 26.23239406566835,
#   'Volatility': 0.21783161882910793,
#   'SHOP weight': 0.15775415104658821,
#   'TSLA weight': 0.09937971866911362,
#   'GOLD weight': 0.0658058305590177,
#   'DAL weight': 0.2136437627716277,
#   'NFLX weight': 0.1556218823210084,
#   'AAPL weight': 0.23450199685733156,
#   'PFE weight': 0.009305870011428845,
#   'BTC weight': 0.06398678776388395},
#  {'Returns': 31.110923636411343,
#   'Volatility': 0.20870519426623693,
#   'SHOP weight': 0.1558315775871166,
#   'TSLA weight': 0.20392933298977173,
#   'GOLD weight': 0.12195980025045294,
#   'DAL weight': 0.1502904606998917,
#   'NFLX weight': 0.007088105157581466,
#   'AAPL weight': 0.09037974622869889,
#   'PFE weight': 0.19531012528189298,
#   'BTC weight': 0.0752108518045937},
#  {'Returns': 19.227441234752472,
#   'Volatility': 0.17837737120586633,
#   'SHOP weight': 0.08649123508066357,
#   'TSLA weight': 0.08965571640112077,
#   'GOLD weight': 0.15382780113923467,
#   'DAL weight': 0.12047913475441778,
#   'NFLX weight': 0.14416492882126047,
#   'AAPL weight': 0.17511880984122244,
#   'PFE weight': 0.13141244796544754,
#   'BTC weight': 0.09884992599663274},
#  {'Returns': 27.78617947321997,
#   'Volatility': 0.20637289330018413,
#   'SHOP weight': 0.14552750494565608,
#   'TSLA weight': 0.17688432720217456,
#   'GOLD weight': 0.03665791852066017,
#   'DAL weight': 0.02848302831685846,
#   'NFLX weight': 0.15977420816545934,
#   'AAPL weight': 0.12668817086573192,
#   'PFE weight': 0.1564040625007089,
#   'BTC weight': 0.16958077948275063},
#  {'Returns': 10.96422041940356,
#   'Volatility': 0.14399828882010673,
#   'SHOP weight': 0.10299777930414804,
#   'TSLA weight': 0.03821883059969498,
#   'GOLD weight': 0.19066665538663316,
#   'DAL weight': 0.11337505993342806,
#   'NFLX weight': 0.09738623935963307,
#   'AAPL weight': 0.09611335768220296,
#   'PFE weight': 0.08050147498203726,
#   'BTC weight': 0.28074060275222246},
#  {'Returns': 31.47024237840047,
#   'Volatility': 0.20575172923879786,
#   'SHOP weight': 0.05279618464478998,
#   'TSLA weight': 0.20823236997439926,
#   'GOLD weight': 0.15761684392891614,
#   'DAL weight': 0.2627443270216776,
#   'NFLX weight': 0.0003204575411239611,
#   'AAPL weight': 0.007602894412188645,
#   'PFE weight': 0.2707187752111497,
#   'BTC weight': 0.039968147265754705},
#  {'Returns': 13.747105755862455,
#   'Volatility': 0.16044777562465695,
#   'SHOP weight': 0.02740951349517866,
#   'TSLA weight': 0.04621505468368507,
#   'GOLD weight': 0.22753404874040203,
#   'DAL weight': 0.1783838811439913,
#   'NFLX weight': 0.13313576004229352,
#   'AAPL weight': 0.11763180864373769,
#   'PFE weight': 0.16527647592974026,
#   'BTC weight': 0.10441345732097146},
#  {'Returns': 24.68900356793325,
#   'Volatility': 0.1609422296212127,
#   'SHOP weight': 0.1272951591412058,
#   'TSLA weight': 0.07860685849152424,
#   'GOLD weight': 0.10711910426306077,
#   'DAL weight': 0.14615070294971363,
#   'NFLX weight': 0.03702932559547792,
#   'AAPL weight': 0.12769268352324079,
#   'PFE weight': 0.23975948206522832,
#   'BTC weight': 0.1363466839705486},
#  {'Returns': 17.325876703087026,
#   'Volatility': 0.19174816411793918,
#   'SHOP weight': 0.006271467391662286,
#   'TSLA weight': 0.1292476651692497,
#   'GOLD weight': 0.20902774592676868,
#   'DAL weight': 0.016108454481673133,
#   'NFLX weight': 0.11879498783372258,
#   'AAPL weight': 0.27137774807292503,
#   'PFE weight': 0.216313283248222,
#   'BTC weight': 0.03285864787577655},
#  {'Returns': 23.99915481831978,
#   'Volatility': 0.18659571552571655,
#   'SHOP weight': 0.2190517203190326,
#   'TSLA weight': 0.05172679393016489,
#   'GOLD weight': 0.09167443438868352,
#   'DAL weight': 0.0510067844048596,
#   'NFLX weight': 0.07371947260320832,
#   'AAPL weight': 0.16152560991832474,
#   'PFE weight': 0.22410277717290092,
#   'BTC weight': 0.1271924072628254},
#  {'Returns': 18.660505170991435,
#   'Volatility': 0.19224562144637589,
#   'SHOP weight': 0.19559264271978938,
#   'TSLA weight': 0.04750731127345402,
#   'GOLD weight': 0.21605428476927338,
#   'DAL weight': 0.17085483618071798,
#   'NFLX weight': 0.0107455919798901,
#   'AAPL weight': 0.17989677763300022,
#   'PFE weight': 0.10590108987010417,
#   'BTC weight': 0.07344746557377056},
#  {'Returns': 25.365377831643574,
#   'Volatility': 0.2855893648927162,
#   'SHOP weight': 0.12424076156105196,
#   'TSLA weight': 0.2858954170096211,
#   'GOLD weight': 0.15855798815083888,
#   'DAL weight': 0.014772905877288134,
#   'NFLX weight': 0.29448918021781445,
#   'AAPL weight': 0.08951533495910782,
#   'PFE weight': 0.02399813834737031,
#   'BTC weight': 0.008530273876907248},
#  {'Returns': 25.141164684725652,
#   'Volatility': 0.20566594581175346,
#   'SHOP weight': 0.12228647504609715,
#   'TSLA weight': 0.19447225305203364,
#   'GOLD weight': 0.18746725858704477,
#   'DAL weight': 0.24650612827511817,
#   'NFLX weight': 0.030248026142413682,
#   'AAPL weight': 0.006636765157651721,
#   'PFE weight': 0.08392900781161353,
#   'BTC weight': 0.1284540859280273},
#  {'Returns': 35.77059232182072,
#   'Volatility': 0.2580473994690587,
#   'SHOP weight': 0.30760320542595354,
#   'TSLA weight': 0.19571916725203636,
#   'GOLD weight': 0.060760810538380894,
#   'DAL weight': 0.04864814828701273,
#   'NFLX weight': 0.03155280162202267,
#   'AAPL weight': 0.13096640027003256,
#   'PFE weight': 0.18849910969225644,
#   'BTC weight': 0.03625035691230497},
#  {'Returns': 38.81865693160351,
#   'Volatility': 0.2649898008199536,
#   'SHOP weight': 0.2592515727064692,
#   'TSLA weight': 0.2581306559969465,
#   'GOLD weight': 0.056128289169352245,
#   'DAL weight': 0.19748009558053664,
#   'NFLX weight': 0.013272440711543331,
#   'AAPL weight': 0.08981277969674835,
#   'PFE weight': 0.07946781776028333,
#   'BTC weight': 0.046456348378120495},
#  {'Returns': 30.59222886843945,
#   'Volatility': 0.23265501860017485,
#   'SHOP weight': 0.19205845266563354,
#   'TSLA weight': 0.19690012956027,
#   'GOLD weight': 0.06352584103841691,
#   'DAL weight': 0.1265523197043195,
#   'NFLX weight': 0.09583458826309876,
#   'AAPL weight': 0.1622243494298886,
#   'PFE weight': 0.06257478433830377,
#   'BTC weight': 0.10032953500006901},
#  {'Returns': 23.020243421136694,
#   'Volatility': 0.2115731456663062,
#   'SHOP weight': 0.2469436119579146,
#   'TSLA weight': 0.08430822985732903,
#   'GOLD weight': 0.13537276521809374,
#   'DAL weight': 0.027432808553372028,
#   'NFLX weight': 0.03644735191201814,
#   'AAPL weight': 0.19942149145962063,
#   'PFE weight': 0.16349007440229812,
#   'BTC weight': 0.10658366663935372},
#  {'Returns': 18.671479162709606,
#   'Volatility': 0.17958701721605194,
#   'SHOP weight': 0.1210561817318445,
#   'TSLA weight': 0.057900577735642784,
#   'GOLD weight': 0.03633501572025878,
#   'DAL weight': 0.13412194810888653,
#   'NFLX weight': 0.23001622605049044,
#   'AAPL weight': 0.15813431961075214,
#   'PFE weight': 0.0007991873020783887,
#   'BTC weight': 0.26163654374004647},
#  {'Returns': 14.298996199555306,
#   'Volatility': 0.1744547007204034,
#   'SHOP weight': 0.03760781312997228,
#   'TSLA weight': 0.12720026602594278,
#   'GOLD weight': 0.21428502564427465,
#   'DAL weight': 0.1761454407735075,
#   'NFLX weight': 0.07276015736700872,
#   'AAPL weight': 0.14719521987465464,
#   'PFE weight': 0.019817382916829458,
#   'BTC weight': 0.20498869426781005},
#  {'Returns': 24.051489027295553,
#   'Volatility': 0.2123709367033229,
#   'SHOP weight': 0.2581151997868094,
#   'TSLA weight': 0.12466136096610937,
#   'GOLD weight': 0.17865665755272228,
#   'DAL weight': 0.16958771500741696,
#   'NFLX weight': 0.007716420020107787,
#   'AAPL weight': 0.05384432961231161,
#   'PFE weight': 0.08063479420601977,
#   'BTC weight': 0.1267835228485029},
#  {'Returns': 24.00131941932475,
#   'Volatility': 0.15187200579071766,
#   'SHOP weight': 0.11892967744533771,
#   'TSLA weight': 0.06303336780192634,
#   'GOLD weight': 0.04602159361271642,
#   'DAL weight': 0.17529983237784658,
#   'NFLX weight': 0.12569710425317285,
#   'AAPL weight': 0.07932889031673113,
#   'PFE weight': 0.17366043816704133,
#   'BTC weight': 0.2180290960252278},
#  {'Returns': 27.369586179854466,
#   'Volatility': 0.2344026235338267,
#   'SHOP weight': 0.13463612187241789,
#   'TSLA weight': 0.23059681535686088,
#   'GOLD weight': 0.027128231580209466,
#   'DAL weight': 0.0695215320351236,
#   'NFLX weight': 0.23851564850453938,
#   'AAPL weight': 0.06883878184601351,
#   'PFE weight': 0.018791086681861077,
#   'BTC weight': 0.2119717821229742},
#  {'Returns': 29.02183036251143,
#   'Volatility': 0.24535263325082246,
#   'SHOP weight': 0.006431675268498628,
#   'TSLA weight': 0.28843859424225576,
#   'GOLD weight': 0.01995864931842348,
# ...
#   'BTC weight': 0.20738944468118115},
#  {'Returns': 30.995651229974513,
#   'Volatility': 0.2176607678384367,
#   'SHOP weight': 0.2494410838052442,
#   'TSLA weight': 0.09481815427219963,
#   'GOLD weight': 0.02872198186449218,
#   'DAL weight': 0.2372680670944064,
#   'NFLX weight': 0.0678295071616066,
#   'AAPL weight': 0.16084929130515577,
#   'PFE weight': 0.04937898660923137,
#   'BTC weight': 0.11169292788766375},
#  {'Returns': 19.763648833005444,
#   'Volatility': 0.17436591887383887,
#   'SHOP weight': 0.1623027231071408,
#   'TSLA weight': 0.06831400369957807,
#   'GOLD weight': 0.1514968901074002,
#   'DAL weight': 0.17621159073637688,
#   'NFLX weight': 0.01734173238236817,
#   'AAPL weight': 0.16674185210471515,
#   'PFE weight': 0.07963421905929638,
#   'BTC weight': 0.17795698880312436},
#  {'Returns': 29.237009996305716,
#   'Volatility': 0.18618524887424676,
#   'SHOP weight': 0.12759204191045076,
#   'TSLA weight': 0.19373480828928094,
#   'GOLD weight': 0.08787718207827974,
#   'DAL weight': 0.11255627083136018,
#   'NFLX weight': 0.03525091307879171,
#   'AAPL weight': 0.06004791380108143,
#   'PFE weight': 0.2137630255198382,
#   'BTC weight': 0.16917784449091716},
#  {'Returns': 22.855678176156466,
#   'Volatility': 0.17526180430128285,
#   'SHOP weight': 0.11223574323271256,
#   'TSLA weight': 0.00829790583977263,
#   'GOLD weight': 0.06607440289485796,
#   'DAL weight': 0.15794308376808522,
#   'NFLX weight': 0.20278958864986388,
#   'AAPL weight': 0.20065832253224,
#   'PFE weight': 0.19408800935217638,
#   'BTC weight': 0.05791294373029149},
#  {'Returns': 16.584942432949973,
#   'Volatility': 0.18079338713224413,
#   'SHOP weight': 0.048392347240454284,
#   'TSLA weight': 0.11193508232271923,
#   'GOLD weight': 0.17236958562406024,
#   'DAL weight': 0.17480696656349928,
#   'NFLX weight': 0.15823559070037474,
#   'AAPL weight': 0.1472900967675169,
#   'PFE weight': 0.03420181208298687,
#   'BTC weight': 0.15276851869838845},
#  {'Returns': 14.21555611629606,
#   'Volatility': 0.15187887935314268,
#   'SHOP weight': 0.11788689279064858,
#   'TSLA weight': 0.02087898841332603,
#   'GOLD weight': 0.1287294325308416,
#   'DAL weight': 0.023341869557915815,
#   'NFLX weight': 0.21790995858744047,
#   'AAPL weight': 0.030604318839840182,
#   'PFE weight': 0.22097998661859014,
#   'BTC weight': 0.23966855266139706},
#  {'Returns': 29.90095347342207,
#   'Volatility': 0.23863782781683976,
#   'SHOP weight': 0.15371019454755158,
#   'TSLA weight': 0.23157146870720174,
#   'GOLD weight': 0.041107798263696954,
#   'DAL weight': 0.08116786741600986,
#   'NFLX weight': 0.24033170828463668,
#   'AAPL weight': 0.038486376961127805,
#   'PFE weight': 0.0780290566153348,
#   'BTC weight': 0.13559552920444065},
#  {'Returns': 32.080944611883666,
#   'Volatility': 0.217932488084291,
#   'SHOP weight': 0.08607319240580542,
#   'TSLA weight': 0.22681795719545242,
#   'GOLD weight': 0.046854519108953024,
#   'DAL weight': 0.17410874619924402,
#   'NFLX weight': 0.13704752866983141,
#   'AAPL weight': 0.12430915039415373,
#   'PFE weight': 0.11141567292696836,
#   'BTC weight': 0.09337323309959165},
#  {'Returns': 32.18070835300832,
#   'Volatility': 0.21756828499393027,
#   'SHOP weight': 0.2656487532341024,
#   'TSLA weight': 0.12371681835011403,
#   'GOLD weight': 0.006704505364222314,
#   'DAL weight': 0.06622640594070062,
#   'NFLX weight': 0.13567819627589056,
#   'AAPL weight': 0.06798965954653088,
#   'PFE weight': 0.20383321219329606,
#   'BTC weight': 0.13020244909514306},
#  {'Returns': 34.15344976034278,
#   'Volatility': 0.2739765408512702,
#   'SHOP weight': 0.1725873222730234,
#   'TSLA weight': 0.32183401734367606,
#   'GOLD weight': 0.1735459063772825,
#   'DAL weight': 0.2299790349476073,
#   'NFLX weight': 0.040065879760925294,
#   'AAPL weight': 0.007298155882651772,
#   'PFE weight': 0.0446619635693092,
#   'BTC weight': 0.01002771984552434},
#  {'Returns': 36.58171144091553,
#   'Volatility': 0.2662869570709416,
#   'SHOP weight': 0.15550532041852597,
#   'TSLA weight': 0.3022019184193759,
#   'GOLD weight': 0.03341519996490424,
#   'DAL weight': 0.014688707541227294,
#   'NFLX weight': 0.06378659011865022,
#   'AAPL weight': 0.22726871639893292,
#   'PFE weight': 0.14502657059347324,
#   'BTC weight': 0.058106976544910274},
#  {'Returns': 14.250133037489691,
#   'Volatility': 0.20954760387002144,
#   'SHOP weight': 0.2043684446056861,
#   'TSLA weight': 0.0006784179373159887,
#   'GOLD weight': 0.15994795031150288,
#   'DAL weight': 0.038255352598605186,
#   'NFLX weight': 0.20457457636631945,
#   'AAPL weight': 0.20064036945756367,
#   'PFE weight': 0.08408764268775762,
#   'BTC weight': 0.10744724603524906},
#  {'Returns': 22.656532040670115,
#   'Volatility': 0.19403769263834264,
#   'SHOP weight': 0.14330968060087357,
#   'TSLA weight': 0.14245275918633607,
#   'GOLD weight': 0.11022788213836007,
#   'DAL weight': 0.04311191653670961,
#   'NFLX weight': 0.14100539038171572,
#   'AAPL weight': 0.11978433750869279,
#   'PFE weight': 0.14095995899883748,
#   'BTC weight': 0.15914807464847475},
#  {'Returns': 21.753175634211964,
#   'Volatility': 0.17768829015431803,
#   'SHOP weight': 0.12998598648447196,
#   'TSLA weight': 0.09745168121324725,
#   'GOLD weight': 0.13817971531073125,
#   'DAL weight': 0.14304876505953626,
#   'NFLX weight': 0.127873079190522,
#   'AAPL weight': 0.09955672971563423,
#   'PFE weight': 0.14371624975635094,
#   'BTC weight': 0.12018779326950613},
#  {'Returns': 33.26382066527002,
#   'Volatility': 0.18928142719922772,
#   'SHOP weight': 0.21223457279918895,
#   'TSLA weight': 0.15001756156354668,
#   'GOLD weight': 0.008248213842155946,
#   'DAL weight': 0.17198183585023083,
#   'NFLX weight': 0.029618233785355663,
#   'AAPL weight': 0.02905733573410748,
#   'PFE weight': 0.1883659490540596,
#   'BTC weight': 0.2104762973713547},
#  {'Returns': 20.770970514852337,
#   'Volatility': 0.18277605974803912,
#   'SHOP weight': 0.160764580132374,
#   'TSLA weight': 0.12158839203827407,
#   'GOLD weight': 0.1699454380400114,
#   'DAL weight': 0.11158086859507693,
#   'NFLX weight': 0.006123869396329478,
#   'AAPL weight': 0.1426051254713625,
#   'PFE weight': 0.1155276488742625,
#   'BTC weight': 0.171864077452309},
#  {'Returns': 14.49696754969628,
#   'Volatility': 0.23390873564691306,
#   'SHOP weight': 0.0808844311907777,
#   'TSLA weight': 0.14623638829101154,
#   'GOLD weight': 0.24327018026169217,
#   'DAL weight': 0.04353414870202917,
#   'NFLX weight': 0.2005516081868172,
#   'AAPL weight': 0.24975640512613642,
#   'PFE weight': 0.015177197537995795,
#   'BTC weight': 0.020589640703540083},
#  {'Returns': 16.617045122418364,
#   'Volatility': 0.16241786670639385,
#   'SHOP weight': 0.14737600897233188,
#   'TSLA weight': 0.028307440971873137,
#   'GOLD weight': 0.1535895737398207,
#   'DAL weight': 0.1462615030049197,
#   'NFLX weight': 0.08362851301084664,
#   'AAPL weight': 0.15130861309128785,
#   'PFE weight': 0.10514146168729155,
#   'BTC weight': 0.18438688552162846},
#  {'Returns': 29.26186249921666,
#   'Volatility': 0.237288066726939,
#   'SHOP weight': 0.22543913910455168,
#   'TSLA weight': 0.21348662730989482,
#   'GOLD weight': 0.05841482315580715,
#   'DAL weight': 0.06466291706110408,
#   'NFLX weight': 0.142324539489332,
#   'AAPL weight': 0.04655595570596282,
#   'PFE weight': 0.07016895026978881,
#   'BTC weight': 0.17894704790355873},
#  {'Returns': 27.065836369005844,
#   'Volatility': 0.2141469288279666,
#   'SHOP weight': 0.07191598638216312,
#   'TSLA weight': 0.20977309222375015,
#   'GOLD weight': 0.05996159516127732,
#   'DAL weight': 0.12843579707063904,
#   'NFLX weight': 0.19167652370869373,
#   'AAPL weight': 0.13954931178012603,
#   'PFE weight': 0.05967333711267196,
#   'BTC weight': 0.13901435656067856},
#  {'Returns': 16.921234817407225,
#   'Volatility': 0.1756337556568898,
#   'SHOP weight': 0.11543423330472234,
#   'TSLA weight': 0.11367719345479148,
#   'GOLD weight': 0.20832902187936186,
#   'DAL weight': 0.1482247795189039,
#   'NFLX weight': 0.13064101258457556,
#   'AAPL weight': 0.015233955780205137,
#   'PFE weight': 0.10328834477716199,
#   'BTC weight': 0.16517145870027763},
#  {'Returns': 19.992877573897623,
#   'Volatility': 0.16197909356408438,
#   'SHOP weight': 0.0036747316347273966,
#   'TSLA weight': 0.16349002677966834,
#   'GOLD weight': 0.1320366850328834,
#   'DAL weight': 0.06810329075289225,
#   'NFLX weight': 0.11900865025562425,
#   'AAPL weight': 0.11415066373346847,
#   'PFE weight': 0.19237186438068865,
#   'BTC weight': 0.2071640874300473},
#  {'Returns': 28.29039595623063,
#   'Volatility': 0.24868231565288862,
#   'SHOP weight': 0.08782043339755856,
#   'TSLA weight': 0.27341990309167985,
#   'GOLD weight': 0.23477376170159173,
#   'DAL weight': 0.29309003125098104,
#   'NFLX weight': 0.012047195224937272,
#   'AAPL weight': 0.027390019577155644,
#   'PFE weight': 0.05317763728644194,
#   'BTC weight': 0.018281018469653985},
#  {'Returns': 27.326489100466222,
#   'Volatility': 0.20783544956368669,
#   'SHOP weight': 0.2065407841549008,
#   'TSLA weight': 0.178480839179496,
#   'GOLD weight': 0.09309845048589085,
#   'DAL weight': 0.027918518135781466,
#   'NFLX weight': 0.0018376576946933045,
#   'AAPL weight': 0.14178197833769496,
#   'PFE weight': 0.16204355488900932,
#   'BTC weight': 0.18829821712253328},
#  {'Returns': 34.68472015478838,
#   'Volatility': 0.21486114021529895,
#   'SHOP weight': 0.15269647654822288,
#   'TSLA weight': 0.20746708193583882,
#   'GOLD weight': 0.011006341538723437,
#   'DAL weight': 0.044735021891700956,
#   'NFLX weight': 0.048561532414288795,
#   'AAPL weight': 0.19437452516612835,
#   'PFE weight': 0.23513922962773828,
#   'BTC weight': 0.10601979087735851},
#  {'Returns': 25.98223052156573,
#   'Volatility': 0.228669749033944,
#   'SHOP weight': 0.12581780712223345,
#   'TSLA weight': 0.20529575634594535,
#   'GOLD weight': 0.1075161037138077,
#   'DAL weight': 0.0516162554524694,
#   'NFLX weight': 0.11794232402784396,
#   'AAPL weight': 0.22144615184212263,
#   'PFE weight': 0.07940240108310218,
#   'BTC weight': 0.09096320041247538},
#  {'Returns': 22.90406998859174,
#   'Volatility': 0.19387792046558752,
#   'SHOP weight': 0.2384589598040978,
#   'TSLA weight': 0.006872032200910654,
#   'GOLD weight': 0.04380747118408512,
#   'DAL weight': 0.07631691916387512,
#   'NFLX weight': 0.15737412555727484,
#   'AAPL weight': 0.16899396591368737,
#   'PFE weight': 0.15443636553701118,
#   'BTC weight': 0.15374016063905807},
#  {'Returns': 19.233836455204372,
#   'Volatility': 0.22502614799354634,
#   'SHOP weight': 0.07467684174124145,
#   'TSLA weight': 0.26999371625626856,
#   'GOLD weight': 0.22974878865801676,
#   'DAL weight': 0.06351752912164424,
#   'NFLX weight': 0.01871535198942032,
#   'AAPL weight': 0.13803874552556059,
#   'PFE weight': 0.012625369175938213,
#   'BTC weight': 0.19268365753190997},
#  {'Returns': 37.25800212146008,
#   'Volatility': 0.2672074915339414,
#   'SHOP weight': 0.09438453222496568,
#   'TSLA weight': 0.33161766776313767,
#   'GOLD weight': 0.010059538885370395,
#   'DAL weight': 0.15920483206661434,
#   'NFLX weight': 0.03867393615327233,
#   'AAPL weight': 0.23273879839584796,
#   'PFE weight': 0.010948500266887956,
#   'BTC weight': 0.12237219424390366},
#  {'Returns': 22.183537112497433,
#   'Volatility': 0.15512512577739634,
#   'SHOP weight': 0.02751991314663034,
#   'TSLA weight': 0.016881693022904525,
#   'GOLD weight': 0.07461839584012141,
#   'DAL weight': 0.22321531056317648,
#   'NFLX weight': 0.16490354295763868,
#   'AAPL weight': 0.15179050960068863,
#   'PFE weight': 0.2321214339280631,
#   'BTC weight': 0.10894920094077688},
#  {'Returns': 38.69610468510828,
#   'Volatility': 0.24087505550573352,
#   'SHOP weight': 0.04497188396498588,
#   'TSLA weight': 0.2695818867957049,
#   'GOLD weight': 0.024459266332191414,
#   'DAL weight': 0.23226253386649745,
#   'NFLX weight': 0.009502337407467617,
#   'AAPL weight': 0.24858006044777178,
#   'PFE weight': 0.14836736623590446,
#   'BTC weight': 0.022274664949476445},
#  {'Returns': 18.07997576677371,
#   'Volatility': 0.18518773426757792,
#   'SHOP weight': 0.053355557743699454,
#   'TSLA weight': 0.11073075364416739,
#   'GOLD weight': 0.14810079921413,
#   'DAL weight': 0.012309194481211433,
#   'NFLX weight': 0.16216089415659074,
#   'AAPL weight': 0.23143554624049736,
#   'PFE weight': 0.17561504786555493,
#   'BTC weight': 0.10629220665414858},
#  {'Returns': 11.515213343060129,
#   'Volatility': 0.1757067387989865,
#   'SHOP weight': 0.00962791921234656,
#   'TSLA weight': 0.11725219084848303,
#   'GOLD weight': 0.23434198533247083,
#   'DAL weight': 0.18266961257519296,
#   'NFLX weight': 0.18682422132559476,
#   'AAPL weight': 0.05686336178744619,
#   'PFE weight': 0.019331914420373502,
#   'BTC weight': 0.19308879449809213},
#  {'Returns': 24.77678885334035,
#   'Volatility': 0.21353606755148688,
#   'SHOP weight': 0.005355163773220173,
#   'TSLA weight': 0.1938534699628053,
#   'GOLD weight': 0.128512560639615,
#   'DAL weight': 0.1886314037225599,
#   'NFLX weight': 0.188988885921978,
#   'AAPL weight': 0.17725987189723494,
#   'PFE weight': 0.07755320299722444,
#   'BTC weight': 0.0398454410853623},
#  {'Returns': 41.650097980127285,
#   'Volatility': 0.2585503740824443,
#   'SHOP weight': 0.24185260337110248,
#   'TSLA weight': 0.2723530560762608,
#   'GOLD weight': 0.03480072539228958,
#   'DAL weight': 0.18556420695040954,
#   'NFLX weight': 0.06038355552522862,
#   'AAPL weight': 0.003901409456844295,
#   'PFE weight': 0.17501547152321678,
#   'BTC weight': 0.02612897170464794},
#  {'Returns': 16.698151547522176,
#   'Volatility': 0.2312794130011172,
#   'SHOP weight': 0.06365480892100406,
#   'TSLA weight': 0.18039872074036173,
#   'GOLD weight': 0.20769406171407917,
#   'DAL weight': 0.0569231065643424,
#   'NFLX weight': 0.21597537959521856,
#   'AAPL weight': 0.20631019727843283,
#   'PFE weight': 0.006548952715725547,
#   'BTC weight': 0.06249477247083566},
#  {'Returns': 19.95371221043572,
#   'Volatility': 0.21858856663821127,
#   'SHOP weight': 0.21807200487853215,
#   'TSLA weight': 0.028355018371514603,
#   'GOLD weight': 0.10666735716111816,
#   'DAL weight': 0.18803699626671486,
#   'NFLX weight': 0.26942462587493554,
#   'AAPL weight': 0.09086228228967402,
#   'PFE weight': 0.005144848756819236,
#   'BTC weight': 0.09343686640069143},
#  {'Returns': 23.38692617545761,
#   'Volatility': 0.21168436870341736,
#   'SHOP weight': 0.15566274374681796,
#   'TSLA weight': 0.1360546429415046,
#   'GOLD weight': 0.12054770805865032,
#   'DAL weight': 0.12104311166170166,
#   'NFLX weight': 0.15477301226273424,
#   'AAPL weight': 0.15822690342872905,
#   'PFE weight': 0.05892145953586399,
#   'BTC weight': 0.09477041836399805},
#  {'Returns': 30.636877982156044,
#   'Volatility': 0.17521253045942078,
#   'SHOP weight': 0.14370629711116487,
#   'TSLA weight': 0.13960690570398004,
#   'GOLD weight': 0.03458288015150072,
#   'DAL weight': 0.18033345913845714,
#   'NFLX weight': 0.07546519410010095,
#   'AAPL weight': 0.03968090738100144,
#   'PFE weight': 0.2083370567049932,
#   'BTC weight': 0.1782872997088015},
#  {'Returns': 26.612682922562264,
#   'Volatility': 0.19180055112122513,
#   'SHOP weight': 0.15980047333043979,
#   'TSLA weight': 0.11667062209861305,
#   'GOLD weight': 0.08175638838761647,
#   'DAL weight': 0.044656105620394695,
#   'NFLX weight': 0.06651591546862391,
#   'AAPL weight': 0.20646557991459863,
#   'PFE weight': 0.22211437546699525,
#   'BTC weight': 0.10202053971271831},
#  {'Returns': 24.672965069594042,
#   'Volatility': 0.1917988613670955,
#   'SHOP weight': 0.21467501603708528,
#   'TSLA weight': 0.016895120159929392,
#   'GOLD weight': 0.11604969903789115,
#   'DAL weight': 0.1608973935969827,
#   'NFLX weight': 0.06914016214886835,
#   'AAPL weight': 0.20088407023379637,
#   'PFE weight': 0.19244866711106617,
#   'BTC weight': 0.029009871674380683},
#  {'Returns': 17.531299659612927,
#   'Volatility': 0.20777811065163782,
#   'SHOP weight': 0.19744612384352012,
#   'TSLA weight': 0.051339849753617585,
#   'GOLD weight': 0.1785884433211648,
#   'DAL weight': 0.11446725715418225,
#   'NFLX weight': 0.1807117322011768,
#   'AAPL weight': 0.13763230827685427,
#   'PFE weight': 0.06596348204129047,
#   'BTC weight': 0.07385080340819383},
#  {'Returns': 15.063833157579783,
#   'Volatility': 0.17234652681364915,
#   'SHOP weight': 0.004858860057813771,
#   'TSLA weight': 0.03474607241850351,
#   'GOLD weight': 0.2456096371919062,
#   'DAL weight': 0.1691155532841624,
#   'NFLX weight': 0.028219069893792154,
#   'AAPL weight': 0.26196764235331793,
#   'PFE weight': 0.22530612259688385,
#   'BTC weight': 0.030177042203620084}]

# %% [markdown]
# for index, row in portfolios.iterrows():
#     portf_dict = [row]
#     print(portf_dict)

# %%
# convert into JSON and save it as a separate file:
#portf = portfolios.to_json()
#port = json.dumps(port)
with open('../Data/portfolio_data.json', 'w') as outfile:
    json.dump(portf, outfile)

portf
# Out:
# '{"Returns":{"0":29.6978434915,"1":23.3025118407,"2":16.8799936843,"3":24.2729415855,"4":33.0902656319,"5":30.3256738499,"6":31.7255386312,"7":15.8515033057,"8":22.9753834918,"9":25.3569666477,"10":26.1046972422,"11":20.2641416308,"12":33.2794867623,"13":22.4240640496,"14":44.0741903314,"15":16.5809892464,"16":19.6123793909,"17":15.4701436311,"18":16.0582389815,"19":25.9080692141,"20":21.5853272165,"21":27.2262983175,"22":20.0890924434,"23":17.5244113344,"24":22.2303349249,"25":29.1598294526,"26":16.9964219748,"27":16.4006555508,"28":16.5441797699,"29":20.5117619504,"30":25.2893768339,"31":17.3902273819,"32":15.3930445246,"33":19.3228361803,"34":15.9474791591,"35":27.7048010821,"36":24.612113787,"37":4.7713995147,"38":32.3850054874,"39":18.0466789084,"40":23.4349137915,"41":24.1738623837,"42":22.1895035035,"43":21.2388482582,"44":24.7273060707,"45":17.4590422671,"46":20.6548705545,"47":21.327810885,"48":13.246090612,"49":23.6848555065,"50":30.2138342233,"51":32.3141306718,"52":23.969153748,"53":34.4651612102,"54":19.6092665806,"55":17.7940928374,"56":19.8443427212,"57":22.5285663521,"58":18.0106439496,"59":34.2234559224,"60":27.4733752612,"61":30.2456798407,"62":10.7563656729,"63":20.5365185504,"64":14.9945662704,"65":25.2069388936,"66":27.002650433,"67":17.8383696428,"68":35.2649374826,"69":24.3893821558,"70":16.3875450928,"71":21.0356224223,"72":11.9567731766,"73":24.930211375,"74":30.4633877852,"75":26.1068392099,"76":19.8519750403,"77":20.5533024755,"78":25.0313599015,"79":14.4759820479,"80":29.590357654,"81":12.9818466411,"82":10.3409991299,"83":30.8275898076,"84":27.6418075937,"85":25.6175974556,"86":20.7924205816,"87":24.5359599661,"88":26.4675371893,"89":20.639944178,"90":21.5070565747,"91":13.2907560248,"92":22.4398150045,"93":26.584074491,"94":25.7326928898,"95":22.8756540997,"96":14.4185275542,"97":22.1984806078,"98":25.1747376963,"99":21.122848828,"100":20.513832701,"101":21.2899184806,"102":30.7257753111,"103":27.6100617282,"104":31.5154215389,"105":29.9314766806,"106":25.5191298581,"107":26.2323940657,"108":31.1109236364,"109":19.2274412348,"110":27.7861794732,"111":10.9642204194,"112":31.4702423784,"113":13.7471057559,"114":24.6890035679,"115":17.3258767031,"116":23.9991548183,"117":18.660505171,"118":25.3653778316,"119":25.1411646847,"120":35.7705923218,"121":38.8186569316,"122":30.5922288684,"123":23.0202434211,"124":18.6714791627,"125":14.2989961996,"126":24.0514890273,"127":24.0013194193,"128":27.3695861799,"129":29.0218303625,"130":12.3114313434,"131":27.1399786804,"132":22.2877367259,"133":25.4156110581,"134":26.9649782631,"135":17.732600554,"136":24.6083692209,"137":17.8716994326,"138":31.9285897656,"139":21.8201678335,"140":29.6901821912,"141":21.5908028923,"142":20.2078310526,"143":23.9040923383,"144":16.4576944126,"145":31.1804243747,"146":18.9907086054,"147":31.1597366628,"148":30.9113613391,"149":20.0404204815,"150":17.0852068648,"151":18.0225455666,"152":28.4166223014,"153":20.9460146195,"154":21.3825775551,"155":20.6842605761,"156":18.3803143922,"157":26.4368370254,"158":23.2737097925,"159":14.3219898104,"160":19.2570916212,"161":20.629705738,"162":5.9634914477,"163":21.1578380766,"164":25.7928319368,"165":28.1516089791,"166":37.4469423175,"167":30.4716401909,"168":22.5623052514,"169":18.5366319643,"170":27.0587854343,"171":21.1045095977,"172":22.3984935669,"173":24.2287711502,"174":25.0960218795,"175":16.6999054156,"176":19.3146701303,"177":28.066909339,"178":23.1623692698,"179":18.7725103045,"180":29.7946359394,"181":16.6553508345,"182":15.170322346,"183":18.9327718382,"184":24.8940115681,"185":30.1669843519,"186":23.5509356333,"187":23.8167365983,"188":30.3002703806,"189":19.7106633484,"190":17.5285883698,"191":14.2058004161,"192":39.5600718149,"193":20.7528168546,"194":16.6015056148,"195":13.1414741568,"196":23.4989700971,"197":14.540873555,"198":18.8256881131,"199":17.0123300861,"200":20.8734020606,"201":18.9163783562,"202":19.7919853516,"203":19.4554367252,"204":20.079788204,"205":26.04020966 ...

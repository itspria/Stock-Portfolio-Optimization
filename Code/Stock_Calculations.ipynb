# %%
import json
import numpy as np
import math
from datetime import datetime
import pandas as pd 
import matplotlib.pyplot as plt
import pymongo

# %% [markdown]
# # SHOP Stock Calculations

# %%
with open('../Data/SHOP_prices.json') as json_file:
    SHOP_data = json.load(json_file)
    
#stock annual return
SHOP_ann_return=round((((SHOP_data[0]['adjclose']/SHOP_data[len(SHOP_data)-1]['adjclose'])-1)*100),2)

SHOP_price_array=[]
for i in range(len(SHOP_data)):
    SHOP_price_array.append(SHOP_data[i]['adjclose'])
    
#daily volatility
SHOP_daily_vol = round(np.std(SHOP_price_array),2)

#annualized volatility
SHOP_ann_vol = SHOP_daily_vol * math.sqrt(252)
SHOP_ann_vol = round(SHOP_ann_vol,2)

#3 mon return volatility
SHOP_date_array=[]

for y in range(len(SHOP_data)):
    SHOP_date_array.append(datetime.strptime(SHOP_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=SHOP_date_array[y]
    if ((firstdate-SHOP_date_array[y]).days==91):
        date_3mon_ago=SHOP_date_array[y]
        mon3_index = y
        
#last three month return
SHOP_3mon_return=round((((SHOP_data[0]['adjclose']/SHOP_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
SHOP_summ_stats = {
    "Ticker": "SHOP",
  "Annual Return": SHOP_ann_return,
  "Daily Volatility": SHOP_daily_vol,
  "Annualized Volatility": SHOP_ann_vol,
  "Last 3 Months Return":  SHOP_3mon_return
}

# convert into JSON:
SHOP_summ_stats = json.dumps(SHOP_summ_stats)

# the result is a JSON string:
print(SHOP_summ_stats)
# Out:
# {"Ticker": "SHOP", "Annual Return": 46.96, "Daily Volatility": 191.43, "Annualized Volatility": 3038.86, "Last 3 Months Return": 23.22}

# %% [markdown]
# # TSLA Stock Calculations

# %%
with open('../Data/TSLA_prices.json') as json_file:
    TSLA_data = json.load(json_file)
    
#stock annual return
TSLA_ann_return=round((((TSLA_data[0]['adjclose']/TSLA_data[len(TSLA_data)-1]['adjclose'])-1)*100),2)

TSLA_price_array=[]
for i in range(len(TSLA_data)):
    TSLA_price_array.append(TSLA_data[i]['adjclose'])
    
#daily volatility
TSLA_daily_vol = round(np.std(TSLA_price_array),2)

#annualized volatility
TSLA_ann_vol = TSLA_daily_vol * math.sqrt(252)
TSLA_ann_vol = round(TSLA_ann_vol,2)

#3 mon return volatility
TSLA_date_array=[]

for y in range(len(TSLA_data)):
    TSLA_date_array.append(datetime.strptime(TSLA_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=TSLA_date_array[y]
    if ((firstdate-TSLA_date_array[y]).days==91):
        date_3mon_ago=TSLA_date_array[y]
        mon3_index = y
        
#last three month return
TSLA_3mon_return=round((((TSLA_data[0]['adjclose']/TSLA_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
TSLA_summ_stats = {
    "Ticker": "TSLA",
  "Annual Return": TSLA_ann_return,
  "Daily Volatility": TSLA_daily_vol,
  "Annualized Volatility": TSLA_ann_vol,
  "Last 3 Months Return":  TSLA_3mon_return
}

# convert into JSON:
TSLA_summ_stats = json.dumps(TSLA_summ_stats)

# the result is a JSON string:
print(TSLA_summ_stats)
# Out:
# {"Ticker": "TSLA", "Annual Return": 60.82, "Daily Volatility": 131.63, "Annualized Volatility": 2089.56, "Last 3 Months Return": 13.87}

# %% [markdown]
# # GOLD Stock Calculations

# %%
with open('../Data/GOLD_prices.json') as json_file:
    GOLD_data = json.load(json_file)
    
#stock annual return
GOLD_ann_return=round((((GOLD_data[0]['adjclose']/GOLD_data[len(GOLD_data)-1]['adjclose'])-1)*100),2)

GOLD_price_array=[]
for i in range(len(GOLD_data)):
    GOLD_price_array.append(GOLD_data[i]['adjclose'])
    
#daily volatility
GOLD_daily_vol = round(np.std(GOLD_price_array),2)

#annualized volatility
GOLD_ann_vol = GOLD_daily_vol * math.sqrt(252)
GOLD_ann_vol = round(GOLD_ann_vol,2)

#3 mon return volatility
GOLD_date_array=[]

for y in range(len(GOLD_data)):
    GOLD_date_array.append(datetime.strptime(GOLD_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=GOLD_date_array[y]
    if ((firstdate-GOLD_date_array[y]).days==91):
        date_3mon_ago=GOLD_date_array[y]
        mon3_index = y
        
#last three month return
GOLD_3mon_return=round((((GOLD_data[0]['adjclose']/GOLD_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
GOLD_summ_stats = {
    "Ticker": "GOLD",
  "Annual Return": GOLD_ann_return,
  "Daily Volatility": GOLD_daily_vol,
  "Annualized Volatility": GOLD_ann_vol,
  "Last 3 Months Return":  GOLD_3mon_return
}

# convert into JSON:
GOLD_summ_stats = json.dumps(GOLD_summ_stats)

# the result is a JSON string:
print(GOLD_summ_stats)
# Out:
# {"Ticker": "GOLD", "Annual Return": -29.43, "Daily Volatility": 2.76, "Annualized Volatility": 43.81, "Last 3 Months Return": -15.95}

# %% [markdown]
# # DAL Stock Calculations

# %%
with open('../Data/DAL_prices.json') as json_file:
    DAL_data = json.load(json_file)
    
#stock annual return
DAL_ann_return=round((((DAL_data[0]['adjclose']/DAL_data[len(DAL_data)-1]['adjclose'])-1)*100),2)

DAL_price_array=[]
for i in range(len(DAL_data)):
    DAL_price_array.append(DAL_data[i]['adjclose'])
    
#daily volatility
DAL_daily_vol = round(np.std(DAL_price_array),2)

#annualized volatility
DAL_ann_vol = DAL_daily_vol * math.sqrt(252)
DAL_ann_vol = round(DAL_ann_vol,2)

#3 mon return volatility
DAL_date_array=[]

for y in range(len(DAL_data)):
    DAL_date_array.append(datetime.strptime(DAL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=DAL_date_array[y]
    if ((firstdate-DAL_date_array[y]).days==91):
        date_3mon_ago=DAL_date_array[y]
        mon3_index = y
        
#last three month return
DAL_3mon_return=round((((DAL_data[0]['adjclose']/DAL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
DAL_summ_stats = {
    "Ticker": "DAL",
  "Annual Return": DAL_ann_return,
  "Daily Volatility": DAL_daily_vol,
  "Annualized Volatility": DAL_ann_vol,
  "Last 3 Months Return":  DAL_3mon_return
}

# convert into JSON:
DAL_summ_stats = json.dumps(DAL_summ_stats)

# the result is a JSON string:
print(DAL_summ_stats)
# Out:
# {"Ticker": "DAL", "Annual Return": 29.79, "Daily Volatility": 5.78, "Annualized Volatility": 91.75, "Last 3 Months Return": -12.92}

# %% [markdown]
# # NFLX Stock Calculations

# %%
with open('../Data/NFLX_prices.json') as json_file:
    NFLX_data = json.load(json_file)
    
#stock annual return
NFLX_ann_return=round((((NFLX_data[0]['adjclose']/NFLX_data[len(NFLX_data)-1]['adjclose'])-1)*100),2)

NFLX_price_array=[]
for i in range(len(NFLX_data)):
    NFLX_price_array.append(NFLX_data[i]['adjclose'])
    
#daily volatility
NFLX_daily_vol = round(np.std(NFLX_price_array),2)

#annualized volatility
NFLX_ann_vol = NFLX_daily_vol * math.sqrt(252)
NFLX_ann_vol = round(NFLX_ann_vol,2)

#3 mon return volatility
NFLX_date_array=[]

for y in range(len(NFLX_data)):
    NFLX_date_array.append(datetime.strptime(NFLX_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=NFLX_date_array[y]
    if ((firstdate-NFLX_date_array[y]).days==91):
        date_3mon_ago=NFLX_date_array[y]
        mon3_index = y
        
#last three month return
NFLX_3mon_return=round((((NFLX_data[0]['adjclose']/NFLX_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
NFLX_summ_stats = {
    "Ticker": "NFLX",
  "Annual Return": NFLX_ann_return,
  "Daily Volatility": NFLX_daily_vol,
  "Annualized Volatility": NFLX_ann_vol,
  "Last 3 Months Return":  NFLX_3mon_return
}

# convert into JSON:
NFLX_summ_stats = json.dumps(NFLX_summ_stats)

# the result is a JSON string:
print(NFLX_summ_stats)
# Out:
# {"Ticker": "NFLX", "Annual Return": 6.69, "Daily Volatility": 24.02, "Annualized Volatility": 381.31, "Last 3 Months Return": 11.16}

# %% [markdown]
# # AAPL Stock Calculations

# %%
with open('../Data/AAPL_prices.json') as json_file:
    AAPL_data = json.load(json_file)
    
#stock annual return
AAPL_ann_return=round((((AAPL_data[0]['adjclose']/AAPL_data[len(AAPL_data)-1]['adjclose'])-1)*100),2)

AAPL_price_array=[]
for i in range(len(AAPL_data)):
    AAPL_price_array.append(AAPL_data[i]['adjclose'])
    
#daily volatility
AAPL_daily_vol = round(np.std(AAPL_price_array),2)

#annualized volatility
AAPL_ann_vol = AAPL_daily_vol * math.sqrt(252)
AAPL_ann_vol = round(AAPL_ann_vol,2)

#3 mon return volatility
AAPL_date_array=[]

for y in range(len(AAPL_data)):
    AAPL_date_array.append(datetime.strptime(AAPL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=AAPL_date_array[y]
    if ((firstdate-AAPL_date_array[y]).days==91):
        date_3mon_ago=AAPL_date_array[y]
        mon3_index = y
        
#last three month return
AAPL_3mon_return=round((((AAPL_data[0]['adjclose']/AAPL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
AAPL_summ_stats = {
    "Ticker": "AAPL",
  "Annual Return": AAPL_ann_return,
  "Daily Volatility": AAPL_daily_vol,
  "Annualized Volatility": AAPL_ann_vol,
  "Last 3 Months Return":  AAPL_3mon_return
}

# convert into JSON:
AAPL_summ_stats = json.dumps(AAPL_summ_stats)

# the result is a JSON string:
print(AAPL_summ_stats)
# Out:
# {"Ticker": "AAPL", "Annual Return": 19.83, "Daily Volatility": 10.84, "Annualized Volatility": 172.08, "Last 3 Months Return": 19.43}

# %% [markdown]
# # PFE Stock Calculations

# %%
with open('../Data/PFE_prices.json') as json_file:
    PFE_data = json.load(json_file)
    
#stock annual return
PFE_ann_return=round((((PFE_data[0]['adjclose']/PFE_data[len(PFE_data)-1]['adjclose'])-1)*100),2)

PFE_price_array=[]
for i in range(len(PFE_data)):
    PFE_price_array.append(PFE_data[i]['adjclose'])
    
#daily volatility
PFE_daily_vol = round(np.std(PFE_price_array),2)

#annualized volatility
PFE_ann_vol = PFE_daily_vol * math.sqrt(252)
PFE_ann_vol = round(PFE_ann_vol,2)

#3 mon return volatility
PFE_date_array=[]

for y in range(len(PFE_data)):
    PFE_date_array.append(datetime.strptime(PFE_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=PFE_date_array[y]
    if ((firstdate-PFE_date_array[y]).days==91):
        date_3mon_ago=PFE_date_array[y]
        mon3_index = y
        
#last three month return
PFE_3mon_return=round((((PFE_data[0]['adjclose']/PFE_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
PFE_summ_stats = {
    "Ticker": "PFE",
  "Annual Return": PFE_ann_return,
  "Daily Volatility": PFE_daily_vol,
  "Annualized Volatility": PFE_ann_vol,
  "Last 3 Months Return":  PFE_3mon_return
}

# convert into JSON:
PFE_summ_stats = json.dumps(PFE_summ_stats)

# the result is a JSON string:
print(PFE_summ_stats)
# Out:
# {"Ticker": "PFE", "Annual Return": 34.84, "Daily Volatility": 3.91, "Annualized Volatility": 62.07, "Last 3 Months Return": 21.42}

# %% [markdown]
# # BTC Stock Calculations

# %%
with open('../Data/BTC_prices.json') as json_file:
    BTC_data = json.load(json_file)
    
#stock annual return
BTC_ann_return=round((((BTC_data[0]['adjclose']/BTC_data[len(BTC_data)-1]['adjclose'])-1)*100),2)

BTC_price_array=[]
for i in range(len(BTC_data)):
    BTC_price_array.append(BTC_data[i]['adjclose'])
    
#daily volatility
BTC_daily_vol = round(np.std(BTC_price_array),2)

#annualized volatility
BTC_ann_vol = BTC_daily_vol * math.sqrt(252)
BTC_ann_vol = round(BTC_ann_vol,2)

#3 mon return volatility
BTC_date_array=[]

for y in range(len(BTC_data)):
    BTC_date_array.append(datetime.strptime(BTC_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=BTC_date_array[y]
    if ((firstdate-BTC_date_array[y]).days==91):
        date_3mon_ago=BTC_date_array[y]
        mon3_index = y
        
#last three month return
BTC_3mon_return=round((((BTC_data[0]['adjclose']/BTC_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
BTC_summ_stats = {
    "Ticker": "BTC",
  "Annual Return": BTC_ann_return,
  "Daily Volatility": BTC_daily_vol,
  "Annualized Volatility": BTC_ann_vol,
  "Last 3 Months Return":  BTC_3mon_return
}

# convert into JSON:
BTC_summ_stats = json.dumps(BTC_summ_stats)

# the result is a JSON string:
print(BTC_summ_stats)
# Out:
# {"Ticker": "BTC", "Annual Return": 315.16, "Daily Volatility": 16031.17, "Annualized Volatility": 254486.93, "Last 3 Months Return": 30.24}

# %% [markdown]
# # Creating a Dataframe of values

# %%
shop_df = pd.DataFrame(json.loads(SHOP_summ_stats), index=[0])
tsla_df = pd.DataFrame(json.loads(TSLA_summ_stats), index=[0])
gold_df = pd.DataFrame(json.loads(GOLD_summ_stats), index=[0])
dal_df = pd.DataFrame(json.loads(DAL_summ_stats), index=[0])
nflx_df = pd.DataFrame(json.loads(NFLX_summ_stats), index=[0])
aapl_df = pd.DataFrame(json.loads(AAPL_summ_stats), index=[0])
pfe_df = pd.DataFrame(json.loads(PFE_summ_stats), index=[0])
btc_df = pd.DataFrame(json.loads(BTC_summ_stats), index=[0])


stocks_calc_combined = shop_df.append([tsla_df,gold_df,dal_df,nflx_df,aapl_df,pfe_df,btc_df])
stocks_calc_combined.reset_index(inplace = True,drop = True)

stocks_calc_combined
# Out:
#   Ticker  Annual Return  Daily Volatility  Annualized Volatility  \
# 0   SHOP          46.96            191.43                3038.86
# 1   TSLA          60.82            131.63                2089.56
# 2   GOLD         -29.43              2.76                  43.81
# 3    DAL          29.79              5.78                  91.75
# 4   NFLX           6.69             24.02                 381.31
# 5   AAPL          19.83             10.84                 172.08
# 6    PFE          34.84              3.91                  62.07
# 7    BTC         315.16          16031.17              254486.93
#
#    Last 3 Months Return
# 0                 23.22
# 1                 13.87
# 2                -15.95
# 3                -12.92
# 4                 11.16
# 5                 19.43
# 6                 21.42
# 7                 30.24

# %%
result = stocks_calc_combined.to_json(orient="index")
parsed = json.loads(result)
with open('../Data/stocks_calc_combined.json', 'w') as outfile:
    json.dump(parsed, outfile)

# %% [markdown]
# # Get daily returns and asssets covariance

# %%
#created dataframes for daily prices
SHOP_data_df = pd.DataFrame(SHOP_data)
SHOP_data_df = SHOP_data_df[["formatted_date", "adjclose"]]
SHOP_data_df.set_index("formatted_date", inplace = True)
SHOP_data_df = SHOP_data_df.rename (columns = {"adjclose": "SHOP"})

TSLA_data_df = pd.DataFrame(TSLA_data)
TSLA_data_df = TSLA_data_df[["formatted_date", "adjclose"]]
TSLA_data_df.set_index("formatted_date", inplace = True)
TSLA_data_df = TSLA_data_df.rename (columns = {"adjclose": "TSLA"})

GOLD_data_df = pd.DataFrame(GOLD_data)
GOLD_data_df = GOLD_data_df[["formatted_date", "adjclose"]]
GOLD_data_df.set_index("formatted_date", inplace = True)
GOLD_data_df = GOLD_data_df.rename (columns = {"adjclose": "GOLD"})

DAL_data_df = pd.DataFrame(DAL_data)
DAL_data_df = DAL_data_df[["formatted_date", "adjclose"]]
DAL_data_df.set_index("formatted_date", inplace = True)
DAL_data_df = DAL_data_df.rename (columns = {"adjclose": "DAL"})

NFLX_data_df = pd.DataFrame(NFLX_data)
NFLX_data_df = NFLX_data_df[["formatted_date", "adjclose"]]
NFLX_data_df.set_index("formatted_date", inplace = True)
NFLX_data_df = NFLX_data_df.rename (columns = {"adjclose": "NFLX"})

AAPL_data_df = pd.DataFrame(AAPL_data)
AAPL_data_df = AAPL_data_df[["formatted_date", "adjclose"]]
AAPL_data_df.set_index("formatted_date", inplace = True)
AAPL_data_df = AAPL_data_df.rename (columns = {"adjclose": "AAPL"})

PFE_data_df = pd.DataFrame(PFE_data)
PFE_data_df = PFE_data_df[["formatted_date", "adjclose"]]
PFE_data_df.set_index("formatted_date", inplace = True)
PFE_data_df = PFE_data_df.rename (columns = {"adjclose": "PFE"})

BTC_data_df = pd.DataFrame(BTC_data)
BTC_data_df = BTC_data_df[["formatted_date", "adjclose"]]
BTC_data_df.set_index("formatted_date", inplace = True)
BTC_data_df = BTC_data_df.rename (columns = {"adjclose": "BTC"})
#BTC_data_df

# %%
#merge assest into a single dataframe
assets_all = pd.concat([SHOP_data_df, TSLA_data_df,GOLD_data_df , DAL_data_df, NFLX_data_df, AAPL_data_df,PFE_data_df,BTC_data_df],axis=1, join="inner")
assets_all
# Out:
#                    SHOP    TSLA   GOLD    DAL    NFLX    AAPL    PFE       BTC
# formatted_date
# 2021-08-27      1531.42  711.92  20.24  41.52  558.92  148.60  46.60  48902.40
# 2021-08-26      1515.58  701.16  19.73  40.77  550.12  147.54  47.38  49058.67
# 2021-08-25      1552.24  711.20  19.85  41.30  547.58  148.36  47.51  46942.22
# 2021-08-24      1538.51  708.49  20.12  40.53  553.41  149.62  48.38  48960.79
# 2021-08-23      1481.41  706.30  20.15  39.21  553.33  149.71  49.93  47706.12
# ...                 ...     ...    ...    ...     ...     ...    ...       ...
# 2020-09-04       973.02  418.32  28.53  31.77  516.05  120.19  33.15  10169.57
# 2020-09-03      1015.70  407.00  28.74  31.22  525.75  120.11  33.19  10511.81
# 2020-09-02      1074.59  447.37  29.08  31.14  552.84  130.56  33.91  10245.30
# 2020-09-01      1134.32  475.05  28.81  30.71  556.55  133.32  33.62  11414.03
# 2020-08-31      1066.42  498.32  29.12  30.85  529.56  128.22  34.45  11970.48
#
# [249 rows x 8 columns]

# %%
#calculate daily pricec changes
assets_all_pricechng = assets_all.pct_change()
#assets_all_pricechng

# %%
#calculate covariance
assets_all_cov = assets_all_pricechng.cov()
assets_all_cov
# Out:
#           SHOP      TSLA      GOLD       DAL      NFLX      AAPL       PFE  \
# SHOP  0.001074  0.000536  0.000140 -0.000117  0.000369  0.000309 -0.000031
# TSLA  0.000536  0.001686  0.000135  0.000127  0.000299  0.000408  0.000041
# GOLD  0.000140  0.000135  0.000409  0.000036  0.000106  0.000112  0.000034
# DAL  -0.000117  0.000127  0.000036  0.000664 -0.000045  0.000018  0.000064
# NFLX  0.000369  0.000299  0.000106 -0.000045  0.000524  0.000234 -0.000033
# AAPL  0.000309  0.000408  0.000112  0.000018  0.000234  0.000387  0.000042
# PFE  -0.000031  0.000041  0.000034  0.000064 -0.000033  0.000042  0.000221
# BTC  -0.000005  0.000163 -0.000039  0.000082 -0.000104  0.000022 -0.000052
#
#            BTC
# SHOP -0.000005
# TSLA  0.000163
# GOLD -0.000039
# DAL   0.000082
# NFLX -0.000104
# AAPL  0.000022
# PFE  -0.000052
# BTC   0.002582

# %%
# convert into JSON:
assets_all_json = assets_all_cov.to_json()
assets_all_json = json.dumps(assets_all_json)

# %% [markdown]
# # Calculate portfolio return and volatility

# %% [markdown]
# ref: https://www.machinelearningplus.com/machine-learning/portfolio-optimization-python-example/

# %%
portfolio_return = []
portfolio_volati = []
asset_weights = []

# %%
#calculate number of assest and max number of portfolios to itterate
num_assets = stocks_calc_combined["Ticker"].count()
print(num_assets)
num_portf = 1000
# Out:
# 8

# %% [markdown]
# for portfolio in range(num_portf):
#     #portfolio returns
#     weights = np.random.random(num_assets)
#     weights = weights/np.sum(weights)
#     asset_weights.append(weights)
# asset_weights

# %% [markdown]
# len(asset_weights)

# %%
for portfolio in range(num_portf):
    #portfolio returns
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    asset_weights.append(weights)
    portf_return = np.dot(weights, stocks_calc_combined["Annual Return"])
    portfolio_return.append(portf_return)
    
    #portfolio risk
    portf_var = assets_all_cov.mul(weights, axis=0).mul(weights, axis=1).sum().sum()
    portf_stdev = np.sqrt(portf_var) # Daily standard deviation
    portf_ann_stdev = portf_stdev*np.sqrt(250) # Annual standard deviation = volatility
    portfolio_volati.append(portf_ann_stdev)
    
    
#portfolio_return

# %%
print(len(portfolio_return), len(portfolio_volati), len(asset_weights))
# Out:
# 1000 1000 1000

# %% [markdown]
# #plot the graph
# plt.figure(figsize=(12,8))
# plt.scatter(portfolio_volati,portfolio_return, marker = "o",facecolors = 'green')
# plt.title(f"Efficient Frontier", fontsize = 13, fontweight = 'bold', y=1.05)
# plt.xlabel("Risk")
# plt.ylabel("Return")
# plt.grid()
# plt.ylim(-20,60)
# plt.xlim(0.05,0.4)
#
# plt.show()

# %%
data = {'Returns':portfolio_return, 'Volatility':portfolio_volati}

for counter, symbol in enumerate(assets_all.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in asset_weights]
    
portfolios  = pd.DataFrame(data)
portf = portfolios.to_dict(orient='records')
portf
# Out:
# [{'Returns': 75.62042112188988,
#   'Volatility': 0.22929720391334374,
#   'SHOP weight': 0.0029027941707776245,
#   'TSLA weight': 0.05317629421305022,
#   'GOLD weight': 0.13238796593249,
#   'DAL weight': 0.2563790552801886,
#   'NFLX weight': 0.08612911292253878,
#   'AAPL weight': 0.1588748127996986,
#   'PFE weight': 0.11759769084626745,
#   'BTC weight': 0.19255227383498869},
#  {'Returns': 86.87323146660071,
#   'Volatility': 0.2459802440258871,
#   'SHOP weight': 0.0075575916934768,
#   'TSLA weight': 0.11434917230102143,
#   'GOLD weight': 0.23338001354175084,
#   'DAL weight': 0.03439863148645499,
#   'NFLX weight': 0.0005521502342260088,
#   'AAPL weight': 0.09364873004718337,
#   'PFE weight': 0.28221995004615824,
#   'BTC weight': 0.23389376064972833},
#  {'Returns': 37.65750678731416,
#   'Volatility': 0.29335906416739777,
#   'SHOP weight': 0.3218543769743209,
#   'TSLA weight': 0.1488874828595671,
#   'GOLD weight': 0.06180761632736011,
#   'DAL weight': 0.049774088236849645,
#   'NFLX weight': 0.055169810050706966,
#   'AAPL weight': 0.23933591543817842,
#   'PFE weight': 0.10741110742928463,
#   'BTC weight': 0.015759602683732235},
#  {'Returns': 101.61184375253607,
#   'Volatility': 0.2621725186438917,
#   'SHOP weight': 0.01080836367100541,
#   'TSLA weight': 0.022834727541556514,
#   'GOLD weight': 0.060620496396043014,
#   'DAL weight': 0.22586372038903108,
#   'NFLX weight': 0.12781207994138383,
#   'AAPL weight': 0.13448529752256588,
#   'PFE weight': 0.1439565016787689,
#   'BTC weight': 0.2736188128596454},
#  {'Returns': 63.32615068770207,
#   'Volatility': 0.23419093783691888,
#   'SHOP weight': 0.2047819034375613,
#   'TSLA weight': 0.09990770495714278,
#   'GOLD weight': 0.17800876163303253,
#   'DAL weight': 0.1808201034555651,
#   'NFLX weight': 0.08948673215040928,
#   'AAPL weight': 0.022917799471465463,
#   'PFE weight': 0.08628659764896672,
#   'BTC weight': 0.1377903972458568},
#  {'Returns': 32.516254494727825,
#   'Volatility': 0.28428190250422,
#   'SHOP weight': 0.022996523713440246,
#   'TSLA weight': 0.28045828440648446,
#   'GOLD weight': 0.0552171608436883,
#   'DAL weight': 0.304204210633153,
#   'NFLX weight': 0.13004402626390815,
#   'AAPL weight': 0.15349835552043312,
#   'PFE weight': 0.049439678326182755,
#   'BTC weight': 0.0041417602927099366},
#  {'Returns': 46.30245078116106,
#   'Volatility': 0.1937921185300727,
#   'SHOP weight': 0.1807473643684161,
#   'TSLA weight': 0.026996795897909823,
#   'GOLD weight': 0.15932375434875237,
#   'DAL weight': 0.22175922058932934,
#   'NFLX weight': 0.1217322719941776,
#   'AAPL weight': 0.019728352645038465,
#   'PFE weight': 0.1853339448032202,
#   'BTC weight': 0.08437829535315608},
#  {'Returns': 49.344062747040226,
#   'Volatility': 0.19934122583730474,
#   'SHOP weight': 0.006537854965310705,
#   'TSLA weight': 0.11205909695801651,
#   'GOLD weight': 0.10057087408144574,
#   'DAL weight': 0.19842099867360719,
#   'NFLX weight': 0.23984081658462914,
#   'AAPL weight': 0.04404747513089314,
#   'PFE weight': 0.2043736387609932,
#   'BTC weight': 0.0941492448451043},
#  {'Returns': 40.74611221153562,
#   'Volatility': 0.2037729020040492,
#   'SHOP weight': 0.17411969856737586,
#   'TSLA weight': 0.09168575916789712,
#   'GOLD weight': 0.10905748908798654,
#   'DAL weight': 0.06650859712608452,
#   'NFLX weight': 0.0663578439426743,
#   'AAPL weight': 0.13299709628796605,
#   'PFE weight': 0.3142426995987066,
#   'BTC weight': 0.04503081622130897},
#  {'Returns': 35.712863738980545,
#   'Volatility': 0.30252132312086344,
#   'SHOP weight': 0.18356020371605292,
#   'TSLA weight': 0.26833158137260865,
#   'GOLD weight': 0.03122499828560646,
#   'DAL weight': 0.010111030083384459,
#   'NFLX weight': 0.26006693260519553,
#   'AAPL weight': 0.06109798225902794,
#   'PFE weight': 0.17856990083707497,
#   'BTC weight': 0.0070373708410491195},
#  {'Returns': 66.26313493880478,
#   'Volatility': 0.2281653207695443,
#   'SHOP weight': 0.07624125617947275,
#   'TSLA weight': 0.10759556089102355,
#   'GOLD weight': 0.13432864897743219,
#   'DAL weight': 0.21565370044891946,
#   'NFLX weight': 0.21176368403333412,
#   'AAPL weight': 0.021475401123191986,
#   'PFE weight': 0.07701421846861194,
#   'BTC weight': 0.15592752987801392},
#  {'Returns': 43.0291424203732,
#   'Volatility': 0.33625702139795904,
#   'SHOP weight': 0.2367435613250874,
#   'TSLA weight': 0.3189562531864758,
#   'GOLD weight': 0.010563242854531455,
#   'DAL weight': 0.08380348596253552,
#   'NFLX weight': 0.09075285567358302,
#   'AAPL weight': 0.17098878724468233,
#   'PFE weight': 0.07657413108524608,
#   'BTC weight': 0.01161768266785845},
#  {'Returns': 72.91944531072856,
#   'Volatility': 0.2855763214061153,
#   'SHOP weight': 0.11230548544547153,
#   'TSLA weight': 0.277268839090954,
#   'GOLD weight': 0.10021121694262007,
#   'DAL weight': 0.07235864863101502,
#   'NFLX weight': 0.12271566427832982,
#   'AAPL weight': 0.04717401314856975,
#   'PFE weight': 0.12354770936504358,
#   'BTC weight': 0.14441842309799618},
#  {'Returns': 70.49406023056949,
#   'Volatility': 0.2095198389450025,
#   'SHOP weight': 0.0864260582513154,
#   'TSLA weight': 0.050535623965820654,
#   'GOLD weight': 0.21050780560692467,
#   'DAL weight': 0.12441158793626353,
#   'NFLX weight': 0.07674036013608006,
#   'AAPL weight': 0.05549744859973735,
#   'PFE weight': 0.21592772680280445,
#   'BTC weight': 0.17995338870105385},
#  {'Returns': 93.49374341699193,
#   'Volatility': 0.29348447630763796,
#   'SHOP weight': 0.09405061875764929,
#   'TSLA weight': 0.24632760940736179,
#   'GOLD weight': 0.05711359718193871,
#   'DAL weight': 0.1068350936742504,
#   'NFLX weight': 0.14009783556572727,
#   'AAPL weight': 0.038433657806995945,
#   'PFE weight': 0.10365303875461282,
#   'BTC weight': 0.21348854885146384},
#  {'Returns': 64.53080876577613,
#   'Volatility': 0.2092836638825057,
#   'SHOP weight': 0.15826793330778183,
#   'TSLA weight': 0.028935604595472317,
#   'GOLD weight': 0.11593285665016202,
#   'DAL weight': 0.1396047198387016,
#   'NFLX weight': 0.0705880559055043,
#   'AAPL weight': 0.17678735636052959,
#   'PFE weight': 0.16784046916270218,
#   'BTC weight': 0.14204300417914628},
#  {'Returns': 65.0838456933512,
#   'Volatility': 0.28335051821221796,
#   'SHOP weight': 0.1620022398995106,
#   'TSLA weight': 0.2500431831228382,
#   'GOLD weight': 0.16583023436113786,
#   'DAL weight': 0.20573674827215838,
#   'NFLX weight': 0.03520071557968192,
#   'AAPL weight': 0.03858721492851246,
#   'PFE weight': 0.017559600233679373,
#   'BTC weight': 0.12504006360248124},
#  {'Returns': 70.0474605388198,
#   'Volatility': 0.2500532812137296,
#   'SHOP weight': 0.1377705453859378,
#   'TSLA weight': 0.14670411027587735,
#   'GOLD weight': 0.09607761839919486,
#   'DAL weight': 0.023239146056291394,
#   'NFLX weight': 0.14202761696259816,
#   'AAPL weight': 0.15028421392791916,
#   'PFE weight': 0.15309616953145558,
#   'BTC weight': 0.15080057946072584},
#  {'Returns': 56.950655201274884,
#   'Volatility': 0.27189733933402305,
#   'SHOP weight': 0.2715307370095301,
#   'TSLA weight': 0.13720613378108362,
#   'GOLD weight': 0.09630971290660836,
#   'DAL weight': 0.16162379210425695,
#   'NFLX weight': 0.12295483306454255,
#   'AAPL weight': 0.10913306880117925,
#   'PFE weight': 0.0036376319175821328,
#   'BTC weight': 0.09760409041521696},
#  {'Returns': 101.07381972094348,
#   'Volatility': 0.29049850111928066,
#   'SHOP weight': 0.07572563829699289,
#   'TSLA weight': 0.2243685272623638,
#   'GOLD weight': 0.07420033625203148,
#   'DAL weight': 0.004340345295422626,
#   'NFLX weight': 0.09066301839702665,
#   'AAPL weight': 0.0748853482502924,
#   'PFE weight': 0.21340133944835005,
#   'BTC weight': 0.24241544679752008},
#  {'Returns': 53.54645424986202,
#   'Volatility': 0.2715243913694487,
#   'SHOP weight': 0.2201448186122112,
#   'TSLA weight': 0.21272242186541426,
#   'GOLD weight': 0.06990392644800751,
#   'DAL weight': 0.19368313702639794,
#   'NFLX weight': 0.1263790680878498,
#   'AAPL weight': 0.03543352144541835,
#   'PFE weight': 0.07012914088048273,
#   'BTC weight': 0.07160396563421811},
#  {'Returns': 30.792811023805342,
#   'Volatility': 0.20439048272716304,
#   'SHOP weight': 0.04609465409368258,
#   'TSLA weight': 0.010140920903120977,
#   'GOLD weight': 0.30766065644422935,
#   'DAL weight': 0.34465217638542317,
#   'NFLX weight': 0.10154717088331182,
#   'AAPL weight': 0.01401426786403044,
#   'PFE weight': 0.10556540459433757,
#   'BTC weight': 0.07032474883186414},
#  {'Returns': 35.62862643093715,
#   'Volatility': 0.2531659574794679,
#   'SHOP weight': 0.20350588405369638,
#   'TSLA weight': 0.10229768918639473,
#   'GOLD weight': 0.04645796795827017,
#   'DAL weight': 0.07104720409222165,
#   'NFLX weight': 0.2609226028129132,
#   'AAPL weight': 0.16582458468595046,
#   'PFE weight': 0.11839768658196041,
#   'BTC weight': 0.031546380628592975},
#  {'Returns': 78.63274680578314,
#   'Volatility': 0.2267968835427229,
#   'SHOP weight': 0.1609683612759218,
#   'TSLA weight': 0.07255635562176634,
#   'GOLD weight': 0.06316369064791359,
#   'DAL weight': 0.15353177744161955,
#   'NFLX weight': 0.001848610566609634,
#   'AAPL weight': 0.171135681945341,
#   'PFE weight': 0.20765865393798327,
#   'BTC weight': 0.16913686856284493},
#  {'Returns': 96.03117626182953,
#   'Volatility': 0.26616330832198903,
#   'SHOP weight': 0.028014588827175637,
#   'TSLA weight': 0.18791376249744227,
#   'GOLD weight': 0.13977856572307298,
#   'DAL weight': 0.06732616235269917,
#   'NFLX weight': 0.037122869132804305,
#   'AAPL weight': 0.04553767916698222,
#   'PFE weight': 0.2552162796740797,
#   'BTC weight': 0.23909009262574368},
#  {'Returns': 34.53728077071494,
#   'Volatility': 0.20499164397323483,
#   'SHOP weight': 0.2116119326080057,
#   'TSLA weight': 0.030208736370315153,
#   'GOLD weight': 0.12192321295088751,
#   'DAL weight': 0.13948754537544542,
#   'NFLX weight': 0.17639359749890496,
#   'AAPL weight': 0.08660947915593269,
#   'PFE weight': 0.19397658968766401,
#   'BTC weight': 0.03978890635284455},
#  {'Returns': 79.50125825517694,
#   'Volatility': 0.2243448062912054,
#   'SHOP weight': 0.1547624944325621,
#   'TSLA weight': 0.010017247970937553,
#   'GOLD weight': 0.12570083399276177,
#   'DAL weight': 0.11187498371111276,
#   'NFLX weight': 0.045147122399708306,
#   'AAPL weight': 0.1747106060577815,
#   'PFE weight': 0.1813599574350493,
#   'BTC weight': 0.19642675400008677},
#  {'Returns': 29.726830940073558,
#   'Volatility': 0.2562865231962944,
#   'SHOP weight': 0.00945796992122871,
#   'TSLA weight': 0.25168426638249664,
#   'GOLD weight': 0.19618339934637485,
#   'DAL weight': 0.23239836780123754,
#   'NFLX weight': 0.1640662574094596,
#   'AAPL weight': 0.050951932822128544,
#   'PFE weight': 0.06886291620885768,
#   'BTC weight': 0.026394890108216332},
#  {'Returns': 47.96925693049898,
#   'Volatility': 0.1961934965160372,
#   'SHOP weight': 0.07995770337245076,
#   'TSLA weight': 0.05998118081510248,
#   'GOLD weight': 0.1669139127226663,
#   'DAL weight': 0.0821521756858018,
#   'NFLX weight': 0.1307240127107932,
#   'AAPL weight': 0.18351704813791572,
#   'PFE weight': 0.19623043631730405,
#   'BTC weight': 0.10052353023796559},
#  {'Returns': 78.76413082196483,
#   'Volatility': 0.2611046862445901,
#   'SHOP weight': 0.10611797292166328,
#   'TSLA weight': 0.10279343424165058,
#   'GOLD weight': 0.13554158557031282,
#   'DAL weight': 0.10000961210972896,
#   'NFLX weight': 0.13355346375868699,
#   'AAPL weight': 0.212677725180568,
#   'PFE weight': 0.009051010462246425,
#   'BTC weight': 0.20025519575514297},
#  {'Returns': 36.5409515115512,
#   'Volatility': 0.22960671182255285,
#   'SHOP weight': 0.223075734431268,
#   'TSLA weight': 0.09781029478119628,
#   'GOLD weight': 0.08678997359933857,
#   'DAL weight': 0.21713091403634252,
#   'NFLX weight': 0.03907575324461589,
#   'AAPL weight': 0.1775120613977886,
#   'PFE weight': 0.13400801049589958,
#   'BTC weight': 0.024597258013550644},
#  {'Returns': 88.74218599280043,
#   'Volatility': 0.2903815258402983,
#   'SHOP weight': 0.10616328361457468,
#   'TSLA weight': 0.18444575525591594,
#   'GOLD weight': 0.10419336876835415,
#   'DAL weight': 0.03039904238464671,
#   'NFLX weight': 0.18489874783498297,
#   'AAPL weight': 0.12248929591746381,
#   'PFE weight': 0.04724400603890346,
#   'BTC weight': 0.22016650018515826},
#  {'Returns': 31.26863526099279,
#   'Volatility': 0.23607771400811162,
#   'SHOP weight': 0.010589637550685657,
#   'TSLA weight': 0.18575593962115963,
#   'GOLD weight': 0.1470048562743112,
#   'DAL weight': 0.1754684313856599,
#   'NFLX weight': 0.15438130708188252,
#   'AAPL weight': 0.20529541046471111,
#   'PFE weight': 0.08855712474488253,
#   'BTC weight': 0.03294729287670742},
#  {'Returns': 30.440534544596836,
#   'Volatility': 0.2752024538388811,
#   'SHOP weight': 0.24082015154940745,
#   'TSLA weight': 0.19455251062138842,
#   'GOLD weight': 0.12175779203747553,
#   'DAL weight': 0.15359295888720384,
#   'NFLX weight': 0.06835941021382809,
#   'AAPL weight': 0.14605750125353903,
#   'PFE weight': 0.07362901651222124,
#   'BTC weight': 0.0012306589249363572},
#  {'Returns': 60.18856518773492,
#   'Volatility': 0.2443203466574806,
#   'SHOP weight': 0.14462221404116665,
#   'TSLA weight': 0.1616597168194352,
#   'GOLD weight': 0.05770347095814474,
#   'DAL weight': 0.2116449271927002,
#   'NFLX weight': 0.039759645239238216,
#   'AAPL weight': 0.18163717643914393,
#   'PFE weight': 0.10301979029466647,
#   'BTC weight': 0.09995305901550464},
#  {'Returns': 65.28990625059706,
#   'Volatility': 0.20616830962786137,
#   'SHOP weight': 0.06768787846882723,
#   'TSLA weight': 0.022128423982540852,
#   'GOLD weight': 0.17282347047221636,
#   'DAL weight': 0.18227606222225062,
#   'NFLX weight': 0.1422307651887884,
#   'AAPL weight': 0.11013201608787489,
#   'PFE weight': 0.13598562133612188,
#   'BTC weight': 0.1667357622413797},
#  {'Returns': 85.30718617929338,
#   'Volatility': 0.25515980157390283,
#   'SHOP weight': 0.2385845607451407,
#   'TSLA weight': 0.03793960697997268,
#   'GOLD weight': 0.10582741540184964,
#   'DAL weight': 0.02463747159841802,
#   'NFLX weight': 0.16073541151978488,
#   'AAPL weight': 0.05498913870912162,
#   'PFE weight': 0.16729100998764557,
#   'BTC weight': 0.2099953850580669},
#  {'Returns': 49.10224720478298,
#   'Volatility': 0.2216126406675694,
#   'SHOP weight': 0.03833295597084599,
#   'TSLA weight': 0.11907447568650432,
#   'GOLD weight': 0.15134820708873584,
#   'DAL weight': 0.14585838035174203,
#   'NFLX weight': 0.16675091452453447,
#   'AAPL weight': 0.2011846171616493,
#   'PFE weight': 0.07441944772514793,
#   'BTC weight': 0.10303100149084009},
#  {'Returns': 42.062937567233966,
#   'Volatility': 0.2300036986010545,
#   'SHOP weight': 0.17593992630970925,
#   'TSLA weight': 0.12163617368240673,
#   'GOLD weight': 0.18132093251639617,
#   'DAL weight': 0.007733737728862598,
#   'NFLX weight': 0.15278630032408913,
#   'AAPL weight': 0.08889650561047785,
#   'PFE weight': 0.2029854375274473,
#   'BTC weight': 0.06870098630061101},
#  {'Returns': 33.18058630173411,
#   'Volatility': 0.253674304429767,
#   'SHOP weight': 0.2137652602348334,
#   'TSLA weight': 0.17123790694748645,
#   'GOLD weight': 0.2416754682136426,
#   'DAL weight': 0.22306255431200833,
#   'NFLX weight': 0.04967090277917544,
#   'AAPL weight': 0.03197651802665639,
#   'PFE weight': 0.03351527713112971,
#   'BTC weight': 0.03509611235506771},
#  {'Returns': 55.092191348119286,
#   'Volatility': 0.19736182699166469,
#   'SHOP weight': 0.04584276117135435,
#   'TSLA weight': 0.017992934064506215,
#   'GOLD weight': 0.18394540465240578,
#   'DAL weight': 0.14689187336668702,
#   'NFLX weight': 0.14746842327248466,
#   'AAPL weight': 0.1857749710114182,
#   'PFE weight': 0.13391006581145656,
#   'BTC weight': 0.1381735666496872},
#  {'Returns': 45.22819838523862,
#   'Volatility': 0.23779198573518973,
#   'SHOP weight': 0.09503319916846631,
#   'TSLA weight': 0.19026133828299627,
#   'GOLD weight': 0.22644799701778368,
#   'DAL weight': 0.08653248279909818,
#   'NFLX weight': 0.16912380608162608,
#   'AAPL weight': 0.024907104407130978,
#   'PFE weight': 0.12058327377135959,
#   'BTC weight': 0.08711079847153888},
#  {'Returns': 75.56268355452778,
#   'Volatility': 0.3033035574560274,
#   'SHOP weight': 0.20032813794918747,
#   'TSLA weight': 0.20767488472573353,
#   'GOLD weight': 0.07331542517297107,
#   'DAL weight': 0.0340667218794974,
#   'NFLX weight': 0.16818732311536758,
#   'AAPL weight': 0.13995529210112673,
#   'PFE weight': 0.01730221498868279,
#   'BTC weight': 0.1591700000674333},
#  {'Returns': 59.18138732713115,
#   'Volatility': 0.22376229044360108,
#   'SHOP weight': 0.1397740142951252,
#   'TSLA weight': 0.1395342808616498,
#   'GOLD weight': 0.09404314700557458,
#   'DAL weight': 0.23823307868988894,
#   'NFLX weight': 0.01754156960057949,
#   'AAPL weight': 0.08823411395559405,
#   'PFE weight': 0.1824412903217157,
#   'BTC weight': 0.10019850526987217},
#  {'Returns': 38.165644106648564,
#   'Volatility': 0.22139785424691086,
#   'SHOP weight': 0.23616167678108482,
#   'TSLA weight': 0.09010678083251286,
#   'GOLD weight': 0.05335807569846278,
#   'DAL weight': 0.08983453285780829,
#   'NFLX weight': 0.10091127586558754,
#   'AAPL weight': 0.12109493835760418,
#   'PFE weight': 0.2847610808566927,
#   'BTC weight': 0.02377163875024682},
#  {'Returns': 92.5084781124801,
#   'Volatility': 0.2499141252674319,
#   'SHOP weight': 0.1696665624089706,
#   'TSLA weight': 0.11877356596855455,
#   'GOLD weight': 0.043192099116593774,
#   'DAL weight': 0.19322758521239705,
#   'NFLX weight': 0.041285023417533095,
#   'AAPL weight': 0.02173922338787223,
#   'PFE weight': 0.2060421077254433,
#   'BTC weight': 0.20607383276263536},
#  {'Returns': 43.2894731839403,
#   'Volatility': 0.22002110493956367,
#   'SHOP weight': 0.055076785028773195,
#   'TSLA weight': 0.15181400673711667,
#   'GOLD weight': 0.024979721395838712,
#   'DAL weight': 0.23780358162889184,
#   'NFLX weight': 0.09961260244957892,
#   'AAPL weight': 0.18515704940251473,
#   'PFE weight': 0.2019365633380753,
#   'BTC weight': 0.04361969001921066},
#  {'Returns': 82.364567479738,
#   'Volatility': 0.24252769707084854,
#   'SHOP weight': 0.16313203579060426,
#   'TSLA weight': 0.03333773342499296,
#   'GOLD weight': 0.2087386532772354,
#   'DAL weight': 0.08216998121211497,
#   'NFLX weight': 0.08726568142126102,
#   'AAPL weight': 0.07727063124440023,
#   'PFE weight': 0.12645198721882242,
#   'BTC weight': 0.22163329641056864},
#  {'Returns': 63.68572781881841,
#   'Volatility': 0.25268160002110146,
#   'SHOP weight': 0.11420497641160603,
#   'TSLA weight': 0.12518073485751383,
#   'GOLD weight': 0.18196825283470192,
#   'DAL weight': 0.06523817902657143,
#   'NFLX weight': 0.05468175611198649,
#   'AAPL weight': 0.2707409560367692,
#   'PFE weight': 0.03873773600386227,
#   'BTC weight': 0.1492474087169889},
#  {'Returns': 27.819717687538933,
#   'Volatility': 0.19078393425411014,
#   'SHOP weight': 0.1714091763882447,
#   'TSLA weight': 0.03799605181740725,
#   'GOLD weight': 0.11504860788160218,
#   'DAL weight': 0.18609005607124915,
#   'NFLX weight': 0.03360626186452285,
#   'AAPL weight': 0.15576126030272455,
#   'PFE weight': 0.2946197548957185,
#   'BTC weight': 0.005468830778530831},
#  {'Returns': 13.484178355026007,
#   'Volatility': 0.19946919896986706,
#   'SHOP weight': 0.02805675854738028,
#   'TSLA weight': 0.07587168227117458,
#   'GOLD weight': 0.24715855870588205,
#   'DAL weight': 0.053155069582274,
#   'NFLX weight': 0.17270499671960662,
#   'AAPL weight': 0.19324375079608852,
#   'PFE weight': 0.22892258177032246,
#   'BTC weight': 0.0008866016072716067},
#  {'Returns': 41.64754636011597,
#   'Volatility': 0.21731929991932641,
#   'SHOP weight': 0.013112255765426222,
#   'TSLA weight': 0.1347544891804097,
#   'GOLD weight': 0.1660163316745483,
#   'DAL weight': 0.19286345807247607,
#   'NFLX weight': 4.4837587646318906e-05,
#   'AAPL weight': 0.27578692762719,
#   'PFE weight': 0.14988332162092236,
#   'BTC weight': 0.06753837847138108},
#  {'Returns': 45.508898589722136,
#   'Volatility': 0.20480240786795098,
#   'SHOP weight': 0.027507082891203127,
#   'TSLA weight': 0.12445576920955147,
#   'GOLD weight': 0.1657910186486684,
#   'DAL weight': 0.16591439986727743,
#   'NFLX weight': 0.16089238990743593,
#   'AAPL weight': 0.10671646197462582,
#   'PFE weight': 0.1605153175018452,
#   'BTC weight': 0.08820755999939259},
#  {'Returns': 95.00418875797,
#   'Volatility': 0.297535242261545,
#   'SHOP weight': 0.24139753932830219,
#   'TSLA weight': 0.10783117639451865,
#   'GOLD weight': 0.2510781548576164,
#   'DAL weight': 0.10180849312234153,
#   'NFLX weight': 0.0065654865556555985,
#   'AAPL weight': 0.030728713528860006,
#   'PFE weight': 0.004690111732975028,
#   'BTC weight': 0.25590032447973066},
#  {'Returns': 62.29036535043186,
#   'Volatility': 0.23642842901080552,
#   'SHOP weight': 0.15470649358614946,
#   'TSLA weight': 0.09960935732481899,
#   'GOLD weight': 0.08154789695380807,
#   'DAL weight': 0.05899092398802926,
#   'NFLX weight': 0.15307240388719703,
#   'AAPL weight': 0.19161957718577874,
#   'PFE weight': 0.1330573101478029,
#   'BTC weight': 0.1273960369264157},
#  {'Returns': 81.11008486598558,
#   'Volatility': 0.25189866830501734,
#   'SHOP weight': 0.02293410877356753,
#   'TSLA weight': 0.13761879318709355,
#   'GOLD weight': 0.013010940580304954,
#   'DAL weight': 0.039166285651672725,
#   'NFLX weight': 0.22048523450345456,
#   'AAPL weight': 0.21367106768711125,
#   'PFE weight': 0.16452676813441047,
#   'BTC weight': 0.18858680148238505},
#  {'Returns': 70.34871699529972,
#   'Volatility': 0.2188228043913912,
#   'SHOP weight': 0.06745691555359959,
#   'TSLA weight': 0.06507636043907662,
#   'GOLD weight': 0.12162797841841635,
#   'DAL weight': 0.2107600841449086,
#   'NFLX weight': 0.03211399114354849,
#   'AAPL weight': 0.19655389936564782,
#   'PFE weight': 0.1432539972025124,
#   'BTC weight': 0.16315677373229007},
#  {'Returns': 59.85015480765755,
#   'Volatility': 0.22502843032629027,
#   'SHOP weight': 0.11064756386347979,
#   'TSLA weight': 0.1444885059929419,
#   'GOLD weight': 0.025734415335835238,
#   'DAL weight': 0.16671925400645532,
#   'NFLX weight': 0.13882497592980003,
#   'AAPL weight': 0.12864165506332637,
#   'PFE weight': 0.18416590303437894,
#   'BTC weight': 0.10077772677378236},
#  {'Returns': 42.256500053571585,
#   'Volatility': 0.20414251067415554,
#   'SHOP weight': 0.1390554436355066,
#   'TSLA weight': 0.0031536956923000816,
#   'GOLD weight': 0.23202058109925275,
#   'DAL weight': 0.22387760066002257,
#   'NFLX weight': 0.006744850528656955,
#   'AAPL weight': 0.22953918625550868,
#   'PFE weight': 0.07525829102543387,
#   'BTC weight': 0.09035035110331853},
#  {'Returns': 77.26566762670365,
#   'Volatility': 0.25051948263495516,
#   'SHOP weight': 0.12071615612720547,
#   'TSLA weight': 0.14248063117979898,
#   'GOLD weight': 0.12099039520928685,
#   'DAL weight': 0.10025602471529264,
#   'NFLX weight': 0.13633659856985608,
#   'AAPL weight': 0.09640104876468936,
#   'PFE weight': 0.10149729314718665,
#   'BTC weight': 0.181321852286684},
#  {'Returns': 35.09227914927406,
#   'Volatility': 0.23528472203511705,
#   'SHOP weight': 0.16372990775214974,
#   'TSLA weight': 0.15971872033330625,
#   'GOLD weight': 0.13206314407690395,
#   'DAL weight': 0.05581227672527915,
#   'NFLX weight': 0.14130956520536045,
#   'AAPL weight': 0.10680685812297688,
#   'PFE weight': 0.21034774916922347,
#   'BTC weight': 0.0302117786148001},
#  {'Returns': 73.17870178165683,
#   'Volatility': 0.21708096332855975,
#   'SHOP weight': 0.0444221740754106,
#   'TSLA weight': 0.03666125873205933,
#   'GOLD weight': 0.16364906003346696,
#   'DAL weight': 0.10445896428061557,
#   'NFLX weight': 0.13721140643019938,
#   'AAPL weight': 0.1612865475113179,
#   'PFE weight': 0.15904396309101496,
#   'BTC weight': 0.19326662584591525},
#  {'Returns': 83.73487143131122,
#   'Volatility': 0.2504644515610369,
#   'SHOP weight': 0.13373218498931308,
#   'TSLA weight': 0.02101989061963382,
#   'GOLD weight': 0.14175249920269398,
#   'DAL weight': 0.020753205661423756,
#   'NFLX weight': 0.18800519171728983,
#   'AAPL weight': 0.15432139012829915,
#   'PFE weight': 0.11370370982761686,
#   'BTC weight': 0.22671192785372957},
#  {'Returns': 55.2798711769714,
#   'Volatility': 0.267962988864365,
#   'SHOP weight': 0.10818311870285757,
#   'TSLA weight': 0.151995881239414,
#   'GOLD weight': 0.2056585838896345,
#   'DAL weight': 0.00863110627529565,
#   'NFLX weight': 0.19287660650344055,
#   'AAPL weight': 0.19835000664118893,
#   'PFE weight': 0.0028555916906419605,
#   'BTC weight': 0.13144910505752688},
#  {'Returns': 71.9713370227507,
#   'Volatility': 0.24474629611479662,
#   'SHOP weight': 0.15267578871920182,
#   'TSLA weight': 0.1308256934891804,
#   'GOLD weight': 0.18099093509626168,
#   'DAL weight': 0.1395044741690467,
#   'NFLX weight': 0.12810897236407312,
#   'AAPL weight': 0.013230598874752765,
#   'PFE weight': 0.08334611861962467,
#   'BTC weight': 0.17131741866785882},
#  {'Returns': 86.34158588442511,
#   'Volatility': 0.24232945875322429,
#   'SHOP weight': 0.09125275347706042,
#   'TSLA weight': 0.06660237420484857,
#   'GOLD weight': 0.11581638423497514,
#   'DAL weight': 0.1691419280526955,
#   'NFLX weight': 0.04198066623297703,
#   'AAPL weight': 0.17624948543430302,
#   'PFE weight': 0.12209632305807355,
#   'BTC weight': 0.21686008530506679},
#  {'Returns': 73.1174333913729,
#   'Volatility': 0.2325102867438573,
#   'SHOP weight': 0.14071543821589208,
#   'TSLA weight': 0.06464743197253932,
#   'GOLD weight': 0.1797102251476825,
#   'DAL weight': 0.1270862013427865,
#   'NFLX weight': 0.10102767132819919,
#   'AAPL weight': 0.10967295991738976,
#   'PFE weight': 0.09315639784312929,
#   'BTC weight': 0.1839836742323814},
#  {'Returns': 88.3368187055516,
#   'Volatility': 0.26238469100907175,
#   'SHOP weight': 0.2463081525890482,
#   'TSLA weight': 0.0780671569498161,
#   'GOLD weight': 0.03922075465649687,
#   'DAL weight': 0.02341776027014156,
#   'NFLX weight': 0.04722311573174304,
#   'AAPL weight': 0.17082606557933547,
#   'PFE weight': 0.19867633960745218,
#   'BTC weight': 0.1962606546159666},
#  {'Returns': 16.13849307290687,
#   'Volatility': 0.21296546277249978,
#   'SHOP weight': 0.039271720882440984,
#   'TSLA weight': 0.07585283903074876,
#   'GOLD weight': 0.2493407694615025,
#   'DAL weight': 0.09247894556201225,
#   'NFLX weight': 0.23987969739980478,
#   'AAPL weight': 0.18497698854890687,
#   'PFE weight': 0.1008148672178396,
#   'BTC weight': 0.01738417189674427},
#  {'Returns': 59.06745772606875,
#   'Volatility': 0.21433659958547402,
#   'SHOP weight': 0.07345808650795065,
#   'TSLA weight': 0.1459126311281396,
#   'GOLD weight': 0.14611974402900707,
#   'DAL weight': 0.21708792902087243,
#   'NFLX weight': 0.07253391330463337,
#   'AAPL weight': 0.017028081492063682,
#   'PFE weight': 0.21252297526967218,
#   'BTC weight': 0.11533663924766094},
#  {'Returns': 73.25884838201358,
#   'Volatility': 0.2230720508317007,
#   'SHOP weight': 0.006730406947167219,
#   'TSLA weight': 0.0012140691978671954,
#   'GOLD weight': 0.1275999626224153,
#   'DAL weight': 0.23827266434222427,
#   'NFLX weight': 0.2347094244289633,
#   'AAPL weight': 0.09830406161524238,
#   'PFE weight': 0.0941380354635423,
#   'BTC weight': 0.1990313753825781},
#  {'Returns': 59.990634393274384,
#   'Volatility': 0.24012078043057397,
#   'SHOP weight': 0.1774088613730604,
#   'TSLA weight': 0.14878341815070212,
#   'GOLD weight': 0.023264677509135783,
#   'DAL weight': 0.11458225327214543,
#   'NFLX weight': 0.1268824895372976,
#   'AAPL weight': 0.1367929333469526,
#   'PFE weight': 0.17655937151095275,
#   'BTC weight': 0.09572599529975323},
#  {'Returns': 65.20710944777446,
#   'Volatility': 0.21691315603352332,
#   'SHOP weight': 0.14677848644283506,
#   'TSLA weight': 0.011304144522107418,
#   'GOLD weight': 0.1804906766742557,
#   'DAL weight': 0.038370537363326504,
#   'NFLX weight': 0.20482551920441955,
#   'AAPL weight': 0.07434511802999941,
#   'PFE weight': 0.17632652051642095,
#   'BTC weight': 0.16755899724663545},
#  {'Returns': 65.31045220412722,
#   'Volatility': 0.24471547425988788,
#   'SHOP weight': 0.08581161230743874,
#   'TSLA weight': 0.2030439717189876,
#   'GOLD weight': 0.176280080653959,
#   'DAL weight': 0.09885741091763695,
#   'NFLX weight': 0.07663048922389358,
#   'AAPL weight': 0.0618875848130884,
#   'PFE weight': 0.15811183585956326,
#   'BTC weight': 0.13937701450543244},
#  {'Returns': 66.48559187096565,
#   'Volatility': 0.27217875299201216,
#   'SHOP weight': 0.1880276923083765,
#   'TSLA weight': 0.1751279126734465,
#   'GOLD weight': 0.11605578002546177,
#   'DAL weight': 0.08686510104638584,
#   'NFLX weight': 0.13176004972271968,
#   'AAPL weight': 0.12742750948671328,
#   'PFE weight': 0.03797732485482327,
#   'BTC weight': 0.13675862988207327},
#  {'Returns': 95.30007491917608,
#   'Volatility': 0.29761886193273873,
#   'SHOP weight': 0.23602561348768772,
#   'TSLA weight': 0.06145293461184094,
#   'GOLD weight': 0.10147575894612554,
#   'DAL weight': 0.0207251761850812,
#   'NFLX weight': 0.01210850496953857,
#   'AAPL weight': 0.2995612582638347,
#   'PFE weight': 0.02797340154129778,
#   'BTC weight': 0.24067735199459364},
#  {'Returns': 68.14513678558518,
#   'Volatility': 0.2345507341451107,
#   'SHOP weight': 0.1537802529419978,
#   'TSLA weight': 0.08768602994779708,
#   'GOLD weight': 0.1338504381969267,
#   'DAL weight': 0.0663808756753914,
#   'NFLX weight': 0.1876748126183872,
#   'AAPL weight': 0.08612988458722425,
#   'PFE weight': 0.12511955359997154,
#   'BTC weight': 0.1593781524323039},
#  {'Returns': 39.01881576187618,
#   'Volatility': 0.2142869671347286,
#   'SHOP weight': 0.032512622673997425,
#   'TSLA weight': 0.18275695940969233,
#   'GOLD weight': 0.1457780437357301,
#   'DAL weight': 0.12728954614579363,
#   'NFLX weight': 0.21953901631658249,
#   'AAPL weight': 0.004374537237355934,
#   'PFE weight': 0.23318881086148568,
#   'BTC weight': 0.05456046361936238},
#  {'Returns': 58.80420390372487,
#   'Volatility': 0.23106427398375495,
#   'SHOP weight': 0.15103323511221156,
#   'TSLA weight': 0.13384932292966084,
#   'GOLD weight': 0.13086613968465624,
#   'DAL weight': 0.19734270760270764,
#   'NFLX weight': 0.041731438935976965,
#   'AAPL weight': 0.12528275667398509,
#   'PFE weight': 0.10888249359881873,
#   'BTC weight': 0.11101190546198296},
#  {'Returns': 72.59624441054866,
#   'Volatility': 0.23014482233184622,
#   'SHOP weight': 0.04703653524777485,
#   'TSLA weight': 0.12308901397660545,
#   'GOLD weight': 0.02288537364022443,
#   'DAL weight': 0.31272851757425246,
#   'NFLX weight': 0.15507153858446573,
#   'AAPL weight': 0.009303279770630451,
#   'PFE weight': 0.18168605142882605,
#   'BTC weight': 0.14819968977722064},
#  {'Returns': 29.713558829606583,
#   'Volatility': 0.21807014408627076,
#   'SHOP weight': 0.2333696241464789,
#   'TSLA weight': 0.032013253690062554,
#   'GOLD weight': 0.14612097143667435,
#   'DAL weight': 0.1075823175692653,
#   'NFLX weight': 0.19782741043895996,
#   'AAPL weight': 0.08326419864094049,
#   'PFE weight': 0.17140278408938878,
#   'BTC weight': 0.028419439988229607},
#  {'Returns': 104.00924895219408,
#   'Volatility': 0.28612822588492615,
#   'SHOP weight': 0.12052459333522897,
#   'TSLA weight': 0.22126301137232238,
#   'GOLD weight': 0.00032602120124468554,
#   'DAL weight': 0.029709953161484597,
#   'NFLX weight': 0.1193528301849082,
#   'AAPL weight': 0.003932930711491016,
#   'PFE weight': 0.27105118389436356,
#   'BTC weight': 0.2338394761389566},
#  {'Returns': 87.44962346193333,
#   'Volatility': 0.2349317489663785,
#   'SHOP weight': 0.10276033789120453,
#   'TSLA weight': 0.028500652051442137,
#   'GOLD weight': 0.13173913784854424,
#   'DAL weight': 0.16924569884485088,
#   'NFLX weight': 0.01682630187370383,
#   'AAPL weight': 0.15029417713161033,
#   'PFE weight': 0.17705042384074252,
#   'BTC weight': 0.22358327051790142},
#  {'Returns': 58.50704208519854,
#   'Volatility': 0.25156168585995065,
#   'SHOP weight': 0.12906377853986412,
#   'TSLA weight': 0.17922120777511433,
#   'GOLD weight': 0.08785400621143104,
#   'DAL weight': 0.004558492376821499,
#   'NFLX weight': 0.12620582264033334,
#   'AAPL weight': 0.1817907242092219,
#   'PFE weight': 0.1864351343619566,
#   'BTC weight': 0.10487083388525734},
#  {'Returns': 38.48168842200401,
#   'Volatility': 0.2565310840069823,
#   'SHOP weight': 0.03610778717818684,
#   'TSLA weight': 0.27599674206472613,
#   'GOLD weight': 0.28144193290291136,
#   'DAL weight': 0.011494097567209347,
#   'NFLX weight': 0.09939684283648174,
#   'AAPL weight': 0.015685335382054834,
#   'PFE weight': 0.2184708589831024,
#   'BTC weight': 0.061406403085327244},
#  {'Returns': 31.72611304697065,
#   'Volatility': 0.2392601922740731,
#   'SHOP weight': 0.07976521441923536,
#   'TSLA weight': 0.19095406361798242,
#   'GOLD weight': 0.19672760451112942,
#   'DAL weight': 0.02873951543970284,
#   'NFLX weight': 0.17070973499165557,
#   'AAPL weight': 0.12099474549479838,
#   'PFE weight': 0.17511996648765668,
#   'BTC weight': 0.03698915503783941},
#  {'Returns': 82.70801489667525,
#   'Volatility': 0.22814737654320671,
#   'SHOP weight': 0.12403632391282361,
#   'TSLA weight': 0.04016503884004852,
#   'GOLD weight': 0.0923126606198853,
#   'DAL weight': 0.1586134196492568,
#   'NFLX weight': 0.21274147764949464,
#   'AAPL weight': 0.00034518710261488236,
#   'PFE weight': 0.16470472333568062,
#   'BTC weight': 0.20708116889019576},
#  {'Returns': 85.03917953886486,
#   'Volatility': 0.24276943304116674,
#   'SHOP weight': 0.10763652464119886,
#   'TSLA weight': 0.059934970616578605,
#   'GOLD weight': 0.18760816959732826,
#   'DAL weight': 0.21895545060191374,
#   'NFLX weight': 0.0167496925342037,
#   'AAPL weight': 0.05955114189326274,
#   'PFE weight': 0.12886562369638432,
#   'BTC weight': 0.2206984264191298},
#  {'Returns': 45.41095047574095,
#   'Volatility': 0.2631464597583898,
#   'SHOP weight': 0.23129745210087527,
#   'TSLA weight': 0.14718897847747417,
#   'GOLD weight': 0.011059773466815727,
#   'DAL weight': 0.2863926507467202,
#   'NFLX weight': 0.013295406530344696,
#   'AAPL weight': 0.22349317779693717,
#   'PFE weight': 0.052206748541442076,
#   'BTC weight': 0.0350658123393906},
#  {'Returns': 48.23685626029223,
#   'Volatility': 0.2289070636248302,
#   'SHOP weight': 0.10788351137149363,
#   'TSLA weight': 0.1487340585223217,
#   'GOLD weight': 0.20703265577061572,
#   'DAL weight': 0.20049791821347118,
#   'NFLX weight': 0.11487438207309593,
#   'AAPL weight': 0.057882097282766894,
#   'PFE weight': 0.06803892460089779,
#   'BTC weight': 0.09505645216533708},
#  {'Returns': 73.82718744739701,
#   'Volatility': 0.22429499425059216,
#   'SHOP weight': 0.05907934589770142,
#   'TSLA weight': 0.07065879983896232,
#   'GOLD weight': 0.06533860837935108,
#   'DAL weight': 0.21166658992615928,
#   'NFLX weight': 0.24652062692189464,
#   'AAPL weight': 0.05126206403553098,
#   'PFE weight': 0.11920164042850658,
#   'BTC weight': 0.1762723245718938},
#  {'Returns': 42.49536931463935,
#   'Volatility': 0.20100446278312134,
#   'SHOP weight': 0.023638339844000763,
#   'TSLA weight': 0.08504856298375693,
#   'GOLD weight': 0.21373890007719146,
#   'DAL weight': 0.04186694027590897,
#   'NFLX weight': 0.13130811992321542,
#   'AAPL weight': 0.21580411043494327,
#   'PFE weight': 0.19568948493974492,
#   'BTC weight': 0.09290554152123823},
#  {'Returns': 20.854261698610372,
#   'Volatility': 0.2242392968225752,
#   'SHOP weight': 0.167684552211201,
#   'TSLA weight': 0.10800443133265368,
#   'GOLD weight': 0.2892558831533385,
#   'DAL weight': 0.009868602017834781,
#   'NFLX weight': 0.04692621650679758,
#   'AAPL weight': 0.13313543576270048,
#   'PFE weight': 0.23393902807473507,
#   'BTC weight': 0.011185850940738788},
#  {'Returns': 27.706937643060936,
#   'Volatility': 0.245297404433561,
#   'SHOP weight': 0.23297145847793327,
#   'TSLA weight': 0.09778768383473545,
#   'GOLD weight': 0.14689022637766544,
#   'DAL weight': 0.16653529695892325,
#   'NFLX weight': 0.12608307919449632,
#   'AAPL weight': 0.16092653788979966,
#   'PFE weight': 0.05543106097268208,
#   'BTC weight': 0.013374656293764445},
#  {'Returns': 43.376060525158614,
#   'Volatility': 0.22212447955449255,
#   'SHOP weight': 0.11117426338746826,
#   'TSLA weight': 0.11641791720866887,
#   'GOLD weight': 0.18524716118917048,
#   'DAL weight': 0.07811703388334008,
#   'NFLX weight': 0.14049297055528867,
#   'AAPL weight': 0.1658236734322658,
#   'PFE weight': 0.1210049929939482,
#   'BTC weight': 0.08172198734984955},
#  {'Returns': 93.39239284156275,
#   'Volatility': 0.30793695589404824,
#   'SHOP weight': 0.2221868814690989,
#   'TSLA weight': 0.19514012234909273,
#   'GOLD weight': 0.06238956323751242,
#   'DAL weight': 0.010315589290685736,
#   'NFLX weight': 0.01739438635286243,
#   'AAPL weight': 0.19123292203443987,
#   'PFE weight': 0.09367901789226843,
#   'BTC weight': 0.20766151737403948},
#  {'Returns': 75.2452185805016,
#   'Volatility': 0.23677229023630295,
#   'SHOP weight': 0.20082214765578427,
#   'TSLA weight': 0.052899430748986453,
#   'GOLD weight': 0.09610400517175088,
#   'DAL weight': 0.1486711728506386,
#   'NFLX weight': 0.01240854070231994,
#   'AAPL weight': 0.20549764995591854,
#   'PFE weight': 0.11608085384943435,
#   'BTC weight': 0.16751619906516702},
#  {'Returns': 42.42209556783646,
#   'Volatility': 0.2399245494910921,
#   'SHOP weight': 0.1229691486473186,
#   'TSLA weight': 0.12884964882115926,
#   'GOLD weight': 0.19636846937531283,
#   'DAL weight': 0.18041851682317725,
#   'NFLX weight': 0.014123306833049734,
#   'AAPL weight': 0.2696506848576409,
#   'PFE weight': 0.013701351520091262,
#   'BTC weight': 0.07391887312225018},
#  {'Returns': 36.68347198229312,
#   'Volatility': 0.26481502725227896,
#   'SHOP weight': 0.18299738795529136,
#   'TSLA weight': 0.21319279752776027,
#   'GOLD weight': 0.07593424726650412,
#   'DAL weight': 0.19646773545042082,
#   'NFLX weight': 0.1928587676454,
#   'AAPL weight': 0.02527459419113969,
#   'PFE weight': 0.09269942407173982,
#   'BTC weight': 0.02057504589174387},
#  {'Returns': 64.0851882254738,
#   'Volatility': 0.2569544466156351,
#   'SHOP weight': 0.048905416362551565,
#   'TSLA weight': 0.2058879006479731,
#   'GOLD weight': 0.19808810314385616,
#   'DAL weight': 0.22775867182534584,
#   'NFLX weight': 0.11218763472998286,
#   'AAPL weight': 0.03133813199519575,
#   'PFE weight': 0.030238900566656436,
#   'BTC weight': 0.1455952407284384},
#  {'Returns': 86.02969548077688,
#   'Volatility': 0.26016496764905755,
#   'SHOP weight': 0.02248392659453728,
#   'TSLA weight': 0.20930550267341383,
#   'GOLD weight': 0.08488367632699748,
#   'DAL weight': 0.15141446410418885,
#   'NFLX weight': 0.1057827843536534,
#   'AAPL weight': 0.05070525232599359,
#   'PFE weight': 0.17765605219275324,
#   'BTC weight': 0.19776834142846236},
#  {'Returns': 161.8000615750158,
#   'Volatility': 0.3847796677097349,
#   'SHOP weight': 0.016776053124231874,
#   'TSLA weight': 0.05001453923177049,
#   'GOLD weight': 0.003551583159216935,
#   'DAL weight': 0.1257083807137305,
#   'NFLX weight': 0.12553432503827883,
#   'AAPL weight': 0.008034804576208721,
#   'PFE weight': 0.20671436338361623,
#   'BTC weight': 0.4636659507729465},
#  {'Returns': 64.13146312834795,
#   'Volatility': 0.21776232493815345,
#   'SHOP weight': 0.19446215659419414,
#   'TSLA weight': 0.07156100550872464,
#   'GOLD weight': 0.19261015356793065,
#   'DAL weight': 0.17823520380235416,
#   'NFLX weight': 0.04272460653075907,
#   'AAPL weight': 0.013767435658102567,
#   'PFE weight': 0.16478756869113315,
#   'BTC weight': 0.1418518696468016},
#  {'Returns': 29.859410477782898,
#   'Volatility': 0.257161993006696,
#   'SHOP weight': 0.19426672137474268,
#   'TSLA weight': 0.123541419009919,
#   'GOLD weight': 0.3754158270210017,
#   'DAL weight': 0.0331799830707612,
#   'NFLX weight': 0.006514813902711139,
#   'AAPL weight': 0.17793105503477583,
#   'PFE weight': 0.02991443924253923,
#   'BTC weight': 0.05923574134354931},
#  {'Returns': 88.59927938649098,
#   'Volatility': 0.24473568399920895,
#   'SHOP weight': 0.014935166156025047,
#   'TSLA weight': 0.11957170580451823,
#   'GOLD weight': 0.08955901437978195,
#   'DAL weight': 0.12719825326150191,
#   'NFLX weight': 0.1657475070534838,
#   'AAPL weight': 0.08500731944133566,
#   'PFE weight': 0.17390906801648223,
#   'BTC weight': 0.22407196588687125},
#  {'Returns': 30.136043276990925,
#   'Volatility': 0.22555664793659105,
#   'SHOP weight': 0.17577074132902404,
#   'TSLA weight': 0.05005058613453356,
#   'GOLD weight': 0.14505869421209755,
#   'DAL weight': 0.03088364332347126,
#   'NFLX weight': 0.3065064137220242,
#   'AAPL weight': 0.07054772288892501,
#   'PFE weight': 0.18182949716653413,
#   'BTC weight': 0.03935270122339025},
#  {'Returns': 30.720011085236365,
#   'Volatility': 0.21784649568691314,
#   'SHOP weight': 0.21265124842147817,
#   'TSLA weight': 0.0354668874370368,
#   'GOLD weight': 0.12364419145779218,
#   'DAL weight': 0.0570399676023915,
#   'NFLX weight': 0.2221017444398769,
#   'AAPL weight': 0.10480866770921762,
#   'PFE weight': 0.21417437038498896,
#   'BTC weight': 0.03011292254721783},
#  {'Returns': 46.59623953502957,
#   'Volatility': 0.22164676113638385,
#   'SHOP weight': 0.12722006502563032,
#   'TSLA weight': 0.13614379997392026,
#   'GOLD weight': 0.167082388382153,
#   'DAL weight': 0.14762321053499347,
#   'NFLX weight': 0.12133960472007575,
#   'AAPL weight': 0.09383950058987695,
#   'PFE weight': 0.12475428638535309,
#   'BTC weight': 0.08199714438799713},
#  {'Returns': 60.227843182786216,
#   'Volatility': 0.24050740379675842,
#   'SHOP weight': 0.2722731225956283,
#   'TSLA weight': 0.019429489702403813,
#   'GOLD weight': 0.15928612143980936,
#   'DAL weight': 0.03086888286779438,
#   'NFLX weight': 0.125958332485362,
#   'AAPL weight': 0.11953176102040683,
#   'PFE weight': 0.13953221115622907,
#   'BTC weight': 0.13312007873236625},
#  {'Returns': 69.49338195236484,
#   'Volatility': 0.21119886352914408,
#   'SHOP weight': 0.029793255851198387,
#   'TSLA weight': 0.03647406285198617,
#   'GOLD weight': 0.26250553695087775,
#   'DAL weight': 0.12009421824277661,
#   'NFLX weight': 0.10685800639275642,
#   'AAPL weight': 0.03424356133826412,
#   'PFE weight': 0.21616560874258833,
#   'BTC weight': 0.19386574962955225},
#  {'Returns': 52.2817738273307,
#   'Volatility': 0.22343897371246393,
#   'SHOP weight': 0.0926676052944311,
#   'TSLA weight': 0.06767058954734854,
#   'GOLD weight': 0.20036636570656985,
#   'DAL weight': 0.07486980120849826,
#   'NFLX weight': 0.11189419926944286,
#   'AAPL weight': 0.2570247618853728,
#   'PFE weight': 0.07127735795263254,
#   'BTC weight': 0.12422931913570387},
#  {'Returns': 90.39410028668627,
#   'Volatility': 0.23739797532311285,
#   'SHOP weight': 0.2047621220862781,
#   'TSLA weight': 0.012272395001957927,
#   'GOLD weight': 0.033183202719790354,
#   'DAL weight': 0.20527440958170654,
#   'NFLX weight': 0.10288074550699519,
#   'AAPL weight': 0.04571395964871073,
#   'PFE weight': 0.18363745814724353,
#   'BTC weight': 0.2122757073073177},
#  {'Returns': 82.19268916497094,
#   'Volatility': 0.22442050399228416,
#   'SHOP weight': 0.1512223042440613,
#   'TSLA weight': 0.018020753412890573,
#   'GOLD weight': 0.0951164735181458,
#   'DAL weight': 0.06856447188756637,
#   'NFLX weight': 0.11440028770467758,
#   'AAPL weight': 0.12522992432833802,
#   'PFE weight': 0.22549390397194133,
#   'BTC weight': 0.20195188093237904},
#  {'Returns': 57.59982386678601,
#   'Volatility': 0.2446881386525652,
#   'SHOP weight': 0.29139505583441266,
#   'TSLA weight': 0.03546056392028602,
#   'GOLD weight': 0.08447262523488083,
#   'DAL weight': 0.050210947715504946,
#   'NFLX weight': 0.1585739520066601,
#   'AAPL weight': 0.119065916289014,
#   'PFE weight': 0.1529424165901427,
#   'BTC weight': 0.10787852240909877},
#  {'Returns': 32.495870929338494,
#   'Volatility': 0.21349190901397636,
#   'SHOP weight': 0.11904333793563479,
#   'TSLA weight': 0.07798445000912593,
#   'GOLD weight': 0.19011923001076317,
#   'DAL weight': 0.1857651470234718,
#   'NFLX weight': 0.027315641020657987,
#   'AAPL weight': 0.26426549299476276,
#   'PFE weight': 0.09241428194106911,
#   'BTC weight': 0.0430924190645145},
#  {'Returns': 83.06420081121932,
#   'Volatility': 0.2546461119464581,
#   'SHOP weight': 0.060421078159786645,
#   'TSLA weight': 0.02100005608725238,
#   'GOLD weight': 0.2657907371846606,
#   'DAL weight': 0.11664127888677979,
#   'NFLX weight': 0.165011181422545,
#   'AAPL weight': 0.08595723904914318,
#   'PFE weight': 0.03349104358203362,
#   'BTC weight': 0.25168738562779874},
#  {'Returns': 32.756988026496515,
#   'Volatility': 0.2029682606071451,
#   'SHOP weight': 0.11837131283239129,
#   'TSLA weight': 0.09473665240714234,
#   'GOLD weight': 0.2009363798392072,
#   'DAL weight': 0.07931270396864468,
#   'NFLX weight': 0.08352760555998007,
#   'AAPL weight': 0.16153266412232198,
#   'PFE weight': 0.21837603473161607,
#   'BTC weight': 0.04320664653869639},
#  {'Returns': 81.9375338552863,
#   'Volatility': 0.2726816170370138,
#   'SHOP weight': 0.23012175795893397,
#   'TSLA weight': 0.08638181978556438,
#   'GOLD weight': 0.21567660928623822,
#   'DAL weight': 0.08546931668439639,
#   'NFLX weight': 0.09239149060156572,
#   'AAPL weight': 0.05498508150756811,
#   'PFE weight': 0.0217049432512881,
#   'BTC weight': 0.21326898092444513},
#  {'Returns': 83.14632871411656,
#   'Volatility': 0.24846860328403805,
#   'SHOP weight': 0.029687829382151514,
#   'TSLA weight': 0.0992204772349201,
#   'GOLD weight': 0.02015239136708842,
#   'DAL weight': 0.27573785875440604,
#   'NFLX weight': 0.12305554940762639,
#   'AAPL weight': 0.1772495085107682,
#   'PFE weight': 0.08161383881804832,
#   'BTC weight': 0.19328254652499105},
#  {'Returns': 55.91171940682004,
#   'Volatility': 0.2034646127657955,
#   'SHOP weight': 0.05782263053726782,
#   'TSLA weight': 0.04746572335011063,
#   'GOLD weight': 0.20992595105940573,
#   'DAL weight': 0.19500897534203476,
#   'NFLX weight': 0.11810490365519359,
#   'AAPL weight': 0.11967336242922486,
#   'PFE weight': 0.11381553396318468,
#   'BTC weight': 0.13818291966357782},
#  {'Returns': 63.81254862220699,
#   'Volatility': 0.22520566984819387,
#   'SHOP weight': 0.2450371003119013,
#   'TSLA weight': 0.004480758191258053,
#   'GOLD weight': 0.10783624466985772,
#   'DAL weight': 0.09632837257755952,
#   'NFLX weight': 0.20820714871051504,
#   'AAPL weight': 0.035324765167979257,
#   'PFE weight': 0.16118087807769757,
#   'BTC weight': 0.1416047322932315},
#  {'Returns': 25.06556122100394,
#   'Volatility': 0.25326835209548904,
#   'SHOP weight': 0.07568880500746589,
#   'TSLA weight': 0.1271442639818667,
#   'GOLD weight': 0.2753172013991207,
#   'DAL weight': 0.027767881140119525,
#   'NFLX weight': 0.2804062165327729,
#   'AAPL weight': 0.1621086008829918,
#   'PFE weight': 0.001029950738899814,
#   'BTC weight': 0.05053708031676266},
#  {'Returns': 37.65066912839101,
#   'Volatility': 0.2520758634257042,
#   'SHOP weight': 0.08634374309010613,
#   'TSLA weight': 0.2357794936005161,
#   'GOLD weight': 0.01740562614948638,
#   'DAL weight': 0.25627043241708525,
#   'NFLX weight': 0.18262669289965874,
#   'AAPL weight': 0.021239250590245548,
#   'PFE weight': 0.18780907792236448,
#   'BTC weight': 0.012525683330537461},
#  {'Returns': 59.22655562986896,
#   'Volatility': 0.23329090672919925,
#   'SHOP weight': 0.18999353498809932,
#   'TSLA weight': 0.15121375382283792,
#   'GOLD weight': 0.0644619575772319,
#   'DAL weight': 0.10173231326064577,
#   'NFLX weight': 0.020836082688183905,
#   'AAPL weight': 0.14192990827215735,
#   'PFE weight': 0.23876180688303747,
#   'BTC weight': 0.09107064250780635},
#  {'Returns': 83.71308382226162,
#   'Volatility': 0.2656427350739441,
#   'SHOP weight': 0.07739118939191679,
#   'TSLA weight': 0.1589646109014759,
#   'GOLD weight': 0.13656944567052962,
#   'DAL weight': 0.031084647906866138,
#   'NFLX weight': 0.0766651625011737,
#   'AAPL weight': 0.19646635903574536,
#   'PFE weight': 0.11649948736654912,
#   'BTC weight': 0.20635909722574353},
#  {'Returns': 55.64485174893234,
#   'Volatility': 0.27578600982311025,
#   'SHOP weight': 0.0819226249595504,
#   'TSLA weight': 0.21687871314301416,
#   'GOLD weight': 0.22164868462875295,
#   'DAL weight': 0.01790031375622077,
#   'NFLX weight': 0.22348065273319034,
#   'AAPL weight': 0.08611269985802666,
#   'PFE weight': 0.02328658306795476,
#   'BTC weight': 0.12876972785328994},
#  {'Returns': 51.490847450919766,
#   'Volatility': 0.20101114827971228,
#   'SHOP weight': 0.13375771733556285,
#   'TSLA weight': 0.06225665041227262,
#   'GOLD weight': 0.1029990341265545,
#   'DAL weight': 0.13802765679318546,
#   'NFLX weight': 0.07607085870876094,
#   'AAPL weight': 0.1968363949533571,
#   'PFE weight': 0.19792493007141002,
#   'BTC weight': 0.09212675759889646},
#  {'Returns': 68.77071737344973,
#   'Volatility': 0.27500482066105375,
#   'SHOP weight': 0.2515667996861902,
#   'TSLA weight': 0.13643015638130698,
#   'GOLD weight': 0.06657962991317613,
#   'DAL weight': 0.1284828748389364,
#   'NFLX weight': 0.19192061462419985,
#   'AAPL weight': 0.06478175830223304,
#   'PFE weight': 0.022395261271398376,
#   'BTC weight': 0.13784290498255902},
#  {'Returns': 30.535166546881964,
#   'Volatility': 0.22583339747489406,
#   'SHOP weight': 0.24163566902623088,
#   'TSLA weight': 0.10843917384045515,
#   'GOLD weight': 0.23694741730704444,
#   'DAL weight': 0.18723737215151182,
#   'NFLX weight': 0.04239589743893079,
#   'AAPL weight': 0.00451175838477748,
#   'PFE weight': 0.15248918392632296,
#   'BTC weight': 0.026343527924726433},
#  {'Returns': 70.20074486860432,
#   'Volatility': 0.24582346997326926,
#   'SHOP weight': 0.0036693719457690675,
#   'TSLA weight': 0.16905160588737742,
#   'GOLD weight': 0.22465634409164956,
#   'DAL weight': 0.06923099991115259,
#   'NFLX weight': 0.19874643909232007,
# ...
#   'PFE weight': 0.2115757013646129,
#   'BTC weight': 0.061980306728320035},
#  {'Returns': 66.37152538734598,
#   'Volatility': 0.23682444936121155,
#   'SHOP weight': 0.013561799310446989,
#   'TSLA weight': 0.18811022166336133,
#   'GOLD weight': 0.22747050144024497,
#   'DAL weight': 0.0577583459207572,
#   'NFLX weight': 0.11208826529960098,
#   'AAPL weight': 0.04706415376063429,
#   'PFE weight': 0.19251342489275244,
#   'BTC weight': 0.16143328771220203},
#  {'Returns': 62.023517472047054,
#   'Volatility': 0.21172408473187593,
#   'SHOP weight': 0.06605581629274122,
#   'TSLA weight': 0.09860523427049887,
#   'GOLD weight': 0.12334299027780918,
#   'DAL weight': 0.15232462136118813,
#   'NFLX weight': 0.11199788760683685,
#   'AAPL weight': 0.15217864375256815,
#   'PFE weight': 0.1600974309599089,
#   'BTC weight': 0.1353973754784488},
#  {'Returns': 38.06667624343555,
#   'Volatility': 0.19119992197553964,
#   'SHOP weight': 0.15195874274403176,
#   'TSLA weight': 0.023827493100598326,
#   'GOLD weight': 0.09409079093436008,
#   'DAL weight': 0.13863199300585077,
#   'NFLX weight': 0.12172856756166783,
#   'AAPL weight': 0.1927677934659824,
#   'PFE weight': 0.22764634412529225,
#   'BTC weight': 0.049348275062216576},
#  {'Returns': 57.20186054298486,
#   'Volatility': 0.21422823035582497,
#   'SHOP weight': 0.0722099863170958,
#   'TSLA weight': 0.03657214395654413,
#   'GOLD weight': 0.128098466698717,
#   'DAL weight': 0.02441008426295279,
#   'NFLX weight': 0.25444752732276843,
#   'AAPL weight': 0.18235597803491946,
#   'PFE weight': 0.16351914205452964,
#   'BTC weight': 0.13838667135247276},
#  {'Returns': 70.7416767011859,
#   'Volatility': 0.2445464475979318,
#   'SHOP weight': 0.1385323051104199,
#   'TSLA weight': 0.1635617969236736,
#   'GOLD weight': 0.1592733903317172,
#   'DAL weight': 0.08716780323616795,
#   'NFLX weight': 0.10985079576820551,
#   'AAPL weight': 0.03830216148996786,
#   'PFE weight': 0.14521655868746491,
#   'BTC weight': 0.15809518845238324},
#  {'Returns': 49.9620263258748,
#   'Volatility': 0.2523580806276628,
#   'SHOP weight': 0.25270235638604804,
#   'TSLA weight': 0.11386918734107604,
#   'GOLD weight': 0.06115205445882984,
#   'DAL weight': 0.22010054435694032,
#   'NFLX weight': 0.07877586288968938,
#   'AAPL weight': 0.1606030537143433,
#   'PFE weight': 0.045834558771797033,
#   'BTC weight': 0.06696238208127615},
#  {'Returns': 93.33952191825803,
#   'Volatility': 0.24710046189475401,
#   'SHOP weight': 0.09984702519994824,
#   'TSLA weight': 0.04559280128488431,
#   'GOLD weight': 0.016053801500027897,
#   'DAL weight': 0.11561548265444863,
#   'NFLX weight': 0.1837791843069212,
#   'AAPL weight': 0.15292876030083372,
#   'PFE weight': 0.15362959238556853,
#   'BTC weight': 0.2325533523673675},
#  {'Returns': 63.49300085218851,
#   'Volatility': 0.2602290024031238,
#   'SHOP weight': 0.09800887400734376,
#   'TSLA weight': 0.23640385901681832,
#   'GOLD weight': 0.1736342924733397,
#   'DAL weight': 0.041321347975571326,
#   'NFLX weight': 0.1173288540105397,
#   'AAPL weight': 0.04422578792769863,
#   'PFE weight': 0.15830448835690988,
#   'BTC weight': 0.13077249623177864},
#  {'Returns': 87.27500985354372,
#   'Volatility': 0.24152680665948467,
#   'SHOP weight': 0.13042604999681773,
#   'TSLA weight': 0.03559538588583906,
#   'GOLD weight': 0.07328442267783915,
#   'DAL weight': 0.21347278643535017,
#   'NFLX weight': 0.07960853289794151,
#   'AAPL weight': 0.14939961954888148,
#   'PFE weight': 0.10345516206868495,
#   'BTC weight': 0.21475804048864583},
#  {'Returns': 67.2510263146139,
#   'Volatility': 0.21657603058728142,
#   'SHOP weight': 0.03994967761078883,
#   'TSLA weight': 0.07553508633473836,
#   'GOLD weight': 0.27291567975966746,
#   'DAL weight': 0.06644187786567593,
#   'NFLX weight': 0.1017909441695253,
#   'AAPL weight': 0.06086146345044809,
#   'PFE weight': 0.19836142611333177,
#   'BTC weight': 0.18414384469582437},
#  {'Returns': 81.08965900426334,
#   'Volatility': 0.24617446635214837,
#   'SHOP weight': 0.1030485898182318,
#   'TSLA weight': 0.019771744047163982,
#   'GOLD weight': 0.23329687132785226,
#   'DAL weight': 0.11315572739284552,
#   'NFLX weight': 0.20225595473870359,
#   'AAPL weight': 0.02779526168619049,
#   'PFE weight': 0.06464853031014475,
#   'BTC weight': 0.2360273206788677},
#  {'Returns': 80.75760716534381,
#   'Volatility': 0.23567675558796408,
#   'SHOP weight': 0.20937986365182623,
#   'TSLA weight': 0.008123279788960392,
#   'GOLD weight': 0.09827974819854358,
#   'DAL weight': 0.198831619545494,
#   'NFLX weight': 0.12628512409788248,
#   'AAPL weight': 0.05904982556842579,
#   'PFE weight': 0.10409347711430299,
#   'BTC weight': 0.19595706203456442},
#  {'Returns': 32.450000310500435,
#   'Volatility': 0.24738556821038818,
#   'SHOP weight': 0.15351690001544022,
#   'TSLA weight': 0.18950380271200865,
#   'GOLD weight': 0.16284942882584802,
#   'DAL weight': 0.15737171764399036,
#   'NFLX weight': 0.0026808935780266423,
#   'AAPL weight': 0.1865956348571685,
#   'PFE weight': 0.12977544982891087,
#   'BTC weight': 0.017706172538606825},
#  {'Returns': 25.82585054605702,
#   'Volatility': 0.2454635720743037,
#   'SHOP weight': 0.01720020426540408,
#   'TSLA weight': 0.2327007403770613,
#   'GOLD weight': 0.18806326735092457,
#   'DAL weight': 0.15174461526195687,
#   'NFLX weight': 0.17858024537937567,
#   'AAPL weight': 0.09048020133737032,
#   'PFE weight': 0.1270679939196581,
#   'BTC weight': 0.014162732108249221},
#  {'Returns': 36.38196416294662,
#   'Volatility': 0.19516988503098934,
#   'SHOP weight': 0.021599047377034844,
#   'TSLA weight': 0.12145047434815696,
#   'GOLD weight': 0.20689169947320826,
#   'DAL weight': 0.1334038489385512,
#   'NFLX weight': 0.15241847312944395,
#   'AAPL weight': 0.08449650927747153,
#   'PFE weight': 0.21676052404608995,
#   'BTC weight': 0.06297942341004323},
#  {'Returns': 66.57270383222445,
#   'Volatility': 0.23276641436552856,
#   'SHOP weight': 0.1178827834729901,
#   'TSLA weight': 0.07747942421249701,
#   'GOLD weight': 0.18509448675823242,
#   'DAL weight': 0.06504973322580976,
#   'NFLX weight': 0.17211835067480905,
#   'AAPL weight': 0.12077458253150639,
#   'PFE weight': 0.09331606817835458,
#   'BTC weight': 0.16828457094580068},
#  {'Returns': 76.02160507882552,
#   'Volatility': 0.2359015967556744,
#   'SHOP weight': 0.12776459800082102,
#   'TSLA weight': 0.06486849066376091,
#   'GOLD weight': 0.03823297227302267,
#   'DAL weight': 0.1426582256972329,
#   'NFLX weight': 0.1951130697815773,
#   'AAPL weight': 0.15854059596307254,
#   'PFE weight': 0.09803038383938266,
#   'BTC weight': 0.17479166378113004},
#  {'Returns': 44.4604129572663,
#   'Volatility': 0.21827266797155692,
#   'SHOP weight': 0.21384261122886403,
#   'TSLA weight': 0.13306820866335198,
#   'GOLD weight': 0.13967532179319223,
#   'DAL weight': 0.04397819899873597,
#   'NFLX weight': 0.025832829846179597,
#   'AAPL weight': 0.04307363225644506,
#   'PFE weight': 0.35007157497782215,
#   'BTC weight': 0.05045762223540904},
#  {'Returns': 31.60452154534661,
#   'Volatility': 0.26199092070278296,
#   'SHOP weight': 0.17870063126158167,
#   'TSLA weight': 0.2473815110235981,
#   'GOLD weight': 0.15107810259131474,
#   'DAL weight': 0.11826135213425726,
#   'NFLX weight': 0.03670680180100575,
#   'AAPL weight': 0.05074679527596007,
#   'PFE weight': 0.21614837330784664,
#   'BTC weight': 0.0009764326044357612},
#  {'Returns': 78.08717999185541,
#   'Volatility': 0.2411375774515185,
#   'SHOP weight': 0.12191496487939561,
#   'TSLA weight': 0.12238101338166256,
#   'GOLD weight': 0.04195252122597177,
#   'DAL weight': 0.11170223128597263,
#   'NFLX weight': 0.152726441490444,
#   'AAPL weight': 0.12914414444450223,
#   'PFE weight': 0.14863116747756477,
#   'BTC weight': 0.17154751581448657},
#  {'Returns': 125.10548480208307,
#   'Volatility': 0.3026003993594878,
#   'SHOP weight': 0.013667715839830353,
#   'TSLA weight': 0.002403871792641347,
#   'GOLD weight': 0.06681210082585322,
#   'DAL weight': 0.1710289603989093,
#   'NFLX weight': 0.007363188549572483,
#   'AAPL weight': 0.10636293465356415,
#   'PFE weight': 0.2863321509067952,
#   'BTC weight': 0.34602907703283403},
#  {'Returns': 26.78870013382098,
#   'Volatility': 0.253803918387864,
#   'SHOP weight': 0.18366738602120816,
#   'TSLA weight': 0.19581464422351738,
#   'GOLD weight': 0.20464483167407907,
#   'DAL weight': 0.15374671097848028,
#   'NFLX weight': 0.06950216837914967,
#   'AAPL weight': 0.08096451566175811,
#   'PFE weight': 0.10546648321446357,
#   'BTC weight': 0.006193259847343747},
#  {'Returns': 41.809885141872854,
#   'Volatility': 0.279653932396946,
#   'SHOP weight': 0.10353995435714847,
#   'TSLA weight': 0.2264538705321348,
#   'GOLD weight': 0.16509487630181474,
#   'DAL weight': 0.0428672019508882,
#   'NFLX weight': 0.18316136934399124,
#   'AAPL weight': 0.18804718200947615,
#   'PFE weight': 0.02434932562225272,
#   'BTC weight': 0.06648621988229365},
#  {'Returns': 52.75006468786117,
#   'Volatility': 0.2445260235749521,
#   'SHOP weight': 0.25014046570491305,
#   'TSLA weight': 0.029581007261855974,
#   'GOLD weight': 0.13137037348069017,
#   'DAL weight': 0.06174900516442833,
#   'NFLX weight': 0.2573077872181902,
#   'AAPL weight': 0.07156047140658751,
#   'PFE weight': 0.08705305107703393,
#   'BTC weight': 0.11123783868630086},
#  {'Returns': 38.20197746268548,
#   'Volatility': 0.20127891819872215,
#   'SHOP weight': 0.20047170273399328,
#   'TSLA weight': 0.036801656898992945,
#   'GOLD weight': 0.21200828416298056,
#   'DAL weight': 0.17701436524946568,
#   'NFLX weight': 0.02839892595595059,
#   'AAPL weight': 0.11809816668606805,
#   'PFE weight': 0.16631958526105028,
#   'BTC weight': 0.06088731305149862},
#  {'Returns': 27.46537608665502,
#   'Volatility': 0.22440972502152387,
#   'SHOP weight': 0.16918190731516847,
#   'TSLA weight': 0.021894672647413776,
#   'GOLD weight': 0.019237999256635573,
#   'DAL weight': 0.037532394204967415,
#   'NFLX weight': 0.25902628848412895,
#   'AAPL weight': 0.2362791753588599,
#   'PFE weight': 0.24874905737987527,
#   'BTC weight': 0.008098505352950681},
#  {'Returns': 68.29903137814549,
#   'Volatility': 0.2213207709905878,
#   'SHOP weight': 0.17717405734392386,
#   'TSLA weight': 0.033545112760912404,
#   'GOLD weight': 0.12385395829717613,
#   'DAL weight': 0.13941879464465384,
#   'NFLX weight': 0.16907445602930132,
#   'AAPL weight': 0.07321776049940028,
#   'PFE weight': 0.12331780424368005,
#   'BTC weight': 0.160398056180952},
#  {'Returns': 104.98301407444877,
#   'Volatility': 0.30313777324068275,
#   'SHOP weight': 0.027801757666027414,
#   'TSLA weight': 0.21460261696189825,
#   'GOLD weight': 0.0964989001789227,
#   'DAL weight': 0.024949304564626268,
#   'NFLX weight': 0.16351813453357644,
#   'AAPL weight': 0.08002866393868355,
#   'PFE weight': 0.1201872202646524,
#   'BTC weight': 0.27241340189161295},
#  {'Returns': 68.72385907857165,
#   'Volatility': 0.22552729073286168,
#   'SHOP weight': 0.07965566872587054,
#   'TSLA weight': 0.0812533014756829,
#   'GOLD weight': 0.20323797634731972,
#   'DAL weight': 0.09567467607444302,
#   'NFLX weight': 0.18919392659060943,
#   'AAPL weight': 0.05339576757604214,
#   'PFE weight': 0.11750872830087096,
#   'BTC weight': 0.18007995490916126},
#  {'Returns': 44.67925502534602,
#   'Volatility': 0.2192695807346717,
#   'SHOP weight': 0.0036962556798111365,
#   'TSLA weight': 0.1577676903486932,
#   'GOLD weight': 0.08256878824077656,
#   'DAL weight': 0.23782253197433761,
#   'NFLX weight': 0.020926565251634225,
#   'AAPL weight': 0.2185607802635511,
#   'PFE weight': 0.221319232770512,
#   'BTC weight': 0.057338155470684174},
#  {'Returns': 87.47698723797426,
#   'Volatility': 0.26131723161303155,
#   'SHOP weight': 0.22325848706610943,
#   'TSLA weight': 0.07470964078525856,
#   'GOLD weight': 0.02290889158358102,
#   'DAL weight': 0.22866009795854766,
#   'NFLX weight': 0.027619330345722014,
#   'AAPL weight': 0.1666827214348301,
#   'PFE weight': 0.06389264567373848,
#   'BTC weight': 0.19226818515221275},
#  {'Returns': 33.638512349443474,
#   'Volatility': 0.21532908328638456,
#   'SHOP weight': 0.1742106475162841,
#   'TSLA weight': 0.09899290268347975,
#   'GOLD weight': 0.1427385772990323,
#   'DAL weight': 0.2442946134356336,
#   'NFLX weight': 0.05163138872275034,
#   'AAPL weight': 0.1167624866274335,
#   'PFE weight': 0.14379814952763234,
#   'BTC weight': 0.027571234187754187},
#  {'Returns': 38.75222112154575,
#   'Volatility': 0.22305816097550757,
#   'SHOP weight': 0.219407715810036,
#   'TSLA weight': 0.09356433129720068,
#   'GOLD weight': 0.13634405365095514,
#   'DAL weight': 0.2565650648028747,
#   'NFLX weight': 0.11946781898247516,
#   'AAPL weight': 0.017051730678177016,
#   'PFE weight': 0.11300863920870241,
#   'BTC weight': 0.04459064556957888},
#  {'Returns': 60.62920228823218,
#   'Volatility': 0.2439733750498016,
#   'SHOP weight': 0.19851258127436622,
#   'TSLA weight': 0.03606960432383819,
#   'GOLD weight': 0.05403193091526735,
#   'DAL weight': 0.02498055037227323,
#   'NFLX weight': 0.15706011956010993,
#   'AAPL weight': 0.2852069992859575,
#   'PFE weight': 0.12018300277040973,
#   'BTC weight': 0.12395521149777779},
#  {'Returns': 102.0087437474867,
#   'Volatility': 0.3102616860274789,
#   'SHOP weight': 0.019275139333526408,
#   'TSLA weight': 0.23474150390839335,
#   'GOLD weight': 0.20228771893599093,
#   'DAL weight': 0.048017830121778814,
#   'NFLX weight': 0.05817817805326041,
#   'AAPL weight': 0.08085194671521376,
#   'PFE weight': 0.08220643736337856,
#   'BTC weight': 0.2744412455684577},
#  {'Returns': 72.79502073419727,
#   'Volatility': 0.26446307040555384,
#   'SHOP weight': 0.16692694553759702,
#   'TSLA weight': 0.12965240279923224,
#   'GOLD weight': 0.08103038573283425,
#   'DAL weight': 0.09556990496401835,
#   'NFLX weight': 0.19230498620662034,
#   'AAPL weight': 0.13835844472649095,
#   'PFE weight': 0.03297166584322392,
#   'BTC weight': 0.1631852641899831},
#  {'Returns': 89.62519020525681,
#   'Volatility': 0.24818651573026212,
#   'SHOP weight': 0.12231427192426021,
#   'TSLA weight': 0.0037309815805105337,
#   'GOLD weight': 0.1677058359365088,
#   'DAL weight': 0.23741090952858007,
#   'NFLX weight': 0.0054962345796359,
#   'AAPL weight': 0.10963085132657027,
#   'PFE weight': 0.11475733500599591,
#   'BTC weight': 0.2389535801179382},
#  {'Returns': 61.66090406703241,
#   'Volatility': 0.2628805277164355,
#   'SHOP weight': 0.20698236657877475,
#   'TSLA weight': 0.11307856992830506,
#   'GOLD weight': 0.20045552044225864,
#   'DAL weight': 0.07279430958926915,
#   'NFLX weight': 0.09987800898145793,
#   'AAPL weight': 0.16161926032709903,
#   'PFE weight': 0.002987144125909532,
#   'BTC weight': 0.1422048200269259},
#  {'Returns': 60.76572388022176,
#   'Volatility': 0.21412191025955893,
#   'SHOP weight': 0.17838290255545902,
#   'TSLA weight': 0.06822372457967976,
#   'GOLD weight': 0.04475349489841178,
#   'DAL weight': 0.15235497476866347,
#   'NFLX weight': 0.1918601776464964,
#   'AAPL weight': 0.06509106972873646,
#   'PFE weight': 0.18512542439507934,
#   'BTC weight': 0.11420823142747362},
#  {'Returns': 79.73450738310379,
#   'Volatility': 0.23604763457944336,
#   'SHOP weight': 0.18642029606324456,
#   'TSLA weight': 0.036889109845762776,
#   'GOLD weight': 0.040351351005168026,
#   'DAL weight': 0.19001544051090738,
#   'NFLX weight': 0.06353710817451692,
#   'AAPL weight': 0.19257050653947502,
#   'PFE weight': 0.11217421253637928,
#   'BTC weight': 0.17804197532454608},
#  {'Returns': 56.70323033028508,
#   'Volatility': 0.24756577266482352,
#   'SHOP weight': 0.12283369629503653,
#   'TSLA weight': 0.14422868949254858,
#   'GOLD weight': 0.049924415564601705,
#   'DAL weight': 0.17019425714975514,
#   'NFLX weight': 0.1864424287327938,
#   'AAPL weight': 0.18042178319751856,
#   'PFE weight': 0.043742853498471554,
#   'BTC weight': 0.10221187606927418},
#  {'Returns': 42.02803386627418,
#   'Volatility': 0.30985496439224125,
#   'SHOP weight': 0.3976434562033617,
#   'TSLA weight': 0.082223189579887,
#   'GOLD weight': 0.08438768108083171,
#   'DAL weight': 0.0021872745033785384,
#   'NFLX weight': 0.14814733782975367,
#   'AAPL weight': 0.1784295458846362,
#   'PFE weight': 0.06233377749396808,
#   'BTC weight': 0.04464773742418318},
#  {'Returns': 98.21361821442258,
#   'Volatility': 0.27301379921070823,
#   'SHOP weight': 0.049074674055459885,
#   'TSLA weight': 0.12027021902971552,
#   'GOLD weight': 0.01583952711084029,
#   'DAL weight': 0.2679402433446973,
#   'NFLX weight': 0.06238520903773167,
#   'AAPL weight': 0.16116936882621616,
#   'PFE weight': 0.08715989468524894,
#   'BTC weight': 0.23616086391009014}]

# %% [markdown]
# for index, row in portfolios.iterrows():
#     portf_dict = [row]
#     print(portf_dict)

# %%
# convert into JSON and save it as a separate file:
#portf = portfolios.to_json()
#port = json.dumps(port)
with open('../Data/portfolio_data.json', 'w') as outfile:
    json.dump(portf, outfile)

portf
# Out:
# [{'Returns': 75.62042112188988,
#   'Volatility': 0.22929720391334374,
#   'SHOP weight': 0.0029027941707776245,
#   'TSLA weight': 0.05317629421305022,
#   'GOLD weight': 0.13238796593249,
#   'DAL weight': 0.2563790552801886,
#   'NFLX weight': 0.08612911292253878,
#   'AAPL weight': 0.1588748127996986,
#   'PFE weight': 0.11759769084626745,
#   'BTC weight': 0.19255227383498869},
#  {'Returns': 86.87323146660071,
#   'Volatility': 0.2459802440258871,
#   'SHOP weight': 0.0075575916934768,
#   'TSLA weight': 0.11434917230102143,
#   'GOLD weight': 0.23338001354175084,
#   'DAL weight': 0.03439863148645499,
#   'NFLX weight': 0.0005521502342260088,
#   'AAPL weight': 0.09364873004718337,
#   'PFE weight': 0.28221995004615824,
#   'BTC weight': 0.23389376064972833},
#  {'Returns': 37.65750678731416,
#   'Volatility': 0.29335906416739777,
#   'SHOP weight': 0.3218543769743209,
#   'TSLA weight': 0.1488874828595671,
#   'GOLD weight': 0.06180761632736011,
#   'DAL weight': 0.049774088236849645,
#   'NFLX weight': 0.055169810050706966,
#   'AAPL weight': 0.23933591543817842,
#   'PFE weight': 0.10741110742928463,
#   'BTC weight': 0.015759602683732235},
#  {'Returns': 101.61184375253607,
#   'Volatility': 0.2621725186438917,
#   'SHOP weight': 0.01080836367100541,
#   'TSLA weight': 0.022834727541556514,
#   'GOLD weight': 0.060620496396043014,
#   'DAL weight': 0.22586372038903108,
#   'NFLX weight': 0.12781207994138383,
#   'AAPL weight': 0.13448529752256588,
#   'PFE weight': 0.1439565016787689,
#   'BTC weight': 0.2736188128596454},
#  {'Returns': 63.32615068770207,
#   'Volatility': 0.23419093783691888,
#   'SHOP weight': 0.2047819034375613,
#   'TSLA weight': 0.09990770495714278,
#   'GOLD weight': 0.17800876163303253,
#   'DAL weight': 0.1808201034555651,
#   'NFLX weight': 0.08948673215040928,
#   'AAPL weight': 0.022917799471465463,
#   'PFE weight': 0.08628659764896672,
#   'BTC weight': 0.1377903972458568},
#  {'Returns': 32.516254494727825,
#   'Volatility': 0.28428190250422,
#   'SHOP weight': 0.022996523713440246,
#   'TSLA weight': 0.28045828440648446,
#   'GOLD weight': 0.0552171608436883,
#   'DAL weight': 0.304204210633153,
#   'NFLX weight': 0.13004402626390815,
#   'AAPL weight': 0.15349835552043312,
#   'PFE weight': 0.049439678326182755,
#   'BTC weight': 0.0041417602927099366},
#  {'Returns': 46.30245078116106,
#   'Volatility': 0.1937921185300727,
#   'SHOP weight': 0.1807473643684161,
#   'TSLA weight': 0.026996795897909823,
#   'GOLD weight': 0.15932375434875237,
#   'DAL weight': 0.22175922058932934,
#   'NFLX weight': 0.1217322719941776,
#   'AAPL weight': 0.019728352645038465,
#   'PFE weight': 0.1853339448032202,
#   'BTC weight': 0.08437829535315608},
#  {'Returns': 49.344062747040226,
#   'Volatility': 0.19934122583730474,
#   'SHOP weight': 0.006537854965310705,
#   'TSLA weight': 0.11205909695801651,
#   'GOLD weight': 0.10057087408144574,
#   'DAL weight': 0.19842099867360719,
#   'NFLX weight': 0.23984081658462914,
#   'AAPL weight': 0.04404747513089314,
#   'PFE weight': 0.2043736387609932,
#   'BTC weight': 0.0941492448451043},
#  {'Returns': 40.74611221153562,
#   'Volatility': 0.2037729020040492,
#   'SHOP weight': 0.17411969856737586,
#   'TSLA weight': 0.09168575916789712,
#   'GOLD weight': 0.10905748908798654,
#   'DAL weight': 0.06650859712608452,
#   'NFLX weight': 0.0663578439426743,
#   'AAPL weight': 0.13299709628796605,
#   'PFE weight': 0.3142426995987066,
#   'BTC weight': 0.04503081622130897},
#  {'Returns': 35.712863738980545,
#   'Volatility': 0.30252132312086344,
#   'SHOP weight': 0.18356020371605292,
#   'TSLA weight': 0.26833158137260865,
#   'GOLD weight': 0.03122499828560646,
#   'DAL weight': 0.010111030083384459,
#   'NFLX weight': 0.26006693260519553,
#   'AAPL weight': 0.06109798225902794,
#   'PFE weight': 0.17856990083707497,
#   'BTC weight': 0.0070373708410491195},
#  {'Returns': 66.26313493880478,
#   'Volatility': 0.2281653207695443,
#   'SHOP weight': 0.07624125617947275,
#   'TSLA weight': 0.10759556089102355,
#   'GOLD weight': 0.13432864897743219,
#   'DAL weight': 0.21565370044891946,
#   'NFLX weight': 0.21176368403333412,
#   'AAPL weight': 0.021475401123191986,
#   'PFE weight': 0.07701421846861194,
#   'BTC weight': 0.15592752987801392},
#  {'Returns': 43.0291424203732,
#   'Volatility': 0.33625702139795904,
#   'SHOP weight': 0.2367435613250874,
#   'TSLA weight': 0.3189562531864758,
#   'GOLD weight': 0.010563242854531455,
#   'DAL weight': 0.08380348596253552,
#   'NFLX weight': 0.09075285567358302,
#   'AAPL weight': 0.17098878724468233,
#   'PFE weight': 0.07657413108524608,
#   'BTC weight': 0.01161768266785845},
#  {'Returns': 72.91944531072856,
#   'Volatility': 0.2855763214061153,
#   'SHOP weight': 0.11230548544547153,
#   'TSLA weight': 0.277268839090954,
#   'GOLD weight': 0.10021121694262007,
#   'DAL weight': 0.07235864863101502,
#   'NFLX weight': 0.12271566427832982,
#   'AAPL weight': 0.04717401314856975,
#   'PFE weight': 0.12354770936504358,
#   'BTC weight': 0.14441842309799618},
#  {'Returns': 70.49406023056949,
#   'Volatility': 0.2095198389450025,
#   'SHOP weight': 0.0864260582513154,
#   'TSLA weight': 0.050535623965820654,
#   'GOLD weight': 0.21050780560692467,
#   'DAL weight': 0.12441158793626353,
#   'NFLX weight': 0.07674036013608006,
#   'AAPL weight': 0.05549744859973735,
#   'PFE weight': 0.21592772680280445,
#   'BTC weight': 0.17995338870105385},
#  {'Returns': 93.49374341699193,
#   'Volatility': 0.29348447630763796,
#   'SHOP weight': 0.09405061875764929,
#   'TSLA weight': 0.24632760940736179,
#   'GOLD weight': 0.05711359718193871,
#   'DAL weight': 0.1068350936742504,
#   'NFLX weight': 0.14009783556572727,
#   'AAPL weight': 0.038433657806995945,
#   'PFE weight': 0.10365303875461282,
#   'BTC weight': 0.21348854885146384},
#  {'Returns': 64.53080876577613,
#   'Volatility': 0.2092836638825057,
#   'SHOP weight': 0.15826793330778183,
#   'TSLA weight': 0.028935604595472317,
#   'GOLD weight': 0.11593285665016202,
#   'DAL weight': 0.1396047198387016,
#   'NFLX weight': 0.0705880559055043,
#   'AAPL weight': 0.17678735636052959,
#   'PFE weight': 0.16784046916270218,
#   'BTC weight': 0.14204300417914628},
#  {'Returns': 65.0838456933512,
#   'Volatility': 0.28335051821221796,
#   'SHOP weight': 0.1620022398995106,
#   'TSLA weight': 0.2500431831228382,
#   'GOLD weight': 0.16583023436113786,
#   'DAL weight': 0.20573674827215838,
#   'NFLX weight': 0.03520071557968192,
#   'AAPL weight': 0.03858721492851246,
#   'PFE weight': 0.017559600233679373,
#   'BTC weight': 0.12504006360248124},
#  {'Returns': 70.0474605388198,
#   'Volatility': 0.2500532812137296,
#   'SHOP weight': 0.1377705453859378,
#   'TSLA weight': 0.14670411027587735,
#   'GOLD weight': 0.09607761839919486,
#   'DAL weight': 0.023239146056291394,
#   'NFLX weight': 0.14202761696259816,
#   'AAPL weight': 0.15028421392791916,
#   'PFE weight': 0.15309616953145558,
#   'BTC weight': 0.15080057946072584},
#  {'Returns': 56.950655201274884,
#   'Volatility': 0.27189733933402305,
#   'SHOP weight': 0.2715307370095301,
#   'TSLA weight': 0.13720613378108362,
#   'GOLD weight': 0.09630971290660836,
#   'DAL weight': 0.16162379210425695,
#   'NFLX weight': 0.12295483306454255,
#   'AAPL weight': 0.10913306880117925,
#   'PFE weight': 0.0036376319175821328,
#   'BTC weight': 0.09760409041521696},
#  {'Returns': 101.07381972094348,
#   'Volatility': 0.29049850111928066,
#   'SHOP weight': 0.07572563829699289,
#   'TSLA weight': 0.2243685272623638,
#   'GOLD weight': 0.07420033625203148,
#   'DAL weight': 0.004340345295422626,
#   'NFLX weight': 0.09066301839702665,
#   'AAPL weight': 0.0748853482502924,
#   'PFE weight': 0.21340133944835005,
#   'BTC weight': 0.24241544679752008},
#  {'Returns': 53.54645424986202,
#   'Volatility': 0.2715243913694487,
#   'SHOP weight': 0.2201448186122112,
#   'TSLA weight': 0.21272242186541426,
#   'GOLD weight': 0.06990392644800751,
#   'DAL weight': 0.19368313702639794,
#   'NFLX weight': 0.1263790680878498,
#   'AAPL weight': 0.03543352144541835,
#   'PFE weight': 0.07012914088048273,
#   'BTC weight': 0.07160396563421811},
#  {'Returns': 30.792811023805342,
#   'Volatility': 0.20439048272716304,
#   'SHOP weight': 0.04609465409368258,
#   'TSLA weight': 0.010140920903120977,
#   'GOLD weight': 0.30766065644422935,
#   'DAL weight': 0.34465217638542317,
#   'NFLX weight': 0.10154717088331182,
#   'AAPL weight': 0.01401426786403044,
#   'PFE weight': 0.10556540459433757,
#   'BTC weight': 0.07032474883186414},
#  {'Returns': 35.62862643093715,
#   'Volatility': 0.2531659574794679,
#   'SHOP weight': 0.20350588405369638,
#   'TSLA weight': 0.10229768918639473,
#   'GOLD weight': 0.04645796795827017,
#   'DAL weight': 0.07104720409222165,
#   'NFLX weight': 0.2609226028129132,
#   'AAPL weight': 0.16582458468595046,
#   'PFE weight': 0.11839768658196041,
#   'BTC weight': 0.031546380628592975},
#  {'Returns': 78.63274680578314,
#   'Volatility': 0.2267968835427229,
#   'SHOP weight': 0.1609683612759218,
#   'TSLA weight': 0.07255635562176634,
#   'GOLD weight': 0.06316369064791359,
#   'DAL weight': 0.15353177744161955,
#   'NFLX weight': 0.001848610566609634,
#   'AAPL weight': 0.171135681945341,
#   'PFE weight': 0.20765865393798327,
#   'BTC weight': 0.16913686856284493},
#  {'Returns': 96.03117626182953,
#   'Volatility': 0.26616330832198903,
#   'SHOP weight': 0.028014588827175637,
#   'TSLA weight': 0.18791376249744227,
#   'GOLD weight': 0.13977856572307298,
#   'DAL weight': 0.06732616235269917,
#   'NFLX weight': 0.037122869132804305,
#   'AAPL weight': 0.04553767916698222,
#   'PFE weight': 0.2552162796740797,
#   'BTC weight': 0.23909009262574368},
#  {'Returns': 34.53728077071494,
#   'Volatility': 0.20499164397323483,
#   'SHOP weight': 0.2116119326080057,
#   'TSLA weight': 0.030208736370315153,
#   'GOLD weight': 0.12192321295088751,
#   'DAL weight': 0.13948754537544542,
#   'NFLX weight': 0.17639359749890496,
#   'AAPL weight': 0.08660947915593269,
#   'PFE weight': 0.19397658968766401,
#   'BTC weight': 0.03978890635284455},
#  {'Returns': 79.50125825517694,
#   'Volatility': 0.2243448062912054,
#   'SHOP weight': 0.1547624944325621,
#   'TSLA weight': 0.010017247970937553,
#   'GOLD weight': 0.12570083399276177,
#   'DAL weight': 0.11187498371111276,
#   'NFLX weight': 0.045147122399708306,
#   'AAPL weight': 0.1747106060577815,
#   'PFE weight': 0.1813599574350493,
#   'BTC weight': 0.19642675400008677},
#  {'Returns': 29.726830940073558,
#   'Volatility': 0.2562865231962944,
#   'SHOP weight': 0.00945796992122871,
#   'TSLA weight': 0.25168426638249664,
#   'GOLD weight': 0.19618339934637485,
#   'DAL weight': 0.23239836780123754,
#   'NFLX weight': 0.1640662574094596,
#   'AAPL weight': 0.050951932822128544,
#   'PFE weight': 0.06886291620885768,
#   'BTC weight': 0.026394890108216332},
#  {'Returns': 47.96925693049898,
#   'Volatility': 0.1961934965160372,
#   'SHOP weight': 0.07995770337245076,
#   'TSLA weight': 0.05998118081510248,
#   'GOLD weight': 0.1669139127226663,
#   'DAL weight': 0.0821521756858018,
#   'NFLX weight': 0.1307240127107932,
#   'AAPL weight': 0.18351704813791572,
#   'PFE weight': 0.19623043631730405,
#   'BTC weight': 0.10052353023796559},
#  {'Returns': 78.76413082196483,
#   'Volatility': 0.2611046862445901,
#   'SHOP weight': 0.10611797292166328,
#   'TSLA weight': 0.10279343424165058,
#   'GOLD weight': 0.13554158557031282,
#   'DAL weight': 0.10000961210972896,
#   'NFLX weight': 0.13355346375868699,
#   'AAPL weight': 0.212677725180568,
#   'PFE weight': 0.009051010462246425,
#   'BTC weight': 0.20025519575514297},
#  {'Returns': 36.5409515115512,
#   'Volatility': 0.22960671182255285,
#   'SHOP weight': 0.223075734431268,
#   'TSLA weight': 0.09781029478119628,
#   'GOLD weight': 0.08678997359933857,
#   'DAL weight': 0.21713091403634252,
#   'NFLX weight': 0.03907575324461589,
#   'AAPL weight': 0.1775120613977886,
#   'PFE weight': 0.13400801049589958,
#   'BTC weight': 0.024597258013550644},
#  {'Returns': 88.74218599280043,
#   'Volatility': 0.2903815258402983,
#   'SHOP weight': 0.10616328361457468,
#   'TSLA weight': 0.18444575525591594,
#   'GOLD weight': 0.10419336876835415,
#   'DAL weight': 0.03039904238464671,
#   'NFLX weight': 0.18489874783498297,
#   'AAPL weight': 0.12248929591746381,
#   'PFE weight': 0.04724400603890346,
#   'BTC weight': 0.22016650018515826},
#  {'Returns': 31.26863526099279,
#   'Volatility': 0.23607771400811162,
#   'SHOP weight': 0.010589637550685657,
#   'TSLA weight': 0.18575593962115963,
#   'GOLD weight': 0.1470048562743112,
#   'DAL weight': 0.1754684313856599,
#   'NFLX weight': 0.15438130708188252,
#   'AAPL weight': 0.20529541046471111,
#   'PFE weight': 0.08855712474488253,
#   'BTC weight': 0.03294729287670742},
#  {'Returns': 30.440534544596836,
#   'Volatility': 0.2752024538388811,
#   'SHOP weight': 0.24082015154940745,
#   'TSLA weight': 0.19455251062138842,
#   'GOLD weight': 0.12175779203747553,
#   'DAL weight': 0.15359295888720384,
#   'NFLX weight': 0.06835941021382809,
#   'AAPL weight': 0.14605750125353903,
#   'PFE weight': 0.07362901651222124,
#   'BTC weight': 0.0012306589249363572},
#  {'Returns': 60.18856518773492,
#   'Volatility': 0.2443203466574806,
#   'SHOP weight': 0.14462221404116665,
#   'TSLA weight': 0.1616597168194352,
#   'GOLD weight': 0.05770347095814474,
#   'DAL weight': 0.2116449271927002,
#   'NFLX weight': 0.039759645239238216,
#   'AAPL weight': 0.18163717643914393,
#   'PFE weight': 0.10301979029466647,
#   'BTC weight': 0.09995305901550464},
#  {'Returns': 65.28990625059706,
#   'Volatility': 0.20616830962786137,
#   'SHOP weight': 0.06768787846882723,
#   'TSLA weight': 0.022128423982540852,
#   'GOLD weight': 0.17282347047221636,
#   'DAL weight': 0.18227606222225062,
#   'NFLX weight': 0.1422307651887884,
#   'AAPL weight': 0.11013201608787489,
#   'PFE weight': 0.13598562133612188,
#   'BTC weight': 0.1667357622413797},
#  {'Returns': 85.30718617929338,
#   'Volatility': 0.25515980157390283,
#   'SHOP weight': 0.2385845607451407,
#   'TSLA weight': 0.03793960697997268,
#   'GOLD weight': 0.10582741540184964,
#   'DAL weight': 0.02463747159841802,
#   'NFLX weight': 0.16073541151978488,
#   'AAPL weight': 0.05498913870912162,
#   'PFE weight': 0.16729100998764557,
#   'BTC weight': 0.2099953850580669},
#  {'Returns': 49.10224720478298,
#   'Volatility': 0.2216126406675694,
#   'SHOP weight': 0.03833295597084599,
#   'TSLA weight': 0.11907447568650432,
#   'GOLD weight': 0.15134820708873584,
#   'DAL weight': 0.14585838035174203,
#   'NFLX weight': 0.16675091452453447,
#   'AAPL weight': 0.2011846171616493,
#   'PFE weight': 0.07441944772514793,
#   'BTC weight': 0.10303100149084009},
#  {'Returns': 42.062937567233966,
#   'Volatility': 0.2300036986010545,
#   'SHOP weight': 0.17593992630970925,
#   'TSLA weight': 0.12163617368240673,
#   'GOLD weight': 0.18132093251639617,
#   'DAL weight': 0.007733737728862598,
#   'NFLX weight': 0.15278630032408913,
#   'AAPL weight': 0.08889650561047785,
#   'PFE weight': 0.2029854375274473,
#   'BTC weight': 0.06870098630061101},
#  {'Returns': 33.18058630173411,
#   'Volatility': 0.253674304429767,
#   'SHOP weight': 0.2137652602348334,
#   'TSLA weight': 0.17123790694748645,
#   'GOLD weight': 0.2416754682136426,
#   'DAL weight': 0.22306255431200833,
#   'NFLX weight': 0.04967090277917544,
#   'AAPL weight': 0.03197651802665639,
#   'PFE weight': 0.03351527713112971,
#   'BTC weight': 0.03509611235506771},
#  {'Returns': 55.092191348119286,
#   'Volatility': 0.19736182699166469,
#   'SHOP weight': 0.04584276117135435,
#   'TSLA weight': 0.017992934064506215,
#   'GOLD weight': 0.18394540465240578,
#   'DAL weight': 0.14689187336668702,
#   'NFLX weight': 0.14746842327248466,
#   'AAPL weight': 0.1857749710114182,
#   'PFE weight': 0.13391006581145656,
#   'BTC weight': 0.1381735666496872},
#  {'Returns': 45.22819838523862,
#   'Volatility': 0.23779198573518973,
#   'SHOP weight': 0.09503319916846631,
#   'TSLA weight': 0.19026133828299627,
#   'GOLD weight': 0.22644799701778368,
#   'DAL weight': 0.08653248279909818,
#   'NFLX weight': 0.16912380608162608,
#   'AAPL weight': 0.024907104407130978,
#   'PFE weight': 0.12058327377135959,
#   'BTC weight': 0.08711079847153888},
#  {'Returns': 75.56268355452778,
#   'Volatility': 0.3033035574560274,
#   'SHOP weight': 0.20032813794918747,
#   'TSLA weight': 0.20767488472573353,
#   'GOLD weight': 0.07331542517297107,
#   'DAL weight': 0.0340667218794974,
#   'NFLX weight': 0.16818732311536758,
#   'AAPL weight': 0.13995529210112673,
#   'PFE weight': 0.01730221498868279,
#   'BTC weight': 0.1591700000674333},
#  {'Returns': 59.18138732713115,
#   'Volatility': 0.22376229044360108,
#   'SHOP weight': 0.1397740142951252,
#   'TSLA weight': 0.1395342808616498,
#   'GOLD weight': 0.09404314700557458,
#   'DAL weight': 0.23823307868988894,
#   'NFLX weight': 0.01754156960057949,
#   'AAPL weight': 0.08823411395559405,
#   'PFE weight': 0.1824412903217157,
#   'BTC weight': 0.10019850526987217},
#  {'Returns': 38.165644106648564,
#   'Volatility': 0.22139785424691086,
#   'SHOP weight': 0.23616167678108482,
#   'TSLA weight': 0.09010678083251286,
#   'GOLD weight': 0.05335807569846278,
#   'DAL weight': 0.08983453285780829,
#   'NFLX weight': 0.10091127586558754,
#   'AAPL weight': 0.12109493835760418,
#   'PFE weight': 0.2847610808566927,
#   'BTC weight': 0.02377163875024682},
#  {'Returns': 92.5084781124801,
#   'Volatility': 0.2499141252674319,
#   'SHOP weight': 0.1696665624089706,
#   'TSLA weight': 0.11877356596855455,
#   'GOLD weight': 0.043192099116593774,
#   'DAL weight': 0.19322758521239705,
#   'NFLX weight': 0.041285023417533095,
#   'AAPL weight': 0.02173922338787223,
#   'PFE weight': 0.2060421077254433,
#   'BTC weight': 0.20607383276263536},
#  {'Returns': 43.2894731839403,
#   'Volatility': 0.22002110493956367,
#   'SHOP weight': 0.055076785028773195,
#   'TSLA weight': 0.15181400673711667,
#   'GOLD weight': 0.024979721395838712,
#   'DAL weight': 0.23780358162889184,
#   'NFLX weight': 0.09961260244957892,
#   'AAPL weight': 0.18515704940251473,
#   'PFE weight': 0.2019365633380753,
#   'BTC weight': 0.04361969001921066},
#  {'Returns': 82.364567479738,
#   'Volatility': 0.24252769707084854,
#   'SHOP weight': 0.16313203579060426,
#   'TSLA weight': 0.03333773342499296,
#   'GOLD weight': 0.2087386532772354,
#   'DAL weight': 0.08216998121211497,
#   'NFLX weight': 0.08726568142126102,
#   'AAPL weight': 0.07727063124440023,
#   'PFE weight': 0.12645198721882242,
#   'BTC weight': 0.22163329641056864},
#  {'Returns': 63.68572781881841,
#   'Volatility': 0.25268160002110146,
#   'SHOP weight': 0.11420497641160603,
#   'TSLA weight': 0.12518073485751383,
#   'GOLD weight': 0.18196825283470192,
#   'DAL weight': 0.06523817902657143,
#   'NFLX weight': 0.05468175611198649,
#   'AAPL weight': 0.2707409560367692,
#   'PFE weight': 0.03873773600386227,
#   'BTC weight': 0.1492474087169889},
#  {'Returns': 27.819717687538933,
#   'Volatility': 0.19078393425411014,
#   'SHOP weight': 0.1714091763882447,
#   'TSLA weight': 0.03799605181740725,
#   'GOLD weight': 0.11504860788160218,
#   'DAL weight': 0.18609005607124915,
#   'NFLX weight': 0.03360626186452285,
#   'AAPL weight': 0.15576126030272455,
#   'PFE weight': 0.2946197548957185,
#   'BTC weight': 0.005468830778530831},
#  {'Returns': 13.484178355026007,
#   'Volatility': 0.19946919896986706,
#   'SHOP weight': 0.02805675854738028,
#   'TSLA weight': 0.07587168227117458,
#   'GOLD weight': 0.24715855870588205,
#   'DAL weight': 0.053155069582274,
#   'NFLX weight': 0.17270499671960662,
#   'AAPL weight': 0.19324375079608852,
#   'PFE weight': 0.22892258177032246,
#   'BTC weight': 0.0008866016072716067},
#  {'Returns': 41.64754636011597,
#   'Volatility': 0.21731929991932641,
#   'SHOP weight': 0.013112255765426222,
#   'TSLA weight': 0.1347544891804097,
#   'GOLD weight': 0.1660163316745483,
#   'DAL weight': 0.19286345807247607,
#   'NFLX weight': 4.4837587646318906e-05,
#   'AAPL weight': 0.27578692762719,
#   'PFE weight': 0.14988332162092236,
#   'BTC weight': 0.06753837847138108},
#  {'Returns': 45.508898589722136,
#   'Volatility': 0.20480240786795098,
#   'SHOP weight': 0.027507082891203127,
#   'TSLA weight': 0.12445576920955147,
#   'GOLD weight': 0.1657910186486684,
#   'DAL weight': 0.16591439986727743,
#   'NFLX weight': 0.16089238990743593,
#   'AAPL weight': 0.10671646197462582,
#   'PFE weight': 0.1605153175018452,
#   'BTC weight': 0.08820755999939259},
#  {'Returns': 95.00418875797,
#   'Volatility': 0.297535242261545,
#   'SHOP weight': 0.24139753932830219,
#   'TSLA weight': 0.10783117639451865,
#   'GOLD weight': 0.2510781548576164,
#   'DAL weight': 0.10180849312234153,
#   'NFLX weight': 0.0065654865556555985,
#   'AAPL weight': 0.030728713528860006,
#   'PFE weight': 0.004690111732975028,
#   'BTC weight': 0.25590032447973066},
#  {'Returns': 62.29036535043186,
#   'Volatility': 0.23642842901080552,
#   'SHOP weight': 0.15470649358614946,
#   'TSLA weight': 0.09960935732481899,
#   'GOLD weight': 0.08154789695380807,
#   'DAL weight': 0.05899092398802926,
#   'NFLX weight': 0.15307240388719703,
#   'AAPL weight': 0.19161957718577874,
#   'PFE weight': 0.1330573101478029,
#   'BTC weight': 0.1273960369264157},
#  {'Returns': 81.11008486598558,
#   'Volatility': 0.25189866830501734,
#   'SHOP weight': 0.02293410877356753,
#   'TSLA weight': 0.13761879318709355,
#   'GOLD weight': 0.013010940580304954,
#   'DAL weight': 0.039166285651672725,
#   'NFLX weight': 0.22048523450345456,
#   'AAPL weight': 0.21367106768711125,
#   'PFE weight': 0.16452676813441047,
#   'BTC weight': 0.18858680148238505},
#  {'Returns': 70.34871699529972,
#   'Volatility': 0.2188228043913912,
#   'SHOP weight': 0.06745691555359959,
#   'TSLA weight': 0.06507636043907662,
#   'GOLD weight': 0.12162797841841635,
#   'DAL weight': 0.2107600841449086,
#   'NFLX weight': 0.03211399114354849,
#   'AAPL weight': 0.19655389936564782,
#   'PFE weight': 0.1432539972025124,
#   'BTC weight': 0.16315677373229007},
#  {'Returns': 59.85015480765755,
#   'Volatility': 0.22502843032629027,
#   'SHOP weight': 0.11064756386347979,
#   'TSLA weight': 0.1444885059929419,
#   'GOLD weight': 0.025734415335835238,
#   'DAL weight': 0.16671925400645532,
#   'NFLX weight': 0.13882497592980003,
#   'AAPL weight': 0.12864165506332637,
#   'PFE weight': 0.18416590303437894,
#   'BTC weight': 0.10077772677378236},
#  {'Returns': 42.256500053571585,
#   'Volatility': 0.20414251067415554,
#   'SHOP weight': 0.1390554436355066,
#   'TSLA weight': 0.0031536956923000816,
#   'GOLD weight': 0.23202058109925275,
#   'DAL weight': 0.22387760066002257,
#   'NFLX weight': 0.006744850528656955,
#   'AAPL weight': 0.22953918625550868,
#   'PFE weight': 0.07525829102543387,
#   'BTC weight': 0.09035035110331853},
#  {'Returns': 77.26566762670365,
#   'Volatility': 0.25051948263495516,
#   'SHOP weight': 0.12071615612720547,
#   'TSLA weight': 0.14248063117979898,
#   'GOLD weight': 0.12099039520928685,
#   'DAL weight': 0.10025602471529264,
#   'NFLX weight': 0.13633659856985608,
#   'AAPL weight': 0.09640104876468936,
#   'PFE weight': 0.10149729314718665,
#   'BTC weight': 0.181321852286684},
#  {'Returns': 35.09227914927406,
#   'Volatility': 0.23528472203511705,
#   'SHOP weight': 0.16372990775214974,
#   'TSLA weight': 0.15971872033330625,
#   'GOLD weight': 0.13206314407690395,
#   'DAL weight': 0.05581227672527915,
#   'NFLX weight': 0.14130956520536045,
#   'AAPL weight': 0.10680685812297688,
#   'PFE weight': 0.21034774916922347,
#   'BTC weight': 0.0302117786148001},
#  {'Returns': 73.17870178165683,
#   'Volatility': 0.21708096332855975,
#   'SHOP weight': 0.0444221740754106,
#   'TSLA weight': 0.03666125873205933,
#   'GOLD weight': 0.16364906003346696,
#   'DAL weight': 0.10445896428061557,
#   'NFLX weight': 0.13721140643019938,
#   'AAPL weight': 0.1612865475113179,
#   'PFE weight': 0.15904396309101496,
#   'BTC weight': 0.19326662584591525},
#  {'Returns': 83.73487143131122,
#   'Volatility': 0.2504644515610369,
#   'SHOP weight': 0.13373218498931308,
#   'TSLA weight': 0.02101989061963382,
#   'GOLD weight': 0.14175249920269398,
#   'DAL weight': 0.020753205661423756,
#   'NFLX weight': 0.18800519171728983,
#   'AAPL weight': 0.15432139012829915,
#   'PFE weight': 0.11370370982761686,
#   'BTC weight': 0.22671192785372957},
#  {'Returns': 55.2798711769714,
#   'Volatility': 0.267962988864365,
#   'SHOP weight': 0.10818311870285757,
#   'TSLA weight': 0.151995881239414,
#   'GOLD weight': 0.2056585838896345,
#   'DAL weight': 0.00863110627529565,
#   'NFLX weight': 0.19287660650344055,
#   'AAPL weight': 0.19835000664118893,
#   'PFE weight': 0.0028555916906419605,
#   'BTC weight': 0.13144910505752688},
#  {'Returns': 71.9713370227507,
#   'Volatility': 0.24474629611479662,
#   'SHOP weight': 0.15267578871920182,
#   'TSLA weight': 0.1308256934891804,
#   'GOLD weight': 0.18099093509626168,
#   'DAL weight': 0.1395044741690467,
#   'NFLX weight': 0.12810897236407312,
#   'AAPL weight': 0.013230598874752765,
#   'PFE weight': 0.08334611861962467,
#   'BTC weight': 0.17131741866785882},
#  {'Returns': 86.34158588442511,
#   'Volatility': 0.24232945875322429,
#   'SHOP weight': 0.09125275347706042,
#   'TSLA weight': 0.06660237420484857,
#   'GOLD weight': 0.11581638423497514,
#   'DAL weight': 0.1691419280526955,
#   'NFLX weight': 0.04198066623297703,
#   'AAPL weight': 0.17624948543430302,
#   'PFE weight': 0.12209632305807355,
#   'BTC weight': 0.21686008530506679},
#  {'Returns': 73.1174333913729,
#   'Volatility': 0.2325102867438573,
#   'SHOP weight': 0.14071543821589208,
#   'TSLA weight': 0.06464743197253932,
#   'GOLD weight': 0.1797102251476825,
#   'DAL weight': 0.1270862013427865,
#   'NFLX weight': 0.10102767132819919,
#   'AAPL weight': 0.10967295991738976,
#   'PFE weight': 0.09315639784312929,
#   'BTC weight': 0.1839836742323814},
#  {'Returns': 88.3368187055516,
#   'Volatility': 0.26238469100907175,
#   'SHOP weight': 0.2463081525890482,
#   'TSLA weight': 0.0780671569498161,
#   'GOLD weight': 0.03922075465649687,
#   'DAL weight': 0.02341776027014156,
#   'NFLX weight': 0.04722311573174304,
#   'AAPL weight': 0.17082606557933547,
#   'PFE weight': 0.19867633960745218,
#   'BTC weight': 0.1962606546159666},
#  {'Returns': 16.13849307290687,
#   'Volatility': 0.21296546277249978,
#   'SHOP weight': 0.039271720882440984,
#   'TSLA weight': 0.07585283903074876,
#   'GOLD weight': 0.2493407694615025,
#   'DAL weight': 0.09247894556201225,
#   'NFLX weight': 0.23987969739980478,
#   'AAPL weight': 0.18497698854890687,
#   'PFE weight': 0.1008148672178396,
#   'BTC weight': 0.01738417189674427},
#  {'Returns': 59.06745772606875,
#   'Volatility': 0.21433659958547402,
#   'SHOP weight': 0.07345808650795065,
#   'TSLA weight': 0.1459126311281396,
#   'GOLD weight': 0.14611974402900707,
#   'DAL weight': 0.21708792902087243,
#   'NFLX weight': 0.07253391330463337,
#   'AAPL weight': 0.017028081492063682,
#   'PFE weight': 0.21252297526967218,
#   'BTC weight': 0.11533663924766094},
#  {'Returns': 73.25884838201358,
#   'Volatility': 0.2230720508317007,
#   'SHOP weight': 0.006730406947167219,
#   'TSLA weight': 0.0012140691978671954,
#   'GOLD weight': 0.1275999626224153,
#   'DAL weight': 0.23827266434222427,
#   'NFLX weight': 0.2347094244289633,
#   'AAPL weight': 0.09830406161524238,
#   'PFE weight': 0.0941380354635423,
#   'BTC weight': 0.1990313753825781},
#  {'Returns': 59.990634393274384,
#   'Volatility': 0.24012078043057397,
#   'SHOP weight': 0.1774088613730604,
#   'TSLA weight': 0.14878341815070212,
#   'GOLD weight': 0.023264677509135783,
#   'DAL weight': 0.11458225327214543,
#   'NFLX weight': 0.1268824895372976,
#   'AAPL weight': 0.1367929333469526,
#   'PFE weight': 0.17655937151095275,
#   'BTC weight': 0.09572599529975323},
#  {'Returns': 65.20710944777446,
#   'Volatility': 0.21691315603352332,
#   'SHOP weight': 0.14677848644283506,
#   'TSLA weight': 0.011304144522107418,
#   'GOLD weight': 0.1804906766742557,
#   'DAL weight': 0.038370537363326504,
#   'NFLX weight': 0.20482551920441955,
#   'AAPL weight': 0.07434511802999941,
#   'PFE weight': 0.17632652051642095,
#   'BTC weight': 0.16755899724663545},
#  {'Returns': 65.31045220412722,
#   'Volatility': 0.24471547425988788,
#   'SHOP weight': 0.08581161230743874,
#   'TSLA weight': 0.2030439717189876,
#   'GOLD weight': 0.176280080653959,
#   'DAL weight': 0.09885741091763695,
#   'NFLX weight': 0.07663048922389358,
#   'AAPL weight': 0.0618875848130884,
#   'PFE weight': 0.15811183585956326,
#   'BTC weight': 0.13937701450543244},
#  {'Returns': 66.48559187096565,
#   'Volatility': 0.27217875299201216,
#   'SHOP weight': 0.1880276923083765,
#   'TSLA weight': 0.1751279126734465,
#   'GOLD weight': 0.11605578002546177,
#   'DAL weight': 0.08686510104638584,
#   'NFLX weight': 0.13176004972271968,
#   'AAPL weight': 0.12742750948671328,
#   'PFE weight': 0.03797732485482327,
#   'BTC weight': 0.13675862988207327},
#  {'Returns': 95.30007491917608,
#   'Volatility': 0.29761886193273873,
#   'SHOP weight': 0.23602561348768772,
#   'TSLA weight': 0.06145293461184094,
#   'GOLD weight': 0.10147575894612554,
#   'DAL weight': 0.0207251761850812,
#   'NFLX weight': 0.01210850496953857,
#   'AAPL weight': 0.2995612582638347,
#   'PFE weight': 0.02797340154129778,
#   'BTC weight': 0.24067735199459364},
#  {'Returns': 68.14513678558518,
#   'Volatility': 0.2345507341451107,
#   'SHOP weight': 0.1537802529419978,
#   'TSLA weight': 0.08768602994779708,
#   'GOLD weight': 0.1338504381969267,
#   'DAL weight': 0.0663808756753914,
#   'NFLX weight': 0.1876748126183872,
#   'AAPL weight': 0.08612988458722425,
#   'PFE weight': 0.12511955359997154,
#   'BTC weight': 0.1593781524323039},
#  {'Returns': 39.01881576187618,
#   'Volatility': 0.2142869671347286,
#   'SHOP weight': 0.032512622673997425,
#   'TSLA weight': 0.18275695940969233,
#   'GOLD weight': 0.1457780437357301,
#   'DAL weight': 0.12728954614579363,
#   'NFLX weight': 0.21953901631658249,
#   'AAPL weight': 0.004374537237355934,
#   'PFE weight': 0.23318881086148568,
#   'BTC weight': 0.05456046361936238},
#  {'Returns': 58.80420390372487,
#   'Volatility': 0.23106427398375495,
#   'SHOP weight': 0.15103323511221156,
#   'TSLA weight': 0.13384932292966084,
#   'GOLD weight': 0.13086613968465624,
#   'DAL weight': 0.19734270760270764,
#   'NFLX weight': 0.041731438935976965,
#   'AAPL weight': 0.12528275667398509,
#   'PFE weight': 0.10888249359881873,
#   'BTC weight': 0.11101190546198296},
#  {'Returns': 72.59624441054866,
#   'Volatility': 0.23014482233184622,
#   'SHOP weight': 0.04703653524777485,
#   'TSLA weight': 0.12308901397660545,
#   'GOLD weight': 0.02288537364022443,
#   'DAL weight': 0.31272851757425246,
#   'NFLX weight': 0.15507153858446573,
#   'AAPL weight': 0.009303279770630451,
#   'PFE weight': 0.18168605142882605,
#   'BTC weight': 0.14819968977722064},
#  {'Returns': 29.713558829606583,
#   'Volatility': 0.21807014408627076,
#   'SHOP weight': 0.2333696241464789,
#   'TSLA weight': 0.032013253690062554,
#   'GOLD weight': 0.14612097143667435,
#   'DAL weight': 0.1075823175692653,
#   'NFLX weight': 0.19782741043895996,
#   'AAPL weight': 0.08326419864094049,
#   'PFE weight': 0.17140278408938878,
#   'BTC weight': 0.028419439988229607},
#  {'Returns': 104.00924895219408,
#   'Volatility': 0.28612822588492615,
#   'SHOP weight': 0.12052459333522897,
#   'TSLA weight': 0.22126301137232238,
#   'GOLD weight': 0.00032602120124468554,
#   'DAL weight': 0.029709953161484597,
#   'NFLX weight': 0.1193528301849082,
#   'AAPL weight': 0.003932930711491016,
#   'PFE weight': 0.27105118389436356,
#   'BTC weight': 0.2338394761389566},
#  {'Returns': 87.44962346193333,
#   'Volatility': 0.2349317489663785,
#   'SHOP weight': 0.10276033789120453,
#   'TSLA weight': 0.028500652051442137,
#   'GOLD weight': 0.13173913784854424,
#   'DAL weight': 0.16924569884485088,
#   'NFLX weight': 0.01682630187370383,
#   'AAPL weight': 0.15029417713161033,
#   'PFE weight': 0.17705042384074252,
#   'BTC weight': 0.22358327051790142},
#  {'Returns': 58.50704208519854,
#   'Volatility': 0.25156168585995065,
#   'SHOP weight': 0.12906377853986412,
#   'TSLA weight': 0.17922120777511433,
#   'GOLD weight': 0.08785400621143104,
#   'DAL weight': 0.004558492376821499,
#   'NFLX weight': 0.12620582264033334,
#   'AAPL weight': 0.1817907242092219,
#   'PFE weight': 0.1864351343619566,
#   'BTC weight': 0.10487083388525734},
#  {'Returns': 38.48168842200401,
#   'Volatility': 0.2565310840069823,
#   'SHOP weight': 0.03610778717818684,
#   'TSLA weight': 0.27599674206472613,
#   'GOLD weight': 0.28144193290291136,
#   'DAL weight': 0.011494097567209347,
#   'NFLX weight': 0.09939684283648174,
#   'AAPL weight': 0.015685335382054834,
#   'PFE weight': 0.2184708589831024,
#   'BTC weight': 0.061406403085327244},
#  {'Returns': 31.72611304697065,
#   'Volatility': 0.2392601922740731,
#   'SHOP weight': 0.07976521441923536,
#   'TSLA weight': 0.19095406361798242,
#   'GOLD weight': 0.19672760451112942,
#   'DAL weight': 0.02873951543970284,
#   'NFLX weight': 0.17070973499165557,
#   'AAPL weight': 0.12099474549479838,
#   'PFE weight': 0.17511996648765668,
#   'BTC weight': 0.03698915503783941},
#  {'Returns': 82.70801489667525,
#   'Volatility': 0.22814737654320671,
#   'SHOP weight': 0.12403632391282361,
#   'TSLA weight': 0.04016503884004852,
#   'GOLD weight': 0.0923126606198853,
#   'DAL weight': 0.1586134196492568,
#   'NFLX weight': 0.21274147764949464,
#   'AAPL weight': 0.00034518710261488236,
#   'PFE weight': 0.16470472333568062,
#   'BTC weight': 0.20708116889019576},
#  {'Returns': 85.03917953886486,
#   'Volatility': 0.24276943304116674,
#   'SHOP weight': 0.10763652464119886,
#   'TSLA weight': 0.059934970616578605,
#   'GOLD weight': 0.18760816959732826,
#   'DAL weight': 0.21895545060191374,
#   'NFLX weight': 0.0167496925342037,
#   'AAPL weight': 0.05955114189326274,
#   'PFE weight': 0.12886562369638432,
#   'BTC weight': 0.2206984264191298},
#  {'Returns': 45.41095047574095,
#   'Volatility': 0.2631464597583898,
#   'SHOP weight': 0.23129745210087527,
#   'TSLA weight': 0.14718897847747417,
#   'GOLD weight': 0.011059773466815727,
#   'DAL weight': 0.2863926507467202,
#   'NFLX weight': 0.013295406530344696,
#   'AAPL weight': 0.22349317779693717,
#   'PFE weight': 0.052206748541442076,
#   'BTC weight': 0.0350658123393906},
#  {'Returns': 48.23685626029223,
#   'Volatility': 0.2289070636248302,
#   'SHOP weight': 0.10788351137149363,
#   'TSLA weight': 0.1487340585223217,
#   'GOLD weight': 0.20703265577061572,
#   'DAL weight': 0.20049791821347118,
#   'NFLX weight': 0.11487438207309593,
#   'AAPL weight': 0.057882097282766894,
#   'PFE weight': 0.06803892460089779,
#   'BTC weight': 0.09505645216533708},
#  {'Returns': 73.82718744739701,
#   'Volatility': 0.22429499425059216,
#   'SHOP weight': 0.05907934589770142,
#   'TSLA weight': 0.07065879983896232,
#   'GOLD weight': 0.06533860837935108,
#   'DAL weight': 0.21166658992615928,
#   'NFLX weight': 0.24652062692189464,
#   'AAPL weight': 0.05126206403553098,
#   'PFE weight': 0.11920164042850658,
#   'BTC weight': 0.1762723245718938},
#  {'Returns': 42.49536931463935,
#   'Volatility': 0.20100446278312134,
#   'SHOP weight': 0.023638339844000763,
#   'TSLA weight': 0.08504856298375693,
#   'GOLD weight': 0.21373890007719146,
#   'DAL weight': 0.04186694027590897,
#   'NFLX weight': 0.13130811992321542,
#   'AAPL weight': 0.21580411043494327,
#   'PFE weight': 0.19568948493974492,
#   'BTC weight': 0.09290554152123823},
#  {'Returns': 20.854261698610372,
#   'Volatility': 0.2242392968225752,
#   'SHOP weight': 0.167684552211201,
#   'TSLA weight': 0.10800443133265368,
#   'GOLD weight': 0.2892558831533385,
#   'DAL weight': 0.009868602017834781,
#   'NFLX weight': 0.04692621650679758,
#   'AAPL weight': 0.13313543576270048,
#   'PFE weight': 0.23393902807473507,
#   'BTC weight': 0.011185850940738788},
#  {'Returns': 27.706937643060936,
#   'Volatility': 0.245297404433561,
#   'SHOP weight': 0.23297145847793327,
#   'TSLA weight': 0.09778768383473545,
#   'GOLD weight': 0.14689022637766544,
#   'DAL weight': 0.16653529695892325,
#   'NFLX weight': 0.12608307919449632,
#   'AAPL weight': 0.16092653788979966,
#   'PFE weight': 0.05543106097268208,
#   'BTC weight': 0.013374656293764445},
#  {'Returns': 43.376060525158614,
#   'Volatility': 0.22212447955449255,
#   'SHOP weight': 0.11117426338746826,
#   'TSLA weight': 0.11641791720866887,
#   'GOLD weight': 0.18524716118917048,
#   'DAL weight': 0.07811703388334008,
#   'NFLX weight': 0.14049297055528867,
#   'AAPL weight': 0.1658236734322658,
#   'PFE weight': 0.1210049929939482,
#   'BTC weight': 0.08172198734984955},
#  {'Returns': 93.39239284156275,
#   'Volatility': 0.30793695589404824,
#   'SHOP weight': 0.2221868814690989,
#   'TSLA weight': 0.19514012234909273,
#   'GOLD weight': 0.06238956323751242,
#   'DAL weight': 0.010315589290685736,
#   'NFLX weight': 0.01739438635286243,
#   'AAPL weight': 0.19123292203443987,
#   'PFE weight': 0.09367901789226843,
#   'BTC weight': 0.20766151737403948},
#  {'Returns': 75.2452185805016,
#   'Volatility': 0.23677229023630295,
#   'SHOP weight': 0.20082214765578427,
#   'TSLA weight': 0.052899430748986453,
#   'GOLD weight': 0.09610400517175088,
#   'DAL weight': 0.1486711728506386,
#   'NFLX weight': 0.01240854070231994,
#   'AAPL weight': 0.20549764995591854,
#   'PFE weight': 0.11608085384943435,
#   'BTC weight': 0.16751619906516702},
#  {'Returns': 42.42209556783646,
#   'Volatility': 0.2399245494910921,
#   'SHOP weight': 0.1229691486473186,
#   'TSLA weight': 0.12884964882115926,
#   'GOLD weight': 0.19636846937531283,
#   'DAL weight': 0.18041851682317725,
#   'NFLX weight': 0.014123306833049734,
#   'AAPL weight': 0.2696506848576409,
#   'PFE weight': 0.013701351520091262,
#   'BTC weight': 0.07391887312225018},
#  {'Returns': 36.68347198229312,
#   'Volatility': 0.26481502725227896,
#   'SHOP weight': 0.18299738795529136,
#   'TSLA weight': 0.21319279752776027,
#   'GOLD weight': 0.07593424726650412,
#   'DAL weight': 0.19646773545042082,
#   'NFLX weight': 0.1928587676454,
#   'AAPL weight': 0.02527459419113969,
#   'PFE weight': 0.09269942407173982,
#   'BTC weight': 0.02057504589174387},
#  {'Returns': 64.0851882254738,
#   'Volatility': 0.2569544466156351,
#   'SHOP weight': 0.048905416362551565,
#   'TSLA weight': 0.2058879006479731,
#   'GOLD weight': 0.19808810314385616,
#   'DAL weight': 0.22775867182534584,
#   'NFLX weight': 0.11218763472998286,
#   'AAPL weight': 0.03133813199519575,
#   'PFE weight': 0.030238900566656436,
#   'BTC weight': 0.1455952407284384},
#  {'Returns': 86.02969548077688,
#   'Volatility': 0.26016496764905755,
#   'SHOP weight': 0.02248392659453728,
#   'TSLA weight': 0.20930550267341383,
#   'GOLD weight': 0.08488367632699748,
#   'DAL weight': 0.15141446410418885,
#   'NFLX weight': 0.1057827843536534,
#   'AAPL weight': 0.05070525232599359,
#   'PFE weight': 0.17765605219275324,
#   'BTC weight': 0.19776834142846236},
#  {'Returns': 161.8000615750158,
#   'Volatility': 0.3847796677097349,
#   'SHOP weight': 0.016776053124231874,
#   'TSLA weight': 0.05001453923177049,
#   'GOLD weight': 0.003551583159216935,
#   'DAL weight': 0.1257083807137305,
#   'NFLX weight': 0.12553432503827883,
#   'AAPL weight': 0.008034804576208721,
#   'PFE weight': 0.20671436338361623,
#   'BTC weight': 0.4636659507729465},
#  {'Returns': 64.13146312834795,
#   'Volatility': 0.21776232493815345,
#   'SHOP weight': 0.19446215659419414,
#   'TSLA weight': 0.07156100550872464,
#   'GOLD weight': 0.19261015356793065,
#   'DAL weight': 0.17823520380235416,
#   'NFLX weight': 0.04272460653075907,
#   'AAPL weight': 0.013767435658102567,
#   'PFE weight': 0.16478756869113315,
#   'BTC weight': 0.1418518696468016},
#  {'Returns': 29.859410477782898,
#   'Volatility': 0.257161993006696,
#   'SHOP weight': 0.19426672137474268,
#   'TSLA weight': 0.123541419009919,
#   'GOLD weight': 0.3754158270210017,
#   'DAL weight': 0.0331799830707612,
#   'NFLX weight': 0.006514813902711139,
#   'AAPL weight': 0.17793105503477583,
#   'PFE weight': 0.02991443924253923,
#   'BTC weight': 0.05923574134354931},
#  {'Returns': 88.59927938649098,
#   'Volatility': 0.24473568399920895,
#   'SHOP weight': 0.014935166156025047,
#   'TSLA weight': 0.11957170580451823,
#   'GOLD weight': 0.08955901437978195,
#   'DAL weight': 0.12719825326150191,
#   'NFLX weight': 0.1657475070534838,
#   'AAPL weight': 0.08500731944133566,
#   'PFE weight': 0.17390906801648223,
#   'BTC weight': 0.22407196588687125},
#  {'Returns': 30.136043276990925,
#   'Volatility': 0.22555664793659105,
#   'SHOP weight': 0.17577074132902404,
#   'TSLA weight': 0.05005058613453356,
#   'GOLD weight': 0.14505869421209755,
#   'DAL weight': 0.03088364332347126,
#   'NFLX weight': 0.3065064137220242,
#   'AAPL weight': 0.07054772288892501,
#   'PFE weight': 0.18182949716653413,
#   'BTC weight': 0.03935270122339025},
#  {'Returns': 30.720011085236365,
#   'Volatility': 0.21784649568691314,
#   'SHOP weight': 0.21265124842147817,
#   'TSLA weight': 0.0354668874370368,
#   'GOLD weight': 0.12364419145779218,
#   'DAL weight': 0.0570399676023915,
#   'NFLX weight': 0.2221017444398769,
#   'AAPL weight': 0.10480866770921762,
#   'PFE weight': 0.21417437038498896,
#   'BTC weight': 0.03011292254721783},
#  {'Returns': 46.59623953502957,
#   'Volatility': 0.22164676113638385,
#   'SHOP weight': 0.12722006502563032,
#   'TSLA weight': 0.13614379997392026,
#   'GOLD weight': 0.167082388382153,
#   'DAL weight': 0.14762321053499347,
#   'NFLX weight': 0.12133960472007575,
#   'AAPL weight': 0.09383950058987695,
#   'PFE weight': 0.12475428638535309,
#   'BTC weight': 0.08199714438799713},
#  {'Returns': 60.227843182786216,
#   'Volatility': 0.24050740379675842,
#   'SHOP weight': 0.2722731225956283,
#   'TSLA weight': 0.019429489702403813,
#   'GOLD weight': 0.15928612143980936,
#   'DAL weight': 0.03086888286779438,
#   'NFLX weight': 0.125958332485362,
#   'AAPL weight': 0.11953176102040683,
#   'PFE weight': 0.13953221115622907,
#   'BTC weight': 0.13312007873236625},
#  {'Returns': 69.49338195236484,
#   'Volatility': 0.21119886352914408,
#   'SHOP weight': 0.029793255851198387,
#   'TSLA weight': 0.03647406285198617,
#   'GOLD weight': 0.26250553695087775,
#   'DAL weight': 0.12009421824277661,
#   'NFLX weight': 0.10685800639275642,
#   'AAPL weight': 0.03424356133826412,
#   'PFE weight': 0.21616560874258833,
#   'BTC weight': 0.19386574962955225},
#  {'Returns': 52.2817738273307,
#   'Volatility': 0.22343897371246393,
#   'SHOP weight': 0.0926676052944311,
#   'TSLA weight': 0.06767058954734854,
#   'GOLD weight': 0.20036636570656985,
#   'DAL weight': 0.07486980120849826,
#   'NFLX weight': 0.11189419926944286,
#   'AAPL weight': 0.2570247618853728,
#   'PFE weight': 0.07127735795263254,
#   'BTC weight': 0.12422931913570387},
#  {'Returns': 90.39410028668627,
#   'Volatility': 0.23739797532311285,
#   'SHOP weight': 0.2047621220862781,
#   'TSLA weight': 0.012272395001957927,
#   'GOLD weight': 0.033183202719790354,
#   'DAL weight': 0.20527440958170654,
#   'NFLX weight': 0.10288074550699519,
#   'AAPL weight': 0.04571395964871073,
#   'PFE weight': 0.18363745814724353,
#   'BTC weight': 0.2122757073073177},
#  {'Returns': 82.19268916497094,
#   'Volatility': 0.22442050399228416,
#   'SHOP weight': 0.1512223042440613,
#   'TSLA weight': 0.018020753412890573,
#   'GOLD weight': 0.0951164735181458,
#   'DAL weight': 0.06856447188756637,
#   'NFLX weight': 0.11440028770467758,
#   'AAPL weight': 0.12522992432833802,
#   'PFE weight': 0.22549390397194133,
#   'BTC weight': 0.20195188093237904},
#  {'Returns': 57.59982386678601,
#   'Volatility': 0.2446881386525652,
#   'SHOP weight': 0.29139505583441266,
#   'TSLA weight': 0.03546056392028602,
#   'GOLD weight': 0.08447262523488083,
#   'DAL weight': 0.050210947715504946,
#   'NFLX weight': 0.1585739520066601,
#   'AAPL weight': 0.119065916289014,
#   'PFE weight': 0.1529424165901427,
#   'BTC weight': 0.10787852240909877},
#  {'Returns': 32.495870929338494,
#   'Volatility': 0.21349190901397636,
#   'SHOP weight': 0.11904333793563479,
#   'TSLA weight': 0.07798445000912593,
#   'GOLD weight': 0.19011923001076317,
#   'DAL weight': 0.1857651470234718,
#   'NFLX weight': 0.027315641020657987,
#   'AAPL weight': 0.26426549299476276,
#   'PFE weight': 0.09241428194106911,
#   'BTC weight': 0.0430924190645145},
#  {'Returns': 83.06420081121932,
#   'Volatility': 0.2546461119464581,
#   'SHOP weight': 0.060421078159786645,
#   'TSLA weight': 0.02100005608725238,
#   'GOLD weight': 0.2657907371846606,
#   'DAL weight': 0.11664127888677979,
#   'NFLX weight': 0.165011181422545,
#   'AAPL weight': 0.08595723904914318,
#   'PFE weight': 0.03349104358203362,
#   'BTC weight': 0.25168738562779874},
#  {'Returns': 32.756988026496515,
#   'Volatility': 0.2029682606071451,
#   'SHOP weight': 0.11837131283239129,
#   'TSLA weight': 0.09473665240714234,
#   'GOLD weight': 0.2009363798392072,
#   'DAL weight': 0.07931270396864468,
#   'NFLX weight': 0.08352760555998007,
#   'AAPL weight': 0.16153266412232198,
#   'PFE weight': 0.21837603473161607,
#   'BTC weight': 0.04320664653869639},
#  {'Returns': 81.9375338552863,
#   'Volatility': 0.2726816170370138,
#   'SHOP weight': 0.23012175795893397,
#   'TSLA weight': 0.08638181978556438,
#   'GOLD weight': 0.21567660928623822,
#   'DAL weight': 0.08546931668439639,
#   'NFLX weight': 0.09239149060156572,
#   'AAPL weight': 0.05498508150756811,
#   'PFE weight': 0.0217049432512881,
#   'BTC weight': 0.21326898092444513},
#  {'Returns': 83.14632871411656,
#   'Volatility': 0.24846860328403805,
#   'SHOP weight': 0.029687829382151514,
#   'TSLA weight': 0.0992204772349201,
#   'GOLD weight': 0.02015239136708842,
#   'DAL weight': 0.27573785875440604,
#   'NFLX weight': 0.12305554940762639,
#   'AAPL weight': 0.1772495085107682,
#   'PFE weight': 0.08161383881804832,
#   'BTC weight': 0.19328254652499105},
#  {'Returns': 55.91171940682004,
#   'Volatility': 0.2034646127657955,
#   'SHOP weight': 0.05782263053726782,
#   'TSLA weight': 0.04746572335011063,
#   'GOLD weight': 0.20992595105940573,
#   'DAL weight': 0.19500897534203476,
#   'NFLX weight': 0.11810490365519359,
#   'AAPL weight': 0.11967336242922486,
#   'PFE weight': 0.11381553396318468,
#   'BTC weight': 0.13818291966357782},
#  {'Returns': 63.81254862220699,
#   'Volatility': 0.22520566984819387,
#   'SHOP weight': 0.2450371003119013,
#   'TSLA weight': 0.004480758191258053,
#   'GOLD weight': 0.10783624466985772,
#   'DAL weight': 0.09632837257755952,
#   'NFLX weight': 0.20820714871051504,
#   'AAPL weight': 0.035324765167979257,
#   'PFE weight': 0.16118087807769757,
#   'BTC weight': 0.1416047322932315},
#  {'Returns': 25.06556122100394,
#   'Volatility': 0.25326835209548904,
#   'SHOP weight': 0.07568880500746589,
#   'TSLA weight': 0.1271442639818667,
#   'GOLD weight': 0.2753172013991207,
#   'DAL weight': 0.027767881140119525,
#   'NFLX weight': 0.2804062165327729,
#   'AAPL weight': 0.1621086008829918,
#   'PFE weight': 0.001029950738899814,
#   'BTC weight': 0.05053708031676266},
#  {'Returns': 37.65066912839101,
#   'Volatility': 0.2520758634257042,
#   'SHOP weight': 0.08634374309010613,
#   'TSLA weight': 0.2357794936005161,
#   'GOLD weight': 0.01740562614948638,
#   'DAL weight': 0.25627043241708525,
#   'NFLX weight': 0.18262669289965874,
#   'AAPL weight': 0.021239250590245548,
#   'PFE weight': 0.18780907792236448,
#   'BTC weight': 0.012525683330537461},
#  {'Returns': 59.22655562986896,
#   'Volatility': 0.23329090672919925,
#   'SHOP weight': 0.18999353498809932,
#   'TSLA weight': 0.15121375382283792,
#   'GOLD weight': 0.0644619575772319,
#   'DAL weight': 0.10173231326064577,
#   'NFLX weight': 0.020836082688183905,
#   'AAPL weight': 0.14192990827215735,
#   'PFE weight': 0.23876180688303747,
#   'BTC weight': 0.09107064250780635},
#  {'Returns': 83.71308382226162,
#   'Volatility': 0.2656427350739441,
#   'SHOP weight': 0.07739118939191679,
#   'TSLA weight': 0.1589646109014759,
#   'GOLD weight': 0.13656944567052962,
#   'DAL weight': 0.031084647906866138,
#   'NFLX weight': 0.0766651625011737,
#   'AAPL weight': 0.19646635903574536,
#   'PFE weight': 0.11649948736654912,
#   'BTC weight': 0.20635909722574353},
#  {'Returns': 55.64485174893234,
#   'Volatility': 0.27578600982311025,
#   'SHOP weight': 0.0819226249595504,
#   'TSLA weight': 0.21687871314301416,
#   'GOLD weight': 0.22164868462875295,
#   'DAL weight': 0.01790031375622077,
#   'NFLX weight': 0.22348065273319034,
#   'AAPL weight': 0.08611269985802666,
#   'PFE weight': 0.02328658306795476,
#   'BTC weight': 0.12876972785328994},
#  {'Returns': 51.490847450919766,
#   'Volatility': 0.20101114827971228,
#   'SHOP weight': 0.13375771733556285,
#   'TSLA weight': 0.06225665041227262,
#   'GOLD weight': 0.1029990341265545,
#   'DAL weight': 0.13802765679318546,
#   'NFLX weight': 0.07607085870876094,
#   'AAPL weight': 0.1968363949533571,
#   'PFE weight': 0.19792493007141002,
#   'BTC weight': 0.09212675759889646},
#  {'Returns': 68.77071737344973,
#   'Volatility': 0.27500482066105375,
#   'SHOP weight': 0.2515667996861902,
#   'TSLA weight': 0.13643015638130698,
#   'GOLD weight': 0.06657962991317613,
#   'DAL weight': 0.1284828748389364,
#   'NFLX weight': 0.19192061462419985,
#   'AAPL weight': 0.06478175830223304,
#   'PFE weight': 0.022395261271398376,
#   'BTC weight': 0.13784290498255902},
#  {'Returns': 30.535166546881964,
#   'Volatility': 0.22583339747489406,
#   'SHOP weight': 0.24163566902623088,
#   'TSLA weight': 0.10843917384045515,
#   'GOLD weight': 0.23694741730704444,
#   'DAL weight': 0.18723737215151182,
#   'NFLX weight': 0.04239589743893079,
#   'AAPL weight': 0.00451175838477748,
#   'PFE weight': 0.15248918392632296,
#   'BTC weight': 0.026343527924726433},
#  {'Returns': 70.20074486860432,
#   'Volatility': 0.24582346997326926,
#   'SHOP weight': 0.0036693719457690675,
#   'TSLA weight': 0.16905160588737742,
#   'GOLD weight': 0.22465634409164956,
#   'DAL weight': 0.06923099991115259,
#   'NFLX weight': 0.19874643909232007,
# ...
#   'PFE weight': 0.2115757013646129,
#   'BTC weight': 0.061980306728320035},
#  {'Returns': 66.37152538734598,
#   'Volatility': 0.23682444936121155,
#   'SHOP weight': 0.013561799310446989,
#   'TSLA weight': 0.18811022166336133,
#   'GOLD weight': 0.22747050144024497,
#   'DAL weight': 0.0577583459207572,
#   'NFLX weight': 0.11208826529960098,
#   'AAPL weight': 0.04706415376063429,
#   'PFE weight': 0.19251342489275244,
#   'BTC weight': 0.16143328771220203},
#  {'Returns': 62.023517472047054,
#   'Volatility': 0.21172408473187593,
#   'SHOP weight': 0.06605581629274122,
#   'TSLA weight': 0.09860523427049887,
#   'GOLD weight': 0.12334299027780918,
#   'DAL weight': 0.15232462136118813,
#   'NFLX weight': 0.11199788760683685,
#   'AAPL weight': 0.15217864375256815,
#   'PFE weight': 0.1600974309599089,
#   'BTC weight': 0.1353973754784488},
#  {'Returns': 38.06667624343555,
#   'Volatility': 0.19119992197553964,
#   'SHOP weight': 0.15195874274403176,
#   'TSLA weight': 0.023827493100598326,
#   'GOLD weight': 0.09409079093436008,
#   'DAL weight': 0.13863199300585077,
#   'NFLX weight': 0.12172856756166783,
#   'AAPL weight': 0.1927677934659824,
#   'PFE weight': 0.22764634412529225,
#   'BTC weight': 0.049348275062216576},
#  {'Returns': 57.20186054298486,
#   'Volatility': 0.21422823035582497,
#   'SHOP weight': 0.0722099863170958,
#   'TSLA weight': 0.03657214395654413,
#   'GOLD weight': 0.128098466698717,
#   'DAL weight': 0.02441008426295279,
#   'NFLX weight': 0.25444752732276843,
#   'AAPL weight': 0.18235597803491946,
#   'PFE weight': 0.16351914205452964,
#   'BTC weight': 0.13838667135247276},
#  {'Returns': 70.7416767011859,
#   'Volatility': 0.2445464475979318,
#   'SHOP weight': 0.1385323051104199,
#   'TSLA weight': 0.1635617969236736,
#   'GOLD weight': 0.1592733903317172,
#   'DAL weight': 0.08716780323616795,
#   'NFLX weight': 0.10985079576820551,
#   'AAPL weight': 0.03830216148996786,
#   'PFE weight': 0.14521655868746491,
#   'BTC weight': 0.15809518845238324},
#  {'Returns': 49.9620263258748,
#   'Volatility': 0.2523580806276628,
#   'SHOP weight': 0.25270235638604804,
#   'TSLA weight': 0.11386918734107604,
#   'GOLD weight': 0.06115205445882984,
#   'DAL weight': 0.22010054435694032,
#   'NFLX weight': 0.07877586288968938,
#   'AAPL weight': 0.1606030537143433,
#   'PFE weight': 0.045834558771797033,
#   'BTC weight': 0.06696238208127615},
#  {'Returns': 93.33952191825803,
#   'Volatility': 0.24710046189475401,
#   'SHOP weight': 0.09984702519994824,
#   'TSLA weight': 0.04559280128488431,
#   'GOLD weight': 0.016053801500027897,
#   'DAL weight': 0.11561548265444863,
#   'NFLX weight': 0.1837791843069212,
#   'AAPL weight': 0.15292876030083372,
#   'PFE weight': 0.15362959238556853,
#   'BTC weight': 0.2325533523673675},
#  {'Returns': 63.49300085218851,
#   'Volatility': 0.2602290024031238,
#   'SHOP weight': 0.09800887400734376,
#   'TSLA weight': 0.23640385901681832,
#   'GOLD weight': 0.1736342924733397,
#   'DAL weight': 0.041321347975571326,
#   'NFLX weight': 0.1173288540105397,
#   'AAPL weight': 0.04422578792769863,
#   'PFE weight': 0.15830448835690988,
#   'BTC weight': 0.13077249623177864},
#  {'Returns': 87.27500985354372,
#   'Volatility': 0.24152680665948467,
#   'SHOP weight': 0.13042604999681773,
#   'TSLA weight': 0.03559538588583906,
#   'GOLD weight': 0.07328442267783915,
#   'DAL weight': 0.21347278643535017,
#   'NFLX weight': 0.07960853289794151,
#   'AAPL weight': 0.14939961954888148,
#   'PFE weight': 0.10345516206868495,
#   'BTC weight': 0.21475804048864583},
#  {'Returns': 67.2510263146139,
#   'Volatility': 0.21657603058728142,
#   'SHOP weight': 0.03994967761078883,
#   'TSLA weight': 0.07553508633473836,
#   'GOLD weight': 0.27291567975966746,
#   'DAL weight': 0.06644187786567593,
#   'NFLX weight': 0.1017909441695253,
#   'AAPL weight': 0.06086146345044809,
#   'PFE weight': 0.19836142611333177,
#   'BTC weight': 0.18414384469582437},
#  {'Returns': 81.08965900426334,
#   'Volatility': 0.24617446635214837,
#   'SHOP weight': 0.1030485898182318,
#   'TSLA weight': 0.019771744047163982,
#   'GOLD weight': 0.23329687132785226,
#   'DAL weight': 0.11315572739284552,
#   'NFLX weight': 0.20225595473870359,
#   'AAPL weight': 0.02779526168619049,
#   'PFE weight': 0.06464853031014475,
#   'BTC weight': 0.2360273206788677},
#  {'Returns': 80.75760716534381,
#   'Volatility': 0.23567675558796408,
#   'SHOP weight': 0.20937986365182623,
#   'TSLA weight': 0.008123279788960392,
#   'GOLD weight': 0.09827974819854358,
#   'DAL weight': 0.198831619545494,
#   'NFLX weight': 0.12628512409788248,
#   'AAPL weight': 0.05904982556842579,
#   'PFE weight': 0.10409347711430299,
#   'BTC weight': 0.19595706203456442},
#  {'Returns': 32.450000310500435,
#   'Volatility': 0.24738556821038818,
#   'SHOP weight': 0.15351690001544022,
#   'TSLA weight': 0.18950380271200865,
#   'GOLD weight': 0.16284942882584802,
#   'DAL weight': 0.15737171764399036,
#   'NFLX weight': 0.0026808935780266423,
#   'AAPL weight': 0.1865956348571685,
#   'PFE weight': 0.12977544982891087,
#   'BTC weight': 0.017706172538606825},
#  {'Returns': 25.82585054605702,
#   'Volatility': 0.2454635720743037,
#   'SHOP weight': 0.01720020426540408,
#   'TSLA weight': 0.2327007403770613,
#   'GOLD weight': 0.18806326735092457,
#   'DAL weight': 0.15174461526195687,
#   'NFLX weight': 0.17858024537937567,
#   'AAPL weight': 0.09048020133737032,
#   'PFE weight': 0.1270679939196581,
#   'BTC weight': 0.014162732108249221},
#  {'Returns': 36.38196416294662,
#   'Volatility': 0.19516988503098934,
#   'SHOP weight': 0.021599047377034844,
#   'TSLA weight': 0.12145047434815696,
#   'GOLD weight': 0.20689169947320826,
#   'DAL weight': 0.1334038489385512,
#   'NFLX weight': 0.15241847312944395,
#   'AAPL weight': 0.08449650927747153,
#   'PFE weight': 0.21676052404608995,
#   'BTC weight': 0.06297942341004323},
#  {'Returns': 66.57270383222445,
#   'Volatility': 0.23276641436552856,
#   'SHOP weight': 0.1178827834729901,
#   'TSLA weight': 0.07747942421249701,
#   'GOLD weight': 0.18509448675823242,
#   'DAL weight': 0.06504973322580976,
#   'NFLX weight': 0.17211835067480905,
#   'AAPL weight': 0.12077458253150639,
#   'PFE weight': 0.09331606817835458,
#   'BTC weight': 0.16828457094580068},
#  {'Returns': 76.02160507882552,
#   'Volatility': 0.2359015967556744,
#   'SHOP weight': 0.12776459800082102,
#   'TSLA weight': 0.06486849066376091,
#   'GOLD weight': 0.03823297227302267,
#   'DAL weight': 0.1426582256972329,
#   'NFLX weight': 0.1951130697815773,
#   'AAPL weight': 0.15854059596307254,
#   'PFE weight': 0.09803038383938266,
#   'BTC weight': 0.17479166378113004},
#  {'Returns': 44.4604129572663,
#   'Volatility': 0.21827266797155692,
#   'SHOP weight': 0.21384261122886403,
#   'TSLA weight': 0.13306820866335198,
#   'GOLD weight': 0.13967532179319223,
#   'DAL weight': 0.04397819899873597,
#   'NFLX weight': 0.025832829846179597,
#   'AAPL weight': 0.04307363225644506,
#   'PFE weight': 0.35007157497782215,
#   'BTC weight': 0.05045762223540904},
#  {'Returns': 31.60452154534661,
#   'Volatility': 0.26199092070278296,
#   'SHOP weight': 0.17870063126158167,
#   'TSLA weight': 0.2473815110235981,
#   'GOLD weight': 0.15107810259131474,
#   'DAL weight': 0.11826135213425726,
#   'NFLX weight': 0.03670680180100575,
#   'AAPL weight': 0.05074679527596007,
#   'PFE weight': 0.21614837330784664,
#   'BTC weight': 0.0009764326044357612},
#  {'Returns': 78.08717999185541,
#   'Volatility': 0.2411375774515185,
#   'SHOP weight': 0.12191496487939561,
#   'TSLA weight': 0.12238101338166256,
#   'GOLD weight': 0.04195252122597177,
#   'DAL weight': 0.11170223128597263,
#   'NFLX weight': 0.152726441490444,
#   'AAPL weight': 0.12914414444450223,
#   'PFE weight': 0.14863116747756477,
#   'BTC weight': 0.17154751581448657},
#  {'Returns': 125.10548480208307,
#   'Volatility': 0.3026003993594878,
#   'SHOP weight': 0.013667715839830353,
#   'TSLA weight': 0.002403871792641347,
#   'GOLD weight': 0.06681210082585322,
#   'DAL weight': 0.1710289603989093,
#   'NFLX weight': 0.007363188549572483,
#   'AAPL weight': 0.10636293465356415,
#   'PFE weight': 0.2863321509067952,
#   'BTC weight': 0.34602907703283403},
#  {'Returns': 26.78870013382098,
#   'Volatility': 0.253803918387864,
#   'SHOP weight': 0.18366738602120816,
#   'TSLA weight': 0.19581464422351738,
#   'GOLD weight': 0.20464483167407907,
#   'DAL weight': 0.15374671097848028,
#   'NFLX weight': 0.06950216837914967,
#   'AAPL weight': 0.08096451566175811,
#   'PFE weight': 0.10546648321446357,
#   'BTC weight': 0.006193259847343747},
#  {'Returns': 41.809885141872854,
#   'Volatility': 0.279653932396946,
#   'SHOP weight': 0.10353995435714847,
#   'TSLA weight': 0.2264538705321348,
#   'GOLD weight': 0.16509487630181474,
#   'DAL weight': 0.0428672019508882,
#   'NFLX weight': 0.18316136934399124,
#   'AAPL weight': 0.18804718200947615,
#   'PFE weight': 0.02434932562225272,
#   'BTC weight': 0.06648621988229365},
#  {'Returns': 52.75006468786117,
#   'Volatility': 0.2445260235749521,
#   'SHOP weight': 0.25014046570491305,
#   'TSLA weight': 0.029581007261855974,
#   'GOLD weight': 0.13137037348069017,
#   'DAL weight': 0.06174900516442833,
#   'NFLX weight': 0.2573077872181902,
#   'AAPL weight': 0.07156047140658751,
#   'PFE weight': 0.08705305107703393,
#   'BTC weight': 0.11123783868630086},
#  {'Returns': 38.20197746268548,
#   'Volatility': 0.20127891819872215,
#   'SHOP weight': 0.20047170273399328,
#   'TSLA weight': 0.036801656898992945,
#   'GOLD weight': 0.21200828416298056,
#   'DAL weight': 0.17701436524946568,
#   'NFLX weight': 0.02839892595595059,
#   'AAPL weight': 0.11809816668606805,
#   'PFE weight': 0.16631958526105028,
#   'BTC weight': 0.06088731305149862},
#  {'Returns': 27.46537608665502,
#   'Volatility': 0.22440972502152387,
#   'SHOP weight': 0.16918190731516847,
#   'TSLA weight': 0.021894672647413776,
#   'GOLD weight': 0.019237999256635573,
#   'DAL weight': 0.037532394204967415,
#   'NFLX weight': 0.25902628848412895,
#   'AAPL weight': 0.2362791753588599,
#   'PFE weight': 0.24874905737987527,
#   'BTC weight': 0.008098505352950681},
#  {'Returns': 68.29903137814549,
#   'Volatility': 0.2213207709905878,
#   'SHOP weight': 0.17717405734392386,
#   'TSLA weight': 0.033545112760912404,
#   'GOLD weight': 0.12385395829717613,
#   'DAL weight': 0.13941879464465384,
#   'NFLX weight': 0.16907445602930132,
#   'AAPL weight': 0.07321776049940028,
#   'PFE weight': 0.12331780424368005,
#   'BTC weight': 0.160398056180952},
#  {'Returns': 104.98301407444877,
#   'Volatility': 0.30313777324068275,
#   'SHOP weight': 0.027801757666027414,
#   'TSLA weight': 0.21460261696189825,
#   'GOLD weight': 0.0964989001789227,
#   'DAL weight': 0.024949304564626268,
#   'NFLX weight': 0.16351813453357644,
#   'AAPL weight': 0.08002866393868355,
#   'PFE weight': 0.1201872202646524,
#   'BTC weight': 0.27241340189161295},
#  {'Returns': 68.72385907857165,
#   'Volatility': 0.22552729073286168,
#   'SHOP weight': 0.07965566872587054,
#   'TSLA weight': 0.0812533014756829,
#   'GOLD weight': 0.20323797634731972,
#   'DAL weight': 0.09567467607444302,
#   'NFLX weight': 0.18919392659060943,
#   'AAPL weight': 0.05339576757604214,
#   'PFE weight': 0.11750872830087096,
#   'BTC weight': 0.18007995490916126},
#  {'Returns': 44.67925502534602,
#   'Volatility': 0.2192695807346717,
#   'SHOP weight': 0.0036962556798111365,
#   'TSLA weight': 0.1577676903486932,
#   'GOLD weight': 0.08256878824077656,
#   'DAL weight': 0.23782253197433761,
#   'NFLX weight': 0.020926565251634225,
#   'AAPL weight': 0.2185607802635511,
#   'PFE weight': 0.221319232770512,
#   'BTC weight': 0.057338155470684174},
#  {'Returns': 87.47698723797426,
#   'Volatility': 0.26131723161303155,
#   'SHOP weight': 0.22325848706610943,
#   'TSLA weight': 0.07470964078525856,
#   'GOLD weight': 0.02290889158358102,
#   'DAL weight': 0.22866009795854766,
#   'NFLX weight': 0.027619330345722014,
#   'AAPL weight': 0.1666827214348301,
#   'PFE weight': 0.06389264567373848,
#   'BTC weight': 0.19226818515221275},
#  {'Returns': 33.638512349443474,
#   'Volatility': 0.21532908328638456,
#   'SHOP weight': 0.1742106475162841,
#   'TSLA weight': 0.09899290268347975,
#   'GOLD weight': 0.1427385772990323,
#   'DAL weight': 0.2442946134356336,
#   'NFLX weight': 0.05163138872275034,
#   'AAPL weight': 0.1167624866274335,
#   'PFE weight': 0.14379814952763234,
#   'BTC weight': 0.027571234187754187},
#  {'Returns': 38.75222112154575,
#   'Volatility': 0.22305816097550757,
#   'SHOP weight': 0.219407715810036,
#   'TSLA weight': 0.09356433129720068,
#   'GOLD weight': 0.13634405365095514,
#   'DAL weight': 0.2565650648028747,
#   'NFLX weight': 0.11946781898247516,
#   'AAPL weight': 0.017051730678177016,
#   'PFE weight': 0.11300863920870241,
#   'BTC weight': 0.04459064556957888},
#  {'Returns': 60.62920228823218,
#   'Volatility': 0.2439733750498016,
#   'SHOP weight': 0.19851258127436622,
#   'TSLA weight': 0.03606960432383819,
#   'GOLD weight': 0.05403193091526735,
#   'DAL weight': 0.02498055037227323,
#   'NFLX weight': 0.15706011956010993,
#   'AAPL weight': 0.2852069992859575,
#   'PFE weight': 0.12018300277040973,
#   'BTC weight': 0.12395521149777779},
#  {'Returns': 102.0087437474867,
#   'Volatility': 0.3102616860274789,
#   'SHOP weight': 0.019275139333526408,
#   'TSLA weight': 0.23474150390839335,
#   'GOLD weight': 0.20228771893599093,
#   'DAL weight': 0.048017830121778814,
#   'NFLX weight': 0.05817817805326041,
#   'AAPL weight': 0.08085194671521376,
#   'PFE weight': 0.08220643736337856,
#   'BTC weight': 0.2744412455684577},
#  {'Returns': 72.79502073419727,
#   'Volatility': 0.26446307040555384,
#   'SHOP weight': 0.16692694553759702,
#   'TSLA weight': 0.12965240279923224,
#   'GOLD weight': 0.08103038573283425,
#   'DAL weight': 0.09556990496401835,
#   'NFLX weight': 0.19230498620662034,
#   'AAPL weight': 0.13835844472649095,
#   'PFE weight': 0.03297166584322392,
#   'BTC weight': 0.1631852641899831},
#  {'Returns': 89.62519020525681,
#   'Volatility': 0.24818651573026212,
#   'SHOP weight': 0.12231427192426021,
#   'TSLA weight': 0.0037309815805105337,
#   'GOLD weight': 0.1677058359365088,
#   'DAL weight': 0.23741090952858007,
#   'NFLX weight': 0.0054962345796359,
#   'AAPL weight': 0.10963085132657027,
#   'PFE weight': 0.11475733500599591,
#   'BTC weight': 0.2389535801179382},
#  {'Returns': 61.66090406703241,
#   'Volatility': 0.2628805277164355,
#   'SHOP weight': 0.20698236657877475,
#   'TSLA weight': 0.11307856992830506,
#   'GOLD weight': 0.20045552044225864,
#   'DAL weight': 0.07279430958926915,
#   'NFLX weight': 0.09987800898145793,
#   'AAPL weight': 0.16161926032709903,
#   'PFE weight': 0.002987144125909532,
#   'BTC weight': 0.1422048200269259},
#  {'Returns': 60.76572388022176,
#   'Volatility': 0.21412191025955893,
#   'SHOP weight': 0.17838290255545902,
#   'TSLA weight': 0.06822372457967976,
#   'GOLD weight': 0.04475349489841178,
#   'DAL weight': 0.15235497476866347,
#   'NFLX weight': 0.1918601776464964,
#   'AAPL weight': 0.06509106972873646,
#   'PFE weight': 0.18512542439507934,
#   'BTC weight': 0.11420823142747362},
#  {'Returns': 79.73450738310379,
#   'Volatility': 0.23604763457944336,
#   'SHOP weight': 0.18642029606324456,
#   'TSLA weight': 0.036889109845762776,
#   'GOLD weight': 0.040351351005168026,
#   'DAL weight': 0.19001544051090738,
#   'NFLX weight': 0.06353710817451692,
#   'AAPL weight': 0.19257050653947502,
#   'PFE weight': 0.11217421253637928,
#   'BTC weight': 0.17804197532454608},
#  {'Returns': 56.70323033028508,
#   'Volatility': 0.24756577266482352,
#   'SHOP weight': 0.12283369629503653,
#   'TSLA weight': 0.14422868949254858,
#   'GOLD weight': 0.049924415564601705,
#   'DAL weight': 0.17019425714975514,
#   'NFLX weight': 0.1864424287327938,
#   'AAPL weight': 0.18042178319751856,
#   'PFE weight': 0.043742853498471554,
#   'BTC weight': 0.10221187606927418},
#  {'Returns': 42.02803386627418,
#   'Volatility': 0.30985496439224125,
#   'SHOP weight': 0.3976434562033617,
#   'TSLA weight': 0.082223189579887,
#   'GOLD weight': 0.08438768108083171,
#   'DAL weight': 0.0021872745033785384,
#   'NFLX weight': 0.14814733782975367,
#   'AAPL weight': 0.1784295458846362,
#   'PFE weight': 0.06233377749396808,
#   'BTC weight': 0.04464773742418318},
#  {'Returns': 98.21361821442258,
#   'Volatility': 0.27301379921070823,
#   'SHOP weight': 0.049074674055459885,
#   'TSLA weight': 0.12027021902971552,
#   'GOLD weight': 0.01583952711084029,
#   'DAL weight': 0.2679402433446973,
#   'NFLX weight': 0.06238520903773167,
#   'AAPL weight': 0.16116936882621616,
#   'PFE weight': 0.08715989468524894,
#   'BTC weight': 0.23616086391009014}]

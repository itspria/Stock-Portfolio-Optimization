# %%
import json
import numpy as np
import math
from datetime import datetime
import pandas as pd 
import matplotlib.pyplot as plt
import pymongo

# %% [markdown]
# # SHOP Stock Calculations

# %%
with open('../Data/SHOP_prices.json') as json_file:
    SHOP_data = json.load(json_file)
    
#stock annual return
SHOP_ann_return=round((((SHOP_data[0]['adjclose']/SHOP_data[len(SHOP_data)-1]['adjclose'])-1)*100),2)

SHOP_price_array=[]
for i in range(len(SHOP_data)):
    SHOP_price_array.append(SHOP_data[i]['adjclose'])
    
#daily volatility
SHOP_daily_vol = round(np.std(SHOP_price_array),2)

#annualized volatility
SHOP_ann_vol = SHOP_daily_vol * math.sqrt(252)
SHOP_ann_vol = round(SHOP_ann_vol,2)

#3 mon return volatility
SHOP_date_array=[]

for y in range(len(SHOP_data)):
    SHOP_date_array.append(datetime.strptime(SHOP_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=SHOP_date_array[y]
    if ((firstdate-SHOP_date_array[y]).days==91):
        date_3mon_ago=SHOP_date_array[y]
        mon3_index = y
        
#last three month return
SHOP_3mon_return=round((((SHOP_data[0]['adjclose']/SHOP_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
SHOP_summ_stats = {
    "Ticker": "SHOP",
  "Annual Return": SHOP_ann_return,
  "Daily Volatility": SHOP_daily_vol,
  "Annualized Volatility": SHOP_ann_vol,
  "Last 3 Months Return":  SHOP_3mon_return
}

# convert into JSON:
SHOP_summ_stats = json.dumps(SHOP_summ_stats)

# the result is a JSON string:
print(SHOP_summ_stats)
# Out:
# {"Ticker": "SHOP", "Annual Return": 42.07, "Daily Volatility": 187.12, "Annualized Volatility": 2970.44, "Last 3 Months Return": 18.51}

# %% [markdown]
# # TSLA Stock Calculations

# %%
with open('../Data/TSLA_prices.json') as json_file:
    TSLA_data = json.load(json_file)
    
#stock annual return
TSLA_ann_return=round((((TSLA_data[0]['adjclose']/TSLA_data[len(TSLA_data)-1]['adjclose'])-1)*100),2)

TSLA_price_array=[]
for i in range(len(TSLA_data)):
    TSLA_price_array.append(TSLA_data[i]['adjclose'])
    
#daily volatility
TSLA_daily_vol = round(np.std(TSLA_price_array),2)

#annualized volatility
TSLA_ann_vol = TSLA_daily_vol * math.sqrt(252)
TSLA_ann_vol = round(TSLA_ann_vol,2)

#3 mon return volatility
TSLA_date_array=[]

for y in range(len(TSLA_data)):
    TSLA_date_array.append(datetime.strptime(TSLA_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=TSLA_date_array[y]
    if ((firstdate-TSLA_date_array[y]).days==91):
        date_3mon_ago=TSLA_date_array[y]
        mon3_index = y
        
#last three month return
TSLA_3mon_return=round((((TSLA_data[0]['adjclose']/TSLA_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
TSLA_summ_stats = {
    "Ticker": "TSLA",
  "Annual Return": TSLA_ann_return,
  "Daily Volatility": TSLA_daily_vol,
  "Annualized Volatility": TSLA_ann_vol,
  "Last 3 Months Return":  TSLA_3mon_return
}

# convert into JSON:
TSLA_summ_stats = json.dumps(TSLA_summ_stats)

# the result is a JSON string:
print(TSLA_summ_stats)
# Out:
# {"Ticker": "TSLA", "Annual Return": 65.92, "Daily Volatility": 134.14, "Annualized Volatility": 2129.41, "Last 3 Months Return": 17.11}

# %% [markdown]
# # GOLD Stock Calculations

# %%
with open('../Data/GOLD_prices.json') as json_file:
    GOLD_data = json.load(json_file)
    
#stock annual return
GOLD_ann_return=round((((GOLD_data[0]['adjclose']/GOLD_data[len(GOLD_data)-1]['adjclose'])-1)*100),2)

GOLD_price_array=[]
for i in range(len(GOLD_data)):
    GOLD_price_array.append(GOLD_data[i]['adjclose'])
    
#daily volatility
GOLD_daily_vol = round(np.std(GOLD_price_array),2)

#annualized volatility
GOLD_ann_vol = GOLD_daily_vol * math.sqrt(252)
GOLD_ann_vol = round(GOLD_ann_vol,2)

#3 mon return volatility
GOLD_date_array=[]

for y in range(len(GOLD_data)):
    GOLD_date_array.append(datetime.strptime(GOLD_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=GOLD_date_array[y]
    if ((firstdate-GOLD_date_array[y]).days==91):
        date_3mon_ago=GOLD_date_array[y]
        mon3_index = y
        
#last three month return
GOLD_3mon_return=round((((GOLD_data[0]['adjclose']/GOLD_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
GOLD_summ_stats = {
    "Ticker": "GOLD",
  "Annual Return": GOLD_ann_return,
  "Daily Volatility": GOLD_daily_vol,
  "Annualized Volatility": GOLD_ann_vol,
  "Last 3 Months Return":  GOLD_3mon_return
}

# convert into JSON:
GOLD_summ_stats = json.dumps(GOLD_summ_stats)

# the result is a JSON string:
print(GOLD_summ_stats)
# Out:
# {"Ticker": "GOLD", "Annual Return": -33.02, "Daily Volatility": 2.83, "Annualized Volatility": 44.92, "Last 3 Months Return": -21.41}

# %% [markdown]
# # DAL Stock Calculations

# %%
with open('../Data/DAL_prices.json') as json_file:
    DAL_data = json.load(json_file)
    
#stock annual return
DAL_ann_return=round((((DAL_data[0]['adjclose']/DAL_data[len(DAL_data)-1]['adjclose'])-1)*100),2)

DAL_price_array=[]
for i in range(len(DAL_data)):
    DAL_price_array.append(DAL_data[i]['adjclose'])
    
#daily volatility
DAL_daily_vol = round(np.std(DAL_price_array),2)

#annualized volatility
DAL_ann_vol = DAL_daily_vol * math.sqrt(252)
DAL_ann_vol = round(DAL_ann_vol,2)

#3 mon return volatility
DAL_date_array=[]

for y in range(len(DAL_data)):
    DAL_date_array.append(datetime.strptime(DAL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=DAL_date_array[y]
    if ((firstdate-DAL_date_array[y]).days==91):
        date_3mon_ago=DAL_date_array[y]
        mon3_index = y
        
#last three month return
DAL_3mon_return=round((((DAL_data[0]['adjclose']/DAL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
DAL_summ_stats = {
    "Ticker": "DAL",
  "Annual Return": DAL_ann_return,
  "Daily Volatility": DAL_daily_vol,
  "Annualized Volatility": DAL_ann_vol,
  "Last 3 Months Return":  DAL_3mon_return
}

# convert into JSON:
DAL_summ_stats = json.dumps(DAL_summ_stats)

# the result is a JSON string:
print(DAL_summ_stats)
# Out:
# {"Ticker": "DAL", "Annual Return": 39.79, "Daily Volatility": 6.0, "Annualized Volatility": 95.25, "Last 3 Months Return": -15.68}

# %% [markdown]
# # NFLX Stock Calculations

# %%
with open('../Data/NFLX_prices.json') as json_file:
    NFLX_data = json.load(json_file)
    
#stock annual return
NFLX_ann_return=round((((NFLX_data[0]['adjclose']/NFLX_data[len(NFLX_data)-1]['adjclose'])-1)*100),2)

NFLX_price_array=[]
for i in range(len(NFLX_data)):
    NFLX_price_array.append(NFLX_data[i]['adjclose'])
    
#daily volatility
NFLX_daily_vol = round(np.std(NFLX_price_array),2)

#annualized volatility
NFLX_ann_vol = NFLX_daily_vol * math.sqrt(252)
NFLX_ann_vol = round(NFLX_ann_vol,2)

#3 mon return volatility
NFLX_date_array=[]

for y in range(len(NFLX_data)):
    NFLX_date_array.append(datetime.strptime(NFLX_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=NFLX_date_array[y]
    if ((firstdate-NFLX_date_array[y]).days==91):
        date_3mon_ago=NFLX_date_array[y]
        mon3_index = y
        
#last three month return
NFLX_3mon_return=round((((NFLX_data[0]['adjclose']/NFLX_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
NFLX_summ_stats = {
    "Ticker": "NFLX",
  "Annual Return": NFLX_ann_return,
  "Daily Volatility": NFLX_daily_vol,
  "Annualized Volatility": NFLX_ann_vol,
  "Last 3 Months Return":  NFLX_3mon_return
}

# convert into JSON:
NFLX_summ_stats = json.dumps(NFLX_summ_stats)

# the result is a JSON string:
print(NFLX_summ_stats)
# Out:
# {"Ticker": "NFLX", "Annual Return": 11.08, "Daily Volatility": 23.71, "Annualized Volatility": 376.38, "Last 3 Months Return": 9.84}

# %% [markdown]
# # AAPL Stock Calculations

# %%
with open('../Data/AAPL_prices.json') as json_file:
    AAPL_data = json.load(json_file)
    
#stock annual return
AAPL_ann_return=round((((AAPL_data[0]['adjclose']/AAPL_data[len(AAPL_data)-1]['adjclose'])-1)*100),2)

AAPL_price_array=[]
for i in range(len(AAPL_data)):
    AAPL_price_array.append(AAPL_data[i]['adjclose'])
    
#daily volatility
AAPL_daily_vol = round(np.std(AAPL_price_array),2)

#annualized volatility
AAPL_ann_vol = AAPL_daily_vol * math.sqrt(252)
AAPL_ann_vol = round(AAPL_ann_vol,2)

#3 mon return volatility
AAPL_date_array=[]

for y in range(len(AAPL_data)):
    AAPL_date_array.append(datetime.strptime(AAPL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=AAPL_date_array[y]
    if ((firstdate-AAPL_date_array[y]).days==91):
        date_3mon_ago=AAPL_date_array[y]
        mon3_index = y
        
#last three month return
AAPL_3mon_return=round((((AAPL_data[0]['adjclose']/AAPL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
AAPL_summ_stats = {
    "Ticker": "AAPL",
  "Annual Return": AAPL_ann_return,
  "Daily Volatility": AAPL_daily_vol,
  "Annualized Volatility": AAPL_ann_vol,
  "Last 3 Months Return":  AAPL_3mon_return
}

# convert into JSON:
AAPL_summ_stats = json.dumps(AAPL_summ_stats)

# the result is a JSON string:
print(AAPL_summ_stats)
# Out:
# {"Ticker": "AAPL", "Annual Return": 19.91, "Daily Volatility": 10.44, "Annualized Volatility": 165.73, "Last 3 Months Return": 18.32}

# %% [markdown]
# # PFE Stock Calculations

# %%
with open('../Data/PFE_prices.json') as json_file:
    PFE_data = json.load(json_file)
    
#stock annual return
PFE_ann_return=round((((PFE_data[0]['adjclose']/PFE_data[len(PFE_data)-1]['adjclose'])-1)*100),2)

PFE_price_array=[]
for i in range(len(PFE_data)):
    PFE_price_array.append(PFE_data[i]['adjclose'])
    
#daily volatility
PFE_daily_vol = round(np.std(PFE_price_array),2)

#annualized volatility
PFE_ann_vol = PFE_daily_vol * math.sqrt(252)
PFE_ann_vol = round(PFE_ann_vol,2)

#3 mon return volatility
PFE_date_array=[]

for y in range(len(PFE_data)):
    PFE_date_array.append(datetime.strptime(PFE_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=PFE_date_array[y]
    if ((firstdate-PFE_date_array[y]).days==91):
        date_3mon_ago=PFE_date_array[y]
        mon3_index = y
        
#last three month return
PFE_3mon_return=round((((PFE_data[0]['adjclose']/PFE_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
PFE_summ_stats = {
    "Ticker": "PFE",
  "Annual Return": PFE_ann_return,
  "Daily Volatility": PFE_daily_vol,
  "Annualized Volatility": PFE_ann_vol,
  "Last 3 Months Return":  PFE_3mon_return
}

# convert into JSON:
PFE_summ_stats = json.dumps(PFE_summ_stats)

# the result is a JSON string:
print(PFE_summ_stats)
# Out:
# {"Ticker": "PFE", "Annual Return": 37.43, "Daily Volatility": 3.6, "Annualized Volatility": 57.15, "Last 3 Months Return": 23.06}

# %% [markdown]
# # BTC Stock Calculations

# %%
with open('../Data/BTC_prices.json') as json_file:
    BTC_data = json.load(json_file)
    
#stock annual return
BTC_ann_return=round((((BTC_data[0]['adjclose']/BTC_data[len(BTC_data)-1]['adjclose'])-1)*100),2)

BTC_price_array=[]
for i in range(len(BTC_data)):
    BTC_price_array.append(BTC_data[i]['adjclose'])
    
#daily volatility
BTC_daily_vol = round(np.std(BTC_price_array),2)

#annualized volatility
BTC_ann_vol = BTC_daily_vol * math.sqrt(252)
BTC_ann_vol = round(BTC_ann_vol,2)

#3 mon return volatility
BTC_date_array=[]

for y in range(len(BTC_data)):
    BTC_date_array.append(datetime.strptime(BTC_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=BTC_date_array[y]
    if ((firstdate-BTC_date_array[y]).days==91):
        date_3mon_ago=BTC_date_array[y]
        mon3_index = y
        
#last three month return
BTC_3mon_return=round((((BTC_data[0]['adjclose']/BTC_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
BTC_summ_stats = {
    "Ticker": "BTC",
  "Annual Return": BTC_ann_return,
  "Daily Volatility": BTC_daily_vol,
  "Annualized Volatility": BTC_ann_vol,
  "Last 3 Months Return":  BTC_3mon_return
}

# convert into JSON:
BTC_summ_stats = json.dumps(BTC_summ_stats)

# the result is a JSON string:
print(BTC_summ_stats)
# Out:
# {"Ticker": "BTC", "Annual Return": -0.39, "Daily Volatility": 0.47, "Annualized Volatility": 7.46, "Last 3 Months Return": 0.5}

# %% [markdown]
# # Creating a Dataframe of values

# %%
shop_df = pd.DataFrame(json.loads(SHOP_summ_stats), index=[0])
tsla_df = pd.DataFrame(json.loads(TSLA_summ_stats), index=[0])
gold_df = pd.DataFrame(json.loads(GOLD_summ_stats), index=[0])
dal_df = pd.DataFrame(json.loads(DAL_summ_stats), index=[0])
nflx_df = pd.DataFrame(json.loads(NFLX_summ_stats), index=[0])
aapl_df = pd.DataFrame(json.loads(AAPL_summ_stats), index=[0])
pfe_df = pd.DataFrame(json.loads(PFE_summ_stats), index=[0])
btc_df = pd.DataFrame(json.loads(BTC_summ_stats), index=[0])


stocks_calc = shop_df.append([tsla_df,gold_df,dal_df,nflx_df,aapl_df,pfe_df,btc_df])
stocks_calc.reset_index(inplace = True,drop = True)

stocks_calc
# Out:
#   Ticker  Annual Return  Daily Volatility  Annualized Volatility  \
# 0   SHOP          42.07            187.12                2970.44
# 1   TSLA          65.92            134.14                2129.41
# 2   GOLD         -33.02              2.83                  44.92
# 3    DAL          39.79              6.00                  95.25
# 4   NFLX          11.08             23.71                 376.38
# 5   AAPL          19.91             10.44                 165.73
# 6    PFE          37.43              3.60                  57.15
# 7    BTC          -0.39              0.47                   7.46
#
#    Last 3 Months Return
# 0                 18.51
# 1                 17.11
# 2                -21.41
# 3                -15.68
# 4                  9.84
# 5                 18.32
# 6                 23.06
# 7                  0.50

# %% [markdown]
# # Get daily returns and asssets covariance

# %%
#created dataframes for daily prices
SHOP_data_df = pd.DataFrame(SHOP_data)
SHOP_data_df = SHOP_data_df[["formatted_date", "adjclose"]]
SHOP_data_df.set_index("formatted_date", inplace = True)
SHOP_data_df = SHOP_data_df.rename (columns = {"adjclose": "SHOP"})

TSLA_data_df = pd.DataFrame(TSLA_data)
TSLA_data_df = TSLA_data_df[["formatted_date", "adjclose"]]
TSLA_data_df.set_index("formatted_date", inplace = True)
TSLA_data_df = TSLA_data_df.rename (columns = {"adjclose": "TSLA"})

GOLD_data_df = pd.DataFrame(GOLD_data)
GOLD_data_df = GOLD_data_df[["formatted_date", "adjclose"]]
GOLD_data_df.set_index("formatted_date", inplace = True)
GOLD_data_df = GOLD_data_df.rename (columns = {"adjclose": "GOLD"})

DAL_data_df = pd.DataFrame(DAL_data)
DAL_data_df = DAL_data_df[["formatted_date", "adjclose"]]
DAL_data_df.set_index("formatted_date", inplace = True)
DAL_data_df = DAL_data_df.rename (columns = {"adjclose": "DAL"})

NFLX_data_df = pd.DataFrame(NFLX_data)
NFLX_data_df = NFLX_data_df[["formatted_date", "adjclose"]]
NFLX_data_df.set_index("formatted_date", inplace = True)
NFLX_data_df = NFLX_data_df.rename (columns = {"adjclose": "NFLX"})

AAPL_data_df = pd.DataFrame(AAPL_data)
AAPL_data_df = AAPL_data_df[["formatted_date", "adjclose"]]
AAPL_data_df.set_index("formatted_date", inplace = True)
AAPL_data_df = AAPL_data_df.rename (columns = {"adjclose": "AAPL"})

PFE_data_df = pd.DataFrame(PFE_data)
PFE_data_df = PFE_data_df[["formatted_date", "adjclose"]]
PFE_data_df.set_index("formatted_date", inplace = True)
PFE_data_df = PFE_data_df.rename (columns = {"adjclose": "PFE"})

BTC_data_df = pd.DataFrame(BTC_data)
BTC_data_df = BTC_data_df[["formatted_date", "adjclose"]]
BTC_data_df.set_index("formatted_date", inplace = True)
BTC_data_df = BTC_data_df.rename (columns = {"adjclose": "BTC"})
#BTC_data_df

# %%
#merge assest into a single dataframe
assets_all = pd.concat([SHOP_data_df, TSLA_data_df,GOLD_data_df , DAL_data_df, NFLX_data_df, AAPL_data_df,PFE_data_df,BTC_data_df],axis=1, join="inner")
assets_all
# Out:
#                    SHOP    TSLA   GOLD    DAL    NFLX    AAPL    PFE     BTC
# formatted_date
# 2021-08-19      1466.11  673.47  19.13  37.93  543.71  146.70  48.80   99.61
# 2021-08-18      1489.18  688.99  19.46  38.65  521.87  146.36  49.31   99.55
# 2021-08-17      1481.87  665.71  19.97  38.78  518.91  150.19  50.42   99.60
# 2021-08-16      1489.00  686.17  20.19  39.93  517.92  151.12  48.91   99.65
# 2021-08-13      1498.00  717.17  20.27  39.90  515.92  149.10  48.48   99.58
# ...                 ...     ...    ...    ...     ...     ...    ...     ...
# 2020-10-07      1073.43  425.30  26.47  32.15  534.66  114.34  33.25   99.92
# 2020-10-06      1041.25  413.98  26.58  31.06  505.87  112.44  32.98  100.03
# 2020-10-05      1065.53  425.68  27.86  32.00  520.65  115.76  33.50  100.00
# 2020-10-02      1028.99  415.09  27.39  31.75  503.06  112.30  33.17  100.00
# 2020-10-01      1054.43  448.16  27.76  31.10  527.51  116.04  33.16  100.00
#
# [223 rows x 8 columns]

# %%
#calculate daily pricec changes
assets_all_pricechng = assets_all.pct_change()
#assets_all_pricechng

# %%
#calculate covariance
assets_all_cov = assets_all_pricechng.cov()
assets_all_cov
# Out:
#           SHOP      TSLA      GOLD       DAL      NFLX      AAPL  \
# SHOP  0.001044  0.000428  0.000132 -0.000113  0.000343  0.000245
# TSLA  0.000428  0.001229  0.000096  0.000143  0.000249  0.000263
# GOLD  0.000132  0.000096  0.000409  0.000015  0.000102  0.000101
# DAL  -0.000113  0.000143  0.000015  0.000634 -0.000046  0.000030
# NFLX  0.000343  0.000249  0.000102 -0.000046  0.000504  0.000189
# AAPL  0.000245  0.000263  0.000101  0.000030  0.000189  0.000327
# PFE  -0.000036 -0.000003  0.000026  0.000062 -0.000039  0.000026
# BTC   0.000009  0.000008  0.000003 -0.000005  0.000005  0.000004
#
#                PFE           BTC
# SHOP -3.579589e-05  9.423874e-06
# TSLA -2.910476e-06  7.966360e-06
# GOLD  2.627074e-05  3.028141e-06
# DAL   6.154588e-05 -4.739645e-06
# NFLX -3.868208e-05  5.046523e-06
# AAPL  2.644448e-05  4.075365e-06
# PFE   2.206190e-04 -1.272857e-07
# BTC  -1.272857e-07  9.158551e-07

# %%
# convert into JSON:
assets_all_json = assets_all_cov.to_json()
assets_all_json = json.dumps(assets_all_json)

# %% [markdown]
# # Calculate portfolio return and volatility

# %% [markdown]
# ref: https://www.machinelearningplus.com/machine-learning/portfolio-optimization-python-example/

# %%
portfolio_return = []
portfolio_volati = []
asset_weights = []

# %%
#calculate number of assest and max number of portfolios to itterate
num_assets = stocks_calc["Ticker"].count()
print(num_assets)
num_portf = 1000
# Out:
# 8

# %% [markdown]
# for portfolio in range(num_portf):
#     #portfolio returns
#     weights = np.random.random(num_assets)
#     weights = weights/np.sum(weights)
#     asset_weights.append(weights)
# asset_weights

# %% [markdown]
# len(asset_weights)

# %%
for portfolio in range(num_portf):
    #portfolio returns
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    asset_weights.append(weights)
    portf_return = np.dot(weights, stocks_calc["Annual Return"])
    portfolio_return.append(portf_return)
    
    #portfolio risk
    portf_var = assets_all_cov.mul(weights, axis=0).mul(weights, axis=1).sum().sum()
    portf_stdev = np.sqrt(portf_var) # Daily standard deviation
    portf_ann_stdev = portf_stdev*np.sqrt(250) # Annual standard deviation = volatility
    portfolio_volati.append(portf_ann_stdev)
    
    
#portfolio_return

# %%
print(len(portfolio_return), len(portfolio_volati), len(asset_weights))
# Out:
# 1000 1000 1000

# %% [markdown]
# #plot the graph
# plt.figure(figsize=(12,8))
# plt.scatter(portfolio_volati,portfolio_return, marker = "o",facecolors = 'green')
# plt.title(f"Efficient Frontier", fontsize = 13, fontweight = 'bold', y=1.05)
# plt.xlabel("Risk")
# plt.ylabel("Return")
# plt.grid()
# plt.ylim(-20,60)
# plt.xlim(0.05,0.4)
#
# plt.show()

# %%
data = {'Returns':portfolio_return, 'Volatility':portfolio_volati}

for counter, symbol in enumerate(assets_all.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in asset_weights]
    
portfolios  = pd.DataFrame(data)
portf = portfolios.to_dict(orient='records')
portf
# Out:
# [{'Returns': 26.160450824882904,
#   'Volatility': 0.21828089876911982,
#   'SHOP weight': 0.06536601361405572,
#   'TSLA weight': 0.096726648925057,
#   'GOLD weight': 0.053761882140969865,
#   'DAL weight': 0.2679694584315692,
#   'NFLX weight': 0.27123087241102223,
#   'AAPL weight': 0.20501621253437927,
#   'PFE weight': 0.028436170018155432,
#   'BTC weight': 0.011492741924791177},
#  {'Returns': 22.950931632756355,
#   'Volatility': 0.1911225002726121,
#   'SHOP weight': 0.06129677596705047,
#   'TSLA weight': 0.15346863167104455,
#   'GOLD weight': 0.0908890374776214,
#   'DAL weight': 0.20257450471984473,
#   'NFLX weight': 0.21419396296846455,
#   'AAPL weight': 0.06073831434198207,
#   'PFE weight': 0.04490319185482104,
#   'BTC weight': 0.17193558099917114},
#  {'Returns': 20.16019196915421,
#   'Volatility': 0.1668181317841796,
#   'SHOP weight': 0.031605815141043006,
#   'TSLA weight': 0.14149445579231007,
#   'GOLD weight': 0.16467041691654524,
#   'DAL weight': 0.11205281450819568,
#   'NFLX weight': 0.0331197100662315,
#   'AAPL weight': 0.179108251310606,
#   'PFE weight': 0.17664845943046098,
#   'BTC weight': 0.1613000768346075},
#  {'Returns': 20.715572242334794,
#   'Volatility': 0.19458417473740108,
#   'SHOP weight': 0.06012429978660469,
#   'TSLA weight': 0.20612369633417624,
#   'GOLD weight': 0.17348667779379853,
#   'DAL weight': 0.12643240403102368,
#   'NFLX weight': 0.08231344035120067,
#   'AAPL weight': 0.10567873219169059,
#   'PFE weight': 0.06282482939190534,
#   'BTC weight': 0.18301592011960024},
#  {'Returns': 11.197541151324367,
#   'Volatility': 0.20996044479487502,
#   'SHOP weight': 0.18400962439580054,
#   'TSLA weight': 0.005124662598108805,
#   'GOLD weight': 0.22640511352103931,
#   'DAL weight': 0.05370526503666326,
#   'NFLX weight': 0.22309310287839093,
#   'AAPL weight': 0.15608713656265963,
#   'PFE weight': 0.07765601970860207,
#   'BTC weight': 0.07391907529873541},
#  {'Returns': 32.5548208694855,
#   'Volatility': 0.19833497149761495,
#   'SHOP weight': 0.1520000207096021,
#   'TSLA weight': 0.12942021197148662,
#   'GOLD weight': 0.0006742994107469324,
#   'DAL weight': 0.1641233302827578,
#   'NFLX weight': 0.11689868823453388,
#   'AAPL weight': 0.17674622581728483,
#   'PFE weight': 0.16942877776829723,
#   'BTC weight': 0.09070844580529058},
#  {'Returns': 13.446149661268484,
#   'Volatility': 0.18705352344122725,
#   'SHOP weight': 0.19178931408003239,
#   'TSLA weight': 0.010964737254034173,
#   'GOLD weight': 0.18990625103299116,
#   'DAL weight': 0.08117103379261348,
#   'NFLX weight': 0.20463311162442033,
#   'AAPL weight': 0.06142195765174033,
#   'PFE weight': 0.11387850240275416,
#   'BTC weight': 0.14623509216141406},
#  {'Returns': 28.81691040879895,
#   'Volatility': 0.18440029568616248,
#   'SHOP weight': 0.1405680026019822,
#   'TSLA weight': 0.13759102944607973,
#   'GOLD weight': 0.06017250617539556,
#   'DAL weight': 0.1632863127534172,
#   'NFLX weight': 0.16662789771747258,
#   'AAPL weight': 0.006553649180216308,
#   'PFE weight': 0.1975953363469671,
#   'BTC weight': 0.12760526577846928},
#  {'Returns': 26.142448616699923,
#   'Volatility': 0.2152562060925414,
#   'SHOP weight': 0.053041351942250625,
#   'TSLA weight': 0.21286623874306337,
#   'GOLD weight': 0.08845538171991012,
#   'DAL weight': 0.20234177307661652,
#   'NFLX weight': 0.20626984948322882,
#   'AAPL weight': 0.07610803854392172,
#   'PFE weight': 0.02671736725191432,
#   'BTC weight': 0.13419999923909456},
#  {'Returns': 11.609334848634044,
#   'Volatility': 0.18641656098977366,
#   'SHOP weight': 0.013818827288219763,
#   'TSLA weight': 0.01963769327848706,
#   'GOLD weight': 0.31158343734022736,
#   'DAL weight': 0.28183410617014043,
#   'NFLX weight': 0.18462987138988585,
#   'AAPL weight': 0.008562921883241006,
#   'PFE weight': 0.17614366039406,
#   'BTC weight': 0.0037894822557384892},
#  {'Returns': 23.322154157705693,
#   'Volatility': 0.17524938412989957,
#   'SHOP weight': 0.048545825626806115,
#   'TSLA weight': 0.16296824593922415,
#   'GOLD weight': 0.08989838370073651,
#   'DAL weight': 0.05085859051888654,
#   'NFLX weight': 0.14414049711878565,
#   'AAPL weight': 0.13641754825679883,
#   'PFE weight': 0.1933313689820792,
#   'BTC weight': 0.17383953985668307},
#  {'Returns': 17.372595152018512,
#   'Volatility': 0.15668803922848415,
#   'SHOP weight': 0.019600796033657383,
#   'TSLA weight': 0.11814103027314617,
#   'GOLD weight': 0.19987158571605845,
#   'DAL weight': 0.09985337445171558,
#   'NFLX weight': 0.02217622363408373,
#   'AAPL weight': 0.1546052730600063,
#   'PFE weight': 0.21716728089003393,
#   'BTC weight': 0.16858443594129835},
#  {'Returns': 25.047842838124904,
#   'Volatility': 0.1998013940853861,
#   'SHOP weight': 0.1621317207421865,
#   'TSLA weight': 0.14714938006814948,
#   'GOLD weight': 0.13022650322950163,
#   'DAL weight': 0.1266428603797401,
#   'NFLX weight': 0.14997699223632907,
#   'AAPL weight': 0.0427037611401964,
#   'PFE weight': 0.14198606032037756,
#   'BTC weight': 0.09918272188351934},
#  {'Returns': 23.924464824204566,
#   'Volatility': 0.16818205638396616,
#   'SHOP weight': 0.18021202961283223,
#   'TSLA weight': 0.04333760840143215,
#   'GOLD weight': 0.09037545066557183,
#   'DAL weight': 0.17838542098821691,
#   'NFLX weight': 0.06470238866157092,
#   'AAPL weight': 0.12296129218702792,
#   'PFE weight': 0.16742779863328705,
#   'BTC weight': 0.15259801085006103},
#  {'Returns': 21.282015870956485,
#   'Volatility': 0.21627573832894334,
#   'SHOP weight': 0.08949891471242724,
#   'TSLA weight': 0.15002258439985214,
#   'GOLD weight': 0.17666062734809726,
#   'DAL weight': 0.13116420158326242,
#   'NFLX weight': 0.16308748407030862,
#   'AAPL weight': 0.20773064155875628,
#   'PFE weight': 0.061623679681024994,
#   'BTC weight': 0.02021186664627116},
#  {'Returns': 24.0267547192136,
#   'Volatility': 0.18310340677592934,
#   'SHOP weight': 0.020269208515564366,
#   'TSLA weight': 0.1498954850548156,
#   'GOLD weight': 0.056285248229088945,
#   'DAL weight': 0.18351898460073995,
#   'NFLX weight': 0.09126481051559805,
#   'AAPL weight': 0.2496792158761064,
#   'PFE weight': 0.051931620867701846,
#   'BTC weight': 0.19715542634038483},
#  {'Returns': 23.1606490715982,
#   'Volatility': 0.23197745101200273,
#   'SHOP weight': 0.1938042924350189,
#   'TSLA weight': 0.15071820735462854,
#   'GOLD weight': 0.1413928291042002,
#   'DAL weight': 0.07342857991927812,
#   'NFLX weight': 0.13522157084198363,
#   'AAPL weight': 0.18349815751387477,
#   'PFE weight': 0.04534315554061677,
#   'BTC weight': 0.0765932072903991},
#  {'Returns': 9.148796112770643,
#   'Volatility': 0.17439594872401187,
#   'SHOP weight': 0.10047835523505114,
#   'TSLA weight': 0.01904111620826263,
#   'GOLD weight': 0.19195828178708824,
#   'DAL weight': 0.08367895139159867,
#   'NFLX weight': 0.23439157498607802,
#   'AAPL weight': 0.1266807938354384,
#   'PFE weight': 0.04365826868241721,
#   'BTC weight': 0.2001126578740656},
#  {'Returns': 27.35655592328629,
#   'Volatility': 0.18244784543058595,
#   'SHOP weight': 0.09494033827257053,
#   'TSLA weight': 0.18938013688188493,
#   'GOLD weight': 0.04467427226216784,
#   'DAL weight': 0.00953637927383639,
#   'NFLX weight': 0.060936830057213884,
#   'AAPL weight': 0.1569473121186745,
#   'PFE weight': 0.22070772584668458,
#   'BTC weight': 0.2228770052869675},
#  {'Returns': 19.34486582431773,
#   'Volatility': 0.17226833764199623,
#   'SHOP weight': 0.08668858805046793,
#   'TSLA weight': 0.026781711161138956,
#   'GOLD weight': 0.19458374887649635,
#   'DAL weight': 0.21829257105911495,
#   'NFLX weight': 0.11984621811198866,
#   'AAPL weight': 0.12353772760484054,
#   'PFE weight': 0.21084064878799041,
#   'BTC weight': 0.019428786347962163},
#  {'Returns': 37.52685919737439,
#   'Volatility': 0.2201640755428277,
#   'SHOP weight': 0.048393771652107315,
#   'TSLA weight': 0.24427680357763526,
#   'GOLD weight': 0.004540180343118507,
#   'DAL weight': 0.13132948972545674,
#   'NFLX weight': 0.06439722974765372,
#   'AAPL weight': 0.23056872063532136,
#   'PFE weight': 0.24104206084392943,
#   'BTC weight': 0.0354517434747776},
#  {'Returns': 27.150767781466826,
#   'Volatility': 0.22453081308444872,
#   'SHOP weight': 0.046548883706061965,
#   'TSLA weight': 0.27522506752115766,
#   'GOLD weight': 0.17633977690022537,
#   'DAL weight': 0.0922975740162889,
#   'NFLX weight': 0.06405542078328645,
#   'AAPL weight': 0.12909436817536193,
#   'PFE weight': 0.1587585139586248,
#   'BTC weight': 0.05768039493899298},
#  {'Returns': 35.142420440335144,
#   'Volatility': 0.20576476050977616,
#   'SHOP weight': 0.19917234628343045,
#   'TSLA weight': 0.17923394998018313,
#   'GOLD weight': 0.0009885098812526607,
#   'DAL weight': 0.13973929569794236,
#   'NFLX weight': 0.10252489061679568,
#   'AAPL weight': 0.03193974717447726,
#   'PFE weight': 0.2058104761295654,
#   'BTC weight': 0.14059078423635313},
#  {'Returns': 35.534462754126665,
#   'Volatility': 0.2160180130626627,
#   'SHOP weight': 0.1928917216672017,
#   'TSLA weight': 0.19778919788562355,
#   'GOLD weight': 0.04341122982080009,
#   'DAL weight': 0.1944869767918982,
#   'NFLX weight': 0.008408647225772331,
#   'AAPL weight': 0.09731584555773438,
#   'PFE weight': 0.16258438374918574,
#   'BTC weight': 0.10311199730178408},
#  {'Returns': 16.140935570903032,
#   'Volatility': 0.2201215644819726,
#   'SHOP weight': 0.20540062737451464,
#   'TSLA weight': 0.158732382151535,
#   'GOLD weight': 0.20748921967727227,
#   'DAL weight': 0.028694296911915978,
#   'NFLX weight': 0.11593566561267493,
#   'AAPL weight': 0.05586781070702277,
#   'PFE weight': 0.011571084567200398,
#   'BTC weight': 0.21630891299786398},
#  {'Returns': 19.709833807300726,
#   'Volatility': 0.20393926206971438,
#   'SHOP weight': 0.1408207147257719,
#   'TSLA weight': 0.13631993262161007,
#   'GOLD weight': 0.1856146146200774,
#   'DAL weight': 0.06312126813071654,
#   'NFLX weight': 0.0957975479640887,
#   'AAPL weight': 0.17986720133692916,
#   'PFE weight': 0.10183769929081606,
#   'BTC weight': 0.09662102130999008},
#  {'Returns': 26.25454536798636,
#   'Volatility': 0.24676457204803517,
#   'SHOP weight': 0.18122145850463886,
#   'TSLA weight': 0.22561469164997827,
#   'GOLD weight': 0.23311706111368338,
#   'DAL weight': 0.18993631916576417,
#   'NFLX weight': 0.020629457636754448,
#   'AAPL weight': 0.10488599168778642,
#   'PFE weight': 0.04226692031392874,
#   'BTC weight': 0.0023280999274657623},
#  {'Returns': 24.154140432686972,
#   'Volatility': 0.1920939270476969,
#   'SHOP weight': 0.17887897840234102,
#   'TSLA weight': 0.05905349552638846,
#   'GOLD weight': 0.1580018772972894,
#   'DAL weight': 0.1893355767128318,
#   'NFLX weight': 0.08913012475596543,
#   'AAPL weight': 0.13645551578824924,
#   'PFE weight': 0.1795037018457255,
#   'BTC weight': 0.009640729671209282},
#  {'Returns': 20.915584013714835,
#   'Volatility': 0.17387508725574402,
#   'SHOP weight': 0.2158221389655956,
#   'TSLA weight': 0.014356943610201197,
#   'GOLD weight': 0.10398485740386666,
#   'DAL weight': 0.25237326111544733,
#   'NFLX weight': 0.09091567564107876,
#   'AAPL weight': 0.039497247610423926,
#   'PFE weight': 0.06868953997403274,
#   'BTC weight': 0.2143603356793538},
#  {'Returns': 22.85818854232014,
#   'Volatility': 0.19040701432084225,
#   'SHOP weight': 0.039656280507345404,
#   'TSLA weight': 0.1800181913600319,
#   'GOLD weight': 0.12385857808566178,
#   'DAL weight': 0.10883952840630094,
#   'NFLX weight': 0.14042626243495954,
#   'AAPL weight': 0.15614352143203816,
#   'PFE weight': 0.11938939818257938,
#   'BTC weight': 0.13166823959108284},
#  {'Returns': 22.335213704323287,
#   'Volatility': 0.22151554459784673,
#   'SHOP weight': 0.08820328107540149,
#   'TSLA weight': 0.2213661672025514,
#   'GOLD weight': 0.14410749363409808,
#   'DAL weight': 0.04987256960995925,
#   'NFLX weight': 0.18900584117986144,
#   'AAPL weight': 0.10832218450735756,
#   'PFE weight': 0.06961454704338048,
#   'BTC weight': 0.1295079157473904},
#  {'Returns': 14.54921912803669,
#   'Volatility': 0.18972187222801168,
#   'SHOP weight': 0.10941137871080933,
#   'TSLA weight': 0.04787558092152402,
#   'GOLD weight': 0.23567432479241193,
#   'DAL weight': 0.21379602337057874,
#   'NFLX weight': 0.2207279536845909,
#   'AAPL weight': 0.0377637836834141,
#   'PFE weight': 0.07721726013962069,
#   'BTC weight': 0.057533694697050275},
#  {'Returns': 20.498699738702637,
#   'Volatility': 0.1808604978481775,
#   'SHOP weight': 0.047841506971665226,
#   'TSLA weight': 0.1518880784365104,
#   'GOLD weight': 0.1635494193188024,
#   'DAL weight': 0.18741758896923183,
#   'NFLX weight': 0.15854446648010515,
#   'AAPL weight': 0.043107773445663855,
#   'PFE weight': 0.10307342325953821,
#   'BTC weight': 0.14457774311848293},
#  {'Returns': 9.60227098047563,
#   'Volatility': 0.1756413403285838,
#   'SHOP weight': 0.05005579650926226,
#   'TSLA weight': 0.014179611925712907,
#   'GOLD weight': 0.1113515771713838,
#   'DAL weight': 0.10692830865973128,
#   'NFLX weight': 0.3627460117699593,
#   'AAPL weight': 0.0839421898389136,
#   'PFE weight': 0.01054868075941834,
#   'BTC weight': 0.26024782336561847},
#  {'Returns': 22.939717296988302,
#   'Volatility': 0.26038372718221414,
#   'SHOP weight': 0.23303307467147838,
#   'TSLA weight': 0.2162997026958273,
#   'GOLD weight': 0.1845973711884744,
#   'DAL weight': 0.012273931515677421,
#   'NFLX weight': 0.15459617860547892,
#   'AAPL weight': 0.06023607282757876,
#   'PFE weight': 0.043007267775048395,
#   'BTC weight': 0.09595640072043651},
#  {'Returns': 25.531680592151147,
#   'Volatility': 0.19961539423228436,
#   'SHOP weight': 0.06543110946024823,
#   'TSLA weight': 0.23739709767078357,
#   'GOLD weight': 0.12590044263703737,
#   'DAL weight': 0.20176819013574426,
#   'NFLX weight': 0.014495271497246344,
#   'AAPL weight': 0.06756846983008837,
#   'PFE weight': 0.049308804862175114,
#   'BTC weight': 0.2381306139066768},
#  {'Returns': 21.288538263440707,
#   'Volatility': 0.18131565972916855,
#   'SHOP weight': 0.14643218888327286,
#   'TSLA weight': 0.10771381955786627,
#   'GOLD weight': 0.11566960356097185,
#   'DAL weight': 0.0774235194321613,
#   'NFLX weight': 0.13709975741472769,
#   'AAPL weight': 0.11058938079227151,
#   'PFE weight': 0.1365533488724235,
#   'BTC weight': 0.168518381486305},
#  {'Returns': 15.85167932219528,
#   'Volatility': 0.1974883083241828,
#   'SHOP weight': 0.20059594887672733,
#   'TSLA weight': 0.03574222576373085,
#   'GOLD weight': 0.14272365244818802,
#   'DAL weight': 0.10956141858704083,
#   'NFLX weight': 0.13005112058197008,
#   'AAPL weight': 0.19766795958153635,
#   'PFE weight': 0.0027725380876027876,
#   'BTC weight': 0.18088513607320383},
#  {'Returns': 22.54494777728894,
#   'Volatility': 0.1998512035766876,
#   'SHOP weight': 0.0669700952825817,
#   'TSLA weight': 0.11669072726982707,
#   'GOLD weight': 0.10854254733384452,
#   'DAL weight': 0.18204568850157143,
#   'NFLX weight': 0.2398751233516074,
#   'AAPL weight': 0.14949863229217802,
#   'PFE weight': 0.07389193710905193,
#   'BTC weight': 0.062485248859337934},
#  {'Returns': 21.815095460126237,
#   'Volatility': 0.1855271052777411,
#   'SHOP weight': 0.11921553991167318,
#   'TSLA weight': 0.11714263375216655,
#   'GOLD weight': 0.08859377233212444,
#   'DAL weight': 0.05471173746741493,
#   'NFLX weight': 0.14320890640752,
#   'AAPL weight': 0.18278733086618307,
#   'PFE weight': 0.12466377044022073,
#   'BTC weight': 0.16967630882269702},
#  {'Returns': 22.088880856879122,
#   'Volatility': 0.15230045965347405,
#   'SHOP weight': 0.10241921860921775,
#   'TSLA weight': 0.08150972116308261,
#   'GOLD weight': 0.052102381328370674,
#   'DAL weight': 0.17883680399418442,
#   'NFLX weight': 0.07642706649666262,
#   'AAPL weight': 0.14204422033717792,
#   'PFE weight': 0.09200351711011899,
#   'BTC weight': 0.2746570709611851},
#  {'Returns': 13.567980653392599,
#   'Volatility': 0.15626204594195187,
#   'SHOP weight': 0.057076512307787985,
#   'TSLA weight': 0.041470288701028604,
#   'GOLD weight': 0.24997669029987796,
#   'DAL weight': 0.1757171265978083,
#   'NFLX weight': 0.13672851600959296,
#   'AAPL weight': 0.0029819603383588193,
#   'PFE weight': 0.21819758015137705,
#   'BTC weight': 0.11785132559416828},
#  {'Returns': 30.254107292145413,
#   'Volatility': 0.21025086356164097,
#   'SHOP weight': 0.15515202241696807,
#   'TSLA weight': 0.20463135346128508,
#   'GOLD weight': 0.06442640385667582,
#   'DAL weight': 0.0983384895035293,
#   'NFLX weight': 0.05781102561188307,
#   'AAPL weight': 0.1391939439748173,
#   'PFE weight': 0.13615840548486444,
#   'BTC weight': 0.144288355689977},
#  {'Returns': 28.412911312221098,
#   'Volatility': 0.24371114105087693,
#   'SHOP weight': 0.09665761590270083,
#   'TSLA weight': 0.2471130274065828,
#   'GOLD weight': 0.16424424688621342,
#   'DAL weight': 0.26327509484854333,
#   'NFLX weight': 0.09201784981711711,
#   'AAPL weight': 0.09671869156698783,
#   'PFE weight': 0.0019784871055631265,
#   'BTC weight': 0.037994986466291625},
#  {'Returns': 18.77947946273135,
#   'Volatility': 0.1752205100080354,
#   'SHOP weight': 0.12202860530518103,
#   'TSLA weight': 0.06438954048370511,
#   'GOLD weight': 0.21343435187357496,
#   'DAL weight': 0.13108326828010197,
#   'NFLX weight': 0.08505226981741307,
#   'AAPL weight': 0.12331989143292706,
#   'PFE weight': 0.20986166851520313,
#   'BTC weight': 0.05083040429189369},
#  {'Returns': 12.626282164690833,
#   'Volatility': 0.150316643649817,
#   'SHOP weight': 0.0023717976495561707,
#   'TSLA weight': 0.08641515171748547,
#   'GOLD weight': 0.18200017305326377,
#   'DAL weight': 0.12443499170119073,
#   'NFLX weight': 0.1574071948427927,
#   'AAPL weight': 0.1169637095883625,
#   'PFE weight': 0.10429483809592226,
#   'BTC weight': 0.2261121433514265},
#  {'Returns': 23.965546684011343,
#   'Volatility': 0.17490279686625834,
#   'SHOP weight': 0.17151754687675175,
#   'TSLA weight': 0.08020256259253013,
#   'GOLD weight': 0.09541310279633493,
#   'DAL weight': 0.17280934934236955,
#   'NFLX weight': 0.11261083948709118,
#   'AAPL weight': 0.06766163958272402,
#   'PFE weight': 0.1390627179623362,
#   'BTC weight': 0.16072224135986227},
#  {'Returns': 14.006505282142324,
#   'Volatility': 0.1722454429637105,
#   'SHOP weight': 0.04494899538006328,
#   'TSLA weight': 0.03313205344216165,
#   'GOLD weight': 0.24958655133106575,
#   'DAL weight': 0.13785123302006186,
#   'NFLX weight': 0.0784603672546142,
#   'AAPL weight': 0.22842476790021668,
#   'PFE weight': 0.19458402699515773,
#   'BTC weight': 0.03301200467665893},
#  {'Returns': 20.27030623718951,
#   'Volatility': 0.22790678793220998,
#   'SHOP weight': 0.19412730424681404,
#   'TSLA weight': 0.19664804474593253,
#   'GOLD weight': 0.23008623759693025,
#   'DAL weight': 0.002910909628654155,
#   'NFLX weight': 0.028068701081159473,
#   'AAPL weight': 0.1155103081367071,
#   'PFE weight': 0.10845783657058321,
#   'BTC weight': 0.12419065799321927},
#  {'Returns': 28.06790475140414,
#   'Volatility': 0.19279912805738064,
#   'SHOP weight': 0.13446396895109297,
#   'TSLA weight': 0.19012730355009766,
#   'GOLD weight': 0.06572479970630307,
#   'DAL weight': 0.13092005022275893,
#   'NFLX weight': 0.027713624200806756,
#   'AAPL weight': 0.132199053913087,
#   'PFE weight': 0.10639713547808179,
#   'BTC weight': 0.21245406397777195},
#  {'Returns': 21.15544912185365,
#   'Volatility': 0.19601623060814358,
#   'SHOP weight': 0.10798711952688848,
#   'TSLA weight': 0.15293691951654934,
#   'GOLD weight': 0.1289697656476198,
#   'DAL weight': 0.056431374302943274,
#   'NFLX weight': 0.1464582836109536,
#   'AAPL weight': 0.1541688956240733,
#   'PFE weight': 0.10445358627717687,
#   'BTC weight': 0.14859405549379537},
#  {'Returns': 22.8049298609454,
#   'Volatility': 0.18751595063389478,
#   'SHOP weight': 0.1899278137987202,
#   'TSLA weight': 0.14304443690931426,
#   'GOLD weight': 0.16461290435663184,
#   'DAL weight': 0.15667570495537037,
#   'NFLX weight': 0.020841248130486822,
#   'AAPL weight': 0.02103912561384078,
#   'PFE weight': 0.10722538745710135,
#   'BTC weight': 0.19663337877853446},
#  {'Returns': 27.170280261084127,
#   'Volatility': 0.21570094707114917,
#   'SHOP weight': 0.1263989803147491,
#   'TSLA weight': 0.18620188567236282,
#   'GOLD weight': 0.10745778600494475,
#   'DAL weight': 0.20657667101553556,
#   'NFLX weight': 0.01264403369513331,
#   'AAPL weight': 0.2154436478427019,
#   'PFE weight': 0.014116771978651604,
#   'BTC weight': 0.13116022347592082},
#  {'Returns': 22.803352614125966,
#   'Volatility': 0.18586168646375173,
#   'SHOP weight': 0.15184945358771548,
#   'TSLA weight': 0.05923332389362272,
#   'GOLD weight': 0.13077229315420316,
#   'DAL weight': 0.15750837441942173,
#   'NFLX weight': 0.15322392175765728,
#   'AAPL weight': 0.13367277673794747,
#   'PFE weight': 0.16619356950063627,
#   'BTC weight': 0.04754628694879586},
#  {'Returns': 23.280599775841758,
#   'Volatility': 0.19215121660153506,
#   'SHOP weight': 0.15623341502951182,
#   'TSLA weight': 0.07322633281897895,
#   'GOLD weight': 0.05740658124277199,
#   'DAL weight': 0.1742390038870919,
#   'NFLX weight': 0.1441882165072198,
#   'AAPL weight': 0.2019618625179198,
#   'PFE weight': 0.03437016821202821,
#   'BTC weight': 0.1583744197844775},
#  {'Returns': 15.147753562557021,
#   'Volatility': 0.16013647187286184,
#   'SHOP weight': 0.039264996243857354,
#   'TSLA weight': 0.049719398059647736,
#   'GOLD weight': 0.20140634821657455,
#   'DAL weight': 0.19551580233018012,
#   'NFLX weight': 0.21112325908370794,
#   'AAPL weight': 0.003680190565680234,
#   'PFE weight': 0.1796256237761594,
#   'BTC weight': 0.11966438172419258},
#  {'Returns': 27.694292839092142,
#   'Volatility': 0.21831774017732128,
#   'SHOP weight': 0.13396817355338617,
#   'TSLA weight': 0.17811489178473464,
#   'GOLD weight': 0.05484265623097145,
#   'DAL weight': 0.049025523672316176,
#   'NFLX weight': 0.17718622238869522,
#   'AAPL weight': 0.17526403086102849,
#   'PFE weight': 0.1273054005858099,
#   'BTC weight': 0.10429310092305794},
#  {'Returns': 20.70197714207912,
#   'Volatility': 0.15778700211931046,
#   'SHOP weight': 0.01883210837325899,
#   'TSLA weight': 0.006100617731833231,
#   'GOLD weight': 0.09197311849046719,
#   'DAL weight': 0.19277257313932408,
#   'NFLX weight': 0.15969589787515345,
#   'AAPL weight': 0.21424200931471,
#   'PFE weight': 0.23697752481866632,
#   'BTC weight': 0.07940615025658677},
#  {'Returns': 10.148006342113886,
#   'Volatility': 0.12542043729646393,
#   'SHOP weight': 0.031547439126082474,
#   'TSLA weight': 0.04631880717022942,
#   'GOLD weight': 0.190942490123533,
#   'DAL weight': 0.049535242041602326,
#   'NFLX weight': 0.0784368682036714,
#   'AAPL weight': 0.1126201501079782,
#   'PFE weight': 0.18988285233669336,
#   'BTC weight': 0.3007161508902099},
#  {'Returns': 18.63834063084103,
#   'Volatility': 0.20038381255785837,
#   'SHOP weight': 0.050167650680838685,
#   'TSLA weight': 0.1360323892375469,
#   'GOLD weight': 0.14052459146443133,
#   'DAL weight': 0.014096037869780685,
#   'NFLX weight': 0.26129457602312983,
#   'AAPL weight': 0.1540235004867669,
#   'PFE weight': 0.1526474675727346,
#   'BTC weight': 0.0912137866647711},
#  {'Returns': 19.44215040306697,
#   'Volatility': 0.16449255961305315,
#   'SHOP weight': 0.04272690197861095,
#   'TSLA weight': 0.07200769253422226,
#   'GOLD weight': 0.16500265460292848,
#   'DAL weight': 0.19290661432383552,
#   'NFLX weight': 0.18494053265537408,
#   'AAPL weight': 0.053491202511446616,
#   'PFE weight': 0.2027775142446645,
#   'BTC weight': 0.0861468871489176},
#  {'Returns': 22.884449838400965,
#   'Volatility': 0.20601312194804725,
#   'SHOP weight': 0.1243716924357424,
#   'TSLA weight': 0.17172640676855638,
#   'GOLD weight': 0.13336516226242962,
#   'DAL weight': 0.12803555917290094,
#   'NFLX weight': 0.20052038358218388,
#   'AAPL weight': 0.035536124893582696,
#   'PFE weight': 0.07383220747712607,
#   'BTC weight': 0.13261246340747795},
#  {'Returns': 23.32818916881181,
#   'Volatility': 0.18723723162790942,
#   'SHOP weight': 0.1561071082021193,
#   'TSLA weight': 0.1273738521089086,
#   'GOLD weight': 0.15015106782747212,
#   'DAL weight': 0.07842367044266295,
#   'NFLX weight': 0.03545105298842272,
#   'AAPL weight': 0.15209896708616813,
#   'PFE weight': 0.182386432480325,
#   'BTC weight': 0.11800784886392122},
#  {'Returns': 8.474345797701037,
#   'Volatility': 0.16708811771438842,
#   'SHOP weight': 0.028202483262424485,
#   'TSLA weight': 0.024785984895465685,
#   'GOLD weight': 0.20823959857635593,
#   'DAL weight': 0.07308319766711993,
#   'NFLX weight': 0.2009885992851847,
#   'AAPL weight': 0.2171531645272311,
#   'PFE weight': 0.08376881135742785,
#   'BTC weight': 0.16377816042879037},
#  {'Returns': 14.490997105056701,
#   'Volatility': 0.19680112413852993,
#   'SHOP weight': 0.13898203576835616,
#   'TSLA weight': 0.0294420417069731,
#   'GOLD weight': 0.2377102490670119,
#   'DAL weight': 0.056142285423425364,
#   'NFLX weight': 0.20372119735148145,
#   'AAPL weight': 0.1367734870129245,
#   'PFE weight': 0.19606088205982078,
#   'BTC weight': 0.00116782161000688},
#  {'Returns': 38.305610014820004,
#   'Volatility': 0.22757268991735816,
#   'SHOP weight': 0.2384927581024517,
#   'TSLA weight': 0.16030396292287438,
#   'GOLD weight': 0.03294714986022637,
#   'DAL weight': 0.23169184933810666,
#   'NFLX weight': 0.02260873826250253,
#   'AAPL weight': 0.11610134397308815,
#   'PFE weight': 0.18743942906884115,
#   'BTC weight': 0.010414768471908982},
#  {'Returns': 21.30829933729316,
#   'Volatility': 0.16275500386467773,
#   'SHOP weight': 0.09787243230109437,
#   'TSLA weight': 0.05952184555086261,
#   'GOLD weight': 0.10166200361874213,
#   'DAL weight': 0.14644075067229786,
#   'NFLX weight': 0.11819649493821138,
#   'AAPL weight': 0.17530689263683613,
#   'PFE weight': 0.16167478534924803,
#   'BTC weight': 0.13932479493270755},
#  {'Returns': 21.65403679994723,
#   'Volatility': 0.19410888960063719,
#   'SHOP weight': 0.038729663980245806,
#   'TSLA weight': 0.18978317015350843,
#   'GOLD weight': 0.1578677284718466,
#   'DAL weight': 0.18566079741255945,
#   'NFLX weight': 0.06697603960737898,
#   'AAPL weight': 0.151506816184252,
#   'PFE weight': 0.043961471486769384,
#   'BTC weight': 0.1655143127034395},
#  {'Returns': 21.727182519047574,
#   'Volatility': 0.19528716918621633,
#   'SHOP weight': 0.07296216031310962,
#   'TSLA weight': 0.08848797587366311,
#   'GOLD weight': 0.0986350961429295,
#   'DAL weight': 0.04451080912558153,
#   'NFLX weight': 0.24044166134973669,
#   'AAPL weight': 0.2192826216721038,
#   'PFE weight': 0.1949309178430216,
#   'BTC weight': 0.04074875767985411},
#  {'Returns': 23.1333382189109,
#   'Volatility': 0.23992491011293438,
#   'SHOP weight': 0.14615145811772667,
#   'TSLA weight': 0.19549870957208695,
#   'GOLD weight': 0.1547697372591834,
#   'DAL weight': 0.016541443661522867,
#   'NFLX weight': 0.12615187881051468,
#   'AAPL weight': 0.2301867095875821,
#   'PFE weight': 0.06927490590612871,
#   'BTC weight': 0.06142515708525463},
#  {'Returns': 25.421172115676242,
#   'Volatility': 0.2143996756536415,
#   'SHOP weight': 0.09106480304272122,
#   'TSLA weight': 0.2560523224965536,
#   'GOLD weight': 0.15023625153934536,
#   'DAL weight': 0.2189952582295995,
#   'NFLX weight': 0.024564773988088453,
#   'AAPL weight': 0.019844552031051635,
#   'PFE weight': 0.010156216867414983,
#   'BTC weight': 0.22908582180522535},
#  {'Returns': 17.977549405634512,
#   'Volatility': 0.16458646924211418,
#   'SHOP weight': 0.1667960867189866,
#   'TSLA weight': 0.05241868230209262,
#   'GOLD weight': 0.10540162316423958,
#   'DAL weight': 0.18671152600549873,
#   'NFLX weight': 0.10800166671599348,
#   'AAPL weight': 0.07891938548154936,
#   'PFE weight': 0.023951558607479703,
#   'BTC weight': 0.27779947100415986},
#  {'Returns': 32.1404932537424,
#   'Volatility': 0.20187953420438348,
#   'SHOP weight': 0.09577798967475348,
#   'TSLA weight': 0.2070644083590248,
#   'GOLD weight': 0.12054633387994271,
#   'DAL weight': 0.18814133076656916,
#   'NFLX weight': 0.06517154752221832,
#   'AAPL weight': 0.029316660424511927,
#   'PFE weight': 0.25818564890189777,
#   'BTC weight': 0.03579608047108181},
#  {'Returns': 10.969984323987592,
#   'Volatility': 0.2098797242860515,
#   'SHOP weight': 0.25597657334853774,
#   'TSLA weight': 0.050748675152975375,
#   'GOLD weight': 0.2748930480835545,
#   'DAL weight': 0.045946907884985136,
#   'NFLX weight': 0.0014029535146001166,
#   'AAPL weight': 0.15063261574200865,
#   'PFE weight': 0.031088148968464534,
#   'BTC weight': 0.18931107730487393},
#  {'Returns': 24.62121345105011,
#   'Volatility': 0.16647349710928658,
#   'SHOP weight': 0.2117863099291383,
#   'TSLA weight': 0.09584046740067652,
#   'GOLD weight': 0.053953836056849974,
#   'DAL weight': 0.05708967633580871,
#   'NFLX weight': 0.02772945704397155,
#   'AAPL weight': 0.06848683543621344,
#   'PFE weight': 0.19624262775866663,
#   'BTC weight': 0.28887079003867494},
#  {'Returns': 10.158847361317354,
#   'Volatility': 0.19811407570776823,
#   'SHOP weight': 0.06076444544556962,
#   'TSLA weight': 0.11294936765682927,
#   'GOLD weight': 0.1964200495144073,
#   'DAL weight': 0.001253662744279288,
#   'NFLX weight': 0.22675119325412404,
#   'AAPL weight': 0.18098975092900838,
#   'PFE weight': 0.014886365798001483,
#   'BTC weight': 0.20598516465778066},
#  {'Returns': 24.344822247568615,
#   'Volatility': 0.18385078188571047,
#   'SHOP weight': 0.056508592774618775,
#   'TSLA weight': 0.17007515403785736,
#   'GOLD weight': 0.08985218675032718,
#   'DAL weight': 0.08648103374103899,
#   'NFLX weight': 0.1660576451968118,
#   'AAPL weight': 0.11916514761350534,
#   'PFE weight': 0.16369960774972547,
#   'BTC weight': 0.14816063213611513},
#  {'Returns': 22.726606436711247,
#   'Volatility': 0.1784331381967846,
#   'SHOP weight': 0.006834511188530905,
#   'TSLA weight': 0.17800814748971167,
#   'GOLD weight': 0.1184215395873943,
#   'DAL weight': 0.17908662065953496,
#   'NFLX weight': 0.12285068047378706,
#   'AAPL weight': 0.10151058344806634,
#   'PFE weight': 0.11161621103146283,
#   'BTC weight': 0.18167170612151204},
#  {'Returns': 19.386362671183246,
#   'Volatility': 0.24639937540822113,
#   'SHOP weight': 0.17579501473471273,
#   'TSLA weight': 0.19174328693625944,
#   'GOLD weight': 0.2366578913640157,
#   'DAL weight': 0.01691169464479765,
#   'NFLX weight': 0.09040522450090903,
#   'AAPL weight': 0.19329050873898818,
#   'PFE weight': 0.04440769013106702,
#   'BTC weight': 0.05078868894925025},
#  {'Returns': 7.3509812821072105,
#   'Volatility': 0.21075986783714581,
#   'SHOP weight': 0.12229244640573496,
#   'TSLA weight': 0.08469222237375451,
#   'GOLD weight': 0.3088625420609974,
#   'DAL weight': 0.040309494470876395,
#   'NFLX weight': 0.15501125719321798,
#   'AAPL weight': 0.16730309891490344,
#   'PFE weight': 0.005732944837330101,
#   'BTC weight': 0.11579599374318511},
#  {'Returns': 29.317872958163225,
#   'Volatility': 0.18334294105955362,
#   'SHOP weight': 0.037482128473669545,
#   'TSLA weight': 0.21932910465263977,
#   'GOLD weight': 0.06875354090227036,
#   'DAL weight': 0.09839677521432819,
#   'NFLX weight': 0.07532569565631184,
#   'AAPL weight': 0.09391065749689988,
#   'PFE weight': 0.24040566866258806,
#   'BTC weight': 0.16639642894129228},
#  {'Returns': 24.484082076351633,
#   'Volatility': 0.23922667088233263,
#   'SHOP weight': 0.1175704291628285,
#   'TSLA weight': 0.23180540092895827,
#   'GOLD weight': 0.15343434371931441,
#   'DAL weight': 0.054796179139243464,
#   'NFLX weight': 0.13881544936415696,
#   'AAPL weight': 0.17718047339223944,
#   'PFE weight': 0.05623746330448966,
#   'BTC weight': 0.07016026098876946},
#  {'Returns': 16.191832821741727,
#   'Volatility': 0.1800322100659805,
#   'SHOP weight': 0.1891463566919848,
#   'TSLA weight': 0.02952982245614519,
#   'GOLD weight': 0.1813321936090671,
#   'DAL weight': 0.20676365784629658,
#   'NFLX weight': 0.06764670819966219,
#   'AAPL weight': 0.1206881863634105,
#   'PFE weight': 0.025800734228063768,
#   'BTC weight': 0.17909234060536988},
#  {'Returns': 9.998739274240911,
#   'Volatility': 0.17239490399848703,
#   'SHOP weight': 0.12861456894956505,
#   'TSLA weight': 0.016990811174103195,
#   'GOLD weight': 0.2110491896200181,
#   'DAL weight': 0.0011778099797501128,
#   'NFLX weight': 0.22410523611397906,
#   'AAPL weight': 0.047095496370368375,
#   'PFE weight': 0.18809595466569567,
#   'BTC weight': 0.18287093312652053},
#  {'Returns': 10.68562172215773,
#   'Volatility': 0.1952939037352805,
#   'SHOP weight': 0.006257220630509725,
#   'TSLA weight': 0.12191607670709295,
#   'GOLD weight': 0.2928697205516073,
#   'DAL weight': 0.05608496349275103,
#   'NFLX weight': 0.18284821202883372,
#   'AAPL weight': 0.1684306038566472,
#   'PFE weight': 0.11930512918927821,
#   'BTC weight': 0.052288073543279856},
#  {'Returns': 10.79749709754901,
#   'Volatility': 0.15406873788043657,
#   'SHOP weight': 0.009027467411378217,
#   'TSLA weight': 0.08072936052795902,
#   'GOLD weight': 0.19195317917917082,
#   'DAL weight': 0.057698279277380554,
#   'NFLX weight': 0.23211215324918152,
#   'AAPL weight': 0.06268414640913521,
#   'PFE weight': 0.14440316605051728,
#   'BTC weight': 0.2213922478952772},
#  {'Returns': 22.049915228001225,
#   'Volatility': 0.20093566671841803,
#   'SHOP weight': 0.1801194410093895,
#   'TSLA weight': 0.09405160777310352,
#   'GOLD weight': 0.15476435427866644,
#   'DAL weight': 0.19942053392850137,
#   'NFLX weight': 0.09629892640562396,
#   'AAPL weight': 0.13256842572591984,
#   'PFE weight': 0.047515540720916606,
#   'BTC weight': 0.09526117015787886},
#  {'Returns': 13.165838554794377,
#   'Volatility': 0.16168714791044975,
#   'SHOP weight': 0.0798128087705829,
#   'TSLA weight': 0.01750594671832312,
#   'GOLD weight': 0.07886419162848067,
#   'DAL weight': 0.05217268482039873,
#   'NFLX weight': 0.18790819968135747,
#   'AAPL weight': 0.2542481945005582,
#   'PFE weight': 0.05728879073375527,
#   'BTC weight': 0.2721991831465436},
#  {'Returns': 22.642110665605642,
#   'Volatility': 0.22138169897180007,
#   'SHOP weight': 0.11073189445754301,
#   'TSLA weight': 0.19661402708529518,
#   'GOLD weight': 0.22058374236041806,
#   'DAL weight': 0.2092753879595088,
#   'NFLX weight': 0.12298570059599209,
#   'AAPL weight': 0.04620029535921134,
#   'PFE weight': 0.04583312359312013,
#   'BTC weight': 0.04777582858891135},
#  {'Returns': 34.66105657123876,
#   'Volatility': 0.21201783857176695,
#   'SHOP weight': 0.18808306445687095,
#   'TSLA weight': 0.186963035100176,
#   'GOLD weight': 0.025426466967273,
#   'DAL weight': 0.16509087291715394,
#   'NFLX weight': 0.13127091564775498,
#   'AAPL weight': 0.01397806277701595,
#   'PFE weight': 0.1870548139446073,
#   'BTC weight': 0.10213276818914784},
#  {'Returns': 17.651397625610947,
#   'Volatility': 0.19743374990561224,
#   'SHOP weight': 0.09348425514123754,
#   'TSLA weight': 0.17785822731270287,
#   'GOLD weight': 0.20920053380328926,
#   'DAL weight': 0.054308243848804935,
#   'NFLX weight': 0.041425830692773113,
#   'AAPL weight': 0.181945758065331,
#   'PFE weight': 0.07281153126897662,
#   'BTC weight': 0.1689656198668847},
#  {'Returns': 24.71760234351325,
#   'Volatility': 0.17832439402645056,
#   'SHOP weight': 0.1101607714366469,
#   'TSLA weight': 0.08228578532951474,
#   'GOLD weight': 0.087196158528764,
#   'DAL weight': 0.23316216600699752,
#   'NFLX weight': 0.08995618398929188,
#   'AAPL weight': 0.16795748133663765,
#   'PFE weight': 0.10600809318494425,
#   'BTC weight': 0.12327336018720318},
#  {'Returns': 34.700677842363994,
#   'Volatility': 0.21453074936039826,
#   'SHOP weight': 0.13622311596878497,
#   'TSLA weight': 0.2845504616102584,
#   'GOLD weight': 0.030830306124455014,
#   'DAL weight': 0.029956667416555793,
#   'NFLX weight': 0.015526777121615166,
#   'AAPL weight': 0.03776055084251411,
#   'PFE weight': 0.2457907431334993,
#   'BTC weight': 0.21936137778231735},
#  {'Returns': 24.670327575145354,
#   'Volatility': 0.1778068889417814,
#   'SHOP weight': 0.011463959984703884,
#   'TSLA weight': 0.16270877083831684,
#   'GOLD weight': 0.09657564412558546,
#   'DAL weight': 0.25815502915933597,
#   'NFLX weight': 0.07603908923763421,
#   'AAPL weight': 0.08097407322783141,
#   'PFE weight': 0.10700691158173273,
#   'BTC weight': 0.20707652184485956},
#  {'Returns': 12.331058692441655,
#   'Volatility': 0.1579170608190668,
#   'SHOP weight': 0.16508632232772277,
#   'TSLA weight': 0.017426359402819766,
#   'GOLD weight': 0.22249058211956965,
#   'DAL weight': 0.14629917433579287,
#   'NFLX weight': 0.019845268357534016,
#   'AAPL weight': 0.10553992713605392,
#   'PFE weight': 0.09432661753654568,
#   'BTC weight': 0.2289857487839614},
#  {'Returns': 19.374478776316145,
#   'Volatility': 0.1744740531885717,
#   'SHOP weight': 0.14146097240953234,
#   'TSLA weight': 0.023844145755499608,
#   'GOLD weight': 0.18029622407153437,
#   'DAL weight': 0.18673756517289863,
#   'NFLX weight': 0.14282030408511365,
#   'AAPL weight': 0.08608371373349219,
#   'PFE weight': 0.18961509066423005,
#   'BTC weight': 0.04914198410769909},
#  {'Returns': 24.126770966790804,
#   'Volatility': 0.17078527377904723,
#   'SHOP weight': 0.1376234958333672,
#   'TSLA weight': 0.013148234563362908,
#   'GOLD weight': 0.04190532703898922,
#   'DAL weight': 0.16379889280296311,
#   'NFLX weight': 0.1550353067443162,
#   'AAPL weight': 0.20185478891955594,
#   'PFE weight': 0.1774574834702355,
#   'BTC weight': 0.10917647062720985},
#  {'Returns': 23.386550692973408,
#   'Volatility': 0.1661135551230025,
#   'SHOP weight': 0.15440621968257004,
#   'TSLA weight': 0.04824195416632623,
#   'GOLD weight': 0.10496677473929701,
#   'DAL weight': 0.17298721408202478,
#   'NFLX weight': 0.010120676559305616,
#   'AAPL weight': 0.18989155454466852,
#   'PFE weight': 0.1725302883399761,
#   'BTC weight': 0.1468553178858317},
#  {'Returns': 30.964273808013317,
#   'Volatility': 0.19891358312698268,
#   'SHOP weight': 0.2518483505530622,
#   'TSLA weight': 0.17437406247057616,
#   'GOLD weight': 0.032779098102837106,
#   'DAL weight': 0.05904242211555645,
#   'NFLX weight': 0.002988375029143084,
#   'AAPL weight': 0.007647439277404473,
#   'PFE weight': 0.20110487923541315,
#   'BTC weight': 0.2702153732160075},
#  {'Returns': 21.148311114083782,
#   'Volatility': 0.18884034927730992,
#   'SHOP weight': 0.10317199959813611,
#   'TSLA weight': 0.132951750449673,
#   'GOLD weight': 0.12729393799650604,
#   'DAL weight': 0.13932234984889436,
#   'NFLX weight': 0.07414953893062609,
#   'AAPL weight': 0.21219926482353635,
#   'PFE weight': 0.04598324514210613,
#   'BTC weight': 0.16492791321052194},
#  {'Returns': 16.841794093663406,
#   'Volatility': 0.23995197102107219,
#   'SHOP weight': 0.22372025707645485,
#   'TSLA weight': 0.041507511530483786,
#   'GOLD weight': 0.17068834105050917,
#   'DAL weight': 0.08241692596722212,
#   'NFLX weight': 0.2522904290422349,
#   'AAPL weight': 0.18382632336440202,
#   'PFE weight': 0.016204965264782826,
#   'BTC weight': 0.029345246703910213},
#  {'Returns': 12.632384338295465,
#   'Volatility': 0.152032682140812,
#   'SHOP weight': 0.11311265159988311,
#   'TSLA weight': 0.0018024250084849468,
#   'GOLD weight': 0.15605000899356244,
#   'DAL weight': 0.15487308906216124,
#   'NFLX weight': 0.10566321362017056,
#   'AAPL weight': 0.172526798653451,
#   'PFE weight': 0.05962354180607305,
#   'BTC weight': 0.2363482712562136},
#  {'Returns': 25.55720350201023,
#   'Volatility': 0.20094203581272643,
#   'SHOP weight': 0.1905828676805412,
#   'TSLA weight': 0.026666332867048295,
#   'GOLD weight': 0.068273971553293,
#   'DAL weight': 0.1448545116405615,
#   'NFLX weight': 0.19617643897420897,
#   'AAPL weight': 0.1867956340111834,
#   'PFE weight': 0.17060393168919794,
#   'BTC weight': 0.016046311583965585},
#  {'Returns': 24.196978661444824,
#   'Volatility': 0.1659013641176917,
#   'SHOP weight': 0.13873481778412874,
#   'TSLA weight': 0.030809140582835116,
#   'GOLD weight': 0.06673362669685903,
#   'DAL weight': 0.18435398233338374,
#   'NFLX weight': 0.13963720171394592,
#   'AAPL weight': 0.1331549183129038,
#   'PFE weight': 0.1882293989908822,
#   'BTC weight': 0.11834691358506151},
#  {'Returns': 25.281246637247392,
#   'Volatility': 0.21712603888062176,
#   'SHOP weight': 0.16073323981303078,
#   'TSLA weight': 0.1666358940661035,
#   'GOLD weight': 0.16205491209658823,
#   'DAL weight': 0.01318489349332624,
#   'NFLX weight': 0.13315526663278895,
#   'AAPL weight': 0.11176466673206988,
#   'PFE weight': 0.23159323790252515,
#   'BTC weight': 0.02087788926356739},
#  {'Returns': 21.973999307487027,
#   'Volatility': 0.20446016783297027,
#   'SHOP weight': 0.11618564673987718,
#   'TSLA weight': 0.16136451624603076,
#   'GOLD weight': 0.19876926201775744,
#   'DAL weight': 0.05587974666870871,
#   'NFLX weight': 0.10585110117984667,
#   'AAPL weight': 0.13977787524595325,
#   'PFE weight': 0.18296312731630243,
#   'BTC weight': 0.03920872458552355},
#  {'Returns': 24.064919875935065,
#   'Volatility': 0.19441864351285493,
#   'SHOP weight': 0.14672248134628058,
#   'TSLA weight': 0.02831926302813861,
#   'GOLD weight': 0.09644688114159082,
#   'DAL weight': 0.19922549105824805,
#   'NFLX weight': 0.19180601391238064,
#   'AAPL weight': 0.1896277765123707,
#   'PFE weight': 0.14383806569882843,
#   'BTC weight': 0.004014027302162143},
#  {'Returns': 28.42906525131125,
#   'Volatility': 0.1857603909128964,
#   'SHOP weight': 0.19784439397441922,
#   'TSLA weight': 0.019822540722836356,
#   'GOLD weight': 0.04174472421224357,
#   'DAL weight': 0.10712184187882699,
#   'NFLX weight': 0.11664882906786771,
#   'AAPL weight': 0.19245206971587436,
#   'PFE weight': 0.2886672466298171,
#   'BTC weight': 0.035698353798114674},
#  {'Returns': 31.334820491126006,
#   'Volatility': 0.21940873552309986,
#   'SHOP weight': 0.2818484025237982,
#   'TSLA weight': 0.03657026896919825,
#   'GOLD weight': 0.010932186669130609,
#   'DAL weight': 0.1445031659626454,
#   'NFLX weight': 0.0020082168005371385,
#   'AAPL weight': 0.31324547368732003,
#   'PFE weight': 0.14545810324425917,
#   'BTC weight': 0.06543418214311122},
#  {'Returns': 19.751639477072807,
#   'Volatility': 0.21216076656859598,
#   'SHOP weight': 0.19032126719189746,
#   'TSLA weight': 0.13384134736357794,
#   'GOLD weight': 0.1411817351301698,
#   'DAL weight': 0.08344659771892673,
#   'NFLX weight': 0.11247165209168297,
#   'AAPL weight': 0.14806511266157915,
#   'PFE weight': 0.003799122497495755,
#   'BTC weight': 0.1868731653446702},
#  {'Returns': 19.07132173685586,
#   'Volatility': 0.2113275527443551,
#   'SHOP weight': 0.20635461223852533,
#   'TSLA weight': 0.07693355597560465,
#   'GOLD weight': 0.15743410059418314,
#   'DAL weight': 0.0061215117391499405,
#   'NFLX weight': 0.14800763847912432,
#   'AAPL weight': 0.16215264666491036,
#   'PFE weight': 0.14542059292759518,
#   'BTC weight': 0.09757534138090702},
#  {'Returns': 18.969870017991923,
#   'Volatility': 0.23195404336749065,
#   'SHOP weight': 0.0008918044403081003,
#   'TSLA weight': 0.21873195112391053,
#   'GOLD weight': 0.21962823899377204,
#   'DAL weight': 0.110007483267657,
#   'NFLX weight': 0.27762614613210285,
#   'AAPL weight': 0.10409234886523358,
#   'PFE weight': 0.05993681927558945,
#   'BTC weight': 0.009085207901426483},
#  {'Returns': 25.828264785422594,
#   'Volatility': 0.24394514515061502,
#   'SHOP weight': 0.09778092924683963,
#   'TSLA weight': 0.26302152787060956,
#   'GOLD weight': 0.13651028198185083,
#   'DAL weight': 0.017893978799614088,
#   'NFLX weight': 0.13357920105974316,
#   'AAPL weight': 0.18565184479751473,
#   'PFE weight': 0.08090940147689467,
#   'BTC weight': 0.08465283476693337},
#  {'Returns': 32.16486178312,
#   'Volatility': 0.19194908158941903,
#   'SHOP weight': 0.11935880035561527,
#   'TSLA weight': 0.16357921557286959,
#   'GOLD weight': 0.02098237279303894,
#   'DAL weight': 0.15937578404999345,
#   'NFLX weight': 0.04695653075723547,
#   'AAPL weight': 0.18276308590745094,
#   'PFE weight': 0.1764199657531723,
#   'BTC weight': 0.13056424481062404},
#  {'Returns': 24.511175471887537,
#   'Volatility': 0.18960358969275426,
#   'SHOP weight': 0.14581534353497777,
#   'TSLA weight': 0.09716460961222324,
#   'GOLD weight': 0.14558118286182567,
#   'DAL weight': 0.12491105053900158,
#   'NFLX weight': 0.04496915044792042,
#   'AAPL weight': 0.20641028062162706,
#   'PFE weight': 0.19281686557042488,
#   'BTC weight': 0.04233151681199933},
#  {'Returns': 21.16883254470494,
#   'Volatility': 0.17459538758916798,
#   'SHOP weight': 0.022027401029998277,
#   'TSLA weight': 0.10473702738503143,
#   'GOLD weight': 0.15202742021908147,
#   'DAL weight': 0.20332094189935984,
#   'NFLX weight': 0.09001668009795243,
#   'AAPL weight': 0.19010795267117198,
#   'PFE weight': 0.14748739628116933,
#   'BTC weight': 0.09027518041623514},
#  {'Returns': 24.997225732175234,
#   'Volatility': 0.23416328380141407,
#   'SHOP weight': 0.2584991183920116,
#   'TSLA weight': 0.000749059540303383,
#   'GOLD weight': 0.02682988824990487,
#   'DAL weight': 0.15522583815031754,
#   'NFLX weight': 0.2771316928062528,
#   'AAPL weight': 0.17985892407417958,
#   'PFE weight': 0.05738581249746091,
#   'BTC weight': 0.04431966628956924},
#  {'Returns': 21.93660449991735,
#   'Volatility': 0.18626565266118095,
#   'SHOP weight': 0.16871908047625367,
#   'TSLA weight': 0.03402311215277061,
#   'GOLD weight': 0.13744145089909257,
#   'DAL weight': 0.19974387294747736,
#   'NFLX weight': 0.09686762101391443,
#   'AAPL weight': 0.18132485484378294,
#   'PFE weight': 0.12093493753291278,
#   'BTC weight': 0.060945070133795624},
#  {'Returns': 26.51422954052956,
#   'Volatility': 0.2016212859225058,
#   'SHOP weight': 0.014418404598293966,
#   'TSLA weight': 0.22509296914241433,
#   'GOLD weight': 0.0444740393447092,
#   'DAL weight': 0.19962110106170425,
#   'NFLX weight': 0.18508590566292646,
#   'AAPL weight': 0.07000524043029499,
#   'PFE weight': 0.03311685991333518,
#   'BTC weight': 0.22818547984632154},
#  {'Returns': 26.34784181560939,
#   'Volatility': 0.22719769390353164,
#   'SHOP weight': 0.17708478938913208,
#   'TSLA weight': 0.14109128130145362,
#   'GOLD weight': 0.13344265264193714,
#   'DAL weight': 0.11781678852140204,
#   'NFLX weight': 0.09824283288011318,
#   'AAPL weight': 0.23580575513439864,
#   'PFE weight': 0.09438688169224575,
#   'BTC weight': 0.0021290184393174907},
#  {'Returns': 21.122015900565394,
#   'Volatility': 0.1451778239208686,
#   'SHOP weight': 0.006385285050066189,
#   'TSLA weight': 0.0020692896611432866,
#   'GOLD weight': 0.08272346754339488,
#   'DAL weight': 0.1711965521828382,
#   'NFLX weight': 0.14145929337478344,
#   'AAPL weight': 0.15738734136654386,
#   'PFE weight': 0.3201155540558991,
#   'BTC weight': 0.11866321676533115},
#  {'Returns': 17.948921404005738,
#   'Volatility': 0.17726991843314485,
#   'SHOP weight': 0.1805201451601911,
#   'TSLA weight': 0.053412261600368875,
#   'GOLD weight': 0.1609748881930282,
#   'DAL weight': 0.10236506941579784,
#   'NFLX weight': 0.14163001550586596,
#   'AAPL weight': 0.06662175467363962,
#   'PFE weight': 0.14000352164643434,
#   'BTC weight': 0.15447234380467406},
#  {'Returns': 14.577120652149874,
#   'Volatility': 0.22354170856369085,
#   'SHOP weight': 0.17898113193808932,
#   'TSLA weight': 0.05702463773082403,
#   'GOLD weight': 0.16142981428590109,
#   'DAL weight': 0.02037615558945607,
#   'NFLX weight': 0.2594090423316051,
#   'AAPL weight': 0.16968947600052983,
#   'PFE weight': 0.04269965341983082,
#   'BTC weight': 0.1103900887037637},
#  {'Returns': 24.206499666704683,
#   'Volatility': 0.2214359734963605,
#   'SHOP weight': 0.2827690947082264,
#   'TSLA weight': 0.01391809495995746,
#   'GOLD weight': 0.12611401990238205,
#   'DAL weight': 0.1750361788033732,
#   'NFLX weight': 0.1915367993339597,
#   'AAPL weight': 0.07477835523218528,
#   'PFE weight': 0.13311565663987102,
#   'BTC weight': 0.00273180042004491},
#  {'Returns': 19.506902979417326,
#   'Volatility': 0.20218733307884254,
#   'SHOP weight': 0.060729888407524676,
#   'TSLA weight': 0.15324854973084576,
#   'GOLD weight': 0.16721112759632828,
#   'DAL weight': 0.023567013608597878,
#   'NFLX weight': 0.14917934798595262,
#   'AAPL weight': 0.22828199869889035,
#   'PFE weight': 0.14067597505737242,
#   'BTC weight': 0.07710609891448816},
#  {'Returns': 33.51890762778147,
#   'Volatility': 0.23936955957552183,
#   'SHOP weight': 0.20483024178512196,
#   'TSLA weight': 0.20487954526389282,
#   'GOLD weight': 0.07061023200169013,
#   'DAL weight': 0.10951206933410051,
#   'NFLX weight': 0.17344626529121718,
#   'AAPL weight': 0.05481611095487661,
#   'PFE weight': 0.1699596542631727,
#   'BTC weight': 0.011945881105928105},
#  {'Returns': 13.418763051920584,
#   'Volatility': 0.17068682594616744,
#   'SHOP weight': 0.16866109078482833,
#   'TSLA weight': 0.0375076918354179,
#   'GOLD weight': 0.21047750682680325,
#   'DAL weight': 0.013915148082773332,
#   'NFLX weight': 0.09158016367377866,
#   'AAPL weight': 0.09905191750817788,
#   'PFE weight': 0.1958717632635832,
#   'BTC weight': 0.1829347180246374},
#  {'Returns': 24.389235771091975,
#   'Volatility': 0.19618496157111984,
#   'SHOP weight': 0.21907880388337392,
#   'TSLA weight': 0.09042933564144061,
#   'GOLD weight': 0.12374076266185884,
#   'DAL weight': 0.24294984778266743,
#   'NFLX weight': 0.07123848373642866,
#   'AAPL weight': 0.0406369951593544,
#   'PFE weight': 0.055914339063382876,
#   'BTC weight': 0.15601143207149332},
#  {'Returns': 14.627324275721447,
#   'Volatility': 0.14710388206635538,
#   'SHOP weight': 0.040825376914637584,
#   'TSLA weight': 0.016176166438606088,
#   'GOLD weight': 0.18479793240850267,
#   'DAL weight': 0.13238828255008098,
#   'NFLX weight': 0.11261447867518107,
#   'AAPL weight': 0.15706639005301162,
#   'PFE weight': 0.22320721122497864,
#   'BTC weight': 0.1329241617350013},
#  {'Returns': 20.45384552290862,
#   'Volatility': 0.1920950438641923,
#   'SHOP weight': 0.17421740717677336,
#   'TSLA weight': 0.0622512681716171,
# ...
#   'BTC weight': 0.08228937116932249},
#  {'Returns': 10.17433686461626,
#   'Volatility': 0.17490226526588296,
#   'SHOP weight': 0.07208631198141897,
#   'TSLA weight': 0.05353421878453749,
#   'GOLD weight': 0.24417609140246813,
#   'DAL weight': 0.140780322032963,
#   'NFLX weight': 0.1430208678336845,
#   'AAPL weight': 0.16127241434343498,
#   'PFE weight': 0.03570415569107671,
#   'BTC weight': 0.14942561793041617},
#  {'Returns': 37.79460377596555,
#   'Volatility': 0.2995191216428425,
#   'SHOP weight': 0.4166640264983242,
#   'TSLA weight': 0.2145902762740104,
#   'GOLD weight': 0.05666008338262239,
#   'DAL weight': 0.1355467818468576,
#   'NFLX weight': 0.012851688468663023,
#   'AAPL weight': 0.05898151584032428,
#   'PFE weight': 0.03493874085116725,
#   'BTC weight': 0.0697668868380309},
#  {'Returns': 22.744135309134627,
#   'Volatility': 0.1692379539995713,
#   'SHOP weight': 0.06524081242682672,
#   'TSLA weight': 0.010653281427825767,
#   'GOLD weight': 0.03585574144889323,
#   'DAL weight': 0.14194889841782168,
#   'NFLX weight': 0.2449212174522033,
#   'AAPL weight': 0.20567360473281776,
#   'PFE weight': 0.21522043592831244,
#   'BTC weight': 0.0804860081652991},
#  {'Returns': 24.427168520200393,
#   'Volatility': 0.16996190032604022,
#   'SHOP weight': 0.04100863872602086,
#   'TSLA weight': 0.05878277424815815,
#   'GOLD weight': 0.06079044586224079,
#   'DAL weight': 0.09268448971348837,
#   'NFLX weight': 0.06132100317981617,
#   'AAPL weight': 0.34740181050699065,
#   'PFE weight': 0.25600150056929494,
#   'BTC weight': 0.08200933719399017},
#  {'Returns': 21.081750201765555,
#   'Volatility': 0.16183451373283295,
#   'SHOP weight': 0.03706306058968426,
#   'TSLA weight': 0.14473691347854356,
#   'GOLD weight': 0.15610738555664516,
#   'DAL weight': 0.11099463610955057,
#   'NFLX weight': 0.07610491684481681,
#   'AAPL weight': 0.09604213597974488,
#   'PFE weight': 0.2144893884610802,
#   'BTC weight': 0.1644615629799345},
#  {'Returns': 17.407186396178616,
#   'Volatility': 0.1444165853963177,
#   'SHOP weight': 0.07529821268462035,
#   'TSLA weight': 0.03801038581642571,
#   'GOLD weight': 0.10253971785979228,
#   'DAL weight': 0.05335779373295206,
#   'NFLX weight': 0.06385824783926296,
#   'AAPL weight': 0.23957770393354008,
#   'PFE weight': 0.20321599553437983,
#   'BTC weight': 0.22414194259902676},
#  {'Returns': 35.67778016713078,
#   'Volatility': 0.27600555412871824,
#   'SHOP weight': 0.20966759534818494,
#   'TSLA weight': 0.26129460526780746,
#   'GOLD weight': 0.048675160105039146,
#   'DAL weight': 0.06504479929744983,
#   'NFLX weight': 0.10180692629568949,
#   'AAPL weight': 0.22528409396253976,
#   'PFE weight': 0.08124343415503196,
#   'BTC weight': 0.006983385568257483},
#  {'Returns': 27.637483698989907,
#   'Volatility': 0.1934283278601988,
#   'SHOP weight': 0.18998509460384397,
#   'TSLA weight': 0.12591747478448803,
#   'GOLD weight': 0.06553764986435821,
#   'DAL weight': 0.17141225469162466,
#   'NFLX weight': 0.011653499007069515,
#   'AAPL weight': 0.16887902919729708,
#   'PFE weight': 0.08726515135905881,
#   'BTC weight': 0.17934984649225966},
#  {'Returns': 21.187908485794647,
#   'Volatility': 0.19988399956885394,
#   'SHOP weight': 0.17062929266849008,
#   'TSLA weight': 0.1060736520327199,
#   'GOLD weight': 0.11534939691606172,
#   'DAL weight': 0.16897443599828177,
#   'NFLX weight': 0.1769986877727958,
#   'AAPL weight': 0.08007246773100639,
#   'PFE weight': 0.01634206219110624,
#   'BTC weight': 0.16556000468953802},
#  {'Returns': 27.20637398885765,
#   'Volatility': 0.2070409346551994,
#   'SHOP weight': 0.04284729224198862,
#   'TSLA weight': 0.16936999329080835,
#   'GOLD weight': 0.08207034151472925,
#   'DAL weight': 0.19343278891247492,
#   'NFLX weight': 0.1427815301726629,
#   'AAPL weight': 0.22422881381466805,
#   'PFE weight': 0.08626204174387844,
#   'BTC weight': 0.05900719830878946},
#  {'Returns': 17.422161700439354,
#   'Volatility': 0.2129219863603982,
#   'SHOP weight': 0.2779042275197706,
#   'TSLA weight': 0.022189404202487217,
#   'GOLD weight': 0.2690512469821286,
#   'DAL weight': 0.08137326208197243,
#   'NFLX weight': 0.05564472430666774,
#   'AAPL weight': 0.07158563904481352,
#   'PFE weight': 0.21044684995898924,
#   'BTC weight': 0.01180464590317058},
#  {'Returns': 25.070793387327583,
#   'Volatility': 0.18375521531158417,
#   'SHOP weight': 0.017485010620079622,
#   'TSLA weight': 0.17581656783853308,
#   'GOLD weight': 0.05535903178298753,
#   'DAL weight': 0.18620358653919367,
#   'NFLX weight': 0.006011853856287987,
#   'AAPL weight': 0.26305077499579044,
#   'PFE weight': 0.05224224290887858,
#   'BTC weight': 0.24383093145824905},
#  {'Returns': 25.101421987122364,
#   'Volatility': 0.2463847593630403,
#   'SHOP weight': 0.0792598926567891,
#   'TSLA weight': 0.23174624518889045,
#   'GOLD weight': 0.11008647452321844,
#   'DAL weight': 0.05717100279058507,
#   'NFLX weight': 0.2192060875027914,
#   'AAPL weight': 0.21106042896527927,
#   'PFE weight': 0.033186770659822756,
#   'BTC weight': 0.058283097712623466},
#  {'Returns': 11.567435355928836,
#   'Volatility': 0.2310650681239845,
#   'SHOP weight': 0.18357943650088657,
#   'TSLA weight': 0.031026803456221816,
#   'GOLD weight': 0.2182709296386169,
#   'DAL weight': 0.02322084070993885,
#   'NFLX weight': 0.2281440518979342,
#   'AAPL weight': 0.23120634789650923,
#   'PFE weight': 0.026021445312887602,
#   'BTC weight': 0.058530144587004757},
#  {'Returns': 13.511920745770897,
#   'Volatility': 0.16031024009453068,
#   'SHOP weight': 0.1043410156430318,
#   'TSLA weight': 0.025519844390243743,
#   'GOLD weight': 0.18171745627037106,
#   'DAL weight': 0.137666718685344,
#   'NFLX weight': 0.10502270163355641,
#   'AAPL weight': 0.17850413366625523,
#   'PFE weight': 0.08855441248582538,
#   'BTC weight': 0.17867371722537234},
#  {'Returns': 28.061406265228985,
#   'Volatility': 0.2180196545446454,
#   'SHOP weight': 0.047595277897560004,
#   'TSLA weight': 0.2413289260053571,
#   'GOLD weight': 0.08933077733499056,
#   'DAL weight': 0.06720725819540757,
#   'NFLX weight': 0.19479383065130465,
#   'AAPL weight': 0.11787001428680588,
#   'PFE weight': 0.15905390758434693,
#   'BTC weight': 0.08282000804422733},
#  {'Returns': 26.078940940306616,
#   'Volatility': 0.19784479777940261,
#   'SHOP weight': 0.11805386934557843,
#   'TSLA weight': 0.1879413179091014,
#   'GOLD weight': 0.09262659768405569,
#   'DAL weight': 0.09754622649779375,
#   'NFLX weight': 0.12241409119757733,
#   'AAPL weight': 0.09963273402567079,
#   'PFE weight': 0.1234888744667609,
#   'BTC weight': 0.15829628887346162},
#  {'Returns': 16.133638450050377,
#   'Volatility': 0.2108402558023608,
#   'SHOP weight': 0.062109295377830186,
#   'TSLA weight': 0.09704429542579182,
#   'GOLD weight': 0.20397758257029064,
#   'DAL weight': 0.12843320148154852,
#   'NFLX weight': 0.22089187843524885,
#   'AAPL weight': 0.2324197176568268,
#   'PFE weight': 0.044819220208289906,
#   'BTC weight': 0.01030480884417338},
#  {'Returns': 33.308189199687355,
#   'Volatility': 0.22832103171854595,
#   'SHOP weight': 0.12496240899798512,
#   'TSLA weight': 0.19774382765730233,
#   'GOLD weight': 0.02936568431904112,
#   'DAL weight': 0.020882594104197485,
#   'NFLX weight': 0.22124204337529751,
#   'AAPL weight': 0.13932691774423706,
#   'PFE weight': 0.26528421687409237,
#   'BTC weight': 0.0011923069278470327},
#  {'Returns': 17.828747189033383,
#   'Volatility': 0.16680292776789968,
#   'SHOP weight': 0.11403644538742,
#   'TSLA weight': 0.02785050810952351,
#   'GOLD weight': 0.10531879659266508,
#   'DAL weight': 0.1635674982461474,
#   'NFLX weight': 0.08273465549011172,
#   'AAPL weight': 0.25958839654316784,
#   'PFE weight': 0.0575301911721733,
#   'BTC weight': 0.18937350845879117},
#  {'Returns': 17.773360122933326,
#   'Volatility': 0.15104421868839776,
#   'SHOP weight': 0.03643212399971972,
#   'TSLA weight': 0.08999685632481506,
#   'GOLD weight': 0.1680113075497431,
#   'DAL weight': 0.19127877498426565,
#   'NFLX weight': 0.02855759653122094,
#   'AAPL weight': 0.12493294453210628,
#   'PFE weight': 0.14758577406854048,
#   'BTC weight': 0.21320462200958873},
#  {'Returns': 26.008417772140067,
#   'Volatility': 0.17762673474914156,
#   'SHOP weight': 0.06054191482274706,
#   'TSLA weight': 0.1738560125726881,
#   'GOLD weight': 0.12037547364677217,
#   'DAL weight': 0.12372472869743353,
#   'NFLX weight': 0.020180521002653946,
#   'AAPL weight': 0.14980816300925354,
#   'PFE weight': 0.21109020878144613,
#   'BTC weight': 0.1404229774670056},
#  {'Returns': 11.441084122074521,
#   'Volatility': 0.14876170452277476,
#   'SHOP weight': 0.15823634351085764,
#   'TSLA weight': 0.012541516645112542,
#   'GOLD weight': 0.2165755540906276,
#   'DAL weight': 0.16033748117868984,
#   'NFLX weight': 0.018594338336761197,
#   'AAPL weight': 0.07184312907814742,
#   'PFE weight': 0.08549838083221761,
#   'BTC weight': 0.2763732563275861},
#  {'Returns': 15.943538608157057,
#   'Volatility': 0.18228814242526986,
#   'SHOP weight': 0.07449572225079144,
#   'TSLA weight': 0.11746071359891368,
#   'GOLD weight': 0.20404692054269447,
#   'DAL weight': 0.18597003987992125,
#   'NFLX weight': 0.02440172482939194,
#   'AAPL weight': 0.20396580582657056,
#   'PFE weight': 0.0038871363168922215,
#   'BTC weight': 0.1857719367548243},
#  {'Returns': 23.633269814121263,
#   'Volatility': 0.20236585246521735,
#   'SHOP weight': 0.21182003069259636,
#   'TSLA weight': 0.12113831124488939,
#   'GOLD weight': 0.1263490149786445,
#   'DAL weight': 0.09150620171312,
#   'NFLX weight': 0.01056818945097799,
#   'AAPL weight': 0.18737923796973152,
#   'PFE weight': 0.09301278166041115,
#   'BTC weight': 0.158226232289629},
#  {'Returns': 17.00579070901497,
#   'Volatility': 0.20351092262923726,
#   'SHOP weight': 0.08962809354205424,
#   'TSLA weight': 0.11808734054788278,
#   'GOLD weight': 0.2974597750316398,
#   'DAL weight': 0.20493713109022485,
#   'NFLX weight': 0.03858084956706495,
#   'AAPL weight': 0.152148834231042,
#   'PFE weight': 0.09784254780914926,
#   'BTC weight': 0.0013154281809420578},
#  {'Returns': 18.970195883372238,
#   'Volatility': 0.21889016341110443,
#   'SHOP weight': 0.07287955198510841,
#   'TSLA weight': 0.215101381516365,
#   'GOLD weight': 0.2425310496914902,
#   'DAL weight': 0.07051243384869783,
#   'NFLX weight': 0.2033903228535796,
#   'AAPL weight': 0.01827709899589178,
#   'PFE weight': 0.11578646071866373,
#   'BTC weight': 0.06152170039020344},
#  {'Returns': 25.82749821713588,
#   'Volatility': 0.1869582311517169,
#   'SHOP weight': 0.0353573009319526,
#   'TSLA weight': 0.15312249945943088,
#   'GOLD weight': 0.07079678422396417,
#   'DAL weight': 0.22086797333699543,
#   'NFLX weight': 0.18111837175163498,
#   'AAPL weight': 0.0990470495073546,
#   'PFE weight': 0.10339014679976821,
#   'BTC weight': 0.13629987398889898},
#  {'Returns': 19.086237317899258,
#   'Volatility': 0.17583266870861425,
#   'SHOP weight': 0.0031397948858334817,
#   'TSLA weight': 0.07351770974738603,
#   'GOLD weight': 0.1595108407985051,
#   'DAL weight': 0.0788430098590517,
#   'NFLX weight': 0.20792346953948138,
#   'AAPL weight': 0.19981686861423706,
#   'PFE weight': 0.26609530048464475,
#   'BTC weight': 0.011153006070860389},
#  {'Returns': 19.617843768741245,
#   'Volatility': 0.19269982448885123,
#   'SHOP weight': 0.14307163816542876,
#   'TSLA weight': 0.1061621564284861,
#   'GOLD weight': 0.0760538071658398,
#   'DAL weight': 0.08313081475179677,
#   'NFLX weight': 0.25031428957040264,
#   'AAPL weight': 0.06194021149753033,
#   'PFE weight': 0.050406076567583336,
#   'BTC weight': 0.2289210058529322},
#  {'Returns': 22.864775433796364,
#   'Volatility': 0.18807363700193763,
#   'SHOP weight': 0.04295614587267984,
#   'TSLA weight': 0.17706967780995897,
#   'GOLD weight': 0.1235260590264121,
#   'DAL weight': 0.07420159481316695,
#   'NFLX weight': 0.14145249792841832,
#   'AAPL weight': 0.15672059784395695,
#   'PFE weight': 0.15691999162960069,
#   'BTC weight': 0.12715343507580612},
#  {'Returns': 15.473639523719214,
#   'Volatility': 0.1743818240369929,
#   'SHOP weight': 0.047094663565764076,
#   'TSLA weight': 0.07399887119613001,
#   'GOLD weight': 0.19884275823887562,
#   'DAL weight': 0.12712647274185987,
#   'NFLX weight': 0.20432192219436945,
#   'AAPL weight': 0.12217762960776402,
#   'PFE weight': 0.1457867307684042,
#   'BTC weight': 0.08065095168683281},
#  {'Returns': 23.324452279285293,
#   'Volatility': 0.22131467824680084,
#   'SHOP weight': 0.07211368864667762,
#   'TSLA weight': 0.20946387900655544,
#   'GOLD weight': 0.16684637622952897,
#   'DAL weight': 0.19884157472898725,
#   'NFLX weight': 0.12922712799992878,
#   'AAPL weight': 0.12973249501861692,
#   'PFE weight': 0.0026941623253406897,
#   'BTC weight': 0.09108069604436435},
#  {'Returns': 23.777288676119845,
#   'Volatility': 0.22886127486563093,
#   'SHOP weight': 0.21840031914610455,
#   'TSLA weight': 0.09582619994332768,
#   'GOLD weight': 0.14751300029944453,
#   'DAL weight': 0.1328376739199129,
#   'NFLX weight': 0.1718256199437623,
#   'AAPL weight': 0.15476014871120947,
#   'PFE weight': 0.07676457929694479,
#   'BTC weight': 0.0020724587392938255},
#  {'Returns': 27.192244939563604,
#   'Volatility': 0.1824177516542274,
#   'SHOP weight': 0.16713051776094953,
#   'TSLA weight': 0.12394293920624909,
#   'GOLD weight': 0.05583066128371535,
#   'DAL weight': 0.159073076392803,
#   'NFLX weight': 0.1401633780766257,
#   'AAPL weight': 0.027501128298515188,
#   'PFE weight': 0.14625801887608045,
#   'BTC weight': 0.18010028010506177},
#  {'Returns': 23.366429966200243,
#   'Volatility': 0.24581619197451762,
#   'SHOP weight': 0.019254286269664835,
#   'TSLA weight': 0.24447985406207567,
#   'GOLD weight': 0.11467573108314959,
#   'DAL weight': 0.029256411680766314,
#   'NFLX weight': 0.25258166690103473,
#   'AAPL weight': 0.2319312522649698,
#   'PFE weight': 0.04464474330804505,
#   'BTC weight': 0.06317605443029405},
#  {'Returns': 31.806334640212757,
#   'Volatility': 0.2004006947669682,
#   'SHOP weight': 0.2450270126279928,
#   'TSLA weight': 0.05649229930095016,
#   'GOLD weight': 0.055666913274893995,
#   'DAL weight': 0.19038629124326573,
#   'NFLX weight': 0.1109578543320337,
#   'AAPL weight': 0.07930921890504372,
#   'PFE weight': 0.24670834961466773,
#   'BTC weight': 0.01545206070115216},
#  {'Returns': 20.010479967326464,
#   'Volatility': 0.21599753847454076,
#   'SHOP weight': 0.07609398525771177,
#   'TSLA weight': 0.17275504369356304,
#   'GOLD weight': 0.10379572277948391,
#   'DAL weight': 0.038654868980742975,
#   'NFLX weight': 0.2491182806655065,
#   'AAPL weight': 0.16361581858518445,
#   'PFE weight': 0.03619927044155367,
#   'BTC weight': 0.15976700959625367},
#  {'Returns': 12.339977950504219,
#   'Volatility': 0.2123864484516265,
#   'SHOP weight': 0.09358011579097934,
#   'TSLA weight': 0.10114621128981816,
#   'GOLD weight': 0.2626018701446942,
#   'DAL weight': 0.0805835364456621,
#   'NFLX weight': 0.22337076006024384,
#   'AAPL weight': 0.14907542478462565,
#   'PFE weight': 0.04738550372308743,
#   'BTC weight': 0.04225657776088925},
#  {'Returns': 30.598587722286258,
#   'Volatility': 0.20495927077012238,
#   'SHOP weight': 0.2847694744935066,
#   'TSLA weight': 0.10529541355128556,
#   'GOLD weight': 0.07116264111078274,
#   'DAL weight': 0.16194140651872033,
#   'NFLX weight': 0.010320013926786185,
#   'AAPL weight': 0.05350959328034054,
#   'PFE weight': 0.17254767120300718,
#   'BTC weight': 0.14045378591557076},
#  {'Returns': 25.183821408237442,
#   'Volatility': 0.1957862387607224,
#   'SHOP weight': 0.18179524848919112,
#   'TSLA weight': 0.040617723128008244,
#   'GOLD weight': 0.10333509493852755,
#   'DAL weight': 0.28295410596176307,
#   'NFLX weight': 0.1979486209536119,
#   'AAPL weight': 0.020638525717895703,
#   'PFE weight': 0.11831648209036123,
#   'BTC weight': 0.05439419872064123},
#  {'Returns': 23.88338146535759,
#   'Volatility': 0.1822698788483797,
#   'SHOP weight': 0.05595040203281393,
#   'TSLA weight': 0.12611471285570378,
#   'GOLD weight': 0.13693379517695423,
#   'DAL weight': 0.11476607421586454,
#   'NFLX weight': 0.13433956298866775,
#   'AAPL weight': 0.17052401419605673,
#   'PFE weight': 0.2218243623625914,
#   'BTC weight': 0.03954707617134761},
#  {'Returns': 18.598179225136484,
#   'Volatility': 0.17798596306821446,
#   'SHOP weight': 0.015713700931807878,
#   'TSLA weight': 0.13300193030245527,
#   'GOLD weight': 0.1483385450579934,
#   'DAL weight': 0.16193511568863872,
#   'NFLX weight': 0.12548340042007095,
#   'AAPL weight': 0.19172527314671983,
#   'PFE weight': 0.06620924416690402,
#   'BTC weight': 0.1575927902854099}]

# %% [markdown]
# for index, row in portfolios.iterrows():
#     portf_dict = [row]
#     print(portf_dict)

# %%
# convert into JSON and save it as a separate file:
#portf = portfolios.to_json()
#port = json.dumps(port)
with open('../Data/portfolio_data.json', 'w') as outfile:
    json.dump(portf, outfile)

portf
# Out:
# [{'Returns': 26.160450824882904,
#   'Volatility': 0.21828089876911982,
#   'SHOP weight': 0.06536601361405572,
#   'TSLA weight': 0.096726648925057,
#   'GOLD weight': 0.053761882140969865,
#   'DAL weight': 0.2679694584315692,
#   'NFLX weight': 0.27123087241102223,
#   'AAPL weight': 0.20501621253437927,
#   'PFE weight': 0.028436170018155432,
#   'BTC weight': 0.011492741924791177},
#  {'Returns': 22.950931632756355,
#   'Volatility': 0.1911225002726121,
#   'SHOP weight': 0.06129677596705047,
#   'TSLA weight': 0.15346863167104455,
#   'GOLD weight': 0.0908890374776214,
#   'DAL weight': 0.20257450471984473,
#   'NFLX weight': 0.21419396296846455,
#   'AAPL weight': 0.06073831434198207,
#   'PFE weight': 0.04490319185482104,
#   'BTC weight': 0.17193558099917114},
#  {'Returns': 20.16019196915421,
#   'Volatility': 0.1668181317841796,
#   'SHOP weight': 0.031605815141043006,
#   'TSLA weight': 0.14149445579231007,
#   'GOLD weight': 0.16467041691654524,
#   'DAL weight': 0.11205281450819568,
#   'NFLX weight': 0.0331197100662315,
#   'AAPL weight': 0.179108251310606,
#   'PFE weight': 0.17664845943046098,
#   'BTC weight': 0.1613000768346075},
#  {'Returns': 20.715572242334794,
#   'Volatility': 0.19458417473740108,
#   'SHOP weight': 0.06012429978660469,
#   'TSLA weight': 0.20612369633417624,
#   'GOLD weight': 0.17348667779379853,
#   'DAL weight': 0.12643240403102368,
#   'NFLX weight': 0.08231344035120067,
#   'AAPL weight': 0.10567873219169059,
#   'PFE weight': 0.06282482939190534,
#   'BTC weight': 0.18301592011960024},
#  {'Returns': 11.197541151324367,
#   'Volatility': 0.20996044479487502,
#   'SHOP weight': 0.18400962439580054,
#   'TSLA weight': 0.005124662598108805,
#   'GOLD weight': 0.22640511352103931,
#   'DAL weight': 0.05370526503666326,
#   'NFLX weight': 0.22309310287839093,
#   'AAPL weight': 0.15608713656265963,
#   'PFE weight': 0.07765601970860207,
#   'BTC weight': 0.07391907529873541},
#  {'Returns': 32.5548208694855,
#   'Volatility': 0.19833497149761495,
#   'SHOP weight': 0.1520000207096021,
#   'TSLA weight': 0.12942021197148662,
#   'GOLD weight': 0.0006742994107469324,
#   'DAL weight': 0.1641233302827578,
#   'NFLX weight': 0.11689868823453388,
#   'AAPL weight': 0.17674622581728483,
#   'PFE weight': 0.16942877776829723,
#   'BTC weight': 0.09070844580529058},
#  {'Returns': 13.446149661268484,
#   'Volatility': 0.18705352344122725,
#   'SHOP weight': 0.19178931408003239,
#   'TSLA weight': 0.010964737254034173,
#   'GOLD weight': 0.18990625103299116,
#   'DAL weight': 0.08117103379261348,
#   'NFLX weight': 0.20463311162442033,
#   'AAPL weight': 0.06142195765174033,
#   'PFE weight': 0.11387850240275416,
#   'BTC weight': 0.14623509216141406},
#  {'Returns': 28.81691040879895,
#   'Volatility': 0.18440029568616248,
#   'SHOP weight': 0.1405680026019822,
#   'TSLA weight': 0.13759102944607973,
#   'GOLD weight': 0.06017250617539556,
#   'DAL weight': 0.1632863127534172,
#   'NFLX weight': 0.16662789771747258,
#   'AAPL weight': 0.006553649180216308,
#   'PFE weight': 0.1975953363469671,
#   'BTC weight': 0.12760526577846928},
#  {'Returns': 26.142448616699923,
#   'Volatility': 0.2152562060925414,
#   'SHOP weight': 0.053041351942250625,
#   'TSLA weight': 0.21286623874306337,
#   'GOLD weight': 0.08845538171991012,
#   'DAL weight': 0.20234177307661652,
#   'NFLX weight': 0.20626984948322882,
#   'AAPL weight': 0.07610803854392172,
#   'PFE weight': 0.02671736725191432,
#   'BTC weight': 0.13419999923909456},
#  {'Returns': 11.609334848634044,
#   'Volatility': 0.18641656098977366,
#   'SHOP weight': 0.013818827288219763,
#   'TSLA weight': 0.01963769327848706,
#   'GOLD weight': 0.31158343734022736,
#   'DAL weight': 0.28183410617014043,
#   'NFLX weight': 0.18462987138988585,
#   'AAPL weight': 0.008562921883241006,
#   'PFE weight': 0.17614366039406,
#   'BTC weight': 0.0037894822557384892},
#  {'Returns': 23.322154157705693,
#   'Volatility': 0.17524938412989957,
#   'SHOP weight': 0.048545825626806115,
#   'TSLA weight': 0.16296824593922415,
#   'GOLD weight': 0.08989838370073651,
#   'DAL weight': 0.05085859051888654,
#   'NFLX weight': 0.14414049711878565,
#   'AAPL weight': 0.13641754825679883,
#   'PFE weight': 0.1933313689820792,
#   'BTC weight': 0.17383953985668307},
#  {'Returns': 17.372595152018512,
#   'Volatility': 0.15668803922848415,
#   'SHOP weight': 0.019600796033657383,
#   'TSLA weight': 0.11814103027314617,
#   'GOLD weight': 0.19987158571605845,
#   'DAL weight': 0.09985337445171558,
#   'NFLX weight': 0.02217622363408373,
#   'AAPL weight': 0.1546052730600063,
#   'PFE weight': 0.21716728089003393,
#   'BTC weight': 0.16858443594129835},
#  {'Returns': 25.047842838124904,
#   'Volatility': 0.1998013940853861,
#   'SHOP weight': 0.1621317207421865,
#   'TSLA weight': 0.14714938006814948,
#   'GOLD weight': 0.13022650322950163,
#   'DAL weight': 0.1266428603797401,
#   'NFLX weight': 0.14997699223632907,
#   'AAPL weight': 0.0427037611401964,
#   'PFE weight': 0.14198606032037756,
#   'BTC weight': 0.09918272188351934},
#  {'Returns': 23.924464824204566,
#   'Volatility': 0.16818205638396616,
#   'SHOP weight': 0.18021202961283223,
#   'TSLA weight': 0.04333760840143215,
#   'GOLD weight': 0.09037545066557183,
#   'DAL weight': 0.17838542098821691,
#   'NFLX weight': 0.06470238866157092,
#   'AAPL weight': 0.12296129218702792,
#   'PFE weight': 0.16742779863328705,
#   'BTC weight': 0.15259801085006103},
#  {'Returns': 21.282015870956485,
#   'Volatility': 0.21627573832894334,
#   'SHOP weight': 0.08949891471242724,
#   'TSLA weight': 0.15002258439985214,
#   'GOLD weight': 0.17666062734809726,
#   'DAL weight': 0.13116420158326242,
#   'NFLX weight': 0.16308748407030862,
#   'AAPL weight': 0.20773064155875628,
#   'PFE weight': 0.061623679681024994,
#   'BTC weight': 0.02021186664627116},
#  {'Returns': 24.0267547192136,
#   'Volatility': 0.18310340677592934,
#   'SHOP weight': 0.020269208515564366,
#   'TSLA weight': 0.1498954850548156,
#   'GOLD weight': 0.056285248229088945,
#   'DAL weight': 0.18351898460073995,
#   'NFLX weight': 0.09126481051559805,
#   'AAPL weight': 0.2496792158761064,
#   'PFE weight': 0.051931620867701846,
#   'BTC weight': 0.19715542634038483},
#  {'Returns': 23.1606490715982,
#   'Volatility': 0.23197745101200273,
#   'SHOP weight': 0.1938042924350189,
#   'TSLA weight': 0.15071820735462854,
#   'GOLD weight': 0.1413928291042002,
#   'DAL weight': 0.07342857991927812,
#   'NFLX weight': 0.13522157084198363,
#   'AAPL weight': 0.18349815751387477,
#   'PFE weight': 0.04534315554061677,
#   'BTC weight': 0.0765932072903991},
#  {'Returns': 9.148796112770643,
#   'Volatility': 0.17439594872401187,
#   'SHOP weight': 0.10047835523505114,
#   'TSLA weight': 0.01904111620826263,
#   'GOLD weight': 0.19195828178708824,
#   'DAL weight': 0.08367895139159867,
#   'NFLX weight': 0.23439157498607802,
#   'AAPL weight': 0.1266807938354384,
#   'PFE weight': 0.04365826868241721,
#   'BTC weight': 0.2001126578740656},
#  {'Returns': 27.35655592328629,
#   'Volatility': 0.18244784543058595,
#   'SHOP weight': 0.09494033827257053,
#   'TSLA weight': 0.18938013688188493,
#   'GOLD weight': 0.04467427226216784,
#   'DAL weight': 0.00953637927383639,
#   'NFLX weight': 0.060936830057213884,
#   'AAPL weight': 0.1569473121186745,
#   'PFE weight': 0.22070772584668458,
#   'BTC weight': 0.2228770052869675},
#  {'Returns': 19.34486582431773,
#   'Volatility': 0.17226833764199623,
#   'SHOP weight': 0.08668858805046793,
#   'TSLA weight': 0.026781711161138956,
#   'GOLD weight': 0.19458374887649635,
#   'DAL weight': 0.21829257105911495,
#   'NFLX weight': 0.11984621811198866,
#   'AAPL weight': 0.12353772760484054,
#   'PFE weight': 0.21084064878799041,
#   'BTC weight': 0.019428786347962163},
#  {'Returns': 37.52685919737439,
#   'Volatility': 0.2201640755428277,
#   'SHOP weight': 0.048393771652107315,
#   'TSLA weight': 0.24427680357763526,
#   'GOLD weight': 0.004540180343118507,
#   'DAL weight': 0.13132948972545674,
#   'NFLX weight': 0.06439722974765372,
#   'AAPL weight': 0.23056872063532136,
#   'PFE weight': 0.24104206084392943,
#   'BTC weight': 0.0354517434747776},
#  {'Returns': 27.150767781466826,
#   'Volatility': 0.22453081308444872,
#   'SHOP weight': 0.046548883706061965,
#   'TSLA weight': 0.27522506752115766,
#   'GOLD weight': 0.17633977690022537,
#   'DAL weight': 0.0922975740162889,
#   'NFLX weight': 0.06405542078328645,
#   'AAPL weight': 0.12909436817536193,
#   'PFE weight': 0.1587585139586248,
#   'BTC weight': 0.05768039493899298},
#  {'Returns': 35.142420440335144,
#   'Volatility': 0.20576476050977616,
#   'SHOP weight': 0.19917234628343045,
#   'TSLA weight': 0.17923394998018313,
#   'GOLD weight': 0.0009885098812526607,
#   'DAL weight': 0.13973929569794236,
#   'NFLX weight': 0.10252489061679568,
#   'AAPL weight': 0.03193974717447726,
#   'PFE weight': 0.2058104761295654,
#   'BTC weight': 0.14059078423635313},
#  {'Returns': 35.534462754126665,
#   'Volatility': 0.2160180130626627,
#   'SHOP weight': 0.1928917216672017,
#   'TSLA weight': 0.19778919788562355,
#   'GOLD weight': 0.04341122982080009,
#   'DAL weight': 0.1944869767918982,
#   'NFLX weight': 0.008408647225772331,
#   'AAPL weight': 0.09731584555773438,
#   'PFE weight': 0.16258438374918574,
#   'BTC weight': 0.10311199730178408},
#  {'Returns': 16.140935570903032,
#   'Volatility': 0.2201215644819726,
#   'SHOP weight': 0.20540062737451464,
#   'TSLA weight': 0.158732382151535,
#   'GOLD weight': 0.20748921967727227,
#   'DAL weight': 0.028694296911915978,
#   'NFLX weight': 0.11593566561267493,
#   'AAPL weight': 0.05586781070702277,
#   'PFE weight': 0.011571084567200398,
#   'BTC weight': 0.21630891299786398},
#  {'Returns': 19.709833807300726,
#   'Volatility': 0.20393926206971438,
#   'SHOP weight': 0.1408207147257719,
#   'TSLA weight': 0.13631993262161007,
#   'GOLD weight': 0.1856146146200774,
#   'DAL weight': 0.06312126813071654,
#   'NFLX weight': 0.0957975479640887,
#   'AAPL weight': 0.17986720133692916,
#   'PFE weight': 0.10183769929081606,
#   'BTC weight': 0.09662102130999008},
#  {'Returns': 26.25454536798636,
#   'Volatility': 0.24676457204803517,
#   'SHOP weight': 0.18122145850463886,
#   'TSLA weight': 0.22561469164997827,
#   'GOLD weight': 0.23311706111368338,
#   'DAL weight': 0.18993631916576417,
#   'NFLX weight': 0.020629457636754448,
#   'AAPL weight': 0.10488599168778642,
#   'PFE weight': 0.04226692031392874,
#   'BTC weight': 0.0023280999274657623},
#  {'Returns': 24.154140432686972,
#   'Volatility': 0.1920939270476969,
#   'SHOP weight': 0.17887897840234102,
#   'TSLA weight': 0.05905349552638846,
#   'GOLD weight': 0.1580018772972894,
#   'DAL weight': 0.1893355767128318,
#   'NFLX weight': 0.08913012475596543,
#   'AAPL weight': 0.13645551578824924,
#   'PFE weight': 0.1795037018457255,
#   'BTC weight': 0.009640729671209282},
#  {'Returns': 20.915584013714835,
#   'Volatility': 0.17387508725574402,
#   'SHOP weight': 0.2158221389655956,
#   'TSLA weight': 0.014356943610201197,
#   'GOLD weight': 0.10398485740386666,
#   'DAL weight': 0.25237326111544733,
#   'NFLX weight': 0.09091567564107876,
#   'AAPL weight': 0.039497247610423926,
#   'PFE weight': 0.06868953997403274,
#   'BTC weight': 0.2143603356793538},
#  {'Returns': 22.85818854232014,
#   'Volatility': 0.19040701432084225,
#   'SHOP weight': 0.039656280507345404,
#   'TSLA weight': 0.1800181913600319,
#   'GOLD weight': 0.12385857808566178,
#   'DAL weight': 0.10883952840630094,
#   'NFLX weight': 0.14042626243495954,
#   'AAPL weight': 0.15614352143203816,
#   'PFE weight': 0.11938939818257938,
#   'BTC weight': 0.13166823959108284},
#  {'Returns': 22.335213704323287,
#   'Volatility': 0.22151554459784673,
#   'SHOP weight': 0.08820328107540149,
#   'TSLA weight': 0.2213661672025514,
#   'GOLD weight': 0.14410749363409808,
#   'DAL weight': 0.04987256960995925,
#   'NFLX weight': 0.18900584117986144,
#   'AAPL weight': 0.10832218450735756,
#   'PFE weight': 0.06961454704338048,
#   'BTC weight': 0.1295079157473904},
#  {'Returns': 14.54921912803669,
#   'Volatility': 0.18972187222801168,
#   'SHOP weight': 0.10941137871080933,
#   'TSLA weight': 0.04787558092152402,
#   'GOLD weight': 0.23567432479241193,
#   'DAL weight': 0.21379602337057874,
#   'NFLX weight': 0.2207279536845909,
#   'AAPL weight': 0.0377637836834141,
#   'PFE weight': 0.07721726013962069,
#   'BTC weight': 0.057533694697050275},
#  {'Returns': 20.498699738702637,
#   'Volatility': 0.1808604978481775,
#   'SHOP weight': 0.047841506971665226,
#   'TSLA weight': 0.1518880784365104,
#   'GOLD weight': 0.1635494193188024,
#   'DAL weight': 0.18741758896923183,
#   'NFLX weight': 0.15854446648010515,
#   'AAPL weight': 0.043107773445663855,
#   'PFE weight': 0.10307342325953821,
#   'BTC weight': 0.14457774311848293},
#  {'Returns': 9.60227098047563,
#   'Volatility': 0.1756413403285838,
#   'SHOP weight': 0.05005579650926226,
#   'TSLA weight': 0.014179611925712907,
#   'GOLD weight': 0.1113515771713838,
#   'DAL weight': 0.10692830865973128,
#   'NFLX weight': 0.3627460117699593,
#   'AAPL weight': 0.0839421898389136,
#   'PFE weight': 0.01054868075941834,
#   'BTC weight': 0.26024782336561847},
#  {'Returns': 22.939717296988302,
#   'Volatility': 0.26038372718221414,
#   'SHOP weight': 0.23303307467147838,
#   'TSLA weight': 0.2162997026958273,
#   'GOLD weight': 0.1845973711884744,
#   'DAL weight': 0.012273931515677421,
#   'NFLX weight': 0.15459617860547892,
#   'AAPL weight': 0.06023607282757876,
#   'PFE weight': 0.043007267775048395,
#   'BTC weight': 0.09595640072043651},
#  {'Returns': 25.531680592151147,
#   'Volatility': 0.19961539423228436,
#   'SHOP weight': 0.06543110946024823,
#   'TSLA weight': 0.23739709767078357,
#   'GOLD weight': 0.12590044263703737,
#   'DAL weight': 0.20176819013574426,
#   'NFLX weight': 0.014495271497246344,
#   'AAPL weight': 0.06756846983008837,
#   'PFE weight': 0.049308804862175114,
#   'BTC weight': 0.2381306139066768},
#  {'Returns': 21.288538263440707,
#   'Volatility': 0.18131565972916855,
#   'SHOP weight': 0.14643218888327286,
#   'TSLA weight': 0.10771381955786627,
#   'GOLD weight': 0.11566960356097185,
#   'DAL weight': 0.0774235194321613,
#   'NFLX weight': 0.13709975741472769,
#   'AAPL weight': 0.11058938079227151,
#   'PFE weight': 0.1365533488724235,
#   'BTC weight': 0.168518381486305},
#  {'Returns': 15.85167932219528,
#   'Volatility': 0.1974883083241828,
#   'SHOP weight': 0.20059594887672733,
#   'TSLA weight': 0.03574222576373085,
#   'GOLD weight': 0.14272365244818802,
#   'DAL weight': 0.10956141858704083,
#   'NFLX weight': 0.13005112058197008,
#   'AAPL weight': 0.19766795958153635,
#   'PFE weight': 0.0027725380876027876,
#   'BTC weight': 0.18088513607320383},
#  {'Returns': 22.54494777728894,
#   'Volatility': 0.1998512035766876,
#   'SHOP weight': 0.0669700952825817,
#   'TSLA weight': 0.11669072726982707,
#   'GOLD weight': 0.10854254733384452,
#   'DAL weight': 0.18204568850157143,
#   'NFLX weight': 0.2398751233516074,
#   'AAPL weight': 0.14949863229217802,
#   'PFE weight': 0.07389193710905193,
#   'BTC weight': 0.062485248859337934},
#  {'Returns': 21.815095460126237,
#   'Volatility': 0.1855271052777411,
#   'SHOP weight': 0.11921553991167318,
#   'TSLA weight': 0.11714263375216655,
#   'GOLD weight': 0.08859377233212444,
#   'DAL weight': 0.05471173746741493,
#   'NFLX weight': 0.14320890640752,
#   'AAPL weight': 0.18278733086618307,
#   'PFE weight': 0.12466377044022073,
#   'BTC weight': 0.16967630882269702},
#  {'Returns': 22.088880856879122,
#   'Volatility': 0.15230045965347405,
#   'SHOP weight': 0.10241921860921775,
#   'TSLA weight': 0.08150972116308261,
#   'GOLD weight': 0.052102381328370674,
#   'DAL weight': 0.17883680399418442,
#   'NFLX weight': 0.07642706649666262,
#   'AAPL weight': 0.14204422033717792,
#   'PFE weight': 0.09200351711011899,
#   'BTC weight': 0.2746570709611851},
#  {'Returns': 13.567980653392599,
#   'Volatility': 0.15626204594195187,
#   'SHOP weight': 0.057076512307787985,
#   'TSLA weight': 0.041470288701028604,
#   'GOLD weight': 0.24997669029987796,
#   'DAL weight': 0.1757171265978083,
#   'NFLX weight': 0.13672851600959296,
#   'AAPL weight': 0.0029819603383588193,
#   'PFE weight': 0.21819758015137705,
#   'BTC weight': 0.11785132559416828},
#  {'Returns': 30.254107292145413,
#   'Volatility': 0.21025086356164097,
#   'SHOP weight': 0.15515202241696807,
#   'TSLA weight': 0.20463135346128508,
#   'GOLD weight': 0.06442640385667582,
#   'DAL weight': 0.0983384895035293,
#   'NFLX weight': 0.05781102561188307,
#   'AAPL weight': 0.1391939439748173,
#   'PFE weight': 0.13615840548486444,
#   'BTC weight': 0.144288355689977},
#  {'Returns': 28.412911312221098,
#   'Volatility': 0.24371114105087693,
#   'SHOP weight': 0.09665761590270083,
#   'TSLA weight': 0.2471130274065828,
#   'GOLD weight': 0.16424424688621342,
#   'DAL weight': 0.26327509484854333,
#   'NFLX weight': 0.09201784981711711,
#   'AAPL weight': 0.09671869156698783,
#   'PFE weight': 0.0019784871055631265,
#   'BTC weight': 0.037994986466291625},
#  {'Returns': 18.77947946273135,
#   'Volatility': 0.1752205100080354,
#   'SHOP weight': 0.12202860530518103,
#   'TSLA weight': 0.06438954048370511,
#   'GOLD weight': 0.21343435187357496,
#   'DAL weight': 0.13108326828010197,
#   'NFLX weight': 0.08505226981741307,
#   'AAPL weight': 0.12331989143292706,
#   'PFE weight': 0.20986166851520313,
#   'BTC weight': 0.05083040429189369},
#  {'Returns': 12.626282164690833,
#   'Volatility': 0.150316643649817,
#   'SHOP weight': 0.0023717976495561707,
#   'TSLA weight': 0.08641515171748547,
#   'GOLD weight': 0.18200017305326377,
#   'DAL weight': 0.12443499170119073,
#   'NFLX weight': 0.1574071948427927,
#   'AAPL weight': 0.1169637095883625,
#   'PFE weight': 0.10429483809592226,
#   'BTC weight': 0.2261121433514265},
#  {'Returns': 23.965546684011343,
#   'Volatility': 0.17490279686625834,
#   'SHOP weight': 0.17151754687675175,
#   'TSLA weight': 0.08020256259253013,
#   'GOLD weight': 0.09541310279633493,
#   'DAL weight': 0.17280934934236955,
#   'NFLX weight': 0.11261083948709118,
#   'AAPL weight': 0.06766163958272402,
#   'PFE weight': 0.1390627179623362,
#   'BTC weight': 0.16072224135986227},
#  {'Returns': 14.006505282142324,
#   'Volatility': 0.1722454429637105,
#   'SHOP weight': 0.04494899538006328,
#   'TSLA weight': 0.03313205344216165,
#   'GOLD weight': 0.24958655133106575,
#   'DAL weight': 0.13785123302006186,
#   'NFLX weight': 0.0784603672546142,
#   'AAPL weight': 0.22842476790021668,
#   'PFE weight': 0.19458402699515773,
#   'BTC weight': 0.03301200467665893},
#  {'Returns': 20.27030623718951,
#   'Volatility': 0.22790678793220998,
#   'SHOP weight': 0.19412730424681404,
#   'TSLA weight': 0.19664804474593253,
#   'GOLD weight': 0.23008623759693025,
#   'DAL weight': 0.002910909628654155,
#   'NFLX weight': 0.028068701081159473,
#   'AAPL weight': 0.1155103081367071,
#   'PFE weight': 0.10845783657058321,
#   'BTC weight': 0.12419065799321927},
#  {'Returns': 28.06790475140414,
#   'Volatility': 0.19279912805738064,
#   'SHOP weight': 0.13446396895109297,
#   'TSLA weight': 0.19012730355009766,
#   'GOLD weight': 0.06572479970630307,
#   'DAL weight': 0.13092005022275893,
#   'NFLX weight': 0.027713624200806756,
#   'AAPL weight': 0.132199053913087,
#   'PFE weight': 0.10639713547808179,
#   'BTC weight': 0.21245406397777195},
#  {'Returns': 21.15544912185365,
#   'Volatility': 0.19601623060814358,
#   'SHOP weight': 0.10798711952688848,
#   'TSLA weight': 0.15293691951654934,
#   'GOLD weight': 0.1289697656476198,
#   'DAL weight': 0.056431374302943274,
#   'NFLX weight': 0.1464582836109536,
#   'AAPL weight': 0.1541688956240733,
#   'PFE weight': 0.10445358627717687,
#   'BTC weight': 0.14859405549379537},
#  {'Returns': 22.8049298609454,
#   'Volatility': 0.18751595063389478,
#   'SHOP weight': 0.1899278137987202,
#   'TSLA weight': 0.14304443690931426,
#   'GOLD weight': 0.16461290435663184,
#   'DAL weight': 0.15667570495537037,
#   'NFLX weight': 0.020841248130486822,
#   'AAPL weight': 0.02103912561384078,
#   'PFE weight': 0.10722538745710135,
#   'BTC weight': 0.19663337877853446},
#  {'Returns': 27.170280261084127,
#   'Volatility': 0.21570094707114917,
#   'SHOP weight': 0.1263989803147491,
#   'TSLA weight': 0.18620188567236282,
#   'GOLD weight': 0.10745778600494475,
#   'DAL weight': 0.20657667101553556,
#   'NFLX weight': 0.01264403369513331,
#   'AAPL weight': 0.2154436478427019,
#   'PFE weight': 0.014116771978651604,
#   'BTC weight': 0.13116022347592082},
#  {'Returns': 22.803352614125966,
#   'Volatility': 0.18586168646375173,
#   'SHOP weight': 0.15184945358771548,
#   'TSLA weight': 0.05923332389362272,
#   'GOLD weight': 0.13077229315420316,
#   'DAL weight': 0.15750837441942173,
#   'NFLX weight': 0.15322392175765728,
#   'AAPL weight': 0.13367277673794747,
#   'PFE weight': 0.16619356950063627,
#   'BTC weight': 0.04754628694879586},
#  {'Returns': 23.280599775841758,
#   'Volatility': 0.19215121660153506,
#   'SHOP weight': 0.15623341502951182,
#   'TSLA weight': 0.07322633281897895,
#   'GOLD weight': 0.05740658124277199,
#   'DAL weight': 0.1742390038870919,
#   'NFLX weight': 0.1441882165072198,
#   'AAPL weight': 0.2019618625179198,
#   'PFE weight': 0.03437016821202821,
#   'BTC weight': 0.1583744197844775},
#  {'Returns': 15.147753562557021,
#   'Volatility': 0.16013647187286184,
#   'SHOP weight': 0.039264996243857354,
#   'TSLA weight': 0.049719398059647736,
#   'GOLD weight': 0.20140634821657455,
#   'DAL weight': 0.19551580233018012,
#   'NFLX weight': 0.21112325908370794,
#   'AAPL weight': 0.003680190565680234,
#   'PFE weight': 0.1796256237761594,
#   'BTC weight': 0.11966438172419258},
#  {'Returns': 27.694292839092142,
#   'Volatility': 0.21831774017732128,
#   'SHOP weight': 0.13396817355338617,
#   'TSLA weight': 0.17811489178473464,
#   'GOLD weight': 0.05484265623097145,
#   'DAL weight': 0.049025523672316176,
#   'NFLX weight': 0.17718622238869522,
#   'AAPL weight': 0.17526403086102849,
#   'PFE weight': 0.1273054005858099,
#   'BTC weight': 0.10429310092305794},
#  {'Returns': 20.70197714207912,
#   'Volatility': 0.15778700211931046,
#   'SHOP weight': 0.01883210837325899,
#   'TSLA weight': 0.006100617731833231,
#   'GOLD weight': 0.09197311849046719,
#   'DAL weight': 0.19277257313932408,
#   'NFLX weight': 0.15969589787515345,
#   'AAPL weight': 0.21424200931471,
#   'PFE weight': 0.23697752481866632,
#   'BTC weight': 0.07940615025658677},
#  {'Returns': 10.148006342113886,
#   'Volatility': 0.12542043729646393,
#   'SHOP weight': 0.031547439126082474,
#   'TSLA weight': 0.04631880717022942,
#   'GOLD weight': 0.190942490123533,
#   'DAL weight': 0.049535242041602326,
#   'NFLX weight': 0.0784368682036714,
#   'AAPL weight': 0.1126201501079782,
#   'PFE weight': 0.18988285233669336,
#   'BTC weight': 0.3007161508902099},
#  {'Returns': 18.63834063084103,
#   'Volatility': 0.20038381255785837,
#   'SHOP weight': 0.050167650680838685,
#   'TSLA weight': 0.1360323892375469,
#   'GOLD weight': 0.14052459146443133,
#   'DAL weight': 0.014096037869780685,
#   'NFLX weight': 0.26129457602312983,
#   'AAPL weight': 0.1540235004867669,
#   'PFE weight': 0.1526474675727346,
#   'BTC weight': 0.0912137866647711},
#  {'Returns': 19.44215040306697,
#   'Volatility': 0.16449255961305315,
#   'SHOP weight': 0.04272690197861095,
#   'TSLA weight': 0.07200769253422226,
#   'GOLD weight': 0.16500265460292848,
#   'DAL weight': 0.19290661432383552,
#   'NFLX weight': 0.18494053265537408,
#   'AAPL weight': 0.053491202511446616,
#   'PFE weight': 0.2027775142446645,
#   'BTC weight': 0.0861468871489176},
#  {'Returns': 22.884449838400965,
#   'Volatility': 0.20601312194804725,
#   'SHOP weight': 0.1243716924357424,
#   'TSLA weight': 0.17172640676855638,
#   'GOLD weight': 0.13336516226242962,
#   'DAL weight': 0.12803555917290094,
#   'NFLX weight': 0.20052038358218388,
#   'AAPL weight': 0.035536124893582696,
#   'PFE weight': 0.07383220747712607,
#   'BTC weight': 0.13261246340747795},
#  {'Returns': 23.32818916881181,
#   'Volatility': 0.18723723162790942,
#   'SHOP weight': 0.1561071082021193,
#   'TSLA weight': 0.1273738521089086,
#   'GOLD weight': 0.15015106782747212,
#   'DAL weight': 0.07842367044266295,
#   'NFLX weight': 0.03545105298842272,
#   'AAPL weight': 0.15209896708616813,
#   'PFE weight': 0.182386432480325,
#   'BTC weight': 0.11800784886392122},
#  {'Returns': 8.474345797701037,
#   'Volatility': 0.16708811771438842,
#   'SHOP weight': 0.028202483262424485,
#   'TSLA weight': 0.024785984895465685,
#   'GOLD weight': 0.20823959857635593,
#   'DAL weight': 0.07308319766711993,
#   'NFLX weight': 0.2009885992851847,
#   'AAPL weight': 0.2171531645272311,
#   'PFE weight': 0.08376881135742785,
#   'BTC weight': 0.16377816042879037},
#  {'Returns': 14.490997105056701,
#   'Volatility': 0.19680112413852993,
#   'SHOP weight': 0.13898203576835616,
#   'TSLA weight': 0.0294420417069731,
#   'GOLD weight': 0.2377102490670119,
#   'DAL weight': 0.056142285423425364,
#   'NFLX weight': 0.20372119735148145,
#   'AAPL weight': 0.1367734870129245,
#   'PFE weight': 0.19606088205982078,
#   'BTC weight': 0.00116782161000688},
#  {'Returns': 38.305610014820004,
#   'Volatility': 0.22757268991735816,
#   'SHOP weight': 0.2384927581024517,
#   'TSLA weight': 0.16030396292287438,
#   'GOLD weight': 0.03294714986022637,
#   'DAL weight': 0.23169184933810666,
#   'NFLX weight': 0.02260873826250253,
#   'AAPL weight': 0.11610134397308815,
#   'PFE weight': 0.18743942906884115,
#   'BTC weight': 0.010414768471908982},
#  {'Returns': 21.30829933729316,
#   'Volatility': 0.16275500386467773,
#   'SHOP weight': 0.09787243230109437,
#   'TSLA weight': 0.05952184555086261,
#   'GOLD weight': 0.10166200361874213,
#   'DAL weight': 0.14644075067229786,
#   'NFLX weight': 0.11819649493821138,
#   'AAPL weight': 0.17530689263683613,
#   'PFE weight': 0.16167478534924803,
#   'BTC weight': 0.13932479493270755},
#  {'Returns': 21.65403679994723,
#   'Volatility': 0.19410888960063719,
#   'SHOP weight': 0.038729663980245806,
#   'TSLA weight': 0.18978317015350843,
#   'GOLD weight': 0.1578677284718466,
#   'DAL weight': 0.18566079741255945,
#   'NFLX weight': 0.06697603960737898,
#   'AAPL weight': 0.151506816184252,
#   'PFE weight': 0.043961471486769384,
#   'BTC weight': 0.1655143127034395},
#  {'Returns': 21.727182519047574,
#   'Volatility': 0.19528716918621633,
#   'SHOP weight': 0.07296216031310962,
#   'TSLA weight': 0.08848797587366311,
#   'GOLD weight': 0.0986350961429295,
#   'DAL weight': 0.04451080912558153,
#   'NFLX weight': 0.24044166134973669,
#   'AAPL weight': 0.2192826216721038,
#   'PFE weight': 0.1949309178430216,
#   'BTC weight': 0.04074875767985411},
#  {'Returns': 23.1333382189109,
#   'Volatility': 0.23992491011293438,
#   'SHOP weight': 0.14615145811772667,
#   'TSLA weight': 0.19549870957208695,
#   'GOLD weight': 0.1547697372591834,
#   'DAL weight': 0.016541443661522867,
#   'NFLX weight': 0.12615187881051468,
#   'AAPL weight': 0.2301867095875821,
#   'PFE weight': 0.06927490590612871,
#   'BTC weight': 0.06142515708525463},
#  {'Returns': 25.421172115676242,
#   'Volatility': 0.2143996756536415,
#   'SHOP weight': 0.09106480304272122,
#   'TSLA weight': 0.2560523224965536,
#   'GOLD weight': 0.15023625153934536,
#   'DAL weight': 0.2189952582295995,
#   'NFLX weight': 0.024564773988088453,
#   'AAPL weight': 0.019844552031051635,
#   'PFE weight': 0.010156216867414983,
#   'BTC weight': 0.22908582180522535},
#  {'Returns': 17.977549405634512,
#   'Volatility': 0.16458646924211418,
#   'SHOP weight': 0.1667960867189866,
#   'TSLA weight': 0.05241868230209262,
#   'GOLD weight': 0.10540162316423958,
#   'DAL weight': 0.18671152600549873,
#   'NFLX weight': 0.10800166671599348,
#   'AAPL weight': 0.07891938548154936,
#   'PFE weight': 0.023951558607479703,
#   'BTC weight': 0.27779947100415986},
#  {'Returns': 32.1404932537424,
#   'Volatility': 0.20187953420438348,
#   'SHOP weight': 0.09577798967475348,
#   'TSLA weight': 0.2070644083590248,
#   'GOLD weight': 0.12054633387994271,
#   'DAL weight': 0.18814133076656916,
#   'NFLX weight': 0.06517154752221832,
#   'AAPL weight': 0.029316660424511927,
#   'PFE weight': 0.25818564890189777,
#   'BTC weight': 0.03579608047108181},
#  {'Returns': 10.969984323987592,
#   'Volatility': 0.2098797242860515,
#   'SHOP weight': 0.25597657334853774,
#   'TSLA weight': 0.050748675152975375,
#   'GOLD weight': 0.2748930480835545,
#   'DAL weight': 0.045946907884985136,
#   'NFLX weight': 0.0014029535146001166,
#   'AAPL weight': 0.15063261574200865,
#   'PFE weight': 0.031088148968464534,
#   'BTC weight': 0.18931107730487393},
#  {'Returns': 24.62121345105011,
#   'Volatility': 0.16647349710928658,
#   'SHOP weight': 0.2117863099291383,
#   'TSLA weight': 0.09584046740067652,
#   'GOLD weight': 0.053953836056849974,
#   'DAL weight': 0.05708967633580871,
#   'NFLX weight': 0.02772945704397155,
#   'AAPL weight': 0.06848683543621344,
#   'PFE weight': 0.19624262775866663,
#   'BTC weight': 0.28887079003867494},
#  {'Returns': 10.158847361317354,
#   'Volatility': 0.19811407570776823,
#   'SHOP weight': 0.06076444544556962,
#   'TSLA weight': 0.11294936765682927,
#   'GOLD weight': 0.1964200495144073,
#   'DAL weight': 0.001253662744279288,
#   'NFLX weight': 0.22675119325412404,
#   'AAPL weight': 0.18098975092900838,
#   'PFE weight': 0.014886365798001483,
#   'BTC weight': 0.20598516465778066},
#  {'Returns': 24.344822247568615,
#   'Volatility': 0.18385078188571047,
#   'SHOP weight': 0.056508592774618775,
#   'TSLA weight': 0.17007515403785736,
#   'GOLD weight': 0.08985218675032718,
#   'DAL weight': 0.08648103374103899,
#   'NFLX weight': 0.1660576451968118,
#   'AAPL weight': 0.11916514761350534,
#   'PFE weight': 0.16369960774972547,
#   'BTC weight': 0.14816063213611513},
#  {'Returns': 22.726606436711247,
#   'Volatility': 0.1784331381967846,
#   'SHOP weight': 0.006834511188530905,
#   'TSLA weight': 0.17800814748971167,
#   'GOLD weight': 0.1184215395873943,
#   'DAL weight': 0.17908662065953496,
#   'NFLX weight': 0.12285068047378706,
#   'AAPL weight': 0.10151058344806634,
#   'PFE weight': 0.11161621103146283,
#   'BTC weight': 0.18167170612151204},
#  {'Returns': 19.386362671183246,
#   'Volatility': 0.24639937540822113,
#   'SHOP weight': 0.17579501473471273,
#   'TSLA weight': 0.19174328693625944,
#   'GOLD weight': 0.2366578913640157,
#   'DAL weight': 0.01691169464479765,
#   'NFLX weight': 0.09040522450090903,
#   'AAPL weight': 0.19329050873898818,
#   'PFE weight': 0.04440769013106702,
#   'BTC weight': 0.05078868894925025},
#  {'Returns': 7.3509812821072105,
#   'Volatility': 0.21075986783714581,
#   'SHOP weight': 0.12229244640573496,
#   'TSLA weight': 0.08469222237375451,
#   'GOLD weight': 0.3088625420609974,
#   'DAL weight': 0.040309494470876395,
#   'NFLX weight': 0.15501125719321798,
#   'AAPL weight': 0.16730309891490344,
#   'PFE weight': 0.005732944837330101,
#   'BTC weight': 0.11579599374318511},
#  {'Returns': 29.317872958163225,
#   'Volatility': 0.18334294105955362,
#   'SHOP weight': 0.037482128473669545,
#   'TSLA weight': 0.21932910465263977,
#   'GOLD weight': 0.06875354090227036,
#   'DAL weight': 0.09839677521432819,
#   'NFLX weight': 0.07532569565631184,
#   'AAPL weight': 0.09391065749689988,
#   'PFE weight': 0.24040566866258806,
#   'BTC weight': 0.16639642894129228},
#  {'Returns': 24.484082076351633,
#   'Volatility': 0.23922667088233263,
#   'SHOP weight': 0.1175704291628285,
#   'TSLA weight': 0.23180540092895827,
#   'GOLD weight': 0.15343434371931441,
#   'DAL weight': 0.054796179139243464,
#   'NFLX weight': 0.13881544936415696,
#   'AAPL weight': 0.17718047339223944,
#   'PFE weight': 0.05623746330448966,
#   'BTC weight': 0.07016026098876946},
#  {'Returns': 16.191832821741727,
#   'Volatility': 0.1800322100659805,
#   'SHOP weight': 0.1891463566919848,
#   'TSLA weight': 0.02952982245614519,
#   'GOLD weight': 0.1813321936090671,
#   'DAL weight': 0.20676365784629658,
#   'NFLX weight': 0.06764670819966219,
#   'AAPL weight': 0.1206881863634105,
#   'PFE weight': 0.025800734228063768,
#   'BTC weight': 0.17909234060536988},
#  {'Returns': 9.998739274240911,
#   'Volatility': 0.17239490399848703,
#   'SHOP weight': 0.12861456894956505,
#   'TSLA weight': 0.016990811174103195,
#   'GOLD weight': 0.2110491896200181,
#   'DAL weight': 0.0011778099797501128,
#   'NFLX weight': 0.22410523611397906,
#   'AAPL weight': 0.047095496370368375,
#   'PFE weight': 0.18809595466569567,
#   'BTC weight': 0.18287093312652053},
#  {'Returns': 10.68562172215773,
#   'Volatility': 0.1952939037352805,
#   'SHOP weight': 0.006257220630509725,
#   'TSLA weight': 0.12191607670709295,
#   'GOLD weight': 0.2928697205516073,
#   'DAL weight': 0.05608496349275103,
#   'NFLX weight': 0.18284821202883372,
#   'AAPL weight': 0.1684306038566472,
#   'PFE weight': 0.11930512918927821,
#   'BTC weight': 0.052288073543279856},
#  {'Returns': 10.79749709754901,
#   'Volatility': 0.15406873788043657,
#   'SHOP weight': 0.009027467411378217,
#   'TSLA weight': 0.08072936052795902,
#   'GOLD weight': 0.19195317917917082,
#   'DAL weight': 0.057698279277380554,
#   'NFLX weight': 0.23211215324918152,
#   'AAPL weight': 0.06268414640913521,
#   'PFE weight': 0.14440316605051728,
#   'BTC weight': 0.2213922478952772},
#  {'Returns': 22.049915228001225,
#   'Volatility': 0.20093566671841803,
#   'SHOP weight': 0.1801194410093895,
#   'TSLA weight': 0.09405160777310352,
#   'GOLD weight': 0.15476435427866644,
#   'DAL weight': 0.19942053392850137,
#   'NFLX weight': 0.09629892640562396,
#   'AAPL weight': 0.13256842572591984,
#   'PFE weight': 0.047515540720916606,
#   'BTC weight': 0.09526117015787886},
#  {'Returns': 13.165838554794377,
#   'Volatility': 0.16168714791044975,
#   'SHOP weight': 0.0798128087705829,
#   'TSLA weight': 0.01750594671832312,
#   'GOLD weight': 0.07886419162848067,
#   'DAL weight': 0.05217268482039873,
#   'NFLX weight': 0.18790819968135747,
#   'AAPL weight': 0.2542481945005582,
#   'PFE weight': 0.05728879073375527,
#   'BTC weight': 0.2721991831465436},
#  {'Returns': 22.642110665605642,
#   'Volatility': 0.22138169897180007,
#   'SHOP weight': 0.11073189445754301,
#   'TSLA weight': 0.19661402708529518,
#   'GOLD weight': 0.22058374236041806,
#   'DAL weight': 0.2092753879595088,
#   'NFLX weight': 0.12298570059599209,
#   'AAPL weight': 0.04620029535921134,
#   'PFE weight': 0.04583312359312013,
#   'BTC weight': 0.04777582858891135},
#  {'Returns': 34.66105657123876,
#   'Volatility': 0.21201783857176695,
#   'SHOP weight': 0.18808306445687095,
#   'TSLA weight': 0.186963035100176,
#   'GOLD weight': 0.025426466967273,
#   'DAL weight': 0.16509087291715394,
#   'NFLX weight': 0.13127091564775498,
#   'AAPL weight': 0.01397806277701595,
#   'PFE weight': 0.1870548139446073,
#   'BTC weight': 0.10213276818914784},
#  {'Returns': 17.651397625610947,
#   'Volatility': 0.19743374990561224,
#   'SHOP weight': 0.09348425514123754,
#   'TSLA weight': 0.17785822731270287,
#   'GOLD weight': 0.20920053380328926,
#   'DAL weight': 0.054308243848804935,
#   'NFLX weight': 0.041425830692773113,
#   'AAPL weight': 0.181945758065331,
#   'PFE weight': 0.07281153126897662,
#   'BTC weight': 0.1689656198668847},
#  {'Returns': 24.71760234351325,
#   'Volatility': 0.17832439402645056,
#   'SHOP weight': 0.1101607714366469,
#   'TSLA weight': 0.08228578532951474,
#   'GOLD weight': 0.087196158528764,
#   'DAL weight': 0.23316216600699752,
#   'NFLX weight': 0.08995618398929188,
#   'AAPL weight': 0.16795748133663765,
#   'PFE weight': 0.10600809318494425,
#   'BTC weight': 0.12327336018720318},
#  {'Returns': 34.700677842363994,
#   'Volatility': 0.21453074936039826,
#   'SHOP weight': 0.13622311596878497,
#   'TSLA weight': 0.2845504616102584,
#   'GOLD weight': 0.030830306124455014,
#   'DAL weight': 0.029956667416555793,
#   'NFLX weight': 0.015526777121615166,
#   'AAPL weight': 0.03776055084251411,
#   'PFE weight': 0.2457907431334993,
#   'BTC weight': 0.21936137778231735},
#  {'Returns': 24.670327575145354,
#   'Volatility': 0.1778068889417814,
#   'SHOP weight': 0.011463959984703884,
#   'TSLA weight': 0.16270877083831684,
#   'GOLD weight': 0.09657564412558546,
#   'DAL weight': 0.25815502915933597,
#   'NFLX weight': 0.07603908923763421,
#   'AAPL weight': 0.08097407322783141,
#   'PFE weight': 0.10700691158173273,
#   'BTC weight': 0.20707652184485956},
#  {'Returns': 12.331058692441655,
#   'Volatility': 0.1579170608190668,
#   'SHOP weight': 0.16508632232772277,
#   'TSLA weight': 0.017426359402819766,
#   'GOLD weight': 0.22249058211956965,
#   'DAL weight': 0.14629917433579287,
#   'NFLX weight': 0.019845268357534016,
#   'AAPL weight': 0.10553992713605392,
#   'PFE weight': 0.09432661753654568,
#   'BTC weight': 0.2289857487839614},
#  {'Returns': 19.374478776316145,
#   'Volatility': 0.1744740531885717,
#   'SHOP weight': 0.14146097240953234,
#   'TSLA weight': 0.023844145755499608,
#   'GOLD weight': 0.18029622407153437,
#   'DAL weight': 0.18673756517289863,
#   'NFLX weight': 0.14282030408511365,
#   'AAPL weight': 0.08608371373349219,
#   'PFE weight': 0.18961509066423005,
#   'BTC weight': 0.04914198410769909},
#  {'Returns': 24.126770966790804,
#   'Volatility': 0.17078527377904723,
#   'SHOP weight': 0.1376234958333672,
#   'TSLA weight': 0.013148234563362908,
#   'GOLD weight': 0.04190532703898922,
#   'DAL weight': 0.16379889280296311,
#   'NFLX weight': 0.1550353067443162,
#   'AAPL weight': 0.20185478891955594,
#   'PFE weight': 0.1774574834702355,
#   'BTC weight': 0.10917647062720985},
#  {'Returns': 23.386550692973408,
#   'Volatility': 0.1661135551230025,
#   'SHOP weight': 0.15440621968257004,
#   'TSLA weight': 0.04824195416632623,
#   'GOLD weight': 0.10496677473929701,
#   'DAL weight': 0.17298721408202478,
#   'NFLX weight': 0.010120676559305616,
#   'AAPL weight': 0.18989155454466852,
#   'PFE weight': 0.1725302883399761,
#   'BTC weight': 0.1468553178858317},
#  {'Returns': 30.964273808013317,
#   'Volatility': 0.19891358312698268,
#   'SHOP weight': 0.2518483505530622,
#   'TSLA weight': 0.17437406247057616,
#   'GOLD weight': 0.032779098102837106,
#   'DAL weight': 0.05904242211555645,
#   'NFLX weight': 0.002988375029143084,
#   'AAPL weight': 0.007647439277404473,
#   'PFE weight': 0.20110487923541315,
#   'BTC weight': 0.2702153732160075},
#  {'Returns': 21.148311114083782,
#   'Volatility': 0.18884034927730992,
#   'SHOP weight': 0.10317199959813611,
#   'TSLA weight': 0.132951750449673,
#   'GOLD weight': 0.12729393799650604,
#   'DAL weight': 0.13932234984889436,
#   'NFLX weight': 0.07414953893062609,
#   'AAPL weight': 0.21219926482353635,
#   'PFE weight': 0.04598324514210613,
#   'BTC weight': 0.16492791321052194},
#  {'Returns': 16.841794093663406,
#   'Volatility': 0.23995197102107219,
#   'SHOP weight': 0.22372025707645485,
#   'TSLA weight': 0.041507511530483786,
#   'GOLD weight': 0.17068834105050917,
#   'DAL weight': 0.08241692596722212,
#   'NFLX weight': 0.2522904290422349,
#   'AAPL weight': 0.18382632336440202,
#   'PFE weight': 0.016204965264782826,
#   'BTC weight': 0.029345246703910213},
#  {'Returns': 12.632384338295465,
#   'Volatility': 0.152032682140812,
#   'SHOP weight': 0.11311265159988311,
#   'TSLA weight': 0.0018024250084849468,
#   'GOLD weight': 0.15605000899356244,
#   'DAL weight': 0.15487308906216124,
#   'NFLX weight': 0.10566321362017056,
#   'AAPL weight': 0.172526798653451,
#   'PFE weight': 0.05962354180607305,
#   'BTC weight': 0.2363482712562136},
#  {'Returns': 25.55720350201023,
#   'Volatility': 0.20094203581272643,
#   'SHOP weight': 0.1905828676805412,
#   'TSLA weight': 0.026666332867048295,
#   'GOLD weight': 0.068273971553293,
#   'DAL weight': 0.1448545116405615,
#   'NFLX weight': 0.19617643897420897,
#   'AAPL weight': 0.1867956340111834,
#   'PFE weight': 0.17060393168919794,
#   'BTC weight': 0.016046311583965585},
#  {'Returns': 24.196978661444824,
#   'Volatility': 0.1659013641176917,
#   'SHOP weight': 0.13873481778412874,
#   'TSLA weight': 0.030809140582835116,
#   'GOLD weight': 0.06673362669685903,
#   'DAL weight': 0.18435398233338374,
#   'NFLX weight': 0.13963720171394592,
#   'AAPL weight': 0.1331549183129038,
#   'PFE weight': 0.1882293989908822,
#   'BTC weight': 0.11834691358506151},
#  {'Returns': 25.281246637247392,
#   'Volatility': 0.21712603888062176,
#   'SHOP weight': 0.16073323981303078,
#   'TSLA weight': 0.1666358940661035,
#   'GOLD weight': 0.16205491209658823,
#   'DAL weight': 0.01318489349332624,
#   'NFLX weight': 0.13315526663278895,
#   'AAPL weight': 0.11176466673206988,
#   'PFE weight': 0.23159323790252515,
#   'BTC weight': 0.02087788926356739},
#  {'Returns': 21.973999307487027,
#   'Volatility': 0.20446016783297027,
#   'SHOP weight': 0.11618564673987718,
#   'TSLA weight': 0.16136451624603076,
#   'GOLD weight': 0.19876926201775744,
#   'DAL weight': 0.05587974666870871,
#   'NFLX weight': 0.10585110117984667,
#   'AAPL weight': 0.13977787524595325,
#   'PFE weight': 0.18296312731630243,
#   'BTC weight': 0.03920872458552355},
#  {'Returns': 24.064919875935065,
#   'Volatility': 0.19441864351285493,
#   'SHOP weight': 0.14672248134628058,
#   'TSLA weight': 0.02831926302813861,
#   'GOLD weight': 0.09644688114159082,
#   'DAL weight': 0.19922549105824805,
#   'NFLX weight': 0.19180601391238064,
#   'AAPL weight': 0.1896277765123707,
#   'PFE weight': 0.14383806569882843,
#   'BTC weight': 0.004014027302162143},
#  {'Returns': 28.42906525131125,
#   'Volatility': 0.1857603909128964,
#   'SHOP weight': 0.19784439397441922,
#   'TSLA weight': 0.019822540722836356,
#   'GOLD weight': 0.04174472421224357,
#   'DAL weight': 0.10712184187882699,
#   'NFLX weight': 0.11664882906786771,
#   'AAPL weight': 0.19245206971587436,
#   'PFE weight': 0.2886672466298171,
#   'BTC weight': 0.035698353798114674},
#  {'Returns': 31.334820491126006,
#   'Volatility': 0.21940873552309986,
#   'SHOP weight': 0.2818484025237982,
#   'TSLA weight': 0.03657026896919825,
#   'GOLD weight': 0.010932186669130609,
#   'DAL weight': 0.1445031659626454,
#   'NFLX weight': 0.0020082168005371385,
#   'AAPL weight': 0.31324547368732003,
#   'PFE weight': 0.14545810324425917,
#   'BTC weight': 0.06543418214311122},
#  {'Returns': 19.751639477072807,
#   'Volatility': 0.21216076656859598,
#   'SHOP weight': 0.19032126719189746,
#   'TSLA weight': 0.13384134736357794,
#   'GOLD weight': 0.1411817351301698,
#   'DAL weight': 0.08344659771892673,
#   'NFLX weight': 0.11247165209168297,
#   'AAPL weight': 0.14806511266157915,
#   'PFE weight': 0.003799122497495755,
#   'BTC weight': 0.1868731653446702},
#  {'Returns': 19.07132173685586,
#   'Volatility': 0.2113275527443551,
#   'SHOP weight': 0.20635461223852533,
#   'TSLA weight': 0.07693355597560465,
#   'GOLD weight': 0.15743410059418314,
#   'DAL weight': 0.0061215117391499405,
#   'NFLX weight': 0.14800763847912432,
#   'AAPL weight': 0.16215264666491036,
#   'PFE weight': 0.14542059292759518,
#   'BTC weight': 0.09757534138090702},
#  {'Returns': 18.969870017991923,
#   'Volatility': 0.23195404336749065,
#   'SHOP weight': 0.0008918044403081003,
#   'TSLA weight': 0.21873195112391053,
#   'GOLD weight': 0.21962823899377204,
#   'DAL weight': 0.110007483267657,
#   'NFLX weight': 0.27762614613210285,
#   'AAPL weight': 0.10409234886523358,
#   'PFE weight': 0.05993681927558945,
#   'BTC weight': 0.009085207901426483},
#  {'Returns': 25.828264785422594,
#   'Volatility': 0.24394514515061502,
#   'SHOP weight': 0.09778092924683963,
#   'TSLA weight': 0.26302152787060956,
#   'GOLD weight': 0.13651028198185083,
#   'DAL weight': 0.017893978799614088,
#   'NFLX weight': 0.13357920105974316,
#   'AAPL weight': 0.18565184479751473,
#   'PFE weight': 0.08090940147689467,
#   'BTC weight': 0.08465283476693337},
#  {'Returns': 32.16486178312,
#   'Volatility': 0.19194908158941903,
#   'SHOP weight': 0.11935880035561527,
#   'TSLA weight': 0.16357921557286959,
#   'GOLD weight': 0.02098237279303894,
#   'DAL weight': 0.15937578404999345,
#   'NFLX weight': 0.04695653075723547,
#   'AAPL weight': 0.18276308590745094,
#   'PFE weight': 0.1764199657531723,
#   'BTC weight': 0.13056424481062404},
#  {'Returns': 24.511175471887537,
#   'Volatility': 0.18960358969275426,
#   'SHOP weight': 0.14581534353497777,
#   'TSLA weight': 0.09716460961222324,
#   'GOLD weight': 0.14558118286182567,
#   'DAL weight': 0.12491105053900158,
#   'NFLX weight': 0.04496915044792042,
#   'AAPL weight': 0.20641028062162706,
#   'PFE weight': 0.19281686557042488,
#   'BTC weight': 0.04233151681199933},
#  {'Returns': 21.16883254470494,
#   'Volatility': 0.17459538758916798,
#   'SHOP weight': 0.022027401029998277,
#   'TSLA weight': 0.10473702738503143,
#   'GOLD weight': 0.15202742021908147,
#   'DAL weight': 0.20332094189935984,
#   'NFLX weight': 0.09001668009795243,
#   'AAPL weight': 0.19010795267117198,
#   'PFE weight': 0.14748739628116933,
#   'BTC weight': 0.09027518041623514},
#  {'Returns': 24.997225732175234,
#   'Volatility': 0.23416328380141407,
#   'SHOP weight': 0.2584991183920116,
#   'TSLA weight': 0.000749059540303383,
#   'GOLD weight': 0.02682988824990487,
#   'DAL weight': 0.15522583815031754,
#   'NFLX weight': 0.2771316928062528,
#   'AAPL weight': 0.17985892407417958,
#   'PFE weight': 0.05738581249746091,
#   'BTC weight': 0.04431966628956924},
#  {'Returns': 21.93660449991735,
#   'Volatility': 0.18626565266118095,
#   'SHOP weight': 0.16871908047625367,
#   'TSLA weight': 0.03402311215277061,
#   'GOLD weight': 0.13744145089909257,
#   'DAL weight': 0.19974387294747736,
#   'NFLX weight': 0.09686762101391443,
#   'AAPL weight': 0.18132485484378294,
#   'PFE weight': 0.12093493753291278,
#   'BTC weight': 0.060945070133795624},
#  {'Returns': 26.51422954052956,
#   'Volatility': 0.2016212859225058,
#   'SHOP weight': 0.014418404598293966,
#   'TSLA weight': 0.22509296914241433,
#   'GOLD weight': 0.0444740393447092,
#   'DAL weight': 0.19962110106170425,
#   'NFLX weight': 0.18508590566292646,
#   'AAPL weight': 0.07000524043029499,
#   'PFE weight': 0.03311685991333518,
#   'BTC weight': 0.22818547984632154},
#  {'Returns': 26.34784181560939,
#   'Volatility': 0.22719769390353164,
#   'SHOP weight': 0.17708478938913208,
#   'TSLA weight': 0.14109128130145362,
#   'GOLD weight': 0.13344265264193714,
#   'DAL weight': 0.11781678852140204,
#   'NFLX weight': 0.09824283288011318,
#   'AAPL weight': 0.23580575513439864,
#   'PFE weight': 0.09438688169224575,
#   'BTC weight': 0.0021290184393174907},
#  {'Returns': 21.122015900565394,
#   'Volatility': 0.1451778239208686,
#   'SHOP weight': 0.006385285050066189,
#   'TSLA weight': 0.0020692896611432866,
#   'GOLD weight': 0.08272346754339488,
#   'DAL weight': 0.1711965521828382,
#   'NFLX weight': 0.14145929337478344,
#   'AAPL weight': 0.15738734136654386,
#   'PFE weight': 0.3201155540558991,
#   'BTC weight': 0.11866321676533115},
#  {'Returns': 17.948921404005738,
#   'Volatility': 0.17726991843314485,
#   'SHOP weight': 0.1805201451601911,
#   'TSLA weight': 0.053412261600368875,
#   'GOLD weight': 0.1609748881930282,
#   'DAL weight': 0.10236506941579784,
#   'NFLX weight': 0.14163001550586596,
#   'AAPL weight': 0.06662175467363962,
#   'PFE weight': 0.14000352164643434,
#   'BTC weight': 0.15447234380467406},
#  {'Returns': 14.577120652149874,
#   'Volatility': 0.22354170856369085,
#   'SHOP weight': 0.17898113193808932,
#   'TSLA weight': 0.05702463773082403,
#   'GOLD weight': 0.16142981428590109,
#   'DAL weight': 0.02037615558945607,
#   'NFLX weight': 0.2594090423316051,
#   'AAPL weight': 0.16968947600052983,
#   'PFE weight': 0.04269965341983082,
#   'BTC weight': 0.1103900887037637},
#  {'Returns': 24.206499666704683,
#   'Volatility': 0.2214359734963605,
#   'SHOP weight': 0.2827690947082264,
#   'TSLA weight': 0.01391809495995746,
#   'GOLD weight': 0.12611401990238205,
#   'DAL weight': 0.1750361788033732,
#   'NFLX weight': 0.1915367993339597,
#   'AAPL weight': 0.07477835523218528,
#   'PFE weight': 0.13311565663987102,
#   'BTC weight': 0.00273180042004491},
#  {'Returns': 19.506902979417326,
#   'Volatility': 0.20218733307884254,
#   'SHOP weight': 0.060729888407524676,
#   'TSLA weight': 0.15324854973084576,
#   'GOLD weight': 0.16721112759632828,
#   'DAL weight': 0.023567013608597878,
#   'NFLX weight': 0.14917934798595262,
#   'AAPL weight': 0.22828199869889035,
#   'PFE weight': 0.14067597505737242,
#   'BTC weight': 0.07710609891448816},
#  {'Returns': 33.51890762778147,
#   'Volatility': 0.23936955957552183,
#   'SHOP weight': 0.20483024178512196,
#   'TSLA weight': 0.20487954526389282,
#   'GOLD weight': 0.07061023200169013,
#   'DAL weight': 0.10951206933410051,
#   'NFLX weight': 0.17344626529121718,
#   'AAPL weight': 0.05481611095487661,
#   'PFE weight': 0.1699596542631727,
#   'BTC weight': 0.011945881105928105},
#  {'Returns': 13.418763051920584,
#   'Volatility': 0.17068682594616744,
#   'SHOP weight': 0.16866109078482833,
#   'TSLA weight': 0.0375076918354179,
#   'GOLD weight': 0.21047750682680325,
#   'DAL weight': 0.013915148082773332,
#   'NFLX weight': 0.09158016367377866,
#   'AAPL weight': 0.09905191750817788,
#   'PFE weight': 0.1958717632635832,
#   'BTC weight': 0.1829347180246374},
#  {'Returns': 24.389235771091975,
#   'Volatility': 0.19618496157111984,
#   'SHOP weight': 0.21907880388337392,
#   'TSLA weight': 0.09042933564144061,
#   'GOLD weight': 0.12374076266185884,
#   'DAL weight': 0.24294984778266743,
#   'NFLX weight': 0.07123848373642866,
#   'AAPL weight': 0.0406369951593544,
#   'PFE weight': 0.055914339063382876,
#   'BTC weight': 0.15601143207149332},
#  {'Returns': 14.627324275721447,
#   'Volatility': 0.14710388206635538,
#   'SHOP weight': 0.040825376914637584,
#   'TSLA weight': 0.016176166438606088,
#   'GOLD weight': 0.18479793240850267,
#   'DAL weight': 0.13238828255008098,
#   'NFLX weight': 0.11261447867518107,
#   'AAPL weight': 0.15706639005301162,
#   'PFE weight': 0.22320721122497864,
#   'BTC weight': 0.1329241617350013},
#  {'Returns': 20.45384552290862,
#   'Volatility': 0.1920950438641923,
#   'SHOP weight': 0.17421740717677336,
#   'TSLA weight': 0.0622512681716171,
# ...
#   'BTC weight': 0.08228937116932249},
#  {'Returns': 10.17433686461626,
#   'Volatility': 0.17490226526588296,
#   'SHOP weight': 0.07208631198141897,
#   'TSLA weight': 0.05353421878453749,
#   'GOLD weight': 0.24417609140246813,
#   'DAL weight': 0.140780322032963,
#   'NFLX weight': 0.1430208678336845,
#   'AAPL weight': 0.16127241434343498,
#   'PFE weight': 0.03570415569107671,
#   'BTC weight': 0.14942561793041617},
#  {'Returns': 37.79460377596555,
#   'Volatility': 0.2995191216428425,
#   'SHOP weight': 0.4166640264983242,
#   'TSLA weight': 0.2145902762740104,
#   'GOLD weight': 0.05666008338262239,
#   'DAL weight': 0.1355467818468576,
#   'NFLX weight': 0.012851688468663023,
#   'AAPL weight': 0.05898151584032428,
#   'PFE weight': 0.03493874085116725,
#   'BTC weight': 0.0697668868380309},
#  {'Returns': 22.744135309134627,
#   'Volatility': 0.1692379539995713,
#   'SHOP weight': 0.06524081242682672,
#   'TSLA weight': 0.010653281427825767,
#   'GOLD weight': 0.03585574144889323,
#   'DAL weight': 0.14194889841782168,
#   'NFLX weight': 0.2449212174522033,
#   'AAPL weight': 0.20567360473281776,
#   'PFE weight': 0.21522043592831244,
#   'BTC weight': 0.0804860081652991},
#  {'Returns': 24.427168520200393,
#   'Volatility': 0.16996190032604022,
#   'SHOP weight': 0.04100863872602086,
#   'TSLA weight': 0.05878277424815815,
#   'GOLD weight': 0.06079044586224079,
#   'DAL weight': 0.09268448971348837,
#   'NFLX weight': 0.06132100317981617,
#   'AAPL weight': 0.34740181050699065,
#   'PFE weight': 0.25600150056929494,
#   'BTC weight': 0.08200933719399017},
#  {'Returns': 21.081750201765555,
#   'Volatility': 0.16183451373283295,
#   'SHOP weight': 0.03706306058968426,
#   'TSLA weight': 0.14473691347854356,
#   'GOLD weight': 0.15610738555664516,
#   'DAL weight': 0.11099463610955057,
#   'NFLX weight': 0.07610491684481681,
#   'AAPL weight': 0.09604213597974488,
#   'PFE weight': 0.2144893884610802,
#   'BTC weight': 0.1644615629799345},
#  {'Returns': 17.407186396178616,
#   'Volatility': 0.1444165853963177,
#   'SHOP weight': 0.07529821268462035,
#   'TSLA weight': 0.03801038581642571,
#   'GOLD weight': 0.10253971785979228,
#   'DAL weight': 0.05335779373295206,
#   'NFLX weight': 0.06385824783926296,
#   'AAPL weight': 0.23957770393354008,
#   'PFE weight': 0.20321599553437983,
#   'BTC weight': 0.22414194259902676},
#  {'Returns': 35.67778016713078,
#   'Volatility': 0.27600555412871824,
#   'SHOP weight': 0.20966759534818494,
#   'TSLA weight': 0.26129460526780746,
#   'GOLD weight': 0.048675160105039146,
#   'DAL weight': 0.06504479929744983,
#   'NFLX weight': 0.10180692629568949,
#   'AAPL weight': 0.22528409396253976,
#   'PFE weight': 0.08124343415503196,
#   'BTC weight': 0.006983385568257483},
#  {'Returns': 27.637483698989907,
#   'Volatility': 0.1934283278601988,
#   'SHOP weight': 0.18998509460384397,
#   'TSLA weight': 0.12591747478448803,
#   'GOLD weight': 0.06553764986435821,
#   'DAL weight': 0.17141225469162466,
#   'NFLX weight': 0.011653499007069515,
#   'AAPL weight': 0.16887902919729708,
#   'PFE weight': 0.08726515135905881,
#   'BTC weight': 0.17934984649225966},
#  {'Returns': 21.187908485794647,
#   'Volatility': 0.19988399956885394,
#   'SHOP weight': 0.17062929266849008,
#   'TSLA weight': 0.1060736520327199,
#   'GOLD weight': 0.11534939691606172,
#   'DAL weight': 0.16897443599828177,
#   'NFLX weight': 0.1769986877727958,
#   'AAPL weight': 0.08007246773100639,
#   'PFE weight': 0.01634206219110624,
#   'BTC weight': 0.16556000468953802},
#  {'Returns': 27.20637398885765,
#   'Volatility': 0.2070409346551994,
#   'SHOP weight': 0.04284729224198862,
#   'TSLA weight': 0.16936999329080835,
#   'GOLD weight': 0.08207034151472925,
#   'DAL weight': 0.19343278891247492,
#   'NFLX weight': 0.1427815301726629,
#   'AAPL weight': 0.22422881381466805,
#   'PFE weight': 0.08626204174387844,
#   'BTC weight': 0.05900719830878946},
#  {'Returns': 17.422161700439354,
#   'Volatility': 0.2129219863603982,
#   'SHOP weight': 0.2779042275197706,
#   'TSLA weight': 0.022189404202487217,
#   'GOLD weight': 0.2690512469821286,
#   'DAL weight': 0.08137326208197243,
#   'NFLX weight': 0.05564472430666774,
#   'AAPL weight': 0.07158563904481352,
#   'PFE weight': 0.21044684995898924,
#   'BTC weight': 0.01180464590317058},
#  {'Returns': 25.070793387327583,
#   'Volatility': 0.18375521531158417,
#   'SHOP weight': 0.017485010620079622,
#   'TSLA weight': 0.17581656783853308,
#   'GOLD weight': 0.05535903178298753,
#   'DAL weight': 0.18620358653919367,
#   'NFLX weight': 0.006011853856287987,
#   'AAPL weight': 0.26305077499579044,
#   'PFE weight': 0.05224224290887858,
#   'BTC weight': 0.24383093145824905},
#  {'Returns': 25.101421987122364,
#   'Volatility': 0.2463847593630403,
#   'SHOP weight': 0.0792598926567891,
#   'TSLA weight': 0.23174624518889045,
#   'GOLD weight': 0.11008647452321844,
#   'DAL weight': 0.05717100279058507,
#   'NFLX weight': 0.2192060875027914,
#   'AAPL weight': 0.21106042896527927,
#   'PFE weight': 0.033186770659822756,
#   'BTC weight': 0.058283097712623466},
#  {'Returns': 11.567435355928836,
#   'Volatility': 0.2310650681239845,
#   'SHOP weight': 0.18357943650088657,
#   'TSLA weight': 0.031026803456221816,
#   'GOLD weight': 0.2182709296386169,
#   'DAL weight': 0.02322084070993885,
#   'NFLX weight': 0.2281440518979342,
#   'AAPL weight': 0.23120634789650923,
#   'PFE weight': 0.026021445312887602,
#   'BTC weight': 0.058530144587004757},
#  {'Returns': 13.511920745770897,
#   'Volatility': 0.16031024009453068,
#   'SHOP weight': 0.1043410156430318,
#   'TSLA weight': 0.025519844390243743,
#   'GOLD weight': 0.18171745627037106,
#   'DAL weight': 0.137666718685344,
#   'NFLX weight': 0.10502270163355641,
#   'AAPL weight': 0.17850413366625523,
#   'PFE weight': 0.08855441248582538,
#   'BTC weight': 0.17867371722537234},
#  {'Returns': 28.061406265228985,
#   'Volatility': 0.2180196545446454,
#   'SHOP weight': 0.047595277897560004,
#   'TSLA weight': 0.2413289260053571,
#   'GOLD weight': 0.08933077733499056,
#   'DAL weight': 0.06720725819540757,
#   'NFLX weight': 0.19479383065130465,
#   'AAPL weight': 0.11787001428680588,
#   'PFE weight': 0.15905390758434693,
#   'BTC weight': 0.08282000804422733},
#  {'Returns': 26.078940940306616,
#   'Volatility': 0.19784479777940261,
#   'SHOP weight': 0.11805386934557843,
#   'TSLA weight': 0.1879413179091014,
#   'GOLD weight': 0.09262659768405569,
#   'DAL weight': 0.09754622649779375,
#   'NFLX weight': 0.12241409119757733,
#   'AAPL weight': 0.09963273402567079,
#   'PFE weight': 0.1234888744667609,
#   'BTC weight': 0.15829628887346162},
#  {'Returns': 16.133638450050377,
#   'Volatility': 0.2108402558023608,
#   'SHOP weight': 0.062109295377830186,
#   'TSLA weight': 0.09704429542579182,
#   'GOLD weight': 0.20397758257029064,
#   'DAL weight': 0.12843320148154852,
#   'NFLX weight': 0.22089187843524885,
#   'AAPL weight': 0.2324197176568268,
#   'PFE weight': 0.044819220208289906,
#   'BTC weight': 0.01030480884417338},
#  {'Returns': 33.308189199687355,
#   'Volatility': 0.22832103171854595,
#   'SHOP weight': 0.12496240899798512,
#   'TSLA weight': 0.19774382765730233,
#   'GOLD weight': 0.02936568431904112,
#   'DAL weight': 0.020882594104197485,
#   'NFLX weight': 0.22124204337529751,
#   'AAPL weight': 0.13932691774423706,
#   'PFE weight': 0.26528421687409237,
#   'BTC weight': 0.0011923069278470327},
#  {'Returns': 17.828747189033383,
#   'Volatility': 0.16680292776789968,
#   'SHOP weight': 0.11403644538742,
#   'TSLA weight': 0.02785050810952351,
#   'GOLD weight': 0.10531879659266508,
#   'DAL weight': 0.1635674982461474,
#   'NFLX weight': 0.08273465549011172,
#   'AAPL weight': 0.25958839654316784,
#   'PFE weight': 0.0575301911721733,
#   'BTC weight': 0.18937350845879117},
#  {'Returns': 17.773360122933326,
#   'Volatility': 0.15104421868839776,
#   'SHOP weight': 0.03643212399971972,
#   'TSLA weight': 0.08999685632481506,
#   'GOLD weight': 0.1680113075497431,
#   'DAL weight': 0.19127877498426565,
#   'NFLX weight': 0.02855759653122094,
#   'AAPL weight': 0.12493294453210628,
#   'PFE weight': 0.14758577406854048,
#   'BTC weight': 0.21320462200958873},
#  {'Returns': 26.008417772140067,
#   'Volatility': 0.17762673474914156,
#   'SHOP weight': 0.06054191482274706,
#   'TSLA weight': 0.1738560125726881,
#   'GOLD weight': 0.12037547364677217,
#   'DAL weight': 0.12372472869743353,
#   'NFLX weight': 0.020180521002653946,
#   'AAPL weight': 0.14980816300925354,
#   'PFE weight': 0.21109020878144613,
#   'BTC weight': 0.1404229774670056},
#  {'Returns': 11.441084122074521,
#   'Volatility': 0.14876170452277476,
#   'SHOP weight': 0.15823634351085764,
#   'TSLA weight': 0.012541516645112542,
#   'GOLD weight': 0.2165755540906276,
#   'DAL weight': 0.16033748117868984,
#   'NFLX weight': 0.018594338336761197,
#   'AAPL weight': 0.07184312907814742,
#   'PFE weight': 0.08549838083221761,
#   'BTC weight': 0.2763732563275861},
#  {'Returns': 15.943538608157057,
#   'Volatility': 0.18228814242526986,
#   'SHOP weight': 0.07449572225079144,
#   'TSLA weight': 0.11746071359891368,
#   'GOLD weight': 0.20404692054269447,
#   'DAL weight': 0.18597003987992125,
#   'NFLX weight': 0.02440172482939194,
#   'AAPL weight': 0.20396580582657056,
#   'PFE weight': 0.0038871363168922215,
#   'BTC weight': 0.1857719367548243},
#  {'Returns': 23.633269814121263,
#   'Volatility': 0.20236585246521735,
#   'SHOP weight': 0.21182003069259636,
#   'TSLA weight': 0.12113831124488939,
#   'GOLD weight': 0.1263490149786445,
#   'DAL weight': 0.09150620171312,
#   'NFLX weight': 0.01056818945097799,
#   'AAPL weight': 0.18737923796973152,
#   'PFE weight': 0.09301278166041115,
#   'BTC weight': 0.158226232289629},
#  {'Returns': 17.00579070901497,
#   'Volatility': 0.20351092262923726,
#   'SHOP weight': 0.08962809354205424,
#   'TSLA weight': 0.11808734054788278,
#   'GOLD weight': 0.2974597750316398,
#   'DAL weight': 0.20493713109022485,
#   'NFLX weight': 0.03858084956706495,
#   'AAPL weight': 0.152148834231042,
#   'PFE weight': 0.09784254780914926,
#   'BTC weight': 0.0013154281809420578},
#  {'Returns': 18.970195883372238,
#   'Volatility': 0.21889016341110443,
#   'SHOP weight': 0.07287955198510841,
#   'TSLA weight': 0.215101381516365,
#   'GOLD weight': 0.2425310496914902,
#   'DAL weight': 0.07051243384869783,
#   'NFLX weight': 0.2033903228535796,
#   'AAPL weight': 0.01827709899589178,
#   'PFE weight': 0.11578646071866373,
#   'BTC weight': 0.06152170039020344},
#  {'Returns': 25.82749821713588,
#   'Volatility': 0.1869582311517169,
#   'SHOP weight': 0.0353573009319526,
#   'TSLA weight': 0.15312249945943088,
#   'GOLD weight': 0.07079678422396417,
#   'DAL weight': 0.22086797333699543,
#   'NFLX weight': 0.18111837175163498,
#   'AAPL weight': 0.0990470495073546,
#   'PFE weight': 0.10339014679976821,
#   'BTC weight': 0.13629987398889898},
#  {'Returns': 19.086237317899258,
#   'Volatility': 0.17583266870861425,
#   'SHOP weight': 0.0031397948858334817,
#   'TSLA weight': 0.07351770974738603,
#   'GOLD weight': 0.1595108407985051,
#   'DAL weight': 0.0788430098590517,
#   'NFLX weight': 0.20792346953948138,
#   'AAPL weight': 0.19981686861423706,
#   'PFE weight': 0.26609530048464475,
#   'BTC weight': 0.011153006070860389},
#  {'Returns': 19.617843768741245,
#   'Volatility': 0.19269982448885123,
#   'SHOP weight': 0.14307163816542876,
#   'TSLA weight': 0.1061621564284861,
#   'GOLD weight': 0.0760538071658398,
#   'DAL weight': 0.08313081475179677,
#   'NFLX weight': 0.25031428957040264,
#   'AAPL weight': 0.06194021149753033,
#   'PFE weight': 0.050406076567583336,
#   'BTC weight': 0.2289210058529322},
#  {'Returns': 22.864775433796364,
#   'Volatility': 0.18807363700193763,
#   'SHOP weight': 0.04295614587267984,
#   'TSLA weight': 0.17706967780995897,
#   'GOLD weight': 0.1235260590264121,
#   'DAL weight': 0.07420159481316695,
#   'NFLX weight': 0.14145249792841832,
#   'AAPL weight': 0.15672059784395695,
#   'PFE weight': 0.15691999162960069,
#   'BTC weight': 0.12715343507580612},
#  {'Returns': 15.473639523719214,
#   'Volatility': 0.1743818240369929,
#   'SHOP weight': 0.047094663565764076,
#   'TSLA weight': 0.07399887119613001,
#   'GOLD weight': 0.19884275823887562,
#   'DAL weight': 0.12712647274185987,
#   'NFLX weight': 0.20432192219436945,
#   'AAPL weight': 0.12217762960776402,
#   'PFE weight': 0.1457867307684042,
#   'BTC weight': 0.08065095168683281},
#  {'Returns': 23.324452279285293,
#   'Volatility': 0.22131467824680084,
#   'SHOP weight': 0.07211368864667762,
#   'TSLA weight': 0.20946387900655544,
#   'GOLD weight': 0.16684637622952897,
#   'DAL weight': 0.19884157472898725,
#   'NFLX weight': 0.12922712799992878,
#   'AAPL weight': 0.12973249501861692,
#   'PFE weight': 0.0026941623253406897,
#   'BTC weight': 0.09108069604436435},
#  {'Returns': 23.777288676119845,
#   'Volatility': 0.22886127486563093,
#   'SHOP weight': 0.21840031914610455,
#   'TSLA weight': 0.09582619994332768,
#   'GOLD weight': 0.14751300029944453,
#   'DAL weight': 0.1328376739199129,
#   'NFLX weight': 0.1718256199437623,
#   'AAPL weight': 0.15476014871120947,
#   'PFE weight': 0.07676457929694479,
#   'BTC weight': 0.0020724587392938255},
#  {'Returns': 27.192244939563604,
#   'Volatility': 0.1824177516542274,
#   'SHOP weight': 0.16713051776094953,
#   'TSLA weight': 0.12394293920624909,
#   'GOLD weight': 0.05583066128371535,
#   'DAL weight': 0.159073076392803,
#   'NFLX weight': 0.1401633780766257,
#   'AAPL weight': 0.027501128298515188,
#   'PFE weight': 0.14625801887608045,
#   'BTC weight': 0.18010028010506177},
#  {'Returns': 23.366429966200243,
#   'Volatility': 0.24581619197451762,
#   'SHOP weight': 0.019254286269664835,
#   'TSLA weight': 0.24447985406207567,
#   'GOLD weight': 0.11467573108314959,
#   'DAL weight': 0.029256411680766314,
#   'NFLX weight': 0.25258166690103473,
#   'AAPL weight': 0.2319312522649698,
#   'PFE weight': 0.04464474330804505,
#   'BTC weight': 0.06317605443029405},
#  {'Returns': 31.806334640212757,
#   'Volatility': 0.2004006947669682,
#   'SHOP weight': 0.2450270126279928,
#   'TSLA weight': 0.05649229930095016,
#   'GOLD weight': 0.055666913274893995,
#   'DAL weight': 0.19038629124326573,
#   'NFLX weight': 0.1109578543320337,
#   'AAPL weight': 0.07930921890504372,
#   'PFE weight': 0.24670834961466773,
#   'BTC weight': 0.01545206070115216},
#  {'Returns': 20.010479967326464,
#   'Volatility': 0.21599753847454076,
#   'SHOP weight': 0.07609398525771177,
#   'TSLA weight': 0.17275504369356304,
#   'GOLD weight': 0.10379572277948391,
#   'DAL weight': 0.038654868980742975,
#   'NFLX weight': 0.2491182806655065,
#   'AAPL weight': 0.16361581858518445,
#   'PFE weight': 0.03619927044155367,
#   'BTC weight': 0.15976700959625367},
#  {'Returns': 12.339977950504219,
#   'Volatility': 0.2123864484516265,
#   'SHOP weight': 0.09358011579097934,
#   'TSLA weight': 0.10114621128981816,
#   'GOLD weight': 0.2626018701446942,
#   'DAL weight': 0.0805835364456621,
#   'NFLX weight': 0.22337076006024384,
#   'AAPL weight': 0.14907542478462565,
#   'PFE weight': 0.04738550372308743,
#   'BTC weight': 0.04225657776088925},
#  {'Returns': 30.598587722286258,
#   'Volatility': 0.20495927077012238,
#   'SHOP weight': 0.2847694744935066,
#   'TSLA weight': 0.10529541355128556,
#   'GOLD weight': 0.07116264111078274,
#   'DAL weight': 0.16194140651872033,
#   'NFLX weight': 0.010320013926786185,
#   'AAPL weight': 0.05350959328034054,
#   'PFE weight': 0.17254767120300718,
#   'BTC weight': 0.14045378591557076},
#  {'Returns': 25.183821408237442,
#   'Volatility': 0.1957862387607224,
#   'SHOP weight': 0.18179524848919112,
#   'TSLA weight': 0.040617723128008244,
#   'GOLD weight': 0.10333509493852755,
#   'DAL weight': 0.28295410596176307,
#   'NFLX weight': 0.1979486209536119,
#   'AAPL weight': 0.020638525717895703,
#   'PFE weight': 0.11831648209036123,
#   'BTC weight': 0.05439419872064123},
#  {'Returns': 23.88338146535759,
#   'Volatility': 0.1822698788483797,
#   'SHOP weight': 0.05595040203281393,
#   'TSLA weight': 0.12611471285570378,
#   'GOLD weight': 0.13693379517695423,
#   'DAL weight': 0.11476607421586454,
#   'NFLX weight': 0.13433956298866775,
#   'AAPL weight': 0.17052401419605673,
#   'PFE weight': 0.2218243623625914,
#   'BTC weight': 0.03954707617134761},
#  {'Returns': 18.598179225136484,
#   'Volatility': 0.17798596306821446,
#   'SHOP weight': 0.015713700931807878,
#   'TSLA weight': 0.13300193030245527,
#   'GOLD weight': 0.1483385450579934,
#   'DAL weight': 0.16193511568863872,
#   'NFLX weight': 0.12548340042007095,
#   'AAPL weight': 0.19172527314671983,
#   'PFE weight': 0.06620924416690402,
#   'BTC weight': 0.1575927902854099}]

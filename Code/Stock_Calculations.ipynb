# %%
import json
import numpy as np
import math
from datetime import datetime
import pandas as pd 
import matplotlib.pyplot as plt
import pymongo

# %% [markdown]
# # SHOP Stock Calculations

# %%
with open('../Data/SHOP_prices.json') as json_file:
    SHOP_data = json.load(json_file)
    
#stock annual return
SHOP_ann_return=round((((SHOP_data[0]['adjclose']/SHOP_data[len(SHOP_data)-1]['adjclose'])-1)*100),2)

SHOP_price_array=[]
for i in range(len(SHOP_data)):
    SHOP_price_array.append(SHOP_data[i]['adjclose'])
    
#daily volatility
SHOP_daily_vol = round(np.std(SHOP_price_array),2)

#annualized volatility
SHOP_ann_vol = SHOP_daily_vol * math.sqrt(252)
SHOP_ann_vol = round(SHOP_ann_vol,2)

#3 mon return volatility
SHOP_date_array=[]

for y in range(len(SHOP_data)):
    SHOP_date_array.append(datetime.strptime(SHOP_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=SHOP_date_array[y]
    if ((firstdate-SHOP_date_array[y]).days==91):
        date_3mon_ago=SHOP_date_array[y]
        mon3_index = y
        
#last three month return
SHOP_3mon_return=round((((SHOP_data[0]['adjclose']/SHOP_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
SHOP_summ_stats = {
    "Ticker": "SHOP",
  "Annual Return": SHOP_ann_return,
  "Daily Volatility": SHOP_daily_vol,
  "Annualized Volatility": SHOP_ann_vol,
  "Last 3 Months Return":  SHOP_3mon_return
}

# convert into JSON:
SHOP_summ_stats = json.dumps(SHOP_summ_stats)

# the result is a JSON string:
print(SHOP_summ_stats)
# Out:
# {"Ticker": "SHOP", "Annual Return": 46.96, "Daily Volatility": 191.43, "Annualized Volatility": 3038.86, "Last 3 Months Return": 23.22}

# %% [markdown]
# # TSLA Stock Calculations

# %%
with open('../Data/TSLA_prices.json') as json_file:
    TSLA_data = json.load(json_file)
    
#stock annual return
TSLA_ann_return=round((((TSLA_data[0]['adjclose']/TSLA_data[len(TSLA_data)-1]['adjclose'])-1)*100),2)

TSLA_price_array=[]
for i in range(len(TSLA_data)):
    TSLA_price_array.append(TSLA_data[i]['adjclose'])
    
#daily volatility
TSLA_daily_vol = round(np.std(TSLA_price_array),2)

#annualized volatility
TSLA_ann_vol = TSLA_daily_vol * math.sqrt(252)
TSLA_ann_vol = round(TSLA_ann_vol,2)

#3 mon return volatility
TSLA_date_array=[]

for y in range(len(TSLA_data)):
    TSLA_date_array.append(datetime.strptime(TSLA_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=TSLA_date_array[y]
    if ((firstdate-TSLA_date_array[y]).days==91):
        date_3mon_ago=TSLA_date_array[y]
        mon3_index = y
        
#last three month return
TSLA_3mon_return=round((((TSLA_data[0]['adjclose']/TSLA_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
TSLA_summ_stats = {
    "Ticker": "TSLA",
  "Annual Return": TSLA_ann_return,
  "Daily Volatility": TSLA_daily_vol,
  "Annualized Volatility": TSLA_ann_vol,
  "Last 3 Months Return":  TSLA_3mon_return
}

# convert into JSON:
TSLA_summ_stats = json.dumps(TSLA_summ_stats)

# the result is a JSON string:
print(TSLA_summ_stats)
# Out:
# {"Ticker": "TSLA", "Annual Return": 60.82, "Daily Volatility": 131.63, "Annualized Volatility": 2089.56, "Last 3 Months Return": 13.87}

# %% [markdown]
# # GOLD Stock Calculations

# %%
with open('../Data/GOLD_prices.json') as json_file:
    GOLD_data = json.load(json_file)
    
#stock annual return
GOLD_ann_return=round((((GOLD_data[0]['adjclose']/GOLD_data[len(GOLD_data)-1]['adjclose'])-1)*100),2)

GOLD_price_array=[]
for i in range(len(GOLD_data)):
    GOLD_price_array.append(GOLD_data[i]['adjclose'])
    
#daily volatility
GOLD_daily_vol = round(np.std(GOLD_price_array),2)

#annualized volatility
GOLD_ann_vol = GOLD_daily_vol * math.sqrt(252)
GOLD_ann_vol = round(GOLD_ann_vol,2)

#3 mon return volatility
GOLD_date_array=[]

for y in range(len(GOLD_data)):
    GOLD_date_array.append(datetime.strptime(GOLD_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=GOLD_date_array[y]
    if ((firstdate-GOLD_date_array[y]).days==91):
        date_3mon_ago=GOLD_date_array[y]
        mon3_index = y
        
#last three month return
GOLD_3mon_return=round((((GOLD_data[0]['adjclose']/GOLD_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
GOLD_summ_stats = {
    "Ticker": "GOLD",
  "Annual Return": GOLD_ann_return,
  "Daily Volatility": GOLD_daily_vol,
  "Annualized Volatility": GOLD_ann_vol,
  "Last 3 Months Return":  GOLD_3mon_return
}

# convert into JSON:
GOLD_summ_stats = json.dumps(GOLD_summ_stats)

# the result is a JSON string:
print(GOLD_summ_stats)
# Out:
# {"Ticker": "GOLD", "Annual Return": -29.43, "Daily Volatility": 2.76, "Annualized Volatility": 43.81, "Last 3 Months Return": -15.95}

# %% [markdown]
# # DAL Stock Calculations

# %%
with open('../Data/DAL_prices.json') as json_file:
    DAL_data = json.load(json_file)
    
#stock annual return
DAL_ann_return=round((((DAL_data[0]['adjclose']/DAL_data[len(DAL_data)-1]['adjclose'])-1)*100),2)

DAL_price_array=[]
for i in range(len(DAL_data)):
    DAL_price_array.append(DAL_data[i]['adjclose'])
    
#daily volatility
DAL_daily_vol = round(np.std(DAL_price_array),2)

#annualized volatility
DAL_ann_vol = DAL_daily_vol * math.sqrt(252)
DAL_ann_vol = round(DAL_ann_vol,2)

#3 mon return volatility
DAL_date_array=[]

for y in range(len(DAL_data)):
    DAL_date_array.append(datetime.strptime(DAL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=DAL_date_array[y]
    if ((firstdate-DAL_date_array[y]).days==91):
        date_3mon_ago=DAL_date_array[y]
        mon3_index = y
        
#last three month return
DAL_3mon_return=round((((DAL_data[0]['adjclose']/DAL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
DAL_summ_stats = {
    "Ticker": "DAL",
  "Annual Return": DAL_ann_return,
  "Daily Volatility": DAL_daily_vol,
  "Annualized Volatility": DAL_ann_vol,
  "Last 3 Months Return":  DAL_3mon_return
}

# convert into JSON:
DAL_summ_stats = json.dumps(DAL_summ_stats)

# the result is a JSON string:
print(DAL_summ_stats)
# Out:
# {"Ticker": "DAL", "Annual Return": 29.79, "Daily Volatility": 5.78, "Annualized Volatility": 91.75, "Last 3 Months Return": -12.92}

# %% [markdown]
# # NFLX Stock Calculations

# %%
with open('../Data/NFLX_prices.json') as json_file:
    NFLX_data = json.load(json_file)
    
#stock annual return
NFLX_ann_return=round((((NFLX_data[0]['adjclose']/NFLX_data[len(NFLX_data)-1]['adjclose'])-1)*100),2)

NFLX_price_array=[]
for i in range(len(NFLX_data)):
    NFLX_price_array.append(NFLX_data[i]['adjclose'])
    
#daily volatility
NFLX_daily_vol = round(np.std(NFLX_price_array),2)

#annualized volatility
NFLX_ann_vol = NFLX_daily_vol * math.sqrt(252)
NFLX_ann_vol = round(NFLX_ann_vol,2)

#3 mon return volatility
NFLX_date_array=[]

for y in range(len(NFLX_data)):
    NFLX_date_array.append(datetime.strptime(NFLX_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=NFLX_date_array[y]
    if ((firstdate-NFLX_date_array[y]).days==91):
        date_3mon_ago=NFLX_date_array[y]
        mon3_index = y
        
#last three month return
NFLX_3mon_return=round((((NFLX_data[0]['adjclose']/NFLX_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
NFLX_summ_stats = {
    "Ticker": "NFLX",
  "Annual Return": NFLX_ann_return,
  "Daily Volatility": NFLX_daily_vol,
  "Annualized Volatility": NFLX_ann_vol,
  "Last 3 Months Return":  NFLX_3mon_return
}

# convert into JSON:
NFLX_summ_stats = json.dumps(NFLX_summ_stats)

# the result is a JSON string:
print(NFLX_summ_stats)
# Out:
# {"Ticker": "NFLX", "Annual Return": 6.69, "Daily Volatility": 24.02, "Annualized Volatility": 381.31, "Last 3 Months Return": 11.16}

# %% [markdown]
# # AAPL Stock Calculations

# %%
with open('../Data/AAPL_prices.json') as json_file:
    AAPL_data = json.load(json_file)
    
#stock annual return
AAPL_ann_return=round((((AAPL_data[0]['adjclose']/AAPL_data[len(AAPL_data)-1]['adjclose'])-1)*100),2)

AAPL_price_array=[]
for i in range(len(AAPL_data)):
    AAPL_price_array.append(AAPL_data[i]['adjclose'])
    
#daily volatility
AAPL_daily_vol = round(np.std(AAPL_price_array),2)

#annualized volatility
AAPL_ann_vol = AAPL_daily_vol * math.sqrt(252)
AAPL_ann_vol = round(AAPL_ann_vol,2)

#3 mon return volatility
AAPL_date_array=[]

for y in range(len(AAPL_data)):
    AAPL_date_array.append(datetime.strptime(AAPL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=AAPL_date_array[y]
    if ((firstdate-AAPL_date_array[y]).days==91):
        date_3mon_ago=AAPL_date_array[y]
        mon3_index = y
        
#last three month return
AAPL_3mon_return=round((((AAPL_data[0]['adjclose']/AAPL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
AAPL_summ_stats = {
    "Ticker": "AAPL",
  "Annual Return": AAPL_ann_return,
  "Daily Volatility": AAPL_daily_vol,
  "Annualized Volatility": AAPL_ann_vol,
  "Last 3 Months Return":  AAPL_3mon_return
}

# convert into JSON:
AAPL_summ_stats = json.dumps(AAPL_summ_stats)

# the result is a JSON string:
print(AAPL_summ_stats)
# Out:
# {"Ticker": "AAPL", "Annual Return": 19.83, "Daily Volatility": 10.84, "Annualized Volatility": 172.08, "Last 3 Months Return": 19.43}

# %% [markdown]
# # PFE Stock Calculations

# %%
with open('../Data/PFE_prices.json') as json_file:
    PFE_data = json.load(json_file)
    
#stock annual return
PFE_ann_return=round((((PFE_data[0]['adjclose']/PFE_data[len(PFE_data)-1]['adjclose'])-1)*100),2)

PFE_price_array=[]
for i in range(len(PFE_data)):
    PFE_price_array.append(PFE_data[i]['adjclose'])
    
#daily volatility
PFE_daily_vol = round(np.std(PFE_price_array),2)

#annualized volatility
PFE_ann_vol = PFE_daily_vol * math.sqrt(252)
PFE_ann_vol = round(PFE_ann_vol,2)

#3 mon return volatility
PFE_date_array=[]

for y in range(len(PFE_data)):
    PFE_date_array.append(datetime.strptime(PFE_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=PFE_date_array[y]
    if ((firstdate-PFE_date_array[y]).days==91):
        date_3mon_ago=PFE_date_array[y]
        mon3_index = y
        
#last three month return
PFE_3mon_return=round((((PFE_data[0]['adjclose']/PFE_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
PFE_summ_stats = {
    "Ticker": "PFE",
  "Annual Return": PFE_ann_return,
  "Daily Volatility": PFE_daily_vol,
  "Annualized Volatility": PFE_ann_vol,
  "Last 3 Months Return":  PFE_3mon_return
}

# convert into JSON:
PFE_summ_stats = json.dumps(PFE_summ_stats)

# the result is a JSON string:
print(PFE_summ_stats)
# Out:
# {"Ticker": "PFE", "Annual Return": 34.84, "Daily Volatility": 3.91, "Annualized Volatility": 62.07, "Last 3 Months Return": 21.42}

# %% [markdown]
# # BTC Stock Calculations

# %%
with open('../Data/BTC_prices.json') as json_file:
    BTC_data = json.load(json_file)
    
#stock annual return
BTC_ann_return=round((((BTC_data[0]['adjclose']/BTC_data[len(BTC_data)-1]['adjclose'])-1)*100),2)

BTC_price_array=[]
for i in range(len(BTC_data)):
    BTC_price_array.append(BTC_data[i]['adjclose'])
    
#daily volatility
BTC_daily_vol = round(np.std(BTC_price_array),2)

#annualized volatility
BTC_ann_vol = BTC_daily_vol * math.sqrt(252)
BTC_ann_vol = round(BTC_ann_vol,2)

#3 mon return volatility
BTC_date_array=[]

for y in range(len(BTC_data)):
    BTC_date_array.append(datetime.strptime(BTC_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=BTC_date_array[y]
    if ((firstdate-BTC_date_array[y]).days==91):
        date_3mon_ago=BTC_date_array[y]
        mon3_index = y
        
#last three month return
BTC_3mon_return=round((((BTC_data[0]['adjclose']/BTC_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
BTC_summ_stats = {
    "Ticker": "BTC",
  "Annual Return": BTC_ann_return,
  "Daily Volatility": BTC_daily_vol,
  "Annualized Volatility": BTC_ann_vol,
  "Last 3 Months Return":  BTC_3mon_return
}

# convert into JSON:
BTC_summ_stats = json.dumps(BTC_summ_stats)

# the result is a JSON string:
print(BTC_summ_stats)
# Out:
# {"Ticker": "BTC", "Annual Return": 315.16, "Daily Volatility": 16031.17, "Annualized Volatility": 254486.93, "Last 3 Months Return": 30.24}

# %% [markdown]
# # Creating a Dataframe of values

# %%
shop_df = pd.DataFrame(json.loads(SHOP_summ_stats), index=[0])
tsla_df = pd.DataFrame(json.loads(TSLA_summ_stats), index=[0])
gold_df = pd.DataFrame(json.loads(GOLD_summ_stats), index=[0])
dal_df = pd.DataFrame(json.loads(DAL_summ_stats), index=[0])
nflx_df = pd.DataFrame(json.loads(NFLX_summ_stats), index=[0])
aapl_df = pd.DataFrame(json.loads(AAPL_summ_stats), index=[0])
pfe_df = pd.DataFrame(json.loads(PFE_summ_stats), index=[0])
btc_df = pd.DataFrame(json.loads(BTC_summ_stats), index=[0])


stocks_calc_combined = shop_df.append([tsla_df,gold_df,dal_df,nflx_df,aapl_df,pfe_df,btc_df])
stocks_calc_combined.reset_index(inplace = True,drop = True)

stocks_calc_combined
# Out:
#   Ticker  Annual Return  Daily Volatility  Annualized Volatility  \
# 0   SHOP          46.96            191.43                3038.86
# 1   TSLA          60.82            131.63                2089.56
# 2   GOLD         -29.43              2.76                  43.81
# 3    DAL          29.79              5.78                  91.75
# 4   NFLX           6.69             24.02                 381.31
# 5   AAPL          19.83             10.84                 172.08
# 6    PFE          34.84              3.91                  62.07
# 7    BTC         315.16          16031.17              254486.93
#
#    Last 3 Months Return
# 0                 23.22
# 1                 13.87
# 2                -15.95
# 3                -12.92
# 4                 11.16
# 5                 19.43
# 6                 21.42
# 7                 30.24

# %%
result = stocks_calc_combined.to_json(orient="index")
parsed = json.loads(result)
with open('../Data/stocks_calc_combined.json', 'w') as outfile:
    json.dump(parsed, outfile)

# %% [markdown]
# # Get daily returns and asssets covariance

# %%
#created dataframes for daily prices
SHOP_data_df = pd.DataFrame(SHOP_data)
SHOP_data_df = SHOP_data_df[["formatted_date", "adjclose"]]
SHOP_data_df.set_index("formatted_date", inplace = True)
SHOP_data_df = SHOP_data_df.rename (columns = {"adjclose": "SHOP"})

TSLA_data_df = pd.DataFrame(TSLA_data)
TSLA_data_df = TSLA_data_df[["formatted_date", "adjclose"]]
TSLA_data_df.set_index("formatted_date", inplace = True)
TSLA_data_df = TSLA_data_df.rename (columns = {"adjclose": "TSLA"})

GOLD_data_df = pd.DataFrame(GOLD_data)
GOLD_data_df = GOLD_data_df[["formatted_date", "adjclose"]]
GOLD_data_df.set_index("formatted_date", inplace = True)
GOLD_data_df = GOLD_data_df.rename (columns = {"adjclose": "GOLD"})

DAL_data_df = pd.DataFrame(DAL_data)
DAL_data_df = DAL_data_df[["formatted_date", "adjclose"]]
DAL_data_df.set_index("formatted_date", inplace = True)
DAL_data_df = DAL_data_df.rename (columns = {"adjclose": "DAL"})

NFLX_data_df = pd.DataFrame(NFLX_data)
NFLX_data_df = NFLX_data_df[["formatted_date", "adjclose"]]
NFLX_data_df.set_index("formatted_date", inplace = True)
NFLX_data_df = NFLX_data_df.rename (columns = {"adjclose": "NFLX"})

AAPL_data_df = pd.DataFrame(AAPL_data)
AAPL_data_df = AAPL_data_df[["formatted_date", "adjclose"]]
AAPL_data_df.set_index("formatted_date", inplace = True)
AAPL_data_df = AAPL_data_df.rename (columns = {"adjclose": "AAPL"})

PFE_data_df = pd.DataFrame(PFE_data)
PFE_data_df = PFE_data_df[["formatted_date", "adjclose"]]
PFE_data_df.set_index("formatted_date", inplace = True)
PFE_data_df = PFE_data_df.rename (columns = {"adjclose": "PFE"})

BTC_data_df = pd.DataFrame(BTC_data)
BTC_data_df = BTC_data_df[["formatted_date", "adjclose"]]
BTC_data_df.set_index("formatted_date", inplace = True)
BTC_data_df = BTC_data_df.rename (columns = {"adjclose": "BTC"})
#BTC_data_df

# %%
#merge assest into a single dataframe
assets_all = pd.concat([SHOP_data_df, TSLA_data_df,GOLD_data_df , DAL_data_df, NFLX_data_df, AAPL_data_df,PFE_data_df,BTC_data_df],axis=1, join="inner")
assets_all
# Out:
#                    SHOP    TSLA   GOLD    DAL    NFLX    AAPL    PFE       BTC
# formatted_date
# 2021-08-27      1531.42  711.92  20.24  41.52  558.92  148.60  46.60  48902.40
# 2021-08-26      1515.58  701.16  19.73  40.77  550.12  147.54  47.38  49058.67
# 2021-08-25      1552.24  711.20  19.85  41.30  547.58  148.36  47.51  46942.22
# 2021-08-24      1538.51  708.49  20.12  40.53  553.41  149.62  48.38  48960.79
# 2021-08-23      1481.41  706.30  20.15  39.21  553.33  149.71  49.93  47706.12
# ...                 ...     ...    ...    ...     ...     ...    ...       ...
# 2020-09-04       973.02  418.32  28.53  31.77  516.05  120.19  33.15  10169.57
# 2020-09-03      1015.70  407.00  28.74  31.22  525.75  120.11  33.19  10511.81
# 2020-09-02      1074.59  447.37  29.08  31.14  552.84  130.56  33.91  10245.30
# 2020-09-01      1134.32  475.05  28.81  30.71  556.55  133.32  33.62  11414.03
# 2020-08-31      1066.42  498.32  29.12  30.85  529.56  128.22  34.45  11970.48
#
# [249 rows x 8 columns]

# %%
#calculate daily pricec changes
assets_all_pricechng = assets_all.pct_change()
#assets_all_pricechng

# %%
#calculate covariance
assets_all_cov = assets_all_pricechng.cov()
assets_all_cov
# Out:
#           SHOP      TSLA      GOLD       DAL      NFLX      AAPL       PFE  \
# SHOP  0.001074  0.000536  0.000140 -0.000117  0.000369  0.000309 -0.000031
# TSLA  0.000536  0.001686  0.000135  0.000127  0.000299  0.000408  0.000041
# GOLD  0.000140  0.000135  0.000409  0.000036  0.000106  0.000112  0.000034
# DAL  -0.000117  0.000127  0.000036  0.000664 -0.000045  0.000018  0.000064
# NFLX  0.000369  0.000299  0.000106 -0.000045  0.000524  0.000234 -0.000033
# AAPL  0.000309  0.000408  0.000112  0.000018  0.000234  0.000387  0.000042
# PFE  -0.000031  0.000041  0.000034  0.000064 -0.000033  0.000042  0.000221
# BTC  -0.000005  0.000163 -0.000039  0.000082 -0.000104  0.000022 -0.000052
#
#            BTC
# SHOP -0.000005
# TSLA  0.000163
# GOLD -0.000039
# DAL   0.000082
# NFLX -0.000104
# AAPL  0.000022
# PFE  -0.000052
# BTC   0.002582

# %%
# convert into JSON:
assets_all_json = assets_all_cov.to_json()
assets_all_json = json.dumps(assets_all_json)

# %% [markdown]
# # Calculate portfolio return and volatility

# %% [markdown]
# ref: https://www.machinelearningplus.com/machine-learning/portfolio-optimization-python-example/

# %%
portfolio_return = []
portfolio_volati = []
asset_weights = []

# %%
#calculate number of assest and max number of portfolios to itterate
num_assets = stocks_calc["Ticker"].count()
print(num_assets)
num_portf = 1000
# Out:
# 8

# %% [markdown]
# for portfolio in range(num_portf):
#     #portfolio returns
#     weights = np.random.random(num_assets)
#     weights = weights/np.sum(weights)
#     asset_weights.append(weights)
# asset_weights

# %% [markdown]
# len(asset_weights)

# %%
for portfolio in range(num_portf):
    #portfolio returns
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    asset_weights.append(weights)
    portf_return = np.dot(weights, stocks_calc["Annual Return"])
    portfolio_return.append(portf_return)
    
    #portfolio risk
    portf_var = assets_all_cov.mul(weights, axis=0).mul(weights, axis=1).sum().sum()
    portf_stdev = np.sqrt(portf_var) # Daily standard deviation
    portf_ann_stdev = portf_stdev*np.sqrt(250) # Annual standard deviation = volatility
    portfolio_volati.append(portf_ann_stdev)
    
    
#portfolio_return

# %%
print(len(portfolio_return), len(portfolio_volati), len(asset_weights))
# Out:
# 1000 1000 1000

# %% [markdown]
# #plot the graph
# plt.figure(figsize=(12,8))
# plt.scatter(portfolio_volati,portfolio_return, marker = "o",facecolors = 'green')
# plt.title(f"Efficient Frontier", fontsize = 13, fontweight = 'bold', y=1.05)
# plt.xlabel("Risk")
# plt.ylabel("Return")
# plt.grid()
# plt.ylim(-20,60)
# plt.xlim(0.05,0.4)
#
# plt.show()

# %%
data = {'Returns':portfolio_return, 'Volatility':portfolio_volati}

for counter, symbol in enumerate(assets_all.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in asset_weights]
    
portfolios  = pd.DataFrame(data)
portf = portfolios.to_dict(orient='records')
portf
# Out:
# [{'Returns': 38.039437848386314,
#   'Volatility': 0.19748879918745926,
#   'SHOP weight': 0.04850713798070183,
#   'TSLA weight': 0.07427317879331047,
#   'GOLD weight': 0.15245738866048664,
#   'DAL weight': 0.22221938923752402,
#   'NFLX weight': 0.11090663702023217,
#   'AAPL weight': 0.19148806693697387,
#   'PFE weight': 0.13736703644243006,
#   'BTC weight': 0.06278116492834078},
#  {'Returns': 77.01430895549245,
#   'Volatility': 0.27203888453131636,
#   'SHOP weight': 0.07651843892670136,
#   'TSLA weight': 0.1984699137641,
#   'GOLD weight': 0.02654206680710156,
#   'DAL weight': 0.10678337672632844,
#   'NFLX weight': 0.18939225528316472,
#   'AAPL weight': 0.16795711880777753,
#   'PFE weight': 0.06956728009223327,
#   'BTC weight': 0.16476954959259316},
#  {'Returns': 82.92573494531261,
#   'Volatility': 0.24943489886011508,
#   'SHOP weight': 0.22853031198194276,
#   'TSLA weight': 0.051660789874116236,
#   'GOLD weight': 0.053751616797324195,
#   'DAL weight': 0.18145691120867355,
#   'NFLX weight': 0.19383142723184796,
#   'AAPL weight': 0.005889116642982426,
#   'PFE weight': 0.09263694536372113,
#   'BTC weight': 0.19224288089939154},
#  {'Returns': 74.23507900533009,
#   'Volatility': 0.26351183116472227,
#   'SHOP weight': 0.2458147283055665,
#   'TSLA weight': 0.14823905957307776,
#   'GOLD weight': 0.04919947323668005,
#   'DAL weight': 0.1060155245808855,
#   'NFLX weight': 0.09258691653521021,
#   'AAPL weight': 0.08823262741197922,
#   'PFE weight': 0.1265302644186265,
#   'BTC weight': 0.14338140593797424},
#  {'Returns': 98.53945079125737,
#   'Volatility': 0.25418913268856086,
#   'SHOP weight': 0.09337008110546678,
#   'TSLA weight': 0.012146968889880082,
#   'GOLD weight': 0.11323682405515889,
#   'DAL weight': 0.027567620205801998,
#   'NFLX weight': 0.08697096919642702,
#   'AAPL weight': 0.18262872347740924,
#   'PFE weight': 0.21703163754602706,
#   'BTC weight': 0.2670471755238289},
#  {'Returns': 63.038403291878765,
#   'Volatility': 0.22945615258626412,
#   'SHOP weight': 0.1498584555380788,
#   'TSLA weight': 0.05976537581447022,
#   'GOLD weight': 0.18545527430713066,
#   'DAL weight': 0.11149658186905893,
#   'NFLX weight': 0.0854233535770685,
#   'AAPL weight': 0.1876371283391892,
#   'PFE weight': 0.06863443820047645,
#   'BTC weight': 0.15172939235452718},
#  {'Returns': 28.470747229436164,
#   'Volatility': 0.22736092217736353,
#   'SHOP weight': 0.012132991516989123,
#   'TSLA weight': 0.10869442157309606,
#   'GOLD weight': 0.25849831773545645,
#   'DAL weight': 0.06690378411493059,
#   'NFLX weight': 0.2265814858408419,
#   'AAPL weight': 0.22346828518464482,
#   'PFE weight': 0.041848949345611286,
#   'BTC weight': 0.06187176468842974},
#  {'Returns': 54.699067142891096,
#   'Volatility': 0.1944221885083727,
#   'SHOP weight': 0.020923176547741895,
#   'TSLA weight': 0.08406983622874821,
#   'GOLD weight': 0.10318032730108859,
#   'DAL weight': 0.09203412239956472,
#   'NFLX weight': 0.038084278948723745,
#   'AAPL weight': 0.24792651054017548,
#   'PFE weight': 0.30921922938640123,
#   'BTC weight': 0.1045625186475562},
#  {'Returns': 75.84967549145433,
#   'Volatility': 0.24031317785291328,
#   'SHOP weight': 0.1897520041763941,
#   'TSLA weight': 0.0443285834894339,
#   'GOLD weight': 0.07719660091928694,
#   'DAL weight': 0.035773630402438424,
#   'NFLX weight': 0.12896960843041907,
#   'AAPL weight': 0.19056111718373717,
#   'PFE weight': 0.15793642121364423,
#   'BTC weight': 0.17548203418464617},
#  {'Returns': 77.15605549700508,
#   'Volatility': 0.2338034029828557,
#   'SHOP weight': 0.15383201679552827,
#   'TSLA weight': 0.07858521132598287,
#   'GOLD weight': 0.17933084392141224,
#   'DAL weight': 0.1268771208642714,
#   'NFLX weight': 0.005253426417121531,
#   'AAPL weight': 0.11718455364012173,
#   'PFE weight': 0.15171110441081814,
#   'BTC weight': 0.18722572262474377},
#  {'Returns': 63.750053880133194,
#   'Volatility': 0.27105697467099393,
#   'SHOP weight': 0.22684471787543944,
#   'TSLA weight': 0.18948620541386027,
#   'GOLD weight': 0.21225427110135395,
#   'DAL weight': 0.0641517545874868,
#   'NFLX weight': 0.0710427721871857,
#   'AAPL weight': 0.01798768513853381,
#   'PFE weight': 0.08455236453596496,
#   'BTC weight': 0.13368022916017505},
#  {'Returns': 38.758749188081175,
#   'Volatility': 0.21251876367456146,
#   'SHOP weight': 0.04809270683494104,
#   'TSLA weight': 0.08967711566963722,
#   'GOLD weight': 0.249467155866005,
#   'DAL weight': 0.2636571565033484,
#   'NFLX weight': 0.00027836974801229906,
#   'AAPL weight': 0.18597626573833034,
#   'PFE weight': 0.08732997992107037,
#   'BTC weight': 0.0755212497186553},
#  {'Returns': 72.63680462202771,
#   'Volatility': 0.25613349559397236,
#   'SHOP weight': 0.2067922993971572,
#   'TSLA weight': 0.14732803784709947,
#   'GOLD weight': 0.16671475068974398,
#   'DAL weight': 0.2274631189264398,
#   'NFLX weight': 0.02734478420540112,
#   'AAPL weight': 0.003619432720395877,
#   'PFE weight': 0.06323747394496226,
#   'BTC weight': 0.15750010226880018},
#  {'Returns': 87.55895166766412,
#   'Volatility': 0.2648438038283611,
#   'SHOP weight': 0.26102518596707996,
#   'TSLA weight': 0.10161119677788998,
#   'GOLD weight': 0.022705590628133487,
#   'DAL weight': 0.27088084609578494,
#   'NFLX weight': 0.007391053078963164,
#   'AAPL weight': 0.05636792844508314,
#   'PFE weight': 0.09880799333483034,
#   'BTC weight': 0.18121020567223495},
#  {'Returns': 80.48234911539924,
#   'Volatility': 0.25097046955779695,
#   'SHOP weight': 0.20753483151625687,
#   'TSLA weight': 0.05744952383421323,
#   'GOLD weight': 0.21203307165337137,
#   'DAL weight': 0.17231756589752686,
#   'NFLX weight': 0.03302974075010928,
#   'AAPL weight': 0.04959016656498555,
#   'PFE weight': 0.06183008425339264,
#   'BTC weight': 0.2062150155301443},
#  {'Returns': 60.262274583238764,
#   'Volatility': 0.23162034776692533,
#   'SHOP weight': 0.18500499642222365,
#   'TSLA weight': 0.14679915562635962,
#   'GOLD weight': 0.19915014279260781,
#   'DAL weight': 0.1417128838921173,
#   'NFLX weight': 0.01507718389227183,
#   'AAPL weight': 0.02078450226734858,
#   'PFE weight': 0.17154533669823469,
#   'BTC weight': 0.11992579840883645},
#  {'Returns': 76.45294104142076,
#   'Volatility': 0.24089439376144817,
#   'SHOP weight': 0.0029270121524426073,
#   'TSLA weight': 0.09518103659502707,
#   'GOLD weight': 0.23377029220250006,
#   'DAL weight': 0.08565376018808513,
#   'NFLX weight': 0.12151564991336257,
#   'AAPL weight': 0.14253572677639587,
#   'PFE weight': 0.10394107519668122,
#   'BTC weight': 0.21447544697550552},
#  {'Returns': 65.51894901115827,
#   'Volatility': 0.24663145528959435,
#   'SHOP weight': 0.15475565203920305,
#   'TSLA weight': 0.07007770094614729,
#   'GOLD weight': 0.04604964889523364,
#   'DAL weight': 0.11527845494484923,
#   'NFLX weight': 0.20427225679638966,
#   'AAPL weight': 0.22863945708031022,
#   'PFE weight': 0.03927942187269502,
#   'BTC weight': 0.14164740742517193},
#  {'Returns': 69.24248109533889,
#   'Volatility': 0.23783676940321746,
#   'SHOP weight': 0.03228285837775809,
#   'TSLA weight': 0.17864042741959912,
#   'GOLD weight': 0.16416562679431185,
#   'DAL weight': 0.12054914420560925,
#   'NFLX weight': 0.0012085432504882966,
#   'AAPL weight': 0.1574039830867346,
#   'PFE weight': 0.19261554543862536,
#   'BTC weight': 0.1531338714268734},
#  {'Returns': 114.1442010514254,
#   'Volatility': 0.29747668537973376,
#   'SHOP weight': 0.09368998203720093,
#   'TSLA weight': 0.044189141892553935,
#   'GOLD weight': 0.12080044336473818,
#   'DAL weight': 0.0873246677353029,
#   'NFLX weight': 0.1015437291230997,
#   'AAPL weight': 0.1502067260808752,
#   'PFE weight': 0.07997598341359591,
#   'BTC weight': 0.3222693263526333},
#  {'Returns': 27.198796292979623,
#   'Volatility': 0.19446517219346218,
#   'SHOP weight': 0.012622176263667078,
#   'TSLA weight': 0.0510625201433829,
#   'GOLD weight': 0.16488496947800435,
#   'DAL weight': 0.19831778615565196,
#   'NFLX weight': 0.17546978625297577,
#   'AAPL weight': 0.23362904243732932,
#   'PFE weight': 0.12504354424836273,
#   'BTC weight': 0.03897017502062589},
#  {'Returns': 85.63261031858256,
#   'Volatility': 0.249886595919901,
#   'SHOP weight': 0.08089285246454281,
#   'TSLA weight': 0.08613433197168884,
#   'GOLD weight': 0.0023993543440104393,
#   'DAL weight': 0.2544287959126108,
#   'NFLX weight': 0.1352449350300149,
#   'AAPL weight': 0.17111877673113277,
#   'PFE weight': 0.07218845681024996,
#   'BTC weight': 0.19759249673574947},
#  {'Returns': 43.80094295102363,
#   'Volatility': 0.2262475393528922,
#   'SHOP weight': 0.15012959258232855,
#   'TSLA weight': 0.1043727028747507,
#   'GOLD weight': 0.13701904034375853,
#   'DAL weight': 0.11054799558551864,
#   'NFLX weight': 0.15191006443304592,
#   'AAPL weight': 0.16913887970385852,
#   'PFE weight': 0.10336112849006271,
#   'BTC weight': 0.07352059598667654},
#  {'Returns': 102.31287179369733,
#   'Volatility': 0.2671736515174968,
#   'SHOP weight': 0.1631775680464003,
#   'TSLA weight': 0.04418728077662477,
#   'GOLD weight': 0.05653583688679066,
#   'DAL weight': 0.19796295654595708,
#   'NFLX weight': 0.009933699817962697,
#   'AAPL weight': 0.15526447663193102,
#   'PFE weight': 0.11754934451568655,
#   'BTC weight': 0.2553888367786469},
#  {'Returns': 66.238413710348,
#   'Volatility': 0.2316156030327396,
#   'SHOP weight': 0.05135827874913023,
#   'TSLA weight': 0.18372151328004496,
#   'GOLD weight': 0.14765785022443698,
#   'DAL weight': 0.16950849796883313,
#   'NFLX weight': 0.07853350401584425,
#   'AAPL weight': 0.042527105176952774,
#   'PFE weight': 0.18686054370579003,
#   'BTC weight': 0.13983270687896768},
#  {'Returns': 91.85310961345323,
#   'Volatility': 0.2496769952852856,
#   'SHOP weight': 0.1533870808529376,
#   'TSLA weight': 0.008885236892379413,
#   'GOLD weight': 0.08349562878637126,
#   'DAL weight': 0.24976989654292686,
#   'NFLX weight': 0.11597590751832608,
#   'AAPL weight': 0.06478842903605128,
#   'PFE weight': 0.08900882959202118,
#   'BTC weight': 0.23468899077898642},
#  {'Returns': 25.106424609209025,
#   'Volatility': 0.22625357281208608,
#   'SHOP weight': 0.1100895949386496,
#   'TSLA weight': 0.13735965018569302,
#   'GOLD weight': 0.12774160155749578,
#   'DAL weight': 0.26279278330541445,
#   'NFLX weight': 0.17499691719756005,
#   'AAPL weight': 0.07664740714483025,
#   'PFE weight': 0.10688591519491425,
#   'BTC weight': 0.0034861304754427004},
#  {'Returns': 25.157624589654226,
#   'Volatility': 0.2704375558908104,
#   'SHOP weight': 0.1885175156195918,
#   'TSLA weight': 0.20427190296082565,
#   'GOLD weight': 0.22489106396841005,
#   'DAL weight': 0.11822519242590854,
#   'NFLX weight': 0.15388716360258478,
#   'AAPL weight': 0.057898796739494156,
#   'PFE weight': 0.041686294338951047,
#   'BTC weight': 0.010622070344233894},
#  {'Returns': 62.48509262145681,
#   'Volatility': 0.21780786487166331,
#   'SHOP weight': 0.042487052605335224,
#   'TSLA weight': 0.14105984743411173,
#   'GOLD weight': 0.2172807396602854,
#   'DAL weight': 0.1853497429931052,
#   'NFLX weight': 0.015763213905357103,
#   'AAPL weight': 0.03245669571203085,
#   'PFE weight': 0.22541658639376613,
#   'BTC weight': 0.14018612129600824},
#  {'Returns': 43.84386956355604,
#   'Volatility': 0.2177013337938676,
#   'SHOP weight': 0.022869901623547274,
#   'TSLA weight': 0.17111089053508868,
#   'GOLD weight': 0.11447633615790162,
#   'DAL weight': 0.1547585862310261,
#   'NFLX weight': 0.12629179468873156,
#   'AAPL weight': 0.15303971501549427,
#   'PFE weight': 0.19226873412441467,
#   'BTC weight': 0.06518404162379578},
#  {'Returns': 78.6588912323956,
#   'Volatility': 0.23839750989684386,
#   'SHOP weight': 0.14761013888964697,
#   'TSLA weight': 0.08547374617073737,
#   'GOLD weight': 0.05715394028295805,
#   'DAL weight': 0.1149401360654575,
#   'NFLX weight': 0.19248996626190043,
#   'AAPL weight': 0.0871067076649706,
#   'PFE weight': 0.13404298707807996,
#   'BTC weight': 0.18118237758624897},
#  {'Returns': 32.88875464182372,
#   'Volatility': 0.22077424478009,
#   'SHOP weight': 0.16378187131956187,
#   'TSLA weight': 0.05513741428214125,
#   'GOLD weight': 0.20628791531151053,
#   'DAL weight': 0.051960658103472494,
#   'NFLX weight': 0.1901552274883894,
#   'AAPL weight': 0.15491966595314027,
#   'PFE weight': 0.1212861151979317,
#   'BTC weight': 0.056471132343852454},
#  {'Returns': 35.12337457351656,
#   'Volatility': 0.22880990701962967,
#   'SHOP weight': 0.22762249731037673,
#   'TSLA weight': 0.12541350812936197,
#   'GOLD weight': 0.10636026541551313,
#   'DAL weight': 0.1263353785574675,
#   'NFLX weight': 0.05469012797296869,
#   'AAPL weight': 0.1139756674416313,
#   'PFE weight': 0.22779998398396026,
#   'BTC weight': 0.017802571188720584},
#  {'Returns': 31.85283140060016,
#   'Volatility': 0.22562916911910003,
#   'SHOP weight': 0.15209878817923891,
#   'TSLA weight': 0.12871112067022206,
#   'GOLD weight': 0.08921847876402293,
#   'DAL weight': 0.2375988926448762,
#   'NFLX weight': 0.03496551675657775,
#   'AAPL weight': 0.1882495824832389,
#   'PFE weight': 0.15999191437794033,
#   'BTC weight': 0.009165706123882972},
#  {'Returns': 56.61415995047104,
#   'Volatility': 0.2348593239004778,
#   'SHOP weight': 0.0700351516032284,
#   'TSLA weight': 0.18099341279613815,
#   'GOLD weight': 0.13187219726272675,
#   'DAL weight': 0.10979026433758003,
#   'NFLX weight': 0.02549650881414784,
#   'AAPL weight': 0.20602729688916296,
#   'PFE weight': 0.17210655652831913,
#   'BTC weight': 0.10367861176869674},
#  {'Returns': 85.22084080829633,
#   'Volatility': 0.26442912481479897,
#   'SHOP weight': 0.17291889197560908,
#   'TSLA weight': 0.13526418698493128,
#   'GOLD weight': 0.04459890721403709,
#   'DAL weight': 0.15870003342410352,
#   'NFLX weight': 0.04050748123868205,
#   'AAPL weight': 0.17806016214193235,
#   'PFE weight': 0.08355023775650441,
#   'BTC weight': 0.18640009926420026},
#  {'Returns': 37.89397780800613,
#   'Volatility': 0.21891864873999156,
#   'SHOP weight': 0.17206218754126096,
#   'TSLA weight': 0.13876543592058768,
#   'GOLD weight': 0.13523817729682525,
#   'DAL weight': 0.18980356680873878,
#   'NFLX weight': 0.10526453466078832,
#   'AAPL weight': 0.03425254956714643,
#   'PFE weight': 0.1871882800941206,
#   'BTC weight': 0.03742526811053198},
#  {'Returns': 79.00847540846303,
#   'Volatility': 0.29073833145263006,
#   'SHOP weight': 0.18813202903863707,
#   'TSLA weight': 0.22122756741203717,
#   'GOLD weight': 0.07349474542592409,
#   'DAL weight': 0.1799889397716787,
#   'NFLX weight': 0.07494499862027154,
#   'AAPL weight': 0.08743216338646607,
#   'PFE weight': 0.013551913176061754,
#   'BTC weight': 0.16122764316892346},
#  {'Returns': 73.90163066982024,
#   'Volatility': 0.23131022168701715,
#   'SHOP weight': 0.14958140781495613,
#   'TSLA weight': 0.06272516272266732,
#   'GOLD weight': 0.14166563010200067,
#   'DAL weight': 0.1949701807277116,
#   'NFLX weight': 0.06414273760326594,
#   'AAPL weight': 0.12257229846977323,
#   'PFE weight': 0.088279575986916,
#   'BTC weight': 0.17606300657270915},
#  {'Returns': 46.66788452422041,
#   'Volatility': 0.2135391772579503,
#   'SHOP weight': 0.10222726402165072,
#   'TSLA weight': 0.1157412567210601,
#   'GOLD weight': 0.13958654822116576,
#   'DAL weight': 0.13366649265327887,
#   'NFLX weight': 0.17994965429062038,
#   'AAPL weight': 0.10282809386338763,
#   'PFE weight': 0.14096498840981303,
#   'BTC weight': 0.08503570181902345},
#  {'Returns': 20.35260874872111,
#   'Volatility': 0.2421826771393544,
#   'SHOP weight': 0.25578636393929927,
#   'TSLA weight': 0.025572187931370137,
#   'GOLD weight': 0.23996070414653078,
#   'DAL weight': 0.16480136664017725,
#   'NFLX weight': 0.22869212099000472,
#   'AAPL weight': 0.051413431957111844,
#   'PFE weight': 0.015180671028300315,
#   'BTC weight': 0.01859315336720574},
#  {'Returns': 88.14800033362744,
#   'Volatility': 0.2821584733680754,
#   'SHOP weight': 0.06409896312672897,
#   'TSLA weight': 0.24672426468013203,
#   'GOLD weight': 0.043928600850187974,
#   'DAL weight': 0.022395283262158894,
#   'NFLX weight': 0.14387693503695487,
#   'AAPL weight': 0.09128612669856609,
#   'PFE weight': 0.19334781598463727,
#   'BTC weight': 0.19434201036063384},
#  {'Returns': 62.805987211243334,
#   'Volatility': 0.24474690795969756,
#   'SHOP weight': 0.14739883157236816,
#   'TSLA weight': 0.17810716881865069,
#   'GOLD weight': 0.13061772402280952,
#   'DAL weight': 0.17563935378971113,
#   'NFLX weight': 0.0744086462071992,
#   'AAPL weight': 0.06507412854432945,
#   'PFE weight': 0.10780153914522896,
#   'BTC weight': 0.12095260789970297},
#  {'Returns': 53.10220020592262,
#   'Volatility': 0.26606870491345336,
#   'SHOP weight': 0.06266158667701083,
#   'TSLA weight': 0.2504522769459635,
#   'GOLD weight': 0.12395956725440381,
#   'DAL weight': 0.21120096202198466,
#   'NFLX weight': 0.019272479869841368,
#   'AAPL weight': 0.1727121286755341,
#   'PFE weight': 0.07710555611180983,
#   'BTC weight': 0.082635442443452},
#  {'Returns': 52.06052941873949,
#   'Volatility': 0.2667429609051711,
#   'SHOP weight': 0.3195976506626234,
#   'TSLA weight': 0.08688632815916576,
#   'GOLD weight': 0.04699575702883836,
#   'DAL weight': 0.08456986686638816,
#   'NFLX weight': 0.12221986025019092,
#   'AAPL weight': 0.16200713923208404,
#   'PFE weight': 0.10491585483207165,
#   'BTC weight': 0.07280754296863774},
#  {'Returns': 46.77028518783823,
#   'Volatility': 0.23844904569979422,
#   'SHOP weight': 0.18195556641272628,
#   'TSLA weight': 0.11774374667757861,
#   'GOLD weight': 0.141553638604447,
#   'DAL weight': 0.13251458746297423,
#   'NFLX weight': 0.10588556866002721,
#   'AAPL weight': 0.17567258158896829,
#   'PFE weight': 0.06601286506153425,
#   'BTC weight': 0.0786614455317441},
#  {'Returns': 90.62802912874893,
#   'Volatility': 0.2607201636185918,
#   'SHOP weight': 0.08161552672331175,
#   'TSLA weight': 0.09974126830072282,
#   'GOLD weight': 0.193012383033569,
#   'DAL weight': 0.1043121613918926,
#   'NFLX weight': 0.09880174052224742,
#   'AAPL weight': 0.0831249526794986,
#   'PFE weight': 0.0926445800684115,
#   'BTC weight': 0.24674738728034631},
#  {'Returns': 67.17888563167422,
#   'Volatility': 0.23354629843262,
#   'SHOP weight': 0.017922591679938347,
#   'TSLA weight': 0.08455902259657327,
#   'GOLD weight': 0.28571759891526527,
#   'DAL weight': 0.1977127829722588,
#   'NFLX weight': 0.01985956958244321,
#   'AAPL weight': 0.12855462037733262,
#   'PFE weight': 0.08097421418527108,
#   'BTC weight': 0.1846995996909173},
#  {'Returns': 62.221178512645466,
#   'Volatility': 0.24009802136224306,
#   'SHOP weight': 0.2279587367508536,
#   'TSLA weight': 0.07299154385996312,
#   'GOLD weight': 0.0853486237574699,
#   'DAL weight': 0.2392918454338633,
#   'NFLX weight': 0.07887744584639092,
#   'AAPL weight': 0.13616283667411974,
#   'PFE weight': 0.0392206284181667,
#   'BTC weight': 0.1201483392591728},
#  {'Returns': 82.33617392340264,
#   'Volatility': 0.2265070330376933,
#   'SHOP weight': 0.20270449214706357,
#   'TSLA weight': 0.013337973577182001,
#   'GOLD weight': 0.13638107976063416,
#   'DAL weight': 0.09599711379342878,
#   'NFLX weight': 0.10333061508386185,
#   'AAPL weight': 0.014283118802830931,
#   'PFE weight': 0.2303910535610295,
#   'BTC weight': 0.2035745532739691},
#  {'Returns': 96.69400966726644,
#   'Volatility': 0.27804279341695676,
#   'SHOP weight': 0.049714644424173456,
#   'TSLA weight': 0.1663691258451865,
#   'GOLD weight': 0.14583649208421653,
#   'DAL weight': 0.049628614858837565,
#   'NFLX weight': 0.07163728226023075,
#   'AAPL weight': 0.13005230812141216,
#   'PFE weight': 0.13518687209199795,
#   'BTC weight': 0.25157466031394515},
#  {'Returns': 36.36528500091342,
#   'Volatility': 0.2967009596430034,
#   'SHOP weight': 0.22207494046214218,
#   'TSLA weight': 0.26528691601600535,
#   'GOLD weight': 0.05941497334495457,
#   'DAL weight': 0.267140067236916,
#   'NFLX weight': 0.09341304390496963,
#   'AAPL weight': 0.04322643776773236,
#   'PFE weight': 0.048060750485096386,
#   'BTC weight': 0.0013828707821834103},
#  {'Returns': 38.16007861074624,
#   'Volatility': 0.23884663314000518,
#   'SHOP weight': 0.04421707320902963,
#   'TSLA weight': 0.22814488549339995,
#   'GOLD weight': 0.12878203062243307,
#   'DAL weight': 0.10206758970353547,
#   'NFLX weight': 0.13134455750359586,
#   'AAPL weight': 0.1180578425969763,
#   'PFE weight': 0.20772198153902433,
#   'BTC weight': 0.03966403933200533},
#  {'Returns': 33.482009159687095,
#   'Volatility': 0.1931401075144944,
#   'SHOP weight': 0.0816272400337988,
#   'TSLA weight': 0.03832132385260081,
#   'GOLD weight': 0.17515275082428236,
#   'DAL weight': 0.07024475917094156,
#   'NFLX weight': 0.19456519941604783,
#   'AAPL weight': 0.1858244186808596,
#   'PFE weight': 0.1952776597836044,
#   'BTC weight': 0.05898664823786464},
#  {'Returns': 46.14906079614227,
#   'Volatility': 0.2230138891663027,
#   'SHOP weight': 0.0384538000462193,
#   'TSLA weight': 0.028913812387569494,
#   'GOLD weight': 0.3214512878350424,
#   'DAL weight': 0.08424942193552967,
#   'NFLX weight': 0.1343747931080796,
#   'AAPL weight': 0.24757754852870084,
#   'PFE weight': 0.0070093619397737774,
#   'BTC weight': 0.1379699742190849},
#  {'Returns': 82.18735174200518,
#   'Volatility': 0.23433607434721257,
#   'SHOP weight': 0.09240471476034387,
#   'TSLA weight': 0.07667404545011895,
#   'GOLD weight': 0.03573379240018554,
#   'DAL weight': 0.15566126073174313,
#   'NFLX weight': 0.1218264605273771,
#   'AAPL weight': 0.18385880067050167,
#   'PFE weight': 0.1429617496446583,
#   'BTC weight': 0.19087917581507144},
#  {'Returns': 60.582190287894086,
#   'Volatility': 0.22682221585817153,
#   'SHOP weight': 0.17014610346096729,
#   'TSLA weight': 0.03638386466951649,
#   'GOLD weight': 0.21056236190005664,
#   'DAL weight': 0.05893048734566379,
#   'NFLX weight': 0.14481095152560775,
#   'AAPL weight': 0.1256553245837617,
#   'PFE weight': 0.10179956455633009,
#   'BTC weight': 0.15171134195809607},
#  {'Returns': 19.664769204124013,
#   'Volatility': 0.22415239005220544,
#   'SHOP weight': 0.1468666282084207,
#   'TSLA weight': 0.0635279118529274,
#   'GOLD weight': 0.2032726832150519,
#   'DAL weight': 0.06981921398445448,
#   'NFLX weight': 0.18223652172772475,
#   'AAPL weight': 0.20404986019868301,
#   'PFE weight': 0.11951100148422233,
#   'BTC weight': 0.010716179328515494},
#  {'Returns': 58.384604046595555,
#   'Volatility': 0.23835536554509948,
#   'SHOP weight': 0.07454621827383828,
#   'TSLA weight': 0.15015337193905762,
#   'GOLD weight': 0.1216179372689878,
#   'DAL weight': 0.16757038067738142,
#   'NFLX weight': 0.14740353958246485,
#   'AAPL weight': 0.16317054832064196,
#   'PFE weight': 0.05424329040174855,
#   'BTC weight': 0.12129471353587955},
#  {'Returns': 63.359483627300094,
#   'Volatility': 0.227629407508074,
#   'SHOP weight': 0.22181209689310868,
#   'TSLA weight': 0.00675061977856869,
#   'GOLD weight': 0.07998074732094598,
#   'DAL weight': 0.2310986901941351,
#   'NFLX weight': 0.06953295499037221,
#   'AAPL weight': 0.19992937189944981,
#   'PFE weight': 0.059183748510692254,
#   'BTC weight': 0.13171177041272727},
#  {'Returns': 20.511940235272917,
#   'Volatility': 0.2076250647717369,
#   'SHOP weight': 0.005128675667691892,
#   'TSLA weight': 0.16708304580243413,
#   'GOLD weight': 0.24825873567678614,
#   'DAL weight': 0.11991831494658475,
#   'NFLX weight': 0.09799185064705312,
#   'AAPL weight': 0.08055044860077928,
#   'PFE weight': 0.2746559990857797,
#   'BTC weight': 0.006412929572890955},
#  {'Returns': 53.38480196290112,
#   'Volatility': 0.2552058376608571,
#   'SHOP weight': 0.22243924530788914,
#   'TSLA weight': 0.15570024450290107,
#   'GOLD weight': 0.12669173748074347,
#   'DAL weight': 0.20586671520455038,
#   'NFLX weight': 0.1569311413775423,
#   'AAPL weight': 0.004705509822662015,
#   'PFE weight': 0.03679036289093172,
#   'BTC weight': 0.09087504341277994},
#  {'Returns': 83.09685206269751,
#   'Volatility': 0.22551411899201781,
#   'SHOP weight': 0.06974592499012253,
#   'TSLA weight': 0.042238161031916494,
#   'GOLD weight': 0.15741303166282206,
#   'DAL weight': 0.10650160751707494,
#   'NFLX weight': 0.0395891286754982,
#   'AAPL weight': 0.1452256612244193,
#   'PFE weight': 0.22430637702738218,
#   'BTC weight': 0.21498010787076427},
#  {'Returns': 70.34382625872058,
#   'Volatility': 0.2150123765555242,
#   'SHOP weight': 0.09674616172555937,
#   'TSLA weight': 0.016029893451905006,
#   'GOLD weight': 0.14100792558187078,
#   'DAL weight': 0.07742272963759696,
#   'NFLX weight': 0.21614600274144183,
#   'AAPL weight': 0.10520984667851509,
#   'PFE weight': 0.16538806773605372,
#   'BTC weight': 0.1820493724470573},
#  {'Returns': 72.84657740527165,
#   'Volatility': 0.2437164442269595,
#   'SHOP weight': 0.1871050475421423,
#   'TSLA weight': 0.12884573415928216,
#   'GOLD weight': 0.11516952023382529,
#   'DAL weight': 0.10119711534459526,
#   'NFLX weight': 0.07003212285264096,
#   'AAPL weight': 0.0973456566237169,
#   'PFE weight': 0.14427952813768744,
#   'BTC weight': 0.15602527510610983},
#  {'Returns': 75.54623779332584,
#   'Volatility': 0.255557454757375,
#   'SHOP weight': 0.11241646533826022,
#   'TSLA weight': 0.17864981849164518,
#   'GOLD weight': 0.18983564189869442,
#   'DAL weight': 0.1018325481279537,
#   'NFLX weight': 0.04757108917685183,
#   'AAPL weight': 0.07766147669295718,
#   'PFE weight': 0.11394276354354992,
#   'BTC weight': 0.1780901967300874},
#  {'Returns': 50.73079596871902,
#   'Volatility': 0.2061843941473248,
#   'SHOP weight': 0.1812795194971495,
#   'TSLA weight': 0.1215657822297847,
#   'GOLD weight': 0.13670664662041002,
#   'DAL weight': 0.1448517251826675,
#   'NFLX weight': 0.04808709854751084,
#   'AAPL weight': 0.0013348532403665723,
#   'PFE weight': 0.2897376790064535,
#   'BTC weight': 0.07643669567565747},
#  {'Returns': 56.178411638620986,
#   'Volatility': 0.23422375112891314,
#   'SHOP weight': 0.16499125703828715,
#   'TSLA weight': 0.13131812298043624,
#   'GOLD weight': 0.08989583992628528,
#   'DAL weight': 0.08995592192877085,
#   'NFLX weight': 0.134668171725093,
#   'AAPL weight': 0.13959203497788344,
#   'PFE weight': 0.1495317718386005,
#   'BTC weight': 0.10004687958464346},
#  {'Returns': 85.62991017215025,
#   'Volatility': 0.2486286960127313,
#   'SHOP weight': 0.057333604565340146,
#   'TSLA weight': 0.11195501110230867,
#   'GOLD weight': 0.04147505594280288,
#   'DAL weight': 0.21195886945295284,
#   'NFLX weight': 0.21413407541254847,
#   'AAPL weight': 0.06140923990042201,
#   'PFE weight': 0.09528416950001525,
#   'BTC weight': 0.2064499741236097},
#  {'Returns': 91.88737184357913,
#   'Volatility': 0.26086478814897474,
#   'SHOP weight': 0.14680874157061763,
#   'TSLA weight': 0.15485328454077904,
#   'GOLD weight': 0.04111276224395756,
#   'DAL weight': 0.0808268230935116,
#   'NFLX weight': 0.017933748413951015,
#   'AAPL weight': 0.1405223949832154,
#   'PFE weight': 0.21492594087326738,
#   'BTC weight': 0.20301630428070053},
#  {'Returns': 65.04968589677343,
#   'Volatility': 0.24890245923468063,
#   'SHOP weight': 0.09558741741648523,
#   'TSLA weight': 0.15315568090047707,
#   'GOLD weight': 0.0853354760665525,
#   'DAL weight': 0.09609098566775198,
#   'NFLX weight': 0.21055948289637355,
#   'AAPL weight': 0.14229030490594147,
#   'PFE weight': 0.07747944191353498,
#   'BTC weight': 0.13950121023288312},
#  {'Returns': 31.43004682634207,
#   'Volatility': 0.22344810652947975,
#   'SHOP weight': 0.11056078143800002,
#   'TSLA weight': 0.12062137717826324,
#   'GOLD weight': 0.11953568277364097,
#   'DAL weight': 0.18314646132199755,
#   'NFLX weight': 0.1710448796293435,
#   'AAPL weight': 0.1676897935958713,
#   'PFE weight': 0.09866353868474319,
#   'BTC weight': 0.02873748537814023},
#  {'Returns': 39.961911751778906,
#   'Volatility': 0.19502182554689995,
#   'SHOP weight': 0.06848830989103208,
#   'TSLA weight': 0.1030632304910072,
#   'GOLD weight': 0.1834834187798624,
#   'DAL weight': 0.14801794006974056,
#   'NFLX weight': 0.14517812831006766,
#   'AAPL weight': 0.08303457217396934,
#   'PFE weight': 0.19921622865783384,
#   'BTC weight': 0.06951817162648706},
#  {'Returns': 55.89356516311187,
#   'Volatility': 0.22483477739257193,
#   'SHOP weight': 0.12492759692865035,
#   'TSLA weight': 0.12748964081198308,
#   'GOLD weight': 0.13211257829397613,
#   'DAL weight': 0.11670254355165008,
#   'NFLX weight': 0.12156968191428806,
#   'AAPL weight': 0.13314130765187632,
#   'PFE weight': 0.13443863341866297,
#   'BTC weight': 0.10961801742891288},
#  {'Returns': 28.550257320790756,
#   'Volatility': 0.2926099657597964,
#   'SHOP weight': 0.2598639541237182,
#   'TSLA weight': 0.1922879625216167,
#   'GOLD weight': 0.2521113481626127,
#   'DAL weight': 0.02922368205366776,
#   'NFLX weight': 0.1847015026045096,
#   'AAPL weight': 0.019999965491678245,
#   'PFE weight': 0.03535829005208235,
#   'BTC weight': 0.02645329499011439},
#  {'Returns': 58.73947027154411,
#   'Volatility': 0.20929263688241387,
#   'SHOP weight': 0.0853964467998019,
#   'TSLA weight': 0.06525890854708025,
#   'GOLD weight': 0.18910195824564657,
#   'DAL weight': 0.16449783790319816,
#   'NFLX weight': 0.18521464343959243,
#   'AAPL weight': 0.05310333716716039,
#   'PFE weight': 0.11414701225454141,
#   'BTC weight': 0.14327985564297882},
#  {'Returns': 50.704946767367915,
#   'Volatility': 0.20692528120420525,
#   'SHOP weight': 0.07804761345302198,
#   'TSLA weight': 0.04330236817473661,
#   'GOLD weight': 0.17747562455704838,
#   'DAL weight': 0.08929134040487938,
#   'NFLX weight': 0.1902073961962152,
#   'AAPL weight': 0.18466284090004595,
#   'PFE weight': 0.11651687855971135,
#   'BTC weight': 0.12049593775434116},
#  {'Returns': 61.26012070127685,
#   'Volatility': 0.23528533194330453,
#   'SHOP weight': 0.15611865140001233,
#   'TSLA weight': 0.07821285319826216,
#   'GOLD weight': 0.10506136322896391,
#   'DAL weight': 0.24042585499527203,
#   'NFLX weight': 0.03229344400186989,
#   'AAPL weight': 0.2344214263908752,
#   'PFE weight': 0.02900092747021421,
#   'BTC weight': 0.12446547931453036},
#  {'Returns': 26.15383918217874,
#   'Volatility': 0.19678244847351908,
#   'SHOP weight': 0.06868828342480375,
#   'TSLA weight': 0.07786080227412746,
#   'GOLD weight': 0.23052347308537807,
#   'DAL weight': 0.17543650983471462,
#   'NFLX weight': 0.07203243921658674,
#   'AAPL weight': 0.18610748239555003,
#   'PFE weight': 0.1573112052291883,
#   'BTC weight': 0.032039804539651},
#  {'Returns': 89.07170344800889,
#   'Volatility': 0.2819672177664415,
#   'SHOP weight': 0.04171168233502337,
#   'TSLA weight': 0.1783334266455506,
#   'GOLD weight': 0.1792471105591523,
#   'DAL weight': 0.09000764196505857,
#   'NFLX weight': 0.17936500582832549,
#   'AAPL weight': 0.06290034753383741,
#   'PFE weight': 0.02920438790143295,
#   'BTC weight': 0.23923039723161932},
#  {'Returns': 87.92473542813205,
#   'Volatility': 0.286180694497677,
#   'SHOP weight': 0.25586102547702877,
#   'TSLA weight': 0.19540879053929203,
#   'GOLD weight': 0.040944032511734424,
#   'DAL weight': 0.15940408319538435,
#   'NFLX weight': 0.056990460611441536,
#   'AAPL weight': 0.003538133948787044,
#   'PFE weight': 0.10948292624348333,
#   'BTC weight': 0.1783705474728485},
#  {'Returns': 107.28928779947276,
#   'Volatility': 0.29774617401853026,
#   'SHOP weight': 0.034030936613704474,
#   'TSLA weight': 0.15809004325406836,
#   'GOLD weight': 0.11515776979433147,
#   'DAL weight': 0.008682578517706345,
#   'NFLX weight': 0.24861242586368146,
#   'AAPL weight': 0.012418235721016512,
#   'PFE weight': 0.12848914637845227,
#   'BTC weight': 0.29451886385703896},
#  {'Returns': 34.0694900917595,
#   'Volatility': 0.2517830084023576,
#   'SHOP weight': 0.34848095241108396,
#   'TSLA weight': 0.00043770149798773387,
#   'GOLD weight': 0.1459254258466092,
#   'DAL weight': 0.18076091026920557,
#   'NFLX weight': 0.10666709310379344,
#   'AAPL weight': 0.14375189210689787,
#   'PFE weight': 0.03671006532151128,
#   'BTC weight': 0.03726595944291102},
#  {'Returns': 75.05476906703493,
#   'Volatility': 0.24555094947191058,
#   'SHOP weight': 0.11736411676512974,
#   'TSLA weight': 0.15104738481746402,
#   'GOLD weight': 0.040828183837052556,
#   'DAL weight': 0.06467542825798352,
#   'NFLX weight': 0.17356427265431323,
#   'AAPL weight': 0.11748271287423089,
#   'PFE weight': 0.17640493490607226,
#   'BTC weight': 0.15863296588775377},
#  {'Returns': 39.88664242206681,
#   'Volatility': 0.19363685530623947,
#   'SHOP weight': 0.23727221413948674,
#   'TSLA weight': 0.003524730174206537,
#   'GOLD weight': 0.07525293909981691,
#   'DAL weight': 0.22299675284961704,
#   'NFLX weight': 0.04069443498222735,
#   'AAPL weight': 0.0990857724297909,
#   'PFE weight': 0.28309240402916747,
#   'BTC weight': 0.03808075229568707},
#  {'Returns': 107.33380213582376,
#   'Volatility': 0.2668678185389705,
#   'SHOP weight': 0.06310500899783861,
#   'TSLA weight': 0.07030615618963168,
#   'GOLD weight': 0.018582329577242984,
#   'DAL weight': 0.014341526746227554,
#   'NFLX weight': 0.011563407721142234,
#   'AAPL weight': 0.2519431731077829,
#   'PFE weight': 0.30162135614807933,
#   'BTC weight': 0.2685370415120546},
#  {'Returns': 60.702887994373455,
#   'Volatility': 0.21609397480755296,
#   'SHOP weight': 0.019093675329079688,
#   'TSLA weight': 0.13972637799451748,
#   'GOLD weight': 0.1824234745373543,
#   'DAL weight': 0.20138215626891828,
#   'NFLX weight': 0.12507743631881457,
#   'AAPL weight': 0.018834694467282,
#   'PFE weight': 0.17595377846627608,
#   'BTC weight': 0.13750840661775748},
#  {'Returns': 62.94536467900885,
#   'Volatility': 0.2074686920333819,
#   'SHOP weight': 0.08168256167994034,
#   'TSLA weight': 0.02318771773566856,
#   'GOLD weight': 0.18801259434918632,
#   'DAL weight': 0.1878974366172366,
#   'NFLX weight': 0.1576175400892139,
#   'AAPL weight': 0.08661141117674999,
#   'PFE weight': 0.11345257606002036,
#   'BTC weight': 0.16153816229198395},
#  {'Returns': 32.092304099737404,
#   'Volatility': 0.2318214229567638,
#   'SHOP weight': 0.20901668287021796,
#   'TSLA weight': 0.04100400419902003,
#   'GOLD weight': 0.22041630962321923,
#   'DAL weight': 0.061094677925559705,
#   'NFLX weight': 0.11664459759725695,
#   'AAPL weight': 0.2190999725399885,
#   'PFE weight': 0.08028133862281904,
#   'BTC weight': 0.05244241662191856},
#  {'Returns': 79.14739424662882,
#   'Volatility': 0.2709123854165785,
#   'SHOP weight': 0.07878165107391173,
#   'TSLA weight': 0.20018620011454175,
#   'GOLD weight': 0.1002210921176625,
#   'DAL weight': 0.215905423089452,
#   'NFLX weight': 0.12671031712674627,
#   'AAPL weight': 0.07170350462783012,
#   'PFE weight': 0.02695977644309637,
#   'BTC weight': 0.1795320354067592},
#  {'Returns': 49.55562676007679,
#   'Volatility': 0.25528583098976576,
#   'SHOP weight': 0.20105087723816137,
#   'TSLA weight': 0.10366865485701549,
#   'GOLD weight': 0.063854886999511,
#   'DAL weight': 0.06980592944987439,
#   'NFLX weight': 0.1959475329200106,
#   'AAPL weight': 0.21434495563913786,
#   'PFE weight': 0.07007968557826978,
#   'BTC weight': 0.08124747731801946},
#  {'Returns': 68.46636937396069,
#   'Volatility': 0.23641998692425414,
#   'SHOP weight': 0.11724572099372856,
#   'TSLA weight': 0.0964751904230391,
#   'GOLD weight': 0.2054933231800506,
#   'DAL weight': 0.14611953391025537,
#   'NFLX weight': 0.1528179348557863,
#   'AAPL weight': 0.054217105024222854,
#   'PFE weight': 0.05368887951260786,
#   'BTC weight': 0.17394231210030944},
#  {'Returns': 83.33164877120103,
#   'Volatility': 0.22767306433839385,
#   'SHOP weight': 0.14174339624687862,
#   'TSLA weight': 0.026851691116826795,
#   'GOLD weight': 0.09553833207584628,
#   'DAL weight': 0.03616367548607983,
#   'NFLX weight': 0.20699398103556366,
#   'AAPL weight': 0.03556058275645814,
#   'PFE weight': 0.24753207433557664,
#   'BTC weight': 0.20961626694677007},
#  {'Returns': 14.053103034793597,
#   'Volatility': 0.2473905820117856,
#   'SHOP weight': 0.1418477522179941,
#   'TSLA weight': 0.15382961765162323,
#   'GOLD weight': 0.3367863904966927,
#   'DAL weight': 0.16596144581510042,
#   'NFLX weight': 0.13888969404892354,
#   'AAPL weight': 0.044315365609475674,
#   'PFE weight': 0.016387357036951017,
#   'BTC weight': 0.001982377123239363},
#  {'Returns': 73.09466018562458,
#   'Volatility': 0.2626349916225761,
#   'SHOP weight': 0.13853463331261992,
#   'TSLA weight': 0.13425904029465824,
#   'GOLD weight': 0.2199402693155539,
#   'DAL weight': 0.015093187707951334,
#   'NFLX weight': 0.037436603170801226,
#   'AAPL weight': 0.19301818194143086,
#   'PFE weight': 0.07888990374879705,
#   'BTC weight': 0.18282818050818753},
#  {'Returns': 43.90641161497953,
#   'Volatility': 0.215055752803867,
#   'SHOP weight': 0.1238887116733761,
#   'TSLA weight': 0.022699118232139773,
#   'GOLD weight': 0.18362439410110168,
#   'DAL weight': 0.2595587746813622,
#   'NFLX weight': 0.09687858609314787,
#   'AAPL weight': 0.21775787853242545,
#   'PFE weight': 0.002544780856895922,
#   'BTC weight': 0.09304775582955097},
#  {'Returns': 69.5063702773323,
#   'Volatility': 0.2322264009509506,
#   'SHOP weight': 0.12725493134798388,
#   'TSLA weight': 0.121882884808363,
#   'GOLD weight': 0.08503180165898386,
#   'DAL weight': 0.06613964809826468,
#   'NFLX weight': 0.1796393006229213,
#   'AAPL weight': 0.09161223800430203,
#   'PFE weight': 0.17793809570685404,
#   'BTC weight': 0.15050109975232728},
#  {'Returns': 47.013722716590905,
#   'Volatility': 0.18830036435890796,
#   'SHOP weight': 0.024681953862384653,
#   'TSLA weight': 0.0604085458816195,
#   'GOLD weight': 0.12975808825344706,
#   'DAL weight': 0.023493831336803245,
#   'NFLX weight': 0.16513196265952151,
#   'AAPL weight': 0.20028926618444384,
#   'PFE weight': 0.3019934643061969,
#   'BTC weight': 0.09424288751558313},
#  {'Returns': 73.36371838553625,
#   'Volatility': 0.24220009037013535,
#   'SHOP weight': 0.0813492573562795,
#   'TSLA weight': 0.07071009054485568,
#   'GOLD weight': 0.1798817483774957,
#   'DAL weight': 0.1061761872259,
#   'NFLX weight': 0.18643692456697403,
#   'AAPL weight': 0.14166793161154567,
#   'PFE weight': 0.03695800433883564,
#   'BTC weight': 0.19681985597811374},
#  {'Returns': 75.13364211786165,
#   'Volatility': 0.2626756320862185,
#   'SHOP weight': 0.0985789302619643,
#   'TSLA weight': 0.08723075604127523,
#   'GOLD weight': 0.23590122143597259,
#   'DAL weight': 5.467892769713252e-05,
#   'NFLX weight': 0.09553166810227916,
#   'AAPL weight': 0.23491120304057525,
#   'PFE weight': 0.04013781899486202,
#   'BTC weight': 0.20765372319537437},
#  {'Returns': 51.87082879403896,
#   'Volatility': 0.23593438758985397,
#   'SHOP weight': 0.2322891113856369,
#   'TSLA weight': 0.04098316592481608,
#   'GOLD weight': 0.011320410523424472,
#   'DAL weight': 0.06049277708210996,
#   'NFLX weight': 0.2755709938293003,
#   'AAPL weight': 0.10938512162546447,
#   'PFE weight': 0.18582961121808741,
#   'BTC weight': 0.08412880841116042},
#  {'Returns': 48.91452415180872,
#   'Volatility': 0.23799596216582075,
#   'SHOP weight': 0.211445233465103,
#   'TSLA weight': 0.16945369088102372,
#   'GOLD weight': 0.08003224505876219,
#   'DAL weight': 0.13481838295634505,
#   'NFLX weight': 0.023017949414064785,
#   'AAPL weight': 0.10047862295800278,
#   'PFE weight': 0.22692237675219934,
#   'BTC weight': 0.05383149851449919},
#  {'Returns': 73.10551191509917,
#   'Volatility': 0.2812676240241782,
#   'SHOP weight': 0.04767102634773398,
#   'TSLA weight': 0.233669563185741,
#   'GOLD weight': 0.11953050757441222,
#   'DAL weight': 0.1406479673125671,
#   'NFLX weight': 0.21421264003025214,
#   'AAPL weight': 0.07478306763884211,
#   'PFE weight': 0.0012415013014131244,
#   'BTC weight': 0.16824372660903836},
#  {'Returns': 102.1115268343288,
#   'Volatility': 0.30169193385153037,
#   'SHOP weight': 0.060427419592998424,
#   'TSLA weight': 0.24624726847568093,
#   'GOLD weight': 0.10754781181749824,
#   'DAL weight': 0.12534892849144422,
#   'NFLX weight': 0.026296770034581304,
#   'AAPL weight': 0.06375436646062854,
#   'PFE weight': 0.12286045615562387,
#   'BTC weight': 0.2475169789715445},
#  {'Returns': 53.30433228138928,
#   'Volatility': 0.23001456111027782,
#   'SHOP weight': 0.11032843558252518,
#   'TSLA weight': 0.13049099531140396,
#   'GOLD weight': 0.028096788961726623,
#   'DAL weight': 0.06501228789008695,
#   'NFLX weight': 0.18657901288534945,
#   'AAPL weight': 0.20070554470655386,
#   'PFE weight': 0.19268577276480173,
#   'BTC weight': 0.08610116189755232},
#  {'Returns': 72.98783921608239,
#   'Volatility': 0.2761913852899156,
#   'SHOP weight': 0.17388214730292625,
#   'TSLA weight': 0.18914709472050473,
#   'GOLD weight': 0.11038371263500671,
#   'DAL weight': 0.08031971865865165,
#   'NFLX weight': 0.12245729019126778,
#   'AAPL weight': 0.1156321760381778,
#   'PFE weight': 0.05189527789985682,
#   'BTC weight': 0.1562825825536084},
#  {'Returns': 76.0045225666579,
#   'Volatility': 0.25691316576747975,
#   'SHOP weight': 0.151200610491127,
#   'TSLA weight': 0.15942779709948987,
#   'GOLD weight': 0.015688609650288163,
#   'DAL weight': 0.16449183010717744,
#   'NFLX weight': 0.1353533179659965,
#   'AAPL weight': 0.1249128329039377,
#   'PFE weight': 0.0965485562705788,
#   'BTC weight': 0.1523764455114043},
#  {'Returns': 71.54410648139053,
#   'Volatility': 0.2270853812015209,
#   'SHOP weight': 0.0003579604895459228,
#   'TSLA weight': 0.01352448693135083,
#   'GOLD weight': 0.2144181337485743,
#   'DAL weight': 0.1732159809992625,
#   'NFLX weight': 0.08602453891421875,
#   'AAPL weight': 0.22815778405046547,
#   'PFE weight': 0.08149705130036974,
#   'BTC weight': 0.2028040635662123},
#  {'Returns': 63.29635478118866,
#   'Volatility': 0.2885270895214556,
#   'SHOP weight': 0.09045941336893197,
#   'TSLA weight': 0.2689703640737908,
#   'GOLD weight': 0.11362799415592593,
#   'DAL weight': 0.06106473079388343,
#   'NFLX weight': 0.1706115322341292,
#   'AAPL weight': 0.11413341414087265,
#   'PFE weight': 0.05806162555439864,
#   'BTC weight': 0.12307092567806731},
#  {'Returns': 20.169431773834916,
#   'Volatility': 0.21324803435804648,
#   'SHOP weight': 0.060892461843703956,
#   'TSLA weight': 0.06819403901355843,
#   'GOLD weight': 0.44307860985647923,
#   'DAL weight': 0.05807634883825533,
#   'NFLX weight': 0.1295798308166643,
#   'AAPL weight': 0.07326200836591368,
#   'PFE weight': 0.1086368182642566,
#   'BTC weight': 0.058279883001168466},
#  {'Returns': 51.128666368381296,
#   'Volatility': 0.2603340491689446,
#   'SHOP weight': 0.10956499776878809,
#   'TSLA weight': 0.1713262462375458,
#   'GOLD weight': 0.17705248461561365,
#   'DAL weight': 0.04176505371474113,
#   'NFLX weight': 0.1753700312286936,
#   'AAPL weight': 0.18291069461379952,
#   'PFE weight': 0.03576792856839992,
#   'BTC weight': 0.10624256325241839},
#  {'Returns': 87.69200164345972,
#   'Volatility': 0.29883017833742426,
#   'SHOP weight': 0.1368826204800455,
#   'TSLA weight': 0.2361310513911379,
#   'GOLD weight': 0.08628476546884525,
#   'DAL weight': 0.0431242612389541,
#   'NFLX weight': 0.19040786956709493,
#   'AAPL weight': 0.031211471627828162,
#   'PFE weight': 0.07386726144795973,
#   'BTC weight': 0.20209069877813438},
#  {'Returns': 74.05703762518681,
#   'Volatility': 0.2328331012873285,
#   'SHOP weight': 0.14789077627029965,
#   'TSLA weight': 0.0011448992961338284,
#   'GOLD weight': 0.2396134577864356,
#   'DAL weight': 0.13318118279748678,
#   'NFLX weight': 0.11612375896315072,
#   'AAPL weight': 0.07717873197702059,
#   'PFE weight': 0.07833638733039704,
#   'BTC weight': 0.20653080557907577},
#  {'Returns': 90.48034674421012,
#   'Volatility': 0.29510636330416234,
#   'SHOP weight': 0.2625926480752279,
#   'TSLA weight': 0.19380815493250436,
#   'GOLD weight': 0.015915309635429975,
#   'DAL weight': 0.12468518075199314,
#   'NFLX weight': 0.09464681195499164,
#   'AAPL weight': 0.026443814612491928,
#   'PFE weight': 0.09591937244844445,
#   'BTC weight': 0.18598870758891647},
#  {'Returns': 94.8015518835987,
#   'Volatility': 0.26079579221161264,
#   'SHOP weight': 0.09626750980647057,
#   'TSLA weight': 0.09834759214569384,
#   'GOLD weight': 0.09279759939371628,
#   'DAL weight': 0.057983741812495875,
#   'NFLX weight': 0.24788779971816705,
#   'AAPL weight': 0.0031786009327719614,
#   'PFE weight': 0.1555263428628673,
#   'BTC weight': 0.24801081332781713},
#  {'Returns': 28.725650208441127,
#   'Volatility': 0.21661138613824746,
#   'SHOP weight': 0.15672404881202895,
#   'TSLA weight': 0.09527652154626227,
#   'GOLD weight': 0.1739537481059162,
#   'DAL weight': 0.06163903660776331,
#   'NFLX weight': 0.24455821531847613,
#   'AAPL weight': 0.0304269134705265,
#   'PFE weight': 0.20765847045869132,
#   'BTC weight': 0.029763045680335293},
#  {'Returns': 28.72733390406674,
#   'Volatility': 0.22186228869765845,
#   'SHOP weight': 0.11536823791018101,
#   'TSLA weight': 0.07426763854838482,
#   'GOLD weight': 0.08915731054924142,
#   'DAL weight': 0.08676703065877854,
#   'NFLX weight': 0.17211158899363366,
#   'AAPL weight': 0.2908168613220319,
#   'PFE weight': 0.1503283490570275,
#   'BTC weight': 0.021182982960721217},
#  {'Returns': 63.92700971924941,
#   'Volatility': 0.24683799550708957,
#   'SHOP weight': 0.025705846775042274,
#   'TSLA weight': 0.11308058944027898,
#   'GOLD weight': 0.1736044087023199,
#   'DAL weight': 0.0601817528461839,
#   'NFLX weight': 0.22348712791398295,
#   'AAPL weight': 0.2111022515578991,
#   'PFE weight': 0.026032579740208003,
#   'BTC weight': 0.16680544302408484},
#  {'Returns': 32.84826270942758,
#   'Volatility': 0.25112365265832437,
#   'SHOP weight': 0.02246370773662821,
#   'TSLA weight': 0.16521145944348606,
#   'GOLD weight': 0.12284841214642414,
#   'DAL weight': 0.027751463923997074,
#   'NFLX weight': 0.3258530438902544,
#   'AAPL weight': 0.192497353644955,
#   'PFE weight': 0.09506701904407042,
#   'BTC weight': 0.0483075401701847},
#  {'Returns': 39.032200061223584,
#   'Volatility': 0.2530862521913912,
#   'SHOP weight': 0.10128376721611923,
#   'TSLA weight': 0.19933924447146947,
#   'GOLD weight': 0.1181416968845936,
#   'DAL weight': 0.08257538566749865,
#   'NFLX weight': 0.11205468172633021,
#   'AAPL weight': 0.22513070979906571,
#   'PFE weight': 0.11749145547254691,
#   'BTC weight': 0.04398305876237623},
#  {'Returns': 61.12328922639587,
#   'Volatility': 0.22584085467028214,
#   'SHOP weight': 0.11648682969958914,
#   'TSLA weight': 0.11848838854820463,
#   'GOLD weight': 0.16433684446884217,
#   'DAL weight': 0.12381691184655569,
#   'NFLX weight': 0.09355754429317241,
#   'AAPL weight': 0.13068692228495588,
#   'PFE weight': 0.11858118039784207,
#   'BTC weight': 0.1340453784608379},
#  {'Returns': 52.4862642216676,
#   'Volatility': 0.22365302998642939,
#   'SHOP weight': 0.12148023516347432,
#   'TSLA weight': 0.1796161855403895,
#   'GOLD weight': 0.061888978626098344,
#   'DAL weight': 0.19338571206877367,
#   'NFLX weight': 0.10641751974433435,
#   'AAPL weight': 0.028404008803586824,
#   'PFE weight': 0.23787522846680453,
#   'BTC weight': 0.07093213158653847},
#  {'Returns': 78.192615434067,
#   'Volatility': 0.251249526464689,
#   'SHOP weight': 0.1604510678261203,
#   'TSLA weight': 0.08604690281784108,
#   'GOLD weight': 0.20739144306593185,
#   'DAL weight': 0.028073874399772783,
#   'NFLX weight': 0.17476580938031247,
#   'AAPL weight': 0.018539716025380536,
#   'PFE weight': 0.11839125447846957,
#   'BTC weight': 0.20633993200617134},
#  {'Returns': 24.125579554799323,
#   'Volatility': 0.21004853863239198,
#   'SHOP weight': 0.04034030099736316,
#   'TSLA weight': 0.1089147613195356,
#   'GOLD weight': 0.14375726561696847,
#   'DAL weight': 0.03231899767726042,
#   'NFLX weight': 0.181926608255083,
#   'AAPL weight': 0.22943787745961153,
#   'PFE weight': 0.24926795661741472,
#   'BTC weight': 0.014036232056763088},
#  {'Returns': 63.064050328275414,
#   'Volatility': 0.26824090158143205,
#   'SHOP weight': 0.13434492111859575,
#   'TSLA weight': 0.2109943782669827,
#   'GOLD weight': 0.05899626162782649,
#   'DAL weight': 0.16027759739589684,
#   'NFLX weight': 0.016433459327032746,
#   'AAPL weight': 0.23404600315117477,
#   'PFE weight': 0.0789895711574157,
#   'BTC weight': 0.10591780795507498},
#  {'Returns': 46.53791404214645,
#   'Volatility': 0.2167218226783004,
#   'SHOP weight': 0.17083363478610086,
#   'TSLA weight': 0.09950865435874175,
#   'GOLD weight': 0.21194544940153165,
#   'DAL weight': 0.11244877094107703,
#   'NFLX weight': 0.044469731722864586,
#   'AAPL weight': 0.12197228589033249,
#   'PFE weight': 0.15208344909155982,
#   'BTC weight': 0.08673802380779179},
#  {'Returns': 54.56086704375993,
#   'Volatility': 0.30080089975761676,
#   'SHOP weight': 0.23010790478279347,
#   'TSLA weight': 0.22881635712776785,
#   'GOLD weight': 0.03389482480019841,
#   'DAL weight': 0.12519185949840408,
#   'NFLX weight': 0.17808257736650385,
#   'AAPL weight': 0.11806095944766712,
#   'PFE weight': 0.012418472476931616,
#   'BTC weight': 0.07342704449973358},
#  {'Returns': 82.63634793222765,
#   'Volatility': 0.24177507490800965,
#   'SHOP weight': 0.04521236658614504,
#   'TSLA weight': 0.17443993223352458,
#   'GOLD weight': 0.02700452282124632,
#   'DAL weight': 0.20586514405663828,
#   'NFLX weight': 0.13211631452261846,
#   'AAPL weight': 0.014123240216864072,
#   'PFE weight': 0.22493037326141158,
#   'BTC weight': 0.17630810630155166},
#  {'Returns': 75.69121916034037,
#   'Volatility': 0.23111396516803054,
#   'SHOP weight': 0.17998099949814894,
#   'TSLA weight': 0.004009577348493426,
#   'GOLD weight': 0.16343380688884318,
#   'DAL weight': 0.09739851319933998,
#   'NFLX weight': 0.17913367854991705,
#   'AAPL weight': 0.05258648763329676,
#   'PFE weight': 0.12584930946376907,
#   'BTC weight': 0.1976076274181917},
#  {'Returns': 57.746903836223964,
#   'Volatility': 0.2374472833306134,
#   'SHOP weight': 0.1146879865260298,
#   'TSLA weight': 0.13761462500363483,
#   'GOLD weight': 0.13523140826544935,
#   'DAL weight': 0.0703014647853588,
#   'NFLX weight': 0.12586285438331246,
# ...
#   'PFE weight': 0.1608490079527167,
#   'BTC weight': 0.20370896833682406},
#  {'Returns': 87.09907254825764,
#   'Volatility': 0.263092201971806,
#   'SHOP weight': 0.027599336782519832,
#   'TSLA weight': 0.164683820113843,
#   'GOLD weight': 0.07295891375546219,
#   'DAL weight': 0.14101085662172874,
#   'NFLX weight': 0.16480821145206448,
#   'AAPL weight': 0.126427674680855,
#   'PFE weight': 0.08995308263293024,
#   'BTC weight': 0.2125581039605964},
#  {'Returns': 34.27347751806593,
#   'Volatility': 0.22486362593955678,
#   'SHOP weight': 0.0964607739583773,
#   'TSLA weight': 0.16957069105495215,
#   'GOLD weight': 0.22729742026406805,
#   'DAL weight': 0.08730996758120939,
#   'NFLX weight': 0.13934855973121227,
#   'AAPL weight': 0.0662707582343356,
#   'PFE weight': 0.16442093534639862,
#   'BTC weight': 0.049320893829446696},
#  {'Returns': 90.0187568318403,
#   'Volatility': 0.29345707508996777,
#   'SHOP weight': 0.05195909927894429,
#   'TSLA weight': 0.24406929856052492,
#   'GOLD weight': 0.22986603078834147,
#   'DAL weight': 0.1238896817284001,
#   'NFLX weight': 0.005086518770490605,
#   'AAPL weight': 0.032375523414808975,
#   'PFE weight': 0.083600141075364,
#   'BTC weight': 0.22915370638312563},
#  {'Returns': 55.099093389947186,
#   'Volatility': 0.32645669095866525,
#   'SHOP weight': 0.2958311640893823,
#   'TSLA weight': 0.27618736324019244,
#   'GOLD weight': 0.16778109629728902,
#   'DAL weight': 0.04682921282972288,
#   'NFLX weight': 0.10938284287685578,
#   'AAPL weight': 0.0021091028168878216,
#   'PFE weight': 0.017586854735066867,
#   'BTC weight': 0.08429236311460296},
#  {'Returns': 59.80762651400431,
#   'Volatility': 0.2690411745100991,
#   'SHOP weight': 0.18350561617512928,
#   'TSLA weight': 0.1950822717539871,
#   'GOLD weight': 0.027115887575029734,
#   'DAL weight': 0.16714439375957937,
#   'NFLX weight': 0.16449535414187538,
#   'AAPL weight': 0.10742857654278327,
#   'PFE weight': 0.060674655681870034,
#   'BTC weight': 0.0945532443697459},
#  {'Returns': 37.36179949315293,
#   'Volatility': 0.22165465813606286,
#   'SHOP weight': 0.09672817614825414,
#   'TSLA weight': 0.12305989529259713,
#   'GOLD weight': 0.2245316142476517,
#   'DAL weight': 0.18826312566342987,
#   'NFLX weight': 0.11699820528968188,
#   'AAPL weight': 0.1286759521996112,
#   'PFE weight': 0.0548242987377839,
#   'BTC weight': 0.06691873242099035},
#  {'Returns': 60.55224557605998,
#   'Volatility': 0.21952094060056765,
#   'SHOP weight': 0.13225363840766904,
#   'TSLA weight': 0.01889461137704048,
#   'GOLD weight': 0.12427714348356757,
#   'DAL weight': 0.08014020413082198,
#   'NFLX weight': 0.19540366703291936,
#   'AAPL weight': 0.1970153592705809,
#   'PFE weight': 0.1076508525846397,
#   'BTC weight': 0.14436452371276098},
#  {'Returns': 35.81472835966005,
#   'Volatility': 0.23843906558352845,
#   'SHOP weight': 0.26300970932855267,
#   'TSLA weight': 0.08655616846579389,
#   'GOLD weight': 0.029583914822900143,
#   'DAL weight': 0.07248917381572362,
#   'NFLX weight': 0.17391931363413513,
#   'AAPL weight': 0.10785423393210766,
#   'PFE weight': 0.25117484798203804,
#   'BTC weight': 0.015412638018748924},
#  {'Returns': 79.72834633422319,
#   'Volatility': 0.2814076201319825,
#   'SHOP weight': 0.18767362178111166,
#   'TSLA weight': 0.19336300713111668,
#   'GOLD weight': 0.14673036982578938,
#   'DAL weight': 0.07262375538827545,
#   'NFLX weight': 0.11151471761803032,
#   'AAPL weight': 0.043155741738614056,
#   'PFE weight': 0.06238246184943921,
#   'BTC weight': 0.18255632466762314},
#  {'Returns': 58.608996380199855,
#   'Volatility': 0.24099512905958229,
#   'SHOP weight': 0.26492534978996596,
#   'TSLA weight': 0.061392710919705114,
#   'GOLD weight': 0.046825866027745015,
#   'DAL weight': 0.2967890479613696,
#   'NFLX weight': 0.1610255401375099,
#   'AAPL weight': 0.011637251228684966,
#   'PFE weight': 0.05688002692633978,
#   'BTC weight': 0.10052420700867966},
#  {'Returns': 30.733848022699924,
#   'Volatility': 0.2883464005733175,
#   'SHOP weight': 0.1746476485570626,
#   'TSLA weight': 0.24996386097184578,
#   'GOLD weight': 0.13677525228770998,
#   'DAL weight': 0.088692747032082,
#   'NFLX weight': 0.08368211392075026,
#   'AAPL weight': 0.1807706428253047,
#   'PFE weight': 0.07979378996011102,
#   'BTC weight': 0.005673944445133601},
#  {'Returns': 62.513774144919346,
#   'Volatility': 0.28971560480128483,
#   'SHOP weight': 0.0414553583185166,
#   'TSLA weight': 0.28472353628156777,
#   'GOLD weight': 0.039647587863487384,
#   'DAL weight': 0.14053809554164637,
#   'NFLX weight': 0.07330131009043853,
#   'AAPL weight': 0.24460896576054247,
#   'PFE weight': 0.07310279297924954,
#   'BTC weight': 0.10262235316455133},
#  {'Returns': 116.3237655171018,
#   'Volatility': 0.3177597668055514,
#   'SHOP weight': 0.04164109135006342,
#   'TSLA weight': 0.24093865811410978,
#   'GOLD weight': 0.02959659376493188,
#   'DAL weight': 0.20210091948691705,
#   'NFLX weight': 0.03277404964534732,
#   'AAPL weight': 0.023530795593696436,
#   'PFE weight': 0.1478894295157052,
#   'BTC weight': 0.2815284625292289},
#  {'Returns': 30.78888447757324,
#   'Volatility': 0.2541560739365216,
#   'SHOP weight': 0.3137030601385874,
#   'TSLA weight': 0.07076214181407933,
#   'GOLD weight': 0.05963730319543435,
#   'DAL weight': 0.0568646786829969,
#   'NFLX weight': 0.22534213726812735,
#   'AAPL weight': 0.03889180886654669,
#   'PFE weight': 0.2299629458644644,
#   'BTC weight': 0.004835924169763593},
#  {'Returns': 18.257459211346777,
#   'Volatility': 0.2172030671570437,
#   'SHOP weight': 0.1912283206509519,
#   'TSLA weight': 0.007042201072797443,
#   'GOLD weight': 0.18596964073999064,
#   'DAL weight': 0.03766426456685091,
#   'NFLX weight': 0.16815869846424447,
#   'AAPL weight': 0.20602346227934845,
#   'PFE weight': 0.20075499164152238,
#   'BTC weight': 0.0031584205842938654},
#  {'Returns': 83.67464404752451,
#   'Volatility': 0.25598203937305525,
#   'SHOP weight': 0.06871287179272081,
#   'TSLA weight': 0.1862639860879411,
#   'GOLD weight': 0.04548092708671587,
#   'DAL weight': 0.1513042914831463,
#   'NFLX weight': 0.032275652095320566,
#   'AAPL weight': 0.16007130012547852,
#   'PFE weight': 0.17694875757278414,
#   'BTC weight': 0.1789422137558927},
#  {'Returns': 61.09780992435667,
#   'Volatility': 0.2529833496697328,
#   'SHOP weight': 0.1691148957349841,
#   'TSLA weight': 0.17712110079355226,
#   'GOLD weight': 0.1609072937771556,
#   'DAL weight': 0.07129225977400099,
#   'NFLX weight': 0.13357096381292252,
#   'AAPL weight': 0.05099010638614375,
#   'PFE weight': 0.112740205489868,
#   'BTC weight': 0.12426317423137288},
#  {'Returns': 69.1607727356814,
#   'Volatility': 0.26773578413545385,
#   'SHOP weight': 0.15950821274024807,
#   'TSLA weight': 0.22827898919876285,
#   'GOLD weight': 0.06332128379696653,
#   'DAL weight': 0.21297688514940671,
#   'NFLX weight': 0.10665152616006535,
#   'AAPL weight': 0.006689616391137456,
#   'PFE weight': 0.09876965936250663,
#   'BTC weight': 0.12380382720090644},
#  {'Returns': 70.71337188635086,
#   'Volatility': 0.24701592911761527,
#   'SHOP weight': 0.06291575885946712,
#   'TSLA weight': 0.16570708151406197,
#   'GOLD weight': 0.12585229533883008,
#   'DAL weight': 0.029231389822746093,
#   'NFLX weight': 0.11125498947280495,
#   'AAPL weight': 0.18780995930523353,
#   'PFE weight': 0.15672351750299052,
#   'BTC weight': 0.16050500818386584},
#  {'Returns': 30.44308168210275,
#   'Volatility': 0.2375580541256683,
#   'SHOP weight': 0.12575891410430198,
#   'TSLA weight': 0.15878880159856182,
#   'GOLD weight': 0.07547236981191996,
#   'DAL weight': 0.17494490541126642,
#   'NFLX weight': 0.1890093266606301,
#   'AAPL weight': 0.13665328284646636,
#   'PFE weight': 0.128458408846287,
#   'BTC weight': 0.010913990720566353},
#  {'Returns': 62.55386346036937,
#   'Volatility': 0.27194119982509707,
#   'SHOP weight': 0.21093004864867762,
#   'TSLA weight': 0.18137525381178163,
#   'GOLD weight': 0.08352380902094221,
#   'DAL weight': 0.19934450930105801,
#   'NFLX weight': 0.17016980757987085,
#   'AAPL weight': 0.03293857456925166,
#   'PFE weight': 0.007189189840530405,
#   'BTC weight': 0.11452880722788755},
#  {'Returns': 34.219934950852625,
#   'Volatility': 0.2672840391770672,
#   'SHOP weight': 0.21277493176495227,
#   'TSLA weight': 0.2157766498384678,
#   'GOLD weight': 0.1255895742404888,
#   'DAL weight': 0.16875088066138785,
#   'NFLX weight': 0.10632537224266891,
#   'AAPL weight': 0.05435714746396299,
#   'PFE weight': 0.10241281782167795,
#   'BTC weight': 0.01401262596639356},
#  {'Returns': 31.084358450838664,
#   'Volatility': 0.22724951368671523,
#   'SHOP weight': 0.002072660879237066,
#   'TSLA weight': 0.2223800822182709,
#   'GOLD weight': 0.0812466944245186,
#   'DAL weight': 0.18930369200117086,
#   'NFLX weight': 0.1740513748013404,
#   'AAPL weight': 0.03205431147799447,
#   'PFE weight': 0.29175579116035383,
#   'BTC weight': 0.007135393037113939},
#  {'Returns': 27.80376868726221,
#   'Volatility': 0.23902563432344232,
#   'SHOP weight': 0.0899819701120759,
#   'TSLA weight': 0.1814944788081879,
#   'GOLD weight': 0.1300218259101172,
#   'DAL weight': 0.1259889723943599,
#   'NFLX weight': 0.1811397412750294,
#   'AAPL weight': 0.14324491712306714,
#   'PFE weight': 0.1359994641159924,
#   'BTC weight': 0.012128630261170082},
#  {'Returns': 41.567747290531784,
#   'Volatility': 0.25073386552774124,
#   'SHOP weight': 0.2929443388203398,
#   'TSLA weight': 0.14709518498843496,
#   'GOLD weight': 0.038058505534750764,
#   'DAL weight': 0.20183118022333094,
#   'NFLX weight': 0.09041432850558122,
#   'AAPL weight': 0.01580277219100297,
#   'PFE weight': 0.19386453603045553,
#   'BTC weight': 0.019989153706103876},
#  {'Returns': 88.42298789265526,
#   'Volatility': 0.2547865065944872,
#   'SHOP weight': 0.07135082412047722,
#   'TSLA weight': 0.12762695634203727,
#   'GOLD weight': 0.05347179941651958,
#   'DAL weight': 0.2583536964665079,
#   'NFLX weight': 0.05947351731899466,
#   'AAPL weight': 0.10702018578083057,
#   'PFE weight': 0.11785021377914588,
#   'BTC weight': 0.20485280677548687},
#  {'Returns': 107.50518729648297,
#   'Volatility': 0.2747457908901721,
#   'SHOP weight': 0.1806069723234119,
#   'TSLA weight': 0.018867095797154086,
#   'GOLD weight': 0.16715770645796993,
#   'DAL weight': 0.03721914328200837,
#   'NFLX weight': 0.0003735791373486249,
#   'AAPL weight': 0.06895827533978144,
#   'PFE weight': 0.23442700906819222,
#   'BTC weight': 0.2923902185941335},
#  {'Returns': 30.177869204602825,
#   'Volatility': 0.2363933641183076,
#   'SHOP weight': 0.13709534217450625,
#   'TSLA weight': 0.1676687716023639,
#   'GOLD weight': 0.20719762093410693,
#   'DAL weight': 0.18814977821193812,
#   'NFLX weight': 0.004513688138434899,
#   'AAPL weight': 0.16320912809570123,
#   'PFE weight': 0.11017717276062437,
#   'BTC weight': 0.021988498082324306},
#  {'Returns': 74.46656782467551,
#   'Volatility': 0.27637102147097836,
#   'SHOP weight': 0.1433032533421962,
#   'TSLA weight': 0.17941148869551476,
#   'GOLD weight': 0.018020214561422932,
#   'DAL weight': 0.008048735069724429,
#   'NFLX weight': 0.16304656782600657,
#   'AAPL weight': 0.21110266843521824,
#   'PFE weight': 0.12657535133169587,
#   'BTC weight': 0.15049172073822092},
#  {'Returns': 61.21885278310701,
#   'Volatility': 0.2250728168041354,
#   'SHOP weight': 0.11214736946781231,
#   'TSLA weight': 0.096741878553466,
#   'GOLD weight': 0.1916747432296449,
#   'DAL weight': 0.11324484010265982,
#   'NFLX weight': 0.22425367192197107,
#   'AAPL weight': 0.010192141705350826,
#   'PFE weight': 0.1024059580376931,
#   'BTC weight': 0.14933939698140192},
#  {'Returns': 48.8967514416543,
#   'Volatility': 0.3032620607050045,
#   'SHOP weight': 0.2712330636141019,
#   'TSLA weight': 0.26880010722685277,
#   'GOLD weight': 0.04258251169043476,
#   'DAL weight': 0.1796776111585615,
#   'NFLX weight': 0.08045540381454885,
#   'AAPL weight': 0.03636315450402939,
#   'PFE weight': 0.08435575481910441,
#   'BTC weight': 0.03653239317236645},
#  {'Returns': 61.332577664851854,
#   'Volatility': 0.24869123737008475,
#   'SHOP weight': 0.17141031785724992,
#   'TSLA weight': 0.14942380632055197,
#   'GOLD weight': 0.15228881388414706,
#   'DAL weight': 0.1602877380310547,
#   'NFLX weight': 0.02786928378361432,
#   'AAPL weight': 0.15685571911005464,
#   'PFE weight': 0.05961462797695584,
#   'BTC weight': 0.12224969303637151},
#  {'Returns': 75.03281845894766,
#   'Volatility': 0.2447611689659117,
#   'SHOP weight': 0.2029717966606252,
#   'TSLA weight': 0.041654749924053956,
#   'GOLD weight': 0.19222963077965202,
#   'DAL weight': 0.21920281668648062,
#   'NFLX weight': 0.02027787715946318,
#   'AAPL weight': 0.1052704556164846,
#   'PFE weight': 0.031951769007603915,
#   'BTC weight': 0.18644090416563655},
#  {'Returns': 38.0597198107249,
#   'Volatility': 0.2451169771607523,
#   'SHOP weight': 0.13692978760659935,
#   'TSLA weight': 0.19708170310453038,
#   'GOLD weight': 0.06764977435548167,
#   'DAL weight': 0.1768393641958677,
#   'NFLX weight': 0.04646739490159045,
#   'AAPL weight': 0.17936122889954806,
#   'PFE weight': 0.1754042403098301,
#   'BTC weight': 0.020266506626552286},
#  {'Returns': 30.43492376259933,
#   'Volatility': 0.23640239013063982,
#   'SHOP weight': 0.18623531773015312,
#   'TSLA weight': 0.17259375576005825,
#   'GOLD weight': 0.2501797978799089,
#   'DAL weight': 0.04080098385651316,
#   'NFLX weight': 0.06436046443958465,
#   'AAPL weight': 0.02668513343695497,
#   'PFE weight': 0.23292038364717063,
#   'BTC weight': 0.02622416324965644},
#  {'Returns': 71.10136665850807,
#   'Volatility': 0.24274398487456844,
#   'SHOP weight': 0.14661267847518442,
#   'TSLA weight': 0.12205842935441513,
#   'GOLD weight': 0.16058752709112367,
#   'DAL weight': 0.09079457315396348,
#   'NFLX weight': 0.1421954044096478,
#   'AAPL weight': 0.06775067177853761,
#   'PFE weight': 0.10193367029312607,
#   'BTC weight': 0.16806704544400183},
#  {'Returns': 64.84641060472266,
#   'Volatility': 0.2590406765069974,
#   'SHOP weight': 0.05072638755790141,
#   'TSLA weight': 0.2758095737935514,
#   'GOLD weight': 0.12395306218465472,
#   'DAL weight': 0.09223794232815792,
#   'NFLX weight': 0.04542325971248151,
#   'AAPL weight': 0.05063001956035647,
#   'PFE weight': 0.24457820117341067,
#   'BTC weight': 0.1166415536894859},
#  {'Returns': 60.83695865498612,
#   'Volatility': 0.22225844209403012,
#   'SHOP weight': 0.13235935970025314,
#   'TSLA weight': 0.12389405860374475,
#   'GOLD weight': 0.10911990514471265,
#   'DAL weight': 0.15432191375591595,
#   'NFLX weight': 0.10145141814771644,
#   'AAPL weight': 0.10754819103235697,
#   'PFE weight': 0.1520249976889811,
#   'BTC weight': 0.11928015592631891},
#  {'Returns': 72.2288518559891,
#   'Volatility': 0.28406995103164395,
#   'SHOP weight': 0.22551275513149707,
#   'TSLA weight': 0.20566993691808585,
#   'GOLD weight': 0.16609771267182985,
#   'DAL weight': 0.13472851032386243,
#   'NFLX weight': 0.03324623771001725,
#   'AAPL weight': 0.05503909015672424,
#   'PFE weight': 0.028343636625629907,
#   'BTC weight': 0.15136212046235345},
#  {'Returns': 84.21595462375802,
#   'Volatility': 0.23689795545617257,
#   'SHOP weight': 0.15142898830367738,
#   'TSLA weight': 0.07081828766531156,
#   'GOLD weight': 0.0782462838788191,
#   'DAL weight': 0.060870495894026544,
#   'NFLX weight': 0.040351876004501505,
#   'AAPL weight': 0.18504269876326684,
#   'PFE weight': 0.2172137686802782,
#   'BTC weight': 0.19602760081011897},
#  {'Returns': 32.69160555808948,
#   'Volatility': 0.18390883083624326,
#   'SHOP weight': 0.06808289810826777,
#   'TSLA weight': 0.005699958449173822,
#   'GOLD weight': 0.022449254800608737,
#   'DAL weight': 0.17040780171110012,
#   'NFLX weight': 0.14648020144155224,
#   'AAPL weight': 0.2834160190468775,
#   'PFE weight': 0.2764974672070558,
#   'BTC weight': 0.026966399235364008},
#  {'Returns': 21.02621294739418,
#   'Volatility': 0.28824507911484815,
#   'SHOP weight': 0.061882926458141335,
#   'TSLA weight': 0.24373828490225555,
#   'GOLD weight': 0.22869543827111152,
#   'DAL weight': 0.001178019235797024,
#   'NFLX weight': 0.2739318481419348,
#   'AAPL weight': 0.13733980659180312,
#   'PFE weight': 0.04045996038181758,
#   'BTC weight': 0.012773716017139145},
#  {'Returns': 69.2662664908981,
#   'Volatility': 0.22719845635068966,
#   'SHOP weight': 0.05029217162380316,
#   'TSLA weight': 0.12105719100929609,
#   'GOLD weight': 0.049427908184152505,
#   'DAL weight': 0.1725080051762192,
#   'NFLX weight': 0.16489211237614457,
#   'AAPL weight': 0.15742847814598604,
#   'PFE weight': 0.13554898845767482,
#   'BTC weight': 0.14884514502672375}]

# %% [markdown]
# for index, row in portfolios.iterrows():
#     portf_dict = [row]
#     print(portf_dict)

# %%
# convert into JSON and save it as a separate file:
#portf = portfolios.to_json()
#port = json.dumps(port)
with open('../Data/portfolio_data.json', 'w') as outfile:
    json.dump(portf, outfile)

portf
# Out:
# [{'Returns': 38.039437848386314,
#   'Volatility': 0.19748879918745926,
#   'SHOP weight': 0.04850713798070183,
#   'TSLA weight': 0.07427317879331047,
#   'GOLD weight': 0.15245738866048664,
#   'DAL weight': 0.22221938923752402,
#   'NFLX weight': 0.11090663702023217,
#   'AAPL weight': 0.19148806693697387,
#   'PFE weight': 0.13736703644243006,
#   'BTC weight': 0.06278116492834078},
#  {'Returns': 77.01430895549245,
#   'Volatility': 0.27203888453131636,
#   'SHOP weight': 0.07651843892670136,
#   'TSLA weight': 0.1984699137641,
#   'GOLD weight': 0.02654206680710156,
#   'DAL weight': 0.10678337672632844,
#   'NFLX weight': 0.18939225528316472,
#   'AAPL weight': 0.16795711880777753,
#   'PFE weight': 0.06956728009223327,
#   'BTC weight': 0.16476954959259316},
#  {'Returns': 82.92573494531261,
#   'Volatility': 0.24943489886011508,
#   'SHOP weight': 0.22853031198194276,
#   'TSLA weight': 0.051660789874116236,
#   'GOLD weight': 0.053751616797324195,
#   'DAL weight': 0.18145691120867355,
#   'NFLX weight': 0.19383142723184796,
#   'AAPL weight': 0.005889116642982426,
#   'PFE weight': 0.09263694536372113,
#   'BTC weight': 0.19224288089939154},
#  {'Returns': 74.23507900533009,
#   'Volatility': 0.26351183116472227,
#   'SHOP weight': 0.2458147283055665,
#   'TSLA weight': 0.14823905957307776,
#   'GOLD weight': 0.04919947323668005,
#   'DAL weight': 0.1060155245808855,
#   'NFLX weight': 0.09258691653521021,
#   'AAPL weight': 0.08823262741197922,
#   'PFE weight': 0.1265302644186265,
#   'BTC weight': 0.14338140593797424},
#  {'Returns': 98.53945079125737,
#   'Volatility': 0.25418913268856086,
#   'SHOP weight': 0.09337008110546678,
#   'TSLA weight': 0.012146968889880082,
#   'GOLD weight': 0.11323682405515889,
#   'DAL weight': 0.027567620205801998,
#   'NFLX weight': 0.08697096919642702,
#   'AAPL weight': 0.18262872347740924,
#   'PFE weight': 0.21703163754602706,
#   'BTC weight': 0.2670471755238289},
#  {'Returns': 63.038403291878765,
#   'Volatility': 0.22945615258626412,
#   'SHOP weight': 0.1498584555380788,
#   'TSLA weight': 0.05976537581447022,
#   'GOLD weight': 0.18545527430713066,
#   'DAL weight': 0.11149658186905893,
#   'NFLX weight': 0.0854233535770685,
#   'AAPL weight': 0.1876371283391892,
#   'PFE weight': 0.06863443820047645,
#   'BTC weight': 0.15172939235452718},
#  {'Returns': 28.470747229436164,
#   'Volatility': 0.22736092217736353,
#   'SHOP weight': 0.012132991516989123,
#   'TSLA weight': 0.10869442157309606,
#   'GOLD weight': 0.25849831773545645,
#   'DAL weight': 0.06690378411493059,
#   'NFLX weight': 0.2265814858408419,
#   'AAPL weight': 0.22346828518464482,
#   'PFE weight': 0.041848949345611286,
#   'BTC weight': 0.06187176468842974},
#  {'Returns': 54.699067142891096,
#   'Volatility': 0.1944221885083727,
#   'SHOP weight': 0.020923176547741895,
#   'TSLA weight': 0.08406983622874821,
#   'GOLD weight': 0.10318032730108859,
#   'DAL weight': 0.09203412239956472,
#   'NFLX weight': 0.038084278948723745,
#   'AAPL weight': 0.24792651054017548,
#   'PFE weight': 0.30921922938640123,
#   'BTC weight': 0.1045625186475562},
#  {'Returns': 75.84967549145433,
#   'Volatility': 0.24031317785291328,
#   'SHOP weight': 0.1897520041763941,
#   'TSLA weight': 0.0443285834894339,
#   'GOLD weight': 0.07719660091928694,
#   'DAL weight': 0.035773630402438424,
#   'NFLX weight': 0.12896960843041907,
#   'AAPL weight': 0.19056111718373717,
#   'PFE weight': 0.15793642121364423,
#   'BTC weight': 0.17548203418464617},
#  {'Returns': 77.15605549700508,
#   'Volatility': 0.2338034029828557,
#   'SHOP weight': 0.15383201679552827,
#   'TSLA weight': 0.07858521132598287,
#   'GOLD weight': 0.17933084392141224,
#   'DAL weight': 0.1268771208642714,
#   'NFLX weight': 0.005253426417121531,
#   'AAPL weight': 0.11718455364012173,
#   'PFE weight': 0.15171110441081814,
#   'BTC weight': 0.18722572262474377},
#  {'Returns': 63.750053880133194,
#   'Volatility': 0.27105697467099393,
#   'SHOP weight': 0.22684471787543944,
#   'TSLA weight': 0.18948620541386027,
#   'GOLD weight': 0.21225427110135395,
#   'DAL weight': 0.0641517545874868,
#   'NFLX weight': 0.0710427721871857,
#   'AAPL weight': 0.01798768513853381,
#   'PFE weight': 0.08455236453596496,
#   'BTC weight': 0.13368022916017505},
#  {'Returns': 38.758749188081175,
#   'Volatility': 0.21251876367456146,
#   'SHOP weight': 0.04809270683494104,
#   'TSLA weight': 0.08967711566963722,
#   'GOLD weight': 0.249467155866005,
#   'DAL weight': 0.2636571565033484,
#   'NFLX weight': 0.00027836974801229906,
#   'AAPL weight': 0.18597626573833034,
#   'PFE weight': 0.08732997992107037,
#   'BTC weight': 0.0755212497186553},
#  {'Returns': 72.63680462202771,
#   'Volatility': 0.25613349559397236,
#   'SHOP weight': 0.2067922993971572,
#   'TSLA weight': 0.14732803784709947,
#   'GOLD weight': 0.16671475068974398,
#   'DAL weight': 0.2274631189264398,
#   'NFLX weight': 0.02734478420540112,
#   'AAPL weight': 0.003619432720395877,
#   'PFE weight': 0.06323747394496226,
#   'BTC weight': 0.15750010226880018},
#  {'Returns': 87.55895166766412,
#   'Volatility': 0.2648438038283611,
#   'SHOP weight': 0.26102518596707996,
#   'TSLA weight': 0.10161119677788998,
#   'GOLD weight': 0.022705590628133487,
#   'DAL weight': 0.27088084609578494,
#   'NFLX weight': 0.007391053078963164,
#   'AAPL weight': 0.05636792844508314,
#   'PFE weight': 0.09880799333483034,
#   'BTC weight': 0.18121020567223495},
#  {'Returns': 80.48234911539924,
#   'Volatility': 0.25097046955779695,
#   'SHOP weight': 0.20753483151625687,
#   'TSLA weight': 0.05744952383421323,
#   'GOLD weight': 0.21203307165337137,
#   'DAL weight': 0.17231756589752686,
#   'NFLX weight': 0.03302974075010928,
#   'AAPL weight': 0.04959016656498555,
#   'PFE weight': 0.06183008425339264,
#   'BTC weight': 0.2062150155301443},
#  {'Returns': 60.262274583238764,
#   'Volatility': 0.23162034776692533,
#   'SHOP weight': 0.18500499642222365,
#   'TSLA weight': 0.14679915562635962,
#   'GOLD weight': 0.19915014279260781,
#   'DAL weight': 0.1417128838921173,
#   'NFLX weight': 0.01507718389227183,
#   'AAPL weight': 0.02078450226734858,
#   'PFE weight': 0.17154533669823469,
#   'BTC weight': 0.11992579840883645},
#  {'Returns': 76.45294104142076,
#   'Volatility': 0.24089439376144817,
#   'SHOP weight': 0.0029270121524426073,
#   'TSLA weight': 0.09518103659502707,
#   'GOLD weight': 0.23377029220250006,
#   'DAL weight': 0.08565376018808513,
#   'NFLX weight': 0.12151564991336257,
#   'AAPL weight': 0.14253572677639587,
#   'PFE weight': 0.10394107519668122,
#   'BTC weight': 0.21447544697550552},
#  {'Returns': 65.51894901115827,
#   'Volatility': 0.24663145528959435,
#   'SHOP weight': 0.15475565203920305,
#   'TSLA weight': 0.07007770094614729,
#   'GOLD weight': 0.04604964889523364,
#   'DAL weight': 0.11527845494484923,
#   'NFLX weight': 0.20427225679638966,
#   'AAPL weight': 0.22863945708031022,
#   'PFE weight': 0.03927942187269502,
#   'BTC weight': 0.14164740742517193},
#  {'Returns': 69.24248109533889,
#   'Volatility': 0.23783676940321746,
#   'SHOP weight': 0.03228285837775809,
#   'TSLA weight': 0.17864042741959912,
#   'GOLD weight': 0.16416562679431185,
#   'DAL weight': 0.12054914420560925,
#   'NFLX weight': 0.0012085432504882966,
#   'AAPL weight': 0.1574039830867346,
#   'PFE weight': 0.19261554543862536,
#   'BTC weight': 0.1531338714268734},
#  {'Returns': 114.1442010514254,
#   'Volatility': 0.29747668537973376,
#   'SHOP weight': 0.09368998203720093,
#   'TSLA weight': 0.044189141892553935,
#   'GOLD weight': 0.12080044336473818,
#   'DAL weight': 0.0873246677353029,
#   'NFLX weight': 0.1015437291230997,
#   'AAPL weight': 0.1502067260808752,
#   'PFE weight': 0.07997598341359591,
#   'BTC weight': 0.3222693263526333},
#  {'Returns': 27.198796292979623,
#   'Volatility': 0.19446517219346218,
#   'SHOP weight': 0.012622176263667078,
#   'TSLA weight': 0.0510625201433829,
#   'GOLD weight': 0.16488496947800435,
#   'DAL weight': 0.19831778615565196,
#   'NFLX weight': 0.17546978625297577,
#   'AAPL weight': 0.23362904243732932,
#   'PFE weight': 0.12504354424836273,
#   'BTC weight': 0.03897017502062589},
#  {'Returns': 85.63261031858256,
#   'Volatility': 0.249886595919901,
#   'SHOP weight': 0.08089285246454281,
#   'TSLA weight': 0.08613433197168884,
#   'GOLD weight': 0.0023993543440104393,
#   'DAL weight': 0.2544287959126108,
#   'NFLX weight': 0.1352449350300149,
#   'AAPL weight': 0.17111877673113277,
#   'PFE weight': 0.07218845681024996,
#   'BTC weight': 0.19759249673574947},
#  {'Returns': 43.80094295102363,
#   'Volatility': 0.2262475393528922,
#   'SHOP weight': 0.15012959258232855,
#   'TSLA weight': 0.1043727028747507,
#   'GOLD weight': 0.13701904034375853,
#   'DAL weight': 0.11054799558551864,
#   'NFLX weight': 0.15191006443304592,
#   'AAPL weight': 0.16913887970385852,
#   'PFE weight': 0.10336112849006271,
#   'BTC weight': 0.07352059598667654},
#  {'Returns': 102.31287179369733,
#   'Volatility': 0.2671736515174968,
#   'SHOP weight': 0.1631775680464003,
#   'TSLA weight': 0.04418728077662477,
#   'GOLD weight': 0.05653583688679066,
#   'DAL weight': 0.19796295654595708,
#   'NFLX weight': 0.009933699817962697,
#   'AAPL weight': 0.15526447663193102,
#   'PFE weight': 0.11754934451568655,
#   'BTC weight': 0.2553888367786469},
#  {'Returns': 66.238413710348,
#   'Volatility': 0.2316156030327396,
#   'SHOP weight': 0.05135827874913023,
#   'TSLA weight': 0.18372151328004496,
#   'GOLD weight': 0.14765785022443698,
#   'DAL weight': 0.16950849796883313,
#   'NFLX weight': 0.07853350401584425,
#   'AAPL weight': 0.042527105176952774,
#   'PFE weight': 0.18686054370579003,
#   'BTC weight': 0.13983270687896768},
#  {'Returns': 91.85310961345323,
#   'Volatility': 0.2496769952852856,
#   'SHOP weight': 0.1533870808529376,
#   'TSLA weight': 0.008885236892379413,
#   'GOLD weight': 0.08349562878637126,
#   'DAL weight': 0.24976989654292686,
#   'NFLX weight': 0.11597590751832608,
#   'AAPL weight': 0.06478842903605128,
#   'PFE weight': 0.08900882959202118,
#   'BTC weight': 0.23468899077898642},
#  {'Returns': 25.106424609209025,
#   'Volatility': 0.22625357281208608,
#   'SHOP weight': 0.1100895949386496,
#   'TSLA weight': 0.13735965018569302,
#   'GOLD weight': 0.12774160155749578,
#   'DAL weight': 0.26279278330541445,
#   'NFLX weight': 0.17499691719756005,
#   'AAPL weight': 0.07664740714483025,
#   'PFE weight': 0.10688591519491425,
#   'BTC weight': 0.0034861304754427004},
#  {'Returns': 25.157624589654226,
#   'Volatility': 0.2704375558908104,
#   'SHOP weight': 0.1885175156195918,
#   'TSLA weight': 0.20427190296082565,
#   'GOLD weight': 0.22489106396841005,
#   'DAL weight': 0.11822519242590854,
#   'NFLX weight': 0.15388716360258478,
#   'AAPL weight': 0.057898796739494156,
#   'PFE weight': 0.041686294338951047,
#   'BTC weight': 0.010622070344233894},
#  {'Returns': 62.48509262145681,
#   'Volatility': 0.21780786487166331,
#   'SHOP weight': 0.042487052605335224,
#   'TSLA weight': 0.14105984743411173,
#   'GOLD weight': 0.2172807396602854,
#   'DAL weight': 0.1853497429931052,
#   'NFLX weight': 0.015763213905357103,
#   'AAPL weight': 0.03245669571203085,
#   'PFE weight': 0.22541658639376613,
#   'BTC weight': 0.14018612129600824},
#  {'Returns': 43.84386956355604,
#   'Volatility': 0.2177013337938676,
#   'SHOP weight': 0.022869901623547274,
#   'TSLA weight': 0.17111089053508868,
#   'GOLD weight': 0.11447633615790162,
#   'DAL weight': 0.1547585862310261,
#   'NFLX weight': 0.12629179468873156,
#   'AAPL weight': 0.15303971501549427,
#   'PFE weight': 0.19226873412441467,
#   'BTC weight': 0.06518404162379578},
#  {'Returns': 78.6588912323956,
#   'Volatility': 0.23839750989684386,
#   'SHOP weight': 0.14761013888964697,
#   'TSLA weight': 0.08547374617073737,
#   'GOLD weight': 0.05715394028295805,
#   'DAL weight': 0.1149401360654575,
#   'NFLX weight': 0.19248996626190043,
#   'AAPL weight': 0.0871067076649706,
#   'PFE weight': 0.13404298707807996,
#   'BTC weight': 0.18118237758624897},
#  {'Returns': 32.88875464182372,
#   'Volatility': 0.22077424478009,
#   'SHOP weight': 0.16378187131956187,
#   'TSLA weight': 0.05513741428214125,
#   'GOLD weight': 0.20628791531151053,
#   'DAL weight': 0.051960658103472494,
#   'NFLX weight': 0.1901552274883894,
#   'AAPL weight': 0.15491966595314027,
#   'PFE weight': 0.1212861151979317,
#   'BTC weight': 0.056471132343852454},
#  {'Returns': 35.12337457351656,
#   'Volatility': 0.22880990701962967,
#   'SHOP weight': 0.22762249731037673,
#   'TSLA weight': 0.12541350812936197,
#   'GOLD weight': 0.10636026541551313,
#   'DAL weight': 0.1263353785574675,
#   'NFLX weight': 0.05469012797296869,
#   'AAPL weight': 0.1139756674416313,
#   'PFE weight': 0.22779998398396026,
#   'BTC weight': 0.017802571188720584},
#  {'Returns': 31.85283140060016,
#   'Volatility': 0.22562916911910003,
#   'SHOP weight': 0.15209878817923891,
#   'TSLA weight': 0.12871112067022206,
#   'GOLD weight': 0.08921847876402293,
#   'DAL weight': 0.2375988926448762,
#   'NFLX weight': 0.03496551675657775,
#   'AAPL weight': 0.1882495824832389,
#   'PFE weight': 0.15999191437794033,
#   'BTC weight': 0.009165706123882972},
#  {'Returns': 56.61415995047104,
#   'Volatility': 0.2348593239004778,
#   'SHOP weight': 0.0700351516032284,
#   'TSLA weight': 0.18099341279613815,
#   'GOLD weight': 0.13187219726272675,
#   'DAL weight': 0.10979026433758003,
#   'NFLX weight': 0.02549650881414784,
#   'AAPL weight': 0.20602729688916296,
#   'PFE weight': 0.17210655652831913,
#   'BTC weight': 0.10367861176869674},
#  {'Returns': 85.22084080829633,
#   'Volatility': 0.26442912481479897,
#   'SHOP weight': 0.17291889197560908,
#   'TSLA weight': 0.13526418698493128,
#   'GOLD weight': 0.04459890721403709,
#   'DAL weight': 0.15870003342410352,
#   'NFLX weight': 0.04050748123868205,
#   'AAPL weight': 0.17806016214193235,
#   'PFE weight': 0.08355023775650441,
#   'BTC weight': 0.18640009926420026},
#  {'Returns': 37.89397780800613,
#   'Volatility': 0.21891864873999156,
#   'SHOP weight': 0.17206218754126096,
#   'TSLA weight': 0.13876543592058768,
#   'GOLD weight': 0.13523817729682525,
#   'DAL weight': 0.18980356680873878,
#   'NFLX weight': 0.10526453466078832,
#   'AAPL weight': 0.03425254956714643,
#   'PFE weight': 0.1871882800941206,
#   'BTC weight': 0.03742526811053198},
#  {'Returns': 79.00847540846303,
#   'Volatility': 0.29073833145263006,
#   'SHOP weight': 0.18813202903863707,
#   'TSLA weight': 0.22122756741203717,
#   'GOLD weight': 0.07349474542592409,
#   'DAL weight': 0.1799889397716787,
#   'NFLX weight': 0.07494499862027154,
#   'AAPL weight': 0.08743216338646607,
#   'PFE weight': 0.013551913176061754,
#   'BTC weight': 0.16122764316892346},
#  {'Returns': 73.90163066982024,
#   'Volatility': 0.23131022168701715,
#   'SHOP weight': 0.14958140781495613,
#   'TSLA weight': 0.06272516272266732,
#   'GOLD weight': 0.14166563010200067,
#   'DAL weight': 0.1949701807277116,
#   'NFLX weight': 0.06414273760326594,
#   'AAPL weight': 0.12257229846977323,
#   'PFE weight': 0.088279575986916,
#   'BTC weight': 0.17606300657270915},
#  {'Returns': 46.66788452422041,
#   'Volatility': 0.2135391772579503,
#   'SHOP weight': 0.10222726402165072,
#   'TSLA weight': 0.1157412567210601,
#   'GOLD weight': 0.13958654822116576,
#   'DAL weight': 0.13366649265327887,
#   'NFLX weight': 0.17994965429062038,
#   'AAPL weight': 0.10282809386338763,
#   'PFE weight': 0.14096498840981303,
#   'BTC weight': 0.08503570181902345},
#  {'Returns': 20.35260874872111,
#   'Volatility': 0.2421826771393544,
#   'SHOP weight': 0.25578636393929927,
#   'TSLA weight': 0.025572187931370137,
#   'GOLD weight': 0.23996070414653078,
#   'DAL weight': 0.16480136664017725,
#   'NFLX weight': 0.22869212099000472,
#   'AAPL weight': 0.051413431957111844,
#   'PFE weight': 0.015180671028300315,
#   'BTC weight': 0.01859315336720574},
#  {'Returns': 88.14800033362744,
#   'Volatility': 0.2821584733680754,
#   'SHOP weight': 0.06409896312672897,
#   'TSLA weight': 0.24672426468013203,
#   'GOLD weight': 0.043928600850187974,
#   'DAL weight': 0.022395283262158894,
#   'NFLX weight': 0.14387693503695487,
#   'AAPL weight': 0.09128612669856609,
#   'PFE weight': 0.19334781598463727,
#   'BTC weight': 0.19434201036063384},
#  {'Returns': 62.805987211243334,
#   'Volatility': 0.24474690795969756,
#   'SHOP weight': 0.14739883157236816,
#   'TSLA weight': 0.17810716881865069,
#   'GOLD weight': 0.13061772402280952,
#   'DAL weight': 0.17563935378971113,
#   'NFLX weight': 0.0744086462071992,
#   'AAPL weight': 0.06507412854432945,
#   'PFE weight': 0.10780153914522896,
#   'BTC weight': 0.12095260789970297},
#  {'Returns': 53.10220020592262,
#   'Volatility': 0.26606870491345336,
#   'SHOP weight': 0.06266158667701083,
#   'TSLA weight': 0.2504522769459635,
#   'GOLD weight': 0.12395956725440381,
#   'DAL weight': 0.21120096202198466,
#   'NFLX weight': 0.019272479869841368,
#   'AAPL weight': 0.1727121286755341,
#   'PFE weight': 0.07710555611180983,
#   'BTC weight': 0.082635442443452},
#  {'Returns': 52.06052941873949,
#   'Volatility': 0.2667429609051711,
#   'SHOP weight': 0.3195976506626234,
#   'TSLA weight': 0.08688632815916576,
#   'GOLD weight': 0.04699575702883836,
#   'DAL weight': 0.08456986686638816,
#   'NFLX weight': 0.12221986025019092,
#   'AAPL weight': 0.16200713923208404,
#   'PFE weight': 0.10491585483207165,
#   'BTC weight': 0.07280754296863774},
#  {'Returns': 46.77028518783823,
#   'Volatility': 0.23844904569979422,
#   'SHOP weight': 0.18195556641272628,
#   'TSLA weight': 0.11774374667757861,
#   'GOLD weight': 0.141553638604447,
#   'DAL weight': 0.13251458746297423,
#   'NFLX weight': 0.10588556866002721,
#   'AAPL weight': 0.17567258158896829,
#   'PFE weight': 0.06601286506153425,
#   'BTC weight': 0.0786614455317441},
#  {'Returns': 90.62802912874893,
#   'Volatility': 0.2607201636185918,
#   'SHOP weight': 0.08161552672331175,
#   'TSLA weight': 0.09974126830072282,
#   'GOLD weight': 0.193012383033569,
#   'DAL weight': 0.1043121613918926,
#   'NFLX weight': 0.09880174052224742,
#   'AAPL weight': 0.0831249526794986,
#   'PFE weight': 0.0926445800684115,
#   'BTC weight': 0.24674738728034631},
#  {'Returns': 67.17888563167422,
#   'Volatility': 0.23354629843262,
#   'SHOP weight': 0.017922591679938347,
#   'TSLA weight': 0.08455902259657327,
#   'GOLD weight': 0.28571759891526527,
#   'DAL weight': 0.1977127829722588,
#   'NFLX weight': 0.01985956958244321,
#   'AAPL weight': 0.12855462037733262,
#   'PFE weight': 0.08097421418527108,
#   'BTC weight': 0.1846995996909173},
#  {'Returns': 62.221178512645466,
#   'Volatility': 0.24009802136224306,
#   'SHOP weight': 0.2279587367508536,
#   'TSLA weight': 0.07299154385996312,
#   'GOLD weight': 0.0853486237574699,
#   'DAL weight': 0.2392918454338633,
#   'NFLX weight': 0.07887744584639092,
#   'AAPL weight': 0.13616283667411974,
#   'PFE weight': 0.0392206284181667,
#   'BTC weight': 0.1201483392591728},
#  {'Returns': 82.33617392340264,
#   'Volatility': 0.2265070330376933,
#   'SHOP weight': 0.20270449214706357,
#   'TSLA weight': 0.013337973577182001,
#   'GOLD weight': 0.13638107976063416,
#   'DAL weight': 0.09599711379342878,
#   'NFLX weight': 0.10333061508386185,
#   'AAPL weight': 0.014283118802830931,
#   'PFE weight': 0.2303910535610295,
#   'BTC weight': 0.2035745532739691},
#  {'Returns': 96.69400966726644,
#   'Volatility': 0.27804279341695676,
#   'SHOP weight': 0.049714644424173456,
#   'TSLA weight': 0.1663691258451865,
#   'GOLD weight': 0.14583649208421653,
#   'DAL weight': 0.049628614858837565,
#   'NFLX weight': 0.07163728226023075,
#   'AAPL weight': 0.13005230812141216,
#   'PFE weight': 0.13518687209199795,
#   'BTC weight': 0.25157466031394515},
#  {'Returns': 36.36528500091342,
#   'Volatility': 0.2967009596430034,
#   'SHOP weight': 0.22207494046214218,
#   'TSLA weight': 0.26528691601600535,
#   'GOLD weight': 0.05941497334495457,
#   'DAL weight': 0.267140067236916,
#   'NFLX weight': 0.09341304390496963,
#   'AAPL weight': 0.04322643776773236,
#   'PFE weight': 0.048060750485096386,
#   'BTC weight': 0.0013828707821834103},
#  {'Returns': 38.16007861074624,
#   'Volatility': 0.23884663314000518,
#   'SHOP weight': 0.04421707320902963,
#   'TSLA weight': 0.22814488549339995,
#   'GOLD weight': 0.12878203062243307,
#   'DAL weight': 0.10206758970353547,
#   'NFLX weight': 0.13134455750359586,
#   'AAPL weight': 0.1180578425969763,
#   'PFE weight': 0.20772198153902433,
#   'BTC weight': 0.03966403933200533},
#  {'Returns': 33.482009159687095,
#   'Volatility': 0.1931401075144944,
#   'SHOP weight': 0.0816272400337988,
#   'TSLA weight': 0.03832132385260081,
#   'GOLD weight': 0.17515275082428236,
#   'DAL weight': 0.07024475917094156,
#   'NFLX weight': 0.19456519941604783,
#   'AAPL weight': 0.1858244186808596,
#   'PFE weight': 0.1952776597836044,
#   'BTC weight': 0.05898664823786464},
#  {'Returns': 46.14906079614227,
#   'Volatility': 0.2230138891663027,
#   'SHOP weight': 0.0384538000462193,
#   'TSLA weight': 0.028913812387569494,
#   'GOLD weight': 0.3214512878350424,
#   'DAL weight': 0.08424942193552967,
#   'NFLX weight': 0.1343747931080796,
#   'AAPL weight': 0.24757754852870084,
#   'PFE weight': 0.0070093619397737774,
#   'BTC weight': 0.1379699742190849},
#  {'Returns': 82.18735174200518,
#   'Volatility': 0.23433607434721257,
#   'SHOP weight': 0.09240471476034387,
#   'TSLA weight': 0.07667404545011895,
#   'GOLD weight': 0.03573379240018554,
#   'DAL weight': 0.15566126073174313,
#   'NFLX weight': 0.1218264605273771,
#   'AAPL weight': 0.18385880067050167,
#   'PFE weight': 0.1429617496446583,
#   'BTC weight': 0.19087917581507144},
#  {'Returns': 60.582190287894086,
#   'Volatility': 0.22682221585817153,
#   'SHOP weight': 0.17014610346096729,
#   'TSLA weight': 0.03638386466951649,
#   'GOLD weight': 0.21056236190005664,
#   'DAL weight': 0.05893048734566379,
#   'NFLX weight': 0.14481095152560775,
#   'AAPL weight': 0.1256553245837617,
#   'PFE weight': 0.10179956455633009,
#   'BTC weight': 0.15171134195809607},
#  {'Returns': 19.664769204124013,
#   'Volatility': 0.22415239005220544,
#   'SHOP weight': 0.1468666282084207,
#   'TSLA weight': 0.0635279118529274,
#   'GOLD weight': 0.2032726832150519,
#   'DAL weight': 0.06981921398445448,
#   'NFLX weight': 0.18223652172772475,
#   'AAPL weight': 0.20404986019868301,
#   'PFE weight': 0.11951100148422233,
#   'BTC weight': 0.010716179328515494},
#  {'Returns': 58.384604046595555,
#   'Volatility': 0.23835536554509948,
#   'SHOP weight': 0.07454621827383828,
#   'TSLA weight': 0.15015337193905762,
#   'GOLD weight': 0.1216179372689878,
#   'DAL weight': 0.16757038067738142,
#   'NFLX weight': 0.14740353958246485,
#   'AAPL weight': 0.16317054832064196,
#   'PFE weight': 0.05424329040174855,
#   'BTC weight': 0.12129471353587955},
#  {'Returns': 63.359483627300094,
#   'Volatility': 0.227629407508074,
#   'SHOP weight': 0.22181209689310868,
#   'TSLA weight': 0.00675061977856869,
#   'GOLD weight': 0.07998074732094598,
#   'DAL weight': 0.2310986901941351,
#   'NFLX weight': 0.06953295499037221,
#   'AAPL weight': 0.19992937189944981,
#   'PFE weight': 0.059183748510692254,
#   'BTC weight': 0.13171177041272727},
#  {'Returns': 20.511940235272917,
#   'Volatility': 0.2076250647717369,
#   'SHOP weight': 0.005128675667691892,
#   'TSLA weight': 0.16708304580243413,
#   'GOLD weight': 0.24825873567678614,
#   'DAL weight': 0.11991831494658475,
#   'NFLX weight': 0.09799185064705312,
#   'AAPL weight': 0.08055044860077928,
#   'PFE weight': 0.2746559990857797,
#   'BTC weight': 0.006412929572890955},
#  {'Returns': 53.38480196290112,
#   'Volatility': 0.2552058376608571,
#   'SHOP weight': 0.22243924530788914,
#   'TSLA weight': 0.15570024450290107,
#   'GOLD weight': 0.12669173748074347,
#   'DAL weight': 0.20586671520455038,
#   'NFLX weight': 0.1569311413775423,
#   'AAPL weight': 0.004705509822662015,
#   'PFE weight': 0.03679036289093172,
#   'BTC weight': 0.09087504341277994},
#  {'Returns': 83.09685206269751,
#   'Volatility': 0.22551411899201781,
#   'SHOP weight': 0.06974592499012253,
#   'TSLA weight': 0.042238161031916494,
#   'GOLD weight': 0.15741303166282206,
#   'DAL weight': 0.10650160751707494,
#   'NFLX weight': 0.0395891286754982,
#   'AAPL weight': 0.1452256612244193,
#   'PFE weight': 0.22430637702738218,
#   'BTC weight': 0.21498010787076427},
#  {'Returns': 70.34382625872058,
#   'Volatility': 0.2150123765555242,
#   'SHOP weight': 0.09674616172555937,
#   'TSLA weight': 0.016029893451905006,
#   'GOLD weight': 0.14100792558187078,
#   'DAL weight': 0.07742272963759696,
#   'NFLX weight': 0.21614600274144183,
#   'AAPL weight': 0.10520984667851509,
#   'PFE weight': 0.16538806773605372,
#   'BTC weight': 0.1820493724470573},
#  {'Returns': 72.84657740527165,
#   'Volatility': 0.2437164442269595,
#   'SHOP weight': 0.1871050475421423,
#   'TSLA weight': 0.12884573415928216,
#   'GOLD weight': 0.11516952023382529,
#   'DAL weight': 0.10119711534459526,
#   'NFLX weight': 0.07003212285264096,
#   'AAPL weight': 0.0973456566237169,
#   'PFE weight': 0.14427952813768744,
#   'BTC weight': 0.15602527510610983},
#  {'Returns': 75.54623779332584,
#   'Volatility': 0.255557454757375,
#   'SHOP weight': 0.11241646533826022,
#   'TSLA weight': 0.17864981849164518,
#   'GOLD weight': 0.18983564189869442,
#   'DAL weight': 0.1018325481279537,
#   'NFLX weight': 0.04757108917685183,
#   'AAPL weight': 0.07766147669295718,
#   'PFE weight': 0.11394276354354992,
#   'BTC weight': 0.1780901967300874},
#  {'Returns': 50.73079596871902,
#   'Volatility': 0.2061843941473248,
#   'SHOP weight': 0.1812795194971495,
#   'TSLA weight': 0.1215657822297847,
#   'GOLD weight': 0.13670664662041002,
#   'DAL weight': 0.1448517251826675,
#   'NFLX weight': 0.04808709854751084,
#   'AAPL weight': 0.0013348532403665723,
#   'PFE weight': 0.2897376790064535,
#   'BTC weight': 0.07643669567565747},
#  {'Returns': 56.178411638620986,
#   'Volatility': 0.23422375112891314,
#   'SHOP weight': 0.16499125703828715,
#   'TSLA weight': 0.13131812298043624,
#   'GOLD weight': 0.08989583992628528,
#   'DAL weight': 0.08995592192877085,
#   'NFLX weight': 0.134668171725093,
#   'AAPL weight': 0.13959203497788344,
#   'PFE weight': 0.1495317718386005,
#   'BTC weight': 0.10004687958464346},
#  {'Returns': 85.62991017215025,
#   'Volatility': 0.2486286960127313,
#   'SHOP weight': 0.057333604565340146,
#   'TSLA weight': 0.11195501110230867,
#   'GOLD weight': 0.04147505594280288,
#   'DAL weight': 0.21195886945295284,
#   'NFLX weight': 0.21413407541254847,
#   'AAPL weight': 0.06140923990042201,
#   'PFE weight': 0.09528416950001525,
#   'BTC weight': 0.2064499741236097},
#  {'Returns': 91.88737184357913,
#   'Volatility': 0.26086478814897474,
#   'SHOP weight': 0.14680874157061763,
#   'TSLA weight': 0.15485328454077904,
#   'GOLD weight': 0.04111276224395756,
#   'DAL weight': 0.0808268230935116,
#   'NFLX weight': 0.017933748413951015,
#   'AAPL weight': 0.1405223949832154,
#   'PFE weight': 0.21492594087326738,
#   'BTC weight': 0.20301630428070053},
#  {'Returns': 65.04968589677343,
#   'Volatility': 0.24890245923468063,
#   'SHOP weight': 0.09558741741648523,
#   'TSLA weight': 0.15315568090047707,
#   'GOLD weight': 0.0853354760665525,
#   'DAL weight': 0.09609098566775198,
#   'NFLX weight': 0.21055948289637355,
#   'AAPL weight': 0.14229030490594147,
#   'PFE weight': 0.07747944191353498,
#   'BTC weight': 0.13950121023288312},
#  {'Returns': 31.43004682634207,
#   'Volatility': 0.22344810652947975,
#   'SHOP weight': 0.11056078143800002,
#   'TSLA weight': 0.12062137717826324,
#   'GOLD weight': 0.11953568277364097,
#   'DAL weight': 0.18314646132199755,
#   'NFLX weight': 0.1710448796293435,
#   'AAPL weight': 0.1676897935958713,
#   'PFE weight': 0.09866353868474319,
#   'BTC weight': 0.02873748537814023},
#  {'Returns': 39.961911751778906,
#   'Volatility': 0.19502182554689995,
#   'SHOP weight': 0.06848830989103208,
#   'TSLA weight': 0.1030632304910072,
#   'GOLD weight': 0.1834834187798624,
#   'DAL weight': 0.14801794006974056,
#   'NFLX weight': 0.14517812831006766,
#   'AAPL weight': 0.08303457217396934,
#   'PFE weight': 0.19921622865783384,
#   'BTC weight': 0.06951817162648706},
#  {'Returns': 55.89356516311187,
#   'Volatility': 0.22483477739257193,
#   'SHOP weight': 0.12492759692865035,
#   'TSLA weight': 0.12748964081198308,
#   'GOLD weight': 0.13211257829397613,
#   'DAL weight': 0.11670254355165008,
#   'NFLX weight': 0.12156968191428806,
#   'AAPL weight': 0.13314130765187632,
#   'PFE weight': 0.13443863341866297,
#   'BTC weight': 0.10961801742891288},
#  {'Returns': 28.550257320790756,
#   'Volatility': 0.2926099657597964,
#   'SHOP weight': 0.2598639541237182,
#   'TSLA weight': 0.1922879625216167,
#   'GOLD weight': 0.2521113481626127,
#   'DAL weight': 0.02922368205366776,
#   'NFLX weight': 0.1847015026045096,
#   'AAPL weight': 0.019999965491678245,
#   'PFE weight': 0.03535829005208235,
#   'BTC weight': 0.02645329499011439},
#  {'Returns': 58.73947027154411,
#   'Volatility': 0.20929263688241387,
#   'SHOP weight': 0.0853964467998019,
#   'TSLA weight': 0.06525890854708025,
#   'GOLD weight': 0.18910195824564657,
#   'DAL weight': 0.16449783790319816,
#   'NFLX weight': 0.18521464343959243,
#   'AAPL weight': 0.05310333716716039,
#   'PFE weight': 0.11414701225454141,
#   'BTC weight': 0.14327985564297882},
#  {'Returns': 50.704946767367915,
#   'Volatility': 0.20692528120420525,
#   'SHOP weight': 0.07804761345302198,
#   'TSLA weight': 0.04330236817473661,
#   'GOLD weight': 0.17747562455704838,
#   'DAL weight': 0.08929134040487938,
#   'NFLX weight': 0.1902073961962152,
#   'AAPL weight': 0.18466284090004595,
#   'PFE weight': 0.11651687855971135,
#   'BTC weight': 0.12049593775434116},
#  {'Returns': 61.26012070127685,
#   'Volatility': 0.23528533194330453,
#   'SHOP weight': 0.15611865140001233,
#   'TSLA weight': 0.07821285319826216,
#   'GOLD weight': 0.10506136322896391,
#   'DAL weight': 0.24042585499527203,
#   'NFLX weight': 0.03229344400186989,
#   'AAPL weight': 0.2344214263908752,
#   'PFE weight': 0.02900092747021421,
#   'BTC weight': 0.12446547931453036},
#  {'Returns': 26.15383918217874,
#   'Volatility': 0.19678244847351908,
#   'SHOP weight': 0.06868828342480375,
#   'TSLA weight': 0.07786080227412746,
#   'GOLD weight': 0.23052347308537807,
#   'DAL weight': 0.17543650983471462,
#   'NFLX weight': 0.07203243921658674,
#   'AAPL weight': 0.18610748239555003,
#   'PFE weight': 0.1573112052291883,
#   'BTC weight': 0.032039804539651},
#  {'Returns': 89.07170344800889,
#   'Volatility': 0.2819672177664415,
#   'SHOP weight': 0.04171168233502337,
#   'TSLA weight': 0.1783334266455506,
#   'GOLD weight': 0.1792471105591523,
#   'DAL weight': 0.09000764196505857,
#   'NFLX weight': 0.17936500582832549,
#   'AAPL weight': 0.06290034753383741,
#   'PFE weight': 0.02920438790143295,
#   'BTC weight': 0.23923039723161932},
#  {'Returns': 87.92473542813205,
#   'Volatility': 0.286180694497677,
#   'SHOP weight': 0.25586102547702877,
#   'TSLA weight': 0.19540879053929203,
#   'GOLD weight': 0.040944032511734424,
#   'DAL weight': 0.15940408319538435,
#   'NFLX weight': 0.056990460611441536,
#   'AAPL weight': 0.003538133948787044,
#   'PFE weight': 0.10948292624348333,
#   'BTC weight': 0.1783705474728485},
#  {'Returns': 107.28928779947276,
#   'Volatility': 0.29774617401853026,
#   'SHOP weight': 0.034030936613704474,
#   'TSLA weight': 0.15809004325406836,
#   'GOLD weight': 0.11515776979433147,
#   'DAL weight': 0.008682578517706345,
#   'NFLX weight': 0.24861242586368146,
#   'AAPL weight': 0.012418235721016512,
#   'PFE weight': 0.12848914637845227,
#   'BTC weight': 0.29451886385703896},
#  {'Returns': 34.0694900917595,
#   'Volatility': 0.2517830084023576,
#   'SHOP weight': 0.34848095241108396,
#   'TSLA weight': 0.00043770149798773387,
#   'GOLD weight': 0.1459254258466092,
#   'DAL weight': 0.18076091026920557,
#   'NFLX weight': 0.10666709310379344,
#   'AAPL weight': 0.14375189210689787,
#   'PFE weight': 0.03671006532151128,
#   'BTC weight': 0.03726595944291102},
#  {'Returns': 75.05476906703493,
#   'Volatility': 0.24555094947191058,
#   'SHOP weight': 0.11736411676512974,
#   'TSLA weight': 0.15104738481746402,
#   'GOLD weight': 0.040828183837052556,
#   'DAL weight': 0.06467542825798352,
#   'NFLX weight': 0.17356427265431323,
#   'AAPL weight': 0.11748271287423089,
#   'PFE weight': 0.17640493490607226,
#   'BTC weight': 0.15863296588775377},
#  {'Returns': 39.88664242206681,
#   'Volatility': 0.19363685530623947,
#   'SHOP weight': 0.23727221413948674,
#   'TSLA weight': 0.003524730174206537,
#   'GOLD weight': 0.07525293909981691,
#   'DAL weight': 0.22299675284961704,
#   'NFLX weight': 0.04069443498222735,
#   'AAPL weight': 0.0990857724297909,
#   'PFE weight': 0.28309240402916747,
#   'BTC weight': 0.03808075229568707},
#  {'Returns': 107.33380213582376,
#   'Volatility': 0.2668678185389705,
#   'SHOP weight': 0.06310500899783861,
#   'TSLA weight': 0.07030615618963168,
#   'GOLD weight': 0.018582329577242984,
#   'DAL weight': 0.014341526746227554,
#   'NFLX weight': 0.011563407721142234,
#   'AAPL weight': 0.2519431731077829,
#   'PFE weight': 0.30162135614807933,
#   'BTC weight': 0.2685370415120546},
#  {'Returns': 60.702887994373455,
#   'Volatility': 0.21609397480755296,
#   'SHOP weight': 0.019093675329079688,
#   'TSLA weight': 0.13972637799451748,
#   'GOLD weight': 0.1824234745373543,
#   'DAL weight': 0.20138215626891828,
#   'NFLX weight': 0.12507743631881457,
#   'AAPL weight': 0.018834694467282,
#   'PFE weight': 0.17595377846627608,
#   'BTC weight': 0.13750840661775748},
#  {'Returns': 62.94536467900885,
#   'Volatility': 0.2074686920333819,
#   'SHOP weight': 0.08168256167994034,
#   'TSLA weight': 0.02318771773566856,
#   'GOLD weight': 0.18801259434918632,
#   'DAL weight': 0.1878974366172366,
#   'NFLX weight': 0.1576175400892139,
#   'AAPL weight': 0.08661141117674999,
#   'PFE weight': 0.11345257606002036,
#   'BTC weight': 0.16153816229198395},
#  {'Returns': 32.092304099737404,
#   'Volatility': 0.2318214229567638,
#   'SHOP weight': 0.20901668287021796,
#   'TSLA weight': 0.04100400419902003,
#   'GOLD weight': 0.22041630962321923,
#   'DAL weight': 0.061094677925559705,
#   'NFLX weight': 0.11664459759725695,
#   'AAPL weight': 0.2190999725399885,
#   'PFE weight': 0.08028133862281904,
#   'BTC weight': 0.05244241662191856},
#  {'Returns': 79.14739424662882,
#   'Volatility': 0.2709123854165785,
#   'SHOP weight': 0.07878165107391173,
#   'TSLA weight': 0.20018620011454175,
#   'GOLD weight': 0.1002210921176625,
#   'DAL weight': 0.215905423089452,
#   'NFLX weight': 0.12671031712674627,
#   'AAPL weight': 0.07170350462783012,
#   'PFE weight': 0.02695977644309637,
#   'BTC weight': 0.1795320354067592},
#  {'Returns': 49.55562676007679,
#   'Volatility': 0.25528583098976576,
#   'SHOP weight': 0.20105087723816137,
#   'TSLA weight': 0.10366865485701549,
#   'GOLD weight': 0.063854886999511,
#   'DAL weight': 0.06980592944987439,
#   'NFLX weight': 0.1959475329200106,
#   'AAPL weight': 0.21434495563913786,
#   'PFE weight': 0.07007968557826978,
#   'BTC weight': 0.08124747731801946},
#  {'Returns': 68.46636937396069,
#   'Volatility': 0.23641998692425414,
#   'SHOP weight': 0.11724572099372856,
#   'TSLA weight': 0.0964751904230391,
#   'GOLD weight': 0.2054933231800506,
#   'DAL weight': 0.14611953391025537,
#   'NFLX weight': 0.1528179348557863,
#   'AAPL weight': 0.054217105024222854,
#   'PFE weight': 0.05368887951260786,
#   'BTC weight': 0.17394231210030944},
#  {'Returns': 83.33164877120103,
#   'Volatility': 0.22767306433839385,
#   'SHOP weight': 0.14174339624687862,
#   'TSLA weight': 0.026851691116826795,
#   'GOLD weight': 0.09553833207584628,
#   'DAL weight': 0.03616367548607983,
#   'NFLX weight': 0.20699398103556366,
#   'AAPL weight': 0.03556058275645814,
#   'PFE weight': 0.24753207433557664,
#   'BTC weight': 0.20961626694677007},
#  {'Returns': 14.053103034793597,
#   'Volatility': 0.2473905820117856,
#   'SHOP weight': 0.1418477522179941,
#   'TSLA weight': 0.15382961765162323,
#   'GOLD weight': 0.3367863904966927,
#   'DAL weight': 0.16596144581510042,
#   'NFLX weight': 0.13888969404892354,
#   'AAPL weight': 0.044315365609475674,
#   'PFE weight': 0.016387357036951017,
#   'BTC weight': 0.001982377123239363},
#  {'Returns': 73.09466018562458,
#   'Volatility': 0.2626349916225761,
#   'SHOP weight': 0.13853463331261992,
#   'TSLA weight': 0.13425904029465824,
#   'GOLD weight': 0.2199402693155539,
#   'DAL weight': 0.015093187707951334,
#   'NFLX weight': 0.037436603170801226,
#   'AAPL weight': 0.19301818194143086,
#   'PFE weight': 0.07888990374879705,
#   'BTC weight': 0.18282818050818753},
#  {'Returns': 43.90641161497953,
#   'Volatility': 0.215055752803867,
#   'SHOP weight': 0.1238887116733761,
#   'TSLA weight': 0.022699118232139773,
#   'GOLD weight': 0.18362439410110168,
#   'DAL weight': 0.2595587746813622,
#   'NFLX weight': 0.09687858609314787,
#   'AAPL weight': 0.21775787853242545,
#   'PFE weight': 0.002544780856895922,
#   'BTC weight': 0.09304775582955097},
#  {'Returns': 69.5063702773323,
#   'Volatility': 0.2322264009509506,
#   'SHOP weight': 0.12725493134798388,
#   'TSLA weight': 0.121882884808363,
#   'GOLD weight': 0.08503180165898386,
#   'DAL weight': 0.06613964809826468,
#   'NFLX weight': 0.1796393006229213,
#   'AAPL weight': 0.09161223800430203,
#   'PFE weight': 0.17793809570685404,
#   'BTC weight': 0.15050109975232728},
#  {'Returns': 47.013722716590905,
#   'Volatility': 0.18830036435890796,
#   'SHOP weight': 0.024681953862384653,
#   'TSLA weight': 0.0604085458816195,
#   'GOLD weight': 0.12975808825344706,
#   'DAL weight': 0.023493831336803245,
#   'NFLX weight': 0.16513196265952151,
#   'AAPL weight': 0.20028926618444384,
#   'PFE weight': 0.3019934643061969,
#   'BTC weight': 0.09424288751558313},
#  {'Returns': 73.36371838553625,
#   'Volatility': 0.24220009037013535,
#   'SHOP weight': 0.0813492573562795,
#   'TSLA weight': 0.07071009054485568,
#   'GOLD weight': 0.1798817483774957,
#   'DAL weight': 0.1061761872259,
#   'NFLX weight': 0.18643692456697403,
#   'AAPL weight': 0.14166793161154567,
#   'PFE weight': 0.03695800433883564,
#   'BTC weight': 0.19681985597811374},
#  {'Returns': 75.13364211786165,
#   'Volatility': 0.2626756320862185,
#   'SHOP weight': 0.0985789302619643,
#   'TSLA weight': 0.08723075604127523,
#   'GOLD weight': 0.23590122143597259,
#   'DAL weight': 5.467892769713252e-05,
#   'NFLX weight': 0.09553166810227916,
#   'AAPL weight': 0.23491120304057525,
#   'PFE weight': 0.04013781899486202,
#   'BTC weight': 0.20765372319537437},
#  {'Returns': 51.87082879403896,
#   'Volatility': 0.23593438758985397,
#   'SHOP weight': 0.2322891113856369,
#   'TSLA weight': 0.04098316592481608,
#   'GOLD weight': 0.011320410523424472,
#   'DAL weight': 0.06049277708210996,
#   'NFLX weight': 0.2755709938293003,
#   'AAPL weight': 0.10938512162546447,
#   'PFE weight': 0.18582961121808741,
#   'BTC weight': 0.08412880841116042},
#  {'Returns': 48.91452415180872,
#   'Volatility': 0.23799596216582075,
#   'SHOP weight': 0.211445233465103,
#   'TSLA weight': 0.16945369088102372,
#   'GOLD weight': 0.08003224505876219,
#   'DAL weight': 0.13481838295634505,
#   'NFLX weight': 0.023017949414064785,
#   'AAPL weight': 0.10047862295800278,
#   'PFE weight': 0.22692237675219934,
#   'BTC weight': 0.05383149851449919},
#  {'Returns': 73.10551191509917,
#   'Volatility': 0.2812676240241782,
#   'SHOP weight': 0.04767102634773398,
#   'TSLA weight': 0.233669563185741,
#   'GOLD weight': 0.11953050757441222,
#   'DAL weight': 0.1406479673125671,
#   'NFLX weight': 0.21421264003025214,
#   'AAPL weight': 0.07478306763884211,
#   'PFE weight': 0.0012415013014131244,
#   'BTC weight': 0.16824372660903836},
#  {'Returns': 102.1115268343288,
#   'Volatility': 0.30169193385153037,
#   'SHOP weight': 0.060427419592998424,
#   'TSLA weight': 0.24624726847568093,
#   'GOLD weight': 0.10754781181749824,
#   'DAL weight': 0.12534892849144422,
#   'NFLX weight': 0.026296770034581304,
#   'AAPL weight': 0.06375436646062854,
#   'PFE weight': 0.12286045615562387,
#   'BTC weight': 0.2475169789715445},
#  {'Returns': 53.30433228138928,
#   'Volatility': 0.23001456111027782,
#   'SHOP weight': 0.11032843558252518,
#   'TSLA weight': 0.13049099531140396,
#   'GOLD weight': 0.028096788961726623,
#   'DAL weight': 0.06501228789008695,
#   'NFLX weight': 0.18657901288534945,
#   'AAPL weight': 0.20070554470655386,
#   'PFE weight': 0.19268577276480173,
#   'BTC weight': 0.08610116189755232},
#  {'Returns': 72.98783921608239,
#   'Volatility': 0.2761913852899156,
#   'SHOP weight': 0.17388214730292625,
#   'TSLA weight': 0.18914709472050473,
#   'GOLD weight': 0.11038371263500671,
#   'DAL weight': 0.08031971865865165,
#   'NFLX weight': 0.12245729019126778,
#   'AAPL weight': 0.1156321760381778,
#   'PFE weight': 0.05189527789985682,
#   'BTC weight': 0.1562825825536084},
#  {'Returns': 76.0045225666579,
#   'Volatility': 0.25691316576747975,
#   'SHOP weight': 0.151200610491127,
#   'TSLA weight': 0.15942779709948987,
#   'GOLD weight': 0.015688609650288163,
#   'DAL weight': 0.16449183010717744,
#   'NFLX weight': 0.1353533179659965,
#   'AAPL weight': 0.1249128329039377,
#   'PFE weight': 0.0965485562705788,
#   'BTC weight': 0.1523764455114043},
#  {'Returns': 71.54410648139053,
#   'Volatility': 0.2270853812015209,
#   'SHOP weight': 0.0003579604895459228,
#   'TSLA weight': 0.01352448693135083,
#   'GOLD weight': 0.2144181337485743,
#   'DAL weight': 0.1732159809992625,
#   'NFLX weight': 0.08602453891421875,
#   'AAPL weight': 0.22815778405046547,
#   'PFE weight': 0.08149705130036974,
#   'BTC weight': 0.2028040635662123},
#  {'Returns': 63.29635478118866,
#   'Volatility': 0.2885270895214556,
#   'SHOP weight': 0.09045941336893197,
#   'TSLA weight': 0.2689703640737908,
#   'GOLD weight': 0.11362799415592593,
#   'DAL weight': 0.06106473079388343,
#   'NFLX weight': 0.1706115322341292,
#   'AAPL weight': 0.11413341414087265,
#   'PFE weight': 0.05806162555439864,
#   'BTC weight': 0.12307092567806731},
#  {'Returns': 20.169431773834916,
#   'Volatility': 0.21324803435804648,
#   'SHOP weight': 0.060892461843703956,
#   'TSLA weight': 0.06819403901355843,
#   'GOLD weight': 0.44307860985647923,
#   'DAL weight': 0.05807634883825533,
#   'NFLX weight': 0.1295798308166643,
#   'AAPL weight': 0.07326200836591368,
#   'PFE weight': 0.1086368182642566,
#   'BTC weight': 0.058279883001168466},
#  {'Returns': 51.128666368381296,
#   'Volatility': 0.2603340491689446,
#   'SHOP weight': 0.10956499776878809,
#   'TSLA weight': 0.1713262462375458,
#   'GOLD weight': 0.17705248461561365,
#   'DAL weight': 0.04176505371474113,
#   'NFLX weight': 0.1753700312286936,
#   'AAPL weight': 0.18291069461379952,
#   'PFE weight': 0.03576792856839992,
#   'BTC weight': 0.10624256325241839},
#  {'Returns': 87.69200164345972,
#   'Volatility': 0.29883017833742426,
#   'SHOP weight': 0.1368826204800455,
#   'TSLA weight': 0.2361310513911379,
#   'GOLD weight': 0.08628476546884525,
#   'DAL weight': 0.0431242612389541,
#   'NFLX weight': 0.19040786956709493,
#   'AAPL weight': 0.031211471627828162,
#   'PFE weight': 0.07386726144795973,
#   'BTC weight': 0.20209069877813438},
#  {'Returns': 74.05703762518681,
#   'Volatility': 0.2328331012873285,
#   'SHOP weight': 0.14789077627029965,
#   'TSLA weight': 0.0011448992961338284,
#   'GOLD weight': 0.2396134577864356,
#   'DAL weight': 0.13318118279748678,
#   'NFLX weight': 0.11612375896315072,
#   'AAPL weight': 0.07717873197702059,
#   'PFE weight': 0.07833638733039704,
#   'BTC weight': 0.20653080557907577},
#  {'Returns': 90.48034674421012,
#   'Volatility': 0.29510636330416234,
#   'SHOP weight': 0.2625926480752279,
#   'TSLA weight': 0.19380815493250436,
#   'GOLD weight': 0.015915309635429975,
#   'DAL weight': 0.12468518075199314,
#   'NFLX weight': 0.09464681195499164,
#   'AAPL weight': 0.026443814612491928,
#   'PFE weight': 0.09591937244844445,
#   'BTC weight': 0.18598870758891647},
#  {'Returns': 94.8015518835987,
#   'Volatility': 0.26079579221161264,
#   'SHOP weight': 0.09626750980647057,
#   'TSLA weight': 0.09834759214569384,
#   'GOLD weight': 0.09279759939371628,
#   'DAL weight': 0.057983741812495875,
#   'NFLX weight': 0.24788779971816705,
#   'AAPL weight': 0.0031786009327719614,
#   'PFE weight': 0.1555263428628673,
#   'BTC weight': 0.24801081332781713},
#  {'Returns': 28.725650208441127,
#   'Volatility': 0.21661138613824746,
#   'SHOP weight': 0.15672404881202895,
#   'TSLA weight': 0.09527652154626227,
#   'GOLD weight': 0.1739537481059162,
#   'DAL weight': 0.06163903660776331,
#   'NFLX weight': 0.24455821531847613,
#   'AAPL weight': 0.0304269134705265,
#   'PFE weight': 0.20765847045869132,
#   'BTC weight': 0.029763045680335293},
#  {'Returns': 28.72733390406674,
#   'Volatility': 0.22186228869765845,
#   'SHOP weight': 0.11536823791018101,
#   'TSLA weight': 0.07426763854838482,
#   'GOLD weight': 0.08915731054924142,
#   'DAL weight': 0.08676703065877854,
#   'NFLX weight': 0.17211158899363366,
#   'AAPL weight': 0.2908168613220319,
#   'PFE weight': 0.1503283490570275,
#   'BTC weight': 0.021182982960721217},
#  {'Returns': 63.92700971924941,
#   'Volatility': 0.24683799550708957,
#   'SHOP weight': 0.025705846775042274,
#   'TSLA weight': 0.11308058944027898,
#   'GOLD weight': 0.1736044087023199,
#   'DAL weight': 0.0601817528461839,
#   'NFLX weight': 0.22348712791398295,
#   'AAPL weight': 0.2111022515578991,
#   'PFE weight': 0.026032579740208003,
#   'BTC weight': 0.16680544302408484},
#  {'Returns': 32.84826270942758,
#   'Volatility': 0.25112365265832437,
#   'SHOP weight': 0.02246370773662821,
#   'TSLA weight': 0.16521145944348606,
#   'GOLD weight': 0.12284841214642414,
#   'DAL weight': 0.027751463923997074,
#   'NFLX weight': 0.3258530438902544,
#   'AAPL weight': 0.192497353644955,
#   'PFE weight': 0.09506701904407042,
#   'BTC weight': 0.0483075401701847},
#  {'Returns': 39.032200061223584,
#   'Volatility': 0.2530862521913912,
#   'SHOP weight': 0.10128376721611923,
#   'TSLA weight': 0.19933924447146947,
#   'GOLD weight': 0.1181416968845936,
#   'DAL weight': 0.08257538566749865,
#   'NFLX weight': 0.11205468172633021,
#   'AAPL weight': 0.22513070979906571,
#   'PFE weight': 0.11749145547254691,
#   'BTC weight': 0.04398305876237623},
#  {'Returns': 61.12328922639587,
#   'Volatility': 0.22584085467028214,
#   'SHOP weight': 0.11648682969958914,
#   'TSLA weight': 0.11848838854820463,
#   'GOLD weight': 0.16433684446884217,
#   'DAL weight': 0.12381691184655569,
#   'NFLX weight': 0.09355754429317241,
#   'AAPL weight': 0.13068692228495588,
#   'PFE weight': 0.11858118039784207,
#   'BTC weight': 0.1340453784608379},
#  {'Returns': 52.4862642216676,
#   'Volatility': 0.22365302998642939,
#   'SHOP weight': 0.12148023516347432,
#   'TSLA weight': 0.1796161855403895,
#   'GOLD weight': 0.061888978626098344,
#   'DAL weight': 0.19338571206877367,
#   'NFLX weight': 0.10641751974433435,
#   'AAPL weight': 0.028404008803586824,
#   'PFE weight': 0.23787522846680453,
#   'BTC weight': 0.07093213158653847},
#  {'Returns': 78.192615434067,
#   'Volatility': 0.251249526464689,
#   'SHOP weight': 0.1604510678261203,
#   'TSLA weight': 0.08604690281784108,
#   'GOLD weight': 0.20739144306593185,
#   'DAL weight': 0.028073874399772783,
#   'NFLX weight': 0.17476580938031247,
#   'AAPL weight': 0.018539716025380536,
#   'PFE weight': 0.11839125447846957,
#   'BTC weight': 0.20633993200617134},
#  {'Returns': 24.125579554799323,
#   'Volatility': 0.21004853863239198,
#   'SHOP weight': 0.04034030099736316,
#   'TSLA weight': 0.1089147613195356,
#   'GOLD weight': 0.14375726561696847,
#   'DAL weight': 0.03231899767726042,
#   'NFLX weight': 0.181926608255083,
#   'AAPL weight': 0.22943787745961153,
#   'PFE weight': 0.24926795661741472,
#   'BTC weight': 0.014036232056763088},
#  {'Returns': 63.064050328275414,
#   'Volatility': 0.26824090158143205,
#   'SHOP weight': 0.13434492111859575,
#   'TSLA weight': 0.2109943782669827,
#   'GOLD weight': 0.05899626162782649,
#   'DAL weight': 0.16027759739589684,
#   'NFLX weight': 0.016433459327032746,
#   'AAPL weight': 0.23404600315117477,
#   'PFE weight': 0.0789895711574157,
#   'BTC weight': 0.10591780795507498},
#  {'Returns': 46.53791404214645,
#   'Volatility': 0.2167218226783004,
#   'SHOP weight': 0.17083363478610086,
#   'TSLA weight': 0.09950865435874175,
#   'GOLD weight': 0.21194544940153165,
#   'DAL weight': 0.11244877094107703,
#   'NFLX weight': 0.044469731722864586,
#   'AAPL weight': 0.12197228589033249,
#   'PFE weight': 0.15208344909155982,
#   'BTC weight': 0.08673802380779179},
#  {'Returns': 54.56086704375993,
#   'Volatility': 0.30080089975761676,
#   'SHOP weight': 0.23010790478279347,
#   'TSLA weight': 0.22881635712776785,
#   'GOLD weight': 0.03389482480019841,
#   'DAL weight': 0.12519185949840408,
#   'NFLX weight': 0.17808257736650385,
#   'AAPL weight': 0.11806095944766712,
#   'PFE weight': 0.012418472476931616,
#   'BTC weight': 0.07342704449973358},
#  {'Returns': 82.63634793222765,
#   'Volatility': 0.24177507490800965,
#   'SHOP weight': 0.04521236658614504,
#   'TSLA weight': 0.17443993223352458,
#   'GOLD weight': 0.02700452282124632,
#   'DAL weight': 0.20586514405663828,
#   'NFLX weight': 0.13211631452261846,
#   'AAPL weight': 0.014123240216864072,
#   'PFE weight': 0.22493037326141158,
#   'BTC weight': 0.17630810630155166},
#  {'Returns': 75.69121916034037,
#   'Volatility': 0.23111396516803054,
#   'SHOP weight': 0.17998099949814894,
#   'TSLA weight': 0.004009577348493426,
#   'GOLD weight': 0.16343380688884318,
#   'DAL weight': 0.09739851319933998,
#   'NFLX weight': 0.17913367854991705,
#   'AAPL weight': 0.05258648763329676,
#   'PFE weight': 0.12584930946376907,
#   'BTC weight': 0.1976076274181917},
#  {'Returns': 57.746903836223964,
#   'Volatility': 0.2374472833306134,
#   'SHOP weight': 0.1146879865260298,
#   'TSLA weight': 0.13761462500363483,
#   'GOLD weight': 0.13523140826544935,
#   'DAL weight': 0.0703014647853588,
#   'NFLX weight': 0.12586285438331246,
# ...
#   'PFE weight': 0.1608490079527167,
#   'BTC weight': 0.20370896833682406},
#  {'Returns': 87.09907254825764,
#   'Volatility': 0.263092201971806,
#   'SHOP weight': 0.027599336782519832,
#   'TSLA weight': 0.164683820113843,
#   'GOLD weight': 0.07295891375546219,
#   'DAL weight': 0.14101085662172874,
#   'NFLX weight': 0.16480821145206448,
#   'AAPL weight': 0.126427674680855,
#   'PFE weight': 0.08995308263293024,
#   'BTC weight': 0.2125581039605964},
#  {'Returns': 34.27347751806593,
#   'Volatility': 0.22486362593955678,
#   'SHOP weight': 0.0964607739583773,
#   'TSLA weight': 0.16957069105495215,
#   'GOLD weight': 0.22729742026406805,
#   'DAL weight': 0.08730996758120939,
#   'NFLX weight': 0.13934855973121227,
#   'AAPL weight': 0.0662707582343356,
#   'PFE weight': 0.16442093534639862,
#   'BTC weight': 0.049320893829446696},
#  {'Returns': 90.0187568318403,
#   'Volatility': 0.29345707508996777,
#   'SHOP weight': 0.05195909927894429,
#   'TSLA weight': 0.24406929856052492,
#   'GOLD weight': 0.22986603078834147,
#   'DAL weight': 0.1238896817284001,
#   'NFLX weight': 0.005086518770490605,
#   'AAPL weight': 0.032375523414808975,
#   'PFE weight': 0.083600141075364,
#   'BTC weight': 0.22915370638312563},
#  {'Returns': 55.099093389947186,
#   'Volatility': 0.32645669095866525,
#   'SHOP weight': 0.2958311640893823,
#   'TSLA weight': 0.27618736324019244,
#   'GOLD weight': 0.16778109629728902,
#   'DAL weight': 0.04682921282972288,
#   'NFLX weight': 0.10938284287685578,
#   'AAPL weight': 0.0021091028168878216,
#   'PFE weight': 0.017586854735066867,
#   'BTC weight': 0.08429236311460296},
#  {'Returns': 59.80762651400431,
#   'Volatility': 0.2690411745100991,
#   'SHOP weight': 0.18350561617512928,
#   'TSLA weight': 0.1950822717539871,
#   'GOLD weight': 0.027115887575029734,
#   'DAL weight': 0.16714439375957937,
#   'NFLX weight': 0.16449535414187538,
#   'AAPL weight': 0.10742857654278327,
#   'PFE weight': 0.060674655681870034,
#   'BTC weight': 0.0945532443697459},
#  {'Returns': 37.36179949315293,
#   'Volatility': 0.22165465813606286,
#   'SHOP weight': 0.09672817614825414,
#   'TSLA weight': 0.12305989529259713,
#   'GOLD weight': 0.2245316142476517,
#   'DAL weight': 0.18826312566342987,
#   'NFLX weight': 0.11699820528968188,
#   'AAPL weight': 0.1286759521996112,
#   'PFE weight': 0.0548242987377839,
#   'BTC weight': 0.06691873242099035},
#  {'Returns': 60.55224557605998,
#   'Volatility': 0.21952094060056765,
#   'SHOP weight': 0.13225363840766904,
#   'TSLA weight': 0.01889461137704048,
#   'GOLD weight': 0.12427714348356757,
#   'DAL weight': 0.08014020413082198,
#   'NFLX weight': 0.19540366703291936,
#   'AAPL weight': 0.1970153592705809,
#   'PFE weight': 0.1076508525846397,
#   'BTC weight': 0.14436452371276098},
#  {'Returns': 35.81472835966005,
#   'Volatility': 0.23843906558352845,
#   'SHOP weight': 0.26300970932855267,
#   'TSLA weight': 0.08655616846579389,
#   'GOLD weight': 0.029583914822900143,
#   'DAL weight': 0.07248917381572362,
#   'NFLX weight': 0.17391931363413513,
#   'AAPL weight': 0.10785423393210766,
#   'PFE weight': 0.25117484798203804,
#   'BTC weight': 0.015412638018748924},
#  {'Returns': 79.72834633422319,
#   'Volatility': 0.2814076201319825,
#   'SHOP weight': 0.18767362178111166,
#   'TSLA weight': 0.19336300713111668,
#   'GOLD weight': 0.14673036982578938,
#   'DAL weight': 0.07262375538827545,
#   'NFLX weight': 0.11151471761803032,
#   'AAPL weight': 0.043155741738614056,
#   'PFE weight': 0.06238246184943921,
#   'BTC weight': 0.18255632466762314},
#  {'Returns': 58.608996380199855,
#   'Volatility': 0.24099512905958229,
#   'SHOP weight': 0.26492534978996596,
#   'TSLA weight': 0.061392710919705114,
#   'GOLD weight': 0.046825866027745015,
#   'DAL weight': 0.2967890479613696,
#   'NFLX weight': 0.1610255401375099,
#   'AAPL weight': 0.011637251228684966,
#   'PFE weight': 0.05688002692633978,
#   'BTC weight': 0.10052420700867966},
#  {'Returns': 30.733848022699924,
#   'Volatility': 0.2883464005733175,
#   'SHOP weight': 0.1746476485570626,
#   'TSLA weight': 0.24996386097184578,
#   'GOLD weight': 0.13677525228770998,
#   'DAL weight': 0.088692747032082,
#   'NFLX weight': 0.08368211392075026,
#   'AAPL weight': 0.1807706428253047,
#   'PFE weight': 0.07979378996011102,
#   'BTC weight': 0.005673944445133601},
#  {'Returns': 62.513774144919346,
#   'Volatility': 0.28971560480128483,
#   'SHOP weight': 0.0414553583185166,
#   'TSLA weight': 0.28472353628156777,
#   'GOLD weight': 0.039647587863487384,
#   'DAL weight': 0.14053809554164637,
#   'NFLX weight': 0.07330131009043853,
#   'AAPL weight': 0.24460896576054247,
#   'PFE weight': 0.07310279297924954,
#   'BTC weight': 0.10262235316455133},
#  {'Returns': 116.3237655171018,
#   'Volatility': 0.3177597668055514,
#   'SHOP weight': 0.04164109135006342,
#   'TSLA weight': 0.24093865811410978,
#   'GOLD weight': 0.02959659376493188,
#   'DAL weight': 0.20210091948691705,
#   'NFLX weight': 0.03277404964534732,
#   'AAPL weight': 0.023530795593696436,
#   'PFE weight': 0.1478894295157052,
#   'BTC weight': 0.2815284625292289},
#  {'Returns': 30.78888447757324,
#   'Volatility': 0.2541560739365216,
#   'SHOP weight': 0.3137030601385874,
#   'TSLA weight': 0.07076214181407933,
#   'GOLD weight': 0.05963730319543435,
#   'DAL weight': 0.0568646786829969,
#   'NFLX weight': 0.22534213726812735,
#   'AAPL weight': 0.03889180886654669,
#   'PFE weight': 0.2299629458644644,
#   'BTC weight': 0.004835924169763593},
#  {'Returns': 18.257459211346777,
#   'Volatility': 0.2172030671570437,
#   'SHOP weight': 0.1912283206509519,
#   'TSLA weight': 0.007042201072797443,
#   'GOLD weight': 0.18596964073999064,
#   'DAL weight': 0.03766426456685091,
#   'NFLX weight': 0.16815869846424447,
#   'AAPL weight': 0.20602346227934845,
#   'PFE weight': 0.20075499164152238,
#   'BTC weight': 0.0031584205842938654},
#  {'Returns': 83.67464404752451,
#   'Volatility': 0.25598203937305525,
#   'SHOP weight': 0.06871287179272081,
#   'TSLA weight': 0.1862639860879411,
#   'GOLD weight': 0.04548092708671587,
#   'DAL weight': 0.1513042914831463,
#   'NFLX weight': 0.032275652095320566,
#   'AAPL weight': 0.16007130012547852,
#   'PFE weight': 0.17694875757278414,
#   'BTC weight': 0.1789422137558927},
#  {'Returns': 61.09780992435667,
#   'Volatility': 0.2529833496697328,
#   'SHOP weight': 0.1691148957349841,
#   'TSLA weight': 0.17712110079355226,
#   'GOLD weight': 0.1609072937771556,
#   'DAL weight': 0.07129225977400099,
#   'NFLX weight': 0.13357096381292252,
#   'AAPL weight': 0.05099010638614375,
#   'PFE weight': 0.112740205489868,
#   'BTC weight': 0.12426317423137288},
#  {'Returns': 69.1607727356814,
#   'Volatility': 0.26773578413545385,
#   'SHOP weight': 0.15950821274024807,
#   'TSLA weight': 0.22827898919876285,
#   'GOLD weight': 0.06332128379696653,
#   'DAL weight': 0.21297688514940671,
#   'NFLX weight': 0.10665152616006535,
#   'AAPL weight': 0.006689616391137456,
#   'PFE weight': 0.09876965936250663,
#   'BTC weight': 0.12380382720090644},
#  {'Returns': 70.71337188635086,
#   'Volatility': 0.24701592911761527,
#   'SHOP weight': 0.06291575885946712,
#   'TSLA weight': 0.16570708151406197,
#   'GOLD weight': 0.12585229533883008,
#   'DAL weight': 0.029231389822746093,
#   'NFLX weight': 0.11125498947280495,
#   'AAPL weight': 0.18780995930523353,
#   'PFE weight': 0.15672351750299052,
#   'BTC weight': 0.16050500818386584},
#  {'Returns': 30.44308168210275,
#   'Volatility': 0.2375580541256683,
#   'SHOP weight': 0.12575891410430198,
#   'TSLA weight': 0.15878880159856182,
#   'GOLD weight': 0.07547236981191996,
#   'DAL weight': 0.17494490541126642,
#   'NFLX weight': 0.1890093266606301,
#   'AAPL weight': 0.13665328284646636,
#   'PFE weight': 0.128458408846287,
#   'BTC weight': 0.010913990720566353},
#  {'Returns': 62.55386346036937,
#   'Volatility': 0.27194119982509707,
#   'SHOP weight': 0.21093004864867762,
#   'TSLA weight': 0.18137525381178163,
#   'GOLD weight': 0.08352380902094221,
#   'DAL weight': 0.19934450930105801,
#   'NFLX weight': 0.17016980757987085,
#   'AAPL weight': 0.03293857456925166,
#   'PFE weight': 0.007189189840530405,
#   'BTC weight': 0.11452880722788755},
#  {'Returns': 34.219934950852625,
#   'Volatility': 0.2672840391770672,
#   'SHOP weight': 0.21277493176495227,
#   'TSLA weight': 0.2157766498384678,
#   'GOLD weight': 0.1255895742404888,
#   'DAL weight': 0.16875088066138785,
#   'NFLX weight': 0.10632537224266891,
#   'AAPL weight': 0.05435714746396299,
#   'PFE weight': 0.10241281782167795,
#   'BTC weight': 0.01401262596639356},
#  {'Returns': 31.084358450838664,
#   'Volatility': 0.22724951368671523,
#   'SHOP weight': 0.002072660879237066,
#   'TSLA weight': 0.2223800822182709,
#   'GOLD weight': 0.0812466944245186,
#   'DAL weight': 0.18930369200117086,
#   'NFLX weight': 0.1740513748013404,
#   'AAPL weight': 0.03205431147799447,
#   'PFE weight': 0.29175579116035383,
#   'BTC weight': 0.007135393037113939},
#  {'Returns': 27.80376868726221,
#   'Volatility': 0.23902563432344232,
#   'SHOP weight': 0.0899819701120759,
#   'TSLA weight': 0.1814944788081879,
#   'GOLD weight': 0.1300218259101172,
#   'DAL weight': 0.1259889723943599,
#   'NFLX weight': 0.1811397412750294,
#   'AAPL weight': 0.14324491712306714,
#   'PFE weight': 0.1359994641159924,
#   'BTC weight': 0.012128630261170082},
#  {'Returns': 41.567747290531784,
#   'Volatility': 0.25073386552774124,
#   'SHOP weight': 0.2929443388203398,
#   'TSLA weight': 0.14709518498843496,
#   'GOLD weight': 0.038058505534750764,
#   'DAL weight': 0.20183118022333094,
#   'NFLX weight': 0.09041432850558122,
#   'AAPL weight': 0.01580277219100297,
#   'PFE weight': 0.19386453603045553,
#   'BTC weight': 0.019989153706103876},
#  {'Returns': 88.42298789265526,
#   'Volatility': 0.2547865065944872,
#   'SHOP weight': 0.07135082412047722,
#   'TSLA weight': 0.12762695634203727,
#   'GOLD weight': 0.05347179941651958,
#   'DAL weight': 0.2583536964665079,
#   'NFLX weight': 0.05947351731899466,
#   'AAPL weight': 0.10702018578083057,
#   'PFE weight': 0.11785021377914588,
#   'BTC weight': 0.20485280677548687},
#  {'Returns': 107.50518729648297,
#   'Volatility': 0.2747457908901721,
#   'SHOP weight': 0.1806069723234119,
#   'TSLA weight': 0.018867095797154086,
#   'GOLD weight': 0.16715770645796993,
#   'DAL weight': 0.03721914328200837,
#   'NFLX weight': 0.0003735791373486249,
#   'AAPL weight': 0.06895827533978144,
#   'PFE weight': 0.23442700906819222,
#   'BTC weight': 0.2923902185941335},
#  {'Returns': 30.177869204602825,
#   'Volatility': 0.2363933641183076,
#   'SHOP weight': 0.13709534217450625,
#   'TSLA weight': 0.1676687716023639,
#   'GOLD weight': 0.20719762093410693,
#   'DAL weight': 0.18814977821193812,
#   'NFLX weight': 0.004513688138434899,
#   'AAPL weight': 0.16320912809570123,
#   'PFE weight': 0.11017717276062437,
#   'BTC weight': 0.021988498082324306},
#  {'Returns': 74.46656782467551,
#   'Volatility': 0.27637102147097836,
#   'SHOP weight': 0.1433032533421962,
#   'TSLA weight': 0.17941148869551476,
#   'GOLD weight': 0.018020214561422932,
#   'DAL weight': 0.008048735069724429,
#   'NFLX weight': 0.16304656782600657,
#   'AAPL weight': 0.21110266843521824,
#   'PFE weight': 0.12657535133169587,
#   'BTC weight': 0.15049172073822092},
#  {'Returns': 61.21885278310701,
#   'Volatility': 0.2250728168041354,
#   'SHOP weight': 0.11214736946781231,
#   'TSLA weight': 0.096741878553466,
#   'GOLD weight': 0.1916747432296449,
#   'DAL weight': 0.11324484010265982,
#   'NFLX weight': 0.22425367192197107,
#   'AAPL weight': 0.010192141705350826,
#   'PFE weight': 0.1024059580376931,
#   'BTC weight': 0.14933939698140192},
#  {'Returns': 48.8967514416543,
#   'Volatility': 0.3032620607050045,
#   'SHOP weight': 0.2712330636141019,
#   'TSLA weight': 0.26880010722685277,
#   'GOLD weight': 0.04258251169043476,
#   'DAL weight': 0.1796776111585615,
#   'NFLX weight': 0.08045540381454885,
#   'AAPL weight': 0.03636315450402939,
#   'PFE weight': 0.08435575481910441,
#   'BTC weight': 0.03653239317236645},
#  {'Returns': 61.332577664851854,
#   'Volatility': 0.24869123737008475,
#   'SHOP weight': 0.17141031785724992,
#   'TSLA weight': 0.14942380632055197,
#   'GOLD weight': 0.15228881388414706,
#   'DAL weight': 0.1602877380310547,
#   'NFLX weight': 0.02786928378361432,
#   'AAPL weight': 0.15685571911005464,
#   'PFE weight': 0.05961462797695584,
#   'BTC weight': 0.12224969303637151},
#  {'Returns': 75.03281845894766,
#   'Volatility': 0.2447611689659117,
#   'SHOP weight': 0.2029717966606252,
#   'TSLA weight': 0.041654749924053956,
#   'GOLD weight': 0.19222963077965202,
#   'DAL weight': 0.21920281668648062,
#   'NFLX weight': 0.02027787715946318,
#   'AAPL weight': 0.1052704556164846,
#   'PFE weight': 0.031951769007603915,
#   'BTC weight': 0.18644090416563655},
#  {'Returns': 38.0597198107249,
#   'Volatility': 0.2451169771607523,
#   'SHOP weight': 0.13692978760659935,
#   'TSLA weight': 0.19708170310453038,
#   'GOLD weight': 0.06764977435548167,
#   'DAL weight': 0.1768393641958677,
#   'NFLX weight': 0.04646739490159045,
#   'AAPL weight': 0.17936122889954806,
#   'PFE weight': 0.1754042403098301,
#   'BTC weight': 0.020266506626552286},
#  {'Returns': 30.43492376259933,
#   'Volatility': 0.23640239013063982,
#   'SHOP weight': 0.18623531773015312,
#   'TSLA weight': 0.17259375576005825,
#   'GOLD weight': 0.2501797978799089,
#   'DAL weight': 0.04080098385651316,
#   'NFLX weight': 0.06436046443958465,
#   'AAPL weight': 0.02668513343695497,
#   'PFE weight': 0.23292038364717063,
#   'BTC weight': 0.02622416324965644},
#  {'Returns': 71.10136665850807,
#   'Volatility': 0.24274398487456844,
#   'SHOP weight': 0.14661267847518442,
#   'TSLA weight': 0.12205842935441513,
#   'GOLD weight': 0.16058752709112367,
#   'DAL weight': 0.09079457315396348,
#   'NFLX weight': 0.1421954044096478,
#   'AAPL weight': 0.06775067177853761,
#   'PFE weight': 0.10193367029312607,
#   'BTC weight': 0.16806704544400183},
#  {'Returns': 64.84641060472266,
#   'Volatility': 0.2590406765069974,
#   'SHOP weight': 0.05072638755790141,
#   'TSLA weight': 0.2758095737935514,
#   'GOLD weight': 0.12395306218465472,
#   'DAL weight': 0.09223794232815792,
#   'NFLX weight': 0.04542325971248151,
#   'AAPL weight': 0.05063001956035647,
#   'PFE weight': 0.24457820117341067,
#   'BTC weight': 0.1166415536894859},
#  {'Returns': 60.83695865498612,
#   'Volatility': 0.22225844209403012,
#   'SHOP weight': 0.13235935970025314,
#   'TSLA weight': 0.12389405860374475,
#   'GOLD weight': 0.10911990514471265,
#   'DAL weight': 0.15432191375591595,
#   'NFLX weight': 0.10145141814771644,
#   'AAPL weight': 0.10754819103235697,
#   'PFE weight': 0.1520249976889811,
#   'BTC weight': 0.11928015592631891},
#  {'Returns': 72.2288518559891,
#   'Volatility': 0.28406995103164395,
#   'SHOP weight': 0.22551275513149707,
#   'TSLA weight': 0.20566993691808585,
#   'GOLD weight': 0.16609771267182985,
#   'DAL weight': 0.13472851032386243,
#   'NFLX weight': 0.03324623771001725,
#   'AAPL weight': 0.05503909015672424,
#   'PFE weight': 0.028343636625629907,
#   'BTC weight': 0.15136212046235345},
#  {'Returns': 84.21595462375802,
#   'Volatility': 0.23689795545617257,
#   'SHOP weight': 0.15142898830367738,
#   'TSLA weight': 0.07081828766531156,
#   'GOLD weight': 0.0782462838788191,
#   'DAL weight': 0.060870495894026544,
#   'NFLX weight': 0.040351876004501505,
#   'AAPL weight': 0.18504269876326684,
#   'PFE weight': 0.2172137686802782,
#   'BTC weight': 0.19602760081011897},
#  {'Returns': 32.69160555808948,
#   'Volatility': 0.18390883083624326,
#   'SHOP weight': 0.06808289810826777,
#   'TSLA weight': 0.005699958449173822,
#   'GOLD weight': 0.022449254800608737,
#   'DAL weight': 0.17040780171110012,
#   'NFLX weight': 0.14648020144155224,
#   'AAPL weight': 0.2834160190468775,
#   'PFE weight': 0.2764974672070558,
#   'BTC weight': 0.026966399235364008},
#  {'Returns': 21.02621294739418,
#   'Volatility': 0.28824507911484815,
#   'SHOP weight': 0.061882926458141335,
#   'TSLA weight': 0.24373828490225555,
#   'GOLD weight': 0.22869543827111152,
#   'DAL weight': 0.001178019235797024,
#   'NFLX weight': 0.2739318481419348,
#   'AAPL weight': 0.13733980659180312,
#   'PFE weight': 0.04045996038181758,
#   'BTC weight': 0.012773716017139145},
#  {'Returns': 69.2662664908981,
#   'Volatility': 0.22719845635068966,
#   'SHOP weight': 0.05029217162380316,
#   'TSLA weight': 0.12105719100929609,
#   'GOLD weight': 0.049427908184152505,
#   'DAL weight': 0.1725080051762192,
#   'NFLX weight': 0.16489211237614457,
#   'AAPL weight': 0.15742847814598604,
#   'PFE weight': 0.13554898845767482,
#   'BTC weight': 0.14884514502672375}]

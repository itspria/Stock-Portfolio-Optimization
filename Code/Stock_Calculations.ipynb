# %%
import json
import numpy as np
import math
from datetime import datetime
import pandas as pd 
import matplotlib.pyplot as plt
import pymongo

# %% [markdown]
# # SHOP Stock Calculations

# %%
with open('../Data/SHOP_prices.json') as json_file:
    SHOP_data = json.load(json_file)
    
#stock annual return
SHOP_ann_return=round((((SHOP_data[0]['adjclose']/SHOP_data[len(SHOP_data)-1]['adjclose'])-1)*100),2)

SHOP_price_array=[]
for i in range(len(SHOP_data)):
    SHOP_price_array.append(SHOP_data[i]['adjclose'])
    
#daily volatility
SHOP_daily_vol = round(np.std(SHOP_price_array),2)

#annualized volatility
SHOP_ann_vol = SHOP_daily_vol * math.sqrt(252)
SHOP_ann_vol = round(SHOP_ann_vol,2)

#3 mon return volatility
SHOP_date_array=[]

for y in range(len(SHOP_data)):
    SHOP_date_array.append(datetime.strptime(SHOP_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=SHOP_date_array[y]
    if ((firstdate-SHOP_date_array[y]).days==91):
        date_3mon_ago=SHOP_date_array[y]
        mon3_index = y
        
#last three month return
SHOP_3mon_return=round((((SHOP_data[0]['adjclose']/SHOP_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
SHOP_summ_stats = {
    "Ticker": "SHOP",
  "Annual Return": SHOP_ann_return,
  "Daily Volatility": SHOP_daily_vol,
  "Annualized Volatility": SHOP_ann_vol,
  "Last 3 Months Return":  SHOP_3mon_return
}

# convert into JSON:
SHOP_summ_stats = json.dumps(SHOP_summ_stats)

# the result is a JSON string:
print(SHOP_summ_stats)
# Out:
# {"Ticker": "SHOP", "Annual Return": 42.07, "Daily Volatility": 187.12, "Annualized Volatility": 2970.44, "Last 3 Months Return": 18.51}

# %% [markdown]
# # TSLA Stock Calculations

# %%
with open('../Data/TSLA_prices.json') as json_file:
    TSLA_data = json.load(json_file)
    
#stock annual return
TSLA_ann_return=round((((TSLA_data[0]['adjclose']/TSLA_data[len(TSLA_data)-1]['adjclose'])-1)*100),2)

TSLA_price_array=[]
for i in range(len(TSLA_data)):
    TSLA_price_array.append(TSLA_data[i]['adjclose'])
    
#daily volatility
TSLA_daily_vol = round(np.std(TSLA_price_array),2)

#annualized volatility
TSLA_ann_vol = TSLA_daily_vol * math.sqrt(252)
TSLA_ann_vol = round(TSLA_ann_vol,2)

#3 mon return volatility
TSLA_date_array=[]

for y in range(len(TSLA_data)):
    TSLA_date_array.append(datetime.strptime(TSLA_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=TSLA_date_array[y]
    if ((firstdate-TSLA_date_array[y]).days==91):
        date_3mon_ago=TSLA_date_array[y]
        mon3_index = y
        
#last three month return
TSLA_3mon_return=round((((TSLA_data[0]['adjclose']/TSLA_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
TSLA_summ_stats = {
    "Ticker": "TSLA",
  "Annual Return": TSLA_ann_return,
  "Daily Volatility": TSLA_daily_vol,
  "Annualized Volatility": TSLA_ann_vol,
  "Last 3 Months Return":  TSLA_3mon_return
}

# convert into JSON:
TSLA_summ_stats = json.dumps(TSLA_summ_stats)

# the result is a JSON string:
print(TSLA_summ_stats)
# Out:
# {"Ticker": "TSLA", "Annual Return": 65.92, "Daily Volatility": 134.14, "Annualized Volatility": 2129.41, "Last 3 Months Return": 17.11}

# %% [markdown]
# # GOLD Stock Calculations

# %%
with open('../Data/GOLD_prices.json') as json_file:
    GOLD_data = json.load(json_file)
    
#stock annual return
GOLD_ann_return=round((((GOLD_data[0]['adjclose']/GOLD_data[len(GOLD_data)-1]['adjclose'])-1)*100),2)

GOLD_price_array=[]
for i in range(len(GOLD_data)):
    GOLD_price_array.append(GOLD_data[i]['adjclose'])
    
#daily volatility
GOLD_daily_vol = round(np.std(GOLD_price_array),2)

#annualized volatility
GOLD_ann_vol = GOLD_daily_vol * math.sqrt(252)
GOLD_ann_vol = round(GOLD_ann_vol,2)

#3 mon return volatility
GOLD_date_array=[]

for y in range(len(GOLD_data)):
    GOLD_date_array.append(datetime.strptime(GOLD_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=GOLD_date_array[y]
    if ((firstdate-GOLD_date_array[y]).days==91):
        date_3mon_ago=GOLD_date_array[y]
        mon3_index = y
        
#last three month return
GOLD_3mon_return=round((((GOLD_data[0]['adjclose']/GOLD_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
GOLD_summ_stats = {
    "Ticker": "GOLD",
  "Annual Return": GOLD_ann_return,
  "Daily Volatility": GOLD_daily_vol,
  "Annualized Volatility": GOLD_ann_vol,
  "Last 3 Months Return":  GOLD_3mon_return
}

# convert into JSON:
GOLD_summ_stats = json.dumps(GOLD_summ_stats)

# the result is a JSON string:
print(GOLD_summ_stats)
# Out:
# {"Ticker": "GOLD", "Annual Return": -33.02, "Daily Volatility": 2.83, "Annualized Volatility": 44.92, "Last 3 Months Return": -21.41}

# %% [markdown]
# # DAL Stock Calculations

# %%
with open('../Data/DAL_prices.json') as json_file:
    DAL_data = json.load(json_file)
    
#stock annual return
DAL_ann_return=round((((DAL_data[0]['adjclose']/DAL_data[len(DAL_data)-1]['adjclose'])-1)*100),2)

DAL_price_array=[]
for i in range(len(DAL_data)):
    DAL_price_array.append(DAL_data[i]['adjclose'])
    
#daily volatility
DAL_daily_vol = round(np.std(DAL_price_array),2)

#annualized volatility
DAL_ann_vol = DAL_daily_vol * math.sqrt(252)
DAL_ann_vol = round(DAL_ann_vol,2)

#3 mon return volatility
DAL_date_array=[]

for y in range(len(DAL_data)):
    DAL_date_array.append(datetime.strptime(DAL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=DAL_date_array[y]
    if ((firstdate-DAL_date_array[y]).days==91):
        date_3mon_ago=DAL_date_array[y]
        mon3_index = y
        
#last three month return
DAL_3mon_return=round((((DAL_data[0]['adjclose']/DAL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
DAL_summ_stats = {
    "Ticker": "DAL",
  "Annual Return": DAL_ann_return,
  "Daily Volatility": DAL_daily_vol,
  "Annualized Volatility": DAL_ann_vol,
  "Last 3 Months Return":  DAL_3mon_return
}

# convert into JSON:
DAL_summ_stats = json.dumps(DAL_summ_stats)

# the result is a JSON string:
print(DAL_summ_stats)
# Out:
# {"Ticker": "DAL", "Annual Return": 39.79, "Daily Volatility": 6.0, "Annualized Volatility": 95.25, "Last 3 Months Return": -15.68}

# %% [markdown]
# # NFLX Stock Calculations

# %%
with open('../Data/NFLX_prices.json') as json_file:
    NFLX_data = json.load(json_file)
    
#stock annual return
NFLX_ann_return=round((((NFLX_data[0]['adjclose']/NFLX_data[len(NFLX_data)-1]['adjclose'])-1)*100),2)

NFLX_price_array=[]
for i in range(len(NFLX_data)):
    NFLX_price_array.append(NFLX_data[i]['adjclose'])
    
#daily volatility
NFLX_daily_vol = round(np.std(NFLX_price_array),2)

#annualized volatility
NFLX_ann_vol = NFLX_daily_vol * math.sqrt(252)
NFLX_ann_vol = round(NFLX_ann_vol,2)

#3 mon return volatility
NFLX_date_array=[]

for y in range(len(NFLX_data)):
    NFLX_date_array.append(datetime.strptime(NFLX_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=NFLX_date_array[y]
    if ((firstdate-NFLX_date_array[y]).days==91):
        date_3mon_ago=NFLX_date_array[y]
        mon3_index = y
        
#last three month return
NFLX_3mon_return=round((((NFLX_data[0]['adjclose']/NFLX_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
NFLX_summ_stats = {
    "Ticker": "NFLX",
  "Annual Return": NFLX_ann_return,
  "Daily Volatility": NFLX_daily_vol,
  "Annualized Volatility": NFLX_ann_vol,
  "Last 3 Months Return":  NFLX_3mon_return
}

# convert into JSON:
NFLX_summ_stats = json.dumps(NFLX_summ_stats)

# the result is a JSON string:
print(NFLX_summ_stats)
# Out:
# {"Ticker": "NFLX", "Annual Return": 11.08, "Daily Volatility": 23.71, "Annualized Volatility": 376.38, "Last 3 Months Return": 9.84}

# %% [markdown]
# # AAPL Stock Calculations

# %%
with open('../Data/AAPL_prices.json') as json_file:
    AAPL_data = json.load(json_file)
    
#stock annual return
AAPL_ann_return=round((((AAPL_data[0]['adjclose']/AAPL_data[len(AAPL_data)-1]['adjclose'])-1)*100),2)

AAPL_price_array=[]
for i in range(len(AAPL_data)):
    AAPL_price_array.append(AAPL_data[i]['adjclose'])
    
#daily volatility
AAPL_daily_vol = round(np.std(AAPL_price_array),2)

#annualized volatility
AAPL_ann_vol = AAPL_daily_vol * math.sqrt(252)
AAPL_ann_vol = round(AAPL_ann_vol,2)

#3 mon return volatility
AAPL_date_array=[]

for y in range(len(AAPL_data)):
    AAPL_date_array.append(datetime.strptime(AAPL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=AAPL_date_array[y]
    if ((firstdate-AAPL_date_array[y]).days==91):
        date_3mon_ago=AAPL_date_array[y]
        mon3_index = y
        
#last three month return
AAPL_3mon_return=round((((AAPL_data[0]['adjclose']/AAPL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
AAPL_summ_stats = {
    "Ticker": "AAPL",
  "Annual Return": AAPL_ann_return,
  "Daily Volatility": AAPL_daily_vol,
  "Annualized Volatility": AAPL_ann_vol,
  "Last 3 Months Return":  AAPL_3mon_return
}

# convert into JSON:
AAPL_summ_stats = json.dumps(AAPL_summ_stats)

# the result is a JSON string:
print(AAPL_summ_stats)
# Out:
# {"Ticker": "AAPL", "Annual Return": 19.91, "Daily Volatility": 10.44, "Annualized Volatility": 165.73, "Last 3 Months Return": 18.32}

# %% [markdown]
# # PFE Stock Calculations

# %%
with open('../Data/PFE_prices.json') as json_file:
    PFE_data = json.load(json_file)
    
#stock annual return
PFE_ann_return=round((((PFE_data[0]['adjclose']/PFE_data[len(PFE_data)-1]['adjclose'])-1)*100),2)

PFE_price_array=[]
for i in range(len(PFE_data)):
    PFE_price_array.append(PFE_data[i]['adjclose'])
    
#daily volatility
PFE_daily_vol = round(np.std(PFE_price_array),2)

#annualized volatility
PFE_ann_vol = PFE_daily_vol * math.sqrt(252)
PFE_ann_vol = round(PFE_ann_vol,2)

#3 mon return volatility
PFE_date_array=[]

for y in range(len(PFE_data)):
    PFE_date_array.append(datetime.strptime(PFE_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=PFE_date_array[y]
    if ((firstdate-PFE_date_array[y]).days==91):
        date_3mon_ago=PFE_date_array[y]
        mon3_index = y
        
#last three month return
PFE_3mon_return=round((((PFE_data[0]['adjclose']/PFE_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
PFE_summ_stats = {
    "Ticker": "PFE",
  "Annual Return": PFE_ann_return,
  "Daily Volatility": PFE_daily_vol,
  "Annualized Volatility": PFE_ann_vol,
  "Last 3 Months Return":  PFE_3mon_return
}

# convert into JSON:
PFE_summ_stats = json.dumps(PFE_summ_stats)

# the result is a JSON string:
print(PFE_summ_stats)
# Out:
# {"Ticker": "PFE", "Annual Return": 37.43, "Daily Volatility": 3.6, "Annualized Volatility": 57.15, "Last 3 Months Return": 23.06}

# %% [markdown]
# # BTC Stock Calculations

# %%
with open('../Data/BTC_prices.json') as json_file:
    BTC_data = json.load(json_file)
    
#stock annual return
BTC_ann_return=round((((BTC_data[0]['adjclose']/BTC_data[len(BTC_data)-1]['adjclose'])-1)*100),2)

BTC_price_array=[]
for i in range(len(BTC_data)):
    BTC_price_array.append(BTC_data[i]['adjclose'])
    
#daily volatility
BTC_daily_vol = round(np.std(BTC_price_array),2)

#annualized volatility
BTC_ann_vol = BTC_daily_vol * math.sqrt(252)
BTC_ann_vol = round(BTC_ann_vol,2)

#3 mon return volatility
BTC_date_array=[]

for y in range(len(BTC_data)):
    BTC_date_array.append(datetime.strptime(BTC_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=BTC_date_array[y]
    if ((firstdate-BTC_date_array[y]).days==91):
        date_3mon_ago=BTC_date_array[y]
        mon3_index = y
        
#last three month return
BTC_3mon_return=round((((BTC_data[0]['adjclose']/BTC_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
BTC_summ_stats = {
    "Ticker": "BTC",
  "Annual Return": BTC_ann_return,
  "Daily Volatility": BTC_daily_vol,
  "Annualized Volatility": BTC_ann_vol,
  "Last 3 Months Return":  BTC_3mon_return
}

# convert into JSON:
BTC_summ_stats = json.dumps(BTC_summ_stats)

# the result is a JSON string:
print(BTC_summ_stats)
# Out:
# {"Ticker": "BTC", "Annual Return": -0.39, "Daily Volatility": 0.47, "Annualized Volatility": 7.46, "Last 3 Months Return": 0.5}

# %% [markdown]
# # Creating a Dataframe of values

# %%
shop_df = pd.DataFrame(json.loads(SHOP_summ_stats), index=[0])
tsla_df = pd.DataFrame(json.loads(TSLA_summ_stats), index=[0])
gold_df = pd.DataFrame(json.loads(GOLD_summ_stats), index=[0])
dal_df = pd.DataFrame(json.loads(DAL_summ_stats), index=[0])
nflx_df = pd.DataFrame(json.loads(NFLX_summ_stats), index=[0])
aapl_df = pd.DataFrame(json.loads(AAPL_summ_stats), index=[0])
pfe_df = pd.DataFrame(json.loads(PFE_summ_stats), index=[0])
btc_df = pd.DataFrame(json.loads(BTC_summ_stats), index=[0])


stocks_calc = shop_df.append([tsla_df,gold_df,dal_df,nflx_df,aapl_df,pfe_df,btc_df])
stocks_calc.reset_index(inplace = True,drop = True)

stocks_calc
# Out:
#   Ticker  Annual Return  Daily Volatility  Annualized Volatility  \
# 0   SHOP          42.07            187.12                2970.44
# 1   TSLA          65.92            134.14                2129.41
# 2   GOLD         -33.02              2.83                  44.92
# 3    DAL          39.79              6.00                  95.25
# 4   NFLX          11.08             23.71                 376.38
# 5   AAPL          19.91             10.44                 165.73
# 6    PFE          37.43              3.60                  57.15
# 7    BTC          -0.39              0.47                   7.46
#
#    Last 3 Months Return
# 0                 18.51
# 1                 17.11
# 2                -21.41
# 3                -15.68
# 4                  9.84
# 5                 18.32
# 6                 23.06
# 7                  0.50

# %% [markdown]
# # Get daily returns and asssets covariance

# %%
#created dataframes for daily prices
SHOP_data_df = pd.DataFrame(SHOP_data)
SHOP_data_df = SHOP_data_df[["formatted_date", "adjclose"]]
SHOP_data_df.set_index("formatted_date", inplace = True)
SHOP_data_df = SHOP_data_df.rename (columns = {"adjclose": "SHOP"})

TSLA_data_df = pd.DataFrame(TSLA_data)
TSLA_data_df = TSLA_data_df[["formatted_date", "adjclose"]]
TSLA_data_df.set_index("formatted_date", inplace = True)
TSLA_data_df = TSLA_data_df.rename (columns = {"adjclose": "TSLA"})

GOLD_data_df = pd.DataFrame(GOLD_data)
GOLD_data_df = GOLD_data_df[["formatted_date", "adjclose"]]
GOLD_data_df.set_index("formatted_date", inplace = True)
GOLD_data_df = GOLD_data_df.rename (columns = {"adjclose": "GOLD"})

DAL_data_df = pd.DataFrame(DAL_data)
DAL_data_df = DAL_data_df[["formatted_date", "adjclose"]]
DAL_data_df.set_index("formatted_date", inplace = True)
DAL_data_df = DAL_data_df.rename (columns = {"adjclose": "DAL"})

NFLX_data_df = pd.DataFrame(NFLX_data)
NFLX_data_df = NFLX_data_df[["formatted_date", "adjclose"]]
NFLX_data_df.set_index("formatted_date", inplace = True)
NFLX_data_df = NFLX_data_df.rename (columns = {"adjclose": "NFLX"})

AAPL_data_df = pd.DataFrame(AAPL_data)
AAPL_data_df = AAPL_data_df[["formatted_date", "adjclose"]]
AAPL_data_df.set_index("formatted_date", inplace = True)
AAPL_data_df = AAPL_data_df.rename (columns = {"adjclose": "AAPL"})

PFE_data_df = pd.DataFrame(PFE_data)
PFE_data_df = PFE_data_df[["formatted_date", "adjclose"]]
PFE_data_df.set_index("formatted_date", inplace = True)
PFE_data_df = PFE_data_df.rename (columns = {"adjclose": "PFE"})

BTC_data_df = pd.DataFrame(BTC_data)
BTC_data_df = BTC_data_df[["formatted_date", "adjclose"]]
BTC_data_df.set_index("formatted_date", inplace = True)
BTC_data_df = BTC_data_df.rename (columns = {"adjclose": "BTC"})
#BTC_data_df

# %%
#merge assest into a single dataframe
assets_all = pd.concat([SHOP_data_df, TSLA_data_df,GOLD_data_df , DAL_data_df, NFLX_data_df, AAPL_data_df,PFE_data_df,BTC_data_df],axis=1, join="inner")
assets_all
# Out:
#                    SHOP    TSLA   GOLD    DAL    NFLX    AAPL    PFE     BTC
# formatted_date
# 2021-08-19      1466.11  673.47  19.13  37.93  543.71  146.70  48.80   99.61
# 2021-08-18      1489.18  688.99  19.46  38.65  521.87  146.36  49.31   99.55
# 2021-08-17      1481.87  665.71  19.97  38.78  518.91  150.19  50.42   99.60
# 2021-08-16      1489.00  686.17  20.19  39.93  517.92  151.12  48.91   99.65
# 2021-08-13      1498.00  717.17  20.27  39.90  515.92  149.10  48.48   99.58
# ...                 ...     ...    ...    ...     ...     ...    ...     ...
# 2020-10-07      1073.43  425.30  26.47  32.15  534.66  114.34  33.25   99.92
# 2020-10-06      1041.25  413.98  26.58  31.06  505.87  112.44  32.98  100.03
# 2020-10-05      1065.53  425.68  27.86  32.00  520.65  115.76  33.50  100.00
# 2020-10-02      1028.99  415.09  27.39  31.75  503.06  112.30  33.17  100.00
# 2020-10-01      1054.43  448.16  27.76  31.10  527.51  116.04  33.16  100.00
#
# [223 rows x 8 columns]

# %%
#calculate daily pricec changes
assets_all_pricechng = assets_all.pct_change()
#assets_all_pricechng

# %%
#calculate covariance
assets_all_cov = assets_all_pricechng.cov()
assets_all_cov
# Out:
#           SHOP      TSLA      GOLD       DAL      NFLX      AAPL  \
# SHOP  0.001044  0.000428  0.000132 -0.000113  0.000343  0.000245
# TSLA  0.000428  0.001229  0.000096  0.000143  0.000249  0.000263
# GOLD  0.000132  0.000096  0.000409  0.000015  0.000102  0.000101
# DAL  -0.000113  0.000143  0.000015  0.000634 -0.000046  0.000030
# NFLX  0.000343  0.000249  0.000102 -0.000046  0.000504  0.000189
# AAPL  0.000245  0.000263  0.000101  0.000030  0.000189  0.000327
# PFE  -0.000036 -0.000003  0.000026  0.000062 -0.000039  0.000026
# BTC   0.000009  0.000008  0.000003 -0.000005  0.000005  0.000004
#
#                PFE           BTC
# SHOP -3.579589e-05  9.423874e-06
# TSLA -2.910476e-06  7.966360e-06
# GOLD  2.627074e-05  3.028141e-06
# DAL   6.154588e-05 -4.739645e-06
# NFLX -3.868208e-05  5.046523e-06
# AAPL  2.644448e-05  4.075365e-06
# PFE   2.206190e-04 -1.272857e-07
# BTC  -1.272857e-07  9.158551e-07

# %%
# convert into JSON:
assets_all_json = assets_all_cov.to_json()
assets_all_json = json.dumps(assets_all_json)

# %% [markdown]
# # Calculate portfolio return and volatility

# %% [markdown]
# ref: https://www.machinelearningplus.com/machine-learning/portfolio-optimization-python-example/

# %%
portfolio_return = []
portfolio_volati = []
asset_weights = []

# %%
#calculate number of assest and max number of portfolios to itterate
num_assets = stocks_calc["Ticker"].count()
print(num_assets)
num_portf = 1000
# Out:
# 8

# %% [markdown]
# for portfolio in range(num_portf):
#     #portfolio returns
#     weights = np.random.random(num_assets)
#     weights = weights/np.sum(weights)
#     asset_weights.append(weights)
# asset_weights

# %% [markdown]
# len(asset_weights)

# %%
for portfolio in range(num_portf):
    #portfolio returns
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    asset_weights.append(weights)
    portf_return = np.dot(weights, stocks_calc["Annual Return"])
    portfolio_return.append(portf_return)
    
    #portfolio risk
    portf_var = assets_all_cov.mul(weights, axis=0).mul(weights, axis=1).sum().sum()
    portf_stdev = np.sqrt(portf_var) # Daily standard deviation
    portf_ann_stdev = portf_stdev*np.sqrt(250) # Annual standard deviation = volatility
    portfolio_volati.append(portf_ann_stdev)
    
    
#portfolio_return

# %%
print(len(portfolio_return), len(portfolio_volati), len(asset_weights))
# Out:
# 1000 1000 1000

# %% [markdown]
# #plot the graph
# plt.figure(figsize=(12,8))
# plt.scatter(portfolio_volati,portfolio_return, marker = "o",facecolors = 'green')
# plt.title(f"Efficient Frontier", fontsize = 13, fontweight = 'bold', y=1.05)
# plt.xlabel("Risk")
# plt.ylabel("Return")
# plt.grid()
# plt.ylim(-20,60)
# plt.xlim(0.05,0.4)
#
# plt.show()

# %%
data = {'Returns':portfolio_return, 'Volatility':portfolio_volati}

for counter, symbol in enumerate(assets_all.columns.tolist()):
    #print(counter, symbol)
    data[symbol+'_weight'] = [w[counter] for w in asset_weights]
    
portfolios  = pd.DataFrame(data)
portf = portfolios.to_dict(orient='records')
portf
portfolios
# Out:
#        Returns  Volatility  SHOP_weight  TSLA_weight  GOLD_weight  DAL_weight  \
# 0    31.468117    0.210886     0.182812     0.170065     0.104900    0.137842
# 1    27.417531    0.236722     0.295118     0.052067     0.052940    0.244015
# 2    27.175682    0.227707     0.239799     0.101597     0.119382    0.182066
# 3    22.684191    0.208507     0.021631     0.088054     0.035591    0.107801
# 4    22.230111    0.211719     0.028722     0.219685     0.208027    0.070978
# ..         ...         ...          ...          ...          ...         ...
# 995  25.645681    0.216341     0.157775     0.183975     0.169418    0.065050
# 996  23.211891    0.228615     0.119218     0.188547     0.181864    0.101640
# 997  29.000813    0.212553     0.054226     0.234300     0.004277    0.089830
# 998  31.457070    0.233081     0.230809     0.203287     0.019460    0.052106
# 999  31.300047    0.214722     0.256541     0.135729     0.013898    0.024183
#
#      NFLX_weight  AAPL_weight  PFE_weight  BTC_weight
# 0       0.095578     0.064116    0.219606    0.025081
# 1       0.234204     0.022155    0.016158    0.083342
# 2       0.072415     0.201415    0.061016    0.022311
# 3       0.404855     0.155743    0.141234    0.045091
# 4       0.142543     0.130339    0.171560    0.028146
# ..           ...          ...         ...         ...
# 995     0.129313     0.070641    0.188640    0.035188
# 996     0.058456     0.260105    0.051217    0.038953
# 997     0.003211     0.324896    0.038338    0.250922
# 998     0.044200     0.170900    0.082815    0.196423
# 999     0.047132     0.152807    0.201914    0.167797
#
# [1000 rows x 10 columns]

# %% [markdown]
# for index, row in portfolios.iterrows():
#     portf_dict = [row]
#     print(portf_dict)

# %%
portfolios.to_csv('../Data/data.csv', index = False)

# %%
# convert into JSON and save it as a separate file:
#portf = portfolios.to_json()
#port = json.dumps(port)
with open('../Data/portfolio_data.json', 'w') as outfile:
    json.dump(portf, outfile)

portf
# Out:
# [{'Returns': 31.46811696192129,
#   'Volatility': 0.21088610400766683,
#   'SHOP_weight': 0.1828121356774809,
#   'TSLA_weight': 0.17006484211042933,
#   'GOLD_weight': 0.10490045785145562,
#   'DAL_weight': 0.1378418677383161,
#   'NFLX_weight': 0.09557776447520513,
#   'AAPL_weight': 0.06411557930227399,
#   'PFE_weight': 0.21960619979676288,
#   'BTC_weight': 0.02508115304807616},
#  {'Returns': 27.41753078594588,
#   'Volatility': 0.2367219272942504,
#   'SHOP_weight': 0.29511807346598823,
#   'TSLA_weight': 0.05206671813654159,
#   'GOLD_weight': 0.05294041743510728,
#   'DAL_weight': 0.24401538862463132,
#   'NFLX_weight': 0.23420392254328118,
#   'AAPL_weight': 0.022155127197611087,
#   'PFE_weight': 0.0161584542367232,
#   'BTC_weight': 0.08334189836011614},
#  {'Returns': 27.17568223500958,
#   'Volatility': 0.22770655969016235,
#   'SHOP_weight': 0.23979861801509367,
#   'TSLA_weight': 0.1015969083160962,
#   'GOLD_weight': 0.11938163430016968,
#   'DAL_weight': 0.18206626150046346,
#   'NFLX_weight': 0.07241527090878316,
#   'AAPL_weight': 0.20141470505017625,
#   'PFE_weight': 0.06101588032606984,
#   'BTC_weight': 0.02231072158314785},
#  {'Returns': 22.684190676008832,
#   'Volatility': 0.20850678069860326,
#   'SHOP_weight': 0.021630805221455007,
#   'TSLA_weight': 0.08805445278676048,
#   'GOLD_weight': 0.035590712867934686,
#   'DAL_weight': 0.10780103426989647,
#   'NFLX_weight': 0.40485518938998455,
#   'AAPL_weight': 0.1557430624676464,
#   'PFE_weight': 0.14123379522833654,
#   'BTC_weight': 0.04509094776798579},
#  {'Returns': 22.23011083160053,
#   'Volatility': 0.21171895115097364,
#   'SHOP_weight': 0.028722078757204852,
#   'TSLA_weight': 0.21968523133376203,
#   'GOLD_weight': 0.20802663015935316,
#   'DAL_weight': 0.07097840839345182,
#   'NFLX_weight': 0.1425430526883878,
#   'AAPL_weight': 0.13033907436621114,
#   'PFE_weight': 0.17155970773952292,
#   'BTC_weight': 0.028145816562106327},
#  {'Returns': 29.144411700378058,
#   'Volatility': 0.1924042116566928,
#   'SHOP_weight': 0.13955841476956216,
#   'TSLA_weight': 0.1722898385527609,
#   'GOLD_weight': 0.024257443904710185,
#   'DAL_weight': 0.14913674988502948,
#   'NFLX_weight': 0.03645821871467403,
#   'AAPL_weight': 0.16868914981716104,
#   'PFE_weight': 0.08304765968041793,
#   'BTC_weight': 0.2265625246756843},
#  {'Returns': 25.810698298329555,
#   'Volatility': 0.17825618120449285,
#   'SHOP_weight': 0.1440892960717346,
#   'TSLA_weight': 0.04944170684456058,
#   'GOLD_weight': 0.011707579989385855,
#   'DAL_weight': 0.11370421183226866,
#   'NFLX_weight': 0.19922428965747202,
#   'AAPL_weight': 0.16499407097462915,
#   'PFE_weight': 0.18464008637593388,
#   'BTC_weight': 0.1321987582540152},
#  {'Returns': 24.308355954056257,
#   'Volatility': 0.18124370938442289,
#   'SHOP_weight': 0.061783139836313276,
#   'TSLA_weight': 0.13916467996666293,
#   'GOLD_weight': 0.09124682445643674,
#   'DAL_weight': 0.16609562787192095,
#   'NFLX_weight': 0.1424714951541112,
#   'AAPL_weight': 0.1463328279272096,
#   'PFE_weight': 0.12020071406125628,
#   'BTC_weight': 0.13270469072608906},
#  {'Returns': 29.91149052005826,
#   'Volatility': 0.24939272345959596,
#   'SHOP_weight': 0.22222220844686227,
#   'TSLA_weight': 0.20018022757558382,
#   'GOLD_weight': 0.13433090751986493,
#   'DAL_weight': 0.13480100937248707,
#   'NFLX_weight': 0.06394828837492761,
#   'AAPL_weight': 0.16915683921208022,
#   'PFE_weight': 0.06323445031698925,
#   'BTC_weight': 0.012126069181204839},
#  {'Returns': 26.567273564411515,
#   'Volatility': 0.18934716811623767,
#   'SHOP_weight': 0.011683150292628043,
#   'TSLA_weight': 0.13949505446710772,
#   'GOLD_weight': 0.05017305857339779,
#   'DAL_weight': 0.11110056430274395,
#   'NFLX_weight': 0.20956415416791646,
#   'AAPL_weight': 0.21835503869972994,
#   'PFE_weight': 0.1995797999716502,
#   'BTC_weight': 0.06004917952482587},
#  {'Returns': 28.18151012693125,
#   'Volatility': 0.20380382783955858,
#   'SHOP_weight': 0.09541742860522205,
#   'TSLA_weight': 0.20177018103377597,
#   'GOLD_weight': 0.08565682029979022,
#   'DAL_weight': 0.19115149352977973,
#   'NFLX_weight': 0.07767479198030312,
#   'AAPL_weight': 0.12510044059691214,
#   'PFE_weight': 0.07468936097906007,
#   'BTC_weight': 0.14853948297515682},
#  {'Returns': 26.49203577349651,
#   'Volatility': 0.14580938108856317,
#   'SHOP_weight': 0.11953627745625786,
#   'TSLA_weight': 0.06837766906396829,
#   'GOLD_weight': 0.01406696527566166,
#   'DAL_weight': 0.22080864390271834,
#   'NFLX_weight': 0.09931537285866375,
#   'AAPL_weight': 0.0033749400833180186,
#   'PFE_weight': 0.2023177512328254,
#   'BTC_weight': 0.2722023801265866},
#  {'Returns': 20.46282669007443,
#   'Volatility': 0.19721358062175143,
#   'SHOP_weight': 0.15699706471360156,
#   'TSLA_weight': 0.10087732395636147,
#   'GOLD_weight': 0.12735646484586294,
#   'DAL_weight': 0.1235897939389609,
#   'NFLX_weight': 0.14924500366639973,
#   'AAPL_weight': 0.15293043236049345,
#   'PFE_weight': 0.04947201293680639,
#   'BTC_weight': 0.13953190358151354},
#  {'Returns': 15.552088653723697,
#   'Volatility': 0.1573798528652975,
#   'SHOP_weight': 0.05775322654561196,
#   'TSLA_weight': 0.08060584431863363,
#   'GOLD_weight': 0.1903203231334157,
#   'DAL_weight': 0.17960232298648263,
#   'NFLX_weight': 0.11977301689838073,
#   'AAPL_weight': 0.07508170920244149,
#   'PFE_weight': 0.11212820527342439,
#   'BTC_weight': 0.1847353516416094},
#  {'Returns': 16.7783173745873,
#   'Volatility': 0.1769815760321266,
#   'SHOP_weight': 0.0038005588705309185,
#   'TSLA_weight': 0.17255879547103398,
#   'GOLD_weight': 0.1869301615178478,
#   'DAL_weight': 0.04176715027973085,
#   'NFLX_weight': 0.15838441964394437,
#   'AAPL_weight': 0.10663427058771538,
#   'PFE_weight': 0.15876663149395603,
#   'BTC_weight': 0.1711580121352406},
#  {'Returns': 35.069448708022925,
#   'Volatility': 0.2016320519698922,
#   'SHOP_weight': 0.18378670234221348,
#   'TSLA_weight': 0.15886018526875967,
#   'GOLD_weight': 0.003278544898848524,
#   'DAL_weight': 0.20105448622400235,
#   'NFLX_weight': 0.09486911698103447,
#   'AAPL_weight': 0.05421693693498024,
#   'PFE_weight': 0.1840746566212992,
#   'BTC_weight': 0.11985937072886196},
#  {'Returns': 15.519122634359018,
#   'Volatility': 0.21306887409073608,
#   'SHOP_weight': 0.18769369662910404,
#   'TSLA_weight': 0.11387930541502773,
#   'GOLD_weight': 0.2711875306529882,
#   'DAL_weight': 0.023810699851961676,
#   'NFLX_weight': 0.06722504393911143,
#   'AAPL_weight': 0.13580328770990133,
#   'PFE_weight': 0.12566284357692623,
#   'BTC_weight': 0.07473759222497942},
#  {'Returns': 26.2448576683602,
#   'Volatility': 0.14565554387930105,
#   'SHOP_weight': 0.06765520370857073,
#   'TSLA_weight': 0.05910884296713266,
#   'GOLD_weight': 0.005424818500050921,
#   'DAL_weight': 0.13073133056506892,
#   'NFLX_weight': 0.0492766074435886,
#   'AAPL_weight': 0.22244659237701644,
#   'PFE_weight': 0.25610969843110837,
#   'BTC_weight': 0.20924690600746332},
#  {'Returns': 31.633415836230398,
#   'Volatility': 0.24661019330953265,
#   'SHOP_weight': 0.1483463251758104,
#   'TSLA_weight': 0.2500803897864547,
#   'GOLD_weight': 0.07762652545934537,
#   'DAL_weight': 0.17768966121144011,
#   'NFLX_weight': 0.21332884113348827,
#   'AAPL_weight': 0.00978593153372295,
#   'PFE_weight': 0.04996422376659868,
#   'BTC_weight': 0.07317810193313946},
#  {'Returns': 14.526004080708859,
#   'Volatility': 0.15846386843915433,
#   'SHOP_weight': 0.02090243451192886,
#   'TSLA_weight': 0.11381283961231133,
#   'GOLD_weight': 0.22960673374391574,
#   'DAL_weight': 0.1565449101150325,
#   'NFLX_weight': 0.009790969454442964,
#   'AAPL_weight': 0.13405743755698948,
#   'PFE_weight': 0.1282385549506243,
#   'BTC_weight': 0.20704612005475487},
#  {'Returns': 24.781372107458626,
#   'Volatility': 0.20667648108527661,
#   'SHOP_weight': 0.16078242716828975,
#   'TSLA_weight': 0.1308787854818238,
#   'GOLD_weight': 0.11279844551658179,
#   'DAL_weight': 0.17656607585817663,
#   'NFLX_weight': 0.22916383641413923,
#   'AAPL_weight': 0.003001880655048471,
#   'PFE_weight': 0.09420198183104639,
#   'BTC_weight': 0.09260656707489394},
#  {'Returns': 25.630639415560164,
#   'Volatility': 0.2084204448785337,
#   'SHOP_weight': 0.1863199300808677,
#   'TSLA_weight': 0.14620299766740896,
#   'GOLD_weight': 0.1573775610229365,
#   'DAL_weight': 0.08248000331526036,
#   'NFLX_weight': 0.09973397717715098,
#   'AAPL_weight': 0.0909089423732656,
#   'PFE_weight': 0.19160648978246114,
#   'BTC_weight': 0.04537009858064876},
#  {'Returns': 23.769656377093476,
#   'Volatility': 0.1720514008015129,
#   'SHOP_weight': 0.03150993524238149,
#   'TSLA_weight': 0.049634381127001984,
#   'GOLD_weight': 0.086992112121457,
#   'DAL_weight': 0.28497458145413157,
#   'NFLX_weight': 0.08221442623047648,
#   'AAPL_weight': 0.20509025958626248,
#   'PFE_weight': 0.15368669781602057,
#   'BTC_weight': 0.1058976064222683},
#  {'Returns': 21.97149897498944,
#   'Volatility': 0.2052087846817996,
#   'SHOP_weight': 0.11762799609833106,
#   'TSLA_weight': 0.19043511404864596,
#   'GOLD_weight': 0.13453930359332378,
#   'DAL_weight': 0.03671999132983498,
#   'NFLX_weight': 0.13062294791410986,
#   'AAPL_weight': 0.12199808205805081,
#   'PFE_weight': 0.09727826003047872,
#   'BTC_weight': 0.17077830492722476},
#  {'Returns': 14.585650282502169,
#   'Volatility': 0.1740267847594125,
#   'SHOP_weight': 0.2163022742868212,
#   'TSLA_weight': 0.00524662837120045,
#   'GOLD_weight': 0.1620078339348537,
#   'DAL_weight': 0.12264897728773527,
#   'NFLX_weight': 0.08610821721344362,
#   'AAPL_weight': 0.11586376910963968,
#   'PFE_weight': 0.06510142090160306,
#   'BTC_weight': 0.2267208788947031},
#  {'Returns': 22.25690155525062,
#   'Volatility': 0.2173853300792471,
#   'SHOP_weight': 0.08280039825278164,
#   'TSLA_weight': 0.1401358422536619,
#   'GOLD_weight': 0.05584936583453835,
#   'DAL_weight': 0.05472578077103483,
#   'NFLX_weight': 0.2524087652420877,
#   'AAPL_weight': 0.24277440265834757,
#   'PFE_weight': 0.043332177950999445,
#   'BTC_weight': 0.12797326703654852},
#  {'Returns': 26.851087471505313,
#   'Volatility': 0.1814580364477333,
#   'SHOP_weight': 0.086252671937772,
#   'TSLA_weight': 0.13590202417054242,
#   'GOLD_weight': 0.11185222600658101,
#   'DAL_weight': 0.20082326414639143,
#   'NFLX_weight': 0.15431833163213843,
#   'AAPL_weight': 0.026377261824179394,
#   'PFE_weight': 0.20735868589688278,
#   'BTC_weight': 0.07711553438551248},
#  {'Returns': 26.39100834720113,
#   'Volatility': 0.2017094400714251,
#   'SHOP_weight': 0.16921808218699072,
#   'TSLA_weight': 0.15324328902666332,
#   'GOLD_weight': 0.17803586546780092,
#   'DAL_weight': 0.09054410324833957,
#   'NFLX_weight': 0.012249129261402938,
#   'AAPL_weight': 0.12376709628057682,
#   'PFE_weight': 0.23671932143721625,
#   'BTC_weight': 0.03622311309100954},
#  {'Returns': 19.658862310768193,
#   'Volatility': 0.15237560698980385,
#   'SHOP_weight': 0.09012097568292901,
#   'TSLA_weight': 0.040613099570998845,
#   'GOLD_weight': 0.11336846400374724,
#   'DAL_weight': 0.154870101797006,
#   'NFLX_weight': 0.09618438261205779,
#   'AAPL_weight': 0.1694030730344301,
#   'PFE_weight': 0.17090655975138638,
#   'BTC_weight': 0.16453334354744456},
#  {'Returns': 28.766975962417398,
#   'Volatility': 0.21542136134906012,
#   'SHOP_weight': 0.04337983156315222,
#   'TSLA_weight': 0.22630544490714463,
#   'GOLD_weight': 0.021238711717298707,
#   'DAL_weight': 0.015055567053975392,
#   'NFLX_weight': 0.20115860066857189,
#   'AAPL_weight': 0.19167919504117292,
#   'PFE_weight': 0.16389381101416148,
#   'BTC_weight': 0.13728883803452263},
#  {'Returns': 23.60506956557927,
#   'Volatility': 0.252600857055758,
#   'SHOP_weight': 0.12065741727187271,
#   'TSLA_weight': 0.2785139949266843,
#   'GOLD_weight': 0.23999696608615467,
#   'DAL_weight': 0.0689903652412157,
#   'NFLX_weight': 0.019300863667315142,
#   'AAPL_weight': 0.1784742505793342,
#   'PFE_weight': 0.04279091907989721,
#   'BTC_weight': 0.051275223147526035},
#  {'Returns': 14.827253882665442,
#   'Volatility': 0.16250137452013397,
#   'SHOP_weight': 6.506774186620508e-05,
#   'TSLA_weight': 0.11591564421250973,
#   'GOLD_weight': 0.17597265760450018,
#   'DAL_weight': 0.10695394714357273,
#   'NFLX_weight': 0.2067858881991736,
#   'AAPL_weight': 0.07850025470062745,
#   'PFE_weight': 0.13239856298130914,
#   'BTC_weight': 0.1834079774164409},
#  {'Returns': 28.56533313893714,
#   'Volatility': 0.17061669297804308,
#   'SHOP_weight': 0.10111447538044427,
#   'TSLA_weight': 0.13727798704082908,
#   'GOLD_weight': 0.009742653991672423,
#   'DAL_weight': 0.09421801831984195,
#   'NFLX_weight': 0.18064143362033885,
#   'AAPL_weight': 0.05163103615295718,
#   'PFE_weight': 0.23720953833243807,
#   'BTC_weight': 0.18816485716147818},
#  {'Returns': 21.083105841352094,
#   'Volatility': 0.1757554191309171,
#   'SHOP_weight': 0.010032063378901857,
#   'TSLA_weight': 0.16707981494231625,
#   'GOLD_weight': 0.1188564562587901,
#   'DAL_weight': 0.045045311185533864,
#   'NFLX_weight': 0.22978622202781995,
#   'AAPL_weight': 0.05292844275453307,
#   'PFE_weight': 0.22015737998869347,
#   'BTC_weight': 0.15611430946341145},
#  {'Returns': 27.57813915251572,
#   'Volatility': 0.24238568552440476,
#   'SHOP_weight': 0.23738873634651628,
#   'TSLA_weight': 0.21906797247108264,
#   'GOLD_weight': 0.12605957989881408,
#   'DAL_weight': 0.032972460834084706,
#   'NFLX_weight': 0.10662925924087933,
#   'AAPL_weight': 0.039260108701683984,
#   'PFE_weight': 0.10921969747046176,
#   'BTC_weight': 0.12940218503647719},
#  {'Returns': 16.39891388141388,
#   'Volatility': 0.17157292439285676,
#   'SHOP_weight': 0.013570480285495174,
#   'TSLA_weight': 0.07606730447306448,
#   'GOLD_weight': 0.17746920443564632,
#   'DAL_weight': 0.15873095381623126,
#   'NFLX_weight': 0.17025705755812778,
#   'AAPL_weight': 0.18527788832317546,
#   'PFE_weight': 0.12870727557190983,
#   'BTC_weight': 0.08991983553634977},
#  {'Returns': 27.37071595610656,
#   'Volatility': 0.20317000934508395,
#   'SHOP_weight': 0.17023298405634055,
#   'TSLA_weight': 0.13518206518768142,
#   'GOLD_weight': 0.09739514964487263,
#   'DAL_weight': 0.1061753861756536,
#   'NFLX_weight': 0.06067858534585186,
#   'AAPL_weight': 0.19902307789458007,
#   'PFE_weight': 0.15188856614692559,
#   'BTC_weight': 0.07942418554809434},
#  {'Returns': 16.54849277144214,
#   'Volatility': 0.14737515789420547,
#   'SHOP_weight': 0.0676231742549863,
#   'TSLA_weight': 0.0031618678297662276,
#   'GOLD_weight': 0.08272269098146301,
#   'DAL_weight': 0.09804270260113072,
#   'NFLX_weight': 0.19100616240599777,
#   'AAPL_weight': 0.18286894846075727,
#   'PFE_weight': 0.17753449541103025,
#   'BTC_weight': 0.1970399580548684},
#  {'Returns': 20.984883096469332,
#   'Volatility': 0.19814304550883677,
#   'SHOP_weight': 0.2152757361266042,
#   'TSLA_weight': 0.09881754533733039,
#   'GOLD_weight': 0.18855959165197525,
#   'DAL_weight': 0.13819160561649516,
#   'NFLX_weight': 0.04088682663391846,
#   'AAPL_weight': 0.10019649381771406,
#   'PFE_weight': 0.09991760828021878,
#   'BTC_weight': 0.11815459253574362},
#  {'Returns': 32.07454377906517,
#   'Volatility': 0.1969845639937219,
#   'SHOP_weight': 0.07285953307970511,
#   'TSLA_weight': 0.1942839005787689,
#   'GOLD_weight': 0.04631174097136381,
#   'DAL_weight': 0.20203752020536336,
#   'NFLX_weight': 0.058367160481429495,
#   'AAPL_weight': 0.14521552209647162,
#   'PFE_weight': 0.16562402627938816,
#   'BTC_weight': 0.11530059630750936},
#  {'Returns': 23.77218490214632,
#   'Volatility': 0.17307681005626976,
#   'SHOP_weight': 0.1341972852376104,
#   'TSLA_weight': 0.08102499493863985,
#   'GOLD_weight': 0.05443402752704423,
#   'DAL_weight': 0.124110100361363,
#   'NFLX_weight': 0.1594809059033514,
#   'AAPL_weight': 0.1338876590493443,
#   'PFE_weight': 0.1410278628464023,
#   'BTC_weight': 0.17183716413624456},
#  {'Returns': 21.062431733411188,
#   'Volatility': 0.18532868393207397,
#   'SHOP_weight': 0.21154615922813244,
#   'TSLA_weight': 0.029761349789076522,
#   'GOLD_weight': 0.14236591232607823,
#   'DAL_weight': 0.10993677847557037,
#   'NFLX_weight': 0.15861004579903218,
#   'AAPL_weight': 0.05643196810075302,
#   'PFE_weight': 0.2051829849381901,
#   'BTC_weight': 0.08616480134316715},
#  {'Returns': 23.916089296909895,
#   'Volatility': 0.1577618518570623,
#   'SHOP_weight': 0.055561389079945935,
#   'TSLA_weight': 0.024717823298830516,
#   'GOLD_weight': 0.025657349593766723,
#   'DAL_weight': 0.19641161580498254,
#   'NFLX_weight': 0.2133362581140538,
#   'AAPL_weight': 0.1435649067219515,
#   'PFE_weight': 0.2086716012904955,
#   'BTC_weight': 0.13207905609597342},
#  {'Returns': 22.868924255151974,
#   'Volatility': 0.18820202943328943,
#   'SHOP_weight': 0.08996768469798294,
#   'TSLA_weight': 0.16223188368242725,
#   'GOLD_weight': 0.16051623075594965,
#   'DAL_weight': 0.11012901157602438,
#   'NFLX_weight': 0.1388012795495118,
#   'AAPL_weight': 0.0693556777271148,
#   'PFE_weight': 0.17170783040831597,
#   'BTC_weight': 0.09729040160267327},
#  {'Returns': 25.136574925461055,
#   'Volatility': 0.20995555200017793,
#   'SHOP_weight': 0.09773435262968097,
#   'TSLA_weight': 0.2075017929928481,
#   'GOLD_weight': 0.1633344326403061,
#   'DAL_weight': 0.16728502977381343,
#   'NFLX_weight': 0.00348752771980256,
#   'AAPL_weight': 0.17443704146341976,
#   'PFE_weight': 0.06991926429235465,
#   'BTC_weight': 0.11630055848777449},
#  {'Returns': 18.877132073916847,
#   'Volatility': 0.19640515336775524,
#   'SHOP_weight': 0.12453780758928788,
#   'TSLA_weight': 0.18937676831083905,
#   'GOLD_weight': 0.23187170635114232,
#   'DAL_weight': 0.08758040275486663,
#   'NFLX_weight': 0.07653263033729336,
#   'AAPL_weight': 0.013891077850261037,
#   'PFE_weight': 0.11393067959286424,
#   'BTC_weight': 0.16227892721344547},
#  {'Returns': 19.105904179371386,
#   'Volatility': 0.17769079672254298,
#   'SHOP_weight': 0.07140996152968838,
#   'TSLA_weight': 0.07656995737056753,
#   'GOLD_weight': 0.19064503306259842,
#   'DAL_weight': 0.1938261905836114,
#   'NFLX_weight': 0.19874139272893018,
#   'AAPL_weight': 0.050267270651322166,
#   'PFE_weight': 0.17237718302323893,
#   'BTC_weight': 0.046163011050042925},
#  {'Returns': 26.745559776517823,
#   'Volatility': 0.24381318087482418,
#   'SHOP_weight': 0.2084688204708421,
#   'TSLA_weight': 0.16751819393529147,
#   'GOLD_weight': 0.0064957883373053344,
#   'DAL_weight': 0.016947385397186255,
#   'NFLX_weight': 0.20173177977291423,
#   'AAPL_weight': 0.181078046368489,
#   'PFE_weight': 0.018961025710956255,
#   'BTC_weight': 0.1987989600070153},
#  {'Returns': 29.499040553598046,
#   'Volatility': 0.20797549057722112,
#   'SHOP_weight': 6.8014403722722e-05,
#   'TSLA_weight': 0.22935844228153426,
#   'GOLD_weight': 0.08292556371700151,
#   'DAL_weight': 0.16722002143542467,
#   'NFLX_weight': 0.00755263938677922,
#   'AAPL_weight': 0.26234418359016604,
#   'PFE_weight': 0.1388720078395323,
#   'BTC_weight': 0.1116591273458392},
#  {'Returns': 24.05299419475725,
#   'Volatility': 0.23936010621250758,
#   'SHOP_weight': 0.1225991493102162,
#   'TSLA_weight': 0.2445768482736842,
#   'GOLD_weight': 0.20444405458745785,
#   'DAL_weight': 0.06751914728973281,
#   'NFLX_weight': 0.07690410091120665,
#   'AAPL_weight': 0.1607779888146536,
#   'PFE_weight': 0.07487441720559877,
#   'BTC_weight': 0.04830429360744981},
#  {'Returns': 20.842044039872746,
#   'Volatility': 0.1636289001715743,
#   'SHOP_weight': 0.10548539138106751,
#   'TSLA_weight': 0.05500122987411665,
#   'GOLD_weight': 0.07585549674500455,
#   'DAL_weight': 0.1840001429684558,
#   'NFLX_weight': 0.1281014636320295,
#   'AAPL_weight': 0.17142025998577332,
#   'PFE_weight': 0.08563952452740116,
#   'BTC_weight': 0.19449649088615142},
#  {'Returns': 20.595485153515387,
#   'Volatility': 0.16300342072994228,
#   'SHOP_weight': 0.05990821698188048,
#   'TSLA_weight': 0.08623989578370576,
#   'GOLD_weight': 0.014363698491249377,
#   'DAL_weight': 0.21372078396472496,
#   'NFLX_weight': 0.1961079571845804,
#   'AAPL_weight': 0.1148715219338303,
#   'PFE_weight': 0.000617424350876253,
#   'BTC_weight': 0.31417050130915253},
#  {'Returns': 13.419470941160359,
#   'Volatility': 0.14673269830217456,
#   'SHOP_weight': 0.07785526544110685,
#   'TSLA_weight': 0.026934903964941588,
#   'GOLD_weight': 0.22431323206823836,
#   'DAL_weight': 0.08783112285385705,
#   'NFLX_weight': 0.1032808340277465,
#   'AAPL_weight': 0.06540067887468455,
#   'PFE_weight': 0.2642967791454251,
#   'BTC_weight': 0.15008718362399992},
#  {'Returns': 21.15395866743995,
#   'Volatility': 0.18272115132587263,
#   'SHOP_weight': 0.03938398274246969,
#   'TSLA_weight': 0.17111842195131888,
#   'GOLD_weight': 0.1269448977717695,
#   'DAL_weight': 0.1825267739748567,
#   'NFLX_weight': 0.13737165164829876,
#   'AAPL_weight': 0.08904704268396225,
#   'PFE_weight': 0.05155554272066121,
#   'BTC_weight': 0.20205168650666294},
#  {'Returns': 20.61989020031199,
#   'Volatility': 0.18430655815470504,
#   'SHOP_weight': 0.14909172381023872,
#   'TSLA_weight': 0.10120416154213599,
#   'GOLD_weight': 0.21606841529141066,
#   'DAL_weight': 0.15030623253320266,
#   'NFLX_weight': 0.04164666906005261,
#   'AAPL_weight': 0.0959551796975554,
#   'PFE_weight': 0.17329556269872248,
#   'BTC_weight': 0.07243205536668128},
#  {'Returns': 24.676971484264932,
#   'Volatility': 0.26322390129567397,
#   'SHOP_weight': 0.278555557019436,
#   'TSLA_weight': 0.20581913918359016,
#   'GOLD_weight': 0.21148627115619797,
#   'DAL_weight': 0.01205316454520113,
#   'NFLX_weight': 0.10772371809829459,
#   'AAPL_weight': 0.02689283751887126,
#   'PFE_weight': 0.1117562306223122,
#   'BTC_weight': 0.045713081856096675},
#  {'Returns': 33.18416543390052,
#   'Volatility': 0.2151682951189543,
#   'SHOP_weight': 0.11663710594435071,
#   'TSLA_weight': 0.19617063929057732,
#   'GOLD_weight': 0.02894406488829792,
#   'DAL_weight': 0.12412833175218682,
#   'NFLX_weight': 0.1043155574591729,
#   'AAPL_weight': 0.20274311263980732,
#   'PFE_weight': 0.16548023958230287,
#   'BTC_weight': 0.06158094844330402},
#  {'Returns': 23.433254685779296,
#   'Volatility': 0.16724939453599377,
#   'SHOP_weight': 0.0398690710861235,
#   'TSLA_weight': 0.13137335558467836,
#   'GOLD_weight': 0.08400049318605239,
#   'DAL_weight': 0.22208196896944463,
#   'NFLX_weight': 0.03801199102521763,
#   'AAPL_weight': 0.1638567841399906,
#   'PFE_weight': 0.09186776951374981,
#   'BTC_weight': 0.228938566494743},
#  {'Returns': 34.4375548659381,
#   'Volatility': 0.22389380555132787,
#   'SHOP_weight': 0.16178679672201923,
#   'TSLA_weight': 0.19551957469492104,
#   'GOLD_weight': 0.03518494677233942,
#   'DAL_weight': 0.14454815956013603,
#   'NFLX_weight': 0.18927147483563808,
#   'AAPL_weight': 0.05660976496405132,
#   'PFE_weight': 0.1854363351671365,
#   'BTC_weight': 0.03164294728375844},
#  {'Returns': 23.220473921248665,
#   'Volatility': 0.19164966185560584,
#   'SHOP_weight': 0.13084842857252954,
#   'TSLA_weight': 0.12803126726754283,
#   'GOLD_weight': 0.09735493467393667,
#   'DAL_weight': 0.1817695781225079,
#   'NFLX_weight': 0.10876774579233116,
#   'AAPL_weight': 0.14854910933875476,
#   'PFE_weight': 0.031067509708665366,
#   'BTC_weight': 0.1736114265237316},
#  {'Returns': 26.166791707706373,
#   'Volatility': 0.19174104381713108,
#   'SHOP_weight': 0.1776345008616244,
#   'TSLA_weight': 0.025896401090564205,
#   'GOLD_weight': 0.025822405361749366,
#   'DAL_weight': 0.008155346073328852,
#   'NFLX_weight': 0.18223440364954094,
#   'AAPL_weight': 0.20224432336368542,
#   'PFE_weight': 0.30714847573746606,
#   'BTC_weight': 0.07086414386204085},
#  {'Returns': 24.900072370404736,
#   'Volatility': 0.1717839859692044,
#   'SHOP_weight': 0.10660975829645153,
#   'TSLA_weight': 0.17295422944473146,
#   'GOLD_weight': 0.09549214871945569,
#   'DAL_weight': 0.05803564042792409,
#   'NFLX_weight': 0.030037195970742094,
#   'AAPL_weight': 0.10831410160819688,
#   'PFE_weight': 0.1992480422672739,
#   'BTC_weight': 0.22930888326522428},
#  {'Returns': 17.645812032244205,
#   'Volatility': 0.21546285094058773,
#   'SHOP_weight': 0.07904018363989425,
#   'TSLA_weight': 0.18791813267144816,
#   'GOLD_weight': 0.24065765307869186,
#   'DAL_weight': 0.023017119201288093,
#   'NFLX_weight': 0.20671630765757504,
#   'AAPL_weight': 0.06287268375367273,
#   'PFE_weight': 0.14540968532174994,
#   'BTC_weight': 0.0543682346756799},
#  {'Returns': 17.16885817207339,
#   'Volatility': 0.1569402674173717,
#   'SHOP_weight': 0.1367369196093223,
#   'TSLA_weight': 0.04240973891412687,
#   'GOLD_weight': 0.18173877331712887,
#   'DAL_weight': 0.1456626209822005,
#   'NFLX_weight': 0.05309073193642564,
#   'AAPL_weight': 0.10571663609067455,
#   'PFE_weight': 0.1656063572815287,
#   'BTC_weight': 0.16903822186859266},
#  {'Returns': 33.95574904387977,
#   'Volatility': 0.24705313426382394,
#   'SHOP_weight': 0.22737618681348223,
#   'TSLA_weight': 0.20576445022351453,
#   'GOLD_weight': 0.04721676140475841,
#   'DAL_weight': 0.10781293642642976,
#   'NFLX_weight': 0.01737528156971315,
#   'AAPL_weight': 0.23874226661167036,
#   'PFE_weight': 0.0848786912919055,
#   'BTC_weight': 0.07083342565852604},
#  {'Returns': 14.813282587790901,
#   'Volatility': 0.16687694825501442,
#   'SHOP_weight': 0.07601739438917784,
#   'TSLA_weight': 0.08124604728870326,
#   'GOLD_weight': 0.23920251120244562,
#   'DAL_weight': 0.12647841702225593,
#   'NFLX_weight': 0.047613887271765375,
#   'AAPL_weight': 0.15371263134204266,
#   'PFE_weight': 0.14925796054054577,
#   'BTC_weight': 0.12647115094306352},
#  {'Returns': 25.489323786022545,
#   'Volatility': 0.18631469888901514,
#   'SHOP_weight': 0.1027000377150949,
#   'TSLA_weight': 0.13931300529977234,
#   'GOLD_weight': 0.09969339320339206,
#   'DAL_weight': 0.23283121536350979,
#   'NFLX_weight': 0.16536133030513975,
#   'AAPL_weight': 0.008649739361922123,
#   'PFE_weight': 0.10857715025080901,
#   'BTC_weight': 0.14287412850036002},
#  {'Returns': 21.16846537392729,
#   'Volatility': 0.1696171737565419,
#   'SHOP_weight': 0.020768715904529694,
#   'TSLA_weight': 0.12325596263349874,
#   'GOLD_weight': 0.10151567380036781,
#   'DAL_weight': 0.17280441097546329,
#   'NFLX_weight': 0.13815942546707136,
#   'AAPL_weight': 0.16780325880280605,
#   'PFE_weight': 0.10263361326550172,
#   'BTC_weight': 0.1730589391507613},
#  {'Returns': 25.26832226858435,
#   'Volatility': 0.20149646616981862,
#   'SHOP_weight': 0.14784370689886744,
#   'TSLA_weight': 0.15306673483636746,
#   'GOLD_weight': 0.0800058744150706,
#   'DAL_weight': 0.009063088646376555,
#   'NFLX_weight': 0.07204948591136162,
#   'AAPL_weight': 0.22114614560774043,
#   'PFE_weight': 0.16292400073428892,
#   'BTC_weight': 0.1539009629499271},
#  {'Returns': 20.757520895874407,
#   'Volatility': 0.21021810157605245,
#   'SHOP_weight': 0.08323046592412409,
#   'TSLA_weight': 0.1814714844111832,
#   'GOLD_weight': 0.10940245641905191,
#   'DAL_weight': 0.050820896666091915,
#   'NFLX_weight': 0.18931105377742927,
#   'AAPL_weight': 0.17429538210320816,
#   'PFE_weight': 0.036975295156488355,
#   'BTC_weight': 0.17449296554242308},
#  {'Returns': 22.180536908742685,
#   'Volatility': 0.21612688026999546,
#   'SHOP_weight': 0.11467302071732915,
#   'TSLA_weight': 0.14051856425833645,
#   'GOLD_weight': 0.17669539191574488,
#   'DAL_weight': 0.1481152607975825,
#   'NFLX_weight': 0.20438377864762197,
#   'AAPL_weight': 0.12562452784060277,
#   'PFE_weight': 0.08734992216356499,
#   'BTC_weight': 0.0026395336592174197},
#  {'Returns': 22.78114705764399,
#   'Volatility': 0.15980072158421743,
#   'SHOP_weight': 0.03263981209484968,
#   'TSLA_weight': 0.07692832748409414,
#   'GOLD_weight': 0.010010888039897047,
#   'DAL_weight': 0.13647499783821748,
#   'NFLX_weight': 0.22835398178124003,
#   'AAPL_weight': 0.16122131066491635,
#   'PFE_weight': 0.14900106627974685,
#   'BTC_weight': 0.20536961581703836},
#  {'Returns': 21.555390990911004,
#   'Volatility': 0.22816531693362255,
#   'SHOP_weight': 0.2192540046911138,
#   'TSLA_weight': 0.12394585208216147,
#   'GOLD_weight': 0.13839850698299383,
#   'DAL_weight': 0.02415180179223282,
#   'NFLX_weight': 0.09874882092238388,
#   'AAPL_weight': 0.21437305959587918,
#   'PFE_weight': 0.06552401642584002,
#   'BTC_weight': 0.11560393750739512},
#  {'Returns': 22.810389129808716,
#   'Volatility': 0.19125976504717163,
#   'SHOP_weight': 0.17785385849702026,
#   'TSLA_weight': 0.14648311445779738,
#   'GOLD_weight': 0.16379355787439165,
#   'DAL_weight': 0.17518939196030045,
#   'NFLX_weight': 0.0469437874415515,
#   'AAPL_weight': 0.024715602907954742,
#   'PFE_weight': 0.08463038132784619,
#   'BTC_weight': 0.18039030553313787},
#  {'Returns': 25.654459349775987,
#   'Volatility': 0.22594939659406116,
#   'SHOP_weight': 0.23150937873842373,
#   'TSLA_weight': 0.14198376995189413,
#   'GOLD_weight': 0.035617726947673116,
#   'DAL_weight': 0.04111051791084889,
#   'NFLX_weight': 0.10367289509993449,
#   'AAPL_weight': 0.19733425459016019,
#   'PFE_weight': 0.02948174745374361,
#   'BTC_weight': 0.21928970930732183},
#  {'Returns': 32.92263293526401,
#   'Volatility': 0.275168498601576,
#   'SHOP_weight': 0.3012700832773035,
#   'TSLA_weight': 0.2194341471675376,
#   'GOLD_weight': 0.09319514461111011,
#   'DAL_weight': 0.08523480764411283,
#   'NFLX_weight': 0.13794002896415736,
#   'AAPL_weight': 0.05001278851612197,
#   'PFE_weight': 0.07902745000143298,
#   'BTC_weight': 0.033885549818223566},
#  {'Returns': 26.538647141506605,
#   'Volatility': 0.19358774234498544,
#   'SHOP_weight': 0.12201929743681983,
#   'TSLA_weight': 0.14570454810536881,
#   'GOLD_weight': 0.0687149893235372,
#   'DAL_weight': 0.0995808135200645,
#   'NFLX_weight': 0.14422048287489964,
#   'AAPL_weight': 0.15079253542136278,
#   'PFE_weight': 0.14838061327959523,
#   'BTC_weight': 0.1205867200383521},
#  {'Returns': 14.35156558675902,
#   'Volatility': 0.17548807715159764,
#   'SHOP_weight': 0.17625595687952744,
#   'TSLA_weight': 0.021914893933593898,
#   'GOLD_weight': 0.18477780408578162,
#   'DAL_weight': 0.07352310987691128,
#   'NFLX_weight': 0.03184887581719417,
#   'AAPL_weight': 0.22720995117484624,
#   'PFE_weight': 0.10317381329745737,
#   'BTC_weight': 0.18129559493468805},
#  {'Returns': 26.20377941135432,
#   'Volatility': 0.20065483942248336,
#   'SHOP_weight': 0.1318377068907734,
#   'TSLA_weight': 0.15448837951204197,
#   'GOLD_weight': 0.08561802793253116,
#   'DAL_weight': 0.09602690096977823,
#   'NFLX_weight': 0.1297745963237095,
#   'AAPL_weight': 0.1613694572276667,
#   'PFE_weight': 0.13016569804988892,
#   'BTC_weight': 0.11071923309361013},
#  {'Returns': 24.519463679999618,
#   'Volatility': 0.16420373882257802,
#   'SHOP_weight': 0.10051798857662649,
#   'TSLA_weight': 0.08266690585182247,
#   'GOLD_weight': 0.025402245135676214,
#   'DAL_weight': 0.21502701641126398,
#   'NFLX_weight': 0.13434844228749748,
#   'AAPL_weight': 0.1230291710675664,
#   'PFE_weight': 0.08753168407363947,
#   'BTC_weight': 0.23147654659590747},
#  {'Returns': 36.4060227501537,
#   'Volatility': 0.256429895914476,
#   'SHOP_weight': 0.21973267163802318,
#   'TSLA_weight': 0.2106005820746878,
#   'GOLD_weight': 0.023973223891432714,
#   'DAL_weight': 0.1301843853091081,
#   'NFLX_weight': 0.10519500792913589,
#   'AAPL_weight': 0.20559661869424187,
#   'PFE_weight': 0.09710440265594593,
#   'BTC_weight': 0.007613107807424595},
#  {'Returns': 25.191959915703023,
#   'Volatility': 0.25612873704889544,
#   'SHOP_weight': 0.23211639934994188,
#   'TSLA_weight': 0.2131115878842046,
#   'GOLD_weight': 0.22106749650712063,
#   'DAL_weight': 0.08928242134289033,
#   'NFLX_weight': 0.06302198615949879,
#   'AAPL_weight': 0.10930721945491223,
#   'PFE_weight': 0.06026267033285916,
#   'BTC_weight': 0.01183021896857231},
#  {'Returns': 23.79431099423107,
#   'Volatility': 0.15137603030968103,
#   'SHOP_weight': 0.13847186884984994,
#   'TSLA_weight': 0.011067910045257631,
#   'GOLD_weight': 0.023479480260629182,
#   'DAL_weight': 0.0941814975568469,
#   'NFLX_weight': 0.09520478228968808,
#   'AAPL_weight': 0.19558133736763128,
#   'PFE_weight': 0.2509387941673715,
#   'BTC_weight': 0.19107432946272535},
#  {'Returns': 16.80119895083383,
#   'Volatility': 0.20094651179616133,
#   'SHOP_weight': 0.013122859438026708,
#   'TSLA_weight': 0.1976150707964832,
#   'GOLD_weight': 0.19011920729358625,
#   'DAL_weight': 0.0291940222567367,
#   'NFLX_weight': 0.15443821211288336,
#   'AAPL_weight': 0.18152788000344675,
#   'PFE_weight': 0.08208087406900356,
#   'BTC_weight': 0.15190187402983357},
#  {'Returns': 12.507731521921096,
#   'Volatility': 0.17171786029286007,
#   'SHOP_weight': 0.08516806602181999,
#   'TSLA_weight': 0.05450307100838032,
#   'GOLD_weight': 0.1611410260213711,
#   'DAL_weight': 0.03363770177372799,
#   'NFLX_weight': 0.20532663553671804,
#   'AAPL_weight': 0.15986577136804953,
#   'PFE_weight': 0.10506329861185376,
#   'BTC_weight': 0.1952944296580792},
#  {'Returns': 22.783362020738075,
#   'Volatility': 0.19133623080087628,
#   'SHOP_weight': 0.17451523704336605,
#   'TSLA_weight': 0.11618416678557701,
#   'GOLD_weight': 0.1614181375057085,
#   'DAL_weight': 0.12354408015191859,
#   'NFLX_weight': 0.10662267382382246,
#   'AAPL_weight': 0.06334485428345776,
#   'PFE_weight': 0.15477215843254577,
#   'BTC_weight': 0.0995986919736039},
#  {'Returns': 25.887777734310657,
#   'Volatility': 0.22021207786524954,
#   'SHOP_weight': 0.14599373334856766,
#   'TSLA_weight': 0.2527318910575948,
#   'GOLD_weight': 0.026591485042087835,
#   'DAL_weight': 0.014842793053630683,
#   'NFLX_weight': 0.09952471589137792,
#   'AAPL_weight': 0.09765744136045086,
#   'PFE_weight': 0.012362091524023034,
#   'BTC_weight': 0.35029584872226716},
#  {'Returns': 29.824884797668624,
#   'Volatility': 0.22385564369214628,
#   'SHOP_weight': 0.1683476060063591,
#   'TSLA_weight': 0.216156579762875,
#   'GOLD_weight': 0.08227065569063273,
#   'DAL_weight': 0.15060420325025534,
#   'NFLX_weight': 0.09449788637112506,
#   'AAPL_weight': 0.08999027768461457,
#   'PFE_weight': 0.064939816432522,
#   'BTC_weight': 0.13319297480161615},
#  {'Returns': 16.709364714612153,
#   'Volatility': 0.22261872443764905,
#   'SHOP_weight': 0.12637890652773054,
#   'TSLA_weight': 0.1643147518690936,
#   'GOLD_weight': 0.2799739427259051,
#   'DAL_weight': 0.07994677941584842,
#   'NFLX_weight': 0.21528159160968754,
#   'AAPL_weight': 0.0037608832045609524,
#   'PFE_weight': 0.11145604221065329,
#   'BTC_weight': 0.01888710243652055},
#  {'Returns': 17.588871230363996,
#   'Volatility': 0.18581942897044668,
#   'SHOP_weight': 0.1370068260293963,
#   'TSLA_weight': 0.10278302323475268,
#   'GOLD_weight': 0.14444674750352654,
#   'DAL_weight': 0.0887536800978232,
#   'NFLX_weight': 0.13666143284908222,
#   'AAPL_weight': 0.14602782497273142,
#   'PFE_weight': 0.05185939051939438,
#   'BTC_weight': 0.19246107479329322},
#  {'Returns': 18.67352227061308,
#   'Volatility': 0.2210128483830903,
#   'SHOP_weight': 0.24208716116729467,
#   'TSLA_weight': 0.04692613074658507,
#   'GOLD_weight': 0.0800962939016199,
#   'DAL_weight': 0.0006374526798649788,
#   'NFLX_weight': 0.20162234177819335,
#   'AAPL_weight': 0.17121678301884707,
#   'PFE_weight': 0.06537413917234534,
#   'BTC_weight': 0.1920396975352496},
#  {'Returns': 26.428615240418857,
#   'Volatility': 0.22948915643100212,
#   'SHOP_weight': 0.18511794555265226,
#   'TSLA_weight': 0.20850478462362926,
#   'GOLD_weight': 0.1342252093214782,
#   'DAL_weight': 0.10781050511005902,
#   'NFLX_weight': 0.10661058135111466,
#   'AAPL_weight': 0.08379564118826349,
#   'PFE_weight': 0.05966744062609764,
#   'BTC_weight': 0.11426789222670553},
#  {'Returns': 17.196842674742562,
#   'Volatility': 0.17578778918638827,
#   'SHOP_weight': 0.020033977922979486,
#   'TSLA_weight': 0.07579192557445255,
#   'GOLD_weight': 0.2611841760407523,
#   'DAL_weight': 0.21312332463021644,
#   'NFLX_weight': 0.012798346819077128,
#   'AAPL_weight': 0.14853297260060008,
#   'PFE_weight': 0.22494884944610152,
#   'BTC_weight': 0.04358642696582042},
#  {'Returns': 20.814790243117514,
#   'Volatility': 0.1422669560988034,
#   'SHOP_weight': 0.16942357356561627,
#   'TSLA_weight': 0.027751360486226527,
#   'GOLD_weight': 0.12294029479261216,
#   'DAL_weight': 0.13844983749198683,
#   'NFLX_weight': 0.01601566111084564,
#   'AAPL_weight': 0.02654472669303149,
#   'PFE_weight': 0.26168541405406487,
#   'BTC_weight': 0.23718913180561624},
#  {'Returns': 35.16106931515405,
#   'Volatility': 0.20370650267030543,
#   'SHOP_weight': 0.15173942217175632,
#   'TSLA_weight': 0.1358381075483206,
#   'GOLD_weight': 0.016867986281693014,
#   'DAL_weight': 0.21188851089336316,
#   'NFLX_weight': 0.008327164581947374,
#   'AAPL_weight': 0.2313911668350663,
#   'PFE_weight': 0.19420299572664387,
#   'BTC_weight': 0.04974464596120926},
#  {'Returns': 29.263536661371333,
#   'Volatility': 0.21957913965168288,
#   'SHOP_weight': 0.10022767542207477,
#   'TSLA_weight': 0.12850807882442591,
#   'GOLD_weight': 0.026166290952721327,
#   'DAL_weight': 0.2648446362525494,
#   'NFLX_weight': 0.24857344313468302,
#   'AAPL_weight': 0.1452680819953073,
#   'PFE_weight': 0.034076361396157245,
#   'BTC_weight': 0.05233543202208102},
#  {'Returns': 31.807857655923282,
#   'Volatility': 0.2022541507808263,
#   'SHOP_weight': 0.08043417467144415,
#   'TSLA_weight': 0.205797139082304,
#   'GOLD_weight': 0.022050787358483096,
#   'DAL_weight': 0.16453119447106468,
#   'NFLX_weight': 0.19618134825262296,
#   'AAPL_weight': 0.04027325699520213,
#   'PFE_weight': 0.16332947972041043,
#   'BTC_weight': 0.12740261944846867},
#  {'Returns': 14.466713038740117,
#   'Volatility': 0.1771660530480206,
#   'SHOP_weight': 0.12504676427653144,
#   'TSLA_weight': 0.015633848431782983,
#   'GOLD_weight': 0.16578439843119208,
#   'DAL_weight': 0.1777276040099466,
#   'NFLX_weight': 0.19444394544704505,
#   'AAPL_weight': 0.13345856944424003,
#   'PFE_weight': 0.04863870216133072,
#   'BTC_weight': 0.13926616779793105},
#  {'Returns': 26.658545529796655,
#   'Volatility': 0.20473610617455687,
#   'SHOP_weight': 0.2345020567660778,
#   'TSLA_weight': 0.10249024996714036,
#   'GOLD_weight': 0.11603146526625109,
#   'DAL_weight': 0.09839062529994354,
#   'NFLX_weight': 0.12078087604404548,
#   'AAPL_weight': 0.05557996285645749,
#   'PFE_weight': 0.20133794862672308,
#   'BTC_weight': 0.07088681517336118},
#  {'Returns': 13.09303096457269,
#   'Volatility': 0.19987257520853768,
#   'SHOP_weight': 0.0005581715281029472,
#   'TSLA_weight': 0.18356077885309274,
#   'GOLD_weight': 0.26065069332708307,
#   'DAL_weight': 0.13669236920625086,
#   'NFLX_weight': 0.2089512106370085,
#   'AAPL_weight': 0.04044600027692244,
#   'PFE_weight': 0.028620420218625264,
#   'BTC_weight': 0.14052035595291415},
#  {'Returns': 19.57739574279639,
#   'Volatility': 0.18111446290092692,
#   'SHOP_weight': 0.037012039033298895,
#   'TSLA_weight': 0.14977800220235785,
#   'GOLD_weight': 0.21977854533138783,
#   'DAL_weight': 0.1986762436500055,
#   'NFLX_weight': 0.060201170664051416,
#   'AAPL_weight': 0.08566722601857082,
#   'PFE_weight': 0.13810406102634792,
#   'BTC_weight': 0.11078271207397979},
#  {'Returns': 23.621285678945313,
#   'Volatility': 0.1764563438970704,
#   'SHOP_weight': 0.0774336820687988,
#   'TSLA_weight': 0.15788544259552745,
#   'GOLD_weight': 0.07646343021165891,
#   'DAL_weight': 0.024451969002583316,
#   'NFLX_weight': 0.1223991258397752,
#   'AAPL_weight': 0.15044443323927806,
#   'PFE_weight': 0.1932482677138486,
#   'BTC_weight': 0.1976736493285297},
#  {'Returns': 15.554385444579246,
#   'Volatility': 0.2021292737818836,
#   'SHOP_weight': 0.12389067581460092,
#   'TSLA_weight': 0.12379855935378156,
#   'GOLD_weight': 0.2405976472552521,
#   'DAL_weight': 0.11365443683171779,
#   'NFLX_weight': 0.08883720178980252,
#   'AAPL_weight': 0.17082824874601607,
#   'PFE_weight': 0.033638146026158854,
#   'BTC_weight': 0.10475508418267018},
#  {'Returns': 22.898706977875015,
#   'Volatility': 0.20338121676231058,
#   'SHOP_weight': 0.20980691633518764,
#   'TSLA_weight': 0.07772437993180736,
#   'GOLD_weight': 0.06660281889213404,
#   'DAL_weight': 0.04613849656180614,
#   'NFLX_weight': 0.24125521851288534,
#   'AAPL_weight': 0.04746342756673656,
#   'PFE_weight': 0.15375732230709196,
#   'BTC_weight': 0.15725141989235092},
#  {'Returns': 15.014664329624043,
#   'Volatility': 0.1895429863436028,
#   'SHOP_weight': 0.2196915492453203,
#   'TSLA_weight': 0.006271037124268906,
#   'GOLD_weight': 0.27533300653028536,
#   'DAL_weight': 0.2108415581654725,
#   'NFLX_weight': 0.014162509670966305,
#   'AAPL_weight': 0.07332740874115604,
#   'PFE_weight': 0.11957272579536089,
#   'BTC_weight': 0.08080020472716967},
#  {'Returns': 29.497029008523906,
#   'Volatility': 0.21868666776153817,
#   'SHOP_weight': 0.14338902614231136,
#   'TSLA_weight': 0.1742560834678401,
#   'GOLD_weight': 0.0025399600655589384,
#   'DAL_weight': 0.07623668710606507,
#   'NFLX_weight': 0.19831073427972273,
#   'AAPL_weight': 0.16331902033250667,
#   'PFE_weight': 0.09713111152427494,
#   'BTC_weight': 0.14481737708172024},
#  {'Returns': 16.231126806039853,
#   'Volatility': 0.16992918364278872,
#   'SHOP_weight': 0.031181115770435,
#   'TSLA_weight': 0.05174688090299038,
#   'GOLD_weight': 0.21483111216736134,
#   'DAL_weight': 0.09357532209714839,
#   'NFLX_weight': 0.10691290986551631,
#   'AAPL_weight': 0.22467007700961947,
#   'PFE_weight': 0.24666393618336133,
#   'BTC_weight': 0.030418646003567813},
#  {'Returns': 23.901137534498474,
#   'Volatility': 0.18492793662062013,
#   'SHOP_weight': 0.1172666105230523,
#   'TSLA_weight': 0.1401749453302266,
#   'GOLD_weight': 0.03862242611888721,
#   'DAL_weight': 0.0007585497986082772,
#   'NFLX_weight': 0.21448790405821938,
#   'AAPL_weight': 0.07458611110483516,
#   'PFE_weight': 0.192292267192428,
#   'BTC_weight': 0.22181118587374293},
#  {'Returns': 23.870393384597147,
#   'Volatility': 0.2103932396681736,
#   'SHOP_weight': 0.14859064869583685,
#   'TSLA_weight': 0.16499315557497232,
#   'GOLD_weight': 0.15368411260503786,
#   'DAL_weight': 0.07439969627670376,
#   'NFLX_weight': 0.18380884389875654,
#   'AAPL_weight': 0.048862283124710026,
#   'PFE_weight': 0.15694551310813257,
#   'BTC_weight': 0.06871574671585001},
#  {'Returns': 26.6548200764387,
#   'Volatility': 0.20190226188820104,
#   'SHOP_weight': 0.025183035568711064,
#   'TSLA_weight': 0.18671951921338367,
#   'GOLD_weight': 0.0529810486623223,
#   'DAL_weight': 0.23178344900780454,
#   'NFLX_weight': 0.1560035172204882,
#   'AAPL_weight': 0.15216954934208005,
#   'PFE_weight': 0.029917702530579654,
#   'BTC_weight': 0.1652421784546306},
#  {'Returns': 15.377407062812962,
#   'Volatility': 0.15839081002549,
#   'SHOP_weight': 0.019324416515612296,
#   'TSLA_weight': 0.10417588104522969,
#   'GOLD_weight': 0.20588987719644786,
#   'DAL_weight': 0.15776666280425697,
#   'NFLX_weight': 0.12338500163008936,
#   'AAPL_weight': 0.07484614245379617,
#   'PFE_weight': 0.14498966648299166,
#   'BTC_weight': 0.1696223518715761},
#  {'Returns': 29.673411104193068,
#   'Volatility': 0.18218105587820466,
#   'SHOP_weight': 0.03036060032771286,
#   'TSLA_weight': 0.17884817297476147,
#   'GOLD_weight': 0.026774985782870287,
#   'DAL_weight': 0.17574216612080099,
#   'NFLX_weight': 0.1247960479692335,
#   'AAPL_weight': 0.13115943366871613,
#   'PFE_weight': 0.17539074674778357,
#   'BTC_weight': 0.15692784640812116},
#  {'Returns': 30.36191735757876,
#   'Volatility': 0.21485852738540548,
#   'SHOP_weight': 0.22371375478073074,
#   'TSLA_weight': 0.18060302237044906,
#   'GOLD_weight': 0.07112524733963262,
#   'DAL_weight': 0.13796099604759335,
#   'NFLX_weight': 0.010852844439042868,
#   'AAPL_weight': 0.11050265546645593,
#   'PFE_weight': 0.09749082189369367,
#   'BTC_weight': 0.1677506576624017},
#  {'Returns': 29.10937210539352,
#   'Volatility': 0.21618441393386678,
#   'SHOP_weight': 0.15636521913590437,
#   'TSLA_weight': 0.1956389654562515,
#   'GOLD_weight': 0.11370994583938678,
#   'DAL_weight': 0.07325651818573446,
#   'NFLX_weight': 0.08159949412098977,
#   'AAPL_weight': 0.13734218800753628,
#   'PFE_weight': 0.18324170067146012,
#   'BTC_weight': 0.058845968582736705},
#  {'Returns': 21.30245351889984,
#   'Volatility': 0.20950712103871086,
#   'SHOP_weight': 0.13883171783246953,
#   'TSLA_weight': 0.1643506287032699,
#   'GOLD_weight': 0.1598268173931163,
#   'DAL_weight': 0.0294790790302483,
#   'NFLX_weight': 0.1657985203300122,
#   'AAPL_weight': 0.09903959162607211,
#   'PFE_weight': 0.1326820599769133,
#   'BTC_weight': 0.10999158510789837},
#  {'Returns': 23.331303815370724,
#   'Volatility': 0.20165858719621213,
#   'SHOP_weight': 0.14520916206546874,
#   'TSLA_weight': 0.10815703667528075,
#   'GOLD_weight': 0.16426873339932174,
#   'DAL_weight': 0.14513686137728357,
#   'NFLX_weight': 0.13118760535625287,
#   'AAPL_weight': 0.1504302472104577,
#   'PFE_weight': 0.14156170071404436,
#   'BTC_weight': 0.014048653201890268},
#  {'Returns': 14.505063314835446,
#   'Volatility': 0.18557242906392846,
#   'SHOP_weight': 0.14389185733031776,
#   'TSLA_weight': 0.061595168805696786,
#   'GOLD_weight': 0.16017298862154092,
#   'DAL_weight': 0.07320910828248331,
#   'NFLX_weight': 0.18391554085370884,
#   'AAPL_weight': 0.1382708015365832,
#   'PFE_weight': 0.05472061164014864,
#   'BTC_weight': 0.18422392292952053},
#  {'Returns': 30.064777550504676,
#   'Volatility': 0.20103552947333758,
#   'SHOP_weight': 0.04238659435032523,
#   'TSLA_weight': 0.1690256689516713,
#   'GOLD_weight': 0.0332205612577505,
#   'DAL_weight': 0.19674996007843107,
#   'NFLX_weight': 0.19903666318724897,
#   'AAPL_weight': 0.14786967287219827,
#   'PFE_weight': 0.14121679740957727,
#   'BTC_weight': 0.07049408189279742},
#  {'Returns': 18.391742899308667,
#   'Volatility': 0.1879761422573159,
#   'SHOP_weight': 0.19400971407943784,
#   'TSLA_weight': 0.06782363462824877,
#   'GOLD_weight': 0.18446227738994858,
#   'DAL_weight': 0.10326429324871526,
#   'NFLX_weight': 0.13541253323779162,
#   'AAPL_weight': 0.05648812422227282,
#   'PFE_weight': 0.1379338804296034,
#   'BTC_weight': 0.1206055427639817},
#  {'Returns': 19.66469140286046,
#   'Volatility': 0.17570562604116027,
#   'SHOP_weight': 0.1335884653710716,
#   'TSLA_weight': 0.1049850630422943,
#   'GOLD_weight': 0.17048017109774447,
#   'DAL_weight': 0.11646808442464864,
#   'NFLX_weight': 0.15376042982549795,
#   'AAPL_weight': 0.017439626320538824,
#   'PFE_weight': 0.1635745488948135,
#   'BTC_weight': 0.1397036110233907},
#  {'Returns': 19.8689977909023,
#   'Volatility': 0.20603326735697242,
#   'SHOP_weight': 0.11665348021615446,
#   'TSLA_weight': 0.18901855873060233,
#   'GOLD_weight': 0.19175505833744472,
#   'DAL_weight': 0.0026929019406047483,
#   'NFLX_weight': 0.029583333423348016,
#   'AAPL_weight': 0.19400648864700878,
#   'PFE_weight': 0.12277061319871443,
#   'BTC_weight': 0.1535195655061224},
#  {'Returns': 31.965794027875248,
#   'Volatility': 0.2091519791472288,
#   'SHOP_weight': 0.18656449205099845,
#   'TSLA_weight': 0.15791068088675742,
#   'GOLD_weight': 0.06433830983654948,
#   'DAL_weight': 0.022209453001304814,
#   'NFLX_weight': 0.05623062351032565,
#   'AAPL_weight': 0.16340670117781894,
#   'PFE_weight': 0.29635299811184546,
#   'BTC_weight': 0.05298674142439977},
#  {'Returns': 22.256415253679144,
#   'Volatility': 0.15870450936260314,
#   'SHOP_weight': 0.16871620068364154,
#   'TSLA_weight': 0.033242942706888406,
#   'GOLD_weight': 0.059216684983435054,
#   'DAL_weight': 0.1805733484317455,
#   'NFLX_weight': 0.12775370595029875,
#   'AAPL_weight': 0.0730305794459534,
#   'PFE_weight': 0.1323990841559261,
#   'BTC_weight': 0.22506745364211111},
#  {'Returns': 23.767343364656387,
#   'Volatility': 0.14415412106250317,
#   'SHOP_weight': 0.03495360180889784,
#   'TSLA_weight': 0.035627554811782536,
#   'GOLD_weight': 0.029043349231033834,
#   'DAL_weight': 0.22696708613325373,
#   'NFLX_weight': 0.09350703747606694,
#   'AAPL_weight': 0.15760026013431946,
#   'PFE_weight': 0.20801391423264445,
#   'BTC_weight': 0.21428719617200118},
#  {'Returns': 13.274587109208763,
#   'Volatility': 0.18486179005664088,
#   'SHOP_weight': 0.1268767804493723,
#   'TSLA_weight': 0.14756030869847753,
#   'GOLD_weight': 0.22580779863687647,
#   'DAL_weight': 0.02093209984023186,
#   'NFLX_weight': 0.06352186477659194,
#   'AAPL_weight': 0.09691047584123859,
#   'PFE_weight': 0.06144508701503131,
#   'BTC_weight': 0.25694558474218004},
#  {'Returns': 17.624441064923843,
#   'Volatility': 0.19955810671185825,
#   'SHOP_weight': 0.02711708352318242,
#   'TSLA_weight': 0.16605049150814472,
#   'GOLD_weight': 0.27589267224148406,
#   'DAL_weight': 0.07943169392040485,
#   'NFLX_weight': 0.08889924715936624,
#   'AAPL_weight': 0.16453393257126583,
#   'PFE_weight': 0.19310790174583747,
#   'BTC_weight': 0.004966977330314307},
#  {'Returns': 26.27712077421813,
#   'Volatility': 0.13881134247517038,
#   'SHOP_weight': 0.12081000567837723,
#   'TSLA_weight': 0.039530862558268334,
#   'GOLD_weight': 0.0028273439207974847,
#   'DAL_weight': 0.19486011556897287,
#   'NFLX_weight': 0.11682542929478397,
#   'AAPL_weight': 0.008115753892724214,
#   'PFE_weight': 0.25579787803850557,
#   'BTC_weight': 0.2612326110475703},
#  {'Returns': 32.30109010536092,
#   'Volatility': 0.2080274501180133,
#   'SHOP_weight': 0.1985810007306821,
#   'TSLA_weight': 0.1402986252390124,
#   'GOLD_weight': 0.023682327295146032,
#   'DAL_weight': 0.09542608317324484,
#   'NFLX_weight': 0.08194741319250934,
#   'AAPL_weight': 0.17478664723023932,
#   'PFE_weight': 0.19583732216776684,
#   'BTC_weight': 0.0894405809713993},
#  {'Returns': 32.06758075646962,
#   'Volatility': 0.2359123446100229,
#   'SHOP_weight': 0.2150650169499587,
#   'TSLA_weight': 0.2136362078986639,
#   'GOLD_weight': 0.012062571771363995,
#   'DAL_weight': 0.13573830577147566,
#   'NFLX_weight': 0.09321847028934867,
#   'AAPL_weight': 0.11729147021822038,
#   'PFE_weight': 0.017163064049893758,
#   'BTC_weight': 0.19582489305107495},
#  {'Returns': 26.07204322556121,
#   'Volatility': 0.15850195385276103,
#   'SHOP_weight': 0.05351413487166553,
#   'TSLA_weight': 0.06575595206500069,
# ...
#   'PFE_weight': 0.18520384680135313,
#   'BTC_weight': 0.25339790757750275},
#  {'Returns': 20.092709219601666,
#   'Volatility': 0.16419096728450208,
#   'SHOP_weight': 0.238766512270059,
#   'TSLA_weight': 0.00955832498271442,
#   'GOLD_weight': 0.1093651801803233,
#   'DAL_weight': 0.08680438448321132,
#   'NFLX_weight': 0.044752011560718716,
#   'AAPL_weight': 0.07267543897127772,
#   'PFE_weight': 0.20632044569120322,
#   'BTC_weight': 0.2317577018604923},
#  {'Returns': 35.37370912984744,
#   'Volatility': 0.2134936792246007,
#   'SHOP_weight': 0.09964433103648147,
#   'TSLA_weight': 0.21454700413773015,
#   'GOLD_weight': 0.04364841953535659,
#   'DAL_weight': 0.1668656780617532,
#   'NFLX_weight': 0.14649937027316273,
#   'AAPL_weight': 0.0755109645497214,
#   'PFE_weight': 0.2330133161605097,
#   'BTC_weight': 0.020270916245284692},
#  {'Returns': 22.250543529729317,
#   'Volatility': 0.208978051069387,
#   'SHOP_weight': 0.15052824688858568,
#   'TSLA_weight': 0.17312776705585572,
#   'GOLD_weight': 0.20198437617735354,
#   'DAL_weight': 0.049490501437193524,
#   'NFLX_weight': 0.03364758280445238,
#   'AAPL_weight': 0.15488844241236213,
#   'PFE_weight': 0.15444369710599593,
#   'BTC_weight': 0.08188938611820101},
#  {'Returns': 22.060225510594446,
#   'Volatility': 0.1963204687964761,
#   'SHOP_weight': 0.18414831473877838,
#   'TSLA_weight': 0.15210887807426757,
#   'GOLD_weight': 0.15583975656044194,
#   'DAL_weight': 0.03364221405883048,
#   'NFLX_weight': 0.026549925427462772,
#   'AAPL_weight': 0.11987525556911396,
#   'PFE_weight': 0.14649022011260268,
#   'BTC_weight': 0.1813454354585023},
#  {'Returns': 23.9995640523829,
#   'Volatility': 0.22207826543769088,
#   'SHOP_weight': 0.17272001227473682,
#   'TSLA_weight': 0.1743816070468189,
#   'GOLD_weight': 0.08178968565317045,
#   'DAL_weight': 0.04660244615851822,
#   'NFLX_weight': 0.21673049131779243,
#   'AAPL_weight': 0.065109008184493,
#   'PFE_weight': 0.06560887156468585,
#   'BTC_weight': 0.17705787779978432},
#  {'Returns': 13.300928761843721,
#   'Volatility': 0.18252486911463758,
#   'SHOP_weight': 0.10241300622929396,
#   'TSLA_weight': 0.07078925953297022,
#   'GOLD_weight': 0.22039541598035642,
#   'DAL_weight': 0.07557914026477887,
#   'NFLX_weight': 0.16618721892334196,
#   'AAPL_weight': 0.1438013016696524,
#   'PFE_weight': 0.10517809255346865,
#   'BTC_weight': 0.11565656484613765},
#  {'Returns': 16.11357881239642,
#   'Volatility': 0.18212182844945934,
#   'SHOP_weight': 0.118839494220231,
#   'TSLA_weight': 0.12219301437676222,
#   'GOLD_weight': 0.2858255271714728,
#   'DAL_weight': 0.030426053498452073,
#   'NFLX_weight': 0.0580100635567062,
#   'AAPL_weight': 0.02413313064709795,
#   'PFE_weight': 0.27244117518212996,
#   'BTC_weight': 0.08813154134714787},
#  {'Returns': 22.949548913573526,
#   'Volatility': 0.20051644459213488,
#   'SHOP_weight': 0.13002691739198854,
#   'TSLA_weight': 0.20450255554377675,
#   'GOLD_weight': 0.1433142629305836,
#   'DAL_weight': 0.01772166433216814,
#   'NFLX_weight': 0.11810940450790622,
#   'AAPL_weight': 0.04053742551740307,
#   'PFE_weight': 0.15982826181521204,
#   'BTC_weight': 0.18595950796096156},
#  {'Returns': 22.483540579789704,
#   'Volatility': 0.19379304318603702,
#   'SHOP_weight': 0.15598179869159792,
#   'TSLA_weight': 0.17927981751077543,
#   'GOLD_weight': 0.11912292978416528,
#   'DAL_weight': 0.059963407243836,
#   'NFLX_weight': 0.08414438155443466,
#   'AAPL_weight': 0.07069783228757964,
#   'PFE_weight': 0.09095341491638517,
#   'BTC_weight': 0.2398564180112259},
#  {'Returns': 25.449151573498057,
#   'Volatility': 0.19099517178069583,
#   'SHOP_weight': 0.09320661429279684,
#   'TSLA_weight': 0.11082675391425152,
#   'GOLD_weight': 0.11367850589302822,
#   'DAL_weight': 0.12936623143158965,
#   'NFLX_weight': 0.1401281606214433,
#   'AAPL_weight': 0.1996424836504272,
#   'PFE_weight': 0.1952421662218005,
#   'BTC_weight': 0.01790908397466268},
#  {'Returns': 23.006151041703504,
#   'Volatility': 0.21400345054643993,
#   'SHOP_weight': 0.10379636465689686,
#   'TSLA_weight': 0.17695308946935404,
#   'GOLD_weight': 0.15902467613280838,
#   'DAL_weight': 0.1123805746362753,
#   'NFLX_weight': 0.20421115819944652,
#   'AAPL_weight': 0.0867859714917579,
#   'PFE_weight': 0.1011280942135499,
#   'BTC_weight': 0.05572007119991101},
#  {'Returns': 24.488011411520006,
#   'Volatility': 0.20913251794376958,
#   'SHOP_weight': 0.15385969432846183,
#   'TSLA_weight': 0.16603282433103494,
#   'GOLD_weight': 0.129808230008373,
#   'DAL_weight': 0.06639018509529532,
#   'NFLX_weight': 0.14051380006971106,
#   'AAPL_weight': 0.10831059951534999,
#   'PFE_weight': 0.13466892279285145,
#   'BTC_weight': 0.10041574385892242},
#  {'Returns': 30.32728453227662,
#   'Volatility': 0.21654487489126803,
#   'SHOP_weight': 0.17725657881089457,
#   'TSLA_weight': 0.19159481610245432,
#   'GOLD_weight': 0.062489437747292896,
#   'DAL_weight': 0.18398762764094898,
#   'NFLX_weight': 0.04024076437087999,
#   'AAPL_weight': 0.13780652037739918,
#   'PFE_weight': 0.04954234490475763,
#   'BTC_weight': 0.15708191004537245},
#  {'Returns': 19.931308449536424,
#   'Volatility': 0.19439608649657902,
#   'SHOP_weight': 0.17033154395169905,
#   'TSLA_weight': 0.16017501122320374,
#   'GOLD_weight': 0.1847308005173686,
#   'DAL_weight': 0.18286514490745825,
#   'NFLX_weight': 0.011395350242774495,
#   'AAPL_weight': 0.04431618675795624,
#   'PFE_weight': 0.003113361691315964,
#   'BTC_weight': 0.24307260070822362},
#  {'Returns': 30.4946161870511,
#   'Volatility': 0.22251200320320988,
#   'SHOP_weight': 0.1918789919461503,
#   'TSLA_weight': 0.1918135296453819,
#   'GOLD_weight': 0.1438712603661166,
#   'DAL_weight': 0.04503987599965896,
#   'NFLX_weight': 0.026278048267431103,
#   'AAPL_weight': 0.13137669824896211,
#   'PFE_weight': 0.2626848190965364,
#   'BTC_weight': 0.0070567764297627105},
#  {'Returns': 12.875343308633799,
#   'Volatility': 0.19355681214834444,
#   'SHOP_weight': 0.03589642188380284,
#   'TSLA_weight': 0.1562569704564482,
#   'GOLD_weight': 0.2920613853629029,
#   'DAL_weight': 0.17688807067765588,
#   'NFLX_weight': 0.06362175941390062,
#   'AAPL_weight': 0.11528806303755319,
#   'PFE_weight': 0.01936257506356396,
#   'BTC_weight': 0.14062475410417238},
#  {'Returns': 24.974591168962764,
#   'Volatility': 0.17625115097900215,
#   'SHOP_weight': 0.221418140599296,
#   'TSLA_weight': 0.046499221062279515,
#   'GOLD_weight': 0.04580178944690381,
#   'DAL_weight': 0.1747801859795154,
#   'NFLX_weight': 0.10793646767106306,
#   'AAPL_weight': 0.07176086153255021,
#   'PFE_weight': 0.12313276875131099,
#   'BTC_weight': 0.20867056495708117},
#  {'Returns': 22.797831812066168,
#   'Volatility': 0.19329865027300636,
#   'SHOP_weight': 0.19356495870055168,
#   'TSLA_weight': 0.13275804720017909,
#   'GOLD_weight': 0.0954153740376705,
#   'DAL_weight': 0.14052887451826038,
#   'NFLX_weight': 0.1014984749637176,
#   'AAPL_weight': 0.061785185459867845,
#   'PFE_weight': 0.032110107346197646,
#   'BTC_weight': 0.24233897777355518},
#  {'Returns': 24.17516519886881,
#   'Volatility': 0.20242012974070933,
#   'SHOP_weight': 0.19121312743512564,
#   'TSLA_weight': 0.087547530962024,
#   'GOLD_weight': 0.034268268552458514,
#   'DAL_weight': 0.15177391702264853,
#   'NFLX_weight': 0.13134469368897067,
#   'AAPL_weight': 0.2026624512094585,
#   'PFE_weight': 0.0010657126021619446,
#   'BTC_weight': 0.20012429852715216},
#  {'Returns': 18.540821436549827,
#   'Volatility': 0.18223750997396332,
#   'SHOP_weight': 0.07572226576883623,
#   'TSLA_weight': 0.15945387087368054,
#   'GOLD_weight': 0.19543047460114177,
#   'DAL_weight': 0.005238520208873388,
#   'NFLX_weight': 0.16431553652410294,
#   'AAPL_weight': 0.027465591492686993,
#   'PFE_weight': 0.23443759353202015,
#   'BTC_weight': 0.13793614699865794},
#  {'Returns': 28.200342847481682,
#   'Volatility': 0.2614518899467232,
#   'SHOP_weight': 0.24531262096879422,
#   'TSLA_weight': 0.2235830687399628,
#   'GOLD_weight': 0.1220757595645843,
#   'DAL_weight': 0.011113638074926812,
#   'NFLX_weight': 0.12832918288034623,
#   'AAPL_weight': 0.09948646073503373,
#   'PFE_weight': 0.08973693414021199,
#   'BTC_weight': 0.08036233489613993},
#  {'Returns': 20.726552782454373,
#   'Volatility': 0.2004850512456264,
#   'SHOP_weight': 0.2043573826972634,
#   'TSLA_weight': 0.11182854934832381,
#   'GOLD_weight': 0.13069363157011799,
#   'DAL_weight': 0.10385607109386394,
#   'NFLX_weight': 0.0857337124375309,
#   'AAPL_weight': 0.13340972622368857,
#   'PFE_weight': 0.0376573332475769,
#   'BTC_weight': 0.1924635933816346},
#  {'Returns': 20.343407627705478,
#   'Volatility': 0.18738381470154686,
#   'SHOP_weight': 0.27590143478995804,
#   'TSLA_weight': 0.006782564623384449,
#   'GOLD_weight': 0.1194120360849049,
#   'DAL_weight': 0.2735392554227423,
#   'NFLX_weight': 0.019172178176730954,
#   'AAPL_weight': 0.037755735549540315,
#   'PFE_weight': 0.012906980052065708,
#   'BTC_weight': 0.2545298153006733},
#  {'Returns': 26.846090589952727,
#   'Volatility': 0.2021608784288755,
#   'SHOP_weight': 0.15248334244091497,
#   'TSLA_weight': 0.1460464764644268,
#   'GOLD_weight': 0.07161167235356333,
#   'DAL_weight': 0.11779126022509813,
#   'NFLX_weight': 0.13680830927566434,
#   'AAPL_weight': 0.14297391949343413,
#   'PFE_weight': 0.11130566302218615,
#   'BTC_weight': 0.12097935672471209},
#  {'Returns': 21.032064634802992,
#   'Volatility': 0.19891100828121247,
#   'SHOP_weight': 0.07496956868184065,
#   'TSLA_weight': 0.15159740794707394,
#   'GOLD_weight': 0.1722811211434046,
#   'DAL_weight': 0.06934229527525518,
#   'NFLX_weight': 0.1874985701285125,
#   'AAPL_weight': 0.12932479442116276,
#   'PFE_weight': 0.1651478122746553,
#   'BTC_weight': 0.04983843012809498},
#  {'Returns': 23.548795772451218,
#   'Volatility': 0.17402223514863813,
#   'SHOP_weight': 0.062903992106085,
#   'TSLA_weight': 0.11813932069777125,
#   'GOLD_weight': 0.13116021552533805,
#   'DAL_weight': 0.17731824021266934,
#   'NFLX_weight': 0.08115544335731094,
#   'AAPL_weight': 0.15775216994845923,
#   'PFE_weight': 0.1707023497552164,
#   'BTC_weight': 0.10086826839714975},
#  {'Returns': 27.834500641933047,
#   'Volatility': 0.20256627751029355,
#   'SHOP_weight': 0.024656670431093538,
#   'TSLA_weight': 0.2071453748622854,
#   'GOLD_weight': 0.050160523807564736,
#   'DAL_weight': 0.23296139917518097,
#   'NFLX_weight': 0.04176329600809874,
#   'AAPL_weight': 0.21055152429675447,
#   'PFE_weight': 0.025512864432991274,
#   'BTC_weight': 0.2072483469860309},
#  {'Returns': 23.6673089151344,
#   'Volatility': 0.21360431901358304,
#   'SHOP_weight': 0.004767299030127768,
#   'TSLA_weight': 0.2140915790255673,
#   'GOLD_weight': 0.12247443322405177,
#   'DAL_weight': 0.18979562794021784,
#   'NFLX_weight': 0.16911798144353285,
#   'AAPL_weight': 0.16219968596063866,
#   'PFE_weight': 0.021057439091337248,
#   'BTC_weight': 0.11649595428452653},
#  {'Returns': 11.253578021282141,
#   'Volatility': 0.1981112463504617,
#   'SHOP_weight': 0.09648880347065372,
#   'TSLA_weight': 0.11406991190798037,
#   'GOLD_weight': 0.23671452241201416,
#   'DAL_weight': 0.04760472572962035,
#   'NFLX_weight': 0.19816453363365122,
#   'AAPL_weight': 0.11491829401298008,
#   'PFE_weight': 0.03141554692084633,
#   'BTC_weight': 0.1606236619122538},
#  {'Returns': 28.71890517125363,
#   'Volatility': 0.18922223729742382,
#   'SHOP_weight': 0.10967770336186776,
#   'TSLA_weight': 0.11508479734875368,
#   'GOLD_weight': 0.04689311429646971,
#   'DAL_weight': 0.08971638998396884,
#   'NFLX_weight': 0.15861994213513508,
#   'AAPL_weight': 0.1862785584918149,
#   'PFE_weight': 0.2418088120194862,
#   'BTC_weight': 0.051920682362503724},
#  {'Returns': 22.766318737339578,
#   'Volatility': 0.2224143301473208,
#   'SHOP_weight': 0.20046438755474755,
#   'TSLA_weight': 0.21185970162788106,
#   'GOLD_weight': 0.1699567880073676,
#   'DAL_weight': 0.026011919146337024,
#   'NFLX_weight': 0.0893927677007537,
#   'AAPL_weight': 0.01434458896619066,
#   'PFE_weight': 0.09995200705075283,
#   'BTC_weight': 0.1880178399459694},
#  {'Returns': 18.31309232543876,
#   'Volatility': 0.17566641027787716,
#   'SHOP_weight': 0.08526520294291481,
#   'TSLA_weight': 0.13394879278052724,
#   'GOLD_weight': 0.1783009678662199,
#   'DAL_weight': 0.08035231989239523,
#   'NFLX_weight': 0.15174396193501274,
#   'AAPL_weight': 0.06341273668906394,
#   'PFE_weight': 0.1523588029936953,
#   'BTC_weight': 0.15461721490017077},
#  {'Returns': 21.931176562919834,
#   'Volatility': 0.22187330766897595,
#   'SHOP_weight': 0.12348330645679834,
#   'TSLA_weight': 0.1896806473161526,
#   'GOLD_weight': 0.1418517252801618,
#   'DAL_weight': 0.10057190258249465,
#   'NFLX_weight': 0.1925301056554264,
#   'AAPL_weight': 0.10310587159362102,
#   'PFE_weight': 0.020799177475909456,
#   'BTC_weight': 0.12797726363943568},
#  {'Returns': 21.614587258802928,
#   'Volatility': 0.17566092122421803,
#   'SHOP_weight': 0.18092205987047486,
#   'TSLA_weight': 0.07545322581590129,
#   'GOLD_weight': 0.11949099879023209,
#   'DAL_weight': 0.06269669391564554,
#   'NFLX_weight': 0.05445622327390699,
#   'AAPL_weight': 0.1543423815813787,
#   'PFE_weight': 0.18353802471684524,
#   'BTC_weight': 0.1691003920356153},
#  {'Returns': 25.03967181217348,
#   'Volatility': 0.19873413098949447,
#   'SHOP_weight': 0.013299052066287462,
#   'TSLA_weight': 0.2323078350954536,
#   'GOLD_weight': 0.06852283088297909,
#   'DAL_weight': 0.01817210852786554,
#   'NFLX_weight': 0.03370208195155116,
#   'AAPL_weight': 0.28111234450076045,
#   'PFE_weight': 0.12885411670998487,
#   'BTC_weight': 0.22402963026511788},
#  {'Returns': 14.17054060288511,
#   'Volatility': 0.18157820582380468,
#   'SHOP_weight': 0.0766245099803267,
#   'TSLA_weight': 0.07448649003155043,
#   'GOLD_weight': 0.24819138086903733,
#   'DAL_weight': 0.05774034868577958,
#   'NFLX_weight': 0.10203816720171113,
#   'AAPL_weight': 0.20321014650587038,
#   'PFE_weight': 0.18114221445842407,
#   'BTC_weight': 0.05656674226730035},
#  {'Returns': 26.72479169021849,
#   'Volatility': 0.22019318539511792,
#   'SHOP_weight': 0.22222438954317128,
#   'TSLA_weight': 0.08893528038588168,
#   'GOLD_weight': 0.10337082706712258,
#   'DAL_weight': 0.07470566765669756,
#   'NFLX_weight': 0.14364155252847977,
#   'AAPL_weight': 0.1840829602984798,
#   'PFE_weight': 0.17897169029669266,
#   'BTC_weight': 0.004067632223474604},
#  {'Returns': 23.903703088368083,
#   'Volatility': 0.1720488812467266,
#   'SHOP_weight': 0.03338067787088772,
#   'TSLA_weight': 0.11832877101865259,
#   'GOLD_weight': 0.05958658943872163,
#   'DAL_weight': 0.1525655260821444,
#   'NFLX_weight': 0.21163157827296086,
#   'AAPL_weight': 0.12408564655305124,
#   'PFE_weight': 0.1559453582049302,
#   'BTC_weight': 0.1444758525586515},
#  {'Returns': 25.645681368186075,
#   'Volatility': 0.21634074745775636,
#   'SHOP_weight': 0.1577747765698953,
#   'TSLA_weight': 0.18397509090238778,
#   'GOLD_weight': 0.16941833937729064,
#   'DAL_weight': 0.06504996522754414,
#   'NFLX_weight': 0.1293127187275305,
#   'AAPL_weight': 0.07064124321913995,
#   'PFE_weight': 0.18863973472173287,
#   'BTC_weight': 0.035188131254478845},
#  {'Returns': 23.211891191906087,
#   'Volatility': 0.22861522779540144,
#   'SHOP_weight': 0.1192183102367694,
#   'TSLA_weight': 0.18854661835633243,
#   'GOLD_weight': 0.18186360318452016,
#   'DAL_weight': 0.10164034737878731,
#   'NFLX_weight': 0.058455790758982384,
#   'AAPL_weight': 0.26010508424263884,
#   'PFE_weight': 0.05121720148452085,
#   'BTC_weight': 0.038953044357448695},
#  {'Returns': 29.00081308482327,
#   'Volatility': 0.2125533639897963,
#   'SHOP_weight': 0.0542264043504134,
#   'TSLA_weight': 0.23429954965084002,
#   'GOLD_weight': 0.0042774422660317125,
#   'DAL_weight': 0.0898304229175702,
#   'NFLX_weight': 0.003210734569413277,
#   'AAPL_weight': 0.3248956055023229,
#   'PFE_weight': 0.03833779613595544,
#   'BTC_weight': 0.25092204460745315},
#  {'Returns': 31.457070031247163,
#   'Volatility': 0.23308077478401484,
#   'SHOP_weight': 0.23080885106657703,
#   'TSLA_weight': 0.20328686644245686,
#   'GOLD_weight': 0.019459655077077198,
#   'DAL_weight': 0.05210643570933875,
#   'NFLX_weight': 0.044200011552942724,
#   'AAPL_weight': 0.17090025819233007,
#   'PFE_weight': 0.08281482511127007,
#   'BTC_weight': 0.1964230968480074},
#  {'Returns': 31.300047312158462,
#   'Volatility': 0.21472225344786386,
#   'SHOP_weight': 0.25654070255514017,
#   'TSLA_weight': 0.13572856874493633,
#   'GOLD_weight': 0.013897675909043134,
#   'DAL_weight': 0.024183049266327777,
#   'NFLX_weight': 0.047132020695586606,
#   'AAPL_weight': 0.1528066384052315,
#   'PFE_weight': 0.2019141961019814,
#   'BTC_weight': 0.16779714832175305}]

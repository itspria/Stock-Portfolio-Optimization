# %%
import json
import numpy as np
import math
from datetime import datetime
import pandas as pd 
import matplotlib.pyplot as plt
import pymongo

# %% [markdown]
# # SHOP Stock Calculations

# %%
with open('../Data/SHOP_prices.json') as json_file:
    SHOP_data = json.load(json_file)
    
#stock annual return
SHOP_ann_return=round((((SHOP_data[0]['adjclose']/SHOP_data[len(SHOP_data)-1]['adjclose'])-1)*100),2)

SHOP_price_array=[]
for i in range(len(SHOP_data)):
    SHOP_price_array.append(SHOP_data[i]['adjclose'])
    
#daily volatility
SHOP_daily_vol = round(np.std(SHOP_price_array),2)

#annualized volatility
SHOP_ann_vol = SHOP_daily_vol * math.sqrt(252)
SHOP_ann_vol = round(SHOP_ann_vol,2)

#3 mon return volatility
SHOP_date_array=[]

for y in range(len(SHOP_data)):
    SHOP_date_array.append(datetime.strptime(SHOP_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=SHOP_date_array[y]
    if ((firstdate-SHOP_date_array[y]).days==91):
        date_3mon_ago=SHOP_date_array[y]
        mon3_index = y
        
#last three month return
SHOP_3mon_return=round((((SHOP_data[0]['adjclose']/SHOP_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
SHOP_summ_stats = {
    "Ticker": "SHOP",
  "Annual Return": SHOP_ann_return,
  "Daily Volatility": SHOP_daily_vol,
  "Annualized Volatility": SHOP_ann_vol,
  "Last 3 Months Return":  SHOP_3mon_return
}

# convert into JSON:
SHOP_summ_stats = json.dumps(SHOP_summ_stats)

# the result is a JSON string:
print(SHOP_summ_stats)
# Out:
# {"Ticker": "SHOP", "Annual Return": 46.96, "Daily Volatility": 191.43, "Annualized Volatility": 3038.86, "Last 3 Months Return": 23.22}

# %% [markdown]
# # TSLA Stock Calculations

# %%
with open('../Data/TSLA_prices.json') as json_file:
    TSLA_data = json.load(json_file)
    
#stock annual return
TSLA_ann_return=round((((TSLA_data[0]['adjclose']/TSLA_data[len(TSLA_data)-1]['adjclose'])-1)*100),2)

TSLA_price_array=[]
for i in range(len(TSLA_data)):
    TSLA_price_array.append(TSLA_data[i]['adjclose'])
    
#daily volatility
TSLA_daily_vol = round(np.std(TSLA_price_array),2)

#annualized volatility
TSLA_ann_vol = TSLA_daily_vol * math.sqrt(252)
TSLA_ann_vol = round(TSLA_ann_vol,2)

#3 mon return volatility
TSLA_date_array=[]

for y in range(len(TSLA_data)):
    TSLA_date_array.append(datetime.strptime(TSLA_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=TSLA_date_array[y]
    if ((firstdate-TSLA_date_array[y]).days==91):
        date_3mon_ago=TSLA_date_array[y]
        mon3_index = y
        
#last three month return
TSLA_3mon_return=round((((TSLA_data[0]['adjclose']/TSLA_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
TSLA_summ_stats = {
    "Ticker": "TSLA",
  "Annual Return": TSLA_ann_return,
  "Daily Volatility": TSLA_daily_vol,
  "Annualized Volatility": TSLA_ann_vol,
  "Last 3 Months Return":  TSLA_3mon_return
}

# convert into JSON:
TSLA_summ_stats = json.dumps(TSLA_summ_stats)

# the result is a JSON string:
print(TSLA_summ_stats)
# Out:
# {"Ticker": "TSLA", "Annual Return": 60.82, "Daily Volatility": 131.63, "Annualized Volatility": 2089.56, "Last 3 Months Return": 13.87}

# %% [markdown]
# # GOLD Stock Calculations

# %%
with open('../Data/GOLD_prices.json') as json_file:
    GOLD_data = json.load(json_file)
    
#stock annual return
GOLD_ann_return=round((((GOLD_data[0]['adjclose']/GOLD_data[len(GOLD_data)-1]['adjclose'])-1)*100),2)

GOLD_price_array=[]
for i in range(len(GOLD_data)):
    GOLD_price_array.append(GOLD_data[i]['adjclose'])
    
#daily volatility
GOLD_daily_vol = round(np.std(GOLD_price_array),2)

#annualized volatility
GOLD_ann_vol = GOLD_daily_vol * math.sqrt(252)
GOLD_ann_vol = round(GOLD_ann_vol,2)

#3 mon return volatility
GOLD_date_array=[]

for y in range(len(GOLD_data)):
    GOLD_date_array.append(datetime.strptime(GOLD_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=GOLD_date_array[y]
    if ((firstdate-GOLD_date_array[y]).days==91):
        date_3mon_ago=GOLD_date_array[y]
        mon3_index = y
        
#last three month return
GOLD_3mon_return=round((((GOLD_data[0]['adjclose']/GOLD_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
GOLD_summ_stats = {
    "Ticker": "GOLD",
  "Annual Return": GOLD_ann_return,
  "Daily Volatility": GOLD_daily_vol,
  "Annualized Volatility": GOLD_ann_vol,
  "Last 3 Months Return":  GOLD_3mon_return
}

# convert into JSON:
GOLD_summ_stats = json.dumps(GOLD_summ_stats)

# the result is a JSON string:
print(GOLD_summ_stats)
# Out:
# {"Ticker": "GOLD", "Annual Return": -29.43, "Daily Volatility": 2.76, "Annualized Volatility": 43.81, "Last 3 Months Return": -15.95}

# %% [markdown]
# # DAL Stock Calculations

# %%
with open('../Data/DAL_prices.json') as json_file:
    DAL_data = json.load(json_file)
    
#stock annual return
DAL_ann_return=round((((DAL_data[0]['adjclose']/DAL_data[len(DAL_data)-1]['adjclose'])-1)*100),2)

DAL_price_array=[]
for i in range(len(DAL_data)):
    DAL_price_array.append(DAL_data[i]['adjclose'])
    
#daily volatility
DAL_daily_vol = round(np.std(DAL_price_array),2)

#annualized volatility
DAL_ann_vol = DAL_daily_vol * math.sqrt(252)
DAL_ann_vol = round(DAL_ann_vol,2)

#3 mon return volatility
DAL_date_array=[]

for y in range(len(DAL_data)):
    DAL_date_array.append(datetime.strptime(DAL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=DAL_date_array[y]
    if ((firstdate-DAL_date_array[y]).days==91):
        date_3mon_ago=DAL_date_array[y]
        mon3_index = y
        
#last three month return
DAL_3mon_return=round((((DAL_data[0]['adjclose']/DAL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
DAL_summ_stats = {
    "Ticker": "DAL",
  "Annual Return": DAL_ann_return,
  "Daily Volatility": DAL_daily_vol,
  "Annualized Volatility": DAL_ann_vol,
  "Last 3 Months Return":  DAL_3mon_return
}

# convert into JSON:
DAL_summ_stats = json.dumps(DAL_summ_stats)

# the result is a JSON string:
print(DAL_summ_stats)
# Out:
# {"Ticker": "DAL", "Annual Return": 29.79, "Daily Volatility": 5.78, "Annualized Volatility": 91.75, "Last 3 Months Return": -12.92}

# %% [markdown]
# # NFLX Stock Calculations

# %%
with open('../Data/NFLX_prices.json') as json_file:
    NFLX_data = json.load(json_file)
    
#stock annual return
NFLX_ann_return=round((((NFLX_data[0]['adjclose']/NFLX_data[len(NFLX_data)-1]['adjclose'])-1)*100),2)

NFLX_price_array=[]
for i in range(len(NFLX_data)):
    NFLX_price_array.append(NFLX_data[i]['adjclose'])
    
#daily volatility
NFLX_daily_vol = round(np.std(NFLX_price_array),2)

#annualized volatility
NFLX_ann_vol = NFLX_daily_vol * math.sqrt(252)
NFLX_ann_vol = round(NFLX_ann_vol,2)

#3 mon return volatility
NFLX_date_array=[]

for y in range(len(NFLX_data)):
    NFLX_date_array.append(datetime.strptime(NFLX_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=NFLX_date_array[y]
    if ((firstdate-NFLX_date_array[y]).days==91):
        date_3mon_ago=NFLX_date_array[y]
        mon3_index = y
        
#last three month return
NFLX_3mon_return=round((((NFLX_data[0]['adjclose']/NFLX_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
NFLX_summ_stats = {
    "Ticker": "NFLX",
  "Annual Return": NFLX_ann_return,
  "Daily Volatility": NFLX_daily_vol,
  "Annualized Volatility": NFLX_ann_vol,
  "Last 3 Months Return":  NFLX_3mon_return
}

# convert into JSON:
NFLX_summ_stats = json.dumps(NFLX_summ_stats)

# the result is a JSON string:
print(NFLX_summ_stats)
# Out:
# {"Ticker": "NFLX", "Annual Return": 6.69, "Daily Volatility": 24.02, "Annualized Volatility": 381.31, "Last 3 Months Return": 11.16}

# %% [markdown]
# # AAPL Stock Calculations

# %%
with open('../Data/AAPL_prices.json') as json_file:
    AAPL_data = json.load(json_file)
    
#stock annual return
AAPL_ann_return=round((((AAPL_data[0]['adjclose']/AAPL_data[len(AAPL_data)-1]['adjclose'])-1)*100),2)

AAPL_price_array=[]
for i in range(len(AAPL_data)):
    AAPL_price_array.append(AAPL_data[i]['adjclose'])
    
#daily volatility
AAPL_daily_vol = round(np.std(AAPL_price_array),2)

#annualized volatility
AAPL_ann_vol = AAPL_daily_vol * math.sqrt(252)
AAPL_ann_vol = round(AAPL_ann_vol,2)

#3 mon return volatility
AAPL_date_array=[]

for y in range(len(AAPL_data)):
    AAPL_date_array.append(datetime.strptime(AAPL_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=AAPL_date_array[y]
    if ((firstdate-AAPL_date_array[y]).days==91):
        date_3mon_ago=AAPL_date_array[y]
        mon3_index = y
        
#last three month return
AAPL_3mon_return=round((((AAPL_data[0]['adjclose']/AAPL_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
AAPL_summ_stats = {
    "Ticker": "AAPL",
  "Annual Return": AAPL_ann_return,
  "Daily Volatility": AAPL_daily_vol,
  "Annualized Volatility": AAPL_ann_vol,
  "Last 3 Months Return":  AAPL_3mon_return
}

# convert into JSON:
AAPL_summ_stats = json.dumps(AAPL_summ_stats)

# the result is a JSON string:
print(AAPL_summ_stats)
# Out:
# {"Ticker": "AAPL", "Annual Return": 19.83, "Daily Volatility": 10.84, "Annualized Volatility": 172.08, "Last 3 Months Return": 19.43}

# %% [markdown]
# # PFE Stock Calculations

# %%
with open('../Data/PFE_prices.json') as json_file:
    PFE_data = json.load(json_file)
    
#stock annual return
PFE_ann_return=round((((PFE_data[0]['adjclose']/PFE_data[len(PFE_data)-1]['adjclose'])-1)*100),2)

PFE_price_array=[]
for i in range(len(PFE_data)):
    PFE_price_array.append(PFE_data[i]['adjclose'])
    
#daily volatility
PFE_daily_vol = round(np.std(PFE_price_array),2)

#annualized volatility
PFE_ann_vol = PFE_daily_vol * math.sqrt(252)
PFE_ann_vol = round(PFE_ann_vol,2)

#3 mon return volatility
PFE_date_array=[]

for y in range(len(PFE_data)):
    PFE_date_array.append(datetime.strptime(PFE_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=PFE_date_array[y]
    if ((firstdate-PFE_date_array[y]).days==91):
        date_3mon_ago=PFE_date_array[y]
        mon3_index = y
        
#last three month return
PFE_3mon_return=round((((PFE_data[0]['adjclose']/PFE_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
PFE_summ_stats = {
    "Ticker": "PFE",
  "Annual Return": PFE_ann_return,
  "Daily Volatility": PFE_daily_vol,
  "Annualized Volatility": PFE_ann_vol,
  "Last 3 Months Return":  PFE_3mon_return
}

# convert into JSON:
PFE_summ_stats = json.dumps(PFE_summ_stats)

# the result is a JSON string:
print(PFE_summ_stats)
# Out:
# {"Ticker": "PFE", "Annual Return": 34.84, "Daily Volatility": 3.91, "Annualized Volatility": 62.07, "Last 3 Months Return": 21.42}

# %% [markdown]
# # BTC Stock Calculations

# %%
with open('../Data/BTC_prices.json') as json_file:
    BTC_data = json.load(json_file)
    
#stock annual return
BTC_ann_return=round((((BTC_data[0]['adjclose']/BTC_data[len(BTC_data)-1]['adjclose'])-1)*100),2)

BTC_price_array=[]
for i in range(len(BTC_data)):
    BTC_price_array.append(BTC_data[i]['adjclose'])
    
#daily volatility
BTC_daily_vol = round(np.std(BTC_price_array),2)

#annualized volatility
BTC_ann_vol = BTC_daily_vol * math.sqrt(252)
BTC_ann_vol = round(BTC_ann_vol,2)

#3 mon return volatility
BTC_date_array=[]

for y in range(len(BTC_data)):
    BTC_date_array.append(datetime.strptime(BTC_data[y]['formatted_date'], '%Y-%m-%d'))
    if (y == 0):
        firstdate=BTC_date_array[y]
    if ((firstdate-BTC_date_array[y]).days==91):
        date_3mon_ago=BTC_date_array[y]
        mon3_index = y
        
#last three month return
BTC_3mon_return=round((((BTC_data[0]['adjclose']/BTC_data[mon3_index]['adjclose'])-1)*100),2)
        
# a Python object (dict):
BTC_summ_stats = {
    "Ticker": "BTC",
  "Annual Return": BTC_ann_return,
  "Daily Volatility": BTC_daily_vol,
  "Annualized Volatility": BTC_ann_vol,
  "Last 3 Months Return":  BTC_3mon_return
}

# convert into JSON:
BTC_summ_stats = json.dumps(BTC_summ_stats)

# the result is a JSON string:
print(BTC_summ_stats)
# Out:
# {"Ticker": "BTC", "Annual Return": 315.16, "Daily Volatility": 16031.17, "Annualized Volatility": 254486.93, "Last 3 Months Return": 30.24}

# %% [markdown]
# # Creating a Dataframe of values

# %%
shop_df = pd.DataFrame(json.loads(SHOP_summ_stats), index=[0])
tsla_df = pd.DataFrame(json.loads(TSLA_summ_stats), index=[0])
gold_df = pd.DataFrame(json.loads(GOLD_summ_stats), index=[0])
dal_df = pd.DataFrame(json.loads(DAL_summ_stats), index=[0])
nflx_df = pd.DataFrame(json.loads(NFLX_summ_stats), index=[0])
aapl_df = pd.DataFrame(json.loads(AAPL_summ_stats), index=[0])
pfe_df = pd.DataFrame(json.loads(PFE_summ_stats), index=[0])
btc_df = pd.DataFrame(json.loads(BTC_summ_stats), index=[0])


stocks_calc_combined = shop_df.append([tsla_df,gold_df,dal_df,nflx_df,aapl_df,pfe_df,btc_df])
stocks_calc_combined.reset_index(inplace = True,drop = True)

stocks_calc_combined
# Out:
#   Ticker  Annual Return  Daily Volatility  Annualized Volatility  \
# 0   SHOP          46.96            191.43                3038.86
# 1   TSLA          60.82            131.63                2089.56
# 2   GOLD         -29.43              2.76                  43.81
# 3    DAL          29.79              5.78                  91.75
# 4   NFLX           6.69             24.02                 381.31
# 5   AAPL          19.83             10.84                 172.08
# 6    PFE          34.84              3.91                  62.07
# 7    BTC         315.16          16031.17              254486.93
#
#    Last 3 Months Return
# 0                 23.22
# 1                 13.87
# 2                -15.95
# 3                -12.92
# 4                 11.16
# 5                 19.43
# 6                 21.42
# 7                 30.24

# %%
result = stocks_calc_combined.to_json(orient="index")
parsed = json.loads(result)
with open('../Data/stocks_calc_combined.json', 'w') as outfile:
    json.dump(parsed, outfile)

# %% [markdown]
# # Get daily returns and asssets covariance

# %%
#created dataframes for daily prices
SHOP_data_df = pd.DataFrame(SHOP_data)
SHOP_data_df = SHOP_data_df[["formatted_date", "adjclose"]]
SHOP_data_df.set_index("formatted_date", inplace = True)
SHOP_data_df = SHOP_data_df.rename (columns = {"adjclose": "SHOP"})

TSLA_data_df = pd.DataFrame(TSLA_data)
TSLA_data_df = TSLA_data_df[["formatted_date", "adjclose"]]
TSLA_data_df.set_index("formatted_date", inplace = True)
TSLA_data_df = TSLA_data_df.rename (columns = {"adjclose": "TSLA"})

GOLD_data_df = pd.DataFrame(GOLD_data)
GOLD_data_df = GOLD_data_df[["formatted_date", "adjclose"]]
GOLD_data_df.set_index("formatted_date", inplace = True)
GOLD_data_df = GOLD_data_df.rename (columns = {"adjclose": "GOLD"})

DAL_data_df = pd.DataFrame(DAL_data)
DAL_data_df = DAL_data_df[["formatted_date", "adjclose"]]
DAL_data_df.set_index("formatted_date", inplace = True)
DAL_data_df = DAL_data_df.rename (columns = {"adjclose": "DAL"})

NFLX_data_df = pd.DataFrame(NFLX_data)
NFLX_data_df = NFLX_data_df[["formatted_date", "adjclose"]]
NFLX_data_df.set_index("formatted_date", inplace = True)
NFLX_data_df = NFLX_data_df.rename (columns = {"adjclose": "NFLX"})

AAPL_data_df = pd.DataFrame(AAPL_data)
AAPL_data_df = AAPL_data_df[["formatted_date", "adjclose"]]
AAPL_data_df.set_index("formatted_date", inplace = True)
AAPL_data_df = AAPL_data_df.rename (columns = {"adjclose": "AAPL"})

PFE_data_df = pd.DataFrame(PFE_data)
PFE_data_df = PFE_data_df[["formatted_date", "adjclose"]]
PFE_data_df.set_index("formatted_date", inplace = True)
PFE_data_df = PFE_data_df.rename (columns = {"adjclose": "PFE"})

BTC_data_df = pd.DataFrame(BTC_data)
BTC_data_df = BTC_data_df[["formatted_date", "adjclose"]]
BTC_data_df.set_index("formatted_date", inplace = True)
BTC_data_df = BTC_data_df.rename (columns = {"adjclose": "BTC"})
#BTC_data_df

# %%
#merge assest into a single dataframe
assets_all = pd.concat([SHOP_data_df, TSLA_data_df,GOLD_data_df , DAL_data_df, NFLX_data_df, AAPL_data_df,PFE_data_df,BTC_data_df],axis=1, join="inner")
assets_all
# Out:
#                    SHOP    TSLA   GOLD    DAL    NFLX    AAPL    PFE       BTC
# formatted_date
# 2021-08-27      1531.42  711.92  20.24  41.52  558.92  148.60  46.60  48902.40
# 2021-08-26      1515.58  701.16  19.73  40.77  550.12  147.54  47.38  49058.67
# 2021-08-25      1552.24  711.20  19.85  41.30  547.58  148.36  47.51  46942.22
# 2021-08-24      1538.51  708.49  20.12  40.53  553.41  149.62  48.38  48960.79
# 2021-08-23      1481.41  706.30  20.15  39.21  553.33  149.71  49.93  47706.12
# ...                 ...     ...    ...    ...     ...     ...    ...       ...
# 2020-09-04       973.02  418.32  28.53  31.77  516.05  120.19  33.15  10169.57
# 2020-09-03      1015.70  407.00  28.74  31.22  525.75  120.11  33.19  10511.81
# 2020-09-02      1074.59  447.37  29.08  31.14  552.84  130.56  33.91  10245.30
# 2020-09-01      1134.32  475.05  28.81  30.71  556.55  133.32  33.62  11414.03
# 2020-08-31      1066.42  498.32  29.12  30.85  529.56  128.22  34.45  11970.48
#
# [249 rows x 8 columns]

# %%
#calculate daily pricec changes
assets_all_pricechng = assets_all.pct_change()
#assets_all_pricechng

# %%
#calculate covariance
assets_all_cov = assets_all_pricechng.cov()
assets_all_cov
# Out:
#           SHOP      TSLA      GOLD       DAL      NFLX      AAPL       PFE  \
# SHOP  0.001074  0.000536  0.000140 -0.000117  0.000369  0.000309 -0.000031
# TSLA  0.000536  0.001686  0.000135  0.000127  0.000299  0.000408  0.000041
# GOLD  0.000140  0.000135  0.000409  0.000036  0.000106  0.000112  0.000034
# DAL  -0.000117  0.000127  0.000036  0.000664 -0.000045  0.000018  0.000064
# NFLX  0.000369  0.000299  0.000106 -0.000045  0.000524  0.000234 -0.000033
# AAPL  0.000309  0.000408  0.000112  0.000018  0.000234  0.000387  0.000042
# PFE  -0.000031  0.000041  0.000034  0.000064 -0.000033  0.000042  0.000221
# BTC  -0.000005  0.000163 -0.000039  0.000082 -0.000104  0.000022 -0.000052
#
#            BTC
# SHOP -0.000005
# TSLA  0.000163
# GOLD -0.000039
# DAL   0.000082
# NFLX -0.000104
# AAPL  0.000022
# PFE  -0.000052
# BTC   0.002582

# %%
# convert into JSON:
assets_all_json = assets_all_cov.to_json()
assets_all_json = json.dumps(assets_all_json)

# %% [markdown]
# # Calculate portfolio return and volatility

# %% [markdown]
# ref: https://www.machinelearningplus.com/machine-learning/portfolio-optimization-python-example/

# %%
portfolio_return = []
portfolio_volati = []
asset_weights = []

# %%
#calculate number of assest and max number of portfolios to itterate
num_assets = stocks_calc_combined["Ticker"].count()
print(num_assets)
num_portf = 1000
# Out:
# 8

# %% [markdown]
# for portfolio in range(num_portf):
#     #portfolio returns
#     weights = np.random.random(num_assets)
#     weights = weights/np.sum(weights)
#     asset_weights.append(weights)
# asset_weights

# %% [markdown]
# len(asset_weights)

# %%
for portfolio in range(num_portf):
    #portfolio returns
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    asset_weights.append(weights)
    portf_return = np.dot(weights, stocks_calc_combined["Annual Return"])
    portfolio_return.append(portf_return)
    
    #portfolio risk
    portf_var = assets_all_cov.mul(weights, axis=0).mul(weights, axis=1).sum().sum()
    portf_stdev = np.sqrt(portf_var) # Daily standard deviation
    portf_ann_stdev = portf_stdev*np.sqrt(250) # Annual standard deviation = volatility
    portfolio_volati.append(portf_ann_stdev)
    
    
#portfolio_return

# %%
print(len(portfolio_return), len(portfolio_volati), len(asset_weights))
# Out:
# 1000 1000 1000

# %% [markdown]
# #plot the graph
# plt.figure(figsize=(12,8))
# plt.scatter(portfolio_volati,portfolio_return, marker = "o",facecolors = 'green')
# plt.title(f"Efficient Frontier", fontsize = 13, fontweight = 'bold', y=1.05)
# plt.xlabel("Risk")
# plt.ylabel("Return")
# plt.grid()
# plt.ylim(-20,60)
# plt.xlim(0.05,0.4)
#
# plt.show()

# %%
data = {'Returns':portfolio_return, 'Volatility':portfolio_volati}

for counter, symbol in enumerate(assets_all.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in asset_weights]
    
portfolios  = pd.DataFrame(data)
portf = portfolios.to_dict(orient='records')
portf
# Out:
# [{'Returns': 94.67324508848252,
#   'Volatility': 0.2524434142625725,
#   'SHOP weight': 0.015936936488438063,
#   'TSLA weight': 0.04684843350445664,
#   'GOLD weight': 0.08701429304623565,
#   'DAL weight': 0.031140853306584244,
#   'NFLX weight': 0.25856429424799804,
#   'AAPL weight': 0.10852124472543646,
#   'PFE weight': 0.19127144109392655,
#   'BTC weight': 0.26070250358692426},
#  {'Returns': 85.29642093223869,
#   'Volatility': 0.2697182801658235,
#   'SHOP weight': 0.030918081066560493,
#   'TSLA weight': 0.12544760821794115,
#   'GOLD weight': 0.16797414256141552,
#   'DAL weight': 0.006450281073816366,
#   'NFLX weight': 0.23715972445015018,
#   'AAPL weight': 0.12194198140635434,
#   'PFE weight': 0.07410207258279478,
#   'BTC weight': 0.23600610864096713},
#  {'Returns': 54.24242610298248,
#   'Volatility': 0.22771153876950082,
#   'SHOP weight': 0.14689082952931076,
#   'TSLA weight': 0.037476284277053636,
#   'GOLD weight': 0.14560526649630068,
#   'DAL weight': 0.1053410146753775,
#   'NFLX weight': 0.19710594478567797,
#   'AAPL weight': 0.19736754829927364,
#   'PFE weight': 0.04517916062748031,
#   'BTC weight': 0.12503395130952558},
#  {'Returns': 88.69148476169305,
#   'Volatility': 0.2668665650028951,
#   'SHOP weight': 0.006850896519702656,
#   'TSLA weight': 0.10759546573212125,
#   'GOLD weight': 0.23467542791500487,
#   'DAL weight': 0.22014019205558205,
#   'NFLX weight': 0.0028157303475953924,
#   'AAPL weight': 0.10017838162236041,
#   'PFE weight': 0.08248720012994984,
#   'BTC weight': 0.24525670567768343},
#  {'Returns': 52.101454013672566,
#   'Volatility': 0.23796590411773078,
#   'SHOP weight': 0.05044199263411328,
#   'TSLA weight': 0.1365840919986922,
#   'GOLD weight': 0.043077213105440874,
#   'DAL weight': 0.27538834255638117,
#   'NFLX weight': 0.11097376516111712,
#   'AAPL weight': 0.2511484667659714,
#   'PFE weight': 0.04621826267961044,
#   'BTC weight': 0.08616786509867355},
#  {'Returns': 53.952754337563306,
#   'Volatility': 0.27128091303274604,
#   'SHOP weight': 0.2514756288159008,
#   'TSLA weight': 0.14493416681290008,
#   'GOLD weight': 0.04467263410181042,
#   'DAL weight': 0.04564389903089309,
#   'NFLX weight': 0.026699543643654976,
#   'AAPL weight': 0.2802396204063896,
#   'PFE weight': 0.13370650775133056,
#   'BTC weight': 0.07262799943712045},
#  {'Returns': 59.34343457366036,
#   'Volatility': 0.2377850392932025,
#   'SHOP weight': 0.1597671439368976,
#   'TSLA weight': 0.06802342701754657,
#   'GOLD weight': 0.0909742007865497,
#   'DAL weight': 0.20237136687115342,
#   'NFLX weight': 0.19746389125580152,
#   'AAPL weight': 0.15223548466594689,
#   'PFE weight': 0.002479416237483932,
#   'BTC weight': 0.12668506922862033},
#  {'Returns': 75.48702537715077,
#   'Volatility': 0.2662932841614614,
#   'SHOP weight': 0.1569143450348114,
#   'TSLA weight': 0.1656203142925539,
#   'GOLD weight': 0.09524138905312894,
#   'DAL weight': 0.06402591454042195,
#   'NFLX weight': 0.09692846757404949,
#   'AAPL weight': 0.16649102923675402,
#   'PFE weight': 0.09027201414122843,
#   'BTC weight': 0.16450652612705194},
#  {'Returns': 39.78701541199331,
#   'Volatility': 0.22235885426470334,
#   'SHOP weight': 0.16131645494758762,
#   'TSLA weight': 0.08073615991572512,
#   'GOLD weight': 0.15953230776198088,
#   'DAL weight': 0.19581625948154724,
#   'NFLX weight': 0.18968713805858234,
#   'AAPL weight': 0.09513391589847565,
#   'PFE weight': 0.0503405454442078,
#   'BTC weight': 0.06743721849189334},
#  {'Returns': 67.97553193664459,
#   'Volatility': 0.2233677111766801,
#   'SHOP weight': 0.05648003430284858,
#   'TSLA weight': 0.03302143545890347,
#   'GOLD weight': 0.212302060315255,
#   'DAL weight': 0.16660972635346508,
#   'NFLX weight': 0.1265178135568719,
#   'AAPL weight': 0.15795953148173295,
#   'PFE weight': 0.06156581055509205,
#   'BTC weight': 0.18554358797583098},
#  {'Returns': 82.73436483538806,
#   'Volatility': 0.2587101710498078,
#   'SHOP weight': 0.02769751704223709,
#   'TSLA weight': 0.13179091825753417,
#   'GOLD weight': 0.20937769719903732,
#   'DAL weight': 0.027956140535940154,
#   'NFLX weight': 0.0968527011079957,
#   'AAPL weight': 0.16907632245572557,
#   'PFE weight': 0.11251673594489256,
#   'BTC weight': 0.22473196745663732},
#  {'Returns': 31.919026059548386,
#   'Volatility': 0.24314714235887305,
#   'SHOP weight': 0.01984789820235718,
#   'TSLA weight': 0.11157125409662236,
#   'GOLD weight': 0.007703599116811644,
#   'DAL weight': 0.24361199106563894,
#   'NFLX weight': 0.347681827592258,
#   'AAPL weight': 0.2183813302138029,
#   'PFE weight': 0.02005788440409093,
#   'BTC weight': 0.031144215308418127},
#  {'Returns': 25.099365551192083,
#   'Volatility': 0.21985305290370363,
#   'SHOP weight': 0.01896576886619867,
#   'TSLA weight': 0.10945654587156278,
#   'GOLD weight': 0.2177232691647642,
#   'DAL weight': 0.1592602584816989,
#   'NFLX weight': 0.28680328361397806,
#   'AAPL weight': 0.1173563574014793,
#   'PFE weight': 0.048274879244181425,
#   'BTC weight': 0.04215963735613661},
#  {'Returns': 51.7630916451333,
#   'Volatility': 0.24137919197097615,
#   'SHOP weight': 0.033184268245242086,
#   'TSLA weight': 0.15846484202571723,
#   'GOLD weight': 0.14414276877850868,
#   'DAL weight': 0.07105997283601839,
#   'NFLX weight': 0.24548982987928766,
#   'AAPL weight': 0.16318821141362452,
#   'PFE weight': 0.07250205568429438,
#   'BTC weight': 0.1119680511373071},
#  {'Returns': 72.93137065037003,
#   'Volatility': 0.25190611781933,
#   'SHOP weight': 0.06230480123177121,
#   'TSLA weight': 0.1685499621625833,
#   'GOLD weight': 0.08575137139734383,
#   'DAL weight': 0.06092289798979656,
#   'NFLX weight': 0.08470705595639733,
#   'AAPL weight': 0.24007546195346952,
#   'PFE weight': 0.13799864470637307,
#   'BTC weight': 0.15968980460226515},
#  {'Returns': 37.81614321723278,
#   'Volatility': 0.18171241387264828,
#   'SHOP weight': 0.07438852555951908,
#   'TSLA weight': 0.02116651630728685,
#   'GOLD weight': 0.07241233472535495,
#   'DAL weight': 0.19144726620107147,
#   'NFLX weight': 0.30704976748145707,
#   'AAPL weight': 0.023283710212305835,
#   'PFE weight': 0.2526807569181425,
#   'BTC weight': 0.05757112259486226},
#  {'Returns': 82.67336639654013,
#   'Volatility': 0.27532672418674253,
#   'SHOP weight': 0.19807528322253945,
#   'TSLA weight': 0.16288722121538518,
#   'GOLD weight': 0.03246144628539378,
#   'DAL weight': 0.17333315050242368,
#   'NFLX weight': 0.023959586091485678,
#   'AAPL weight': 0.1798462935131276,
#   'PFE weight': 0.059857721461260886,
#   'BTC weight': 0.16957929770838368},
#  {'Returns': 53.780978778695896,
#   'Volatility': 0.24918324798228683,
#   'SHOP weight': 0.1398090139706632,
#   'TSLA weight': 0.14328448651561945,
#   'GOLD weight': 0.060025308088850086,
#   'DAL weight': 0.19554232983641415,
#   'NFLX weight': 0.13966181089657756,
#   'AAPL weight': 0.20465446594039877,
#   'PFE weight': 0.02650952326195055,
#   'BTC weight': 0.09051306148952624},
#  {'Returns': 40.837430670387015,
#   'Volatility': 0.22902895094975473,
#   'SHOP weight': 0.03442559599221485,
#   'TSLA weight': 0.21121538377070018,
#   'GOLD weight': 0.15656440948514092,
#   'DAL weight': 0.18178761853153425,
#   'NFLX weight': 0.07763099674852031,
#   'AAPL weight': 0.09224603231709035,
#   'PFE weight': 0.19389264740371753,
#   'BTC weight': 0.052237315751081655},
#  {'Returns': 38.85099870966818,
#   'Volatility': 0.24161582686351776,
#   'SHOP weight': 0.19142320490040846,
#   'TSLA weight': 0.0687722383911035,
#   'GOLD weight': 0.18375649171675237,
#   'DAL weight': 0.10217408255862706,
#   'NFLX weight': 0.25072373824091254,
#   'AAPL weight': 0.1074453012431087,
#   'PFE weight': 0.021144145447760932,
#   'BTC weight': 0.07456079750132652},
#  {'Returns': 48.807674417718786,
#   'Volatility': 0.26283887007712403,
#   'SHOP weight': 0.22021059203379198,
#   'TSLA weight': 0.077751278703193,
#   'GOLD weight': 0.007541357739814845,
#   'DAL weight': 0.05157316813066796,
#   'NFLX weight': 0.3560716977799148,
#   'AAPL weight': 0.10423342663793098,
#   'PFE weight': 0.10552147052399441,
#   'BTC weight': 0.07709700845069203},
#  {'Returns': 43.882703407359884,
#   'Volatility': 0.259598613905215,
#   'SHOP weight': 0.0809517018098664,
#   'TSLA weight': 0.26092340223637467,
#   'GOLD weight': 0.018785053597450155,
#   'DAL weight': 0.24276507080888482,
#   'NFLX weight': 0.10033382104686582,
#   'AAPL weight': 0.07047422912716982,
#   'PFE weight': 0.19866100991760785,
#   'BTC weight': 0.02710571145578042},
#  {'Returns': 98.44599231984064,
#   'Volatility': 0.27877876603402396,
#   'SHOP weight': 0.06925522736748695,
#   'TSLA weight': 0.09461855917940766,
#   'GOLD weight': 0.2747027237324992,
#   'DAL weight': 0.07598089021700913,
#   'NFLX weight': 0.03754393670033685,
#   'AAPL weight': 0.04280391969716136,
#   'PFE weight': 0.11954028748638501,
#   'BTC weight': 0.2855544556197138},
#  {'Returns': 38.2038333747702,
#   'Volatility': 0.24647507891951745,
#   'SHOP weight': 0.11546164390650653,
#   'TSLA weight': 0.1353425188617075,
#   'GOLD weight': 0.03676790586670639,
#   'DAL weight': 0.1634013994742173,
#   'NFLX weight': 0.1994748339247056,
#   'AAPL weight': 0.2531080826552295,
#   'PFE weight': 0.05702131621122097,
#   'BTC weight': 0.03942229909970624},
#  {'Returns': 79.93742427218018,
#   'Volatility': 0.22624481261939525,
#   'SHOP weight': 0.08524806939114901,
#   'TSLA weight': 0.00011548590357091406,
#   'GOLD weight': 0.011876816815126963,
#   'DAL weight': 0.15900990485088365,
#   'NFLX weight': 0.10292015226022322,
#   'AAPL weight': 0.3051403720090661,
#   'PFE weight': 0.14624535011996873,
#   'BTC weight': 0.18944384865001143},
#  {'Returns': 93.5899262320719,
#   'Volatility': 0.25818501800371335,
#   'SHOP weight': 0.1179543408398941,
#   'TSLA weight': 0.10827824493096792,
#   'GOLD weight': 0.06989687283069461,
#   'DAL weight': 0.1112504680538354,
#   'NFLX weight': 0.17160664347087684,
#   'AAPL weight': 0.05460926904259442,
#   'PFE weight': 0.1337709208185761,
#   'BTC weight': 0.23263324001256055},
#  {'Returns': 50.204235173321074,
#   'Volatility': 0.23866594951126271,
#   'SHOP weight': 0.062287724952834383,
#   'TSLA weight': 0.20271876630766128,
#   'GOLD weight': 0.17791821425373716,
#   'DAL weight': 0.19324084321477966,
#   'NFLX weight': 0.1398118542854949,
#   'AAPL weight': 0.033829071026246174,
#   'PFE weight': 0.09674024991478786,
#   'BTC weight': 0.0934532760444586},
#  {'Returns': 19.660448274591943,
#   'Volatility': 0.21940970021742465,
#   'SHOP weight': 0.12063545691615854,
#   'TSLA weight': 0.09582941727579142,
#   'GOLD weight': 0.19710564518239376,
#   'DAL weight': 0.19965237546170686,
#   'NFLX weight': 0.09703764323756622,
#   'AAPL weight': 0.19947030914472674,
#   'PFE weight': 0.08930389313091114,
#   'BTC weight': 0.0009652596507453771},
#  {'Returns': 52.31384385353708,
#   'Volatility': 0.20403766848837662,
#   'SHOP weight': 0.02338620876064482,
#   'TSLA weight': 0.0788956866893234,
#   'GOLD weight': 0.20229077948836102,
#   'DAL weight': 0.04373794161521486,
#   'NFLX weight': 0.15881388252120637,
#   'AAPL weight': 0.17777524743398398,
#   'PFE weight': 0.1884527958607029,
#   'BTC weight': 0.1266474576305626},
#  {'Returns': 96.82796341473355,
#   'Volatility': 0.2949955776157143,
#   'SHOP weight': 0.14379695411434515,
#   'TSLA weight': 0.11384125351926319,
#   'GOLD weight': 0.04464353841311097,
#   'DAL weight': 0.05589463881688701,
#   'NFLX weight': 0.1814573007458175,
#   'AAPL weight': 0.2045784525313491,
#   'PFE weight': 0.011004035186982992,
#   'BTC weight': 0.2447838266722441},
#  {'Returns': 30.58512364510569,
#   'Volatility': 0.21392754469723557,
#   'SHOP weight': 0.06012922617652714,
#   'TSLA weight': 0.128867035855177,
#   'GOLD weight': 0.1757170411334345,
#   'DAL weight': 0.06937290885520683,
#   'NFLX weight': 0.14415455322779197,
#   'AAPL weight': 0.19883583226156443,
#   'PFE weight': 0.18598513275819992,
#   'BTC weight': 0.0369382697320981},
#  {'Returns': 55.26678650712711,
#   'Volatility': 0.28479554279997416,
#   'SHOP weight': 0.18400694770508863,
#   'TSLA weight': 0.2248740907781868,
#   'GOLD weight': 0.1425648913738796,
#   'DAL weight': 0.08057156025966894,
#   'NFLX weight': 0.1551977687006423,
#   'AAPL weight': 0.0903644818479192,
#   'PFE weight': 0.02378615034526284,
#   'BTC weight': 0.09863410898935167},
#  {'Returns': 65.48546454533752,
#   'Volatility': 0.24831335974152532,
#   'SHOP weight': 0.03566237500162407,
#   'TSLA weight': 0.15548810024973855,
#   'GOLD weight': 0.1580743853878726,
#   'DAL weight': 0.02383167431916854,
#   'NFLX weight': 0.19378949016098562,
#   'AAPL weight': 0.17497459964816398,
#   'PFE weight': 0.09930740994716299,
#   'BTC weight': 0.15887196528528355},
#  {'Returns': 74.8991018169242,
#   'Volatility': 0.23622026596465534,
#   'SHOP weight': 0.12364695911853273,
#   'TSLA weight': 0.03832888597039619,
#   'GOLD weight': 0.14492921602482883,
#   'DAL weight': 0.16948584482047582,
#   'NFLX weight': 0.1115003705064094,
#   'AAPL weight': 0.17905919793005237,
#   'PFE weight': 0.04197634342382041,
#   'BTC weight': 0.19107318220548428},
#  {'Returns': 80.49481919659152,
#   'Volatility': 0.22234792130739947,
#   'SHOP weight': 0.08941717374528989,
#   'TSLA weight': 0.022661461639656506,
#   'GOLD weight': 0.06818265962283913,
#   'DAL weight': 0.09763208921736877,
#   'NFLX weight': 0.16033157592359498,
#   'AAPL weight': 0.17517960247744166,
#   'PFE weight': 0.18682282194378794,
#   'BTC weight': 0.19977261543002112},
#  {'Returns': 62.25903104700435,
#   'Volatility': 0.24345488448606606,
#   'SHOP weight': 0.14523552484974056,
#   'TSLA weight': 0.16721357469777848,
#   'GOLD weight': 0.11275941104061811,
#   'DAL weight': 0.11996639675625853,
#   'NFLX weight': 0.02717633084332922,
#   'AAPL weight': 0.1726589517341044,
#   'PFE weight': 0.13896501682351367,
#   'BTC weight': 0.11602479325465705},
#  {'Returns': 71.39862358059733,
#   'Volatility': 0.22574423012949932,
#   'SHOP weight': 0.05606632435463874,
#   'TSLA weight': 0.012692452510380118,
#   'GOLD weight': 0.23756911858161248,
#   'DAL weight': 0.2087315338809812,
#   'NFLX weight': 0.03163887995180565,
#   'AAPL weight': 0.1608644467524595,
#   'PFE weight': 0.09560069599817214,
#   'BTC weight': 0.19683654796994995},
#  {'Returns': 79.69670999565115,
#   'Volatility': 0.26111772051498566,
#   'SHOP weight': 0.040818716275719,
#   'TSLA weight': 0.1743911036095358,
#   'GOLD weight': 0.1507398849235299,
#   'DAL weight': 0.1138321645925459,
#   'NFLX weight': 0.14077759674613952,
#   'AAPL weight': 0.11354484492039212,
#   'PFE weight': 0.06697513888754489,
#   'BTC weight': 0.19892055004459272},
#  {'Returns': 55.241786178608365,
#   'Volatility': 0.2364557052779881,
#   'SHOP weight': 0.1496304836644867,
#   'TSLA weight': 0.10339829530730175,
#   'GOLD weight': 0.042259473200288,
#   'DAL weight': 0.012135158690325679,
#   'NFLX weight': 0.09138580629781183,
#   'AAPL weight': 0.30066095456323827,
#   'PFE weight': 0.20861805860703667,
#   'BTC weight': 0.09191176966951109},
#  {'Returns': 46.250895796544015,
#   'Volatility': 0.22419466838114155,
#   'SHOP weight': 0.15405739049900694,
#   'TSLA weight': 0.14975519648814753,
#   'GOLD weight': 0.03798343479675175,
#   'DAL weight': 0.12529735031568787,
#   'NFLX weight': 0.10316386420080635,
#   'AAPL weight': 0.13623678278692947,
#   'PFE weight': 0.24471886590375186,
#   'BTC weight': 0.04878711500891818},
#  {'Returns': 52.98429802349148,
#   'Volatility': 0.18206410064954423,
#   'SHOP weight': 0.0011274716721298868,
#   'TSLA weight': 0.010219437755436446,
#   'GOLD weight': 0.06540471673330624,
#   'DAL weight': 0.2387752890168093,
#   'NFLX weight': 0.06814499302674834,
#   'AAPL weight': 0.15408205483490553,
#   'PFE weight': 0.36412402774013636,
#   'BTC weight': 0.09812200922052798},
#  {'Returns': 51.04682701012427,
#   'Volatility': 0.25799795536697445,
#   'SHOP weight': 0.19699133237024796,
#   'TSLA weight': 0.18821497108385313,
#   'GOLD weight': 0.13200662866538174,
#   'DAL weight': 0.04235553541913334,
#   'NFLX weight': 0.09824205211943558,
#   'AAPL weight': 0.10981984276224697,
#   'PFE weight': 0.15374043453228245,
#   'BTC weight': 0.07862920304741901},
#  {'Returns': 66.58709142550028,
#   'Volatility': 0.2825228574606494,
#   'SHOP weight': 0.018129351694950942,
#   'TSLA weight': 0.24585645760204733,
#   'GOLD weight': 0.12906837917232628,
#   'DAL weight': 0.021510138832672686,
#   'NFLX weight': 0.23059930470346163,
#   'AAPL weight': 0.14534787785243353,
#   'PFE weight': 0.05888594334225689,
#   'BTC weight': 0.15060254679985077},
#  {'Returns': 55.048122440905445,
#   'Volatility': 0.25557020788370954,
#   'SHOP weight': 0.13240840590384756,
#   'TSLA weight': 0.202727266290817,
#   'GOLD weight': 0.10880801253692692,
#   'DAL weight': 0.074790857491063,
#   'NFLX weight': 0.18640433933016945,
#   'AAPL weight': 0.0764927966805322,
#   'PFE weight': 0.12168345443818857,
#   'BTC weight': 0.09668486732845535},
#  {'Returns': 102.51773781628509,
#   'Volatility': 0.26782760919792187,
#   'SHOP weight': 0.17174124922487116,
#   'TSLA weight': 0.10992457747361613,
#   'GOLD weight': 0.049331798463136504,
#   'DAL weight': 0.14790355133891397,
#   'NFLX weight': 0.04044814244436259,
#   'AAPL weight': 0.0582402640321451,
#   'PFE weight': 0.17743801923708938,
#   'BTC weight': 0.24497239778586513},
#  {'Returns': 61.83447253994282,
#   'Volatility': 0.21625085375015987,
#   'SHOP weight': 0.027493226695129398,
#   'TSLA weight': 0.14332630659396786,
#   'GOLD weight': 0.07607328816686544,
#   'DAL weight': 0.11720153188337115,
#   'NFLX weight': 0.09029546828973158,
#   'AAPL weight': 0.19070111049323035,
#   'PFE weight': 0.23425061948143786,
#   'BTC weight': 0.1206584483962663},
#  {'Returns': 66.13112028951188,
#   'Volatility': 0.2066461645894206,
#   'SHOP weight': 0.11932964445715845,
#   'TSLA weight': 0.054882135418345634,
#   'GOLD weight': 0.1847136631311686,
#   'DAL weight': 0.09560364254144664,
#   'NFLX weight': 0.013162617338529936,
#   'AAPL weight': 0.13991642527611567,
#   'PFE weight': 0.23812522705173594,
#   'BTC weight': 0.15426664478549917},
#  {'Returns': 51.270330303216646,
#   'Volatility': 0.2726571116426929,
#   'SHOP weight': 0.06670507963469698,
#   'TSLA weight': 0.2132054873667919,
#   'GOLD weight': 0.07132992552105787,
#   'DAL weight': 0.04219827046162875,
#   'NFLX weight': 0.26691940763247723,
#   'AAPL weight': 0.18233186045837801,
#   'PFE weight': 0.06765941132772703,
#   'BTC weight': 0.08965055759724229},
#  {'Returns': 48.36995458294284,
#   'Volatility': 0.20251820139236293,
#   'SHOP weight': 0.06774361929072299,
#   'TSLA weight': 0.0863502686471182,
#   'GOLD weight': 0.19521508932566248,
#   'DAL weight': 0.15362311456543115,
#   'NFLX weight': 0.1051594233590377,
#   'AAPL weight': 0.14843678528275048,
#   'PFE weight': 0.14010388284886216,
#   'BTC weight': 0.10336781668041486},
#  {'Returns': 64.70887658046507,
#   'Volatility': 0.25841534164771524,
#   'SHOP weight': 0.1369235827629126,
#   'TSLA weight': 0.17836836138299608,
#   'GOLD weight': 0.1954268826846597,
#   'DAL weight': 0.0887334005163475,
#   'NFLX weight': 0.057673552940190276,
#   'AAPL weight': 0.1361335175274855,
#   'PFE weight': 0.063153313612517,
#   'BTC weight': 0.14358738857289127},
#  {'Returns': 74.13260489451636,
#   'Volatility': 0.25760609267291257,
#   'SHOP weight': 0.08891559435052322,
#   'TSLA weight': 0.19899685390371952,
#   'GOLD weight': 0.09276329555822455,
#   'DAL weight': 0.1035494290952993,
#   'NFLX weight': 0.04947003866254986,
#   'AAPL weight': 0.17360666422645768,
#   'PFE weight': 0.13741755604034908,
#   'BTC weight': 0.15528056816287686},
#  {'Returns': 74.26650919101417,
#   'Volatility': 0.25651937174069156,
#   'SHOP weight': 0.1531671182236842,
#   'TSLA weight': 0.17836378845049933,
#   'GOLD weight': 0.08585834413584405,
#   'DAL weight': 0.16229298679060158,
#   'NFLX weight': 0.0295889152546877,
#   'AAPL weight': 0.12824359255145473,
#   'PFE weight': 0.11254307371523496,
#   'BTC weight': 0.14994218087799357},
#  {'Returns': 125.18155378680505,
#   'Volatility': 0.34069971641478336,
#   'SHOP weight': 0.005070023100192186,
#   'TSLA weight': 0.14262711414967624,
#   'GOLD weight': 0.21302599593221788,
#   'DAL weight': 0.1355583097837549,
#   'NFLX weight': 0.02545827243719588,
#   'AAPL weight': 0.06748353697406394,
#   'PFE weight': 0.04448115271964025,
#   'BTC weight': 0.3662955949032588},
#  {'Returns': 76.76636258210145,
#   'Volatility': 0.25960423232163043,
#   'SHOP weight': 0.10107406976125459,
#   'TSLA weight': 0.20485968307798014,
#   'GOLD weight': 0.08980075717389817,
#   'DAL weight': 0.11291992650965135,
#   'NFLX weight': 0.08775203806734708,
#   'AAPL weight': 0.10383021805451215,
#   'PFE weight': 0.13655860548869217,
#   'BTC weight': 0.16320470186666433},
#  {'Returns': 48.50554164555291,
#   'Volatility': 0.2542023019558533,
#   'SHOP weight': 0.24540147800100218,
#   'TSLA weight': 0.06690357362255174,
#   'GOLD weight': 0.06408112786706874,
#   'DAL weight': 0.15591899037214468,
#   'NFLX weight': 0.32660868409229993,
#   'AAPL weight': 0.01926021481152075,
#   'PFE weight': 0.03855632449688995,
#   'BTC weight': 0.08326960673652209},
#  {'Returns': 37.14604631504895,
#   'Volatility': 0.2384382366931503,
#   'SHOP weight': 0.010599006680271406,
#   'TSLA weight': 0.20087089387590937,
#   'GOLD weight': 0.15524657802351557,
#   'DAL weight': 0.19998947414937837,
#   'NFLX weight': 0.06273305036375752,
#   'AAPL weight': 0.2155739763402714,
#   'PFE weight': 0.10879586154213566,
#   'BTC weight': 0.0461911590247606},
#  {'Returns': 58.46796085340417,
#   'Volatility': 0.2601241578309257,
#   'SHOP weight': 0.01455340140017804,
#   'TSLA weight': 0.2076666966458561,
#   'GOLD weight': 0.04238861085692027,
#   'DAL weight': 0.15603092863554843,
#   'NFLX weight': 0.22603603113904247,
#   'AAPL weight': 0.192274647997571,
#   'PFE weight': 0.051112390937733204,
#   'BTC weight': 0.10993729238715055},
#  {'Returns': 93.1714703329942,
#   'Volatility': 0.27033489596529836,
#   'SHOP weight': 0.1417034184308591,
#   'TSLA weight': 0.16075459651691484,
#   'GOLD weight': 0.015571424347460429,
#   'DAL weight': 0.03946464358426772,
#   'NFLX weight': 0.032747088795598775,
#   'AAPL weight': 0.19700972629168725,
#   'PFE weight': 0.20756702826662754,
#   'BTC weight': 0.20518207376658426},
#  {'Returns': 95.62896660950477,
#   'Volatility': 0.3015481655302471,
#   'SHOP weight': 0.13652689074274826,
#   'TSLA weight': 0.13574964289046365,
#   'GOLD weight': 0.018795966794781693,
#   'DAL weight': 0.018568461407066108,
#   'NFLX weight': 0.13593730469580245,
#   'AAPL weight': 0.2921958668451316,
#   'PFE weight': 0.02991362498606743,
#   'BTC weight': 0.2323122416379387},
#  {'Returns': 37.586701734859496,
#   'Volatility': 0.2038178870262241,
#   'SHOP weight': 0.026019941852262328,
#   'TSLA weight': 0.14374110458277095,
#   'GOLD weight': 0.19660772897902018,
#   'DAL weight': 0.14740346427281764,
#   'NFLX weight': 0.2196600769072862,
#   'AAPL weight': 0.006182937157655951,
#   'PFE weight': 0.19491118235590102,
#   'BTC weight': 0.06547356389228581},
#  {'Returns': 77.6124434236966,
#   'Volatility': 0.24742182995896095,
#   'SHOP weight': 0.11705888082070512,
#   'TSLA weight': 0.1168388245729928,
#   'GOLD weight': 0.12144174233932452,
#   'DAL weight': 0.02878434658433764,
#   'NFLX weight': 0.16807680215408027,
#   'AAPL weight': 0.11699957353741545,
#   'PFE weight': 0.1426000424783853,
#   'BTC weight': 0.18819978751275887},
#  {'Returns': 52.127569119168726,
#   'Volatility': 0.20545526814615175,
#   'SHOP weight': 0.09920025307554942,
#   'TSLA weight': 0.08206923339374551,
#   'GOLD weight': 0.08810410760048136,
#   'DAL weight': 0.1438152251734882,
#   'NFLX weight': 0.10364798998359025,
#   'AAPL weight': 0.21176732463815354,
#   'PFE weight': 0.17708172618140533,
#   'BTC weight': 0.09431413995358648},
#  {'Returns': 94.63953929843227,
#   'Volatility': 0.27343650448132584,
#   'SHOP weight': 0.14942990746508003,
#   'TSLA weight': 0.11591570771780267,
#   'GOLD weight': 0.11294368352364818,
#   'DAL weight': 0.18644252740899975,
#   'NFLX weight': 0.045088072424375826,
#   'AAPL weight': 0.10752008729323839,
#   'PFE weight': 0.04699902035283918,
#   'BTC weight': 0.23566099381401606},
#  {'Returns': 70.71189017326317,
#   'Volatility': 0.2320187338812371,
#   'SHOP weight': 0.10075676889678321,
#   'TSLA weight': 0.034780694731252615,
#   'GOLD weight': 0.18865676146113894,
#   'DAL weight': 0.14134934672572694,
#   'NFLX weight': 0.1618909732478893,
#   'AAPL weight': 0.14157660998115734,
#   'PFE weight': 0.04096246168716679,
#   'BTC weight': 0.19002638326888482},
#  {'Returns': 70.4474989029315,
#   'Volatility': 0.26290559089728655,
#   'SHOP weight': 0.008133959785435732,
#   'TSLA weight': 0.2053454162270759,
#   'GOLD weight': 0.2568822139754403,
#   'DAL weight': 0.05456207375299934,
#   'NFLX weight': 0.1998155144728333,
#   'AAPL weight': 0.010110705432995165,
#   'PFE weight': 0.0770223759766282,
#   'BTC weight': 0.18812774037659208},
#  {'Returns': 45.00654288811779,
#   'Volatility': 0.2482217686644084,
#   'SHOP weight': 0.20357507294852623,
#   'TSLA weight': 0.16438471948625857,
#   'GOLD weight': 0.11910795982106695,
#   'DAL weight': 0.028848477426571106,
#   'NFLX weight': 0.08769517862157851,
#   'AAPL weight': 0.13748902160612525,
#   'PFE weight': 0.20267246937305614,
#   'BTC weight': 0.05622710071681718},
#  {'Returns': 61.48905475858879,
#   'Volatility': 0.21631239323700366,
#   'SHOP weight': 0.07409187869111146,
#   'TSLA weight': 0.11527493011694605,
#   'GOLD weight': 0.16684794784093576,
#   'DAL weight': 0.11823960793105455,
#   'NFLX weight': 0.05808857129542877,
#   'AAPL weight': 0.15964523912370945,
#   'PFE weight': 0.17186678200204034,
#   'BTC weight': 0.13594504299877364},
#  {'Returns': 98.41207481776055,
#   'Volatility': 0.2793047609704542,
#   'SHOP weight': 0.22482267211155071,
#   'TSLA weight': 0.08580564742238657,
#   'GOLD weight': 0.10265901708763729,
#   'DAL weight': 0.024733934884262482,
#   'NFLX weight': 0.1369666191558823,
#   'AAPL weight': 0.0346727624620056,
#   'PFE weight': 0.1416348548496067,
#   'BTC weight': 0.24870449202666847},
#  {'Returns': 83.51816084106481,
#   'Volatility': 0.2881239928372427,
#   'SHOP weight': 0.11163606491240863,
#   'TSLA weight': 0.2672889403038139,
#   'GOLD weight': 0.18869754580333165,
#   'DAL weight': 0.06845375270249646,
#   'NFLX weight': 0.004886936099929211,
#   'AAPL weight': 0.02157816359417852,
#   'PFE weight': 0.14726273730900327,
#   'BTC weight': 0.19019585927483837},
#  {'Returns': 63.1503280267427,
#   'Volatility': 0.21696946836890282,
#   'SHOP weight': 0.1214572697588042,
#   'TSLA weight': 0.11545490525416344,
#   'GOLD weight': 0.08435493659061892,
#   'DAL weight': 0.16862855634838755,
#   'NFLX weight': 0.09818681069038356,
#   'AAPL weight': 0.1089014401162365,
#   'PFE weight': 0.17990541200595966,
#   'BTC weight': 0.12311066923544614},
#  {'Returns': 45.15451951104427,
#   'Volatility': 0.21918884434163344,
#   'SHOP weight': 0.14801147029425382,
#   'TSLA weight': 0.07652977512244434,
#   'GOLD weight': 0.18585491439164858,
#   'DAL weight': 0.19437541163821678,
#   'NFLX weight': 0.19733858870885693,
#   'AAPL weight': 0.05479619471015814,
#   'PFE weight': 0.05092597866440558,
#   'BTC weight': 0.09216766647001585},
#  {'Returns': 35.87161164706937,
#   'Volatility': 0.3399978450025175,
#   'SHOP weight': 0.286758203341827,
#   'TSLA weight': 0.31058553168833974,
#   'GOLD weight': 0.11714416970890303,
#   'DAL weight': 0.008379590155703774,
#   'NFLX weight': 0.15351720739188113,
#   'AAPL weight': 0.019842104499129407,
#   'PFE weight': 0.09778859631283819,
#   'BTC weight': 0.005984596901377856},
#  {'Returns': 62.59418843920983,
#   'Volatility': 0.2169574399150787,
#   'SHOP weight': 0.1924139966677808,
#   'TSLA weight': 0.018450328403727328,
#   'GOLD weight': 0.19082454588153108,
#   'DAL weight': 0.10817388013916623,
#   'NFLX weight': 0.051463534536451146,
#   'AAPL weight': 0.15074389162288843,
#   'PFE weight': 0.14001056177300925,
#   'BTC weight': 0.1479192609754457},
#  {'Returns': 59.180410143445584,
#   'Volatility': 0.21134825906851995,
#   'SHOP weight': 0.08688888261558088,
#   'TSLA weight': 0.12600706036345619,
#   'GOLD weight': 0.09075832942482669,
#   'DAL weight': 0.17276783577212454,
#   'NFLX weight': 0.1799077536877157,
#   'AAPL weight': 0.035076766177377545,
#   'PFE weight': 0.19333197645621952,
#   'BTC weight': 0.11526139550269913},
#  {'Returns': 51.089862560271236,
#   'Volatility': 0.21360424673988268,
#   'SHOP weight': 0.03307042422680632,
#   'TSLA weight': 0.11357596377722975,
#   'GOLD weight': 0.11749364010841298,
#   'DAL weight': 0.24816941970491588,
#   'NFLX weight': 0.19375863589263462,
#   'AAPL weight': 0.08560517129793183,
#   'PFE weight': 0.10686357247299387,
#   'BTC weight': 0.10146317251907483},
#  {'Returns': 82.12115167624361,
#   'Volatility': 0.287795148079006,
#   'SHOP weight': 0.1262164564087365,
#   'TSLA weight': 0.24188612554529243,
#   'GOLD weight': 0.06287835218213532,
#   'DAL weight': 0.15310869797738688,
#   'NFLX weight': 0.07493501806255966,
#   'AAPL weight': 0.10812361515214455,
#   'PFE weight': 0.06156908083209914,
#   'BTC weight': 0.17128265383964544},
#  {'Returns': 59.84708464434726,
#   'Volatility': 0.2545779104076922,
#   'SHOP weight': 0.12236550132701168,
#   'TSLA weight': 0.15557796711288566,
#   'GOLD weight': 0.02849004103558326,
#   'DAL weight': 0.25104158903944884,
#   'NFLX weight': 0.22571165123375894,
#   'AAPL weight': 0.09550086579878435,
#   'PFE weight': 0.012978462069010946,
#   'BTC weight': 0.10833392238351645},
#  {'Returns': 53.077371000646686,
#   'Volatility': 0.2150774402388033,
#   'SHOP weight': 0.08114942374059904,
#   'TSLA weight': 0.14053035089697358,
#   'GOLD weight': 0.21965208502196915,
#   'DAL weight': 0.08925527250386955,
#   'NFLX weight': 0.006892173820694789,
#   'AAPL weight': 0.13490313653150787,
#   'PFE weight': 0.2192073446151501,
#   'BTC weight': 0.10841021286923601},
#  {'Returns': 67.05172629131944,
#   'Volatility': 0.2627193191298192,
#   'SHOP weight': 0.05858642553395966,
#   'TSLA weight': 0.20908306992374293,
#   'GOLD weight': 0.00633027426185772,
#   'DAL weight': 0.19407158909204994,
#   'NFLX weight': 0.12443021865828882,
#   'AAPL weight': 0.20663844340500193,
#   'PFE weight': 0.07935262110678654,
#   'BTC weight': 0.12150735801831249},
#  {'Returns': 29.44387215529699,
#   'Volatility': 0.2521702428390905,
#   'SHOP weight': 0.1418846375702687,
#   'TSLA weight': 0.14188461285724596,
#   'GOLD weight': 0.3229536504123552,
#   'DAL weight': 0.005011732062490805,
#   'NFLX weight': 0.05737569661412473,
#   'AAPL weight': 0.2114912455828544,
#   'PFE weight': 0.0667114317474141,
#   'BTC weight': 0.052686993153246216},
#  {'Returns': 78.26871364487589,
#   'Volatility': 0.26046123973187996,
#   'SHOP weight': 0.10002569951988378,
#   'TSLA weight': 0.1292654903572011,
#   'GOLD weight': 0.08324350228844286,
#   'DAL weight': 0.147949049842295,
#   'NFLX weight': 0.16328821239373237,
#   'AAPL weight': 0.17476064633258237,
#   'PFE weight': 0.015340801801064088,
#   'BTC weight': 0.18612659746479832},
#  {'Returns': 96.77986759621236,
#   'Volatility': 0.2508064603363563,
#   'SHOP weight': 0.08260343917311967,
#   'TSLA weight': 0.09701518816235036,
#   'GOLD weight': 0.1218247919873837,
#   'DAL weight': 0.12518925429088862,
#   'NFLX weight': 0.08266222478360528,
#   'AAPL weight': 0.026336615225363767,
#   'PFE weight': 0.21607225827238843,
#   'BTC weight': 0.24829622810490012},
#  {'Returns': 83.93626913512463,
#   'Volatility': 0.26448974228297084,
#   'SHOP weight': 0.11351146374744478,
#   'TSLA weight': 0.191360733035449,
#   'GOLD weight': 0.07487152107499467,
#   'DAL weight': 0.1262351093865975,
#   'NFLX weight': 0.09957367261454496,
#   'AAPL weight': 0.08422833256896377,
#   'PFE weight': 0.12376902320807683,
#   'BTC weight': 0.1864501443639285},
#  {'Returns': 42.9809746908352,
#   'Volatility': 0.19585492752658384,
#   'SHOP weight': 0.16025176519488643,
#   'TSLA weight': 0.06850014699551901,
#   'GOLD weight': 0.1463630340084079,
#   'DAL weight': 0.2019582131136249,
#   'NFLX weight': 0.1268410582784055,
#   'AAPL weight': 0.027338444443440336,
#   'PFE weight': 0.20158603484318846,
#   'BTC weight': 0.06716130312252755},
#  {'Returns': 23.287028026117454,
#   'Volatility': 0.2501722770887257,
#   'SHOP weight': 0.11314565817545577,
#   'TSLA weight': 0.20664576148808111,
#   'GOLD weight': 0.21842433618704707,
#   'DAL weight': 0.004025952175727321,
#   'NFLX weight': 0.06871204345821821,
#   'AAPL weight': 0.16131476145697582,
#   'PFE weight': 0.22729952535894568,
#   'BTC weight': 0.000431961699548982},
#  {'Returns': 73.01943849860162,
#   'Volatility': 0.22331929458532349,
#   'SHOP weight': 0.1612864010915556,
#   'TSLA weight': 0.027284928114025605,
#   'GOLD weight': 0.1867318344931134,
#   'DAL weight': 0.04026374529169506,
#   'NFLX weight': 0.07399334557160274,
#   'AAPL weight': 0.12710850862475737,
#   'PFE weight': 0.19885926480317864,
#   'BTC weight': 0.18447197201007154},
#  {'Returns': 75.95797392286596,
#   'Volatility': 0.2364557462676105,
#   'SHOP weight': 0.15287270260826366,
#   'TSLA weight': 0.10324618367552871,
#   'GOLD weight': 0.08492145947810593,
#   'DAL weight': 0.1574369930740298,
#   'NFLX weight': 0.050040437907431894,
#   'AAPL weight': 0.15179876468265233,
#   'PFE weight': 0.133719853708027,
#   'BTC weight': 0.16596360486596068},
#  {'Returns': 43.84900486728847,
#   'Volatility': 0.24125458328399224,
#   'SHOP weight': 0.15937219809585226,
#   'TSLA weight': 0.15977343926439153,
#   'GOLD weight': 0.189228433961367,
#   'DAL weight': 0.09529942208428098,
#   'NFLX weight': 0.07904795479457458,
#   'AAPL weight': 0.143039630932677,
#   'PFE weight': 0.1030998719432433,
#   'BTC weight': 0.0711390489236133},
#  {'Returns': 22.93234539364439,
#   'Volatility': 0.19912928412519784,
#   'SHOP weight': 0.042284898301249915,
#   'TSLA weight': 0.04123943110860731,
#   'GOLD weight': 0.2822731892944721,
#   'DAL weight': 0.08839346318828155,
#   'NFLX weight': 0.11772186924242531,
#   'AAPL weight': 0.2583427409452601,
#   'PFE weight': 0.1259083204773136,
#   'BTC weight': 0.0438360874423901},
#  {'Returns': 85.86311151277555,
#   'Volatility': 0.2590475243668066,
#   'SHOP weight': 0.15270886995746502,
#   'TSLA weight': 0.15849147106689257,
#   'GOLD weight': 0.07220256753257984,
#   'DAL weight': 0.09051463980773893,
#   'NFLX weight': 0.011830926063122233,
#   'AAPL weight': 0.14879165409594675,
#   'PFE weight': 0.17739397238386645,
#   'BTC weight': 0.18806589909238813},
#  {'Returns': 31.621877457425704,
#   'Volatility': 0.21171819550351975,
#   'SHOP weight': 0.00327857571374744,
#   'TSLA weight': 0.12451283131924072,
#   'GOLD weight': 0.22314716442039764,
#   'DAL weight': 0.046562408332852114,
#   'NFLX weight': 0.10229920691141726,
#   'AAPL weight': 0.2617647236727813,
#   'PFE weight': 0.1853068170897307,
#   'BTC weight': 0.053128272539832745},
#  {'Returns': 37.871681583422514,
#   'Volatility': 0.24629161060960966,
#   'SHOP weight': 0.09885270539428269,
#   'TSLA weight': 0.18278128328577742,
#   'GOLD weight': 0.0898631545599419,
#   'DAL weight': 0.12678687433910774,
#   'NFLX weight': 0.1988808929356904,
#   'AAPL weight': 0.15977949982587442,
#   'PFE weight': 0.10203998199028519,
#   'BTC weight': 0.04101560766904014},
#  {'Returns': 65.14719637924628,
#   'Volatility': 0.25586768371101665,
#   'SHOP weight': 0.10894562248657151,
#   'TSLA weight': 0.1634771147054668,
#   'GOLD weight': 0.16946929630091728,
#   'DAL weight': 0.026704689909265746,
#   'NFLX weight': 0.1201636389532852,
#   'AAPL weight': 0.17206799012375432,
#   'PFE weight': 0.09030022443192894,
#   'BTC weight': 0.1488714230888102},
#  {'Returns': 78.60702877843572,
#   'Volatility': 0.22441315912843246,
#   'SHOP weight': 0.043548290501106,
#   'TSLA weight': 0.09631004340877923,
#   'GOLD weight': 0.051647675175053954,
#   'DAL weight': 0.1742892123028656,
#   'NFLX weight': 0.17836326379671116,
#   'AAPL weight': 0.08987015765144683,
#   'PFE weight': 0.18294295349088507,
#   'BTC weight': 0.1830284036731523},
#  {'Returns': 39.61245193931874,
#   'Volatility': 0.21571832716960318,
#   'SHOP weight': 0.08993978390101681,
#   'TSLA weight': 0.12767501822188282,
#   'GOLD weight': 0.1918243786367705,
#   'DAL weight': 0.10350924130015117,
#   'NFLX weight': 0.14038113146146475,
#   'AAPL weight': 0.1386733749745325,
#   'PFE weight': 0.13932599745454932,
#   'BTC weight': 0.06867107404963209},
#  {'Returns': 38.11024575568013,
#   'Volatility': 0.2863017580310493,
#   'SHOP weight': 0.03329766459682573,
#   'TSLA weight': 0.27003424813419047,
#   'GOLD weight': 0.0641978134623269,
#   'DAL weight': 0.04670384505023611,
#   'NFLX weight': 0.22147859134787024,
#   'AAPL weight': 0.22962206637679242,
#   'PFE weight': 0.09936937496395722,
#   'BTC weight': 0.03529639606780099},
#  {'Returns': 34.336674919768555,
#   'Volatility': 0.23544133543155324,
#   'SHOP weight': 0.17697259047572161,
#   'TSLA weight': 0.047501551775433075,
#   'GOLD weight': 0.22026984096776892,
#   'DAL weight': 0.08316501420382955,
#   'NFLX weight': 0.22889479430508647,
#   'AAPL weight': 0.14990346235027718,
#   'PFE weight': 0.024129495927695307,
#   'BTC weight': 0.06916324999418788},
#  {'Returns': 115.77421814845955,
#   'Volatility': 0.34098364386058405,
#   'SHOP weight': 0.17059046144776696,
#   'TSLA weight': 0.22292812086340336,
#   'GOLD weight': 0.0009730530702447054,
#   'DAL weight': 0.04793189997985224,
#   'NFLX weight': 0.10618544942346518,
#   'AAPL weight': 0.13837686457934517,
#   'PFE weight': 0.03317061278628346,
#   'BTC weight': 0.27984353784963895},
#  {'Returns': 56.52369678450802,
#   'Volatility': 0.23356824905755413,
#   'SHOP weight': 0.019966208475940175,
#   'TSLA weight': 0.13492104745172956,
#   'GOLD weight': 0.20147810365220692,
#   'DAL weight': 0.1553022658830306,
#   'NFLX weight': 0.1627388448196856,
#   'AAPL weight': 0.1561986184684104,
#   'PFE weight': 0.03171165128072718,
#   'BTC weight': 0.13768325996826955},
#  {'Returns': 62.314412048246815,
#   'Volatility': 0.21718087991667256,
#   'SHOP weight': 0.1638622523451208,
#   'TSLA weight': 0.047609596941815324,
#   'GOLD weight': 0.028160210943402982,
#   'DAL weight': 0.10111941650280912,
#   'NFLX weight': 0.16851152226012336,
#   'AAPL weight': 0.18597169294419752,
#   'PFE weight': 0.18309347410611612,
#   'BTC weight': 0.12167183395641469},
#  {'Returns': 53.33501041849387,
#   'Volatility': 0.18084637771852774,
#   'SHOP weight': 0.06650186558321611,
#   'TSLA weight': 0.0532715665010126,
#   'GOLD weight': 0.12360822620829819,
#   'DAL weight': 0.17413468018803638,
#   'NFLX weight': 0.12446580031672724,
#   'AAPL weight': 0.06437184796188247,
#   'PFE weight': 0.288057303694203,
#   'BTC weight': 0.10558870954662393},
#  {'Returns': 64.31515661533038,
#   'Volatility': 0.2418753723943719,
#   'SHOP weight': 0.16752905969756648,
#   'TSLA weight': 0.027605887271070686,
#   'GOLD weight': 0.1968412558830213,
#   'DAL weight': 0.06308044740604407,
#   'NFLX weight': 0.2067599190202852,
#   'AAPL weight': 0.13252939942516687,
#   'PFE weight': 0.03618126716553643,
#   'BTC weight': 0.169472764131309},
#  {'Returns': 39.729867223608096,
#   'Volatility': 0.23064627960987366,
#   'SHOP weight': 0.16194367387957434,
#   'TSLA weight': 0.09857307413272838,
#   'GOLD weight': 0.14686330040448636,
#   'DAL weight': 0.3161598221693732,
#   'NFLX weight': 0.10897040059618411,
#   'AAPL weight': 0.0897888211904407,
#   'PFE weight': 0.021276322039234276,
#   'BTC weight': 0.056424585587978554},
#  {'Returns': 52.3439398003777,
#   'Volatility': 0.24323124122881454,
#   'SHOP weight': 0.22421695259714283,
#   'TSLA weight': 0.07054434652089547,
#   'GOLD weight': 0.18334319712053462,
#   'DAL weight': 0.14331935054344003,
#   'NFLX weight': 0.13187857050372917,
#   'AAPL weight': 0.1279778324903437,
#   'PFE weight': 0.007795637649611151,
#   'BTC weight': 0.11092411257430303},
#  {'Returns': 75.65628303641508,
#   'Volatility': 0.2725679898798336,
#   'SHOP weight': 0.16732496972422634,
#   'TSLA weight': 0.15248485137016635,
#   'GOLD weight': 0.0692937211259795,
#   'DAL weight': 0.05631627263788139,
#   'NFLX weight': 0.1523690460850057,
#   'AAPL weight': 0.17510768254258025,
#   'PFE weight': 0.061285079086201136,
#   'BTC weight': 0.16581837742795938},
#  {'Returns': 92.37805496393791,
#   'Volatility': 0.27533456699443953,
#   'SHOP weight': 0.08711232557657725,
#   'TSLA weight': 0.07547398249520672,
#   'GOLD weight': 0.1905481401459685,
#   'DAL weight': 0.06813431781765304,
#   'NFLX weight': 0.12485183219376543,
#   'AAPL weight': 0.1703372178045641,
#   'PFE weight': 0.022471309607011696,
#   'BTC weight': 0.26107087435925325},
#  {'Returns': 92.56902457834953,
#   'Volatility': 0.2824980766958834,
#   'SHOP weight': 0.1189871280105494,
#   'TSLA weight': 0.18726173524247586,
#   'GOLD weight': 0.1392122491415179,
#   'DAL weight': 0.0023679193043134278,
#   'NFLX weight': 0.07988938761087379,
#   'AAPL weight': 0.09651351540112729,
#   'PFE weight': 0.14717744001270366,
#   'BTC weight': 0.2285906252764387},
#  {'Returns': 72.92437370889506,
#   'Volatility': 0.23098317748772115,
#   'SHOP weight': 0.1177823694659527,
#   'TSLA weight': 0.042442702329688956,
#   'GOLD weight': 0.20444028979686443,
#   'DAL weight': 0.06267924131798061,
#   'NFLX weight': 0.2277898074188965,
#   'AAPL weight': 0.016968178595480162,
#   'PFE weight': 0.12927771566309773,
#   'BTC weight': 0.19861969541203897},
#  {'Returns': 88.39840226081489,
#   'Volatility': 0.3048583195897353,
#   'SHOP weight': 0.17238270961016322,
#   'TSLA weight': 0.23600685281986655,
#   'GOLD weight': 0.15412039946941253,
#   'DAL weight': 0.016590739940335435,
#   'NFLX weight': 0.06098519669776964,
#   'AAPL weight': 0.0766374711980281,
#   'PFE weight': 0.07567878200385793,
#   'BTC weight': 0.20759784826056663},
#  {'Returns': 19.578197246526308,
#   'Volatility': 0.20683180088060335,
#   'SHOP weight': 0.13508453620133992,
#   'TSLA weight': 0.05622337741531334,
#   'GOLD weight': 0.3122983105082068,
#   'DAL weight': 0.17396997073277232,
#   'NFLX weight': 0.012996218549393965,
#   'AAPL weight': 0.17066908861766084,
#   'PFE weight': 0.11907443453568771,
#   'BTC weight': 0.01968406343962509},
#  {'Returns': 35.98093443070212,
#   'Volatility': 0.20419665745746202,
#   'SHOP weight': 0.16170410171090163,
#   'TSLA weight': 0.07429093238052407,
#   'GOLD weight': 0.07858895667227683,
#   'DAL weight': 0.11529285543391841,
#   'NFLX weight': 0.13353980867702867,
#   'AAPL weight': 0.15937091837420478,
#   'PFE weight': 0.2449798120285298,
#   'BTC weight': 0.03223261472261583},
#  {'Returns': 56.05108792755984,
#   'Volatility': 0.21338983799019476,
#   'SHOP weight': 0.17163484811314675,
#   'TSLA weight': 0.0016605683292209789,
#   'GOLD weight': 0.18802878912123638,
#   'DAL weight': 0.0996425911216793,
#   'NFLX weight': 0.08238140656231083,
#   'AAPL weight': 0.20990944144617155,
#   'PFE weight': 0.11423195763194141,
#   'BTC weight': 0.13251039767429285},
#  {'Returns': 25.55679386852528,
#   'Volatility': 0.2728646256400157,
#   'SHOP weight': 0.058550783885291446,
#   'TSLA weight': 0.24859853744685156,
#   'GOLD weight': 0.12322684577037721,
#   'DAL weight': 0.2051449988040351,
#   'NFLX weight': 0.20000569886552733,
#   'AAPL weight': 0.13177259874507413,
#   'PFE weight': 0.03229954077501994,
#   'BTC weight': 0.0004009957078232733},
#  {'Returns': 89.00697321225111,
#   'Volatility': 0.2564071279047567,
#   'SHOP weight': 0.14741194581653344,
#   'TSLA weight': 0.08297825059568793,
#   'GOLD weight': 0.06614994175198287,
#   'DAL weight': 0.20323137912865397,
#   'NFLX weight': 0.06725243105189782,
#   'AAPL weight': 0.15318181055728092,
#   'PFE weight': 0.06684205926985921,
#   'BTC weight': 0.21295218182810394},
#  {'Returns': 20.32060787712134,
#   'Volatility': 0.2089722772669088,
#   'SHOP weight': 0.04338202578461577,
#   'TSLA weight': 0.006011162965232268,
#   'GOLD weight': 0.15494800941773493,
#   'DAL weight': 0.09388611688776828,
#   'NFLX weight': 0.31984095957617603,
#   'AAPL weight': 0.2432044501436473,
#   'PFE weight': 0.11059762705465698,
#   'BTC weight': 0.028129648170168445},
#  {'Returns': 57.892637043839265,
#   'Volatility': 0.24178295017429058,
#   'SHOP weight': 0.1612034000717355,
#   'TSLA weight': 0.12357648611906873,
#   'GOLD weight': 0.16157324528381545,
#   'DAL weight': 0.11487579603532823,
#   'NFLX weight': 0.08780496365359794,
#   'AAPL weight': 0.17001037428703145,
#   'PFE weight': 0.06010693526694985,
#   'BTC weight': 0.1208487992824728},
#  {'Returns': 24.826627121730013,
#   'Volatility': 0.1869123752127699,
#   'SHOP weight': 0.15235499991981793,
#   'TSLA weight': 0.01697287366967842,
#   'GOLD weight': 0.2250131649418618,
#   'DAL weight': 0.22457457149533813,
#   'NFLX weight': 0.12792611674504645,
#   'AAPL weight': 0.026815964150949282,
#   'PFE weight': 0.20030615478968208,
#   'BTC weight': 0.026036154287625908},
#  {'Returns': 61.22397339174321,
#   'Volatility': 0.22362367954436066,
#   'SHOP weight': 0.08643067196257367,
#   'TSLA weight': 0.1429910208128121,
#   'GOLD weight': 0.15050135232454412,
#   'DAL weight': 0.16382650414665645,
#   'NFLX weight': 0.10327823991187765,
#   'AAPL weight': 0.08268808864378144,
#   'PFE weight': 0.14089626777872802,
#   'BTC weight': 0.1293878544190266},
#  {'Returns': 26.45409264586805,
#   'Volatility': 0.20540287560341816,
#   'SHOP weight': 0.12059752325218694,
#   'TSLA weight': 0.028224696852515965,
#   'GOLD weight': 0.2960375697083228,
#   'DAL weight': 0.04960866713583732,
#   'NFLX weight': 0.16372661221683815,
#   'AAPL weight': 0.14970476483041467,
#   'PFE weight': 0.1366206994370264,
#   'BTC weight': 0.055479466566857816},
#  {'Returns': 76.71217089623777,
#   'Volatility': 0.2518486161959367,
#   'SHOP weight': 0.0758400183573387,
#   'TSLA weight': 0.16490974487316307,
#   'GOLD weight': 0.09836508031315046,
#   'DAL weight': 0.14212527227772706,
#   'NFLX weight': 0.17931471590959214,
#   'AAPL weight': 0.07364194667527241,
#   'PFE weight': 0.0879301982236022,
#   'BTC weight': 0.1778730233701541},
#  {'Returns': 61.87777389823825,
#   'Volatility': 0.27745517936473646,
#   'SHOP weight': 0.1744530233245731,
#   'TSLA weight': 0.2445856166593804,
#   'GOLD weight': 0.12616114296703537,
#   'DAL weight': 0.15174748293232282,
#   'NFLX weight': 0.07850553856263302,
#   'AAPL weight': 0.05126440820760768,
#   'PFE weight': 0.06475260733871496,
#   'BTC weight': 0.10853018000773268},
#  {'Returns': 53.609840109258144,
#   'Volatility': 0.19027016919670914,
#   'SHOP weight': 0.08118025970131286,
#   'TSLA weight': 0.02459641859174329,
#   'GOLD weight': 0.10162310109227647,
#   'DAL weight': 0.23140610436049736,
#   'NFLX weight': 0.133969354366611,
#   'AAPL weight': 0.13476771973141247,
#   'PFE weight': 0.18315004037434562,
#   'BTC weight': 0.109307001781801},
#  {'Returns': 76.81428759155622,
#   'Volatility': 0.24208916216596052,
#   'SHOP weight': 0.1438413775079777,
#   'TSLA weight': 0.09647412326839762,
#   'GOLD weight': 0.05713508028600385,
#   'DAL weight': 0.16216366954798378,
#   'NFLX weight': 0.2549564088428713,
#   'AAPL weight': 0.00988458013981807,
#   'PFE weight': 0.09881487680366981,
#   'BTC weight': 0.17672988360327785},
#  {'Returns': 61.673333297201744,
#   'Volatility': 0.23057230029874276,
#   'SHOP weight': 0.06606960603744616,
#   'TSLA weight': 0.14244147619164035,
#   'GOLD weight': 0.10332591572309195,
#   'DAL weight': 0.15769346728105663,
#   'NFLX weight': 0.1589948164970332,
#   'AAPL weight': 0.13982778024365908,
#   'PFE weight': 0.10199665335244844,
#   'BTC weight': 0.12965028467362422},
#  {'Returns': 48.501406012168,
#   'Volatility': 0.2484050952326615,
#   'SHOP weight': 0.1117479976379024,
#   'TSLA weight': 0.18028339144076605,
#   'GOLD weight': 0.17778143248639638,
#   'DAL weight': 0.11423824655669235,
#   'NFLX weight': 0.12067437082990712,
#   'AAPL weight': 0.15033108927189576,
#   'PFE weight': 0.05476215481364544,
#   'BTC weight': 0.09018131696279448},
#  {'Returns': 83.20894210050334,
#   'Volatility': 0.3185460112340732,
#   'SHOP weight': 0.2512465969149171,
#   'TSLA weight': 0.22752968023663422,
#   'GOLD weight': 0.1514664359940528,
#   'DAL weight': 0.015786855244100013,
#   'NFLX weight': 0.05266572539267909,
#   'AAPL weight': 0.09250791545316822,
#   'PFE weight': 0.02294430897783597,
#   'BTC weight': 0.18585248178661257},
#  {'Returns': 50.56554022889064,
#   'Volatility': 0.2255453763281806,
#   'SHOP weight': 0.12491452109396793,
#   'TSLA weight': 0.13795541083063978,
#   'GOLD weight': 0.2826801298176916,
#   'DAL weight': 0.14948484759219482,
#   'NFLX weight': 0.00930413615067839,
#   'AAPL weight': 0.06384197013603346,
#   'PFE weight': 0.1220500614051967,
#   'BTC weight': 0.10976892297359735},
#  {'Returns': 40.59880567613773,
#   'Volatility': 0.2049638340914298,
#   'SHOP weight': 0.19582592190368106,
#   'TSLA weight': 0.03142001842096148,
#   'GOLD weight': 0.025652406034368077,
#   'DAL weight': 0.24602112364011264,
#   'NFLX weight': 0.22316506203965716,
#   'AAPL weight': 0.041683856146412394,
#   'PFE weight': 0.1921107449074373,
#   'BTC weight': 0.04412086690736991},
#  {'Returns': 50.2387203298161,
#   'Volatility': 0.26233912891696376,
#   'SHOP weight': 0.19499462900573034,
#   'TSLA weight': 0.20277379267449042,
#   'GOLD weight': 0.13926424157153874,
#   'DAL weight': 0.12968243507419716,
#   'NFLX weight': 0.056139219799715576,
#   'AAPL weight': 0.11586537226416743,
#   'PFE weight': 0.08746399371918566,
#   'BTC weight': 0.07381631589097469},
#  {'Returns': 66.13686968612384,
#   'Volatility': 0.21515642543795427,
#   'SHOP weight': 0.17297773184084586,
#   'TSLA weight': 0.10681026601865001,
#   'GOLD weight': 0.006680280307729658,
#   'DAL weight': 0.2553790550009299,
#   'NFLX weight': 0.030988428405654314,
# ...
#   'PFE weight': 0.12498338129637848,
#   'BTC weight': 0.21727520998954658},
#  {'Returns': 65.94776954173767,
#   'Volatility': 0.20607612159749572,
#   'SHOP weight': 0.15339245306237045,
#   'TSLA weight': 0.019641434345999725,
#   'GOLD weight': 0.06747044105078676,
#   'DAL weight': 0.15554417021090142,
#   'NFLX weight': 0.15956011952762278,
#   'AAPL weight': 0.11973661155573224,
#   'PFE weight': 0.1814289720289571,
#   'BTC weight': 0.14322579821762949},
#  {'Returns': 62.700543176821256,
#   'Volatility': 0.271707190719473,
#   'SHOP weight': 0.215998565932763,
#   'TSLA weight': 0.15672094675301568,
#   'GOLD weight': 0.07808597209214597,
#   'DAL weight': 0.1097412279546023,
#   'NFLX weight': 0.17056332962949367,
#   'AAPL weight': 0.12082613908078804,
#   'PFE weight': 0.029061367553771603,
#   'BTC weight': 0.11900245100341986},
#  {'Returns': 76.82787110283496,
#   'Volatility': 0.21789808532968005,
#   'SHOP weight': 0.0788243638267312,
#   'TSLA weight': 0.012474688768348867,
#   'GOLD weight': 0.1880522813343987,
#   'DAL weight': 0.07944095787061288,
#   'NFLX weight': 0.016983986860762034,
#   'AAPL weight': 0.19196285867048155,
#   'PFE weight': 0.23050862916254306,
#   'BTC weight': 0.2017522335061218},
#  {'Returns': 69.2602642245434,
#   'Volatility': 0.2353015694295731,
#   'SHOP weight': 0.13821390648720278,
#   'TSLA weight': 0.15052447403400107,
#   'GOLD weight': 0.07454620986195576,
#   'DAL weight': 0.15968492983933025,
#   'NFLX weight': 0.08960799801000643,
#   'AAPL weight': 0.09148290671196055,
#   'PFE weight': 0.1592115384553723,
#   'BTC weight': 0.1367280366001708},
#  {'Returns': 90.75241867507766,
#   'Volatility': 0.2567515767404794,
#   'SHOP weight': 0.06524902851821617,
#   'TSLA weight': 0.14369061567382088,
#   'GOLD weight': 0.10702881377214693,
#   'DAL weight': 0.11844892519294924,
#   'NFLX weight': 0.08590242503840759,
#   'AAPL weight': 0.10546798545844716,
#   'PFE weight': 0.1499447444661826,
#   'BTC weight': 0.22426746187982935},
#  {'Returns': 31.862971846542617,
#   'Volatility': 0.20100892304849483,
#   'SHOP weight': 0.15427350220248187,
#   'TSLA weight': 0.06826503169822916,
#   'GOLD weight': 0.12639371997267326,
#   'DAL weight': 0.2201829020323419,
#   'NFLX weight': 0.009252736647146442,
#   'AAPL weight': 0.18475400734248618,
#   'PFE weight': 0.2167278371870346,
#   'BTC weight': 0.020150262917606562},
#  {'Returns': 46.594694342297146,
#   'Volatility': 0.20278747588428217,
#   'SHOP weight': 0.027870491365542188,
#   'TSLA weight': 0.09945033006187554,
#   'GOLD weight': 0.1649206807127659,
#   'DAL weight': 0.07886402166676425,
#   'NFLX weight': 0.12808637730865716,
#   'AAPL weight': 0.21393566062733504,
#   'PFE weight': 0.19181070289026186,
#   'BTC weight': 0.09506173536679816},
#  {'Returns': 30.308973414316572,
#   'Volatility': 0.1950061518284082,
#   'SHOP weight': 0.08767120280837998,
#   'TSLA weight': 0.007174545272589023,
#   'GOLD weight': 0.1126707675506275,
#   'DAL weight': 0.37466016128595797,
#   'NFLX weight': 0.13655643465895997,
#   'AAPL weight': 0.02241012166909297,
#   'PFE weight': 0.23198095569213206,
#   'BTC weight': 0.026875811062260523},
#  {'Returns': 105.14058638263893,
#   'Volatility': 0.30684692863230933,
#   'SHOP weight': 0.12512258988656658,
#   'TSLA weight': 0.26166790103679455,
#   'GOLD weight': 0.06432087212408238,
#   'DAL weight': 0.0731316825887568,
#   'NFLX weight': 0.03523588250195769,
#   'AAPL weight': 0.01775642113031487,
#   'PFE weight': 0.1810851417904528,
#   'BTC weight': 0.24167950894107434},
#  {'Returns': 83.84787881229686,
#   'Volatility': 0.27177530869680144,
#   'SHOP weight': 0.16069895444346072,
#   'TSLA weight': 0.16531377789193216,
#   'GOLD weight': 0.12342983938506367,
#   'DAL weight': 0.07804687658218333,
#   'NFLX weight': 0.00821608919547897,
#   'AAPL weight': 0.17245709016171065,
#   'PFE weight': 0.09951362850095902,
#   'BTC weight': 0.19232374383921153},
#  {'Returns': 48.55731496060302,
#   'Volatility': 0.20504897825006815,
#   'SHOP weight': 0.1047755079435439,
#   'TSLA weight': 0.08367777080161623,
#   'GOLD weight': 0.1112499693492759,
#   'DAL weight': 0.21419327100373015,
#   'NFLX weight': 0.08469761104785928,
#   'AAPL weight': 0.1707899447704114,
#   'PFE weight': 0.14695085056319646,
#   'BTC weight': 0.0836650745203667},
#  {'Returns': 66.1519847792117,
#   'Volatility': 0.26172922467183185,
#   'SHOP weight': 0.01796361063154212,
#   'TSLA weight': 0.2322954865100796,
#   'GOLD weight': 0.15539768984301555,
#   'DAL weight': 0.18300476884589656,
#   'NFLX weight': 0.13059181468563977,
#   'AAPL weight': 0.07500650567392358,
#   'PFE weight': 0.06028913950170408,
#   'BTC weight': 0.14545098430819875},
#  {'Returns': 88.9416329932836,
#   'Volatility': 0.25366304122815364,
#   'SHOP weight': 0.1337249523495209,
#   'TSLA weight': 0.006998809304440718,
#   'GOLD weight': 0.15663398927876945,
#   'DAL weight': 0.0809529085988391,
#   'NFLX weight': 0.024130712988673142,
#   'AAPL weight': 0.25657545957431344,
#   'PFE weight': 0.10088180730580608,
#   'BTC weight': 0.24010136059963713},
#  {'Returns': 49.20949269902194,
#   'Volatility': 0.22944387848811812,
#   'SHOP weight': 0.18452806206335923,
#   'TSLA weight': 0.011476527863018799,
#   'GOLD weight': 0.16298838174082975,
#   'DAL weight': 0.012345588652369711,
#   'NFLX weight': 0.16397056150153844,
#   'AAPL weight': 0.2390295230973045,
#   'PFE weight': 0.11658577946061355,
#   'BTC weight': 0.10907557562096616},
#  {'Returns': 72.13596703830382,
#   'Volatility': 0.28231433494227665,
#   'SHOP weight': 0.1409400372310024,
#   'TSLA weight': 0.2076386781200278,
#   'GOLD weight': 0.01763967743405445,
#   'DAL weight': 0.00374178728360903,
#   'NFLX weight': 0.1704495203250849,
#   'AAPL weight': 0.18825943433185216,
#   'PFE weight': 0.13231171883299206,
#   'BTC weight': 0.13901914644137728},
#  {'Returns': 75.48275354762305,
#   'Volatility': 0.2474344504721604,
#   'SHOP weight': 0.13064988838333436,
#   'TSLA weight': 0.1316043355536479,
#   'GOLD weight': 0.025768936552198803,
#   'DAL weight': 0.02403221940311927,
#   'NFLX weight': 0.13202450024007015,
#   'AAPL weight': 0.20110019726419537,
#   'PFE weight': 0.19731160294867392,
#   'BTC weight': 0.15750831965476023},
#  {'Returns': 41.771077035231926,
#   'Volatility': 0.24098328310598974,
#   'SHOP weight': 0.1871195175543886,
#   'TSLA weight': 0.16172714757740872,
#   'GOLD weight': 0.05382398264125824,
#   'DAL weight': 0.15774839525116394,
#   'NFLX weight': 0.18863237050445733,
#   'AAPL weight': 0.05261893998234209,
#   'PFE weight': 0.1597407999292666,
#   'BTC weight': 0.03858884655971438},
#  {'Returns': 85.67207172419532,
#   'Volatility': 0.2866227840894001,
#   'SHOP weight': 0.11333718477774031,
#   'TSLA weight': 0.20687337424663055,
#   'GOLD weight': 0.13939751779117926,
#   'DAL weight': 0.0870814687596903,
#   'NFLX weight': 0.11566091083814499,
#   'AAPL weight': 0.09286063789800116,
#   'PFE weight': 0.03741024029770333,
#   'BTC weight': 0.2073786653909102},
#  {'Returns': 55.60361001448064,
#   'Volatility': 0.2102377258798922,
#   'SHOP weight': 0.10986962020659219,
#   'TSLA weight': 0.10873569124033608,
#   'GOLD weight': 0.06824743982786814,
#   'DAL weight': 0.16587336298885674,
#   'NFLX weight': 0.07275588297056307,
#   'AAPL weight': 0.17747104346452428,
#   'PFE weight': 0.20235917795134709,
#   'BTC weight': 0.09468778134991251},
#  {'Returns': 125.18501217807501,
#   'Volatility': 0.31511587531314555,
#   'SHOP weight': 0.021838479726970533,
#   'TSLA weight': 0.10817796610323162,
#   'GOLD weight': 0.08767240783295356,
#   'DAL weight': 0.10232237650675484,
#   'NFLX weight': 0.056313408648047625,
#   'AAPL weight': 0.12510650989084016,
#   'PFE weight': 0.15294823533761556,
#   'BTC weight': 0.34562061595358606},
#  {'Returns': 56.5377062366847,
#   'Volatility': 0.2538853223715368,
#   'SHOP weight': 0.12895622462876036,
#   'TSLA weight': 0.17326165225430196,
#   'GOLD weight': 0.11586043590791055,
#   'DAL weight': 0.15715208297232416,
#   'NFLX weight': 0.17343041354851857,
#   'AAPL weight': 0.11301957233675515,
#   'PFE weight': 0.029687065463320964,
#   'BTC weight': 0.10863255288810823},
#  {'Returns': 79.9018302696746,
#   'Volatility': 0.2546507702454868,
#   'SHOP weight': 0.02097685311093155,
#   'TSLA weight': 0.18968923101211715,
#   'GOLD weight': 0.13680875348662694,
#   'DAL weight': 0.048449690157414294,
#   'NFLX weight': 0.137092719708084,
#   'AAPL weight': 0.10456307887252701,
#   'PFE weight': 0.1685502173744203,
#   'BTC weight': 0.1938694562778787},
#  {'Returns': 54.06493254122699,
#   'Volatility': 0.28569204675756327,
#   'SHOP weight': 0.022895391453512656,
#   'TSLA weight': 0.2832031985524544,
#   'GOLD weight': 0.0011028653675822864,
#   'DAL weight': 0.08077597373628076,
#   'NFLX weight': 0.23982077314961275,
#   'AAPL weight': 0.17489203996996347,
#   'PFE weight': 0.12080895366431818,
#   'BTC weight': 0.07650080410627544},
#  {'Returns': 61.24825517493122,
#   'Volatility': 0.23068910967405357,
#   'SHOP weight': 0.07266386676333396,
#   'TSLA weight': 0.15217148512090176,
#   'GOLD weight': 0.12256748497913701,
#   'DAL weight': 0.14113489510054708,
#   'NFLX weight': 0.11527187319530081,
#   'AAPL weight': 0.14753694388186844,
#   'PFE weight': 0.12157108022439304,
#   'BTC weight': 0.12708237073451786},
#  {'Returns': 81.98141177572195,
#   'Volatility': 0.27990954790407735,
#   'SHOP weight': 0.01913223576362813,
#   'TSLA weight': 0.19445540591629043,
#   'GOLD weight': 0.0425827526220774,
#   'DAL weight': 0.05883240076310766,
#   'NFLX weight': 0.2645520022022758,
#   'AAPL weight': 0.16497692557249716,
#   'PFE weight': 0.059924194389456266,
#   'BTC weight': 0.19554408277066712},
#  {'Returns': 41.43889951459936,
#   'Volatility': 0.2764488599389155,
#   'SHOP weight': 0.20204468299846584,
#   'TSLA weight': 0.20947577865421624,
#   'GOLD weight': 0.1606855089067612,
#   'DAL weight': 0.15106806671826542,
#   'NFLX weight': 0.20987117699748192,
#   'AAPL weight': 0.0017034519320437177,
#   'PFE weight': 0.009031431297170264,
#   'BTC weight': 0.05611990249559534},
#  {'Returns': 55.84011953071813,
#   'Volatility': 0.21697042702685876,
#   'SHOP weight': 0.01890433827879681,
#   'TSLA weight': 0.12952841545059743,
#   'GOLD weight': 0.08875959481424366,
#   'DAL weight': 0.19599164849597023,
#   'NFLX weight': 0.19866973673909366,
#   'AAPL weight': 0.12369519436865001,
#   'PFE weight': 0.13190324915834314,
#   'BTC weight': 0.11254782269430508},
#  {'Returns': 41.8216469496588,
#   'Volatility': 0.25556561154788304,
#   'SHOP weight': 0.16566212279749867,
#   'TSLA weight': 0.16762825219421978,
#   'GOLD weight': 0.153084705202554,
#   'DAL weight': 0.14030134930663413,
#   'NFLX weight': 0.21309167436649398,
#   'AAPL weight': 0.06788355750836128,
#   'PFE weight': 0.02748112016557942,
#   'BTC weight': 0.06486721845865881},
#  {'Returns': 41.80173522072437,
#   'Volatility': 0.27550920640090304,
#   'SHOP weight': 0.0353845090316193,
#   'TSLA weight': 0.27353920421445876,
#   'GOLD weight': 0.23157407563827842,
#   'DAL weight': 0.03705474150620628,
#   'NFLX weight': 0.04923723435704347,
#   'AAPL weight': 0.20900035967151423,
#   'PFE weight': 0.09635941083534524,
#   'BTC weight': 0.06785046474553437},
#  {'Returns': 84.48151077436901,
#   'Volatility': 0.26352375571637526,
#   'SHOP weight': 0.003680014085017863,
#   'TSLA weight': 0.12632320084054166,
#   'GOLD weight': 0.19867429997995276,
#   'DAL weight': 0.24627423545399404,
#   'NFLX weight': 0.09419471150638718,
#   'AAPL weight': 0.0647340413211254,
#   'PFE weight': 0.03798467416846616,
#   'BTC weight': 0.22813482264451498},
#  {'Returns': 33.313378078640014,
#   'Volatility': 0.22601365421707917,
#   'SHOP weight': 0.1829056957127035,
#   'TSLA weight': 0.06745697003599455,
#   'GOLD weight': 0.03744007802049064,
#   'DAL weight': 0.0367680024417937,
#   'NFLX weight': 0.2511779129131888,
#   'AAPL weight': 0.14825886227732354,
#   'PFE weight': 0.2531899494779866,
#   'BTC weight': 0.02280252912051865},
#  {'Returns': 36.658333529495025,
#   'Volatility': 0.2655539739276776,
#   'SHOP weight': 0.2568530210678597,
#   'TSLA weight': 0.14151921135074352,
#   'GOLD weight': 0.08458587716008412,
#   'DAL weight': 0.22464343531515696,
#   'NFLX weight': 0.05379319112639547,
#   'AAPL weight': 0.19162599450059886,
#   'PFE weight': 0.025610926213099548,
#   'BTC weight': 0.021368343266061726},
#  {'Returns': 54.822191110514,
#   'Volatility': 0.1994951381462211,
#   'SHOP weight': 0.21029594188290873,
#   'TSLA weight': 0.016708853395066888,
#   'GOLD weight': 0.04348367215580874,
#   'DAL weight': 0.2141755279710041,
#   'NFLX weight': 0.14761552103744807,
#   'AAPL weight': 0.055456832895349084,
#   'PFE weight': 0.2199999010606734,
#   'BTC weight': 0.09226374960174105},
#  {'Returns': 50.20227011439547,
#   'Volatility': 0.21115555718022938,
#   'SHOP weight': 0.25149304205741774,
#   'TSLA weight': 0.013106724155870707,
#   'GOLD weight': 0.1055052487101691,
#   'DAL weight': 0.3077814475750394,
#   'NFLX weight': 0.07663181236058103,
#   'AAPL weight': 0.0035031972520867937,
#   'PFE weight': 0.16164694646528094,
#   'BTC weight': 0.08033158142355429},
#  {'Returns': 24.906467149183285,
#   'Volatility': 0.24331956893248408,
#   'SHOP weight': 0.0992119967738759,
#   'TSLA weight': 0.06434279802402051,
#   'GOLD weight': 0.05612523409923027,
#   'DAL weight': 0.031820073102112156,
#   'NFLX weight': 0.35493563714964776,
#   'AAPL weight': 0.2444340030056147,
#   'PFE weight': 0.13264679397841855,
#   'BTC weight': 0.016483463867080158},
#  {'Returns': 53.952283110620904,
#   'Volatility': 0.24861042444133608,
#   'SHOP weight': 0.13161666895433438,
#   'TSLA weight': 0.1444740538932536,
#   'GOLD weight': 0.06886130557613127,
#   'DAL weight': 0.1317589580319113,
#   'NFLX weight': 0.18191286924379027,
#   'AAPL weight': 0.1930885788772059,
#   'PFE weight': 0.052419062111635474,
#   'BTC weight': 0.0958685033117377},
#  {'Returns': 31.93113712409705,
#   'Volatility': 0.25251522128728,
#   'SHOP weight': 0.14307330072106053,
#   'TSLA weight': 0.1904100911062336,
#   'GOLD weight': 0.17097214587405984,
#   'DAL weight': 0.05482197215137312,
#   'NFLX weight': 0.1179396894777473,
#   'AAPL weight': 0.15952521032910852,
#   'PFE weight': 0.13689507252882102,
#   'BTC weight': 0.026362517811596053},
#  {'Returns': 37.77609938433686,
#   'Volatility': 0.21406231415276342,
#   'SHOP weight': 0.010260789518563868,
#   'TSLA weight': 0.1225173087753969,
#   'GOLD weight': 0.045622033768983425,
#   'DAL weight': 0.12267570064372282,
#   'NFLX weight': 0.21332673291287657,
#   'AAPL weight': 0.2489515387372071,
#   'PFE weight': 0.19054754568636662,
#   'BTC weight': 0.04609834995688272},
#  {'Returns': 20.599683243229705,
#   'Volatility': 0.227533868701547,
#   'SHOP weight': 0.04422977303463691,
#   'TSLA weight': 0.10848317146309772,
#   'GOLD weight': 0.22221326139489658,
#   'DAL weight': 0.1791275085850893,
#   'NFLX weight': 0.1710444831887193,
#   'AAPL weight': 0.24196753832262566,
#   'PFE weight': 0.011393522074474728,
#   'BTC weight': 0.021540741936459742},
#  {'Returns': 51.542560450686274,
#   'Volatility': 0.2266174372477731,
#   'SHOP weight': 0.152620509016822,
#   'TSLA weight': 0.08064326763669252,
#   'GOLD weight': 0.11336470138029041,
#   'DAL weight': 0.16043990319750734,
#   'NFLX weight': 0.1536777537580839,
#   'AAPL weight': 0.1797372892791844,
#   'PFE weight': 0.06006686062928465,
#   'BTC weight': 0.09944971510213477},
#  {'Returns': 70.95453883309452,
#   'Volatility': 0.23783242019608528,
#   'SHOP weight': 0.12037926404368476,
#   'TSLA weight': 0.0901668468551579,
#   'GOLD weight': 0.08991895870272544,
#   'DAL weight': 0.18086549798780593,
#   'NFLX weight': 0.12721553237051142,
#   'AAPL weight': 0.17770974072476217,
#   'PFE weight': 0.05230719385887687,
#   'BTC weight': 0.1614369654564755},
#  {'Returns': 85.51207342162274,
#   'Volatility': 0.28880151226533074,
#   'SHOP weight': 0.2188991903761281,
#   'TSLA weight': 0.19111442729830547,
#   'GOLD weight': 0.058043652302707784,
#   'DAL weight': 0.049245344569668545,
#   'NFLX weight': 0.12570518950112913,
#   'AAPL weight': 0.06649820968753715,
#   'PFE weight': 0.10652653425077982,
#   'BTC weight': 0.18396745201374384},
#  {'Returns': 86.20472423023944,
#   'Volatility': 0.2700713112910251,
#   'SHOP weight': 0.19142718049806304,
#   'TSLA weight': 0.16451825817354426,
#   'GOLD weight': 0.13701611251903648,
#   'DAL weight': 0.11254924858845988,
#   'NFLX weight': 0.05992847464914711,
#   'AAPL weight': 0.027535754429994803,
#   'PFE weight': 0.10637878126021837,
#   'BTC weight': 0.20064618988153593}]

# %%
portfolios
# Out:
#        Returns  Volatility  SHOP weight  TSLA weight  GOLD weight  DAL weight  \
# 0    94.673245    0.252443     0.015937     0.046848     0.087014    0.031141
# 1    85.296421    0.269718     0.030918     0.125448     0.167974    0.006450
# 2    54.242426    0.227712     0.146891     0.037476     0.145605    0.105341
# 3    88.691485    0.266867     0.006851     0.107595     0.234675    0.220140
# 4    52.101454    0.237966     0.050442     0.136584     0.043077    0.275388
# ..         ...         ...          ...          ...          ...         ...
# 995  20.599683    0.227534     0.044230     0.108483     0.222213    0.179128
# 996  51.542560    0.226617     0.152621     0.080643     0.113365    0.160440
# 997  70.954539    0.237832     0.120379     0.090167     0.089919    0.180865
# 998  85.512073    0.288802     0.218899     0.191114     0.058044    0.049245
# 999  86.204724    0.270071     0.191427     0.164518     0.137016    0.112549
#
#      NFLX weight  AAPL weight  PFE weight  BTC weight
# 0       0.258564     0.108521    0.191271    0.260703
# 1       0.237160     0.121942    0.074102    0.236006
# 2       0.197106     0.197368    0.045179    0.125034
# 3       0.002816     0.100178    0.082487    0.245257
# 4       0.110974     0.251148    0.046218    0.086168
# ..           ...          ...         ...         ...
# 995     0.171044     0.241968    0.011394    0.021541
# 996     0.153678     0.179737    0.060067    0.099450
# 997     0.127216     0.177710    0.052307    0.161437
# 998     0.125705     0.066498    0.106527    0.183967
# 999     0.059928     0.027536    0.106379    0.200646
#
# [1000 rows x 10 columns]

# %%
portfolios.describe()
# Out:
#            Returns   Volatility  SHOP weight  TSLA weight  GOLD weight  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     60.199571     0.244196     0.121223     0.128201     0.123205
# std      21.800925     0.028769     0.069440     0.073159     0.072113
# min       6.807647     0.180218     0.000022     0.000115     0.000038
# 25%      43.475971     0.223392     0.066001     0.071587     0.065109
# 50%      60.657575     0.242981     0.120778     0.127694     0.120902
# 75%      76.771589     0.262529     0.168716     0.182976     0.177930
# max     132.166460     0.355005     0.396037     0.392598     0.372055
#
#         DAL weight  NFLX weight  AAPL weight   PFE weight   BTC weight
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.121306     0.126836     0.128816     0.127003     0.123411
# std       0.070265     0.071870     0.070926     0.069960     0.072185
# min       0.000273     0.000042     0.000067     0.000353     0.000401
# 25%       0.063107     0.072229     0.070762     0.071253     0.065157
# 50%       0.120184     0.125975     0.129823     0.128443     0.121382
# 75%       0.172318     0.175460     0.177449     0.181261     0.178427
# max       0.374660     0.387392     0.398865     0.364124     0.366296

# %% [markdown]
# for index, row in portfolios.iterrows():
#     portf_dict = [row]
#     print(portf_dict)

# %%
# convert into JSON and save it as a separate file:
#portf = portfolios.to_json()
#port = json.dumps(port)
with open('../Data/portfolio_data.json', 'w') as outfile:
    json.dump(portf, outfile)

portf
# Out:
# [{'Returns': 94.67324508848252,
#   'Volatility': 0.2524434142625725,
#   'SHOP weight': 0.015936936488438063,
#   'TSLA weight': 0.04684843350445664,
#   'GOLD weight': 0.08701429304623565,
#   'DAL weight': 0.031140853306584244,
#   'NFLX weight': 0.25856429424799804,
#   'AAPL weight': 0.10852124472543646,
#   'PFE weight': 0.19127144109392655,
#   'BTC weight': 0.26070250358692426},
#  {'Returns': 85.29642093223869,
#   'Volatility': 0.2697182801658235,
#   'SHOP weight': 0.030918081066560493,
#   'TSLA weight': 0.12544760821794115,
#   'GOLD weight': 0.16797414256141552,
#   'DAL weight': 0.006450281073816366,
#   'NFLX weight': 0.23715972445015018,
#   'AAPL weight': 0.12194198140635434,
#   'PFE weight': 0.07410207258279478,
#   'BTC weight': 0.23600610864096713},
#  {'Returns': 54.24242610298248,
#   'Volatility': 0.22771153876950082,
#   'SHOP weight': 0.14689082952931076,
#   'TSLA weight': 0.037476284277053636,
#   'GOLD weight': 0.14560526649630068,
#   'DAL weight': 0.1053410146753775,
#   'NFLX weight': 0.19710594478567797,
#   'AAPL weight': 0.19736754829927364,
#   'PFE weight': 0.04517916062748031,
#   'BTC weight': 0.12503395130952558},
#  {'Returns': 88.69148476169305,
#   'Volatility': 0.2668665650028951,
#   'SHOP weight': 0.006850896519702656,
#   'TSLA weight': 0.10759546573212125,
#   'GOLD weight': 0.23467542791500487,
#   'DAL weight': 0.22014019205558205,
#   'NFLX weight': 0.0028157303475953924,
#   'AAPL weight': 0.10017838162236041,
#   'PFE weight': 0.08248720012994984,
#   'BTC weight': 0.24525670567768343},
#  {'Returns': 52.101454013672566,
#   'Volatility': 0.23796590411773078,
#   'SHOP weight': 0.05044199263411328,
#   'TSLA weight': 0.1365840919986922,
#   'GOLD weight': 0.043077213105440874,
#   'DAL weight': 0.27538834255638117,
#   'NFLX weight': 0.11097376516111712,
#   'AAPL weight': 0.2511484667659714,
#   'PFE weight': 0.04621826267961044,
#   'BTC weight': 0.08616786509867355},
#  {'Returns': 53.952754337563306,
#   'Volatility': 0.27128091303274604,
#   'SHOP weight': 0.2514756288159008,
#   'TSLA weight': 0.14493416681290008,
#   'GOLD weight': 0.04467263410181042,
#   'DAL weight': 0.04564389903089309,
#   'NFLX weight': 0.026699543643654976,
#   'AAPL weight': 0.2802396204063896,
#   'PFE weight': 0.13370650775133056,
#   'BTC weight': 0.07262799943712045},
#  {'Returns': 59.34343457366036,
#   'Volatility': 0.2377850392932025,
#   'SHOP weight': 0.1597671439368976,
#   'TSLA weight': 0.06802342701754657,
#   'GOLD weight': 0.0909742007865497,
#   'DAL weight': 0.20237136687115342,
#   'NFLX weight': 0.19746389125580152,
#   'AAPL weight': 0.15223548466594689,
#   'PFE weight': 0.002479416237483932,
#   'BTC weight': 0.12668506922862033},
#  {'Returns': 75.48702537715077,
#   'Volatility': 0.2662932841614614,
#   'SHOP weight': 0.1569143450348114,
#   'TSLA weight': 0.1656203142925539,
#   'GOLD weight': 0.09524138905312894,
#   'DAL weight': 0.06402591454042195,
#   'NFLX weight': 0.09692846757404949,
#   'AAPL weight': 0.16649102923675402,
#   'PFE weight': 0.09027201414122843,
#   'BTC weight': 0.16450652612705194},
#  {'Returns': 39.78701541199331,
#   'Volatility': 0.22235885426470334,
#   'SHOP weight': 0.16131645494758762,
#   'TSLA weight': 0.08073615991572512,
#   'GOLD weight': 0.15953230776198088,
#   'DAL weight': 0.19581625948154724,
#   'NFLX weight': 0.18968713805858234,
#   'AAPL weight': 0.09513391589847565,
#   'PFE weight': 0.0503405454442078,
#   'BTC weight': 0.06743721849189334},
#  {'Returns': 67.97553193664459,
#   'Volatility': 0.2233677111766801,
#   'SHOP weight': 0.05648003430284858,
#   'TSLA weight': 0.03302143545890347,
#   'GOLD weight': 0.212302060315255,
#   'DAL weight': 0.16660972635346508,
#   'NFLX weight': 0.1265178135568719,
#   'AAPL weight': 0.15795953148173295,
#   'PFE weight': 0.06156581055509205,
#   'BTC weight': 0.18554358797583098},
#  {'Returns': 82.73436483538806,
#   'Volatility': 0.2587101710498078,
#   'SHOP weight': 0.02769751704223709,
#   'TSLA weight': 0.13179091825753417,
#   'GOLD weight': 0.20937769719903732,
#   'DAL weight': 0.027956140535940154,
#   'NFLX weight': 0.0968527011079957,
#   'AAPL weight': 0.16907632245572557,
#   'PFE weight': 0.11251673594489256,
#   'BTC weight': 0.22473196745663732},
#  {'Returns': 31.919026059548386,
#   'Volatility': 0.24314714235887305,
#   'SHOP weight': 0.01984789820235718,
#   'TSLA weight': 0.11157125409662236,
#   'GOLD weight': 0.007703599116811644,
#   'DAL weight': 0.24361199106563894,
#   'NFLX weight': 0.347681827592258,
#   'AAPL weight': 0.2183813302138029,
#   'PFE weight': 0.02005788440409093,
#   'BTC weight': 0.031144215308418127},
#  {'Returns': 25.099365551192083,
#   'Volatility': 0.21985305290370363,
#   'SHOP weight': 0.01896576886619867,
#   'TSLA weight': 0.10945654587156278,
#   'GOLD weight': 0.2177232691647642,
#   'DAL weight': 0.1592602584816989,
#   'NFLX weight': 0.28680328361397806,
#   'AAPL weight': 0.1173563574014793,
#   'PFE weight': 0.048274879244181425,
#   'BTC weight': 0.04215963735613661},
#  {'Returns': 51.7630916451333,
#   'Volatility': 0.24137919197097615,
#   'SHOP weight': 0.033184268245242086,
#   'TSLA weight': 0.15846484202571723,
#   'GOLD weight': 0.14414276877850868,
#   'DAL weight': 0.07105997283601839,
#   'NFLX weight': 0.24548982987928766,
#   'AAPL weight': 0.16318821141362452,
#   'PFE weight': 0.07250205568429438,
#   'BTC weight': 0.1119680511373071},
#  {'Returns': 72.93137065037003,
#   'Volatility': 0.25190611781933,
#   'SHOP weight': 0.06230480123177121,
#   'TSLA weight': 0.1685499621625833,
#   'GOLD weight': 0.08575137139734383,
#   'DAL weight': 0.06092289798979656,
#   'NFLX weight': 0.08470705595639733,
#   'AAPL weight': 0.24007546195346952,
#   'PFE weight': 0.13799864470637307,
#   'BTC weight': 0.15968980460226515},
#  {'Returns': 37.81614321723278,
#   'Volatility': 0.18171241387264828,
#   'SHOP weight': 0.07438852555951908,
#   'TSLA weight': 0.02116651630728685,
#   'GOLD weight': 0.07241233472535495,
#   'DAL weight': 0.19144726620107147,
#   'NFLX weight': 0.30704976748145707,
#   'AAPL weight': 0.023283710212305835,
#   'PFE weight': 0.2526807569181425,
#   'BTC weight': 0.05757112259486226},
#  {'Returns': 82.67336639654013,
#   'Volatility': 0.27532672418674253,
#   'SHOP weight': 0.19807528322253945,
#   'TSLA weight': 0.16288722121538518,
#   'GOLD weight': 0.03246144628539378,
#   'DAL weight': 0.17333315050242368,
#   'NFLX weight': 0.023959586091485678,
#   'AAPL weight': 0.1798462935131276,
#   'PFE weight': 0.059857721461260886,
#   'BTC weight': 0.16957929770838368},
#  {'Returns': 53.780978778695896,
#   'Volatility': 0.24918324798228683,
#   'SHOP weight': 0.1398090139706632,
#   'TSLA weight': 0.14328448651561945,
#   'GOLD weight': 0.060025308088850086,
#   'DAL weight': 0.19554232983641415,
#   'NFLX weight': 0.13966181089657756,
#   'AAPL weight': 0.20465446594039877,
#   'PFE weight': 0.02650952326195055,
#   'BTC weight': 0.09051306148952624},
#  {'Returns': 40.837430670387015,
#   'Volatility': 0.22902895094975473,
#   'SHOP weight': 0.03442559599221485,
#   'TSLA weight': 0.21121538377070018,
#   'GOLD weight': 0.15656440948514092,
#   'DAL weight': 0.18178761853153425,
#   'NFLX weight': 0.07763099674852031,
#   'AAPL weight': 0.09224603231709035,
#   'PFE weight': 0.19389264740371753,
#   'BTC weight': 0.052237315751081655},
#  {'Returns': 38.85099870966818,
#   'Volatility': 0.24161582686351776,
#   'SHOP weight': 0.19142320490040846,
#   'TSLA weight': 0.0687722383911035,
#   'GOLD weight': 0.18375649171675237,
#   'DAL weight': 0.10217408255862706,
#   'NFLX weight': 0.25072373824091254,
#   'AAPL weight': 0.1074453012431087,
#   'PFE weight': 0.021144145447760932,
#   'BTC weight': 0.07456079750132652},
#  {'Returns': 48.807674417718786,
#   'Volatility': 0.26283887007712403,
#   'SHOP weight': 0.22021059203379198,
#   'TSLA weight': 0.077751278703193,
#   'GOLD weight': 0.007541357739814845,
#   'DAL weight': 0.05157316813066796,
#   'NFLX weight': 0.3560716977799148,
#   'AAPL weight': 0.10423342663793098,
#   'PFE weight': 0.10552147052399441,
#   'BTC weight': 0.07709700845069203},
#  {'Returns': 43.882703407359884,
#   'Volatility': 0.259598613905215,
#   'SHOP weight': 0.0809517018098664,
#   'TSLA weight': 0.26092340223637467,
#   'GOLD weight': 0.018785053597450155,
#   'DAL weight': 0.24276507080888482,
#   'NFLX weight': 0.10033382104686582,
#   'AAPL weight': 0.07047422912716982,
#   'PFE weight': 0.19866100991760785,
#   'BTC weight': 0.02710571145578042},
#  {'Returns': 98.44599231984064,
#   'Volatility': 0.27877876603402396,
#   'SHOP weight': 0.06925522736748695,
#   'TSLA weight': 0.09461855917940766,
#   'GOLD weight': 0.2747027237324992,
#   'DAL weight': 0.07598089021700913,
#   'NFLX weight': 0.03754393670033685,
#   'AAPL weight': 0.04280391969716136,
#   'PFE weight': 0.11954028748638501,
#   'BTC weight': 0.2855544556197138},
#  {'Returns': 38.2038333747702,
#   'Volatility': 0.24647507891951745,
#   'SHOP weight': 0.11546164390650653,
#   'TSLA weight': 0.1353425188617075,
#   'GOLD weight': 0.03676790586670639,
#   'DAL weight': 0.1634013994742173,
#   'NFLX weight': 0.1994748339247056,
#   'AAPL weight': 0.2531080826552295,
#   'PFE weight': 0.05702131621122097,
#   'BTC weight': 0.03942229909970624},
#  {'Returns': 79.93742427218018,
#   'Volatility': 0.22624481261939525,
#   'SHOP weight': 0.08524806939114901,
#   'TSLA weight': 0.00011548590357091406,
#   'GOLD weight': 0.011876816815126963,
#   'DAL weight': 0.15900990485088365,
#   'NFLX weight': 0.10292015226022322,
#   'AAPL weight': 0.3051403720090661,
#   'PFE weight': 0.14624535011996873,
#   'BTC weight': 0.18944384865001143},
#  {'Returns': 93.5899262320719,
#   'Volatility': 0.25818501800371335,
#   'SHOP weight': 0.1179543408398941,
#   'TSLA weight': 0.10827824493096792,
#   'GOLD weight': 0.06989687283069461,
#   'DAL weight': 0.1112504680538354,
#   'NFLX weight': 0.17160664347087684,
#   'AAPL weight': 0.05460926904259442,
#   'PFE weight': 0.1337709208185761,
#   'BTC weight': 0.23263324001256055},
#  {'Returns': 50.204235173321074,
#   'Volatility': 0.23866594951126271,
#   'SHOP weight': 0.062287724952834383,
#   'TSLA weight': 0.20271876630766128,
#   'GOLD weight': 0.17791821425373716,
#   'DAL weight': 0.19324084321477966,
#   'NFLX weight': 0.1398118542854949,
#   'AAPL weight': 0.033829071026246174,
#   'PFE weight': 0.09674024991478786,
#   'BTC weight': 0.0934532760444586},
#  {'Returns': 19.660448274591943,
#   'Volatility': 0.21940970021742465,
#   'SHOP weight': 0.12063545691615854,
#   'TSLA weight': 0.09582941727579142,
#   'GOLD weight': 0.19710564518239376,
#   'DAL weight': 0.19965237546170686,
#   'NFLX weight': 0.09703764323756622,
#   'AAPL weight': 0.19947030914472674,
#   'PFE weight': 0.08930389313091114,
#   'BTC weight': 0.0009652596507453771},
#  {'Returns': 52.31384385353708,
#   'Volatility': 0.20403766848837662,
#   'SHOP weight': 0.02338620876064482,
#   'TSLA weight': 0.0788956866893234,
#   'GOLD weight': 0.20229077948836102,
#   'DAL weight': 0.04373794161521486,
#   'NFLX weight': 0.15881388252120637,
#   'AAPL weight': 0.17777524743398398,
#   'PFE weight': 0.1884527958607029,
#   'BTC weight': 0.1266474576305626},
#  {'Returns': 96.82796341473355,
#   'Volatility': 0.2949955776157143,
#   'SHOP weight': 0.14379695411434515,
#   'TSLA weight': 0.11384125351926319,
#   'GOLD weight': 0.04464353841311097,
#   'DAL weight': 0.05589463881688701,
#   'NFLX weight': 0.1814573007458175,
#   'AAPL weight': 0.2045784525313491,
#   'PFE weight': 0.011004035186982992,
#   'BTC weight': 0.2447838266722441},
#  {'Returns': 30.58512364510569,
#   'Volatility': 0.21392754469723557,
#   'SHOP weight': 0.06012922617652714,
#   'TSLA weight': 0.128867035855177,
#   'GOLD weight': 0.1757170411334345,
#   'DAL weight': 0.06937290885520683,
#   'NFLX weight': 0.14415455322779197,
#   'AAPL weight': 0.19883583226156443,
#   'PFE weight': 0.18598513275819992,
#   'BTC weight': 0.0369382697320981},
#  {'Returns': 55.26678650712711,
#   'Volatility': 0.28479554279997416,
#   'SHOP weight': 0.18400694770508863,
#   'TSLA weight': 0.2248740907781868,
#   'GOLD weight': 0.1425648913738796,
#   'DAL weight': 0.08057156025966894,
#   'NFLX weight': 0.1551977687006423,
#   'AAPL weight': 0.0903644818479192,
#   'PFE weight': 0.02378615034526284,
#   'BTC weight': 0.09863410898935167},
#  {'Returns': 65.48546454533752,
#   'Volatility': 0.24831335974152532,
#   'SHOP weight': 0.03566237500162407,
#   'TSLA weight': 0.15548810024973855,
#   'GOLD weight': 0.1580743853878726,
#   'DAL weight': 0.02383167431916854,
#   'NFLX weight': 0.19378949016098562,
#   'AAPL weight': 0.17497459964816398,
#   'PFE weight': 0.09930740994716299,
#   'BTC weight': 0.15887196528528355},
#  {'Returns': 74.8991018169242,
#   'Volatility': 0.23622026596465534,
#   'SHOP weight': 0.12364695911853273,
#   'TSLA weight': 0.03832888597039619,
#   'GOLD weight': 0.14492921602482883,
#   'DAL weight': 0.16948584482047582,
#   'NFLX weight': 0.1115003705064094,
#   'AAPL weight': 0.17905919793005237,
#   'PFE weight': 0.04197634342382041,
#   'BTC weight': 0.19107318220548428},
#  {'Returns': 80.49481919659152,
#   'Volatility': 0.22234792130739947,
#   'SHOP weight': 0.08941717374528989,
#   'TSLA weight': 0.022661461639656506,
#   'GOLD weight': 0.06818265962283913,
#   'DAL weight': 0.09763208921736877,
#   'NFLX weight': 0.16033157592359498,
#   'AAPL weight': 0.17517960247744166,
#   'PFE weight': 0.18682282194378794,
#   'BTC weight': 0.19977261543002112},
#  {'Returns': 62.25903104700435,
#   'Volatility': 0.24345488448606606,
#   'SHOP weight': 0.14523552484974056,
#   'TSLA weight': 0.16721357469777848,
#   'GOLD weight': 0.11275941104061811,
#   'DAL weight': 0.11996639675625853,
#   'NFLX weight': 0.02717633084332922,
#   'AAPL weight': 0.1726589517341044,
#   'PFE weight': 0.13896501682351367,
#   'BTC weight': 0.11602479325465705},
#  {'Returns': 71.39862358059733,
#   'Volatility': 0.22574423012949932,
#   'SHOP weight': 0.05606632435463874,
#   'TSLA weight': 0.012692452510380118,
#   'GOLD weight': 0.23756911858161248,
#   'DAL weight': 0.2087315338809812,
#   'NFLX weight': 0.03163887995180565,
#   'AAPL weight': 0.1608644467524595,
#   'PFE weight': 0.09560069599817214,
#   'BTC weight': 0.19683654796994995},
#  {'Returns': 79.69670999565115,
#   'Volatility': 0.26111772051498566,
#   'SHOP weight': 0.040818716275719,
#   'TSLA weight': 0.1743911036095358,
#   'GOLD weight': 0.1507398849235299,
#   'DAL weight': 0.1138321645925459,
#   'NFLX weight': 0.14077759674613952,
#   'AAPL weight': 0.11354484492039212,
#   'PFE weight': 0.06697513888754489,
#   'BTC weight': 0.19892055004459272},
#  {'Returns': 55.241786178608365,
#   'Volatility': 0.2364557052779881,
#   'SHOP weight': 0.1496304836644867,
#   'TSLA weight': 0.10339829530730175,
#   'GOLD weight': 0.042259473200288,
#   'DAL weight': 0.012135158690325679,
#   'NFLX weight': 0.09138580629781183,
#   'AAPL weight': 0.30066095456323827,
#   'PFE weight': 0.20861805860703667,
#   'BTC weight': 0.09191176966951109},
#  {'Returns': 46.250895796544015,
#   'Volatility': 0.22419466838114155,
#   'SHOP weight': 0.15405739049900694,
#   'TSLA weight': 0.14975519648814753,
#   'GOLD weight': 0.03798343479675175,
#   'DAL weight': 0.12529735031568787,
#   'NFLX weight': 0.10316386420080635,
#   'AAPL weight': 0.13623678278692947,
#   'PFE weight': 0.24471886590375186,
#   'BTC weight': 0.04878711500891818},
#  {'Returns': 52.98429802349148,
#   'Volatility': 0.18206410064954423,
#   'SHOP weight': 0.0011274716721298868,
#   'TSLA weight': 0.010219437755436446,
#   'GOLD weight': 0.06540471673330624,
#   'DAL weight': 0.2387752890168093,
#   'NFLX weight': 0.06814499302674834,
#   'AAPL weight': 0.15408205483490553,
#   'PFE weight': 0.36412402774013636,
#   'BTC weight': 0.09812200922052798},
#  {'Returns': 51.04682701012427,
#   'Volatility': 0.25799795536697445,
#   'SHOP weight': 0.19699133237024796,
#   'TSLA weight': 0.18821497108385313,
#   'GOLD weight': 0.13200662866538174,
#   'DAL weight': 0.04235553541913334,
#   'NFLX weight': 0.09824205211943558,
#   'AAPL weight': 0.10981984276224697,
#   'PFE weight': 0.15374043453228245,
#   'BTC weight': 0.07862920304741901},
#  {'Returns': 66.58709142550028,
#   'Volatility': 0.2825228574606494,
#   'SHOP weight': 0.018129351694950942,
#   'TSLA weight': 0.24585645760204733,
#   'GOLD weight': 0.12906837917232628,
#   'DAL weight': 0.021510138832672686,
#   'NFLX weight': 0.23059930470346163,
#   'AAPL weight': 0.14534787785243353,
#   'PFE weight': 0.05888594334225689,
#   'BTC weight': 0.15060254679985077},
#  {'Returns': 55.048122440905445,
#   'Volatility': 0.25557020788370954,
#   'SHOP weight': 0.13240840590384756,
#   'TSLA weight': 0.202727266290817,
#   'GOLD weight': 0.10880801253692692,
#   'DAL weight': 0.074790857491063,
#   'NFLX weight': 0.18640433933016945,
#   'AAPL weight': 0.0764927966805322,
#   'PFE weight': 0.12168345443818857,
#   'BTC weight': 0.09668486732845535},
#  {'Returns': 102.51773781628509,
#   'Volatility': 0.26782760919792187,
#   'SHOP weight': 0.17174124922487116,
#   'TSLA weight': 0.10992457747361613,
#   'GOLD weight': 0.049331798463136504,
#   'DAL weight': 0.14790355133891397,
#   'NFLX weight': 0.04044814244436259,
#   'AAPL weight': 0.0582402640321451,
#   'PFE weight': 0.17743801923708938,
#   'BTC weight': 0.24497239778586513},
#  {'Returns': 61.83447253994282,
#   'Volatility': 0.21625085375015987,
#   'SHOP weight': 0.027493226695129398,
#   'TSLA weight': 0.14332630659396786,
#   'GOLD weight': 0.07607328816686544,
#   'DAL weight': 0.11720153188337115,
#   'NFLX weight': 0.09029546828973158,
#   'AAPL weight': 0.19070111049323035,
#   'PFE weight': 0.23425061948143786,
#   'BTC weight': 0.1206584483962663},
#  {'Returns': 66.13112028951188,
#   'Volatility': 0.2066461645894206,
#   'SHOP weight': 0.11932964445715845,
#   'TSLA weight': 0.054882135418345634,
#   'GOLD weight': 0.1847136631311686,
#   'DAL weight': 0.09560364254144664,
#   'NFLX weight': 0.013162617338529936,
#   'AAPL weight': 0.13991642527611567,
#   'PFE weight': 0.23812522705173594,
#   'BTC weight': 0.15426664478549917},
#  {'Returns': 51.270330303216646,
#   'Volatility': 0.2726571116426929,
#   'SHOP weight': 0.06670507963469698,
#   'TSLA weight': 0.2132054873667919,
#   'GOLD weight': 0.07132992552105787,
#   'DAL weight': 0.04219827046162875,
#   'NFLX weight': 0.26691940763247723,
#   'AAPL weight': 0.18233186045837801,
#   'PFE weight': 0.06765941132772703,
#   'BTC weight': 0.08965055759724229},
#  {'Returns': 48.36995458294284,
#   'Volatility': 0.20251820139236293,
#   'SHOP weight': 0.06774361929072299,
#   'TSLA weight': 0.0863502686471182,
#   'GOLD weight': 0.19521508932566248,
#   'DAL weight': 0.15362311456543115,
#   'NFLX weight': 0.1051594233590377,
#   'AAPL weight': 0.14843678528275048,
#   'PFE weight': 0.14010388284886216,
#   'BTC weight': 0.10336781668041486},
#  {'Returns': 64.70887658046507,
#   'Volatility': 0.25841534164771524,
#   'SHOP weight': 0.1369235827629126,
#   'TSLA weight': 0.17836836138299608,
#   'GOLD weight': 0.1954268826846597,
#   'DAL weight': 0.0887334005163475,
#   'NFLX weight': 0.057673552940190276,
#   'AAPL weight': 0.1361335175274855,
#   'PFE weight': 0.063153313612517,
#   'BTC weight': 0.14358738857289127},
#  {'Returns': 74.13260489451636,
#   'Volatility': 0.25760609267291257,
#   'SHOP weight': 0.08891559435052322,
#   'TSLA weight': 0.19899685390371952,
#   'GOLD weight': 0.09276329555822455,
#   'DAL weight': 0.1035494290952993,
#   'NFLX weight': 0.04947003866254986,
#   'AAPL weight': 0.17360666422645768,
#   'PFE weight': 0.13741755604034908,
#   'BTC weight': 0.15528056816287686},
#  {'Returns': 74.26650919101417,
#   'Volatility': 0.25651937174069156,
#   'SHOP weight': 0.1531671182236842,
#   'TSLA weight': 0.17836378845049933,
#   'GOLD weight': 0.08585834413584405,
#   'DAL weight': 0.16229298679060158,
#   'NFLX weight': 0.0295889152546877,
#   'AAPL weight': 0.12824359255145473,
#   'PFE weight': 0.11254307371523496,
#   'BTC weight': 0.14994218087799357},
#  {'Returns': 125.18155378680505,
#   'Volatility': 0.34069971641478336,
#   'SHOP weight': 0.005070023100192186,
#   'TSLA weight': 0.14262711414967624,
#   'GOLD weight': 0.21302599593221788,
#   'DAL weight': 0.1355583097837549,
#   'NFLX weight': 0.02545827243719588,
#   'AAPL weight': 0.06748353697406394,
#   'PFE weight': 0.04448115271964025,
#   'BTC weight': 0.3662955949032588},
#  {'Returns': 76.76636258210145,
#   'Volatility': 0.25960423232163043,
#   'SHOP weight': 0.10107406976125459,
#   'TSLA weight': 0.20485968307798014,
#   'GOLD weight': 0.08980075717389817,
#   'DAL weight': 0.11291992650965135,
#   'NFLX weight': 0.08775203806734708,
#   'AAPL weight': 0.10383021805451215,
#   'PFE weight': 0.13655860548869217,
#   'BTC weight': 0.16320470186666433},
#  {'Returns': 48.50554164555291,
#   'Volatility': 0.2542023019558533,
#   'SHOP weight': 0.24540147800100218,
#   'TSLA weight': 0.06690357362255174,
#   'GOLD weight': 0.06408112786706874,
#   'DAL weight': 0.15591899037214468,
#   'NFLX weight': 0.32660868409229993,
#   'AAPL weight': 0.01926021481152075,
#   'PFE weight': 0.03855632449688995,
#   'BTC weight': 0.08326960673652209},
#  {'Returns': 37.14604631504895,
#   'Volatility': 0.2384382366931503,
#   'SHOP weight': 0.010599006680271406,
#   'TSLA weight': 0.20087089387590937,
#   'GOLD weight': 0.15524657802351557,
#   'DAL weight': 0.19998947414937837,
#   'NFLX weight': 0.06273305036375752,
#   'AAPL weight': 0.2155739763402714,
#   'PFE weight': 0.10879586154213566,
#   'BTC weight': 0.0461911590247606},
#  {'Returns': 58.46796085340417,
#   'Volatility': 0.2601241578309257,
#   'SHOP weight': 0.01455340140017804,
#   'TSLA weight': 0.2076666966458561,
#   'GOLD weight': 0.04238861085692027,
#   'DAL weight': 0.15603092863554843,
#   'NFLX weight': 0.22603603113904247,
#   'AAPL weight': 0.192274647997571,
#   'PFE weight': 0.051112390937733204,
#   'BTC weight': 0.10993729238715055},
#  {'Returns': 93.1714703329942,
#   'Volatility': 0.27033489596529836,
#   'SHOP weight': 0.1417034184308591,
#   'TSLA weight': 0.16075459651691484,
#   'GOLD weight': 0.015571424347460429,
#   'DAL weight': 0.03946464358426772,
#   'NFLX weight': 0.032747088795598775,
#   'AAPL weight': 0.19700972629168725,
#   'PFE weight': 0.20756702826662754,
#   'BTC weight': 0.20518207376658426},
#  {'Returns': 95.62896660950477,
#   'Volatility': 0.3015481655302471,
#   'SHOP weight': 0.13652689074274826,
#   'TSLA weight': 0.13574964289046365,
#   'GOLD weight': 0.018795966794781693,
#   'DAL weight': 0.018568461407066108,
#   'NFLX weight': 0.13593730469580245,
#   'AAPL weight': 0.2921958668451316,
#   'PFE weight': 0.02991362498606743,
#   'BTC weight': 0.2323122416379387},
#  {'Returns': 37.586701734859496,
#   'Volatility': 0.2038178870262241,
#   'SHOP weight': 0.026019941852262328,
#   'TSLA weight': 0.14374110458277095,
#   'GOLD weight': 0.19660772897902018,
#   'DAL weight': 0.14740346427281764,
#   'NFLX weight': 0.2196600769072862,
#   'AAPL weight': 0.006182937157655951,
#   'PFE weight': 0.19491118235590102,
#   'BTC weight': 0.06547356389228581},
#  {'Returns': 77.6124434236966,
#   'Volatility': 0.24742182995896095,
#   'SHOP weight': 0.11705888082070512,
#   'TSLA weight': 0.1168388245729928,
#   'GOLD weight': 0.12144174233932452,
#   'DAL weight': 0.02878434658433764,
#   'NFLX weight': 0.16807680215408027,
#   'AAPL weight': 0.11699957353741545,
#   'PFE weight': 0.1426000424783853,
#   'BTC weight': 0.18819978751275887},
#  {'Returns': 52.127569119168726,
#   'Volatility': 0.20545526814615175,
#   'SHOP weight': 0.09920025307554942,
#   'TSLA weight': 0.08206923339374551,
#   'GOLD weight': 0.08810410760048136,
#   'DAL weight': 0.1438152251734882,
#   'NFLX weight': 0.10364798998359025,
#   'AAPL weight': 0.21176732463815354,
#   'PFE weight': 0.17708172618140533,
#   'BTC weight': 0.09431413995358648},
#  {'Returns': 94.63953929843227,
#   'Volatility': 0.27343650448132584,
#   'SHOP weight': 0.14942990746508003,
#   'TSLA weight': 0.11591570771780267,
#   'GOLD weight': 0.11294368352364818,
#   'DAL weight': 0.18644252740899975,
#   'NFLX weight': 0.045088072424375826,
#   'AAPL weight': 0.10752008729323839,
#   'PFE weight': 0.04699902035283918,
#   'BTC weight': 0.23566099381401606},
#  {'Returns': 70.71189017326317,
#   'Volatility': 0.2320187338812371,
#   'SHOP weight': 0.10075676889678321,
#   'TSLA weight': 0.034780694731252615,
#   'GOLD weight': 0.18865676146113894,
#   'DAL weight': 0.14134934672572694,
#   'NFLX weight': 0.1618909732478893,
#   'AAPL weight': 0.14157660998115734,
#   'PFE weight': 0.04096246168716679,
#   'BTC weight': 0.19002638326888482},
#  {'Returns': 70.4474989029315,
#   'Volatility': 0.26290559089728655,
#   'SHOP weight': 0.008133959785435732,
#   'TSLA weight': 0.2053454162270759,
#   'GOLD weight': 0.2568822139754403,
#   'DAL weight': 0.05456207375299934,
#   'NFLX weight': 0.1998155144728333,
#   'AAPL weight': 0.010110705432995165,
#   'PFE weight': 0.0770223759766282,
#   'BTC weight': 0.18812774037659208},
#  {'Returns': 45.00654288811779,
#   'Volatility': 0.2482217686644084,
#   'SHOP weight': 0.20357507294852623,
#   'TSLA weight': 0.16438471948625857,
#   'GOLD weight': 0.11910795982106695,
#   'DAL weight': 0.028848477426571106,
#   'NFLX weight': 0.08769517862157851,
#   'AAPL weight': 0.13748902160612525,
#   'PFE weight': 0.20267246937305614,
#   'BTC weight': 0.05622710071681718},
#  {'Returns': 61.48905475858879,
#   'Volatility': 0.21631239323700366,
#   'SHOP weight': 0.07409187869111146,
#   'TSLA weight': 0.11527493011694605,
#   'GOLD weight': 0.16684794784093576,
#   'DAL weight': 0.11823960793105455,
#   'NFLX weight': 0.05808857129542877,
#   'AAPL weight': 0.15964523912370945,
#   'PFE weight': 0.17186678200204034,
#   'BTC weight': 0.13594504299877364},
#  {'Returns': 98.41207481776055,
#   'Volatility': 0.2793047609704542,
#   'SHOP weight': 0.22482267211155071,
#   'TSLA weight': 0.08580564742238657,
#   'GOLD weight': 0.10265901708763729,
#   'DAL weight': 0.024733934884262482,
#   'NFLX weight': 0.1369666191558823,
#   'AAPL weight': 0.0346727624620056,
#   'PFE weight': 0.1416348548496067,
#   'BTC weight': 0.24870449202666847},
#  {'Returns': 83.51816084106481,
#   'Volatility': 0.2881239928372427,
#   'SHOP weight': 0.11163606491240863,
#   'TSLA weight': 0.2672889403038139,
#   'GOLD weight': 0.18869754580333165,
#   'DAL weight': 0.06845375270249646,
#   'NFLX weight': 0.004886936099929211,
#   'AAPL weight': 0.02157816359417852,
#   'PFE weight': 0.14726273730900327,
#   'BTC weight': 0.19019585927483837},
#  {'Returns': 63.1503280267427,
#   'Volatility': 0.21696946836890282,
#   'SHOP weight': 0.1214572697588042,
#   'TSLA weight': 0.11545490525416344,
#   'GOLD weight': 0.08435493659061892,
#   'DAL weight': 0.16862855634838755,
#   'NFLX weight': 0.09818681069038356,
#   'AAPL weight': 0.1089014401162365,
#   'PFE weight': 0.17990541200595966,
#   'BTC weight': 0.12311066923544614},
#  {'Returns': 45.15451951104427,
#   'Volatility': 0.21918884434163344,
#   'SHOP weight': 0.14801147029425382,
#   'TSLA weight': 0.07652977512244434,
#   'GOLD weight': 0.18585491439164858,
#   'DAL weight': 0.19437541163821678,
#   'NFLX weight': 0.19733858870885693,
#   'AAPL weight': 0.05479619471015814,
#   'PFE weight': 0.05092597866440558,
#   'BTC weight': 0.09216766647001585},
#  {'Returns': 35.87161164706937,
#   'Volatility': 0.3399978450025175,
#   'SHOP weight': 0.286758203341827,
#   'TSLA weight': 0.31058553168833974,
#   'GOLD weight': 0.11714416970890303,
#   'DAL weight': 0.008379590155703774,
#   'NFLX weight': 0.15351720739188113,
#   'AAPL weight': 0.019842104499129407,
#   'PFE weight': 0.09778859631283819,
#   'BTC weight': 0.005984596901377856},
#  {'Returns': 62.59418843920983,
#   'Volatility': 0.2169574399150787,
#   'SHOP weight': 0.1924139966677808,
#   'TSLA weight': 0.018450328403727328,
#   'GOLD weight': 0.19082454588153108,
#   'DAL weight': 0.10817388013916623,
#   'NFLX weight': 0.051463534536451146,
#   'AAPL weight': 0.15074389162288843,
#   'PFE weight': 0.14001056177300925,
#   'BTC weight': 0.1479192609754457},
#  {'Returns': 59.180410143445584,
#   'Volatility': 0.21134825906851995,
#   'SHOP weight': 0.08688888261558088,
#   'TSLA weight': 0.12600706036345619,
#   'GOLD weight': 0.09075832942482669,
#   'DAL weight': 0.17276783577212454,
#   'NFLX weight': 0.1799077536877157,
#   'AAPL weight': 0.035076766177377545,
#   'PFE weight': 0.19333197645621952,
#   'BTC weight': 0.11526139550269913},
#  {'Returns': 51.089862560271236,
#   'Volatility': 0.21360424673988268,
#   'SHOP weight': 0.03307042422680632,
#   'TSLA weight': 0.11357596377722975,
#   'GOLD weight': 0.11749364010841298,
#   'DAL weight': 0.24816941970491588,
#   'NFLX weight': 0.19375863589263462,
#   'AAPL weight': 0.08560517129793183,
#   'PFE weight': 0.10686357247299387,
#   'BTC weight': 0.10146317251907483},
#  {'Returns': 82.12115167624361,
#   'Volatility': 0.287795148079006,
#   'SHOP weight': 0.1262164564087365,
#   'TSLA weight': 0.24188612554529243,
#   'GOLD weight': 0.06287835218213532,
#   'DAL weight': 0.15310869797738688,
#   'NFLX weight': 0.07493501806255966,
#   'AAPL weight': 0.10812361515214455,
#   'PFE weight': 0.06156908083209914,
#   'BTC weight': 0.17128265383964544},
#  {'Returns': 59.84708464434726,
#   'Volatility': 0.2545779104076922,
#   'SHOP weight': 0.12236550132701168,
#   'TSLA weight': 0.15557796711288566,
#   'GOLD weight': 0.02849004103558326,
#   'DAL weight': 0.25104158903944884,
#   'NFLX weight': 0.22571165123375894,
#   'AAPL weight': 0.09550086579878435,
#   'PFE weight': 0.012978462069010946,
#   'BTC weight': 0.10833392238351645},
#  {'Returns': 53.077371000646686,
#   'Volatility': 0.2150774402388033,
#   'SHOP weight': 0.08114942374059904,
#   'TSLA weight': 0.14053035089697358,
#   'GOLD weight': 0.21965208502196915,
#   'DAL weight': 0.08925527250386955,
#   'NFLX weight': 0.006892173820694789,
#   'AAPL weight': 0.13490313653150787,
#   'PFE weight': 0.2192073446151501,
#   'BTC weight': 0.10841021286923601},
#  {'Returns': 67.05172629131944,
#   'Volatility': 0.2627193191298192,
#   'SHOP weight': 0.05858642553395966,
#   'TSLA weight': 0.20908306992374293,
#   'GOLD weight': 0.00633027426185772,
#   'DAL weight': 0.19407158909204994,
#   'NFLX weight': 0.12443021865828882,
#   'AAPL weight': 0.20663844340500193,
#   'PFE weight': 0.07935262110678654,
#   'BTC weight': 0.12150735801831249},
#  {'Returns': 29.44387215529699,
#   'Volatility': 0.2521702428390905,
#   'SHOP weight': 0.1418846375702687,
#   'TSLA weight': 0.14188461285724596,
#   'GOLD weight': 0.3229536504123552,
#   'DAL weight': 0.005011732062490805,
#   'NFLX weight': 0.05737569661412473,
#   'AAPL weight': 0.2114912455828544,
#   'PFE weight': 0.0667114317474141,
#   'BTC weight': 0.052686993153246216},
#  {'Returns': 78.26871364487589,
#   'Volatility': 0.26046123973187996,
#   'SHOP weight': 0.10002569951988378,
#   'TSLA weight': 0.1292654903572011,
#   'GOLD weight': 0.08324350228844286,
#   'DAL weight': 0.147949049842295,
#   'NFLX weight': 0.16328821239373237,
#   'AAPL weight': 0.17476064633258237,
#   'PFE weight': 0.015340801801064088,
#   'BTC weight': 0.18612659746479832},
#  {'Returns': 96.77986759621236,
#   'Volatility': 0.2508064603363563,
#   'SHOP weight': 0.08260343917311967,
#   'TSLA weight': 0.09701518816235036,
#   'GOLD weight': 0.1218247919873837,
#   'DAL weight': 0.12518925429088862,
#   'NFLX weight': 0.08266222478360528,
#   'AAPL weight': 0.026336615225363767,
#   'PFE weight': 0.21607225827238843,
#   'BTC weight': 0.24829622810490012},
#  {'Returns': 83.93626913512463,
#   'Volatility': 0.26448974228297084,
#   'SHOP weight': 0.11351146374744478,
#   'TSLA weight': 0.191360733035449,
#   'GOLD weight': 0.07487152107499467,
#   'DAL weight': 0.1262351093865975,
#   'NFLX weight': 0.09957367261454496,
#   'AAPL weight': 0.08422833256896377,
#   'PFE weight': 0.12376902320807683,
#   'BTC weight': 0.1864501443639285},
#  {'Returns': 42.9809746908352,
#   'Volatility': 0.19585492752658384,
#   'SHOP weight': 0.16025176519488643,
#   'TSLA weight': 0.06850014699551901,
#   'GOLD weight': 0.1463630340084079,
#   'DAL weight': 0.2019582131136249,
#   'NFLX weight': 0.1268410582784055,
#   'AAPL weight': 0.027338444443440336,
#   'PFE weight': 0.20158603484318846,
#   'BTC weight': 0.06716130312252755},
#  {'Returns': 23.287028026117454,
#   'Volatility': 0.2501722770887257,
#   'SHOP weight': 0.11314565817545577,
#   'TSLA weight': 0.20664576148808111,
#   'GOLD weight': 0.21842433618704707,
#   'DAL weight': 0.004025952175727321,
#   'NFLX weight': 0.06871204345821821,
#   'AAPL weight': 0.16131476145697582,
#   'PFE weight': 0.22729952535894568,
#   'BTC weight': 0.000431961699548982},
#  {'Returns': 73.01943849860162,
#   'Volatility': 0.22331929458532349,
#   'SHOP weight': 0.1612864010915556,
#   'TSLA weight': 0.027284928114025605,
#   'GOLD weight': 0.1867318344931134,
#   'DAL weight': 0.04026374529169506,
#   'NFLX weight': 0.07399334557160274,
#   'AAPL weight': 0.12710850862475737,
#   'PFE weight': 0.19885926480317864,
#   'BTC weight': 0.18447197201007154},
#  {'Returns': 75.95797392286596,
#   'Volatility': 0.2364557462676105,
#   'SHOP weight': 0.15287270260826366,
#   'TSLA weight': 0.10324618367552871,
#   'GOLD weight': 0.08492145947810593,
#   'DAL weight': 0.1574369930740298,
#   'NFLX weight': 0.050040437907431894,
#   'AAPL weight': 0.15179876468265233,
#   'PFE weight': 0.133719853708027,
#   'BTC weight': 0.16596360486596068},
#  {'Returns': 43.84900486728847,
#   'Volatility': 0.24125458328399224,
#   'SHOP weight': 0.15937219809585226,
#   'TSLA weight': 0.15977343926439153,
#   'GOLD weight': 0.189228433961367,
#   'DAL weight': 0.09529942208428098,
#   'NFLX weight': 0.07904795479457458,
#   'AAPL weight': 0.143039630932677,
#   'PFE weight': 0.1030998719432433,
#   'BTC weight': 0.0711390489236133},
#  {'Returns': 22.93234539364439,
#   'Volatility': 0.19912928412519784,
#   'SHOP weight': 0.042284898301249915,
#   'TSLA weight': 0.04123943110860731,
#   'GOLD weight': 0.2822731892944721,
#   'DAL weight': 0.08839346318828155,
#   'NFLX weight': 0.11772186924242531,
#   'AAPL weight': 0.2583427409452601,
#   'PFE weight': 0.1259083204773136,
#   'BTC weight': 0.0438360874423901},
#  {'Returns': 85.86311151277555,
#   'Volatility': 0.2590475243668066,
#   'SHOP weight': 0.15270886995746502,
#   'TSLA weight': 0.15849147106689257,
#   'GOLD weight': 0.07220256753257984,
#   'DAL weight': 0.09051463980773893,
#   'NFLX weight': 0.011830926063122233,
#   'AAPL weight': 0.14879165409594675,
#   'PFE weight': 0.17739397238386645,
#   'BTC weight': 0.18806589909238813},
#  {'Returns': 31.621877457425704,
#   'Volatility': 0.21171819550351975,
#   'SHOP weight': 0.00327857571374744,
#   'TSLA weight': 0.12451283131924072,
#   'GOLD weight': 0.22314716442039764,
#   'DAL weight': 0.046562408332852114,
#   'NFLX weight': 0.10229920691141726,
#   'AAPL weight': 0.2617647236727813,
#   'PFE weight': 0.1853068170897307,
#   'BTC weight': 0.053128272539832745},
#  {'Returns': 37.871681583422514,
#   'Volatility': 0.24629161060960966,
#   'SHOP weight': 0.09885270539428269,
#   'TSLA weight': 0.18278128328577742,
#   'GOLD weight': 0.0898631545599419,
#   'DAL weight': 0.12678687433910774,
#   'NFLX weight': 0.1988808929356904,
#   'AAPL weight': 0.15977949982587442,
#   'PFE weight': 0.10203998199028519,
#   'BTC weight': 0.04101560766904014},
#  {'Returns': 65.14719637924628,
#   'Volatility': 0.25586768371101665,
#   'SHOP weight': 0.10894562248657151,
#   'TSLA weight': 0.1634771147054668,
#   'GOLD weight': 0.16946929630091728,
#   'DAL weight': 0.026704689909265746,
#   'NFLX weight': 0.1201636389532852,
#   'AAPL weight': 0.17206799012375432,
#   'PFE weight': 0.09030022443192894,
#   'BTC weight': 0.1488714230888102},
#  {'Returns': 78.60702877843572,
#   'Volatility': 0.22441315912843246,
#   'SHOP weight': 0.043548290501106,
#   'TSLA weight': 0.09631004340877923,
#   'GOLD weight': 0.051647675175053954,
#   'DAL weight': 0.1742892123028656,
#   'NFLX weight': 0.17836326379671116,
#   'AAPL weight': 0.08987015765144683,
#   'PFE weight': 0.18294295349088507,
#   'BTC weight': 0.1830284036731523},
#  {'Returns': 39.61245193931874,
#   'Volatility': 0.21571832716960318,
#   'SHOP weight': 0.08993978390101681,
#   'TSLA weight': 0.12767501822188282,
#   'GOLD weight': 0.1918243786367705,
#   'DAL weight': 0.10350924130015117,
#   'NFLX weight': 0.14038113146146475,
#   'AAPL weight': 0.1386733749745325,
#   'PFE weight': 0.13932599745454932,
#   'BTC weight': 0.06867107404963209},
#  {'Returns': 38.11024575568013,
#   'Volatility': 0.2863017580310493,
#   'SHOP weight': 0.03329766459682573,
#   'TSLA weight': 0.27003424813419047,
#   'GOLD weight': 0.0641978134623269,
#   'DAL weight': 0.04670384505023611,
#   'NFLX weight': 0.22147859134787024,
#   'AAPL weight': 0.22962206637679242,
#   'PFE weight': 0.09936937496395722,
#   'BTC weight': 0.03529639606780099},
#  {'Returns': 34.336674919768555,
#   'Volatility': 0.23544133543155324,
#   'SHOP weight': 0.17697259047572161,
#   'TSLA weight': 0.047501551775433075,
#   'GOLD weight': 0.22026984096776892,
#   'DAL weight': 0.08316501420382955,
#   'NFLX weight': 0.22889479430508647,
#   'AAPL weight': 0.14990346235027718,
#   'PFE weight': 0.024129495927695307,
#   'BTC weight': 0.06916324999418788},
#  {'Returns': 115.77421814845955,
#   'Volatility': 0.34098364386058405,
#   'SHOP weight': 0.17059046144776696,
#   'TSLA weight': 0.22292812086340336,
#   'GOLD weight': 0.0009730530702447054,
#   'DAL weight': 0.04793189997985224,
#   'NFLX weight': 0.10618544942346518,
#   'AAPL weight': 0.13837686457934517,
#   'PFE weight': 0.03317061278628346,
#   'BTC weight': 0.27984353784963895},
#  {'Returns': 56.52369678450802,
#   'Volatility': 0.23356824905755413,
#   'SHOP weight': 0.019966208475940175,
#   'TSLA weight': 0.13492104745172956,
#   'GOLD weight': 0.20147810365220692,
#   'DAL weight': 0.1553022658830306,
#   'NFLX weight': 0.1627388448196856,
#   'AAPL weight': 0.1561986184684104,
#   'PFE weight': 0.03171165128072718,
#   'BTC weight': 0.13768325996826955},
#  {'Returns': 62.314412048246815,
#   'Volatility': 0.21718087991667256,
#   'SHOP weight': 0.1638622523451208,
#   'TSLA weight': 0.047609596941815324,
#   'GOLD weight': 0.028160210943402982,
#   'DAL weight': 0.10111941650280912,
#   'NFLX weight': 0.16851152226012336,
#   'AAPL weight': 0.18597169294419752,
#   'PFE weight': 0.18309347410611612,
#   'BTC weight': 0.12167183395641469},
#  {'Returns': 53.33501041849387,
#   'Volatility': 0.18084637771852774,
#   'SHOP weight': 0.06650186558321611,
#   'TSLA weight': 0.0532715665010126,
#   'GOLD weight': 0.12360822620829819,
#   'DAL weight': 0.17413468018803638,
#   'NFLX weight': 0.12446580031672724,
#   'AAPL weight': 0.06437184796188247,
#   'PFE weight': 0.288057303694203,
#   'BTC weight': 0.10558870954662393},
#  {'Returns': 64.31515661533038,
#   'Volatility': 0.2418753723943719,
#   'SHOP weight': 0.16752905969756648,
#   'TSLA weight': 0.027605887271070686,
#   'GOLD weight': 0.1968412558830213,
#   'DAL weight': 0.06308044740604407,
#   'NFLX weight': 0.2067599190202852,
#   'AAPL weight': 0.13252939942516687,
#   'PFE weight': 0.03618126716553643,
#   'BTC weight': 0.169472764131309},
#  {'Returns': 39.729867223608096,
#   'Volatility': 0.23064627960987366,
#   'SHOP weight': 0.16194367387957434,
#   'TSLA weight': 0.09857307413272838,
#   'GOLD weight': 0.14686330040448636,
#   'DAL weight': 0.3161598221693732,
#   'NFLX weight': 0.10897040059618411,
#   'AAPL weight': 0.0897888211904407,
#   'PFE weight': 0.021276322039234276,
#   'BTC weight': 0.056424585587978554},
#  {'Returns': 52.3439398003777,
#   'Volatility': 0.24323124122881454,
#   'SHOP weight': 0.22421695259714283,
#   'TSLA weight': 0.07054434652089547,
#   'GOLD weight': 0.18334319712053462,
#   'DAL weight': 0.14331935054344003,
#   'NFLX weight': 0.13187857050372917,
#   'AAPL weight': 0.1279778324903437,
#   'PFE weight': 0.007795637649611151,
#   'BTC weight': 0.11092411257430303},
#  {'Returns': 75.65628303641508,
#   'Volatility': 0.2725679898798336,
#   'SHOP weight': 0.16732496972422634,
#   'TSLA weight': 0.15248485137016635,
#   'GOLD weight': 0.0692937211259795,
#   'DAL weight': 0.05631627263788139,
#   'NFLX weight': 0.1523690460850057,
#   'AAPL weight': 0.17510768254258025,
#   'PFE weight': 0.061285079086201136,
#   'BTC weight': 0.16581837742795938},
#  {'Returns': 92.37805496393791,
#   'Volatility': 0.27533456699443953,
#   'SHOP weight': 0.08711232557657725,
#   'TSLA weight': 0.07547398249520672,
#   'GOLD weight': 0.1905481401459685,
#   'DAL weight': 0.06813431781765304,
#   'NFLX weight': 0.12485183219376543,
#   'AAPL weight': 0.1703372178045641,
#   'PFE weight': 0.022471309607011696,
#   'BTC weight': 0.26107087435925325},
#  {'Returns': 92.56902457834953,
#   'Volatility': 0.2824980766958834,
#   'SHOP weight': 0.1189871280105494,
#   'TSLA weight': 0.18726173524247586,
#   'GOLD weight': 0.1392122491415179,
#   'DAL weight': 0.0023679193043134278,
#   'NFLX weight': 0.07988938761087379,
#   'AAPL weight': 0.09651351540112729,
#   'PFE weight': 0.14717744001270366,
#   'BTC weight': 0.2285906252764387},
#  {'Returns': 72.92437370889506,
#   'Volatility': 0.23098317748772115,
#   'SHOP weight': 0.1177823694659527,
#   'TSLA weight': 0.042442702329688956,
#   'GOLD weight': 0.20444028979686443,
#   'DAL weight': 0.06267924131798061,
#   'NFLX weight': 0.2277898074188965,
#   'AAPL weight': 0.016968178595480162,
#   'PFE weight': 0.12927771566309773,
#   'BTC weight': 0.19861969541203897},
#  {'Returns': 88.39840226081489,
#   'Volatility': 0.3048583195897353,
#   'SHOP weight': 0.17238270961016322,
#   'TSLA weight': 0.23600685281986655,
#   'GOLD weight': 0.15412039946941253,
#   'DAL weight': 0.016590739940335435,
#   'NFLX weight': 0.06098519669776964,
#   'AAPL weight': 0.0766374711980281,
#   'PFE weight': 0.07567878200385793,
#   'BTC weight': 0.20759784826056663},
#  {'Returns': 19.578197246526308,
#   'Volatility': 0.20683180088060335,
#   'SHOP weight': 0.13508453620133992,
#   'TSLA weight': 0.05622337741531334,
#   'GOLD weight': 0.3122983105082068,
#   'DAL weight': 0.17396997073277232,
#   'NFLX weight': 0.012996218549393965,
#   'AAPL weight': 0.17066908861766084,
#   'PFE weight': 0.11907443453568771,
#   'BTC weight': 0.01968406343962509},
#  {'Returns': 35.98093443070212,
#   'Volatility': 0.20419665745746202,
#   'SHOP weight': 0.16170410171090163,
#   'TSLA weight': 0.07429093238052407,
#   'GOLD weight': 0.07858895667227683,
#   'DAL weight': 0.11529285543391841,
#   'NFLX weight': 0.13353980867702867,
#   'AAPL weight': 0.15937091837420478,
#   'PFE weight': 0.2449798120285298,
#   'BTC weight': 0.03223261472261583},
#  {'Returns': 56.05108792755984,
#   'Volatility': 0.21338983799019476,
#   'SHOP weight': 0.17163484811314675,
#   'TSLA weight': 0.0016605683292209789,
#   'GOLD weight': 0.18802878912123638,
#   'DAL weight': 0.0996425911216793,
#   'NFLX weight': 0.08238140656231083,
#   'AAPL weight': 0.20990944144617155,
#   'PFE weight': 0.11423195763194141,
#   'BTC weight': 0.13251039767429285},
#  {'Returns': 25.55679386852528,
#   'Volatility': 0.2728646256400157,
#   'SHOP weight': 0.058550783885291446,
#   'TSLA weight': 0.24859853744685156,
#   'GOLD weight': 0.12322684577037721,
#   'DAL weight': 0.2051449988040351,
#   'NFLX weight': 0.20000569886552733,
#   'AAPL weight': 0.13177259874507413,
#   'PFE weight': 0.03229954077501994,
#   'BTC weight': 0.0004009957078232733},
#  {'Returns': 89.00697321225111,
#   'Volatility': 0.2564071279047567,
#   'SHOP weight': 0.14741194581653344,
#   'TSLA weight': 0.08297825059568793,
#   'GOLD weight': 0.06614994175198287,
#   'DAL weight': 0.20323137912865397,
#   'NFLX weight': 0.06725243105189782,
#   'AAPL weight': 0.15318181055728092,
#   'PFE weight': 0.06684205926985921,
#   'BTC weight': 0.21295218182810394},
#  {'Returns': 20.32060787712134,
#   'Volatility': 0.2089722772669088,
#   'SHOP weight': 0.04338202578461577,
#   'TSLA weight': 0.006011162965232268,
#   'GOLD weight': 0.15494800941773493,
#   'DAL weight': 0.09388611688776828,
#   'NFLX weight': 0.31984095957617603,
#   'AAPL weight': 0.2432044501436473,
#   'PFE weight': 0.11059762705465698,
#   'BTC weight': 0.028129648170168445},
#  {'Returns': 57.892637043839265,
#   'Volatility': 0.24178295017429058,
#   'SHOP weight': 0.1612034000717355,
#   'TSLA weight': 0.12357648611906873,
#   'GOLD weight': 0.16157324528381545,
#   'DAL weight': 0.11487579603532823,
#   'NFLX weight': 0.08780496365359794,
#   'AAPL weight': 0.17001037428703145,
#   'PFE weight': 0.06010693526694985,
#   'BTC weight': 0.1208487992824728},
#  {'Returns': 24.826627121730013,
#   'Volatility': 0.1869123752127699,
#   'SHOP weight': 0.15235499991981793,
#   'TSLA weight': 0.01697287366967842,
#   'GOLD weight': 0.2250131649418618,
#   'DAL weight': 0.22457457149533813,
#   'NFLX weight': 0.12792611674504645,
#   'AAPL weight': 0.026815964150949282,
#   'PFE weight': 0.20030615478968208,
#   'BTC weight': 0.026036154287625908},
#  {'Returns': 61.22397339174321,
#   'Volatility': 0.22362367954436066,
#   'SHOP weight': 0.08643067196257367,
#   'TSLA weight': 0.1429910208128121,
#   'GOLD weight': 0.15050135232454412,
#   'DAL weight': 0.16382650414665645,
#   'NFLX weight': 0.10327823991187765,
#   'AAPL weight': 0.08268808864378144,
#   'PFE weight': 0.14089626777872802,
#   'BTC weight': 0.1293878544190266},
#  {'Returns': 26.45409264586805,
#   'Volatility': 0.20540287560341816,
#   'SHOP weight': 0.12059752325218694,
#   'TSLA weight': 0.028224696852515965,
#   'GOLD weight': 0.2960375697083228,
#   'DAL weight': 0.04960866713583732,
#   'NFLX weight': 0.16372661221683815,
#   'AAPL weight': 0.14970476483041467,
#   'PFE weight': 0.1366206994370264,
#   'BTC weight': 0.055479466566857816},
#  {'Returns': 76.71217089623777,
#   'Volatility': 0.2518486161959367,
#   'SHOP weight': 0.0758400183573387,
#   'TSLA weight': 0.16490974487316307,
#   'GOLD weight': 0.09836508031315046,
#   'DAL weight': 0.14212527227772706,
#   'NFLX weight': 0.17931471590959214,
#   'AAPL weight': 0.07364194667527241,
#   'PFE weight': 0.0879301982236022,
#   'BTC weight': 0.1778730233701541},
#  {'Returns': 61.87777389823825,
#   'Volatility': 0.27745517936473646,
#   'SHOP weight': 0.1744530233245731,
#   'TSLA weight': 0.2445856166593804,
#   'GOLD weight': 0.12616114296703537,
#   'DAL weight': 0.15174748293232282,
#   'NFLX weight': 0.07850553856263302,
#   'AAPL weight': 0.05126440820760768,
#   'PFE weight': 0.06475260733871496,
#   'BTC weight': 0.10853018000773268},
#  {'Returns': 53.609840109258144,
#   'Volatility': 0.19027016919670914,
#   'SHOP weight': 0.08118025970131286,
#   'TSLA weight': 0.02459641859174329,
#   'GOLD weight': 0.10162310109227647,
#   'DAL weight': 0.23140610436049736,
#   'NFLX weight': 0.133969354366611,
#   'AAPL weight': 0.13476771973141247,
#   'PFE weight': 0.18315004037434562,
#   'BTC weight': 0.109307001781801},
#  {'Returns': 76.81428759155622,
#   'Volatility': 0.24208916216596052,
#   'SHOP weight': 0.1438413775079777,
#   'TSLA weight': 0.09647412326839762,
#   'GOLD weight': 0.05713508028600385,
#   'DAL weight': 0.16216366954798378,
#   'NFLX weight': 0.2549564088428713,
#   'AAPL weight': 0.00988458013981807,
#   'PFE weight': 0.09881487680366981,
#   'BTC weight': 0.17672988360327785},
#  {'Returns': 61.673333297201744,
#   'Volatility': 0.23057230029874276,
#   'SHOP weight': 0.06606960603744616,
#   'TSLA weight': 0.14244147619164035,
#   'GOLD weight': 0.10332591572309195,
#   'DAL weight': 0.15769346728105663,
#   'NFLX weight': 0.1589948164970332,
#   'AAPL weight': 0.13982778024365908,
#   'PFE weight': 0.10199665335244844,
#   'BTC weight': 0.12965028467362422},
#  {'Returns': 48.501406012168,
#   'Volatility': 0.2484050952326615,
#   'SHOP weight': 0.1117479976379024,
#   'TSLA weight': 0.18028339144076605,
#   'GOLD weight': 0.17778143248639638,
#   'DAL weight': 0.11423824655669235,
#   'NFLX weight': 0.12067437082990712,
#   'AAPL weight': 0.15033108927189576,
#   'PFE weight': 0.05476215481364544,
#   'BTC weight': 0.09018131696279448},
#  {'Returns': 83.20894210050334,
#   'Volatility': 0.3185460112340732,
#   'SHOP weight': 0.2512465969149171,
#   'TSLA weight': 0.22752968023663422,
#   'GOLD weight': 0.1514664359940528,
#   'DAL weight': 0.015786855244100013,
#   'NFLX weight': 0.05266572539267909,
#   'AAPL weight': 0.09250791545316822,
#   'PFE weight': 0.02294430897783597,
#   'BTC weight': 0.18585248178661257},
#  {'Returns': 50.56554022889064,
#   'Volatility': 0.2255453763281806,
#   'SHOP weight': 0.12491452109396793,
#   'TSLA weight': 0.13795541083063978,
#   'GOLD weight': 0.2826801298176916,
#   'DAL weight': 0.14948484759219482,
#   'NFLX weight': 0.00930413615067839,
#   'AAPL weight': 0.06384197013603346,
#   'PFE weight': 0.1220500614051967,
#   'BTC weight': 0.10976892297359735},
#  {'Returns': 40.59880567613773,
#   'Volatility': 0.2049638340914298,
#   'SHOP weight': 0.19582592190368106,
#   'TSLA weight': 0.03142001842096148,
#   'GOLD weight': 0.025652406034368077,
#   'DAL weight': 0.24602112364011264,
#   'NFLX weight': 0.22316506203965716,
#   'AAPL weight': 0.041683856146412394,
#   'PFE weight': 0.1921107449074373,
#   'BTC weight': 0.04412086690736991},
#  {'Returns': 50.2387203298161,
#   'Volatility': 0.26233912891696376,
#   'SHOP weight': 0.19499462900573034,
#   'TSLA weight': 0.20277379267449042,
#   'GOLD weight': 0.13926424157153874,
#   'DAL weight': 0.12968243507419716,
#   'NFLX weight': 0.056139219799715576,
#   'AAPL weight': 0.11586537226416743,
#   'PFE weight': 0.08746399371918566,
#   'BTC weight': 0.07381631589097469},
#  {'Returns': 66.13686968612384,
#   'Volatility': 0.21515642543795427,
#   'SHOP weight': 0.17297773184084586,
#   'TSLA weight': 0.10681026601865001,
#   'GOLD weight': 0.006680280307729658,
#   'DAL weight': 0.2553790550009299,
#   'NFLX weight': 0.030988428405654314,
# ...
#   'PFE weight': 0.12498338129637848,
#   'BTC weight': 0.21727520998954658},
#  {'Returns': 65.94776954173767,
#   'Volatility': 0.20607612159749572,
#   'SHOP weight': 0.15339245306237045,
#   'TSLA weight': 0.019641434345999725,
#   'GOLD weight': 0.06747044105078676,
#   'DAL weight': 0.15554417021090142,
#   'NFLX weight': 0.15956011952762278,
#   'AAPL weight': 0.11973661155573224,
#   'PFE weight': 0.1814289720289571,
#   'BTC weight': 0.14322579821762949},
#  {'Returns': 62.700543176821256,
#   'Volatility': 0.271707190719473,
#   'SHOP weight': 0.215998565932763,
#   'TSLA weight': 0.15672094675301568,
#   'GOLD weight': 0.07808597209214597,
#   'DAL weight': 0.1097412279546023,
#   'NFLX weight': 0.17056332962949367,
#   'AAPL weight': 0.12082613908078804,
#   'PFE weight': 0.029061367553771603,
#   'BTC weight': 0.11900245100341986},
#  {'Returns': 76.82787110283496,
#   'Volatility': 0.21789808532968005,
#   'SHOP weight': 0.0788243638267312,
#   'TSLA weight': 0.012474688768348867,
#   'GOLD weight': 0.1880522813343987,
#   'DAL weight': 0.07944095787061288,
#   'NFLX weight': 0.016983986860762034,
#   'AAPL weight': 0.19196285867048155,
#   'PFE weight': 0.23050862916254306,
#   'BTC weight': 0.2017522335061218},
#  {'Returns': 69.2602642245434,
#   'Volatility': 0.2353015694295731,
#   'SHOP weight': 0.13821390648720278,
#   'TSLA weight': 0.15052447403400107,
#   'GOLD weight': 0.07454620986195576,
#   'DAL weight': 0.15968492983933025,
#   'NFLX weight': 0.08960799801000643,
#   'AAPL weight': 0.09148290671196055,
#   'PFE weight': 0.1592115384553723,
#   'BTC weight': 0.1367280366001708},
#  {'Returns': 90.75241867507766,
#   'Volatility': 0.2567515767404794,
#   'SHOP weight': 0.06524902851821617,
#   'TSLA weight': 0.14369061567382088,
#   'GOLD weight': 0.10702881377214693,
#   'DAL weight': 0.11844892519294924,
#   'NFLX weight': 0.08590242503840759,
#   'AAPL weight': 0.10546798545844716,
#   'PFE weight': 0.1499447444661826,
#   'BTC weight': 0.22426746187982935},
#  {'Returns': 31.862971846542617,
#   'Volatility': 0.20100892304849483,
#   'SHOP weight': 0.15427350220248187,
#   'TSLA weight': 0.06826503169822916,
#   'GOLD weight': 0.12639371997267326,
#   'DAL weight': 0.2201829020323419,
#   'NFLX weight': 0.009252736647146442,
#   'AAPL weight': 0.18475400734248618,
#   'PFE weight': 0.2167278371870346,
#   'BTC weight': 0.020150262917606562},
#  {'Returns': 46.594694342297146,
#   'Volatility': 0.20278747588428217,
#   'SHOP weight': 0.027870491365542188,
#   'TSLA weight': 0.09945033006187554,
#   'GOLD weight': 0.1649206807127659,
#   'DAL weight': 0.07886402166676425,
#   'NFLX weight': 0.12808637730865716,
#   'AAPL weight': 0.21393566062733504,
#   'PFE weight': 0.19181070289026186,
#   'BTC weight': 0.09506173536679816},
#  {'Returns': 30.308973414316572,
#   'Volatility': 0.1950061518284082,
#   'SHOP weight': 0.08767120280837998,
#   'TSLA weight': 0.007174545272589023,
#   'GOLD weight': 0.1126707675506275,
#   'DAL weight': 0.37466016128595797,
#   'NFLX weight': 0.13655643465895997,
#   'AAPL weight': 0.02241012166909297,
#   'PFE weight': 0.23198095569213206,
#   'BTC weight': 0.026875811062260523},
#  {'Returns': 105.14058638263893,
#   'Volatility': 0.30684692863230933,
#   'SHOP weight': 0.12512258988656658,
#   'TSLA weight': 0.26166790103679455,
#   'GOLD weight': 0.06432087212408238,
#   'DAL weight': 0.0731316825887568,
#   'NFLX weight': 0.03523588250195769,
#   'AAPL weight': 0.01775642113031487,
#   'PFE weight': 0.1810851417904528,
#   'BTC weight': 0.24167950894107434},
#  {'Returns': 83.84787881229686,
#   'Volatility': 0.27177530869680144,
#   'SHOP weight': 0.16069895444346072,
#   'TSLA weight': 0.16531377789193216,
#   'GOLD weight': 0.12342983938506367,
#   'DAL weight': 0.07804687658218333,
#   'NFLX weight': 0.00821608919547897,
#   'AAPL weight': 0.17245709016171065,
#   'PFE weight': 0.09951362850095902,
#   'BTC weight': 0.19232374383921153},
#  {'Returns': 48.55731496060302,
#   'Volatility': 0.20504897825006815,
#   'SHOP weight': 0.1047755079435439,
#   'TSLA weight': 0.08367777080161623,
#   'GOLD weight': 0.1112499693492759,
#   'DAL weight': 0.21419327100373015,
#   'NFLX weight': 0.08469761104785928,
#   'AAPL weight': 0.1707899447704114,
#   'PFE weight': 0.14695085056319646,
#   'BTC weight': 0.0836650745203667},
#  {'Returns': 66.1519847792117,
#   'Volatility': 0.26172922467183185,
#   'SHOP weight': 0.01796361063154212,
#   'TSLA weight': 0.2322954865100796,
#   'GOLD weight': 0.15539768984301555,
#   'DAL weight': 0.18300476884589656,
#   'NFLX weight': 0.13059181468563977,
#   'AAPL weight': 0.07500650567392358,
#   'PFE weight': 0.06028913950170408,
#   'BTC weight': 0.14545098430819875},
#  {'Returns': 88.9416329932836,
#   'Volatility': 0.25366304122815364,
#   'SHOP weight': 0.1337249523495209,
#   'TSLA weight': 0.006998809304440718,
#   'GOLD weight': 0.15663398927876945,
#   'DAL weight': 0.0809529085988391,
#   'NFLX weight': 0.024130712988673142,
#   'AAPL weight': 0.25657545957431344,
#   'PFE weight': 0.10088180730580608,
#   'BTC weight': 0.24010136059963713},
#  {'Returns': 49.20949269902194,
#   'Volatility': 0.22944387848811812,
#   'SHOP weight': 0.18452806206335923,
#   'TSLA weight': 0.011476527863018799,
#   'GOLD weight': 0.16298838174082975,
#   'DAL weight': 0.012345588652369711,
#   'NFLX weight': 0.16397056150153844,
#   'AAPL weight': 0.2390295230973045,
#   'PFE weight': 0.11658577946061355,
#   'BTC weight': 0.10907557562096616},
#  {'Returns': 72.13596703830382,
#   'Volatility': 0.28231433494227665,
#   'SHOP weight': 0.1409400372310024,
#   'TSLA weight': 0.2076386781200278,
#   'GOLD weight': 0.01763967743405445,
#   'DAL weight': 0.00374178728360903,
#   'NFLX weight': 0.1704495203250849,
#   'AAPL weight': 0.18825943433185216,
#   'PFE weight': 0.13231171883299206,
#   'BTC weight': 0.13901914644137728},
#  {'Returns': 75.48275354762305,
#   'Volatility': 0.2474344504721604,
#   'SHOP weight': 0.13064988838333436,
#   'TSLA weight': 0.1316043355536479,
#   'GOLD weight': 0.025768936552198803,
#   'DAL weight': 0.02403221940311927,
#   'NFLX weight': 0.13202450024007015,
#   'AAPL weight': 0.20110019726419537,
#   'PFE weight': 0.19731160294867392,
#   'BTC weight': 0.15750831965476023},
#  {'Returns': 41.771077035231926,
#   'Volatility': 0.24098328310598974,
#   'SHOP weight': 0.1871195175543886,
#   'TSLA weight': 0.16172714757740872,
#   'GOLD weight': 0.05382398264125824,
#   'DAL weight': 0.15774839525116394,
#   'NFLX weight': 0.18863237050445733,
#   'AAPL weight': 0.05261893998234209,
#   'PFE weight': 0.1597407999292666,
#   'BTC weight': 0.03858884655971438},
#  {'Returns': 85.67207172419532,
#   'Volatility': 0.2866227840894001,
#   'SHOP weight': 0.11333718477774031,
#   'TSLA weight': 0.20687337424663055,
#   'GOLD weight': 0.13939751779117926,
#   'DAL weight': 0.0870814687596903,
#   'NFLX weight': 0.11566091083814499,
#   'AAPL weight': 0.09286063789800116,
#   'PFE weight': 0.03741024029770333,
#   'BTC weight': 0.2073786653909102},
#  {'Returns': 55.60361001448064,
#   'Volatility': 0.2102377258798922,
#   'SHOP weight': 0.10986962020659219,
#   'TSLA weight': 0.10873569124033608,
#   'GOLD weight': 0.06824743982786814,
#   'DAL weight': 0.16587336298885674,
#   'NFLX weight': 0.07275588297056307,
#   'AAPL weight': 0.17747104346452428,
#   'PFE weight': 0.20235917795134709,
#   'BTC weight': 0.09468778134991251},
#  {'Returns': 125.18501217807501,
#   'Volatility': 0.31511587531314555,
#   'SHOP weight': 0.021838479726970533,
#   'TSLA weight': 0.10817796610323162,
#   'GOLD weight': 0.08767240783295356,
#   'DAL weight': 0.10232237650675484,
#   'NFLX weight': 0.056313408648047625,
#   'AAPL weight': 0.12510650989084016,
#   'PFE weight': 0.15294823533761556,
#   'BTC weight': 0.34562061595358606},
#  {'Returns': 56.5377062366847,
#   'Volatility': 0.2538853223715368,
#   'SHOP weight': 0.12895622462876036,
#   'TSLA weight': 0.17326165225430196,
#   'GOLD weight': 0.11586043590791055,
#   'DAL weight': 0.15715208297232416,
#   'NFLX weight': 0.17343041354851857,
#   'AAPL weight': 0.11301957233675515,
#   'PFE weight': 0.029687065463320964,
#   'BTC weight': 0.10863255288810823},
#  {'Returns': 79.9018302696746,
#   'Volatility': 0.2546507702454868,
#   'SHOP weight': 0.02097685311093155,
#   'TSLA weight': 0.18968923101211715,
#   'GOLD weight': 0.13680875348662694,
#   'DAL weight': 0.048449690157414294,
#   'NFLX weight': 0.137092719708084,
#   'AAPL weight': 0.10456307887252701,
#   'PFE weight': 0.1685502173744203,
#   'BTC weight': 0.1938694562778787},
#  {'Returns': 54.06493254122699,
#   'Volatility': 0.28569204675756327,
#   'SHOP weight': 0.022895391453512656,
#   'TSLA weight': 0.2832031985524544,
#   'GOLD weight': 0.0011028653675822864,
#   'DAL weight': 0.08077597373628076,
#   'NFLX weight': 0.23982077314961275,
#   'AAPL weight': 0.17489203996996347,
#   'PFE weight': 0.12080895366431818,
#   'BTC weight': 0.07650080410627544},
#  {'Returns': 61.24825517493122,
#   'Volatility': 0.23068910967405357,
#   'SHOP weight': 0.07266386676333396,
#   'TSLA weight': 0.15217148512090176,
#   'GOLD weight': 0.12256748497913701,
#   'DAL weight': 0.14113489510054708,
#   'NFLX weight': 0.11527187319530081,
#   'AAPL weight': 0.14753694388186844,
#   'PFE weight': 0.12157108022439304,
#   'BTC weight': 0.12708237073451786},
#  {'Returns': 81.98141177572195,
#   'Volatility': 0.27990954790407735,
#   'SHOP weight': 0.01913223576362813,
#   'TSLA weight': 0.19445540591629043,
#   'GOLD weight': 0.0425827526220774,
#   'DAL weight': 0.05883240076310766,
#   'NFLX weight': 0.2645520022022758,
#   'AAPL weight': 0.16497692557249716,
#   'PFE weight': 0.059924194389456266,
#   'BTC weight': 0.19554408277066712},
#  {'Returns': 41.43889951459936,
#   'Volatility': 0.2764488599389155,
#   'SHOP weight': 0.20204468299846584,
#   'TSLA weight': 0.20947577865421624,
#   'GOLD weight': 0.1606855089067612,
#   'DAL weight': 0.15106806671826542,
#   'NFLX weight': 0.20987117699748192,
#   'AAPL weight': 0.0017034519320437177,
#   'PFE weight': 0.009031431297170264,
#   'BTC weight': 0.05611990249559534},
#  {'Returns': 55.84011953071813,
#   'Volatility': 0.21697042702685876,
#   'SHOP weight': 0.01890433827879681,
#   'TSLA weight': 0.12952841545059743,
#   'GOLD weight': 0.08875959481424366,
#   'DAL weight': 0.19599164849597023,
#   'NFLX weight': 0.19866973673909366,
#   'AAPL weight': 0.12369519436865001,
#   'PFE weight': 0.13190324915834314,
#   'BTC weight': 0.11254782269430508},
#  {'Returns': 41.8216469496588,
#   'Volatility': 0.25556561154788304,
#   'SHOP weight': 0.16566212279749867,
#   'TSLA weight': 0.16762825219421978,
#   'GOLD weight': 0.153084705202554,
#   'DAL weight': 0.14030134930663413,
#   'NFLX weight': 0.21309167436649398,
#   'AAPL weight': 0.06788355750836128,
#   'PFE weight': 0.02748112016557942,
#   'BTC weight': 0.06486721845865881},
#  {'Returns': 41.80173522072437,
#   'Volatility': 0.27550920640090304,
#   'SHOP weight': 0.0353845090316193,
#   'TSLA weight': 0.27353920421445876,
#   'GOLD weight': 0.23157407563827842,
#   'DAL weight': 0.03705474150620628,
#   'NFLX weight': 0.04923723435704347,
#   'AAPL weight': 0.20900035967151423,
#   'PFE weight': 0.09635941083534524,
#   'BTC weight': 0.06785046474553437},
#  {'Returns': 84.48151077436901,
#   'Volatility': 0.26352375571637526,
#   'SHOP weight': 0.003680014085017863,
#   'TSLA weight': 0.12632320084054166,
#   'GOLD weight': 0.19867429997995276,
#   'DAL weight': 0.24627423545399404,
#   'NFLX weight': 0.09419471150638718,
#   'AAPL weight': 0.0647340413211254,
#   'PFE weight': 0.03798467416846616,
#   'BTC weight': 0.22813482264451498},
#  {'Returns': 33.313378078640014,
#   'Volatility': 0.22601365421707917,
#   'SHOP weight': 0.1829056957127035,
#   'TSLA weight': 0.06745697003599455,
#   'GOLD weight': 0.03744007802049064,
#   'DAL weight': 0.0367680024417937,
#   'NFLX weight': 0.2511779129131888,
#   'AAPL weight': 0.14825886227732354,
#   'PFE weight': 0.2531899494779866,
#   'BTC weight': 0.02280252912051865},
#  {'Returns': 36.658333529495025,
#   'Volatility': 0.2655539739276776,
#   'SHOP weight': 0.2568530210678597,
#   'TSLA weight': 0.14151921135074352,
#   'GOLD weight': 0.08458587716008412,
#   'DAL weight': 0.22464343531515696,
#   'NFLX weight': 0.05379319112639547,
#   'AAPL weight': 0.19162599450059886,
#   'PFE weight': 0.025610926213099548,
#   'BTC weight': 0.021368343266061726},
#  {'Returns': 54.822191110514,
#   'Volatility': 0.1994951381462211,
#   'SHOP weight': 0.21029594188290873,
#   'TSLA weight': 0.016708853395066888,
#   'GOLD weight': 0.04348367215580874,
#   'DAL weight': 0.2141755279710041,
#   'NFLX weight': 0.14761552103744807,
#   'AAPL weight': 0.055456832895349084,
#   'PFE weight': 0.2199999010606734,
#   'BTC weight': 0.09226374960174105},
#  {'Returns': 50.20227011439547,
#   'Volatility': 0.21115555718022938,
#   'SHOP weight': 0.25149304205741774,
#   'TSLA weight': 0.013106724155870707,
#   'GOLD weight': 0.1055052487101691,
#   'DAL weight': 0.3077814475750394,
#   'NFLX weight': 0.07663181236058103,
#   'AAPL weight': 0.0035031972520867937,
#   'PFE weight': 0.16164694646528094,
#   'BTC weight': 0.08033158142355429},
#  {'Returns': 24.906467149183285,
#   'Volatility': 0.24331956893248408,
#   'SHOP weight': 0.0992119967738759,
#   'TSLA weight': 0.06434279802402051,
#   'GOLD weight': 0.05612523409923027,
#   'DAL weight': 0.031820073102112156,
#   'NFLX weight': 0.35493563714964776,
#   'AAPL weight': 0.2444340030056147,
#   'PFE weight': 0.13264679397841855,
#   'BTC weight': 0.016483463867080158},
#  {'Returns': 53.952283110620904,
#   'Volatility': 0.24861042444133608,
#   'SHOP weight': 0.13161666895433438,
#   'TSLA weight': 0.1444740538932536,
#   'GOLD weight': 0.06886130557613127,
#   'DAL weight': 0.1317589580319113,
#   'NFLX weight': 0.18191286924379027,
#   'AAPL weight': 0.1930885788772059,
#   'PFE weight': 0.052419062111635474,
#   'BTC weight': 0.0958685033117377},
#  {'Returns': 31.93113712409705,
#   'Volatility': 0.25251522128728,
#   'SHOP weight': 0.14307330072106053,
#   'TSLA weight': 0.1904100911062336,
#   'GOLD weight': 0.17097214587405984,
#   'DAL weight': 0.05482197215137312,
#   'NFLX weight': 0.1179396894777473,
#   'AAPL weight': 0.15952521032910852,
#   'PFE weight': 0.13689507252882102,
#   'BTC weight': 0.026362517811596053},
#  {'Returns': 37.77609938433686,
#   'Volatility': 0.21406231415276342,
#   'SHOP weight': 0.010260789518563868,
#   'TSLA weight': 0.1225173087753969,
#   'GOLD weight': 0.045622033768983425,
#   'DAL weight': 0.12267570064372282,
#   'NFLX weight': 0.21332673291287657,
#   'AAPL weight': 0.2489515387372071,
#   'PFE weight': 0.19054754568636662,
#   'BTC weight': 0.04609834995688272},
#  {'Returns': 20.599683243229705,
#   'Volatility': 0.227533868701547,
#   'SHOP weight': 0.04422977303463691,
#   'TSLA weight': 0.10848317146309772,
#   'GOLD weight': 0.22221326139489658,
#   'DAL weight': 0.1791275085850893,
#   'NFLX weight': 0.1710444831887193,
#   'AAPL weight': 0.24196753832262566,
#   'PFE weight': 0.011393522074474728,
#   'BTC weight': 0.021540741936459742},
#  {'Returns': 51.542560450686274,
#   'Volatility': 0.2266174372477731,
#   'SHOP weight': 0.152620509016822,
#   'TSLA weight': 0.08064326763669252,
#   'GOLD weight': 0.11336470138029041,
#   'DAL weight': 0.16043990319750734,
#   'NFLX weight': 0.1536777537580839,
#   'AAPL weight': 0.1797372892791844,
#   'PFE weight': 0.06006686062928465,
#   'BTC weight': 0.09944971510213477},
#  {'Returns': 70.95453883309452,
#   'Volatility': 0.23783242019608528,
#   'SHOP weight': 0.12037926404368476,
#   'TSLA weight': 0.0901668468551579,
#   'GOLD weight': 0.08991895870272544,
#   'DAL weight': 0.18086549798780593,
#   'NFLX weight': 0.12721553237051142,
#   'AAPL weight': 0.17770974072476217,
#   'PFE weight': 0.05230719385887687,
#   'BTC weight': 0.1614369654564755},
#  {'Returns': 85.51207342162274,
#   'Volatility': 0.28880151226533074,
#   'SHOP weight': 0.2188991903761281,
#   'TSLA weight': 0.19111442729830547,
#   'GOLD weight': 0.058043652302707784,
#   'DAL weight': 0.049245344569668545,
#   'NFLX weight': 0.12570518950112913,
#   'AAPL weight': 0.06649820968753715,
#   'PFE weight': 0.10652653425077982,
#   'BTC weight': 0.18396745201374384},
#  {'Returns': 86.20472423023944,
#   'Volatility': 0.2700713112910251,
#   'SHOP weight': 0.19142718049806304,
#   'TSLA weight': 0.16451825817354426,
#   'GOLD weight': 0.13701611251903648,
#   'DAL weight': 0.11254924858845988,
#   'NFLX weight': 0.05992847464914711,
#   'AAPL weight': 0.027535754429994803,
#   'PFE weight': 0.10637878126021837,
#   'BTC weight': 0.20064618988153593}]

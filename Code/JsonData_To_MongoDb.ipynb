# %%
# Module used to connect Python with MongoDb
import pymongo
import json

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Drop database if exists
client.drop_database('stocksDB')

# %%
database_list = client.list_database_names()
print ("db names:", database_list)
# Out:
# db names: ['ClassDB', 'ClassID', 'admin', 'config', 'fruits_db', 'local', 'mars_app', 'phone_app', 'store_inventory', 'team_db', 'travel_db']

# %%
# Define the 'stocksDB' database in Mongo
db = client['stocksDB']

# %%
#Read the Data folder and create collection for each file
import os
for file in os.listdir("../Data"):
    if file.endswith(".json"):
        name = file.split('.')[0]
        collection = db[name]
        f = open(f"../Data/{file}")
        data = json.load(f)
        collection.insert_many(data)
        f.close()

# %%
#List all the newly created collections
col_list = db.list_collection_names()
print ("collections on the db:", col_list)
# Out:
# collections on the db: ['NFLX_prices', 'portfolio_data', 'SHOP_prices', 'DAL_prices', 'BTC_prices', 'TSLA_prices', 'GOLD_prices', 'AAPL_prices', 'PFE_prices']

# %%
#Verify if data was inserted correctly
data = db.BTC_prices.find()
for row in data:
    print(row)
# Out:
# {'_id': ObjectId('612b981d96c7bf3bde6b0b65'), 'date': 1629379800, 'adjclose': 99.61, 'formatted_date': '2021-08-19'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b66'), 'date': 1629293400, 'adjclose': 99.55, 'formatted_date': '2021-08-18'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b67'), 'date': 1629207000, 'adjclose': 99.6, 'formatted_date': '2021-08-17'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b68'), 'date': 1629120600, 'adjclose': 99.65, 'formatted_date': '2021-08-16'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b69'), 'date': 1628861400, 'adjclose': 99.58, 'formatted_date': '2021-08-13'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b6a'), 'date': 1628775000, 'adjclose': 99.44, 'formatted_date': '2021-08-12'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b6b'), 'date': 1628688600, 'adjclose': 99.47, 'formatted_date': '2021-08-11'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b6c'), 'date': 1628602200, 'adjclose': 99.39, 'formatted_date': '2021-08-10'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b6d'), 'date': 1628515800, 'adjclose': 99.48, 'formatted_date': '2021-08-09'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b6e'), 'date': 1628256600, 'adjclose': 99.56, 'formatted_date': '2021-08-06'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b6f'), 'date': 1628170200, 'adjclose': 99.74, 'formatted_date': '2021-08-05'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b70'), 'date': 1628083800, 'adjclose': 99.85, 'formatted_date': '2021-08-04'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b71'), 'date': 1627997400, 'adjclose': 99.9, 'formatted_date': '2021-08-03'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b72'), 'date': 1627911000, 'adjclose': 99.9, 'formatted_date': '2021-08-02'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b73'), 'date': 1627651800, 'adjclose': 99.78, 'formatted_date': '2021-07-30'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b74'), 'date': 1627565400, 'adjclose': 99.7, 'formatted_date': '2021-07-29'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b75'), 'date': 1627479000, 'adjclose': 99.75, 'formatted_date': '2021-07-28'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b76'), 'date': 1627392600, 'adjclose': 99.72, 'formatted_date': '2021-07-27'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b77'), 'date': 1627306200, 'adjclose': 99.65, 'formatted_date': '2021-07-26'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b78'), 'date': 1627047000, 'adjclose': 99.64, 'formatted_date': '2021-07-23'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b79'), 'date': 1626960600, 'adjclose': 99.64, 'formatted_date': '2021-07-22'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b7a'), 'date': 1626874200, 'adjclose': 99.55, 'formatted_date': '2021-07-21'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b7b'), 'date': 1626787800, 'adjclose': 99.71, 'formatted_date': '2021-07-20'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b7c'), 'date': 1626701400, 'adjclose': 99.65, 'formatted_date': '2021-07-19'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b7d'), 'date': 1626442200, 'adjclose': 99.11, 'formatted_date': '2021-07-16'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b7e'), 'date': 1626355800, 'adjclose': 99.11, 'formatted_date': '2021-07-15'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b7f'), 'date': 1626269400, 'adjclose': 99.11, 'formatted_date': '2021-07-14'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b80'), 'date': 1626183000, 'adjclose': 99.11, 'formatted_date': '2021-07-13'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b81'), 'date': 1626096600, 'adjclose': 99.11, 'formatted_date': '2021-07-12'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b82'), 'date': 1625837400, 'adjclose': 99.11, 'formatted_date': '2021-07-09'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b83'), 'date': 1625751000, 'adjclose': 99.11, 'formatted_date': '2021-07-08'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b84'), 'date': 1625664600, 'adjclose': 99.11, 'formatted_date': '2021-07-07'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b85'), 'date': 1625578200, 'adjclose': 99.11, 'formatted_date': '2021-07-06'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b86'), 'date': 1625232600, 'adjclose': 99.11, 'formatted_date': '2021-07-02'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b87'), 'date': 1625146200, 'adjclose': 99.11, 'formatted_date': '2021-07-01'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b88'), 'date': 1625059800, 'adjclose': 99.11, 'formatted_date': '2021-06-30'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b89'), 'date': 1624973400, 'adjclose': 99.11, 'formatted_date': '2021-06-29'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b8a'), 'date': 1624887000, 'adjclose': 99.11, 'formatted_date': '2021-06-28'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b8b'), 'date': 1624627800, 'adjclose': 99.11, 'formatted_date': '2021-06-25'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b8c'), 'date': 1624541400, 'adjclose': 99.11, 'formatted_date': '2021-06-24'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b8d'), 'date': 1624455000, 'adjclose': 99.11, 'formatted_date': '2021-06-23'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b8e'), 'date': 1624368600, 'adjclose': 99.11, 'formatted_date': '2021-06-22'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b8f'), 'date': 1624282200, 'adjclose': 99.11, 'formatted_date': '2021-06-21'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b90'), 'date': 1624023000, 'adjclose': 99.11, 'formatted_date': '2021-06-18'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b91'), 'date': 1623936600, 'adjclose': 99.11, 'formatted_date': '2021-06-17'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b92'), 'date': 1623850200, 'adjclose': 99.11, 'formatted_date': '2021-06-16'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b93'), 'date': 1623763800, 'adjclose': 99.11, 'formatted_date': '2021-06-15'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b94'), 'date': 1623677400, 'adjclose': 99.11, 'formatted_date': '2021-06-14'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b95'), 'date': 1623418200, 'adjclose': 99.11, 'formatted_date': '2021-06-11'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b96'), 'date': 1623331800, 'adjclose': 99.11, 'formatted_date': '2021-06-10'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b97'), 'date': 1623245400, 'adjclose': 99.11, 'formatted_date': '2021-06-09'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b98'), 'date': 1623159000, 'adjclose': 99.11, 'formatted_date': '2021-06-08'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b99'), 'date': 1623072600, 'adjclose': 99.11, 'formatted_date': '2021-06-07'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b9a'), 'date': 1622813400, 'adjclose': 99.11, 'formatted_date': '2021-06-04'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b9b'), 'date': 1622727000, 'adjclose': 99.11, 'formatted_date': '2021-06-03'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b9c'), 'date': 1622640600, 'adjclose': 99.11, 'formatted_date': '2021-06-02'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b9d'), 'date': 1622554200, 'adjclose': 99.11, 'formatted_date': '2021-06-01'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b9e'), 'date': 1622208600, 'adjclose': 99.11, 'formatted_date': '2021-05-28'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0b9f'), 'date': 1622122200, 'adjclose': 99.11, 'formatted_date': '2021-05-27'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0ba0'), 'date': 1622035800, 'adjclose': 99.11, 'formatted_date': '2021-05-26'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0ba1'), 'date': 1621949400, 'adjclose': 99.11, 'formatted_date': '2021-05-25'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0ba2'), 'date': 1621863000, 'adjclose': 99.11, 'formatted_date': '2021-05-24'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0ba3'), 'date': 1621603800, 'adjclose': 99.11, 'formatted_date': '2021-05-21'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0ba4'), 'date': 1621517400, 'adjclose': 99.11, 'formatted_date': '2021-05-20'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0ba5'), 'date': 1621431000, 'adjclose': 99.11, 'formatted_date': '2021-05-19'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0ba6'), 'date': 1621344600, 'adjclose': 99.11, 'formatted_date': '2021-05-18'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0ba7'), 'date': 1621258200, 'adjclose': 99.11, 'formatted_date': '2021-05-17'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0ba8'), 'date': 1620999000, 'adjclose': 99.11, 'formatted_date': '2021-05-14'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0ba9'), 'date': 1620912600, 'adjclose': 99.11, 'formatted_date': '2021-05-13'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0baa'), 'date': 1620826200, 'adjclose': 99.11, 'formatted_date': '2021-05-12'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bab'), 'date': 1620739800, 'adjclose': 99.11, 'formatted_date': '2021-05-11'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bac'), 'date': 1620653400, 'adjclose': 99.11, 'formatted_date': '2021-05-10'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bad'), 'date': 1620394200, 'adjclose': 99.15, 'formatted_date': '2021-05-07'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bae'), 'date': 1620307800, 'adjclose': 99.07, 'formatted_date': '2021-05-06'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0baf'), 'date': 1620221400, 'adjclose': 99.06, 'formatted_date': '2021-05-05'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bb0'), 'date': 1620135000, 'adjclose': 98.99, 'formatted_date': '2021-05-04'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bb1'), 'date': 1620048600, 'adjclose': 98.94, 'formatted_date': '2021-05-03'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bb2'), 'date': 1619789400, 'adjclose': 98.89, 'formatted_date': '2021-04-30'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bb3'), 'date': 1619703000, 'adjclose': 98.86, 'formatted_date': '2021-04-29'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bb4'), 'date': 1619616600, 'adjclose': 98.89, 'formatted_date': '2021-04-28'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bb5'), 'date': 1619530200, 'adjclose': 98.83, 'formatted_date': '2021-04-27'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bb6'), 'date': 1619443800, 'adjclose': 98.97, 'formatted_date': '2021-04-26'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bb7'), 'date': 1619184600, 'adjclose': 98.98, 'formatted_date': '2021-04-23'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bb8'), 'date': 1619098200, 'adjclose': 99.0, 'formatted_date': '2021-04-22'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bb9'), 'date': 1619011800, 'adjclose': 98.97, 'formatted_date': '2021-04-21'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bba'), 'date': 1618925400, 'adjclose': 99.04, 'formatted_date': '2021-04-20'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bbb'), 'date': 1618839000, 'adjclose': 99.1, 'formatted_date': '2021-04-19'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bbc'), 'date': 1618579800, 'adjclose': 99.24, 'formatted_date': '2021-04-16'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bbd'), 'date': 1618493400, 'adjclose': 99.01, 'formatted_date': '2021-04-15'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bbe'), 'date': 1618407000, 'adjclose': 98.81, 'formatted_date': '2021-04-14'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bbf'), 'date': 1618320600, 'adjclose': 98.82, 'formatted_date': '2021-04-13'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bc0'), 'date': 1618234200, 'adjclose': 98.71, 'formatted_date': '2021-04-12'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bc1'), 'date': 1617975000, 'adjclose': 98.76, 'formatted_date': '2021-04-09'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bc2'), 'date': 1617888600, 'adjclose': 98.82, 'formatted_date': '2021-04-08'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bc3'), 'date': 1617802200, 'adjclose': 98.72, 'formatted_date': '2021-04-07'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bc4'), 'date': 1617715800, 'adjclose': 98.71, 'formatted_date': '2021-04-06'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bc5'), 'date': 1617629400, 'adjclose': 98.52, 'formatted_date': '2021-04-05'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bc6'), 'date': 1617283800, 'adjclose': 98.64, 'formatted_date': '2021-04-01'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bc7'), 'date': 1617197400, 'adjclose': 98.51, 'formatted_date': '2021-03-31'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bc8'), 'date': 1617111000, 'adjclose': 98.51, 'formatted_date': '2021-03-30'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bc9'), 'date': 1617024600, 'adjclose': 98.54, 'formatted_date': '2021-03-29'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bca'), 'date': 1616765400, 'adjclose': 98.64, 'formatted_date': '2021-03-26'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bcb'), 'date': 1616679000, 'adjclose': 98.73, 'formatted_date': '2021-03-25'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bcc'), 'date': 1616592600, 'adjclose': 98.73, 'formatted_date': '2021-03-24'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bcd'), 'date': 1616506200, 'adjclose': 98.69, 'formatted_date': '2021-03-23'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bce'), 'date': 1616419800, 'adjclose': 98.57, 'formatted_date': '2021-03-22'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bcf'), 'date': 1616160600, 'adjclose': 98.48, 'formatted_date': '2021-03-19'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bd0'), 'date': 1616074200, 'adjclose': 98.49, 'formatted_date': '2021-03-18'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bd1'), 'date': 1615987800, 'adjclose': 98.7, 'formatted_date': '2021-03-17'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bd2'), 'date': 1615901400, 'adjclose': 98.63, 'formatted_date': '2021-03-16'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bd3'), 'date': 1615815000, 'adjclose': 98.62, 'formatted_date': '2021-03-15'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bd4'), 'date': 1615559400, 'adjclose': 98.59, 'formatted_date': '2021-03-12'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bd5'), 'date': 1615473000, 'adjclose': 98.84, 'formatted_date': '2021-03-11'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bd6'), 'date': 1615386600, 'adjclose': 98.74, 'formatted_date': '2021-03-10'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bd7'), 'date': 1615300200, 'adjclose': 98.62, 'formatted_date': '2021-03-09'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bd8'), 'date': 1615213800, 'adjclose': 98.53, 'formatted_date': '2021-03-08'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bd9'), 'date': 1614954600, 'adjclose': 98.76, 'formatted_date': '2021-03-05'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bda'), 'date': 1614868200, 'adjclose': 98.85, 'formatted_date': '2021-03-04'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bdb'), 'date': 1614781800, 'adjclose': 99.01, 'formatted_date': '2021-03-03'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bdc'), 'date': 1614695400, 'adjclose': 99.18, 'formatted_date': '2021-03-02'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bdd'), 'date': 1614609000, 'adjclose': 99.11, 'formatted_date': '2021-03-01'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bde'), 'date': 1614349800, 'adjclose': 98.98, 'formatted_date': '2021-02-26'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bdf'), 'date': 1614263400, 'adjclose': 98.75, 'formatted_date': '2021-02-25'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0be0'), 'date': 1614177000, 'adjclose': 99.36, 'formatted_date': '2021-02-24'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0be1'), 'date': 1614090600, 'adjclose': 99.4, 'formatted_date': '2021-02-23'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0be2'), 'date': 1614004200, 'adjclose': 99.36, 'formatted_date': '2021-02-22'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0be3'), 'date': 1613745000, 'adjclose': 99.46, 'formatted_date': '2021-02-19'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0be4'), 'date': 1613658600, 'adjclose': 99.58, 'formatted_date': '2021-02-18'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0be5'), 'date': 1613572200, 'adjclose': 99.57, 'formatted_date': '2021-02-17'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0be6'), 'date': 1613485800, 'adjclose': 99.53, 'formatted_date': '2021-02-16'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0be7'), 'date': 1613140200, 'adjclose': 99.78, 'formatted_date': '2021-02-12'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0be8'), 'date': 1613053800, 'adjclose': 99.87, 'formatted_date': '2021-02-11'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0be9'), 'date': 1612967400, 'adjclose': 99.87, 'formatted_date': '2021-02-10'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bea'), 'date': 1612881000, 'adjclose': 99.79, 'formatted_date': '2021-02-09'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0beb'), 'date': 1612794600, 'adjclose': 99.75, 'formatted_date': '2021-02-08'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bec'), 'date': 1612535400, 'adjclose': 99.76, 'formatted_date': '2021-02-05'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bed'), 'date': 1612449000, 'adjclose': 99.79, 'formatted_date': '2021-02-04'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bee'), 'date': 1612362600, 'adjclose': 99.76, 'formatted_date': '2021-02-03'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bef'), 'date': 1612276200, 'adjclose': 99.81, 'formatted_date': '2021-02-02'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bf0'), 'date': 1612189800, 'adjclose': 99.87, 'formatted_date': '2021-02-01'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bf1'), 'date': 1611930600, 'adjclose': 99.85, 'formatted_date': '2021-01-29'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bf2'), 'date': 1611844200, 'adjclose': 99.85, 'formatted_date': '2021-01-28'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bf3'), 'date': 1611757800, 'adjclose': 99.9, 'formatted_date': '2021-01-27'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bf4'), 'date': 1611671400, 'adjclose': 99.92, 'formatted_date': '2021-01-26'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bf5'), 'date': 1611585000, 'adjclose': 99.92, 'formatted_date': '2021-01-25'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bf6'), 'date': 1611325800, 'adjclose': 99.83, 'formatted_date': '2021-01-22'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bf7'), 'date': 1611239400, 'adjclose': 99.79, 'formatted_date': '2021-01-21'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bf8'), 'date': 1611153000, 'adjclose': 99.84, 'formatted_date': '2021-01-20'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bf9'), 'date': 1611066600, 'adjclose': 99.83, 'formatted_date': '2021-01-19'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bfa'), 'date': 1610721000, 'adjclose': 99.81, 'formatted_date': '2021-01-15'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bfb'), 'date': 1610634600, 'adjclose': 99.73, 'formatted_date': '2021-01-14'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bfc'), 'date': 1610548200, 'adjclose': 99.76, 'formatted_date': '2021-01-13'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bfd'), 'date': 1610461800, 'adjclose': 99.66, 'formatted_date': '2021-01-12'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bfe'), 'date': 1610375400, 'adjclose': 99.67, 'formatted_date': '2021-01-11'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0bff'), 'date': 1610116200, 'adjclose': 99.72, 'formatted_date': '2021-01-08'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c00'), 'date': 1610029800, 'adjclose': 99.81, 'formatted_date': '2021-01-07'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c01'), 'date': 1609943400, 'adjclose': 99.87, 'formatted_date': '2021-01-06'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c02'), 'date': 1609857000, 'adjclose': 100.05, 'formatted_date': '2021-01-05'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c03'), 'date': 1609770600, 'adjclose': 100.12, 'formatted_date': '2021-01-04'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c04'), 'date': 1609425000, 'adjclose': 100.15, 'formatted_date': '2020-12-31'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c05'), 'date': 1609338600, 'adjclose': 100.1, 'formatted_date': '2020-12-30'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c06'), 'date': 1609252200, 'adjclose': 100.07, 'formatted_date': '2020-12-29'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c07'), 'date': 1609165800, 'adjclose': 100.06, 'formatted_date': '2020-12-28'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c08'), 'date': 1608820200, 'adjclose': 100.03, 'formatted_date': '2020-12-24'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c09'), 'date': 1608733800, 'adjclose': 99.99, 'formatted_date': '2020-12-23'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c0a'), 'date': 1608647400, 'adjclose': 100.03, 'formatted_date': '2020-12-22'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c0b'), 'date': 1608561000, 'adjclose': 99.96, 'formatted_date': '2020-12-21'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c0c'), 'date': 1608301800, 'adjclose': 99.99, 'formatted_date': '2020-12-18'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c0d'), 'date': 1608215400, 'adjclose': 100.0, 'formatted_date': '2020-12-17'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c0e'), 'date': 1608129000, 'adjclose': 100.0, 'formatted_date': '2020-12-16'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c0f'), 'date': 1608042600, 'adjclose': 100.0, 'formatted_date': '2020-12-15'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c10'), 'date': 1607956200, 'adjclose': 100.0, 'formatted_date': '2020-12-14'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c11'), 'date': 1607697000, 'adjclose': 100.02, 'formatted_date': '2020-12-11'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c12'), 'date': 1607610600, 'adjclose': 99.93, 'formatted_date': '2020-12-10'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c13'), 'date': 1607524200, 'adjclose': 99.86, 'formatted_date': '2020-12-09'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c14'), 'date': 1607437800, 'adjclose': 99.97, 'formatted_date': '2020-12-08'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c15'), 'date': 1607351400, 'adjclose': 99.96, 'formatted_date': '2020-12-07'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c16'), 'date': 1607092200, 'adjclose': 99.86, 'formatted_date': '2020-12-04'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c17'), 'date': 1607005800, 'adjclose': 99.97, 'formatted_date': '2020-12-03'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c18'), 'date': 1606919400, 'adjclose': 99.88, 'formatted_date': '2020-12-02'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c19'), 'date': 1606833000, 'adjclose': 99.9, 'formatted_date': '2020-12-01'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c1a'), 'date': 1606746600, 'adjclose': 100.04, 'formatted_date': '2020-11-30'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c1b'), 'date': 1606487400, 'adjclose': 99.99, 'formatted_date': '2020-11-27'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c1c'), 'date': 1606314600, 'adjclose': 99.91, 'formatted_date': '2020-11-25'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c1d'), 'date': 1606228200, 'adjclose': 99.89, 'formatted_date': '2020-11-24'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c1e'), 'date': 1606141800, 'adjclose': 99.89, 'formatted_date': '2020-11-23'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c1f'), 'date': 1605882600, 'adjclose': 99.92, 'formatted_date': '2020-11-20'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c20'), 'date': 1605796200, 'adjclose': 99.89, 'formatted_date': '2020-11-19'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c21'), 'date': 1605709800, 'adjclose': 99.85, 'formatted_date': '2020-11-18'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c22'), 'date': 1605623400, 'adjclose': 99.85, 'formatted_date': '2020-11-17'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c23'), 'date': 1605537000, 'adjclose': 99.77, 'formatted_date': '2020-11-16'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c24'), 'date': 1605277800, 'adjclose': 99.77, 'formatted_date': '2020-11-13'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c25'), 'date': 1605191400, 'adjclose': 99.77, 'formatted_date': '2020-11-12'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c26'), 'date': 1605105000, 'adjclose': 99.66, 'formatted_date': '2020-11-11'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c27'), 'date': 1605018600, 'adjclose': 99.64, 'formatted_date': '2020-11-10'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c28'), 'date': 1604932200, 'adjclose': 99.75, 'formatted_date': '2020-11-09'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c29'), 'date': 1604673000, 'adjclose': 99.9, 'formatted_date': '2020-11-06'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c2a'), 'date': 1604586600, 'adjclose': 100.0, 'formatted_date': '2020-11-05'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c2b'), 'date': 1604500200, 'adjclose': 99.97, 'formatted_date': '2020-11-04'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c2c'), 'date': 1604413800, 'adjclose': 99.67, 'formatted_date': '2020-11-03'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c2d'), 'date': 1604327400, 'adjclose': 99.7, 'formatted_date': '2020-11-02'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c2e'), 'date': 1604064600, 'adjclose': 99.7, 'formatted_date': '2020-10-30'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c2f'), 'date': 1603978200, 'adjclose': 99.77, 'formatted_date': '2020-10-29'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c30'), 'date': 1603891800, 'adjclose': 99.89, 'formatted_date': '2020-10-28'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c31'), 'date': 1603805400, 'adjclose': 99.92, 'formatted_date': '2020-10-27'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c32'), 'date': 1603719000, 'adjclose': 99.86, 'formatted_date': '2020-10-26'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c33'), 'date': 1603459800, 'adjclose': 99.79, 'formatted_date': '2020-10-23'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c34'), 'date': 1603373400, 'adjclose': 99.75, 'formatted_date': '2020-10-22'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c35'), 'date': 1603287000, 'adjclose': 99.82, 'formatted_date': '2020-10-21'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c36'), 'date': 1603200600, 'adjclose': 99.85, 'formatted_date': '2020-10-20'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c37'), 'date': 1603114200, 'adjclose': 99.89, 'formatted_date': '2020-10-19'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c38'), 'date': 1602855000, 'adjclose': 99.93, 'formatted_date': '2020-10-16'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c39'), 'date': 1602768600, 'adjclose': 99.94, 'formatted_date': '2020-10-15'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c3a'), 'date': 1602682200, 'adjclose': 99.97, 'formatted_date': '2020-10-14'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c3b'), 'date': 1602595800, 'adjclose': 99.96, 'formatted_date': '2020-10-13'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c3c'), 'date': 1602509400, 'adjclose': 99.94, 'formatted_date': '2020-10-12'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c3d'), 'date': 1602250200, 'adjclose': 99.94, 'formatted_date': '2020-10-09'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c3e'), 'date': 1602163800, 'adjclose': 100.0, 'formatted_date': '2020-10-08'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c3f'), 'date': 1602077400, 'adjclose': 99.92, 'formatted_date': '2020-10-07'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c40'), 'date': 1601991000, 'adjclose': 100.03, 'formatted_date': '2020-10-06'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c41'), 'date': 1601904600, 'adjclose': 100.0, 'formatted_date': '2020-10-05'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c42'), 'date': 1601645400, 'adjclose': 100, 'formatted_date': '2020-10-02'}
# {'_id': ObjectId('612b981d96c7bf3bde6b0c43'), 'date': 1601559000, 'adjclose': 100, 'formatted_date': '2020-10-01'}
